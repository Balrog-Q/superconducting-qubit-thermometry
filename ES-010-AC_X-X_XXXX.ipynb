# %% [markdown]
# # Overview

# %% [markdown]
# ## Description
#
# This is a template notebook to tune up a single qubit using the LabOneQ workflow architecture. The following tune-up experiments are implemented:
#
# 1. Resonator Spectroscopy
# 2. Qubit Spectroscopy
# 3. Amplitude Rabi Experiment
# 4. Ramsey Experiment
# 5. T1 Lifetime experiment
# 6. DRAG Calibration
# 7. Hahn-Echo Experiment
#
# All experiments can be performed on the ge and ef transition.

# %% [markdown]
# ## Changelog
#
# All changes must be logged here! Do not make changes to this notebook other than expanding or modifying the standard experiments in a meaningful! All device-specific parameters and measurements have to be done in a different notebook!
#
# Stick to semantic versioning:
# - **Last Digit**: Fix a bug that does not add any new features and is backwards compatible -> increment last digit by one (e.g. 0.0.4 to 0.0.5)
#
# - **Middle Digit**: Add a new feature while keeping backwards compatibility (older versions can still be executed without any modifications) -> increment middle digit by one and set last digit to 0 (e.g. 1.2.12 to 1.3.0)
#
# - **First Digit**: Make changes that will break older versions, making them incompatible with the new version -> increment first digit by one and set all other digits to 0 (e.g. 3.2.9 to 4.0.0)
#
# **Current Version:** 1.0.0
#
# **2026-07-23**, *Elias*: Created this template notebook and added resonator and qubit spectroscopy, amplitude Rabi, Ramsey T1 and DRAG

# %% [markdown]
# # Package Imports and Initialization

# %% [markdown]
# ## LabOne Q Libraries

# %%
# LabOne Q:
from laboneq.simple import *
from laboneq.dsl.quantum import QPU
from laboneq.contrib.example_helpers.generate_descriptor import generate_descriptor
from laboneq.workflow.logbook import LoggingStore
from laboneq.serializers import load, save

# LabOne Q Applications:
from laboneq_applications.qpu_types.tunable_transmon import (
    TunableTransmonQubit,
    TunableTransmonOperations,
)

# Plot:
from laboneq.contrib.example_helpers.plotting.plot_helpers import plot_results, plot_simulation

# Workflows:
from laboneq_applications.experiments import (
    resonator_spectroscopy,
    resonator_spectroscopy_amplitude,
    qubit_spectroscopy,
    amplitude_rabi,
    ramsey,
    drag_q_scaling,
    lifetime_measurement,
    echo,
)

# %% [markdown]
# ## Other Imports

# %%
from copy import deepcopy
from pprint import pprint
import numpy as np
import time
from pathlib import Path
import os

# %%
def set_transition(transition: str):
    assert transition in ['ge', 'ef'], "Choose transition from 'ge' or 'ef'!"
    return transition

def log_sweep_help(t1_min: float, t1_max: float, t1_num: int):
    t1_log_sweep = np.logspace(np.log10(t1_max / t1_num / 10), np.log10(t1_max), t1_num - 1)
    t1_log_sweep_arr = np.append([0.0], t1_log_sweep)
    return t1_log_sweep_arr

# %% [markdown]
# ## Descriptor and Device Setup

# %%
number_of_qubits = 1

descriptor = generate_descriptor(
    #pqsc=["DEV10001"],
    shfqc_2=["DEV12192"],
    number_data_qubits=number_of_qubits,
    multiplex=True,
    number_multiplex=number_of_qubits,
    include_cr_lines=False,
    ip_address="localhost",
    #options = "SHFQC/QC2CH",
)

setup = DeviceSetup.from_descriptor(descriptor, "localhost")
setup.instruments[0].device_options = "SHFQC/QC2CH"

# %%
qubits = TunableTransmonQubit.from_device_setup(setup)

# %% [markdown]
# ## Qubit Initialization

# %%
cooldown_start_date = '2026-07-03' # YYYY-MM-DD
sample_name = 'ES-010-AC_X-X_XXXX'
qubit_name = 'Q2'

assert cooldown_start_date != '', 'Enter cooldown name'
assert sample_name != '', 'Enter sample name'
assert qubit_name != '', 'Enter qubit name'

# %%
for q in qubits:
    q.parameters.ge_drive_pulse["sigma"] = 0.25
    q.parameters.readout_amplitude = 0.5
    q.parameters.reset_delay_length = 150e-6
    q.parameters.readout_range_out = -25
    q.parameters.readout_lo_frequency = 5.2e9
    q.parameters.drive_range = 0
    q.parameters.readout_range_in = -45
    q.parameters.readout_integration_delay = 80e-9

qubits[0].parameters.drive_lo_frequency = 4e9
qubits[0].parameters.resonance_frequency_ge = 4.1e9
qubits[0].parameters.resonance_frequency_ef = 3.9e9
qubits[0].parameters.readout_resonator_frequency = 5.256e9
qubits[0].parameters.spectroscopy_length = 5e-6
qubits[0].parameters.spectroscopy_amplitude = 0.5
qubits[0].uid = qubit_name

# %%
qops = TunableTransmonOperations()
qpu = QPU(qubits, quantum_operations=qops)

# %%
for q in qubits:
    print("-------------")
    print("Qubit UID:", q.uid)
    print("Qubit logical signals:")
    for sig, lsg in q.signals.items():
        print(f"  {sig:<10} ('{lsg:>10}')")
# Out:
# -------------
# Qubit UID: Q2
# Qubit logical signals:
#   drive      ('  q0/drive')
#   drive_ef   ('q0/drive_ef')
#   measure    ('q0/measure')
#   acquire    ('q0/acquire')

# %% [markdown]
# ## LabOne Q Session Connection

# %%
session = Session(setup)
session.connect(do_emulation=False)
# Out:
# [2026.07.24 16:41:48.646] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is C:\Users\phys-pico-lab\Documents\laboneq_workflow_notebooks\samples\ES-010-AC_X-X_XXXX\laboneq_output\log
# [2026.07.24 16:41:48.684] INFO    VERSION: laboneq 26.4.0
# [2026.07.24 16:41:48.690] INFO    Connecting to data server at localhost:8004
# [2026.07.24 16:41:48.733] INFO    Connected to Zurich Instruments LabOne Data Server version 26.04.1.6 at localhost:8004
# [2026.07.24 16:41:48.764] INFO    Configuring the device setup
# [2026.07.24 16:41:48.781] INFO    The device setup is configured
# [2026.07.24 16:41:49.156] INFO    System profile saved to C:\Users\phys-pico-lab\AppData\Local\laboneq\profiles\unknown-613335402d7b7f78058d100a7c9ddd62592a6fd7431fa79c3e5a4ab0cfd13ec3.yaml

# %% [markdown]
# ## Data Saving

# %%
data_root_directory = os.path.join('N:\\', 'xld', 'qubit_thermometry_v2', sample_name, f'COOLDOWN_{cooldown_start_date}', qubit_name)
qpu_file_path = os.path.join('N:\\', 'xld', 'qubit_thermometry_v2', sample_name, f'COOLDOWN_{cooldown_start_date}', f'{sample_name}_qpu.json')

if not os.path.isdir(data_root_directory):
    os.makedirs(data_root_directory, exist_ok=True)

print(f'Saving data to: {data_root_directory}')
# Out:
# Saving data to: N:\xld\qubit_thermometry_v2\ES-010-AC_X-X_XXXX\COOLDOWN_2026-07-03\Q2

# %%
folder_store = workflow.logbook.FolderStore(data_root_directory)
folder_store.activate()

logging_store = LoggingStore()
logging_store.activate()

# %% [markdown]
# # Tune-Up Experiments

# %% [markdown]
# ## Spectroscopy

# %% [markdown]
# ### Resonator Spectroscopy

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

readout_range_out = -25
readout_range_in = -45
readout_amplitude = 0.25
n_avg_exponent = 15

freq_range = 20e6
n_points = 101

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temp_pars.readout_range_out = readout_range_out
temp_pars.readout_range_in = readout_range_in
temp_pars.readout_amplitude = readout_amplitude
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = resonator_spectroscopy.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(False)

qubit_to_measure = qubits[0]

frequencies = qubits[0].parameters.readout_resonator_frequency + np.linspace(
    -freq_range / 2, freq_range / 2, n_points
)

exp_workflow = resonator_spectroscopy.experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=qubit_to_measure.uid,
    frequencies=frequencies,
    options=options,
    temporary_parameters=temporary_parameters
)
workflow_result = exp_workflow.run()
# Out:
# [2026.07.24 16:43:36.697] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 16:43:36.697] INFO      Workflow 'resonator_spectroscopy': execution started at 2026-07-24
# [2026.07.24 16:43:36.697] INFO      13:43:36.697272Z
# [2026.07.24 16:43:36.697] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 16:43:36.950] INFO    Task 'temporary_qpu': started at 2026-07-24 13:43:36.948631Z
# [2026.07.24 16:43:36.987] INFO    Task 'temporary_qpu': ended at 2026-07-24 13:43:36.987202Z
# [2026.07.24 16:43:37.059] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-07-24
# [2026.07.24 16:43:37.059] INFO    13:43:37.059216Z
# [2026.07.24 16:43:37.114] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-07-24 13:43:37.114380Z
# [2026.07.24 16:43:37.181] INFO    Task 'create_experiment': started at 2026-07-24 13:43:37.181089Z
# [2026.07.24 16:43:37.275] INFO    Task 'create_experiment': ended at 2026-07-24 13:43:37.275376Z
# [2026.07.24 16:43:37.359] INFO    Task 'compile_experiment': started at 2026-07-24 13:43:37.359168Z
# [2026.07.24 16:43:37.450] INFO    Starting LabOne Q Compiler run...
# [2026.07.24 16:43:37.450] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.07.24 16:43:37.450] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.07.24 16:43:37.450] INFO    Schedule completed. [0.001 s]
# [2026.07.24 16:43:37.459] INFO    Code generation completed for all AWGs. [0.004 s]
# [2026.07.24 16:43:37.459] INFO    Completed compilation step 1 of 1. [0.007 s]
# [2026.07.24 16:43:37.465] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.24 16:43:37.466] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.07.24 16:43:37.468] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.24 16:43:37.468] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.07.24 16:43:37.469] INFO      SHFQC_DEV12192_sg     0          9            1           0         0
# [2026.07.24 16:43:37.470] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.24 16:43:37.470] INFO      TOTAL                           30            1                  8000
# [2026.07.24 16:43:37.470] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.24 16:43:37.476] INFO    Finished LabOne Q Compiler run.
# [2026.07.24 16:43:37.481] INFO    Task 'compile_experiment': ended at 2026-07-24 13:43:37.481204Z
# [2026.07.24 16:43:37.584] INFO    Task 'run_experiment': started at 2026-07-24 13:43:37.584053Z
# [2026.07.24 16:43:37.722] INFO    Starting near-time execution...
# [2026.07.24 16:43:37.772] INFO    Estimated RT execution time: 10.22 s.
# [2026.07.24 16:43:48.049] INFO    Finished near-time execution.
# [2026.07.24 16:43:48.140] INFO    Task 'run_experiment': ended at 2026-07-24 13:43:48.140360Z
# [2026.07.24 16:43:48.220] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 16:43:48.220] INFO      Workflow 'analysis_workflow': execution started at 2026-07-24
# [2026.07.24 16:43:48.236] INFO      13:43:48.220206Z
# [2026.07.24 16:43:48.236] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 16:43:48.323] INFO    Task 'calculate_signal_magnitude_and_phase': started at 2026-07-24
# [2026.07.24 16:43:48.325] INFO    13:43:48.321247Z
# [2026.07.24 16:43:48.373] INFO    Task 'calculate_signal_magnitude_and_phase': ended at 2026-07-24
# [2026.07.24 16:43:48.373] INFO    13:43:48.373010Z
# [2026.07.24 16:43:48.574] INFO    Task 'fit_data': started at 2026-07-24 13:43:48.573501Z
# [2026.07.24 16:43:48.685] INFO    Task 'fit_data': ended at 2026-07-24 13:43:48.685643Z
# [2026.07.24 16:43:48.737] INFO    Task 'extract_qubit_parameters': started at 2026-07-24 13:43:48.732849Z
# [2026.07.24 16:43:48.813] INFO    Task 'extract_qubit_parameters': ended at 2026-07-24 13:43:48.813270Z
# [2026.07.24 16:43:48.889] INFO    Task 'plot_raw_complex_data_1d': started at 2026-07-24 13:43:48.889875Z
# [2026.07.24 16:43:48.989] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-07-24 13:43:48.989764Z
# [2026.07.24 16:43:49.393] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-07-24 13:43:49.393336Z
# [2026.07.24 16:43:49.439] INFO    Task 'plot_magnitude_phase': started at 2026-07-24 13:43:49.439885Z
# [2026.07.24 16:43:49.615] INFO    Artifact: 'Magnitude_Phase_Q2' of type 'Figure' logged at 2026-07-24
# [2026.07.24 16:43:49.615] INFO    13:43:49.615021Z
# [2026.07.24 16:43:50.279] INFO    Task 'plot_magnitude_phase': ended at 2026-07-24 13:43:50.279017Z
# [2026.07.24 16:43:50.328] INFO    Task 'plot_real_imaginary': started at 2026-07-24 13:43:50.328396Z
# [2026.07.24 16:43:50.408] INFO    Artifact: 'Real_Imaginary_Q2' of type 'Figure' logged at 2026-07-24
# [2026.07.24 16:43:50.408] INFO    13:43:50.408041Z
# [2026.07.24 16:43:50.794] INFO    Task 'plot_real_imaginary': ended at 2026-07-24 13:43:50.794331Z
# [2026.07.24 16:43:50.827] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 16:43:50.827] INFO      Workflow 'analysis_workflow': execution ended at 2026-07-24 13:43:50.827902Z
# [2026.07.24 16:43:50.827] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 16:43:50.875] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 16:43:50.876] INFO      Workflow 'resonator_spectroscopy': execution ended at 2026-07-24
# [2026.07.24 16:43:50.876] INFO      13:43:50.875625Z
# [2026.07.24 16:43:50.877] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)
    print('Updated global experiment parameters!\n')

analysis_workflow_result= workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)
resonator_spectroscopy.update_qpu(qpu, qubit_parameters["new_parameter_values"])
print("\nReadout resonator frequency: ", qubit_to_measure.parameters.readout_resonator_frequency * 1e-9, ' GHz')
# Out:
# Updated global experiment parameters!
#
# {'new_parameter_values': {'Q2': {'readout_resonator_frequency': 5256000000.0+/-0}},
#  'old_parameter_values': {'Q2': {'readout_resonator_frequency': 5256000000.0}}}
#
# Readout resonator frequency:  5.256  GHz

# %% [markdown]
# ## Qubit Spectroscopy

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

spectroscopy_length = 2e-6
spectroscopy_amplitude = 0.75
readout_amplitude = 0.12
drive_range = -5
n_avg_exponent = 12

freq_range = 30e6
n_points = 51

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temp_pars.spectroscopy_length = spectroscopy_length
temp_pars.spectroscopy_amplitude = spectroscopy_amplitude
temp_pars.readout_amplitude = readout_amplitude
temp_pars.drive_range = drive_range
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = qubit_spectroscopy.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.update(False) 
options.close_figures(False)

qubits_to_measure = [qubits[0]]

frequencies = [
    temporary_parameters[q.uid].resonance_frequency_ge + np.linspace(- freq_range / 2, freq_range / 2, n_points)
    for q in qubits_to_measure
]
exp_workflow = qubit_spectroscopy.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    frequencies=frequencies,
    options=options,
    temporary_parameters=temporary_parameters
)
workflow_result = exp_workflow.run()
# Out:
# [2026.07.24 17:58:26.758] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 17:58:26.758] INFO      Workflow 'qubit_spectroscopy': execution started at 2026-07-24
# [2026.07.24 17:58:26.758] INFO      14:58:26.758748Z
# [2026.07.24 17:58:26.763] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 17:58:27.022] INFO    Task 'temporary_qpu': started at 2026-07-24 14:58:27.022174Z
# [2026.07.24 17:58:27.069] INFO    Task 'temporary_qpu': ended at 2026-07-24 14:58:27.069937Z
# [2026.07.24 17:58:27.151] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-07-24
# [2026.07.24 17:58:27.159] INFO    14:58:27.151719Z
# [2026.07.24 17:58:27.200] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-07-24 14:58:27.200492Z
# [2026.07.24 17:58:27.288] INFO    Task 'create_experiment': started at 2026-07-24 14:58:27.288790Z
# [2026.07.24 17:58:27.392] INFO    Task 'create_experiment': ended at 2026-07-24 14:58:27.392954Z
# [2026.07.24 17:58:27.472] INFO    Task 'compile_experiment': started at 2026-07-24 14:58:27.472755Z
# [2026.07.24 17:58:27.568] INFO    Starting LabOne Q Compiler run...
# [2026.07.24 17:58:27.571] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.07.24 17:58:27.571] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.07.24 17:58:27.582] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.07.24 17:58:27.582] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.07.24 17:58:27.582] INFO    Schedule completed. [0.001 s]
# [2026.07.24 17:58:27.588] INFO    Code generation completed for all AWGs. [0.006 s]
# [2026.07.24 17:58:27.588] INFO    Completed compilation step 1 of 1. [0.010 s]
# [2026.07.24 17:58:27.598] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.24 17:58:27.600] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.07.24 17:58:27.600] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.24 17:58:27.603] INFO      SHFQC_DEV12192        0         10            0           1      8000
# [2026.07.24 17:58:27.603] INFO      SHFQC_DEV12192_sg     0         25            2           1        64
# [2026.07.24 17:58:27.605] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.24 17:58:27.607] INFO      TOTAL                           35            2                  8064
# [2026.07.24 17:58:27.607] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.24 17:58:27.617] INFO    Finished LabOne Q Compiler run.
# [2026.07.24 17:58:27.621] INFO    Task 'compile_experiment': ended at 2026-07-24 14:58:27.621045Z
# [2026.07.24 17:58:27.734] INFO    Task 'run_experiment': started at 2026-07-24 14:58:27.734605Z
# [2026.07.24 17:58:27.878] INFO    Starting near-time execution...
# [2026.07.24 17:58:29.065] INFO    Finished near-time execution.
# [2026.07.24 17:58:29.114] INFO    Task 'run_experiment': ended at 2026-07-24 14:58:29.114199Z
# [2026.07.24 17:58:29.194] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 17:58:29.194] INFO      Workflow 'analysis_workflow': execution started at 2026-07-24
# [2026.07.24 17:58:29.194] INFO      14:58:29.194932Z
# [2026.07.24 17:58:29.194] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 17:58:29.289] INFO    Task 'calculate_signal_magnitude_and_phase': started at 2026-07-24
# [2026.07.24 17:58:29.289] INFO    14:58:29.289965Z
# [2026.07.24 17:58:29.338] INFO    Task 'calculate_signal_magnitude_and_phase': ended at 2026-07-24
# [2026.07.24 17:58:29.338] INFO    14:58:29.337780Z
# [2026.07.24 17:58:29.416] INFO    Task 'fit_data': started at 2026-07-24 14:58:29.407842Z
# [2026.07.24 17:58:29.562] INFO    Task 'fit_data': ended at 2026-07-24 14:58:29.546404Z
# [2026.07.24 17:58:29.627] INFO    Task 'extract_qubit_parameters': started at 2026-07-24 14:58:29.627573Z
# [2026.07.24 17:58:29.737] INFO    Task 'extract_qubit_parameters': ended at 2026-07-24 14:58:29.737795Z
# [2026.07.24 17:58:29.779] INFO    Task 'plot_raw_complex_data_1d': started at 2026-07-24 14:58:29.779161Z
# [2026.07.24 17:58:29.849] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-07-24 14:58:29.849183Z
# [2026.07.24 17:58:30.140] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-07-24 14:58:30.140108Z
# [2026.07.24 17:58:30.173] INFO    Task 'plot_qubit_spectroscopy': started at 2026-07-24 14:58:30.173367Z
# [2026.07.24 17:58:30.287] INFO    Artifact: 'Qubit_Spectroscopy_Q2' of type 'Figure' logged at 2026-07-24
# [2026.07.24 17:58:30.289] INFO    14:58:30.270013Z
# [2026.07.24 17:58:30.612] INFO    Task 'plot_qubit_spectroscopy': ended at 2026-07-24 14:58:30.612270Z
# [2026.07.24 17:58:30.638] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 17:58:30.638] INFO      Workflow 'analysis_workflow': execution ended at 2026-07-24 14:58:30.638168Z
# [2026.07.24 17:58:30.638] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 17:58:30.665] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 17:58:30.665] INFO      Workflow 'qubit_spectroscopy': execution ended at 2026-07-24
# [2026.07.24 17:58:30.665] INFO      14:58:30.665816Z
# [2026.07.24 17:58:30.665] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
manual_center_frequency = 4.05e9
temporary_parameters[qubit_to_measure.uid].resonance_frequency_ge = manual_center_frequency

# %%
if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)
    print('Updated global experiment parameters!\n')

analysis_workflow_result= workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)
qubit_spectroscopy.update_qpu(qpu, qubit_parameters["new_parameter_values"])
print("Readout resonance frequency ge: ", qubit_to_measure.parameters.resonance_frequency_ge)
# Out:
# Updated global experiment parameters!
#
# {'new_parameter_values': {'Q2': {'resonance_frequency_ge': 4036708665.150076+/-245902.49444965276}},
#  'old_parameter_values': {'Q2': {'resonance_frequency_ge': 4038787737.3461456}}}
# Readout resonance frequency ge:  4036708665.150076

# %% [markdown]
# # Control Pulses

# %% [markdown]
# ## Amplitude Rabi

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ge')

drive_range = 10
drive_length = 300e-9
readout_amplitude = 0.3
n_avg_exponent = 13

amp_min = 0
amp_max = 1
n_amp = 51

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temp_pars.drive_range = drive_range
temp_pars.readout_amplitude = readout_amplitude
if transition == 'ge':
    temp_pars.ge_drive_length = drive_length
elif transition == 'ef':
    temp_pars.ef_drive_length = drive_length
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = amplitude_rabi.experiment_workflow.options()

options.count(2**n_avg_exponent)
options.close_figures(False) # Plot figures

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

exp_workflow = amplitude_rabi.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    amplitudes=[np.linspace(amp_min, amp_max, n_amp) for q in qubits_to_measure],
    options=options,
    temporary_parameters=temporary_parameters
)
workflow_result = exp_workflow.run()
# Out:
# [2026.07.24 18:03:44.165] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 18:03:44.166] INFO      Workflow 'amplitude_rabi': execution started at 2026-07-24 15:03:44.164070Z
# [2026.07.24 18:03:44.166] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 18:03:44.428] INFO    Task 'temporary_qpu': started at 2026-07-24 15:03:44.428591Z
# [2026.07.24 18:03:44.467] INFO    Task 'temporary_qpu': ended at 2026-07-24 15:03:44.467361Z
# [2026.07.24 18:03:44.566] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-07-24
# [2026.07.24 18:03:44.566] INFO    15:03:44.566415Z
# [2026.07.24 18:03:44.615] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-07-24 15:03:44.615109Z
# [2026.07.24 18:03:44.700] INFO    Task 'create_experiment': started at 2026-07-24 15:03:44.700145Z
# [2026.07.24 18:03:44.797] INFO    Task 'create_experiment': ended at 2026-07-24 15:03:44.797288Z
# [2026.07.24 18:03:44.885] INFO    Task 'compile_experiment': started at 2026-07-24 15:03:44.885689Z
# [2026.07.24 18:03:44.983] INFO    Starting LabOne Q Compiler run...
# [2026.07.24 18:03:44.983] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.07.24 18:03:44.983] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.07.24 18:03:44.983] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.07.24 18:03:44.983] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.07.24 18:03:44.999] INFO    Schedule completed. [0.001 s]
# [2026.07.24 18:03:45.003] INFO    Code generation completed for all AWGs. [0.005 s]
# [2026.07.24 18:03:45.003] INFO    Completed compilation step 1 of 1. [0.009 s]
# [2026.07.24 18:03:45.016] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.24 18:03:45.019] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.07.24 18:03:45.021] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.24 18:03:45.021] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.07.24 18:03:45.023] INFO      SHFQC_DEV12192_sg     0        169           53           2      2432
# [2026.07.24 18:03:45.023] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.24 18:03:45.023] INFO      TOTAL                          190           53                 10432
# [2026.07.24 18:03:45.025] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.24 18:03:45.037] INFO    Finished LabOne Q Compiler run.
# [2026.07.24 18:03:45.040] INFO    Task 'compile_experiment': ended at 2026-07-24 15:03:45.040130Z
# [2026.07.24 18:03:45.160] INFO    Task 'run_experiment': started at 2026-07-24 15:03:45.158618Z
# [2026.07.24 18:03:45.290] INFO    Starting near-time execution...
# [2026.07.24 18:03:45.357] INFO    Estimated RT execution time: 218.09 s.
# [2026.07.24 18:07:23.510] INFO    Finished near-time execution.
# [2026.07.24 18:07:23.600] INFO    Task 'run_experiment': ended at 2026-07-24 15:07:23.600076Z
# [2026.07.24 18:07:23.712] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 18:07:23.712] INFO      Workflow 'analysis_workflow': execution started at 2026-07-24
# [2026.07.24 18:07:23.714] INFO      15:07:23.712811Z
# [2026.07.24 18:07:23.716] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 18:07:23.797] INFO    Task 'calculate_qubit_population': started at 2026-07-24 15:07:23.797872Z
# [2026.07.24 18:07:23.894] INFO    Task 'calculate_qubit_population': ended at 2026-07-24 15:07:23.894383Z
# [2026.07.24 18:07:23.975] INFO    Task 'fit_data': started at 2026-07-24 15:07:23.975298Z
# [2026.07.24 18:07:24.102] INFO    Task 'fit_data': ended at 2026-07-24 15:07:24.102993Z
# [2026.07.24 18:07:24.200] INFO    Task 'extract_qubit_parameters': started at 2026-07-24 15:07:24.200368Z
# [2026.07.24 18:07:24.317] INFO    Task 'extract_qubit_parameters': ended at 2026-07-24 15:07:24.317947Z
# [2026.07.24 18:07:24.409] INFO    Task 'plot_raw_complex_data_1d': started at 2026-07-24 15:07:24.409067Z
# [2026.07.24 18:07:24.538] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-07-24 15:07:24.537065Z
# [2026.07.24 18:07:25.019] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-07-24 15:07:25.019079Z
# [2026.07.24 18:07:25.070] INFO    Task 'plot_population': started at 2026-07-24 15:07:25.070069Z
# [2026.07.24 18:07:25.234] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-07-24 15:07:25.234638Z
# [2026.07.24 18:07:25.562] INFO    Task 'plot_population': ended at 2026-07-24 15:07:25.562966Z
# [2026.07.24 18:07:25.603] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 18:07:25.605] INFO      Workflow 'analysis_workflow': execution ended at 2026-07-24 15:07:25.601216Z
# [2026.07.24 18:07:25.605] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 18:07:25.645] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 18:07:25.645] INFO      Workflow 'amplitude_rabi': execution ended at 2026-07-24 15:07:25.645143Z
# [2026.07.24 18:07:25.645] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)
    print('Updated global experiment parameters!\n')

analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)
amplitude_rabi.update_qpu(qpu, qubit_parameters["new_parameter_values"])
if transition == 'ge':
    print("Drive amplitude pi ge: ", qubit_to_measure.parameters.ge_drive_amplitude_pi)
    print("Drive amplitude pi2 ge: ", qubit_to_measure.parameters.ge_drive_amplitude_pi2)
elif transition == 'ef':
    print("Drive amplitude pi ef: ", qubit_to_measure.parameters.ef_drive_amplitude_pi)
    print("Drive amplitude pi2 ef: ", qubit_to_measure.parameters.ef_drive_amplitude_pi2)
# Out:
# Updated global experiment parameters!
#
# {'new_parameter_values': {'Q2': {'ge_drive_amplitude_pi': 0.5103086767488765+/-0.026966806025240146,
#                                  'ge_drive_amplitude_pi2': 0.2536259770112463+/-0.021461926901676406}},
#  'old_parameter_values': {'Q2': {'ge_drive_amplitude_pi': 0.5140787193447097,
#                                  'ge_drive_amplitude_pi2': 0.2532295876211112}}}
# Drive amplitude pi ge:  0.5103086767488765
# Drive amplitude pi2 ge:  0.2536259770112463

# %% [markdown]
# ## Ramsey

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

detuning = 0.5e6
transition = set_transition('ge')

n_avg_exponent = 13

delay_min = 0
delay_max = 10e-6
n_delay = 51

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = ramsey.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(False) # Plot figures

options.transition(transition)
options.cal_states(transition)

# Note: if neighbouring qubits are physically coupled by a resonator,
# you usually don't want to run Ramsey in parallel on them because
# your result will be skewed by strong residual-ZZ coupling.
# Next-nearest neighbours is typically okay.
# qubits_to_measure = [qubits[0], qubits[2]]
qubits_to_measure = [qubits[0]]

delays = [
    np.linspace(delay_min, delay_max, n_delay)
]
detunings = [
    detuning
]

exp_workflow = ramsey.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    delays=delays,
    detunings=detunings,
    options=options,
    temporary_parameters=temporary_parameters
)

workflow_result = exp_workflow.run()
# Out:
# [2026.07.24 17:59:01.207] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 17:59:01.209] INFO      Workflow 'ramsey': execution started at 2026-07-24 14:59:01.207309Z
# [2026.07.24 17:59:01.209] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 17:59:01.473] INFO    Task 'temporary_qpu': started at 2026-07-24 14:59:01.471276Z
# [2026.07.24 17:59:01.512] INFO    Task 'temporary_qpu': ended at 2026-07-24 14:59:01.512481Z
# [2026.07.24 17:59:01.615] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-07-24
# [2026.07.24 17:59:01.617] INFO    14:59:01.608919Z
# [2026.07.24 17:59:01.659] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-07-24 14:59:01.659003Z
# [2026.07.24 17:59:01.743] INFO    Task 'create_experiment': started at 2026-07-24 14:59:01.743672Z
# [2026.07.24 17:59:01.836] INFO    Task 'create_experiment': ended at 2026-07-24 14:59:01.836256Z
# [2026.07.24 17:59:01.920] INFO    Task 'compile_experiment': started at 2026-07-24 14:59:01.920042Z
# [2026.07.24 17:59:02.011] INFO    Starting LabOne Q Compiler run...
# [2026.07.24 17:59:02.011] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.07.24 17:59:02.011] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.07.24 17:59:02.018] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.07.24 17:59:02.018] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.07.24 17:59:02.018] INFO    Schedule completed. [0.001 s]
# [2026.07.24 17:59:02.026] INFO    Code generation completed for all AWGs. [0.006 s]
# [2026.07.24 17:59:02.029] INFO    Completed compilation step 1 of 1. [0.009 s]
# [2026.07.24 17:59:02.034] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.24 17:59:02.037] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.07.24 17:59:02.038] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.24 17:59:02.040] INFO      SHFQC_DEV12192        0        215            0           1      8000
# [2026.07.24 17:59:02.041] INFO      SHFQC_DEV12192_sg     0        272           14           3      4832
# [2026.07.24 17:59:02.041] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.24 17:59:02.041] INFO      TOTAL                          487           14                 12832
# [2026.07.24 17:59:02.041] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.24 17:59:02.068] INFO    Finished LabOne Q Compiler run.
# [2026.07.24 17:59:02.068] INFO    Task 'compile_experiment': ended at 2026-07-24 14:59:02.068658Z
# [2026.07.24 17:59:02.183] INFO    Task 'run_experiment': started at 2026-07-24 14:59:02.183342Z
# [2026.07.24 17:59:02.299] INFO    Starting near-time execution...
# [2026.07.24 17:59:02.366] INFO    Estimated RT execution time: 220.30 s.
# [2026.07.24 18:02:42.744] INFO    Finished near-time execution.
# [2026.07.24 18:02:42.833] INFO    Task 'run_experiment': ended at 2026-07-24 15:02:42.828316Z
# [2026.07.24 18:02:42.987] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 18:02:42.987] INFO      Workflow 'analysis_workflow': execution started at 2026-07-24
# [2026.07.24 18:02:42.987] INFO      15:02:42.987096Z
# [2026.07.24 18:02:42.987] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 18:02:43.101] INFO    Task 'calculate_qubit_population': started at 2026-07-24 15:02:43.101458Z
# [2026.07.24 18:02:43.185] INFO    Task 'calculate_qubit_population': ended at 2026-07-24 15:02:43.185837Z
# [2026.07.24 18:02:43.287] INFO    Task 'fit_data': started at 2026-07-24 15:02:43.287750Z
# [2026.07.24 18:02:43.449] INFO    Task 'fit_data': ended at 2026-07-24 15:02:43.449398Z
# [2026.07.24 18:02:43.535] INFO    Task 'extract_qubit_parameters': started at 2026-07-24 15:02:43.535322Z
# [2026.07.24 18:02:43.663] INFO    Task 'extract_qubit_parameters': ended at 2026-07-24 15:02:43.663798Z
# [2026.07.24 18:02:43.745] INFO    Task 'plot_raw_complex_data_1d': started at 2026-07-24 15:02:43.745074Z
# [2026.07.24 18:02:43.888] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-07-24 15:02:43.881885Z
# [2026.07.24 18:02:44.499] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-07-24 15:02:44.499795Z
# [2026.07.24 18:02:44.548] INFO    Task 'plot_population': started at 2026-07-24 15:02:44.548315Z
# [2026.07.24 18:02:44.704] INFO    Artifact: 'Ramsey_Q2' of type 'Figure' logged at 2026-07-24 15:02:44.700553Z
# [2026.07.24 18:02:45.210] INFO    Task 'plot_population': ended at 2026-07-24 15:02:45.210941Z
# [2026.07.24 18:02:45.275] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 18:02:45.277] INFO      Workflow 'analysis_workflow': execution ended at 2026-07-24 15:02:45.275003Z
# [2026.07.24 18:02:45.281] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 18:02:45.327] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 18:02:45.327] INFO      Workflow 'ramsey': execution ended at 2026-07-24 15:02:45.327145Z
# [2026.07.24 18:02:45.327] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)
    print('Updated global experiment parameters!\n')

analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)
ramsey.update_qpu(qpu, qubit_parameters["new_parameter_values"])
if transition == 'ge':
    print("ge_T2_star: ", qubit_to_measure.parameters.ge_T2_star)
    print("resonance_frequency_ge: ", qubit_to_measure.parameters.resonance_frequency_ge)
elif transition == 'ef':
    print("ef_T2_star: ", qubit_to_measure.parameters.ef_T2_star)
    print("resonance_frequency_ef: ", qubit_to_measure.parameters.resonance_frequency_ef)
# Out:
# Updated global experiment parameters!
#
# {'new_parameter_values': {'Q2': {'ge_T2_star': 1.984451703140877e-05+/-7.717164688113875e-06,
#                                  'resonance_frequency_ge': 4038787737.3461456+/-5646.288535220184}},
#  'old_parameter_values': {'Q2': {'ge_T2_star': 1.0868139225239659e-05,
#                                  'resonance_frequency_ge': 4040362961.797084}}}
# ge_T2_star:  1.984451703140877e-05
# resonance_frequency_ge:  4038787737.3461456

# %% [markdown]
# ## T1 Lifetime

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ge')

n_avg_exponent = 13

delay_min = 0
delay_max = 300e-6
n_delay = 75
log_spacing = True

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = lifetime_measurement.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(False) # Plot figures


qubits_to_measure = [qubits[0]]

if log_spacing:
    delays = [log_sweep_help(delay_min, delay_max, n_delay)]
else:
    delays = [np.linspace(delay_min, delay_max, n_delay)]

exp_workflow = lifetime_measurement.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    delays=delays,
    options=options,
    temporary_parameters=temporary_parameters 
)

workflow_result = exp_workflow.run()
# Out:
# [2026.07.24 17:13:59.047] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 17:13:59.047] INFO      Workflow 'lifetime_measurement': execution started at 2026-07-24
# [2026.07.24 17:13:59.047] INFO      14:13:59.047270Z
# [2026.07.24 17:13:59.047] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 17:13:59.317] INFO    Task 'temporary_qpu': started at 2026-07-24 14:13:59.317070Z
# [2026.07.24 17:13:59.348] INFO    Task 'temporary_qpu': ended at 2026-07-24 14:13:59.348875Z
# [2026.07.24 17:13:59.447] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-07-24
# [2026.07.24 17:13:59.448] INFO    14:13:59.446890Z
# [2026.07.24 17:13:59.479] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-07-24 14:13:59.479389Z
# [2026.07.24 17:13:59.569] INFO    Task 'create_experiment': started at 2026-07-24 14:13:59.569899Z
# [2026.07.24 17:13:59.669] INFO    Task 'create_experiment': ended at 2026-07-24 14:13:59.669547Z
# [2026.07.24 17:13:59.765] INFO    Task 'compile_experiment': started at 2026-07-24 14:13:59.765279Z
# [2026.07.24 17:13:59.850] INFO    Starting LabOne Q Compiler run...
# [2026.07.24 17:13:59.850] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.07.24 17:13:59.850] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.07.24 17:13:59.850] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.07.24 17:13:59.850] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.07.24 17:13:59.850] INFO    Schedule completed. [0.003 s]
# [2026.07.24 17:13:59.865] INFO    Code generation completed for all AWGs. [0.013 s]
# [2026.07.24 17:13:59.877] INFO    Completed compilation step 1 of 1. [0.021 s]
# [2026.07.24 17:13:59.880] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.24 17:13:59.880] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.07.24 17:13:59.891] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.24 17:13:59.892] INFO      SHFQC_DEV12192        0        313            0           1      8000
# [2026.07.24 17:13:59.892] INFO      SHFQC_DEV12192_sg     0        342           17          16     19680
# [2026.07.24 17:13:59.892] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.24 17:13:59.892] INFO      TOTAL                          655           17                 27680
# [2026.07.24 17:13:59.892] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.24 17:13:59.924] INFO    Finished LabOne Q Compiler run.
# [2026.07.24 17:13:59.926] INFO    Task 'compile_experiment': ended at 2026-07-24 14:13:59.926850Z
# [2026.07.24 17:14:00.015] INFO    Task 'run_experiment': started at 2026-07-24 14:14:00.015477Z
# [2026.07.24 17:14:00.117] INFO    Starting near-time execution...
# [2026.07.24 17:14:00.182] INFO    Estimated RT execution time: 345.16 s.
# [2026.07.24 17:19:45.395] INFO    Finished near-time execution.
# [2026.07.24 17:19:45.523] INFO    Task 'run_experiment': ended at 2026-07-24 14:19:45.523680Z
# [2026.07.24 17:19:45.632] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 17:19:45.632] INFO      Workflow 'analysis_workflow': execution started at 2026-07-24
# [2026.07.24 17:19:45.635] INFO      14:19:45.632033Z
# [2026.07.24 17:19:45.635] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 17:19:45.725] INFO    Task 'calculate_qubit_population': started at 2026-07-24 14:19:45.724143Z
# [2026.07.24 17:19:45.823] INFO    Task 'calculate_qubit_population': ended at 2026-07-24 14:19:45.816243Z
# [2026.07.24 17:19:45.888] INFO    Task 'fit_data': started at 2026-07-24 14:19:45.888106Z
# [2026.07.24 17:19:46.017] INFO    Task 'fit_data': ended at 2026-07-24 14:19:46.017494Z
# [2026.07.24 17:19:46.113] INFO    Task 'extract_qubit_parameters': started at 2026-07-24 14:19:46.113836Z
# [2026.07.24 17:19:46.226] INFO    Task 'extract_qubit_parameters': ended at 2026-07-24 14:19:46.226541Z
# [2026.07.24 17:19:46.289] INFO    Task 'plot_raw_complex_data_1d': started at 2026-07-24 14:19:46.289775Z
# [2026.07.24 17:19:46.431] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-07-24 14:19:46.431387Z
# [2026.07.24 17:19:46.984] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-07-24 14:19:46.984535Z
# [2026.07.24 17:19:47.031] INFO    Task 'plot_population': started at 2026-07-24 14:19:47.031499Z
# [2026.07.24 17:19:47.187] INFO    Artifact: 'T1_Q2' of type 'Figure' logged at 2026-07-24 14:19:47.181166Z
# [2026.07.24 17:19:47.519] INFO    Task 'plot_population': ended at 2026-07-24 14:19:47.517308Z
# [2026.07.24 17:19:47.571] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 17:19:47.571] INFO      Workflow 'analysis_workflow': execution ended at 2026-07-24 14:19:47.570332Z
# [2026.07.24 17:19:47.573] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 17:19:47.627] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 17:19:47.627] INFO      Workflow 'lifetime_measurement': execution ended at 2026-07-24
# [2026.07.24 17:19:47.627] INFO      14:19:47.625110Z
# [2026.07.24 17:19:47.630] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)
    print('Updated global experiment parameters!\n')

analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)
ramsey.update_qpu(qpu, qubit_parameters["new_parameter_values"])
if transition == 'ge':
    print("ge_T1: ", qubit_to_measure.parameters.ge_T1)
elif transition == 'ef':
    print("ef_T1: ", qubit_to_measure.parameters.ef_T1)
# Out:
# Updated global experiment parameters!
#
# {'new_parameter_values': {'Q2': {'ge_T1': 5.01188553985567e-05+/-2.2943229577360487e-06}},
#  'old_parameter_values': {'Q2': {'ge_T1': 0}}}
# ge_T1:  5.01188553985567e-05

# %%
temporary_parameters[qubit_to_measure.uid].reset_delay_length = 500e-6
if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])

# %% [markdown]
# ## DRAG Calibration

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ge')

n_avg_exponent = 13

q_min = -0.05
q_max = 0.05
n_q = 31

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = drag_q_scaling.experiment_workflow.options()
# options.update(True)  # updates the qubit parameter 'ge_drive_pulse["beta"]'
options.count(2**n_avg_exponent)
options.close_figures(False) # Plot figures

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

exp_workflow = drag_q_scaling.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    q_scalings=[np.linspace(q_min, q_max, n_q) for _ in qubits_to_measure],
    options=options,
)
workflow_result = exp_workflow.run()
# Out:
# [2026.07.24 17:20:23.240] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 17:20:23.240] INFO      Workflow 'drag_q_scaling': execution started at 2026-07-24 14:20:23.240304Z
# [2026.07.24 17:20:23.240] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 17:20:23.490] INFO    Task 'temporary_qpu': started at 2026-07-24 14:20:23.490435Z
# [2026.07.24 17:20:23.552] INFO    Task 'temporary_qpu': ended at 2026-07-24 14:20:23.552575Z
# [2026.07.24 17:20:23.651] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-07-24
# [2026.07.24 17:20:23.651] INFO    14:20:23.651032Z
# [2026.07.24 17:20:23.697] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-07-24 14:20:23.697292Z
# [2026.07.24 17:20:23.777] INFO    Task 'create_experiment': started at 2026-07-24 14:20:23.777797Z
# [2026.07.24 17:20:23.889] INFO    Task 'create_experiment': ended at 2026-07-24 14:20:23.889035Z
# [2026.07.24 17:20:23.984] INFO    Task 'compile_experiment': started at 2026-07-24 14:20:23.983693Z
# [2026.07.24 17:20:24.072] INFO    Starting LabOne Q Compiler run...
# [2026.07.24 17:20:24.073] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.07.24 17:20:24.075] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.07.24 17:20:24.075] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.07.24 17:20:24.077] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.07.24 17:20:24.080] INFO    Schedule completed. [0.002 s]
# [2026.07.24 17:20:24.132] INFO    Code generation completed for all AWGs. [0.054 s]
# [2026.07.24 17:20:24.135] INFO    Completed compilation step 1 of 1. [0.060 s]
# [2026.07.24 17:20:24.144] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.24 17:20:24.144] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.07.24 17:20:24.144] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.24 17:20:24.153] INFO      SHFQC_DEV12192        0         31            0           1      8000
# [2026.07.24 17:20:24.153] INFO      SHFQC_DEV12192_sg     0        571           95          94    224416
# [2026.07.24 17:20:24.153] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.24 17:20:24.153] INFO      TOTAL                          602           95                232416
# [2026.07.24 17:20:24.157] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.24 17:20:24.198] ERROR   Task 'compile_experiment': failed at 2026-07-24 14:20:24.198830Z with:
# [2026.07.24 17:20:24.198] ERROR   Task 'compile_experiment': failed at 2026-07-24 14:20:24.198830Z with:
# [2026.07.24 17:20:24.208] ERROR   LabOneQException('Compilation error - resource limitation exceeded.\nTo
# [2026.07.24 17:20:24.208] ERROR   LabOneQException('Compilation error - resource limitation exceeded.\nTo
# [2026.07.24 17:20:24.208] ERROR   circumvent this, try one or more of the following:\n- Double check the integrity
# [2026.07.24 17:20:24.208] ERROR   circumvent this, try one or more of the following:\n- Double check the integrity
# [2026.07.24 17:20:24.213] ERROR   of your experiment (look for unexpectedly long pulses, large number of sweep
# [2026.07.24 17:20:24.213] ERROR   of your experiment (look for unexpectedly long pulses, large number of sweep
# [2026.07.24 17:20:24.215] ERROR   steps, etc.)\n- Reduce the number of sweep steps\n- Reduce the number of
# [2026.07.24 17:20:24.215] ERROR   steps, etc.)\n- Reduce the number of sweep steps\n- Reduce the number of
# [2026.07.24 17:20:24.217] ERROR   variations in the pulses that are being played\n- Enable chunking for a sweep\n-
# [2026.07.24 17:20:24.217] ERROR   variations in the pulses that are being played\n- Enable chunking for a sweep\n-
# [2026.07.24 17:20:24.217] ERROR   If chunking is already enabled, increase the chunk count or switch to automatic
# [2026.07.24 17:20:24.217] ERROR   If chunking is already enabled, increase the chunk count or switch to automatic
# [2026.07.24 17:20:24.217] ERROR   chunking')
# [2026.07.24 17:20:24.217] ERROR   chunking')
# [2026.07.24 17:20:24.266] INFO    Task 'compile_experiment': ended at 2026-07-24 14:20:24.266380Z
# [2026.07.24 17:20:24.317] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.24 17:20:24.317] INFO      Workflow 'drag_q_scaling': execution ended at 2026-07-24 14:20:24.317903Z
# [2026.07.24 17:20:24.319] INFO     ──────────────────────────────────────────────────────────────────────────────
# ---------------------------------------------------------------------------
# ResourceLimitationError                   Traceback (most recent call last)
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\compiler\workflow\compiler.py:231, in Compiler._process_experiment(self, compiler_module, device_class)
#     230 try:
# --> 231     return self._compile_whole_or_with_chunks(
#     232         experiment=experiment,
#     233         chunk_count=chunk_count,
#     234         device_class=device_class,
#     235         compiler_module=compiler_module,
#     236     )
#     237 except ResourceLimitationError as err:
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\compiler\workflow\compiler.py:167, in Compiler._compile_whole_or_with_chunks(self, experiment, chunk_count, device_class, compiler_module)
#     165 rt_loop_properties = executor.rt_loop_properties()
# --> 167 executor.finalize()
#     169 combined_output = combined_compiler_output.get_first_combined_output()
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\compiler\workflow\neartime_execution.py:271, in NtCompilerExecutor.finalize(self)
#     270     delegate.after_final_run(self._combined_compiler_output)
# --> 271 rt_linker.finalize(self._combined_compiler_output, self._settings)
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\compiler\workflow\rt_linker.py:51, in finalize(this, settings)
#      50 def finalize(this: CombinedRTCompilerOutputContainer, settings: CompilerSettings):
# ---> 51     get_compiler_hooks(this.device_class).linker().finalize(
#      52         this.combined_output, settings
#      53     )
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\compiler\seqc\linker.py:414, in SeqCLinker.finalize(this, settings)
#     401 seqc_items = [
#     402     SeqCCompileItem(
#     403         dev_type=seqc_program.dev_type,
#    (...)    412     if seqc_program.dev_type is not None
#     413 ]
# --> 414 seqc_compile.awg_compile(seqc_items, settings)
#     415 for seqc_item in seqc_items:
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\core\utilities\seqc_compile.py:124, in awg_compile(awg_data, settings)
#     119     error_msgs = [
#     120         str(future.exception())
#     121         for future in futures
#     122         if future.exception() is not None
#     123     ]
# --> 124     _process_errors(error_msgs, settings)
#     125 _logger.debug("Finished compilation.")
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\core\utilities\seqc_compile.py:105, in _process_errors(messages, settings)
#     104         other_errors.append(msg)
# --> 105 reserr_collector.raise_or_pass()
#     106 if other_errors:
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\compiler\common\resource_usage.py:47, in ResourceLimitationErrorCollector.raise_or_pass(self)
#      46 if self._max is not None:
# ---> 47     raise self._max
#
# ResourceLimitationError: seq_SHFQC_DEV12192_sg_0_[].seqc: AWG compilation failed.
# Compilation failed: Compiler Error (line: 570): waveforms are not fitting into wave memory (185.5 kSa over a maximum of 196.6 kSa)
#
#
# The above exception was the direct cause of the following exception:
#
# LabOneQException                          Traceback (most recent call last)
# Cell In[89], line 18
#      14     qubits=[q.uid for q in qubits_to_measure],
#      15     q_scalings=[np.linspace(q_min, q_max, n_q) for _ in qubits_to_measure],
#      16     options=options,
#      17 )
# ---> 18 workflow_result = exp_workflow.run()
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\workflow\core.py:227, in Workflow.run(self, until)
#     223 for logstore in self._logstores():
#     224     state.add_recorder(
#     225         logstore.create_logbook(self, start_time=state.start_time)
#     226     )
# --> 227 return self._execute(state)
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\workflow\core.py:137, in Workflow._execute(self, state)
#     135 try:
#     136     with executor.ExecutorStateContext.scoped(state):
# --> 137         self._root.execute(state)
#     138 except Exception:
#     139     if self._recovery is not None:
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\workflow\blocks\workflow_block.py:158, in WorkflowBlock.execute(self, executor)
#     153     if executor.get_block_status(block) in (
#     154         ExecutionStatus.FINISHED,
#     155         ExecutionStatus.SKIPPED,
#     156     ):
#     157         continue
# --> 158     block.execute(executor)
#     159 body_loop_finished = True
#     160 executor.set_block_status(self, ExecutionStatus.FINISHED)
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\workflow\blocks\task_block.py:61, in TaskBlock.execute(self, executor)
#      59     self._exucute_hidden(executor)
#      60 else:
# ---> 61     self._execute_visible(executor)
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\workflow\blocks\task_block.py:91, in TaskBlock._execute_visible(self, executor)
#      89 executor.set_block_status(self, ExecutionStatus.IN_PROGRESS)
#      90 try:
# ---> 91     task._output = self.task.func(**params)
#      92 except Exception as error:
#      93     task._end_time = utc_now()
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\workflow\tasks\compile_experiment.py:58, in compile_experiment(session, experiment, options)
#      40 """A task to compile the specified experiment for a given setup.
#      41
#      42 This task is used to prepare a LabOne Q DSL experiment for execution on a quantum
#    (...)     55         The `laboneq` compiled experiment.
#      56 """
#      57 opts = CompileExperimentOptions() if options is None else options
# ---> 58 return session.compile(
#      59     experiment=experiment,
#      60     compiler_settings=opts.compiler_settings,
#      61 )
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\dsl\session.py:419, in Session.compile(self, experiment, compiler_settings)
#     410 """Compiles the specified experiment and stores it in the compiled_experiment property.
#     411
#     412 Requires connected LabOne Q session (`session.connect()`) either with or without emulation mode.
#    (...)    416     compiler_settings: Extra options passed to the compiler.
#     417 """
#     418 self._experiment_definition = experiment
# --> 419 self._compiled_experiment = compile_experiment(
#     420     device_setup=self.device_setup,
#     421     experiment=self.experiment,
#     422     compiler_settings={
#     423         **(compiler_settings or {}),
#     424     },
#     425 )
#     426 self._last_results = None
#     427 return self._compiled_experiment
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\core\utilities\compile_experiment.py:37, in compile_experiment(device_setup, experiment, compiler_settings)
#      34 new_setup = convert_device_setup_to_setup(device_setup)
#      35 signal_mapping = convert_signal_map(experiment)
# ---> 37 scheduled_experiment = compile_experiment_impl(
#      38     device_setup=new_setup,
#      39     experiment=experiment,
#      40     signal_mappings=signal_mapping,
#      41     compiler_settings=compiler_settings,
#      42 )
#      43 compiled_experiment = CompiledExperiment(
#      44     device_setup=device_setup,
#      45     experiment=experiment,
#    (...)     48     scheduled_experiment=scheduled_experiment,
#      49 )
#      50 return compiled_experiment
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\implementation\payload_builder\payload_builder.py:38, in compile_experiment(device_setup, experiment, signal_mappings, compiler_settings)
#      33 execution = ExecutionFactoryFromExperiment().make(
#      34     experiment,
#      35     driver_parameter_map=driver_parameter_map,
#      36 )
#      37 compiler = Compiler(compiler_settings)
# ---> 38 return compiler.run(
#      39     CompilationJob(experiment_info=experiment_info, execution=execution)
#      40 )
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\compiler\workflow\compiler.py:297, in Compiler.run(self, data)
#     294 self._chunking_info = data.experiment_info.chunking
#     296 self._analyze_setup(self._experiment_dao)
# --> 297 compiler_output = self._process_experiment(compiler_module, device_class)
#     299 assert compiler_output is not None
#     300 _logger.info("Finished LabOne Q Compiler run.")
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\compiler\workflow\compiler.py:247, in Compiler._process_experiment(self, compiler_module, device_class)
#     237     except ResourceLimitationError as err:
#     238         msg = (
#     239             "Compilation error - resource limitation exceeded.\n"
#     240             "To circumvent this, try one or more of the following:\n"
#    (...)    245             "- If chunking is already enabled, increase the chunk count or switch to automatic chunking"
#     246         )
# --> 247         raise LabOneQException(msg) from err
#     248 else:  # auto chunking
#     249     divisors = _divisors(chunking.sweep_iterations)
#
# LabOneQException: Compilation error - resource limitation exceeded.
# To circumvent this, try one or more of the following:
# - Double check the integrity of your experiment (look for unexpectedly long pulses, large number of sweep steps, etc.)
# - Reduce the number of sweep steps
# - Reduce the number of variations in the pulses that are being played
# - Enable chunking for a sweep
# - If chunking is already enabled, increase the chunk count or switch to automatic chunking

# %%
if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    print('Updated global experiment parameters!\n')

analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)
ramsey.update_qpu(qpu, qubit_parameters["new_parameter_values"])
if transition == 'ge':
    print("ge_drive_pulse[beta]: ", qubit_to_measure.parameters.ge_drive_pulse["beta"])
elif transition == 'ef':
    print("ef_drive_pulse[beta]: ", qubit_to_measure.parameters.ef_drive_pulse["beta"])

# %% [markdown]
# ## Hahn-Echo

# %% [markdown]
# #### Experiment Parameters

# %% [markdown]
# #### Run Workflow

# %% [markdown]
# #### Update Parameters
