# %% [markdown]
# # Overview

# %% [markdown]
# ## Description
#
# This is a template notebook to tune up a single qubit using the LabOneQ workflow architecture. The following tune-up experiments are implemented:
#
# 1. [Resonator Spectroscopy](#resonator-spectroscopy)
# 2. Qubit Spectroscopy
# 3. Amplitude Rabi Experiment
# 4. Ramsey Experiment
# 5. T1 Lifetime experiment
# 6. DRAG Calibration
# 7. Hahn-Echo Experiment
#
# All experiments can be performed on the ge and ef transition.

# %% [markdown]
# ## Changelog
#
# All changes must be logged here! Do not make changes to this notebook other than expanding or modifying the standard experiments in a meaningful! All device-specific parameters and measurements have to be done in a different notebook!
#
# Stick to semantic versioning:
# - **Last Digit**: Fix a bug that does not add any new features and is backwards compatible -> increment last digit by one (e.g. 0.0.4 to 0.0.5)
#
# - **Middle Digit**: Add a new feature while keeping backwards compatibility (older versions can still be executed without any modifications) -> increment middle digit by one and set last digit to 0 (e.g. 1.2.12 to 1.3.0)
#
# - **First Digit**: Make changes that will break older versions, making them incompatible with the new version -> increment first digit by one and set all other digits to 0 (e.g. 3.2.9 to 4.0.0)
#
# **Current Version:** 1.4.0
#
# **2026-07-23**, *Elias*: Created this template notebook and added resonator and qubit spectroscopy, amplitude Rabi, Ramsey T1 and DRAG
#
# **2026-08-07**, *Kha*: Updated Hahn Echo, added Readout Optimisation, Single Shots, Population Measurements
#
# **2026-08-13**, *Kha*: Added Rabi Shevron, Rabi Frequency Calibration, Rabi Error Amplification

# %% [markdown]
# # Package Imports and Initialization

# %% [markdown]
# ## LabOne Q Libraries

# %%
# LabOne Q:
from laboneq.simple import *
from laboneq.dsl.quantum import QPU
from laboneq.contrib.example_helpers.generate_descriptor import generate_descriptor
from laboneq.workflow.logbook import LoggingStore
from laboneq.serializers import load, save

# LabOne Q Applications:
from laboneq_applications.qpu_types.tunable_transmon import (
    TunableTransmonQubit,
    TunableTransmonOperations,
)

# Plot:
from laboneq.contrib.example_helpers.plotting.plot_helpers import plot_results, plot_simulation

# Workflows:
from laboneq_applications.experiments import (
    resonator_spectroscopy,
    qubit_spectroscopy,
    amplitude_rabi,
    amplitude_fine,
    ramsey,
    drag_q_scaling,
    lifetime_measurement,
    echo,
    dispersive_shift,
    iq_blobs,
)

# %% [markdown]
# ## Other Imports

# %%
from copy import deepcopy
from pprint import pprint
from pathlib import Path

import os
import attrs
import numpy as np
import time
import pandas as pd
import matplotlib.pyplot as plt

from scipy.io import savemat
from scipy.optimize import curve_fit
from scipy.stats import norm

# %% [markdown]
# ## Helpers

# %%
def set_transition(transition: str):
    assert transition in ['ge', 'ef'], "Choose transition from 'ge' or 'ef'!"
    return transition

def log_sweep_help(t1_min: float, t1_max: float, t1_num: int):
    t1_log_sweep = np.logspace(np.log10(t1_max / t1_num / 10), np.log10(t1_max), t1_num - 1)
    t1_log_sweep_arr = np.append([0.0], t1_log_sweep)
    return t1_log_sweep_arr

# %%
def get_path_to_file(file_name: str, extension: str, directory: str | None = None) -> str:
    """Timestamped file path inside the cooldown data directory.

    New-structure replacement for the old
    `get_path_to_file(figname, '.png', sample_parameters)`.
    """
    directory = data_root_directory if directory is None else directory
    timestamp = time.strftime('%Y%m%d_%H%M%S')
    return os.path.join(directory, f'{timestamp}_{file_name}{extension}')

def get_analysis_task_output(workflow_result, task_name: str):
    """Output of a task inside the nested `analysis_workflow` of a workflow result.
    
    Used to reach the raw lmfit results (`fit_data`) and the pair-wise signal
    distances (`calculate_signal_differences`), which are not part of the
    analysis-workflow output itself.
    """
    return workflow_result.tasks['analysis_workflow'].tasks[task_name].output

# %%
def gauss(x, mu, sigma, A):
    """Old `lib.helpers.fitting_helper.gauss`, unchanged."""
    return A * np.exp(-((x - mu) ** 2) / 2 / sigma** 2)

def bimodal(x, mu1, sigma1, A1, mu2, sigma2, A2):
    """Old `lib.helpers.fitting_helper.bimodal`, unchanged."""
    return gauss(x, mu1, sigma1, A1) + gauss(x, mu2, sigma2, A2)

def collect_shots_from_result(result, qubit_uid: str, states: str) -> dict:
    """Single shots per prepared state from an `iq_blobs` workflow result.
    
    New-structure replacement for the old
    `SS_results.get_data("SS_rabi")[:, 0]` / `[:, 1]` (two-point sweep) and
    `SS_results.get_data("shots")` (one experiment per state).
    """
    return {
        s: result[dsl.handles.calibration_trace_handle(qubit_uid, s)].data
        for s in states
    }

def analyze_single_shots(shots_per_state, state_0='g', state_1='e',
                         plot=False, n_bins=50):
    """Rotate the shots onto the state-discrimination axis and get its statistics.

    New-structure replacement for the old `analize_Single_Shots(SS_results)`.
    Same maths, but it takes the `shots_per_state` dict instead of a
    `Results` object, and returns snake_case keys plus the rotated/projected
    shots (old `zero_data_proj` / `one_data_proj`).

    After the rotation, state_0 sits on the negative and state_1 on the positive
    real axis, so `shots_0_proj > 0` counts the misassigned state_0 shots.
    """
    data_0 = np.asarray(shots_per_state[state_0])
    data_1 = np.asarray(shots_per_state[state_1])

    mean_0 = np.mean(data_0)
    mean_1 = np.mean(data_1)

    mid_point = 0.5 * (mean_0 + mean_1)

    data_0_corr = data_0 - mid_point
    data_1_corr = data_1 - mid_point

    # old: r = np.abs(zero_mean - one_mean) / 2
    distance = np.abs(mean_0 - mean_1) / 2
    phi = np.angle(mean_0 - mid_point)

    data_0_rot = data_0_corr * np.exp(1j * (np.pi - phi))
    data_1_rot = data_1_corr * np.exp(1j * (np.pi - phi))

    std_x_0 = np.sqrt(np.var(data_0_rot.real, ddof=1))
    std_y_0 = np.sqrt(np.var(data_0_rot.imag, ddof=1))
    std_x_1 = np.sqrt(np.var(data_1_rot.real, ddof=1))
    std_y_1 = np.sqrt(np.var(data_1_rot.imag, ddof=1))

    results = {
        'distance': distance,
        'mean_0': np.mean(data_0_rot),
        'mean_1': np.mean(data_1_rot),
        'std_x_0': std_x_0,
        'std_y_0': std_y_0,
        'std_x_1': std_x_1,
        'std_y_1': std_y_1,
        'rel_std_0': std_x_0 / distance,
        'rel_std_1': std_x_1 / distance,
        'shots_0_rot': data_0_rot,
        'shots_1_rot': data_1_rot,
        'shots_0_proj': data_0_rot.real,
        'shots_1_proj': data_1_rot.real,
        'n_misassigned_0': int(np.sum(data_0_rot.real > 0)),
        'n_assigned_0': int(np.sum(data_0_rot.real <= 0)),
    }

    if plot:
        fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)
        fig.suptitle(f'Rotated single shots - {state_0} vs {state_1}')

        axs[0].set_title('Real')
        axs[0].hist(data_0_rot.real, bins=n_bins, alpha=0.5, label=state_0)
        axs[0].hist(data_1_rot.real, bins=n_bins, alpha=0.5, label=state_1)
        axs[0].set_yscale('log')
        axs[0].legend()

        axs[1].set_title('Imag')
        axs[1].hist(data_0_rot.imag, bins=n_bins, alpha=0.5, label=state_0)
        axs[1].hist(data_1_rot.imag, bins=n_bins, alpha=0.5, label=state_1)
        axs[1].set_yscale('log')
        axs[1].legend()

        results['figure'] = fig

    return results


def summarize_single_shot_metrics(res_ss, assignment_fidelity=None):
    """Compact printout of the figures of merit of one single-shot measurement."""
    print('State distance:          ', round(float(res_ss['distance']), 6))
    print('Relative STD state 0:    ', round(float(res_ss['rel_std_0']), 4))
    print('Relative STD state 1:    ', round(float(res_ss['rel_std_1']), 4))
    print('Misassigned state-0 shots:', res_ss['n_misassigned_0'],
          '/', res_ss['n_misassigned_0'] + res_ss['n_assigned_0'])
    if assignment_fidelity is not None:
        print('Assignment fidelity:     ', f'{assignment_fidelity * 100:0.2f} %')

# %% [markdown]
# ## Descriptor and Device Setup

# %%
number_of_qubits = 1

descriptor = generate_descriptor(
    #pqsc=["DEV10001"],
    shfqc_2=["DEV12192"],
    number_data_qubits=number_of_qubits,
    multiplex=True,
    number_multiplex=number_of_qubits,
    include_cr_lines=False,
    ip_address="localhost",
    #options = "SHFQC/QC2CH",
)

setup = DeviceSetup.from_descriptor(descriptor, "localhost")
setup.instruments[0].device_options = "SHFQC/QC2CH"

# %%
qubits = TunableTransmonQubit.from_device_setup(setup)

# %% [markdown]
# ## Qubit Initialization

# %%
cooldown_start_date = '2026-08-25' # YYYY-MM-DD
sample_name = 'ES-009-DE_1-2_9150'
qubit_name = 'Q2'

assert cooldown_start_date != '', 'Enter cooldown name'
assert sample_name != '', 'Enter sample name'
assert qubit_name != '', 'Enter qubit name'

# %%
qubits # Check in
# Out:
# [TunableTransmonQubit(
# │   uid='q0',
# │   signals={
# │   │   'drive': 'q0/drive',
# │   │   'drive_ef': 'q0/drive_ef',
# │   │   'measure': 'q0/measure',
# │   │   'acquire': 'q0/acquire'
# │   },
# │   parameters=TunableTransmonQubitParameters(
# │   │   custom={},
# │   │   ge_T1=0,
# │   │   ge_T2=0,
# │   │   ge_T2_star=0,
# │   │   ef_T1=0,
# │   │   ef_T2=0,
# │   │   ef_T2_star=0,
# │   │   drive_lo_frequency=None,
# │   │   readout_lo_frequency=None,
# │   │   resonance_frequency_ge=None,
# │   │   resonance_frequency_ef=None,
# │   │   readout_resonator_frequency=None,
# │   │   ge_drive_amplitude_pi=0.2,
# │   │   ge_drive_amplitude_pi2=0.1,
# │   │   ge_drive_length=5e-08,
# │   │   ge_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   ef_drive_amplitude_pi=0.2,
# │   │   ef_drive_amplitude_pi2=0.1,
# │   │   ef_drive_length=5e-08,
# │   │   ef_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   qubit_resonator_coupling_strength_g=0,
# │   │   ge_chi_shift=0,
# │   │   readout_amplitude=1.0,
# │   │   readout_length=2e-06,
# │   │   readout_pulse={
# │   │   │   'function': 'const'
# │   │   },
# │   │   readout_integration_length=2e-06,
# │   │   readout_integration_delay=2e-08,
# │   │   readout_integration_kernels_type='default',
# │   │   readout_integration_kernels=None,
# │   │   readout_integration_discrimination_thresholds=None,
# │   │   reset_delay_length=1e-06,
# │   │   drive_range=10,
# │   │   readout_range_out=5,
# │   │   readout_range_in=10,
# │   │   flux_range=5,
# │   │   spectroscopy_length=5e-06,
# │   │   spectroscopy_amplitude=1,
# │   │   spectroscopy_pulse={
# │   │   │   'function': 'const',
# │   │   │   'can_compress': True
# │   │   },
# │   │   dc_slot=0,
# │   │   dc_voltage_parking=0.0,
# │   │   flux_offset_voltage=0.0,
# │   │   user_defined={}
# │   )
# )
# ]

# %%
for q in qubits:
    q.parameters.ge_drive_pulse["sigma"] = 0.25
    q.parameters.readout_amplitude = 0.5
    q.parameters.reset_delay_length = 300e-6
    q.parameters.readout_range_out = -20
    q.parameters.readout_lo_frequency = 6e9
    q.parameters.drive_range = 0
    q.parameters.readout_range_in = -45
    q.parameters.readout_integration_delay = 80e-9

qubits[0].parameters.drive_lo_frequency = 4.8e9
qubits[0].parameters.resonance_frequency_ge = 5.01e9
qubits[0].parameters.resonance_frequency_ef = 4.8e9
qubits[0].parameters.readout_resonator_frequency = 5.9602e9
qubits[0].parameters.spectroscopy_length = 5e-6
qubits[0].parameters.spectroscopy_amplitude = 0.5
qubits[0].uid = qubit_name

# %%
qops = TunableTransmonOperations()
qpu = QPU(qubits, quantum_operations=qops)

# %%
for q in qubits:
    print("-------------")
    print("Qubit UID:", q.uid)
    print("Qubit logical signals:")
    for sig, lsg in q.signals.items():
        print(f"  {sig:<10} ('{lsg:>10}')")
# Out:
# -------------
# Qubit UID: Q2
# Qubit logical signals:
#   drive      ('  q0/drive')
#   drive_ef   ('q0/drive_ef')
#   measure    ('q0/measure')
#   acquire    ('q0/acquire')

# %% [markdown]
# ## LabOne Q Session Connection

# %%
session = Session(setup)
session.connect(do_emulation=False)
# Out:
# [2026.08.25 11:16:05.538] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is C:\Users\phys-pico-lab\Documents\laboneq_workflow_notebooks\samples\ES-009-DE_1-2_9150\laboneq_output\log
# [2026.08.25 11:16:05.584] INFO    VERSION: laboneq 26.4.0
# [2026.08.25 11:16:05.590] INFO    Connecting to data server at localhost:8004
# [2026.08.25 11:16:05.616] INFO    Connected to Zurich Instruments LabOne Data Server version 26.04.1.6 at localhost:8004
# [2026.08.25 11:16:05.645] INFO    Configuring the device setup
# [2026.08.25 11:16:05.666] INFO    The device setup is configured
# [2026.08.25 11:16:06.068] INFO    System profile saved to C:\Users\phys-pico-lab\AppData\Local\laboneq\profiles\unknown-613335402d7b7f78058d100a7c9ddd62592a6fd7431fa79c3e5a4ab0cfd13ec3.yaml

# %% [markdown]
# ## Data Saving

# %%
data_root_directory = os.path.join('N:\\', 'xld', 'qubit_thermometry_v2', sample_name, f'COOLDOWN_{cooldown_start_date}', qubit_name)
qpu_file_path = os.path.join('N:\\', 'xld', 'qubit_thermometry_v2', sample_name, f'COOLDOWN_{cooldown_start_date}', f'{sample_name}_qpu.json')

if not os.path.isdir(data_root_directory):
    os.makedirs(data_root_directory, exist_ok=True)

print(f'Saving data to: {data_root_directory}')
# Out:
# Saving data to: N:\xld\qubit_thermometry_v2\ES-009-DE_1-2_9150\COOLDOWN_2026-08-25\Q2

# %%
folder_store = workflow.logbook.FolderStore(data_root_directory)
folder_store.activate()
# folder_store.deactivate()

logging_store = LoggingStore()
logging_store.activate()
# logging_store.deactivate()

# %% [markdown]
# # Tune-Up Experiments

# %%
qpu.quantum_elements
# Out:
# [TunableTransmonQubit(
# │   uid='Q2',
# │   signals={
# │   │   'drive': 'q0/drive',
# │   │   'drive_ef': 'q0/drive_ef',
# │   │   'measure': 'q0/measure',
# │   │   'acquire': 'q0/acquire'
# │   },
# │   parameters=TunableTransmonQubitParameters(
# │   │   custom={},
# │   │   ge_T1=0,
# │   │   ge_T2=0,
# │   │   ge_T2_star=0,
# │   │   ef_T1=0,
# │   │   ef_T2=0,
# │   │   ef_T2_star=0,
# │   │   drive_lo_frequency=4800000000.0,
# │   │   readout_lo_frequency=6000000000.0,
# │   │   resonance_frequency_ge=5010000000.0,
# │   │   resonance_frequency_ef=4800000000.0,
# │   │   readout_resonator_frequency=5960200000.0,
# │   │   ge_drive_amplitude_pi=0.2,
# │   │   ge_drive_amplitude_pi2=0.1,
# │   │   ge_drive_length=5e-08,
# │   │   ge_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   ef_drive_amplitude_pi=0.2,
# │   │   ef_drive_amplitude_pi2=0.1,
# │   │   ef_drive_length=5e-08,
# │   │   ef_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   qubit_resonator_coupling_strength_g=0,
# │   │   ge_chi_shift=0,
# │   │   readout_amplitude=0.5,
# │   │   readout_length=2e-06,
# │   │   readout_pulse={
# │   │   │   'function': 'const'
# │   │   },
# │   │   readout_integration_length=2e-06,
# │   │   readout_integration_delay=8e-08,
# │   │   readout_integration_kernels_type='default',
# │   │   readout_integration_kernels=None,
# │   │   readout_integration_discrimination_thresholds=None,
# │   │   reset_delay_length=0.0003,
# │   │   drive_range=0,
# │   │   readout_range_out=-20,
# │   │   readout_range_in=-45,
# │   │   flux_range=5,
# │   │   spectroscopy_length=5e-06,
# │   │   spectroscopy_amplitude=0.5,
# │   │   spectroscopy_pulse={
# │   │   │   'function': 'const',
# │   │   │   'can_compress': True
# │   │   },
# │   │   dc_slot=0,
# │   │   dc_voltage_parking=0.0,
# │   │   flux_offset_voltage=0.0,
# │   │   user_defined={}
# │   )
# )
# ]

# %% [markdown]
# ## Spectroscopy

# %% [markdown]
# ### Resonator Spectroscopy <a class="anchor" id="resonator-spectroscopy"></a>

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

readout_range_out = -30
readout_range_in = -45
readout_amplitude = 0.1
n_avg_exponent = 15

freq_range = 10e6
n_points = 1001

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temp_pars.readout_range_out = readout_range_out
temp_pars.readout_range_in = readout_range_in
temp_pars.readout_amplitude = readout_amplitude
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = resonator_spectroscopy.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(False)

qubit_to_measure = qubits[0]

frequencies = temporary_parameters[q.uid].readout_resonator_frequency + np.linspace(
    -freq_range / 2, freq_range / 2, n_points
)

exp_workflow = resonator_spectroscopy.experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=qubit_to_measure.uid,
    frequencies=frequencies,
    options=options,
    temporary_parameters=temporary_parameters
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.25 11:17:24.418] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:17:24.418] INFO      Workflow 'resonator_spectroscopy': execution started at 2026-08-25
# [2026.08.25 11:17:24.418] INFO      08:17:24.410367Z
# [2026.08.25 11:17:24.425] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:17:24.666] INFO    Task 'temporary_qpu': started at 2026-08-25 08:17:24.666339Z
# [2026.08.25 11:17:24.740] INFO    Task 'temporary_qpu': ended at 2026-08-25 08:17:24.740489Z
# [2026.08.25 11:17:24.825] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 11:17:24.825] INFO    08:17:24.822260Z
# [2026.08.25 11:17:24.857] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 08:17:24.857362Z
# [2026.08.25 11:17:24.953] INFO    Task 'create_experiment': started at 2026-08-25 08:17:24.953438Z
# [2026.08.25 11:17:25.068] INFO    Task 'create_experiment': ended at 2026-08-25 08:17:25.068185Z
# [2026.08.25 11:17:25.182] INFO    Task 'compile_experiment': started at 2026-08-25 08:17:25.182458Z
# [2026.08.25 11:17:25.286] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 11:17:25.290] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 11:17:25.290] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 11:17:25.308] INFO    Schedule completed. [0.015 s]
# [2026.08.25 11:17:25.342] INFO    Code generation completed for all AWGs. [0.034 s]
# [2026.08.25 11:17:25.342] INFO    Completed compilation step 1 of 1. [0.053 s]
# [2026.08.25 11:17:25.353] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:17:25.355] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 11:17:25.356] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:17:25.356] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.25 11:17:25.356] INFO      SHFQC_DEV12192_sg     0          9            1           0         0
# [2026.08.25 11:17:25.358] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:17:25.358] INFO      TOTAL                           30            1                  8000
# [2026.08.25 11:17:25.360] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:17:25.404] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 11:17:25.406] INFO    Task 'compile_experiment': ended at 2026-08-25 08:17:25.406603Z
# [2026.08.25 11:17:25.539] INFO    Task 'run_experiment': started at 2026-08-25 08:17:25.539320Z
# [2026.08.25 11:17:25.676] INFO    Starting near-time execution...
# [2026.08.25 11:17:25.750] INFO    Estimated RT execution time: 101.29 s.
# [2026.08.25 11:19:07.112] INFO    Finished near-time execution.
# [2026.08.25 11:19:07.189] INFO    Task 'run_experiment': ended at 2026-08-25 08:19:07.189455Z
# [2026.08.25 11:19:07.293] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:19:07.293] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 11:19:07.297] INFO      08:19:07.293950Z
# [2026.08.25 11:19:07.297] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:19:07.390] INFO    Task 'calculate_signal_magnitude_and_phase': started at 2026-08-25
# [2026.08.25 11:19:07.390] INFO    08:19:07.388767Z
# [2026.08.25 11:19:07.430] INFO    Task 'calculate_signal_magnitude_and_phase': ended at 2026-08-25
# [2026.08.25 11:19:07.433] INFO    08:19:07.430697Z
# [2026.08.25 11:19:07.640] INFO    Task 'fit_data': started at 2026-08-25 08:19:07.640720Z
# [2026.08.25 11:19:07.770] INFO    Task 'fit_data': ended at 2026-08-25 08:19:07.769098Z
# [2026.08.25 11:19:07.800] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 08:19:07.800722Z
# [2026.08.25 11:19:07.916] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 08:19:07.916798Z
# [2026.08.25 11:19:07.997] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 08:19:07.997666Z
# [2026.08.25 11:19:08.213] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 08:19:08.203861Z
# [2026.08.25 11:19:09.239] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 08:19:09.239369Z
# [2026.08.25 11:19:09.286] INFO    Task 'plot_magnitude_phase': started at 2026-08-25 08:19:09.286015Z
# [2026.08.25 11:19:09.429] INFO    Artifact: 'Magnitude_Phase_Q2' of type 'Figure' logged at 2026-08-25
# [2026.08.25 11:19:09.429] INFO    08:19:09.429908Z
# [2026.08.25 11:19:09.865] INFO    Task 'plot_magnitude_phase': ended at 2026-08-25 08:19:09.865050Z
# [2026.08.25 11:19:09.911] INFO    Task 'plot_real_imaginary': started at 2026-08-25 08:19:09.911012Z
# [2026.08.25 11:19:10.026] INFO    Artifact: 'Real_Imaginary_Q2' of type 'Figure' logged at 2026-08-25
# [2026.08.25 11:19:10.026] INFO    08:19:10.026230Z
# [2026.08.25 11:19:10.331] INFO    Task 'plot_real_imaginary': ended at 2026-08-25 08:19:10.331518Z
# [2026.08.25 11:19:10.375] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:19:10.375] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 08:19:10.375654Z
# [2026.08.25 11:19:10.375] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:19:10.423] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:19:10.423] INFO      Workflow 'resonator_spectroscopy': execution ended at 2026-08-25
# [2026.08.25 11:19:10.423] INFO      08:19:10.423282Z
# [2026.08.25 11:19:10.428] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)

    resonator_spectroscopy.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    print("\nReadout resonator frequency: ", qubit_to_measure.parameters.readout_resonator_frequency * 1e-9, ' GHz')
    
    print('\nUpdated global experiment parameters!\n')
# Out:
# Updated global experiment parameters!
#
# {'new_parameter_values': {'Q2': {'readout_resonator_frequency': 5960170000.0+/-0}},
#  'old_parameter_values': {'Q2': {'readout_resonator_frequency': 5960200000.0}}}
#
# Readout resonator frequency:  5.960170000000001  GHz

# %% [markdown]
# ## Qubit Spectroscopy

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

spectroscopy_length = 10e-6
spectroscopy_amplitude = 0.2
readout_amplitude = 0.2
readout_length = 2e-6
drive_range = -20
n_avg_exponent = 13

freq_range = 100e6
n_points = 251

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temp_pars.spectroscopy_length = spectroscopy_length
temp_pars.spectroscopy_amplitude = spectroscopy_amplitude
temp_pars.readout_amplitude = readout_amplitude
temp_pars.readout_length = readout_length
temp_pars.drive_range = drive_range
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = qubit_spectroscopy.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.update(False) 
options.close_figures(False)

qubits_to_measure = [qubits[0]]

frequencies = [
    temporary_parameters[q.uid].resonance_frequency_ge + np.linspace(- freq_range / 2, freq_range / 2, n_points)
    for q in qubits_to_measure
]
exp_workflow = qubit_spectroscopy.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    frequencies=frequencies,
    options=options,
    temporary_parameters=temporary_parameters
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.25 11:30:02.901] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:30:02.901] INFO      Workflow 'qubit_spectroscopy': execution started at 2026-08-25
# [2026.08.25 11:30:02.901] INFO      08:30:02.901943Z
# [2026.08.25 11:30:02.917] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:30:03.196] INFO    Task 'temporary_qpu': started at 2026-08-25 08:30:03.196684Z
# [2026.08.25 11:30:03.255] INFO    Task 'temporary_qpu': ended at 2026-08-25 08:30:03.255109Z
# [2026.08.25 11:30:03.353] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 11:30:03.353] INFO    08:30:03.353456Z
# [2026.08.25 11:30:03.413] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 08:30:03.413170Z
# [2026.08.25 11:30:03.516] INFO    Task 'create_experiment': started at 2026-08-25 08:30:03.516996Z
# [2026.08.25 11:30:03.651] INFO    Task 'create_experiment': ended at 2026-08-25 08:30:03.651734Z
# [2026.08.25 11:30:03.738] INFO    Task 'compile_experiment': started at 2026-08-25 08:30:03.738466Z
# [2026.08.25 11:30:03.848] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 11:30:03.852] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 11:30:03.853] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 11:30:03.853] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 11:30:03.853] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 11:30:03.863] INFO    Schedule completed. [0.007 s]
# [2026.08.25 11:30:03.883] INFO    Code generation completed for all AWGs. [0.020 s]
# [2026.08.25 11:30:03.883] INFO    Completed compilation step 1 of 1. [0.030 s]
# [2026.08.25 11:30:03.889] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:30:03.889] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 11:30:03.889] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:30:03.889] INFO      SHFQC_DEV12192        0         10            0           1      8000
# [2026.08.25 11:30:03.895] INFO      SHFQC_DEV12192_sg     0         25            2           1        64
# [2026.08.25 11:30:03.896] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:30:03.897] INFO      TOTAL                           35            2                  8064
# [2026.08.25 11:30:03.899] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:30:03.910] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 11:30:03.912] INFO    Task 'compile_experiment': ended at 2026-08-25 08:30:03.910581Z
# [2026.08.25 11:30:04.009] INFO    Task 'run_experiment': started at 2026-08-25 08:30:04.009645Z
# [2026.08.25 11:30:04.172] INFO    Starting near-time execution...
# [2026.08.25 11:30:04.256] INFO    Estimated RT execution time: 26.91 s.
# [2026.08.25 11:30:31.232] INFO    Finished near-time execution.
# [2026.08.25 11:30:31.314] INFO    Task 'run_experiment': ended at 2026-08-25 08:30:31.314382Z
# [2026.08.25 11:30:31.456] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:30:31.456] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 11:30:31.456] INFO      08:30:31.456773Z
# [2026.08.25 11:30:31.464] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:30:31.555] INFO    Task 'calculate_signal_magnitude_and_phase': started at 2026-08-25
# [2026.08.25 11:30:31.555] INFO    08:30:31.554460Z
# [2026.08.25 11:30:31.600] INFO    Task 'calculate_signal_magnitude_and_phase': ended at 2026-08-25
# [2026.08.25 11:30:31.600] INFO    08:30:31.600691Z
# [2026.08.25 11:30:31.699] INFO    Task 'fit_data': started at 2026-08-25 08:30:31.699790Z
# [2026.08.25 11:30:31.858] INFO    Task 'fit_data': ended at 2026-08-25 08:30:31.858051Z
# [2026.08.25 11:30:31.956] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 08:30:31.956730Z
# [2026.08.25 11:30:32.086] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 08:30:32.086343Z
# [2026.08.25 11:30:32.164] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 08:30:32.164404Z
# [2026.08.25 11:30:32.281] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 08:30:32.276689Z
# [2026.08.25 11:30:32.825] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 08:30:32.825465Z
# [2026.08.25 11:30:32.872] INFO    Task 'plot_qubit_spectroscopy': started at 2026-08-25 08:30:32.872633Z
# [2026.08.25 11:30:33.000] INFO    Artifact: 'Qubit_Spectroscopy_Q2' of type 'Figure' logged at 2026-08-25
# [2026.08.25 11:30:33.008] INFO    08:30:33.000377Z
# [2026.08.25 11:30:33.450] INFO    Task 'plot_qubit_spectroscopy': ended at 2026-08-25 08:30:33.450467Z
# [2026.08.25 11:30:33.489] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:30:33.498] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 08:30:33.489097Z
# [2026.08.25 11:30:33.503] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:30:33.530] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:30:33.547] INFO      Workflow 'qubit_spectroscopy': execution ended at 2026-08-25
# [2026.08.25 11:30:33.547] INFO      08:30:33.530769Z
# [2026.08.25 11:30:33.547] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
manual_center_frequency = 5.008e9
temporary_parameters[qubit_to_measure.uid].resonance_frequency_ge = manual_center_frequency

# %%
analysis_workflow_result= workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)

    qubit_spectroscopy.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    print("\nReadout resonance frequency ge: ", qubit_to_measure.parameters.resonance_frequency_ge)
    
    print('\nUpdated global experiment parameters!\n')
# Out:
# Updated global experiment parameters!
#
# {'new_parameter_values': {'Q2': {'resonance_frequency_ge': 5008115602.771751+/-67288.13790448953}},
#  'old_parameter_values': {'Q2': {'resonance_frequency_ge': 5008000000.0}}}
# Readout resonance frequency ge:  5008115602.771751

# %% [markdown]
# # Control Pulses

# %% [markdown]
# ## First Transision: g-e

# %% [markdown]
# ### Amplitude Rabi

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ge')

drive_range = 10
drive_length = 100e-9
readout_amplitude = 0.2
n_avg_exponent = 13

amp_min = 0
amp_max = 1
n_amp = 41

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temp_pars.drive_range = drive_range
temp_pars.readout_amplitude = readout_amplitude
if transition == 'ge':
    temp_pars.ge_drive_length = drive_length
elif transition == 'ef':
    temp_pars.ef_drive_length = drive_length
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = amplitude_rabi.experiment_workflow.options()

options.count(2**n_avg_exponent)
options.close_figures(False) # Plot figures

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

exp_workflow = amplitude_rabi.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    amplitudes=[np.linspace(amp_min, amp_max, n_amp) for q in qubits_to_measure],
    options=options,
    temporary_parameters=temporary_parameters
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.25 11:35:44.111] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:35:44.113] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 08:35:44.109991Z
# [2026.08.25 11:35:44.115] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:35:44.460] INFO    Task 'temporary_qpu': started at 2026-08-25 08:35:44.460488Z
# [2026.08.25 11:35:44.549] INFO    Task 'temporary_qpu': ended at 2026-08-25 08:35:44.549233Z
# [2026.08.25 11:35:44.670] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 11:35:44.670] INFO    08:35:44.670955Z
# [2026.08.25 11:35:44.716] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 08:35:44.714448Z
# [2026.08.25 11:35:44.797] INFO    Task 'create_experiment': started at 2026-08-25 08:35:44.797185Z
# [2026.08.25 11:35:44.877] INFO    Task 'create_experiment': ended at 2026-08-25 08:35:44.877408Z
# [2026.08.25 11:35:44.942] INFO    Task 'compile_experiment': started at 2026-08-25 08:35:44.942226Z
# [2026.08.25 11:35:45.022] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 11:35:45.022] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 11:35:45.031] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 11:35:45.033] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 11:35:45.033] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 11:35:45.035] INFO    Schedule completed. [0.001 s]
# [2026.08.25 11:35:45.039] INFO    Code generation completed for all AWGs. [0.003 s]
# [2026.08.25 11:35:45.039] INFO    Completed compilation step 1 of 1. [0.006 s]
# [2026.08.25 11:35:45.044] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:35:45.046] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 11:35:45.046] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:35:45.046] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.25 11:35:45.046] INFO      SHFQC_DEV12192_sg     0        139           42           2       832
# [2026.08.25 11:35:45.046] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:35:45.046] INFO      TOTAL                          160           42                  8832
# [2026.08.25 11:35:45.053] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:35:45.068] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 11:35:45.070] INFO    Task 'compile_experiment': ended at 2026-08-25 08:35:45.068703Z
# [2026.08.25 11:35:45.169] INFO    Task 'run_experiment': started at 2026-08-25 08:35:45.169502Z
# [2026.08.25 11:35:45.279] INFO    Starting near-time execution...
# [2026.08.25 11:35:45.353] INFO    Estimated RT execution time: 106.42 s.
# [2026.08.25 11:37:31.849] INFO    Finished near-time execution.
# [2026.08.25 11:37:31.916] INFO    Task 'run_experiment': ended at 2026-08-25 08:37:31.916576Z
# [2026.08.25 11:37:32.025] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:37:32.025] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 11:37:32.025] INFO      08:37:32.025766Z
# [2026.08.25 11:37:32.025] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:37:32.122] INFO    Task 'calculate_qubit_population': started at 2026-08-25 08:37:32.122446Z
# [2026.08.25 11:37:32.214] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 08:37:32.214604Z
# [2026.08.25 11:37:32.296] INFO    Task 'fit_data': started at 2026-08-25 08:37:32.296025Z
# [2026.08.25 11:37:32.430] INFO    Task 'fit_data': ended at 2026-08-25 08:37:32.430580Z
# [2026.08.25 11:37:32.523] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 08:37:32.521448Z
# [2026.08.25 11:37:32.747] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 08:37:32.747380Z
# [2026.08.25 11:37:32.841] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 08:37:32.841714Z
# [2026.08.25 11:37:32.954] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 08:37:32.954098Z
# [2026.08.25 11:37:33.420] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 08:37:33.420642Z
# [2026.08.25 11:37:33.480] INFO    Task 'plot_population': started at 2026-08-25 08:37:33.480482Z
# [2026.08.25 11:37:33.623] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 08:37:33.623648Z
# [2026.08.25 11:37:33.922] INFO    Task 'plot_population': ended at 2026-08-25 08:37:33.922557Z
# [2026.08.25 11:37:33.953] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:37:33.953] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 08:37:33.953461Z
# [2026.08.25 11:37:33.953] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:37:34.001] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:37:34.001] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 08:37:34.001038Z
# [2026.08.25 11:37:34.001] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)
    
    amplitude_rabi.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nDrive amplitude pi ge: ", qubit_to_measure.parameters.ge_drive_amplitude_pi)
        print("Drive amplitude pi2 ge: ", qubit_to_measure.parameters.ge_drive_amplitude_pi2)
    elif transition == 'ef':
        print("\nDrive amplitude pi ef: ", qubit_to_measure.parameters.ef_drive_amplitude_pi)
        print("Drive amplitude pi2 ef: ", qubit_to_measure.parameters.ef_drive_amplitude_pi2)
    
    print('\nUpdated global experiment parameters!\n')
# Out:
# Updated global experiment parameters!
#
# {'new_parameter_values': {'Q2': {'ge_drive_amplitude_pi': 0.3695426862928893+/-0.0010423367939460773,
#                                  'ge_drive_amplitude_pi2': 0.1844107701092291+/-0.000935774748291959}},
#  'old_parameter_values': {'Q2': {'ge_drive_amplitude_pi': 0.2,
#                                  'ge_drive_amplitude_pi2': 0.1}}}
# Drive amplitude pi ge:  0.3695426862928893
# Drive amplitude pi2 ge:  0.1844107701092291

# %% [markdown]
# ### Rabi Shevron

# %% [markdown]
# #### Experiment Parameters

# %%
# Rabi chevron is a diagnostic 2D scan (amplitude vs. detuning) - it is not expected
# to update the global qubit parameters directly, so we leave this False by default.
update_global_parameters = False

transition = set_transition('ge')

drive_range = 10
drive_length = 100e-9
readout_amplitude = 0.2
n_avg_exponent = 13

amp_min = 0
amp_max = 1
n_amp = 41

# frequency detuning range swept around the qubit's current resonance frequency
chevron_detuning_min = -6e6
chevron_detuning_max = 2e6
n_detuning = 9
chevron_detunings = np.linspace(chevron_detuning_min, chevron_detuning_max, n_detuning)

if transition == 'ge':
    base_resonance_frequency = qubits[0].parameters.resonance_frequency_ge
elif transition == 'ef':
    base_resonance_frequency = qubits[0].parameters.resonance_frequency_ef

# %% [markdown]
# #### Run Workflow

# %%
options = amplitude_rabi.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(True)  # suppress per-detuning plots; we build one 2D map below

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

rabi_chevron_results = []

for detuning in chevron_detunings:
    print(f'Measuring chevron point at detuning: {detuning * 1e-6:.3f} MHz')

    temporary_parameters = {}
    temp_pars = deepcopy(qubits[0].parameters)
    temp_pars.drive_range = drive_range
    temp_pars.readout_amplitude = readout_amplitude
    if transition == 'ge':
        temp_pars.ge_drive_length = drive_length
        temp_pars.resonance_frequency_ge = base_resonance_frequency + detuning
    elif transition == 'ef':
        temp_pars.ef_drive_length = drive_length
        temp_pars.resonance_frequency_ef = base_resonance_frequency + detuning
    temporary_parameters[q.uid] = temp_pars

    exp_workflow = amplitude_rabi.experiment_workflow(
        session=session,
        qpu=qpu,
        qubits=[q.uid for q in qubits_to_measure],
        amplitudes=[np.linspace(amp_min, amp_max, n_amp) for q in qubits_to_measure],
        options=options,
        temporary_parameters=temporary_parameters
    )
    workflow_result = exp_workflow.run()

    # Raw acquired signal for the qubit under test.
    # NOTE: adjust the accessor below if `get_data` does not match the acquire
    # handle used internally by the installed version of `amplitude_rabi`.
    raw_signal = workflow_result.tasks["run_experiment"].output.get_data(qubit_to_measure.uid+"/result")
    rabi_chevron_results.append(raw_signal)

rabi_chevron_arr = np.array(rabi_chevron_results)
rabi_chevron_amp = np.linspace(amp_min, amp_max, n_amp)
# Out:
# Measuring chevron point at detuning: -6.000 MHz
# [2026.08.25 11:46:39.585] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:46:39.585] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 08:46:39.585209Z
# [2026.08.25 11:46:39.585] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:46:39.914] INFO    Task 'temporary_qpu': started at 2026-08-25 08:46:39.914167Z
# [2026.08.25 11:46:39.953] INFO    Task 'temporary_qpu': ended at 2026-08-25 08:46:39.953684Z
# [2026.08.25 11:46:40.050] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 11:46:40.050] INFO    08:46:40.050400Z
# [2026.08.25 11:46:40.101] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 08:46:40.101010Z
# [2026.08.25 11:46:40.199] INFO    Task 'create_experiment': started at 2026-08-25 08:46:40.199426Z
# [2026.08.25 11:46:40.356] INFO    Task 'create_experiment': ended at 2026-08-25 08:46:40.356002Z
# [2026.08.25 11:46:40.730] INFO    Task 'compile_experiment': started at 2026-08-25 08:46:40.730973Z
# [2026.08.25 11:46:40.804] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 11:46:40.822] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 11:46:40.822] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 11:46:40.822] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 11:46:40.822] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 11:46:40.822] INFO    Schedule completed. [0.000 s]
# [2026.08.25 11:46:40.838] INFO    Code generation completed for all AWGs. [0.010 s]
# [2026.08.25 11:46:40.838] INFO    Completed compilation step 1 of 1. [0.015 s]
# [2026.08.25 11:46:40.852] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:46:40.854] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 11:46:40.856] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:46:40.856] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.25 11:46:40.856] INFO      SHFQC_DEV12192_sg     0        139           43           2       832
# [2026.08.25 11:46:40.856] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:46:40.856] INFO      TOTAL                          160           43                  8832
# [2026.08.25 11:46:40.856] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:46:40.868] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 11:46:40.882] INFO    Task 'compile_experiment': ended at 2026-08-25 08:46:40.868221Z
# [2026.08.25 11:46:40.999] INFO    Task 'run_experiment': started at 2026-08-25 08:46:40.998014Z
# [2026.08.25 11:46:41.141] INFO    Starting near-time execution...
# [2026.08.25 11:46:41.223] INFO    Estimated RT execution time: 106.42 s.
# [2026.08.25 11:48:27.705] INFO    Finished near-time execution.
# [2026.08.25 11:48:27.773] INFO    Task 'run_experiment': ended at 2026-08-25 08:48:27.773986Z
# [2026.08.25 11:48:27.886] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:48:27.886] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 11:48:27.897] INFO      08:48:27.886404Z
# [2026.08.25 11:48:27.897] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:48:28.003] INFO    Task 'calculate_qubit_population': started at 2026-08-25 08:48:28.003356Z
# [2026.08.25 11:48:28.090] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 08:48:28.090761Z
# [2026.08.25 11:48:28.170] INFO    Task 'fit_data': started at 2026-08-25 08:48:28.170670Z
# [2026.08.25 11:48:28.299] INFO    Task 'fit_data': ended at 2026-08-25 08:48:28.299103Z
# [2026.08.25 11:48:28.380] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 08:48:28.380027Z
# [2026.08.25 11:48:28.510] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 08:48:28.508141Z
# [2026.08.25 11:48:28.588] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 08:48:28.588353Z
# [2026.08.25 11:48:28.713] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 08:48:28.713843Z
# [2026.08.25 11:48:29.392] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 08:48:29.392007Z
# [2026.08.25 11:48:29.439] INFO    Task 'plot_population': started at 2026-08-25 08:48:29.439505Z
# [2026.08.25 11:48:29.637] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 08:48:29.637561Z
# [2026.08.25 11:48:30.162] INFO    Task 'plot_population': ended at 2026-08-25 08:48:30.162996Z
# [2026.08.25 11:48:30.213] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:48:30.213] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 08:48:30.213344Z
# [2026.08.25 11:48:30.213] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:48:30.268] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:48:30.272] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 08:48:30.268724Z
# [2026.08.25 11:48:30.274] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: -5.000 MHz
# [2026.08.25 11:48:30.428] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:48:30.430] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 08:48:30.417885Z
# [2026.08.25 11:48:30.433] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:48:30.739] INFO    Task 'temporary_qpu': started at 2026-08-25 08:48:30.739751Z
# [2026.08.25 11:48:30.786] INFO    Task 'temporary_qpu': ended at 2026-08-25 08:48:30.786875Z
# [2026.08.25 11:48:30.878] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 11:48:30.882] INFO    08:48:30.878599Z
# [2026.08.25 11:48:30.931] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 08:48:30.931225Z
# [2026.08.25 11:48:31.012] INFO    Task 'create_experiment': started at 2026-08-25 08:48:31.012114Z
# [2026.08.25 11:48:31.155] INFO    Task 'create_experiment': ended at 2026-08-25 08:48:31.155941Z
# [2026.08.25 11:48:31.283] INFO    Task 'compile_experiment': started at 2026-08-25 08:48:31.283937Z
# [2026.08.25 11:48:31.430] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 11:48:31.430] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 11:48:31.442] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 11:48:31.443] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 11:48:31.443] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 11:48:31.443] INFO    Schedule completed. [0.001 s]
# [2026.08.25 11:48:31.453] INFO    Code generation completed for all AWGs. [0.009 s]
# [2026.08.25 11:48:31.455] INFO    Completed compilation step 1 of 1. [0.013 s]
# [2026.08.25 11:48:31.463] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:48:31.465] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 11:48:31.465] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:48:31.465] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.25 11:48:31.465] INFO      SHFQC_DEV12192_sg     0        139           43           2       832
# [2026.08.25 11:48:31.465] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:48:31.471] INFO      TOTAL                          160           43                  8832
# [2026.08.25 11:48:31.471] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:48:31.494] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 11:48:31.497] INFO    Task 'compile_experiment': ended at 2026-08-25 08:48:31.497703Z
# [2026.08.25 11:48:31.686] INFO    Task 'run_experiment': started at 2026-08-25 08:48:31.686261Z
# [2026.08.25 11:48:31.828] INFO    Starting near-time execution...
# [2026.08.25 11:48:31.907] INFO    Estimated RT execution time: 106.42 s.
# [2026.08.25 11:50:18.383] INFO    Finished near-time execution.
# [2026.08.25 11:50:18.481] INFO    Task 'run_experiment': ended at 2026-08-25 08:50:18.481607Z
# [2026.08.25 11:50:18.592] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:50:18.592] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 11:50:18.592] INFO      08:50:18.592946Z
# [2026.08.25 11:50:18.602] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:50:18.689] INFO    Task 'calculate_qubit_population': started at 2026-08-25 08:50:18.689377Z
# [2026.08.25 11:50:18.802] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 08:50:18.802473Z
# [2026.08.25 11:50:18.938] INFO    Task 'fit_data': started at 2026-08-25 08:50:18.938068Z
# [2026.08.25 11:50:19.063] INFO    Task 'fit_data': ended at 2026-08-25 08:50:19.060163Z
# [2026.08.25 11:50:19.138] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 08:50:19.138536Z
# [2026.08.25 11:50:19.266] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 08:50:19.266612Z
# [2026.08.25 11:50:19.364] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 08:50:19.364510Z
# [2026.08.25 11:50:19.496] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 08:50:19.491842Z
# [2026.08.25 11:50:20.104] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 08:50:20.104111Z
# [2026.08.25 11:50:20.141] INFO    Task 'plot_population': started at 2026-08-25 08:50:20.141243Z
# [2026.08.25 11:50:20.554] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 08:50:20.554726Z
# [2026.08.25 11:50:20.955] INFO    Task 'plot_population': ended at 2026-08-25 08:50:20.940033Z
# [2026.08.25 11:50:20.997] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:50:20.997] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 08:50:20.997452Z
# [2026.08.25 11:50:21.002] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:50:21.046] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:50:21.051] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 08:50:21.046802Z
# [2026.08.25 11:50:21.054] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: -4.000 MHz
# [2026.08.25 11:50:21.203] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:50:21.203] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 08:50:21.203589Z
# [2026.08.25 11:50:21.203] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:50:21.501] INFO    Task 'temporary_qpu': started at 2026-08-25 08:50:21.501177Z
# [2026.08.25 11:50:21.533] INFO    Task 'temporary_qpu': ended at 2026-08-25 08:50:21.533989Z
# [2026.08.25 11:50:21.629] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 11:50:21.629] INFO    08:50:21.629482Z
# [2026.08.25 11:50:21.685] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 08:50:21.685224Z
# [2026.08.25 11:50:21.775] INFO    Task 'create_experiment': started at 2026-08-25 08:50:21.775259Z
# [2026.08.25 11:50:21.920] INFO    Task 'create_experiment': ended at 2026-08-25 08:50:21.917790Z
# [2026.08.25 11:50:22.042] INFO    Task 'compile_experiment': started at 2026-08-25 08:50:22.042304Z
# [2026.08.25 11:50:22.207] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 11:50:22.216] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 11:50:22.221] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 11:50:22.225] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 11:50:22.227] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 11:50:22.230] INFO    Schedule completed. [0.001 s]
# [2026.08.25 11:50:22.239] INFO    Code generation completed for all AWGs. [0.008 s]
# [2026.08.25 11:50:22.241] INFO    Completed compilation step 1 of 1. [0.014 s]
# [2026.08.25 11:50:22.249] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:50:22.251] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 11:50:22.253] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:50:22.255] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.25 11:50:22.256] INFO      SHFQC_DEV12192_sg     0        139           43           2       832
# [2026.08.25 11:50:22.257] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:50:22.257] INFO      TOTAL                          160           43                  8832
# [2026.08.25 11:50:22.257] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:50:22.273] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 11:50:22.273] INFO    Task 'compile_experiment': ended at 2026-08-25 08:50:22.273133Z
# [2026.08.25 11:50:22.437] INFO    Task 'run_experiment': started at 2026-08-25 08:50:22.437204Z
# [2026.08.25 11:50:22.616] INFO    Starting near-time execution...
# [2026.08.25 11:50:22.686] INFO    Estimated RT execution time: 106.42 s.
# [2026.08.25 11:52:09.175] INFO    Finished near-time execution.
# [2026.08.25 11:52:09.256] INFO    Task 'run_experiment': ended at 2026-08-25 08:52:09.256210Z
# [2026.08.25 11:52:09.367] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:52:09.367] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 11:52:09.372] INFO      08:52:09.367873Z
# [2026.08.25 11:52:09.374] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:52:09.492] INFO    Task 'calculate_qubit_population': started at 2026-08-25 08:52:09.492381Z
# [2026.08.25 11:52:09.580] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 08:52:09.580486Z
# [2026.08.25 11:52:09.659] INFO    Task 'fit_data': started at 2026-08-25 08:52:09.659576Z
# [2026.08.25 11:52:09.793] INFO    Task 'fit_data': ended at 2026-08-25 08:52:09.787427Z
# [2026.08.25 11:52:09.868] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 08:52:09.868381Z
# [2026.08.25 11:52:09.981] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 08:52:09.981753Z
# [2026.08.25 11:52:10.058] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 08:52:10.058970Z
# [2026.08.25 11:52:10.187] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 08:52:10.187507Z
# [2026.08.25 11:52:10.670] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 08:52:10.670463Z
# [2026.08.25 11:52:10.720] INFO    Task 'plot_population': started at 2026-08-25 08:52:10.720086Z
# [2026.08.25 11:52:10.862] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 08:52:10.862865Z
# [2026.08.25 11:52:11.183] INFO    Task 'plot_population': ended at 2026-08-25 08:52:11.183987Z
# [2026.08.25 11:52:11.222] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:52:11.222] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 08:52:11.222871Z
# [2026.08.25 11:52:11.222] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:52:11.280] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:52:11.282] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 08:52:11.280690Z
# [2026.08.25 11:52:11.282] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: -3.000 MHz
# [2026.08.25 11:52:11.457] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:52:11.467] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 08:52:11.457909Z
# [2026.08.25 11:52:11.467] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:52:12.052] INFO    Task 'temporary_qpu': started at 2026-08-25 08:52:12.052218Z
# [2026.08.25 11:52:12.102] INFO    Task 'temporary_qpu': ended at 2026-08-25 08:52:12.102471Z
# [2026.08.25 11:52:12.197] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 11:52:12.197] INFO    08:52:12.197545Z
# [2026.08.25 11:52:12.265] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 08:52:12.261002Z
# [2026.08.25 11:52:12.342] INFO    Task 'create_experiment': started at 2026-08-25 08:52:12.342067Z
# [2026.08.25 11:52:12.486] INFO    Task 'create_experiment': ended at 2026-08-25 08:52:12.486051Z
# [2026.08.25 11:52:12.631] INFO    Task 'compile_experiment': started at 2026-08-25 08:52:12.631059Z
# [2026.08.25 11:52:12.729] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 11:52:12.743] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 11:52:12.743] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 11:52:12.743] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 11:52:12.746] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 11:52:12.746] INFO    Schedule completed. [0.001 s]
# [2026.08.25 11:52:12.750] INFO    Code generation completed for all AWGs. [0.008 s]
# [2026.08.25 11:52:12.759] INFO    Completed compilation step 1 of 1. [0.013 s]
# [2026.08.25 11:52:12.772] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:52:12.774] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 11:52:12.775] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:52:12.775] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.25 11:52:12.777] INFO      SHFQC_DEV12192_sg     0        139           43           2       832
# [2026.08.25 11:52:12.777] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:52:12.777] INFO      TOTAL                          160           43                  8832
# [2026.08.25 11:52:12.781] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:52:12.793] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 11:52:12.796] INFO    Task 'compile_experiment': ended at 2026-08-25 08:52:12.793284Z
# [2026.08.25 11:52:12.984] INFO    Task 'run_experiment': started at 2026-08-25 08:52:12.984424Z
# [2026.08.25 11:52:13.206] INFO    Starting near-time execution...
# [2026.08.25 11:52:13.304] INFO    Estimated RT execution time: 106.42 s.
# [2026.08.25 11:53:59.791] INFO    Finished near-time execution.
# [2026.08.25 11:53:59.904] INFO    Task 'run_experiment': ended at 2026-08-25 08:53:59.902265Z
# [2026.08.25 11:53:59.989] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:53:59.989] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 11:53:59.989] INFO      08:53:59.989418Z
# [2026.08.25 11:53:59.989] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:54:00.090] INFO    Task 'calculate_qubit_population': started at 2026-08-25 08:54:00.090022Z
# [2026.08.25 11:54:00.183] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 08:54:00.183943Z
# [2026.08.25 11:54:00.260] INFO    Task 'fit_data': started at 2026-08-25 08:54:00.260423Z
# [2026.08.25 11:54:00.420] INFO    Task 'fit_data': ended at 2026-08-25 08:54:00.420558Z
# [2026.08.25 11:54:00.528] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 08:54:00.528430Z
# [2026.08.25 11:54:00.644] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 08:54:00.644300Z
# [2026.08.25 11:54:00.745] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 08:54:00.745053Z
# [2026.08.25 11:54:00.865] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 08:54:00.865347Z
# [2026.08.25 11:54:01.184] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 08:54:01.184982Z
# [2026.08.25 11:54:01.236] INFO    Task 'plot_population': started at 2026-08-25 08:54:01.236224Z
# [2026.08.25 11:54:01.380] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 08:54:01.380372Z
# [2026.08.25 11:54:01.642] INFO    Task 'plot_population': ended at 2026-08-25 08:54:01.642115Z
# [2026.08.25 11:54:01.686] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:54:01.686] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 08:54:01.686765Z
# [2026.08.25 11:54:01.686] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:54:01.737] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:54:01.737] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 08:54:01.737153Z
# [2026.08.25 11:54:01.737] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: -2.000 MHz
# [2026.08.25 11:54:01.909] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:54:01.911] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 08:54:01.908325Z
# [2026.08.25 11:54:01.912] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:54:02.172] INFO    Task 'temporary_qpu': started at 2026-08-25 08:54:02.168273Z
# [2026.08.25 11:54:02.207] INFO    Task 'temporary_qpu': ended at 2026-08-25 08:54:02.207118Z
# [2026.08.25 11:54:02.287] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 11:54:02.287] INFO    08:54:02.287808Z
# [2026.08.25 11:54:02.344] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 08:54:02.344111Z
# [2026.08.25 11:54:02.426] INFO    Task 'create_experiment': started at 2026-08-25 08:54:02.426609Z
# [2026.08.25 11:54:02.553] INFO    Task 'create_experiment': ended at 2026-08-25 08:54:02.553487Z
# [2026.08.25 11:54:02.910] INFO    Task 'compile_experiment': started at 2026-08-25 08:54:02.910605Z
# [2026.08.25 11:54:03.003] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 11:54:03.009] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 11:54:03.010] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 11:54:03.010] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 11:54:03.010] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 11:54:03.014] INFO    Schedule completed. [0.002 s]
# [2026.08.25 11:54:03.019] INFO    Code generation completed for all AWGs. [0.005 s]
# [2026.08.25 11:54:03.025] INFO    Completed compilation step 1 of 1. [0.012 s]
# [2026.08.25 11:54:03.035] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:54:03.036] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 11:54:03.038] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:54:03.038] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.25 11:54:03.038] INFO      SHFQC_DEV12192_sg     0        139           43           2       832
# [2026.08.25 11:54:03.038] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:54:03.038] INFO      TOTAL                          160           43                  8832
# [2026.08.25 11:54:03.038] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:54:03.057] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 11:54:03.057] INFO    Task 'compile_experiment': ended at 2026-08-25 08:54:03.057832Z
# [2026.08.25 11:54:03.211] INFO    Task 'run_experiment': started at 2026-08-25 08:54:03.211956Z
# [2026.08.25 11:54:03.366] INFO    Starting near-time execution...
# [2026.08.25 11:54:03.431] INFO    Estimated RT execution time: 106.42 s.
# [2026.08.25 11:55:49.912] INFO    Finished near-time execution.
# [2026.08.25 11:55:49.973] INFO    Task 'run_experiment': ended at 2026-08-25 08:55:49.973963Z
# [2026.08.25 11:55:50.068] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:55:50.068] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 11:55:50.068] INFO      08:55:50.068438Z
# [2026.08.25 11:55:50.068] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:55:50.164] INFO    Task 'calculate_qubit_population': started at 2026-08-25 08:55:50.164848Z
# [2026.08.25 11:55:50.247] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 08:55:50.247787Z
# [2026.08.25 11:55:50.334] INFO    Task 'fit_data': started at 2026-08-25 08:55:50.334958Z
# [2026.08.25 11:55:50.470] INFO    Task 'fit_data': ended at 2026-08-25 08:55:50.470080Z
# [2026.08.25 11:55:50.567] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 08:55:50.567472Z
# [2026.08.25 11:55:50.693] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 08:55:50.693910Z
# [2026.08.25 11:55:50.778] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 08:55:50.778549Z
# [2026.08.25 11:55:50.946] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 08:55:50.946120Z
# [2026.08.25 11:55:51.416] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 08:55:51.416892Z
# [2026.08.25 11:55:51.466] INFO    Task 'plot_population': started at 2026-08-25 08:55:51.466959Z
# [2026.08.25 11:55:51.884] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 08:55:51.884534Z
# [2026.08.25 11:55:52.208] INFO    Task 'plot_population': ended at 2026-08-25 08:55:52.208490Z
# [2026.08.25 11:55:52.269] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:55:52.269] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 08:55:52.269720Z
# [2026.08.25 11:55:52.269] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:55:52.346] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:55:52.346] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 08:55:52.344778Z
# [2026.08.25 11:55:52.348] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: -1.000 MHz
# [2026.08.25 11:55:52.509] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:55:52.509] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 08:55:52.509792Z
# [2026.08.25 11:55:52.509] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:55:52.815] INFO    Task 'temporary_qpu': started at 2026-08-25 08:55:52.815483Z
# [2026.08.25 11:55:52.862] INFO    Task 'temporary_qpu': ended at 2026-08-25 08:55:52.862239Z
# [2026.08.25 11:55:52.940] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 11:55:52.940] INFO    08:55:52.937265Z
# [2026.08.25 11:55:52.988] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 08:55:52.988595Z
# [2026.08.25 11:55:53.069] INFO    Task 'create_experiment': started at 2026-08-25 08:55:53.069609Z
# [2026.08.25 11:55:53.246] INFO    Task 'create_experiment': ended at 2026-08-25 08:55:53.246399Z
# [2026.08.25 11:55:53.339] INFO    Task 'compile_experiment': started at 2026-08-25 08:55:53.327303Z
# [2026.08.25 11:55:53.423] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 11:55:53.429] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 11:55:53.429] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 11:55:53.429] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 11:55:53.429] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 11:55:53.439] INFO    Schedule completed. [0.002 s]
# [2026.08.25 11:55:53.445] INFO    Code generation completed for all AWGs. [0.006 s]
# [2026.08.25 11:55:53.445] INFO    Completed compilation step 1 of 1. [0.013 s]
# [2026.08.25 11:55:53.455] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:55:53.455] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 11:55:53.455] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:55:53.455] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.25 11:55:53.455] INFO      SHFQC_DEV12192_sg     0        139           43           2       832
# [2026.08.25 11:55:53.459] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:55:53.459] INFO      TOTAL                          160           43                  8832
# [2026.08.25 11:55:53.459] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:55:53.473] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 11:55:53.473] INFO    Task 'compile_experiment': ended at 2026-08-25 08:55:53.473351Z
# [2026.08.25 11:55:53.601] INFO    Task 'run_experiment': started at 2026-08-25 08:55:53.601649Z
# [2026.08.25 11:55:53.758] INFO    Starting near-time execution...
# [2026.08.25 11:55:53.855] INFO    Estimated RT execution time: 106.42 s.
# [2026.08.25 11:57:40.329] INFO    Finished near-time execution.
# [2026.08.25 11:57:40.431] INFO    Task 'run_experiment': ended at 2026-08-25 08:57:40.431052Z
# [2026.08.25 11:57:40.555] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:57:40.557] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 11:57:40.557] INFO      08:57:40.554037Z
# [2026.08.25 11:57:40.557] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:57:40.701] INFO    Task 'calculate_qubit_population': started at 2026-08-25 08:57:40.701561Z
# [2026.08.25 11:57:40.810] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 08:57:40.810063Z
# [2026.08.25 11:57:40.959] INFO    Task 'fit_data': started at 2026-08-25 08:57:40.959967Z
# [2026.08.25 11:57:41.173] INFO    Task 'fit_data': ended at 2026-08-25 08:57:41.173527Z
# [2026.08.25 11:57:41.303] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 08:57:41.302600Z
# [2026.08.25 11:57:41.437] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 08:57:41.432060Z
# [2026.08.25 11:57:41.517] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 08:57:41.517577Z
# [2026.08.25 11:57:41.680] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 08:57:41.680034Z
# [2026.08.25 11:57:42.163] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 08:57:42.163535Z
# [2026.08.25 11:57:42.223] INFO    Task 'plot_population': started at 2026-08-25 08:57:42.223404Z
# [2026.08.25 11:57:42.386] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 08:57:42.386398Z
# [2026.08.25 11:57:42.836] INFO    Task 'plot_population': ended at 2026-08-25 08:57:42.836273Z
# [2026.08.25 11:57:42.884] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:57:42.884] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 08:57:42.880587Z
# [2026.08.25 11:57:42.884] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:57:42.918] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:57:42.918] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 08:57:42.918521Z
# [2026.08.25 11:57:42.918] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: 0.000 MHz
# [2026.08.25 11:57:43.091] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:57:43.091] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 08:57:43.091989Z
# [2026.08.25 11:57:43.091] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:57:43.608] INFO    Task 'temporary_qpu': started at 2026-08-25 08:57:43.608711Z
# [2026.08.25 11:57:43.664] INFO    Task 'temporary_qpu': ended at 2026-08-25 08:57:43.656781Z
# [2026.08.25 11:57:43.737] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 11:57:43.737] INFO    08:57:43.737497Z
# [2026.08.25 11:57:43.787] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 08:57:43.787607Z
# [2026.08.25 11:57:43.880] INFO    Task 'create_experiment': started at 2026-08-25 08:57:43.880932Z
# [2026.08.25 11:57:44.015] INFO    Task 'create_experiment': ended at 2026-08-25 08:57:44.015470Z
# [2026.08.25 11:57:44.113] INFO    Task 'compile_experiment': started at 2026-08-25 08:57:44.113033Z
# [2026.08.25 11:57:44.187] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 11:57:44.203] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 11:57:44.203] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 11:57:44.208] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 11:57:44.208] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 11:57:44.208] INFO    Schedule completed. [0.001 s]
# [2026.08.25 11:57:44.219] INFO    Code generation completed for all AWGs. [0.006 s]
# [2026.08.25 11:57:44.221] INFO    Completed compilation step 1 of 1. [0.010 s]
# [2026.08.25 11:57:44.228] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:57:44.228] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 11:57:44.228] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:57:44.235] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.25 11:57:44.235] INFO      SHFQC_DEV12192_sg     0        139           43           2       832
# [2026.08.25 11:57:44.237] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:57:44.237] INFO      TOTAL                          160           43                  8832
# [2026.08.25 11:57:44.240] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:57:44.251] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 11:57:44.251] INFO    Task 'compile_experiment': ended at 2026-08-25 08:57:44.251270Z
# [2026.08.25 11:57:44.382] INFO    Task 'run_experiment': started at 2026-08-25 08:57:44.381088Z
# [2026.08.25 11:57:44.524] INFO    Starting near-time execution...
# [2026.08.25 11:57:44.606] INFO    Estimated RT execution time: 106.42 s.
# [2026.08.25 11:59:31.093] INFO    Finished near-time execution.
# [2026.08.25 11:59:31.184] INFO    Task 'run_experiment': ended at 2026-08-25 08:59:31.184668Z
# [2026.08.25 11:59:31.281] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:59:31.281] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 11:59:31.283] INFO      08:59:31.273458Z
# [2026.08.25 11:59:31.283] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:59:31.383] INFO    Task 'calculate_qubit_population': started at 2026-08-25 08:59:31.383814Z
# [2026.08.25 11:59:31.507] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 08:59:31.507481Z
# [2026.08.25 11:59:31.587] INFO    Task 'fit_data': started at 2026-08-25 08:59:31.587178Z
# [2026.08.25 11:59:31.737] INFO    Task 'fit_data': ended at 2026-08-25 08:59:31.735169Z
# [2026.08.25 11:59:31.828] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 08:59:31.828409Z
# [2026.08.25 11:59:31.957] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 08:59:31.957417Z
# [2026.08.25 11:59:32.045] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 08:59:32.045710Z
# [2026.08.25 11:59:32.150] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 08:59:32.150038Z
# [2026.08.25 11:59:32.519] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 08:59:32.519401Z
# [2026.08.25 11:59:32.567] INFO    Task 'plot_population': started at 2026-08-25 08:59:32.567499Z
# [2026.08.25 11:59:32.728] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 08:59:32.728812Z
# [2026.08.25 11:59:33.309] INFO    Task 'plot_population': ended at 2026-08-25 08:59:33.309001Z
# [2026.08.25 11:59:33.355] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:59:33.355] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 08:59:33.355673Z
# [2026.08.25 11:59:33.355] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:59:33.405] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:59:33.405] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 08:59:33.405013Z
# [2026.08.25 11:59:33.405] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: 1.000 MHz
# [2026.08.25 11:59:33.552] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:59:33.552] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 08:59:33.552097Z
# [2026.08.25 11:59:33.552] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 11:59:33.862] INFO    Task 'temporary_qpu': started at 2026-08-25 08:59:33.862734Z
# [2026.08.25 11:59:33.905] INFO    Task 'temporary_qpu': ended at 2026-08-25 08:59:33.905046Z
# [2026.08.25 11:59:34.004] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 11:59:34.020] INFO    08:59:34.004299Z
# [2026.08.25 11:59:34.074] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 08:59:34.074168Z
# [2026.08.25 11:59:34.156] INFO    Task 'create_experiment': started at 2026-08-25 08:59:34.156823Z
# [2026.08.25 11:59:34.278] INFO    Task 'create_experiment': ended at 2026-08-25 08:59:34.278110Z
# [2026.08.25 11:59:34.407] INFO    Task 'compile_experiment': started at 2026-08-25 08:59:34.407887Z
# [2026.08.25 11:59:34.502] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 11:59:34.502] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 11:59:34.502] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 11:59:34.502] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 11:59:34.502] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 11:59:34.518] INFO    Schedule completed. [0.001 s]
# [2026.08.25 11:59:34.523] INFO    Code generation completed for all AWGs. [0.007 s]
# [2026.08.25 11:59:34.523] INFO    Completed compilation step 1 of 1. [0.010 s]
# [2026.08.25 11:59:34.532] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:59:34.535] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 11:59:34.535] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:59:34.535] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.25 11:59:34.538] INFO      SHFQC_DEV12192_sg     0        139           43           2       832
# [2026.08.25 11:59:34.538] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:59:34.538] INFO      TOTAL                          160           43                  8832
# [2026.08.25 11:59:34.538] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 11:59:34.553] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 11:59:34.553] INFO    Task 'compile_experiment': ended at 2026-08-25 08:59:34.553371Z
# [2026.08.25 11:59:34.679] INFO    Task 'run_experiment': started at 2026-08-25 08:59:34.679975Z
# [2026.08.25 11:59:34.824] INFO    Starting near-time execution...
# [2026.08.25 11:59:34.904] INFO    Estimated RT execution time: 106.42 s.
# [2026.08.25 12:01:21.373] INFO    Finished near-time execution.
# [2026.08.25 12:01:21.452] INFO    Task 'run_experiment': ended at 2026-08-25 09:01:21.451662Z
# [2026.08.25 12:01:21.613] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:01:21.615] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 12:01:21.615] INFO      09:01:21.613015Z
# [2026.08.25 12:01:21.615] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:01:21.789] INFO    Task 'calculate_qubit_population': started at 2026-08-25 09:01:21.789069Z
# [2026.08.25 12:01:21.902] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 09:01:21.902963Z
# [2026.08.25 12:01:21.981] INFO    Task 'fit_data': started at 2026-08-25 09:01:21.981409Z
# [2026.08.25 12:01:22.171] INFO    Task 'fit_data': ended at 2026-08-25 09:01:22.169556Z
# [2026.08.25 12:01:22.289] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 09:01:22.289785Z
# [2026.08.25 12:01:22.510] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 09:01:22.494514Z
# [2026.08.25 12:01:22.573] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 09:01:22.573931Z
# [2026.08.25 12:01:22.663] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 09:01:22.663072Z
# [2026.08.25 12:01:23.037] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 09:01:23.037620Z
# [2026.08.25 12:01:23.089] INFO    Task 'plot_population': started at 2026-08-25 09:01:23.089898Z
# [2026.08.25 12:01:23.233] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 09:01:23.228180Z
# [2026.08.25 12:01:23.561] INFO    Task 'plot_population': ended at 2026-08-25 09:01:23.561548Z
# [2026.08.25 12:01:23.592] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:01:23.592] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 09:01:23.592633Z
# [2026.08.25 12:01:23.592] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:01:23.623] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:01:23.623] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 09:01:23.623006Z
# [2026.08.25 12:01:23.623] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: 2.000 MHz
# [2026.08.25 12:01:23.765] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:01:23.765] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 09:01:23.765063Z
# [2026.08.25 12:01:23.765] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:01:24.053] INFO    Task 'temporary_qpu': started at 2026-08-25 09:01:24.037776Z
# [2026.08.25 12:01:24.135] INFO    Task 'temporary_qpu': ended at 2026-08-25 09:01:24.135006Z
# [2026.08.25 12:01:24.242] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 12:01:24.242] INFO    09:01:24.242339Z
# [2026.08.25 12:01:24.281] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 09:01:24.281340Z
# [2026.08.25 12:01:24.377] INFO    Task 'create_experiment': started at 2026-08-25 09:01:24.377236Z
# [2026.08.25 12:01:24.488] INFO    Task 'create_experiment': ended at 2026-08-25 09:01:24.488701Z
# [2026.08.25 12:01:24.618] INFO    Task 'compile_experiment': started at 2026-08-25 09:01:24.618151Z
# [2026.08.25 12:01:24.733] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 12:01:24.733] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 12:01:24.744] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 12:01:24.744] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 12:01:24.746] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 12:01:24.747] INFO    Schedule completed. [0.000 s]
# [2026.08.25 12:01:24.755] INFO    Code generation completed for all AWGs. [0.006 s]
# [2026.08.25 12:01:24.755] INFO    Completed compilation step 1 of 1. [0.009 s]
# [2026.08.25 12:01:24.763] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:01:24.763] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 12:01:24.763] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:01:24.763] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.25 12:01:24.767] INFO      SHFQC_DEV12192_sg     0        139           43           2       832
# [2026.08.25 12:01:24.767] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:01:24.767] INFO      TOTAL                          160           43                  8832
# [2026.08.25 12:01:24.767] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:01:24.781] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 12:01:24.783] INFO    Task 'compile_experiment': ended at 2026-08-25 09:01:24.783693Z
# [2026.08.25 12:01:24.894] INFO    Task 'run_experiment': started at 2026-08-25 09:01:24.894897Z
# [2026.08.25 12:01:25.000] INFO    Starting near-time execution...
# [2026.08.25 12:01:25.082] INFO    Estimated RT execution time: 106.42 s.
# [2026.08.25 12:03:11.581] INFO    Finished near-time execution.
# [2026.08.25 12:03:11.644] INFO    Task 'run_experiment': ended at 2026-08-25 09:03:11.644744Z
# [2026.08.25 12:03:11.752] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:03:11.753] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 12:03:11.754] INFO      09:03:11.752922Z
# [2026.08.25 12:03:11.754] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:03:11.858] INFO    Task 'calculate_qubit_population': started at 2026-08-25 09:03:11.857389Z
# [2026.08.25 12:03:11.962] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 09:03:11.962481Z
# [2026.08.25 12:03:12.061] INFO    Task 'fit_data': started at 2026-08-25 09:03:12.060709Z
# [2026.08.25 12:03:12.202] INFO    Task 'fit_data': ended at 2026-08-25 09:03:12.202200Z
# [2026.08.25 12:03:12.284] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 09:03:12.284556Z
# [2026.08.25 12:03:12.421] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 09:03:12.421041Z
# [2026.08.25 12:03:12.523] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 09:03:12.522554Z
# [2026.08.25 12:03:12.667] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 09:03:12.667934Z
# [2026.08.25 12:03:13.036] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 09:03:13.035776Z
# [2026.08.25 12:03:13.084] INFO    Task 'plot_population': started at 2026-08-25 09:03:13.084261Z
# [2026.08.25 12:03:13.238] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 09:03:13.238253Z
# [2026.08.25 12:03:13.598] INFO    Task 'plot_population': ended at 2026-08-25 09:03:13.598028Z
# [2026.08.25 12:03:13.632] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:03:13.647] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 09:03:13.632105Z
# [2026.08.25 12:03:13.649] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:03:13.695] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:03:13.695] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 09:03:13.678983Z
# [2026.08.25 12:03:13.697] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Plot Chevron Map

# %%
X = rabi_chevron_amp
Y = chevron_detunings * 1e-6
Z = np.absolute(rabi_chevron_arr)

fig, ax = plt.subplots(figsize=(8, 6))
c = ax.pcolormesh(X, Y, Z, cmap='Reds', shading='auto')
fig.colorbar(c, ax=ax, label='Signal amplitude (a.u.)')
ax.set_xlabel('Drive amplitude (a.u.)')
ax.set_ylabel('Detuning (MHz)')
ax.set_title(f'Rabi chevron, {transition}-transition')

figname = f'Rabi_chevron_{transition}_'
file_path = get_path_to_file(figname, '.png')
plt.savefig(file_path, dpi=600, format='png', metadata=None,
        bbox_inches=None, pad_inches=0.1,
        facecolor='auto', edgecolor='auto',
        backend=None,
       )

# %% [markdown]
# #### Save Data

# %%
Data_rabi_chevron = {
    'rabi_chevron': rabi_chevron_arr,
    'detunings': chevron_detunings,
    'rabi_amp': rabi_chevron_amp,
}

file_name = f'Rabi_chevron_{transition}_'
file_path = get_path_to_file(file_name, '.mat')
savemat(file_path, Data_rabi_chevron)

# %% [markdown]
# ### Rabi Frequency Calibration

# %% [markdown]
# #### Experiment Parameters

# %%
# This experiment derives a slope/intercept relation between drive-pulse length and
# the required pi-pulse amplitude. It is diagnostic/informational (used to
# extrapolate the amplitude needed for a target pulse length or Rabi frequency), so
# it does not directly overwrite `qubit_to_measure.parameters` below.
update_global_parameters = False

transition = set_transition('ge')

drive_range = 10
readout_amplitude = 0.2
n_avg_exponent = 12

amp_min = 0
amp_max = 1.0
n_amp = 101

drive_length_min = 50e-9
drive_length_max = 400e-9
n_drive_length = 36
drive_lengths = np.linspace(drive_length_min, drive_length_max, n_drive_length)

# %% [markdown]
# #### Run Workflow

# %%
options = amplitude_rabi.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(True)  # suppress per-length plots; we build one summary plot below

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

fitted_pi_amplitudes = []

for drive_length in drive_lengths:
    print(f'Measuring Rabi with drive length: {drive_length * 1e9:.1f} ns')

    temporary_parameters = {}
    temp_pars = deepcopy(qubits[0].parameters)
    temp_pars.drive_range = drive_range
    temp_pars.readout_amplitude = readout_amplitude
    if transition == 'ge':
        temp_pars.ge_drive_length = drive_length
    elif transition == 'ef':
        temp_pars.ef_drive_length = drive_length
    temporary_parameters[q.uid] = temp_pars

    exp_workflow = amplitude_rabi.experiment_workflow(
        session=session,
        qpu=qpu,
        qubits=[q.uid for q in qubits_to_measure],
        amplitudes=[np.linspace(amp_min, amp_max, n_amp) for q in qubits_to_measure],
        options=options,
        temporary_parameters=temporary_parameters
    )
    workflow_result = exp_workflow.run()

    analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
    # NOTE: adjust the key names below to match the installed library version if
    # `new_parameter_values` is not nested exactly this way.
    new_parameter_values = analysis_workflow_result.output["new_parameter_values"]
    if transition == 'ge':
        fitted_pi_amplitude = new_parameter_values[qubit_to_measure.uid]["ge_drive_amplitude_pi"]
    elif transition == 'ef':
        fitted_pi_amplitude = new_parameter_values[qubit_to_measure.uid]["ef_drive_amplitude_pi"]
    fitted_pi_amplitudes.append(fitted_pi_amplitude)

fitted_pi_amplitudes = np.array(fitted_pi_amplitudes)
# Out:
# Measuring Rabi with drive length: 50.0 ns
# [2026.08.25 12:07:04.042] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:07:04.046] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 09:07:04.042559Z
# [2026.08.25 12:07:04.046] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:07:04.401] INFO    Task 'temporary_qpu': started at 2026-08-25 09:07:04.401034Z
# [2026.08.25 12:07:04.462] INFO    Task 'temporary_qpu': ended at 2026-08-25 09:07:04.460122Z
# [2026.08.25 12:07:04.561] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 12:07:04.563] INFO    09:07:04.561716Z
# [2026.08.25 12:07:04.615] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 09:07:04.615436Z
# [2026.08.25 12:07:04.701] INFO    Task 'create_experiment': started at 2026-08-25 09:07:04.701500Z
# [2026.08.25 12:07:04.814] INFO    Task 'create_experiment': ended at 2026-08-25 09:07:04.814948Z
# [2026.08.25 12:07:04.941] INFO    Task 'compile_experiment': started at 2026-08-25 09:07:04.941180Z
# [2026.08.25 12:07:05.069] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 12:07:05.069] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 12:07:05.069] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 12:07:05.069] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 12:07:05.069] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 12:07:05.085] INFO    Schedule completed. [0.001 s]
# [2026.08.25 12:07:05.090] INFO    Code generation completed for all AWGs. [0.010 s]
# [2026.08.25 12:07:05.098] INFO    Completed compilation step 1 of 1. [0.014 s]
# [2026.08.25 12:07:05.101] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:07:05.101] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 12:07:05.101] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:07:05.101] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.25 12:07:05.101] INFO      SHFQC_DEV12192_sg     0        319          103           2       448
# [2026.08.25 12:07:05.111] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:07:05.111] INFO      TOTAL                          340          103                  8448
# [2026.08.25 12:07:05.113] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:07:05.126] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 12:07:05.126] INFO    Task 'compile_experiment': ended at 2026-08-25 09:07:05.126814Z
# [2026.08.25 12:07:05.290] INFO    Task 'run_experiment': started at 2026-08-25 09:07:05.290097Z
# [2026.08.25 12:07:05.427] INFO    Starting near-time execution...
# [2026.08.25 12:07:05.535] INFO    Estimated RT execution time: 127.43 s.
# [2026.08.25 12:09:13.034] INFO    Finished near-time execution.
# [2026.08.25 12:09:13.179] INFO    Task 'run_experiment': ended at 2026-08-25 09:09:13.179756Z
# [2026.08.25 12:09:13.292] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:09:13.292] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 12:09:13.305] INFO      09:09:13.292035Z
# [2026.08.25 12:09:13.306] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:09:13.387] INFO    Task 'calculate_qubit_population': started at 2026-08-25 09:09:13.387251Z
# [2026.08.25 12:09:13.466] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 09:09:13.466513Z
# [2026.08.25 12:09:13.546] INFO    Task 'fit_data': started at 2026-08-25 09:09:13.546662Z
# [2026.08.25 12:09:13.675] INFO    Task 'fit_data': ended at 2026-08-25 09:09:13.675194Z
# [2026.08.25 12:09:13.761] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 09:09:13.761130Z
# [2026.08.25 12:09:13.883] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 09:09:13.867436Z
# [2026.08.25 12:09:13.979] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 09:09:13.967696Z
# [2026.08.25 12:09:14.107] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 09:09:14.107824Z
# [2026.08.25 12:09:14.495] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 09:09:14.495383Z
# [2026.08.25 12:09:14.527] INFO    Task 'plot_population': started at 2026-08-25 09:09:14.527105Z
# [2026.08.25 12:09:14.783] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 09:09:14.783381Z
# [2026.08.25 12:09:15.400] INFO    Task 'plot_population': ended at 2026-08-25 09:09:15.400334Z
# [2026.08.25 12:09:15.429] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:09:15.429] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 09:09:15.429327Z
# [2026.08.25 12:09:15.429] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:09:15.479] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:09:15.479] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 09:09:15.479155Z
# [2026.08.25 12:09:15.479] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring Rabi with drive length: 60.0 ns
# [2026.08.25 12:09:15.610] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:09:15.610] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 09:09:15.610068Z
# [2026.08.25 12:09:15.610] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:09:15.863] INFO    Task 'temporary_qpu': started at 2026-08-25 09:09:15.863586Z
# [2026.08.25 12:09:15.895] INFO    Task 'temporary_qpu': ended at 2026-08-25 09:09:15.895162Z
# [2026.08.25 12:09:15.976] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 12:09:15.976] INFO    09:09:15.976838Z
# [2026.08.25 12:09:16.024] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 09:09:16.024110Z
# [2026.08.25 12:09:16.103] INFO    Task 'create_experiment': started at 2026-08-25 09:09:16.103629Z
# [2026.08.25 12:09:16.216] INFO    Task 'create_experiment': ended at 2026-08-25 09:09:16.216197Z
# [2026.08.25 12:09:16.296] INFO    Task 'compile_experiment': started at 2026-08-25 09:09:16.296776Z
# [2026.08.25 12:09:16.379] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 12:09:16.379] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 12:09:16.379] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 12:09:16.379] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 12:09:16.379] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 12:09:16.389] INFO    Schedule completed. [0.001 s]
# [2026.08.25 12:09:16.399] INFO    Code generation completed for all AWGs. [0.009 s]
# [2026.08.25 12:09:16.399] INFO    Completed compilation step 1 of 1. [0.014 s]
# [2026.08.25 12:09:16.417] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:09:16.423] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 12:09:16.423] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:09:16.425] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.25 12:09:16.425] INFO      SHFQC_DEV12192_sg     0        319          103           2       512
# [2026.08.25 12:09:16.428] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:09:16.428] INFO      TOTAL                          340          103                  8512
# [2026.08.25 12:09:16.430] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:09:16.439] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 12:09:16.439] INFO    Task 'compile_experiment': ended at 2026-08-25 09:09:16.439985Z
# [2026.08.25 12:09:16.553] INFO    Task 'run_experiment': started at 2026-08-25 09:09:16.553152Z
# [2026.08.25 12:09:16.718] INFO    Starting near-time execution...
# [2026.08.25 12:09:16.814] INFO    Estimated RT execution time: 127.44 s.
# [2026.08.25 12:11:24.321] INFO    Finished near-time execution.
# [2026.08.25 12:11:24.402] INFO    Task 'run_experiment': ended at 2026-08-25 09:11:24.402192Z
# [2026.08.25 12:11:24.489] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:11:24.489] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 12:11:24.489] INFO      09:11:24.489695Z
# [2026.08.25 12:11:24.493] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:11:24.589] INFO    Task 'calculate_qubit_population': started at 2026-08-25 09:11:24.585976Z
# [2026.08.25 12:11:24.674] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 09:11:24.674374Z
# [2026.08.25 12:11:24.755] INFO    Task 'fit_data': started at 2026-08-25 09:11:24.755349Z
# [2026.08.25 12:11:24.905] INFO    Task 'fit_data': ended at 2026-08-25 09:11:24.905269Z
# [2026.08.25 12:11:24.982] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 09:11:24.982055Z
# [2026.08.25 12:11:25.142] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 09:11:25.142274Z
# [2026.08.25 12:11:25.229] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 09:11:25.229375Z
# [2026.08.25 12:11:25.318] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 09:11:25.318708Z
# [2026.08.25 12:11:25.753] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 09:11:25.753401Z
# [2026.08.25 12:11:25.801] INFO    Task 'plot_population': started at 2026-08-25 09:11:25.801163Z
# [2026.08.25 12:11:25.946] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 09:11:25.931630Z
# [2026.08.25 12:11:26.218] INFO    Task 'plot_population': ended at 2026-08-25 09:11:26.218552Z
# [2026.08.25 12:11:26.291] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:11:26.291] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 09:11:26.291789Z
# [2026.08.25 12:11:26.291] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:11:26.330] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:11:26.345] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 09:11:26.330217Z
# [2026.08.25 12:11:26.347] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring Rabi with drive length: 70.0 ns
# [2026.08.25 12:11:26.493] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:11:26.493] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 09:11:26.493164Z
# [2026.08.25 12:11:26.493] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:11:26.813] INFO    Task 'temporary_qpu': started at 2026-08-25 09:11:26.813856Z
# [2026.08.25 12:11:26.846] INFO    Task 'temporary_qpu': ended at 2026-08-25 09:11:26.846062Z
# [2026.08.25 12:11:26.942] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 12:11:26.942] INFO    09:11:26.942939Z
# [2026.08.25 12:11:26.973] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 09:11:26.973551Z
# [2026.08.25 12:11:27.057] INFO    Task 'create_experiment': started at 2026-08-25 09:11:27.057726Z
# [2026.08.25 12:11:27.193] INFO    Task 'create_experiment': ended at 2026-08-25 09:11:27.182160Z
# [2026.08.25 12:11:27.261] INFO    Task 'compile_experiment': started at 2026-08-25 09:11:27.261399Z
# [2026.08.25 12:11:27.358] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 12:11:27.358] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 12:11:27.358] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 12:11:27.358] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 12:11:27.363] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 12:11:27.365] INFO    Schedule completed. [0.004 s]
# [2026.08.25 12:11:27.384] INFO    Code generation completed for all AWGs. [0.014 s]
# [2026.08.25 12:11:27.390] INFO    Completed compilation step 1 of 1. [0.022 s]
# [2026.08.25 12:11:27.393] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:11:27.393] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 12:11:27.393] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:11:27.393] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.25 12:11:27.393] INFO      SHFQC_DEV12192_sg     0        319          103           2       576
# [2026.08.25 12:11:27.393] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:11:27.393] INFO      TOTAL                          340          103                  8576
# [2026.08.25 12:11:27.393] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:11:27.414] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 12:11:27.414] INFO    Task 'compile_experiment': ended at 2026-08-25 09:11:27.414408Z
# [2026.08.25 12:11:27.534] INFO    Task 'run_experiment': started at 2026-08-25 09:11:27.534925Z
# [2026.08.25 12:11:27.694] INFO    Starting near-time execution...
# [2026.08.25 12:11:27.807] INFO    Estimated RT execution time: 127.44 s.
# [2026.08.25 12:13:35.335] INFO    Finished near-time execution.
# [2026.08.25 12:13:35.471] INFO    Task 'run_experiment': ended at 2026-08-25 09:13:35.471528Z
# [2026.08.25 12:13:35.646] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:13:35.648] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 12:13:35.648] INFO      09:13:35.646474Z
# [2026.08.25 12:13:35.649] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:13:35.744] INFO    Task 'calculate_qubit_population': started at 2026-08-25 09:13:35.744380Z
# [2026.08.25 12:13:35.888] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 09:13:35.888840Z
# [2026.08.25 12:13:35.976] INFO    Task 'fit_data': started at 2026-08-25 09:13:35.976878Z
# [2026.08.25 12:13:36.113] INFO    Task 'fit_data': ended at 2026-08-25 09:13:36.113046Z
# [2026.08.25 12:13:36.209] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 09:13:36.209025Z
# [2026.08.25 12:13:36.370] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 09:13:36.370026Z
# [2026.08.25 12:13:36.437] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 09:13:36.437584Z
# [2026.08.25 12:13:36.537] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 09:13:36.537918Z
# [2026.08.25 12:13:36.867] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 09:13:36.867258Z
# [2026.08.25 12:13:36.915] INFO    Task 'plot_population': started at 2026-08-25 09:13:36.898769Z
# [2026.08.25 12:13:37.061] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 09:13:37.061520Z
# [2026.08.25 12:13:37.382] INFO    Task 'plot_population': ended at 2026-08-25 09:13:37.382637Z
# [2026.08.25 12:13:37.398] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:13:37.414] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 09:13:37.398326Z
# [2026.08.25 12:13:37.414] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:13:37.445] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:13:37.445] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 09:13:37.445992Z
# [2026.08.25 12:13:37.445] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring Rabi with drive length: 80.0 ns
# [2026.08.25 12:13:37.575] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:13:37.575] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 09:13:37.575600Z
# [2026.08.25 12:13:37.575] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:13:37.895] INFO    Task 'temporary_qpu': started at 2026-08-25 09:13:37.895663Z
# [2026.08.25 12:13:37.931] INFO    Task 'temporary_qpu': ended at 2026-08-25 09:13:37.931507Z
# [2026.08.25 12:13:38.008] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 12:13:38.024] INFO    09:13:38.008464Z
# [2026.08.25 12:13:38.058] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 09:13:38.058266Z
# [2026.08.25 12:13:38.156] INFO    Task 'create_experiment': started at 2026-08-25 09:13:38.156621Z
# [2026.08.25 12:13:38.250] INFO    Task 'create_experiment': ended at 2026-08-25 09:13:38.250076Z
# [2026.08.25 12:13:38.346] INFO    Task 'compile_experiment': started at 2026-08-25 09:13:38.346471Z
# [2026.08.25 12:13:38.443] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 12:13:38.443] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 12:13:38.459] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 12:13:38.459] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 12:13:38.461] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 12:13:38.465] INFO    Schedule completed. [0.004 s]
# [2026.08.25 12:13:38.477] INFO    Code generation completed for all AWGs. [0.011 s]
# [2026.08.25 12:13:38.477] INFO    Completed compilation step 1 of 1. [0.021 s]
# [2026.08.25 12:13:38.493] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:13:38.493] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 12:13:38.493] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:13:38.493] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.25 12:13:38.493] INFO      SHFQC_DEV12192_sg     0        319          103           2       640
# [2026.08.25 12:13:38.502] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:13:38.504] INFO      TOTAL                          340          103                  8640
# [2026.08.25 12:13:38.506] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:13:38.524] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 12:13:38.524] INFO    Task 'compile_experiment': ended at 2026-08-25 09:13:38.524107Z
# [2026.08.25 12:13:38.641] INFO    Task 'run_experiment': started at 2026-08-25 09:13:38.641125Z
# [2026.08.25 12:13:38.781] INFO    Starting near-time execution...
# [2026.08.25 12:13:38.845] INFO    Estimated RT execution time: 127.44 s.
# [2026.08.25 12:15:46.331] WARNING SHFQC/QA:dev12192: Channel 0 Input overrange count: 1
# [2026.08.25 12:15:46.381] INFO    Finished near-time execution.
# [2026.08.25 12:15:46.492] INFO    Task 'run_experiment': ended at 2026-08-25 09:15:46.492762Z
# [2026.08.25 12:15:46.686] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:15:46.686] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 12:15:46.701] INFO      09:15:46.686457Z
# [2026.08.25 12:15:46.702] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:15:46.798] INFO    Task 'calculate_qubit_population': started at 2026-08-25 09:15:46.798542Z
# [2026.08.25 12:15:46.881] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 09:15:46.881941Z
# [2026.08.25 12:15:46.959] INFO    Task 'fit_data': started at 2026-08-25 09:15:46.959340Z
# [2026.08.25 12:15:47.104] INFO    Task 'fit_data': ended at 2026-08-25 09:15:47.098752Z
# [2026.08.25 12:15:47.186] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 09:15:47.186278Z
# [2026.08.25 12:15:47.296] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 09:15:47.296350Z
# [2026.08.25 12:15:47.361] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 09:15:47.361219Z
# [2026.08.25 12:15:47.482] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 09:15:47.482812Z
# [2026.08.25 12:15:48.053] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 09:15:48.053540Z
# [2026.08.25 12:15:48.166] INFO    Task 'plot_population': started at 2026-08-25 09:15:48.166604Z
# [2026.08.25 12:15:48.310] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 09:15:48.310694Z
# [2026.08.25 12:15:48.746] INFO    Task 'plot_population': ended at 2026-08-25 09:15:48.746738Z
# [2026.08.25 12:15:48.795] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:15:48.795] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 09:15:48.795728Z
# [2026.08.25 12:15:48.795] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:15:48.842] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:15:48.842] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 09:15:48.842898Z
# [2026.08.25 12:15:48.858] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring Rabi with drive length: 90.0 ns
# [2026.08.25 12:15:49.020] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:15:49.020] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 09:15:49.020545Z
# [2026.08.25 12:15:49.036] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:15:49.357] INFO    Task 'temporary_qpu': started at 2026-08-25 09:15:49.357575Z
# [2026.08.25 12:15:49.389] INFO    Task 'temporary_qpu': ended at 2026-08-25 09:15:49.389727Z
# [2026.08.25 12:15:49.486] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 12:15:49.486] INFO    09:15:49.486264Z
# [2026.08.25 12:15:49.533] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 09:15:49.533767Z
# [2026.08.25 12:15:49.614] INFO    Task 'create_experiment': started at 2026-08-25 09:15:49.614467Z
# [2026.08.25 12:15:49.774] INFO    Task 'create_experiment': ended at 2026-08-25 09:15:49.774100Z
# [2026.08.25 12:15:49.838] INFO    Task 'compile_experiment': started at 2026-08-25 09:15:49.838777Z
# [2026.08.25 12:15:49.935] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 12:15:49.935] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 12:15:49.949] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 12:15:49.951] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 12:15:49.953] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 12:15:49.957] INFO    Schedule completed. [0.004 s]
# [2026.08.25 12:15:49.966] INFO    Code generation completed for all AWGs. [0.010 s]
# [2026.08.25 12:15:49.966] INFO    Completed compilation step 1 of 1. [0.018 s]
# [2026.08.25 12:15:49.966] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:15:49.983] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 12:15:49.983] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:15:49.983] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.25 12:15:49.987] INFO      SHFQC_DEV12192_sg     0        319          103           2       768
# [2026.08.25 12:15:49.987] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:15:49.987] INFO      TOTAL                          340          103                  8768
# [2026.08.25 12:15:49.987] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:15:50.022] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 12:15:50.022] INFO    Task 'compile_experiment': ended at 2026-08-25 09:15:50.022837Z
# [2026.08.25 12:15:50.111] INFO    Task 'run_experiment': started at 2026-08-25 09:15:50.111108Z
# [2026.08.25 12:15:50.241] INFO    Starting near-time execution...
# [2026.08.25 12:15:50.319] INFO    Estimated RT execution time: 127.45 s.
# [2026.08.25 12:17:57.840] INFO    Finished near-time execution.
# [2026.08.25 12:17:57.952] INFO    Task 'run_experiment': ended at 2026-08-25 09:17:57.952609Z
# [2026.08.25 12:17:58.099] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:17:58.099] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 12:17:58.099] INFO      09:17:58.099105Z
# [2026.08.25 12:17:58.099] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:17:58.195] INFO    Task 'calculate_qubit_population': started at 2026-08-25 09:17:58.195034Z
# [2026.08.25 12:17:58.305] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 09:17:58.305982Z
# [2026.08.25 12:17:58.402] INFO    Task 'fit_data': started at 2026-08-25 09:17:58.402167Z
# [2026.08.25 12:17:58.530] INFO    Task 'fit_data': ended at 2026-08-25 09:17:58.530257Z
# [2026.08.25 12:17:58.629] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 09:17:58.629415Z
# [2026.08.25 12:17:58.786] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 09:17:58.786329Z
# [2026.08.25 12:17:58.906] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 09:17:58.906803Z
# [2026.08.25 12:17:59.020] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 09:17:59.020589Z
# [2026.08.25 12:17:59.497] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 09:17:59.497195Z
# [2026.08.25 12:17:59.541] INFO    Task 'plot_population': started at 2026-08-25 09:17:59.541532Z
# [2026.08.25 12:17:59.686] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 09:17:59.686130Z
# [2026.08.25 12:18:00.106] INFO    Task 'plot_population': ended at 2026-08-25 09:18:00.106302Z
# [2026.08.25 12:18:00.162] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:18:00.162] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 09:18:00.162791Z
# [2026.08.25 12:18:00.162] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:18:00.202] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:18:00.202] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 09:18:00.202383Z
# [2026.08.25 12:18:00.212] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring Rabi with drive length: 100.0 ns
# [2026.08.25 12:18:00.362] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:18:00.362] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 09:18:00.362422Z
# [2026.08.25 12:18:00.362] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:18:00.637] INFO    Task 'temporary_qpu': started at 2026-08-25 09:18:00.637505Z
# [2026.08.25 12:18:00.685] INFO    Task 'temporary_qpu': ended at 2026-08-25 09:18:00.685503Z
# [2026.08.25 12:18:00.831] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 12:18:00.831] INFO    09:18:00.831141Z
# [2026.08.25 12:18:00.871] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 09:18:00.871857Z
# [2026.08.25 12:18:00.964] INFO    Task 'create_experiment': started at 2026-08-25 09:18:00.964350Z
# [2026.08.25 12:18:01.085] INFO    Task 'create_experiment': ended at 2026-08-25 09:18:01.085951Z
# [2026.08.25 12:18:01.199] INFO    Task 'compile_experiment': started at 2026-08-25 09:18:01.199401Z
# [2026.08.25 12:18:01.365] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 12:18:01.372] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 12:18:01.374] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 12:18:01.374] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 12:18:01.380] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 12:18:01.384] INFO    Schedule completed. [0.002 s]
# [2026.08.25 12:18:01.396] INFO    Code generation completed for all AWGs. [0.010 s]
# [2026.08.25 12:18:01.400] INFO    Completed compilation step 1 of 1. [0.018 s]
# [2026.08.25 12:18:01.407] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:18:01.410] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 12:18:01.410] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:18:01.410] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.25 12:18:01.415] INFO      SHFQC_DEV12192_sg     0        319          103           2       832
# [2026.08.25 12:18:01.415] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:18:01.415] INFO      TOTAL                          340          103                  8832
# [2026.08.25 12:18:01.415] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:18:01.424] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 12:18:01.424] INFO    Task 'compile_experiment': ended at 2026-08-25 09:18:01.424945Z
# [2026.08.25 12:18:01.597] INFO    Task 'run_experiment': started at 2026-08-25 09:18:01.597067Z
# [2026.08.25 12:18:01.773] INFO    Starting near-time execution...
# [2026.08.25 12:18:01.849] INFO    Estimated RT execution time: 127.45 s.
# [2026.08.25 12:20:09.378] INFO    Finished near-time execution.
# [2026.08.25 12:20:09.529] INFO    Task 'run_experiment': ended at 2026-08-25 09:20:09.529695Z
# [2026.08.25 12:20:09.684] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:20:09.684] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 12:20:09.684] INFO      09:20:09.681786Z
# [2026.08.25 12:20:09.684] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:20:09.794] INFO    Task 'calculate_qubit_population': started at 2026-08-25 09:20:09.794807Z
# [2026.08.25 12:20:09.908] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 09:20:09.908129Z
# [2026.08.25 12:20:10.034] INFO    Task 'fit_data': started at 2026-08-25 09:20:10.034877Z
# [2026.08.25 12:20:10.186] INFO    Task 'fit_data': ended at 2026-08-25 09:20:10.186127Z
# [2026.08.25 12:20:10.283] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 09:20:10.283152Z
# [2026.08.25 12:20:10.415] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 09:20:10.415977Z
# [2026.08.25 12:20:10.524] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 09:20:10.524221Z
# [2026.08.25 12:20:10.686] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 09:20:10.684432Z
# [2026.08.25 12:20:11.088] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 09:20:11.088441Z
# [2026.08.25 12:20:11.143] INFO    Task 'plot_population': started at 2026-08-25 09:20:11.141928Z
# [2026.08.25 12:20:11.296] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 09:20:11.296894Z
# [2026.08.25 12:20:11.683] INFO    Task 'plot_population': ended at 2026-08-25 09:20:11.683017Z
# [2026.08.25 12:20:11.748] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:20:11.748] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 09:20:11.748451Z
# [2026.08.25 12:20:11.748] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:20:11.779] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:20:11.779] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 09:20:11.779499Z
# [2026.08.25 12:20:11.779] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring Rabi with drive length: 110.0 ns
# [2026.08.25 12:20:11.989] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:20:11.989] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 09:20:11.989572Z
# [2026.08.25 12:20:11.989] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:20:12.312] INFO    Task 'temporary_qpu': started at 2026-08-25 09:20:12.312312Z
# [2026.08.25 12:20:12.362] INFO    Task 'temporary_qpu': ended at 2026-08-25 09:20:12.362661Z
# [2026.08.25 12:20:12.473] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 12:20:12.473] INFO    09:20:12.473258Z
# [2026.08.25 12:20:12.523] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 09:20:12.523351Z
# [2026.08.25 12:20:12.644] INFO    Task 'create_experiment': started at 2026-08-25 09:20:12.644121Z
# [2026.08.25 12:20:12.755] INFO    Task 'create_experiment': ended at 2026-08-25 09:20:12.755102Z
# [2026.08.25 12:20:12.889] INFO    Task 'compile_experiment': started at 2026-08-25 09:20:12.889700Z
# [2026.08.25 12:20:13.019] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 12:20:13.024] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 12:20:13.024] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 12:20:13.024] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 12:20:13.028] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 12:20:13.030] INFO    Schedule completed. [0.003 s]
# [2026.08.25 12:20:13.050] INFO    Code generation completed for all AWGs. [0.014 s]
# [2026.08.25 12:20:13.050] INFO    Completed compilation step 1 of 1. [0.023 s]
# [2026.08.25 12:20:13.050] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:20:13.050] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 12:20:13.050] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:20:13.063] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.25 12:20:13.065] INFO      SHFQC_DEV12192_sg     0        319          103           2       896
# [2026.08.25 12:20:13.065] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:20:13.066] INFO      TOTAL                          340          103                  8896
# [2026.08.25 12:20:13.067] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:20:13.088] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 12:20:13.088] INFO    Task 'compile_experiment': ended at 2026-08-25 09:20:13.088187Z
# [2026.08.25 12:20:13.212] INFO    Task 'run_experiment': started at 2026-08-25 09:20:13.212020Z
# [2026.08.25 12:20:13.408] INFO    Starting near-time execution...
# [2026.08.25 12:20:13.499] INFO    Estimated RT execution time: 127.46 s.
# [2026.08.25 12:22:20.985] WARNING SHFQC/QA:dev12192: Channel 0 Input overrange count: 1
# [2026.08.25 12:22:21.031] INFO    Finished near-time execution.
# [2026.08.25 12:22:21.121] INFO    Task 'run_experiment': ended at 2026-08-25 09:22:21.121505Z
# [2026.08.25 12:22:21.235] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:22:21.235] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 12:22:21.235] INFO      09:22:21.235880Z
# [2026.08.25 12:22:21.235] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:22:21.348] INFO    Task 'calculate_qubit_population': started at 2026-08-25 09:22:21.348657Z
# [2026.08.25 12:22:21.426] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 09:22:21.426759Z
# [2026.08.25 12:22:21.524] INFO    Task 'fit_data': started at 2026-08-25 09:22:21.524506Z
# [2026.08.25 12:22:21.667] INFO    Task 'fit_data': ended at 2026-08-25 09:22:21.667643Z
# [2026.08.25 12:22:21.749] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 09:22:21.749895Z
# [2026.08.25 12:22:21.928] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 09:22:21.928445Z
# [2026.08.25 12:22:22.021] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 09:22:22.021109Z
# [2026.08.25 12:22:22.166] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 09:22:22.166852Z
# [2026.08.25 12:22:22.619] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 09:22:22.619093Z
# [2026.08.25 12:22:22.666] INFO    Task 'plot_population': started at 2026-08-25 09:22:22.666949Z
# [2026.08.25 12:22:22.808] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 09:22:22.808717Z
# [2026.08.25 12:22:23.181] INFO    Task 'plot_population': ended at 2026-08-25 09:22:23.181932Z
# [2026.08.25 12:22:23.216] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:22:23.216] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 09:22:23.216452Z
# [2026.08.25 12:22:23.216] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:22:23.258] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:22:23.258] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 09:22:23.258069Z
# [2026.08.25 12:22:23.268] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring Rabi with drive length: 120.0 ns
# [2026.08.25 12:22:23.389] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:22:23.389] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 09:22:23.389127Z
# [2026.08.25 12:22:23.389] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:22:23.909] INFO    Task 'temporary_qpu': started at 2026-08-25 09:22:23.909293Z
# [2026.08.25 12:22:23.953] INFO    Task 'temporary_qpu': ended at 2026-08-25 09:22:23.953433Z
# [2026.08.25 12:22:24.292] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 12:22:24.292] INFO    09:22:24.292488Z
# [2026.08.25 12:22:24.338] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 09:22:24.338835Z
# [2026.08.25 12:22:24.440] INFO    Task 'create_experiment': started at 2026-08-25 09:22:24.439334Z
# [2026.08.25 12:22:24.547] INFO    Task 'create_experiment': ended at 2026-08-25 09:22:24.547925Z
# [2026.08.25 12:22:24.628] INFO    Task 'compile_experiment': started at 2026-08-25 09:22:24.628786Z
# [2026.08.25 12:22:24.707] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 12:22:24.707] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 12:22:24.721] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 12:22:24.723] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 12:22:24.724] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 12:22:24.725] INFO    Schedule completed. [0.001 s]
# [2026.08.25 12:22:24.745] INFO    Code generation completed for all AWGs. [0.018 s]
# [2026.08.25 12:22:24.745] INFO    Completed compilation step 1 of 1. [0.023 s]
# [2026.08.25 12:22:24.758] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:22:24.760] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 12:22:24.760] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:22:24.760] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.25 12:22:24.760] INFO      SHFQC_DEV12192_sg     0        319          103           2       960
# [2026.08.25 12:22:24.760] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:22:24.760] INFO      TOTAL                          340          103                  8960
# [2026.08.25 12:22:24.760] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:22:24.788] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 12:22:24.792] INFO    Task 'compile_experiment': ended at 2026-08-25 09:22:24.792902Z
# [2026.08.25 12:22:24.900] INFO    Task 'run_experiment': started at 2026-08-25 09:22:24.900351Z
# [2026.08.25 12:22:25.081] INFO    Starting near-time execution...
# [2026.08.25 12:22:25.184] INFO    Estimated RT execution time: 127.46 s.
# [2026.08.25 12:24:32.717] INFO    Finished near-time execution.
# [2026.08.25 12:24:32.772] INFO    Task 'run_experiment': ended at 2026-08-25 09:24:32.772672Z
# [2026.08.25 12:24:32.903] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:24:32.903] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 12:24:32.903] INFO      09:24:32.903617Z
# [2026.08.25 12:24:32.916] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:24:32.998] INFO    Task 'calculate_qubit_population': started at 2026-08-25 09:24:32.998282Z
# [2026.08.25 12:24:33.094] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 09:24:33.094527Z
# [2026.08.25 12:24:33.191] INFO    Task 'fit_data': started at 2026-08-25 09:24:33.191162Z
# [2026.08.25 12:24:33.360] INFO    Task 'fit_data': ended at 2026-08-25 09:24:33.360813Z
# [2026.08.25 12:24:33.432] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 09:24:33.432327Z
# [2026.08.25 12:24:33.544] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 09:24:33.544838Z
# [2026.08.25 12:24:33.626] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 09:24:33.624613Z
# [2026.08.25 12:24:33.721] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 09:24:33.721802Z
# [2026.08.25 12:24:34.203] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 09:24:34.203196Z
# [2026.08.25 12:24:34.235] INFO    Task 'plot_population': started at 2026-08-25 09:24:34.235080Z
# [2026.08.25 12:24:34.398] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 09:24:34.398237Z
# [2026.08.25 12:24:34.719] INFO    Task 'plot_population': ended at 2026-08-25 09:24:34.719238Z
# [2026.08.25 12:24:34.749] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:24:34.749] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 09:24:34.749931Z
# [2026.08.25 12:24:34.749] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:24:34.790] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:24:34.795] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 09:24:34.790177Z
# [2026.08.25 12:24:34.796] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring Rabi with drive length: 130.0 ns
# [2026.08.25 12:24:34.927] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:24:34.927] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 09:24:34.927497Z
# [2026.08.25 12:24:34.927] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 12:24:35.261] INFO    Task 'temporary_qpu': started at 2026-08-25 09:24:35.259186Z
# [2026.08.25 12:24:35.295] INFO    Task 'temporary_qpu': ended at 2026-08-25 09:24:35.295993Z
# [2026.08.25 12:24:35.426] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 12:24:35.426] INFO    09:24:35.426937Z
# [2026.08.25 12:24:35.490] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 09:24:35.490462Z
# [2026.08.25 12:24:35.574] INFO    Task 'create_experiment': started at 2026-08-25 09:24:35.574185Z
# [2026.08.25 12:24:35.730] INFO    Task 'create_experiment': ended at 2026-08-25 09:24:35.730589Z
# [2026.08.25 12:24:35.828] INFO    Task 'compile_experiment': started at 2026-08-25 09:24:35.828871Z
# [2026.08.25 12:24:35.941] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 12:24:35.948] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 12:24:35.949] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 12:24:35.949] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 12:24:35.949] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 12:24:35.959] INFO    Schedule completed. [0.003 s]
# [2026.08.25 12:24:35.978] INFO    Code generation completed for all AWGs. [0.017 s]
# [2026.08.25 12:24:35.980] INFO    Completed compilation step 1 of 1. [0.026 s]
# [2026.08.25 12:24:35.990] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:24:35.990] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 12:24:35.990] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 12:24:35.990] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.25 12:24:35.999] INFO      SHFQC_DEV12192_sg     0        319          103           2      1088
# ...
# [2026.08.25 13:19:25.849] INFO    Task 'compile_experiment': started at 2026-08-25 10:19:25.849712Z
# [2026.08.25 13:19:25.923] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 13:19:25.929] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 13:19:25.929] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 13:19:25.933] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 13:19:25.933] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 13:19:25.937] INFO    Schedule completed. [0.002 s]
# [2026.08.25 13:19:25.944] INFO    Code generation completed for all AWGs. [0.006 s]
# [2026.08.25 13:19:25.945] INFO    Completed compilation step 1 of 1. [0.010 s]
# [2026.08.25 13:19:25.954] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 13:19:25.954] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 13:19:25.956] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 13:19:25.956] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.25 13:19:25.958] INFO      SHFQC_DEV12192_sg     0        319          103           2      3072
# [2026.08.25 13:19:25.958] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 13:19:25.960] INFO      TOTAL                          340          103                 11072
# [2026.08.25 13:19:25.960] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 13:19:25.982] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 13:19:25.982] INFO    Task 'compile_experiment': ended at 2026-08-25 10:19:25.982671Z
# [2026.08.25 13:19:26.075] INFO    Task 'run_experiment': started at 2026-08-25 10:19:26.075206Z
# [2026.08.25 13:19:26.161] INFO    Starting near-time execution...
# [2026.08.25 13:19:26.243] INFO    Estimated RT execution time: 127.57 s.
# [2026.08.25 13:21:33.886] INFO    Finished near-time execution.
# [2026.08.25 13:21:33.975] INFO    Task 'run_experiment': ended at 2026-08-25 10:21:33.973178Z
# [2026.08.25 13:21:34.079] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 13:21:34.079] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 13:21:34.079] INFO      10:21:34.079265Z
# [2026.08.25 13:21:34.079] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 13:21:34.177] INFO    Task 'calculate_qubit_population': started at 2026-08-25 10:21:34.177953Z
# [2026.08.25 13:21:34.272] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 10:21:34.272237Z
# [2026.08.25 13:21:34.366] INFO    Task 'fit_data': started at 2026-08-25 10:21:34.366299Z
# [2026.08.25 13:21:35.139] INFO    Task 'fit_data': ended at 2026-08-25 10:21:35.139385Z
# [2026.08.25 13:21:35.286] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 10:21:35.286633Z
# [2026.08.25 13:21:35.428] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 10:21:35.428706Z
# [2026.08.25 13:21:35.524] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 10:21:35.524911Z
# [2026.08.25 13:21:35.670] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 10:21:35.670153Z
# [2026.08.25 13:21:36.008] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 10:21:36.008065Z
# [2026.08.25 13:21:36.074] INFO    Task 'plot_population': started at 2026-08-25 10:21:36.074081Z
# [2026.08.25 13:21:36.300] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 10:21:36.300926Z
# [2026.08.25 13:21:36.650] INFO    Task 'plot_population': ended at 2026-08-25 10:21:36.650612Z
# [2026.08.25 13:21:36.699] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 13:21:36.699] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 10:21:36.699773Z
# [2026.08.25 13:21:36.699] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 13:21:36.732] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 13:21:36.732] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 10:21:36.732000Z
# [2026.08.25 13:21:36.732] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring Rabi with drive length: 390.0 ns
# [2026.08.25 13:21:36.982] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 13:21:36.982] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 10:21:36.982055Z
# [2026.08.25 13:21:36.982] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 13:21:37.325] INFO    Task 'temporary_qpu': started at 2026-08-25 10:21:37.325524Z
# [2026.08.25 13:21:37.361] INFO    Task 'temporary_qpu': ended at 2026-08-25 10:21:37.361605Z
# [2026.08.25 13:21:37.450] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 13:21:37.453] INFO    10:21:37.450118Z
# [2026.08.25 13:21:37.502] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 10:21:37.500486Z
# [2026.08.25 13:21:37.627] INFO    Task 'create_experiment': started at 2026-08-25 10:21:37.627082Z
# [2026.08.25 13:21:37.763] INFO    Task 'create_experiment': ended at 2026-08-25 10:21:37.763066Z
# [2026.08.25 13:21:37.848] INFO    Task 'compile_experiment': started at 2026-08-25 10:21:37.848877Z
# [2026.08.25 13:21:37.931] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 13:21:37.931] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 13:21:37.931] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 13:21:37.931] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 13:21:37.931] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 13:21:37.939] INFO    Schedule completed. [0.001 s]
# [2026.08.25 13:21:37.947] INFO    Code generation completed for all AWGs. [0.010 s]
# [2026.08.25 13:21:37.947] INFO    Completed compilation step 1 of 1. [0.016 s]
# [2026.08.25 13:21:37.957] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 13:21:37.963] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 13:21:37.963] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 13:21:37.963] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.25 13:21:37.968] INFO      SHFQC_DEV12192_sg     0        319          103           2      3136
# [2026.08.25 13:21:37.968] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 13:21:37.968] INFO      TOTAL                          340          103                 11136
# [2026.08.25 13:21:37.968] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 13:21:37.999] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 13:21:37.999] INFO    Task 'compile_experiment': ended at 2026-08-25 10:21:37.999782Z
# [2026.08.25 13:21:38.142] INFO    Task 'run_experiment': started at 2026-08-25 10:21:38.142544Z
# [2026.08.25 13:21:38.252] INFO    Starting near-time execution...
# [2026.08.25 13:21:38.329] INFO    Estimated RT execution time: 127.57 s.
# [2026.08.25 13:23:45.962] INFO    Finished near-time execution.
# [2026.08.25 13:23:46.045] INFO    Task 'run_experiment': ended at 2026-08-25 10:23:46.043908Z
# [2026.08.25 13:23:46.142] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 13:23:46.142] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 13:23:46.142] INFO      10:23:46.142117Z
# [2026.08.25 13:23:46.142] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 13:23:46.242] INFO    Task 'calculate_qubit_population': started at 2026-08-25 10:23:46.242288Z
# [2026.08.25 13:23:46.342] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 10:23:46.342710Z
# [2026.08.25 13:23:46.413] INFO    Task 'fit_data': started at 2026-08-25 10:23:46.413350Z
# [2026.08.25 13:23:46.576] INFO    Task 'fit_data': ended at 2026-08-25 10:23:46.576302Z
# [2026.08.25 13:23:46.655] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 10:23:46.655248Z
# [2026.08.25 13:23:46.817] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 10:23:46.817796Z
# [2026.08.25 13:23:46.896] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 10:23:46.896862Z
# [2026.08.25 13:23:47.029] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 10:23:47.029354Z
# [2026.08.25 13:23:47.507] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 10:23:47.507420Z
# [2026.08.25 13:23:47.556] INFO    Task 'plot_population': started at 2026-08-25 10:23:47.556221Z
# [2026.08.25 13:23:47.748] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 10:23:47.748413Z
# [2026.08.25 13:23:48.166] INFO    Task 'plot_population': ended at 2026-08-25 10:23:48.166094Z
# [2026.08.25 13:23:48.198] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 13:23:48.198] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 10:23:48.198229Z
# [2026.08.25 13:23:48.198] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 13:23:48.247] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 13:23:48.247] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 10:23:48.247170Z
# [2026.08.25 13:23:48.247] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring Rabi with drive length: 400.0 ns
# [2026.08.25 13:23:48.407] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 13:23:48.407] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 10:23:48.407990Z
# [2026.08.25 13:23:48.407] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 13:23:48.684] INFO    Task 'temporary_qpu': started at 2026-08-25 10:23:48.684123Z
# [2026.08.25 13:23:48.730] INFO    Task 'temporary_qpu': ended at 2026-08-25 10:23:48.719879Z
# [2026.08.25 13:23:48.812] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 13:23:48.812] INFO    10:23:48.812617Z
# [2026.08.25 13:23:48.861] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 10:23:48.861491Z
# [2026.08.25 13:23:48.971] INFO    Task 'create_experiment': started at 2026-08-25 10:23:48.971318Z
# [2026.08.25 13:23:49.132] INFO    Task 'create_experiment': ended at 2026-08-25 10:23:49.132859Z
# [2026.08.25 13:23:49.247] INFO    Task 'compile_experiment': started at 2026-08-25 10:23:49.247674Z
# [2026.08.25 13:23:49.324] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 13:23:49.340] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 13:23:49.340] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 13:23:49.340] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 13:23:49.340] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 13:23:49.348] INFO    Schedule completed. [0.004 s]
# [2026.08.25 13:23:49.361] INFO    Code generation completed for all AWGs. [0.010 s]
# [2026.08.25 13:23:49.361] INFO    Completed compilation step 1 of 1. [0.017 s]
# [2026.08.25 13:23:49.361] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 13:23:49.361] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 13:23:49.361] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 13:23:49.361] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.25 13:23:49.361] INFO      SHFQC_DEV12192_sg     0        319          103           2      3200
# [2026.08.25 13:23:49.373] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 13:23:49.375] INFO      TOTAL                          340          103                 11200
# [2026.08.25 13:23:49.375] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 13:23:49.397] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 13:23:49.397] INFO    Task 'compile_experiment': ended at 2026-08-25 10:23:49.397225Z
# [2026.08.25 13:23:49.518] INFO    Task 'run_experiment': started at 2026-08-25 10:23:49.518225Z
# [2026.08.25 13:23:49.664] INFO    Starting near-time execution...
# [2026.08.25 13:23:49.784] INFO    Estimated RT execution time: 127.58 s.
# [2026.08.25 13:25:57.440] INFO    Finished near-time execution.
# [2026.08.25 13:25:57.520] INFO    Task 'run_experiment': ended at 2026-08-25 10:25:57.520351Z
# [2026.08.25 13:25:57.627] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 13:25:57.629] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 13:25:57.629] INFO      10:25:57.618888Z
# [2026.08.25 13:25:57.632] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 13:25:57.705] INFO    Task 'calculate_qubit_population': started at 2026-08-25 10:25:57.705453Z
# [2026.08.25 13:25:57.814] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 10:25:57.814892Z
# [2026.08.25 13:25:57.912] INFO    Task 'fit_data': started at 2026-08-25 10:25:57.912185Z
# [2026.08.25 13:25:58.002] INFO    Task 'fit_data': ended at 2026-08-25 10:25:58.002391Z
# [2026.08.25 13:25:58.058] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 10:25:58.058866Z
# [2026.08.25 13:25:58.147] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 10:25:58.147338Z
# [2026.08.25 13:25:58.210] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 10:25:58.210666Z
# [2026.08.25 13:25:58.277] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 10:25:58.277065Z
# [2026.08.25 13:25:58.694] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 10:25:58.684776Z
# [2026.08.25 13:25:58.743] INFO    Task 'plot_population': started at 2026-08-25 10:25:58.743386Z
# [2026.08.25 13:25:58.850] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 10:25:58.838030Z
# [2026.08.25 13:25:59.225] INFO    Task 'plot_population': ended at 2026-08-25 10:25:59.225563Z
# [2026.08.25 13:25:59.255] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 13:25:59.258] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 10:25:59.253311Z
# [2026.08.25 13:25:59.258] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 13:25:59.279] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 13:25:59.279] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 10:25:59.279334Z
# [2026.08.25 13:25:59.288] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Fit and Plot Amplitude vs. Drive Length

# %%
from uncertainties import unumpy as unp

x = (1 / drive_lengths).astype('float64')  # proxy for Rabi frequency scaling with drive length
y = unp.nominal_values(fitted_pi_amplitudes).astype('float64')

rabi_freq_calib_popt, rabi_freq_calib_pcov = np.polyfit(x, y, 1, cov=True)
rabi_slope, rabi_intercept = rabi_freq_calib_popt

print('Rabi amplitude-length slope:', rabi_slope)
print('Rabi amplitude-length intercept:', rabi_intercept)

fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(x * 1e-6, y, '.k')
ax.plot(x * 1e-6, np.polyval(rabi_freq_calib_popt, x), '-r')
ax.set_xlabel('1 / drive length (1/us)')
ax.set_ylabel(f'{transition} pi-pulse amplitude (a.u.)')
ax.set_title('Rabi frequency calibration')

figname = f'Rabi_freq_calib_{transition}_'
file_path = get_path_to_file(figname, '.png')
plt.savefig(file_path, dpi=600, format='png', metadata=None,
        bbox_inches=None, pad_inches=0.1,
        facecolor='auto', edgecolor='auto',
        backend=None,
       )
# Out:
# Rabi amplitude-length slope: 3.6770696918395964e-08
# Rabi amplitude-length intercept: 0.0008458989025878482

# %% [markdown]
# #### Save Data

# %%
Data_rabi_freq_calib = {
    'drive_lengths': drive_lengths,
    'fitted_pi_amplitudes':  unp.nominal_values(fitted_pi_amplitudes).astype('float64'),
    'rabi_slope': rabi_slope,
    'rabi_intercept': rabi_intercept,
}

file_name = f'Rabi_freq_calib_{transition}_'
file_path = get_path_to_file(file_name, '.mat')
savemat(file_path, Data_rabi_freq_calib)

# %% [markdown]
# ### Rabi Error Amplification

# %% [markdown]
# #### x180 pulse

# %% [markdown]
# ##### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ge')

n_avg_exponent = 13

x180_max_repetitions = 16
x180_repetitions = list(range(0, x180_max_repetitions + 1))

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# ##### Run Workflow

# %%
options = amplitude_fine.experiment_workflow_x180.options()
options.count(2**n_avg_exponent)
options.close_figures(False)  # Plot figures

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

exp_workflow = amplitude_fine.experiment_workflow_x180(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    repetitions=[x180_repetitions for q in qubits_to_measure],
    options=options,
    temporary_parameters=temporary_parameters
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.25 14:41:58.407] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 14:41:58.407] INFO      Workflow 'experiment_workflow_x180': execution started at 2026-08-25
# [2026.08.25 14:41:58.407] INFO      11:41:58.407340Z
# [2026.08.25 14:41:58.407] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 14:41:58.792] INFO    Task 'temporary_qpu': started at 2026-08-25 11:41:58.792855Z
# [2026.08.25 14:41:58.873] INFO    Task 'temporary_qpu': ended at 2026-08-25 11:41:58.873971Z
# [2026.08.25 14:41:59.003] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 14:41:59.003] INFO    11:41:59.003793Z
# [2026.08.25 14:41:59.073] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 11:41:59.073391Z
# [2026.08.25 14:41:59.206] INFO    Task 'create_experiment': started at 2026-08-25 11:41:59.206719Z
# [2026.08.25 14:41:59.361] INFO    Task 'create_experiment': ended at 2026-08-25 11:41:59.358415Z
# [2026.08.25 14:41:59.474] INFO    Task 'compile_experiment': started at 2026-08-25 11:41:59.474744Z
# [2026.08.25 14:41:59.601] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 14:41:59.607] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 14:41:59.607] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 14:41:59.610] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 14:41:59.610] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 14:41:59.610] INFO    Schedule completed. [0.001 s]
# [2026.08.25 14:41:59.610] INFO    Code generation completed for all AWGs. [0.007 s]
# [2026.08.25 14:41:59.610] INFO    Completed compilation step 1 of 1. [0.012 s]
# [2026.08.25 14:41:59.628] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 14:41:59.628] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 14:41:59.637] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 14:41:59.637] INFO      SHFQC_DEV12192        0         79            0           1      8000
# [2026.08.25 14:41:59.637] INFO      SHFQC_DEV12192_sg     0        109            5           3      2016
# [2026.08.25 14:41:59.639] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 14:41:59.639] INFO      TOTAL                          188            5                 10016
# [2026.08.25 14:41:59.639] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 14:41:59.655] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 14:41:59.655] INFO    Task 'compile_experiment': ended at 2026-08-25 11:41:59.655138Z
# [2026.08.25 14:41:59.819] INFO    Task 'run_experiment': started at 2026-08-25 11:41:59.819276Z
# [2026.08.25 14:41:59.996] INFO    Starting near-time execution...
# [2026.08.25 14:42:00.075] INFO    Estimated RT execution time: 47.13 s.
# [2026.08.25 14:42:47.266] INFO    Finished near-time execution.
# [2026.08.25 14:42:47.335] INFO    Task 'run_experiment': ended at 2026-08-25 11:42:47.335029Z
# [2026.08.25 14:42:47.444] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 14:42:47.444] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 14:42:47.444] INFO      11:42:47.444882Z
# [2026.08.25 14:42:47.444] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 14:42:47.540] INFO    Task 'calculate_qubit_population': started at 2026-08-25 11:42:47.540783Z
# [2026.08.25 14:42:47.639] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 11:42:47.639939Z
# [2026.08.25 14:42:47.750] INFO    Task 'fit_data': started at 2026-08-25 11:42:47.750164Z
# [2026.08.25 14:42:47.925] INFO    Task 'fit_data': ended at 2026-08-25 11:42:47.925496Z
# [2026.08.25 14:42:48.022] INFO    Task 'process_fit_results': started at 2026-08-25 11:42:48.022419Z
# [2026.08.25 14:42:48.198] INFO    Task 'process_fit_results': ended at 2026-08-25 11:42:48.198568Z
# [2026.08.25 14:42:48.326] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 11:42:48.326680Z
# [2026.08.25 14:42:48.520] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 11:42:48.518941Z
# [2026.08.25 14:42:48.646] INFO    Task 'xaxis_label': started at 2026-08-25 11:42:48.646318Z
# [2026.08.25 14:42:48.709] INFO    Task 'xaxis_label': ended at 2026-08-25 11:42:48.709658Z
# [2026.08.25 14:42:48.754] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 11:42:48.754158Z
# [2026.08.25 14:42:48.904] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 11:42:48.904694Z
# [2026.08.25 14:42:49.490] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 11:42:49.490967Z
# [2026.08.25 14:42:49.532] INFO    Task 'plot_population': started at 2026-08-25 11:42:49.532338Z
# [2026.08.25 14:42:49.721] INFO    Artifact: 'Amplitude_Fine_Q2' of type 'Figure' logged at 2026-08-25
# [2026.08.25 14:42:49.721] INFO    11:42:49.716931Z
# [2026.08.25 14:42:50.034] INFO    Task 'plot_population': ended at 2026-08-25 11:42:50.034226Z
# [2026.08.25 14:42:50.084] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 14:42:50.084] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 11:42:50.084098Z
# [2026.08.25 14:42:50.084] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 14:42:50.156] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 14:42:50.156] INFO      Workflow 'experiment_workflow_x180': execution ended at 2026-08-25
# [2026.08.25 14:42:50.156] INFO      11:42:50.156196Z
# [2026.08.25 14:42:50.161] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ##### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)
    
    amplitude_fine.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nDrive amplitude pi ge (error-amplified): ", qubit_to_measure.parameters.ge_drive_amplitude_pi)
    elif transition == 'ef':
        print("\nDrive amplitude pi ef (error-amplified): ", qubit_to_measure.parameters.ef_drive_amplitude_pi)
        
    print('\nUpdated global experiment parameters!\n')
# Out:
# {'new_parameter_values': {'Q2': {'ge_drive_amplitude_pi': 0.3675929365111754+/-0.00015603200117427992}},
#  'old_parameter_values': {'Q2': {'ge_drive_amplitude_pi': 0.3695426862928893}}}
#
# Drive amplitude pi ge (error-amplified):  0.3675929365111754
#
# Updated global experiment parameters!

# %% [markdown]
# #### x90 pulse

# %% [markdown]
# ##### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ge')

n_avg_exponent = 13

x90_max_repetitions = 40
x90_repetitions = list(range(1, x90_max_repetitions + 1, 2))

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# ##### Run Workflow

# %%
options = amplitude_fine.experiment_workflow_x90.options()
options.count(2**n_avg_exponent)
options.close_figures(False)  # Plot figures

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

exp_workflow = amplitude_fine.experiment_workflow_x90(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    repetitions=[x90_repetitions for q in qubits_to_measure],
    options=options,
    temporary_parameters=temporary_parameters
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.25 14:43:17.531] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 14:43:17.531] INFO      Workflow 'experiment_workflow_x90': execution started at 2026-08-25
# [2026.08.25 14:43:17.531] INFO      11:43:17.531690Z
# [2026.08.25 14:43:17.531] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 14:43:18.032] INFO    Task 'temporary_qpu': started at 2026-08-25 11:43:18.030694Z
# [2026.08.25 14:43:18.141] INFO    Task 'temporary_qpu': ended at 2026-08-25 11:43:18.141472Z
# [2026.08.25 14:43:18.350] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 14:43:18.350] INFO    11:43:18.350471Z
# [2026.08.25 14:43:18.447] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 11:43:18.447430Z
# [2026.08.25 14:43:18.641] INFO    Task 'create_experiment': started at 2026-08-25 11:43:18.641577Z
# [2026.08.25 14:43:18.916] INFO    Task 'create_experiment': ended at 2026-08-25 11:43:18.916731Z
# [2026.08.25 14:43:19.275] INFO    Task 'compile_experiment': started at 2026-08-25 11:43:19.275772Z
# [2026.08.25 14:43:19.594] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 14:43:19.609] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 14:43:19.611] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 14:43:19.613] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 14:43:19.613] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 14:43:19.623] INFO    Schedule completed. [0.004 s]
# [2026.08.25 14:43:19.638] INFO    Code generation completed for all AWGs. [0.013 s]
# [2026.08.25 14:43:19.641] INFO    Completed compilation step 1 of 1. [0.021 s]
# [2026.08.25 14:43:19.649] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 14:43:19.649] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 14:43:19.649] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 14:43:19.652] INFO      SHFQC_DEV12192        0         91            0           1      8000
# [2026.08.25 14:43:19.652] INFO      SHFQC_DEV12192_sg     0        113            3           2      1216
# [2026.08.25 14:43:19.654] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 14:43:19.655] INFO      TOTAL                          204            3                  9216
# [2026.08.25 14:43:19.656] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 14:43:19.677] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 14:43:19.677] INFO    Task 'compile_experiment': ended at 2026-08-25 11:43:19.677163Z
# [2026.08.25 14:43:20.223] INFO    Task 'run_experiment': started at 2026-08-25 11:43:20.223046Z
# [2026.08.25 14:43:20.457] INFO    Starting near-time execution...
# [2026.08.25 14:43:20.526] INFO    Estimated RT execution time: 54.77 s.
# [2026.08.25 14:44:15.373] INFO    Finished near-time execution.
# [2026.08.25 14:44:15.469] INFO    Task 'run_experiment': ended at 2026-08-25 11:44:15.469324Z
# [2026.08.25 14:44:15.623] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 14:44:15.623] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 14:44:15.623] INFO      11:44:15.616967Z
# [2026.08.25 14:44:15.623] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 14:44:15.747] INFO    Task 'calculate_qubit_population': started at 2026-08-25 11:44:15.747025Z
# [2026.08.25 14:44:15.855] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 11:44:15.847295Z
# [2026.08.25 14:44:15.954] INFO    Task 'fit_data': started at 2026-08-25 11:44:15.954313Z
# [2026.08.25 14:44:16.173] INFO    Task 'fit_data': ended at 2026-08-25 11:44:16.173058Z
# [2026.08.25 14:44:16.318] INFO    Task 'process_fit_results': started at 2026-08-25 11:44:16.317023Z
# [2026.08.25 14:44:16.482] INFO    Task 'process_fit_results': ended at 2026-08-25 11:44:16.482294Z
# [2026.08.25 14:44:16.594] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 11:44:16.594562Z
# [2026.08.25 14:44:16.756] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 11:44:16.756300Z
# [2026.08.25 14:44:16.869] INFO    Task 'xaxis_label': started at 2026-08-25 11:44:16.869170Z
# [2026.08.25 14:44:16.932] INFO    Task 'xaxis_label': ended at 2026-08-25 11:44:16.932727Z
# [2026.08.25 14:44:16.981] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 11:44:16.981567Z
# [2026.08.25 14:44:17.159] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 11:44:17.159158Z
# [2026.08.25 14:44:17.543] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 11:44:17.542170Z
# [2026.08.25 14:44:17.605] INFO    Task 'plot_population': started at 2026-08-25 11:44:17.605747Z
# [2026.08.25 14:44:17.814] INFO    Artifact: 'Amplitude_Fine_Q2' of type 'Figure' logged at 2026-08-25
# [2026.08.25 14:44:17.815] INFO    11:44:17.814211Z
# [2026.08.25 14:44:18.161] INFO    Task 'plot_population': ended at 2026-08-25 11:44:18.161403Z
# [2026.08.25 14:44:18.216] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 14:44:18.225] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 11:44:18.216631Z
# [2026.08.25 14:44:18.225] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 14:44:18.275] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 14:44:18.275] INFO      Workflow 'experiment_workflow_x90': execution ended at 2026-08-25
# [2026.08.25 14:44:18.275] INFO      11:44:18.275836Z
# [2026.08.25 14:44:18.280] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ##### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)

    amplitude_fine.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nDrive amplitude pi2 ge (error-amplified): ", qubit_to_measure.parameters.ge_drive_amplitude_pi2)
    elif transition == 'ef':
        print("\nDrive amplitude pi2 ef (error-amplified): ", qubit_to_measure.parameters.ef_drive_amplitude_pi2)
    
    print('\nUpdated global experiment parameters!\n')
# Out:
# {'new_parameter_values': {'Q2': {'ge_drive_amplitude_pi2': 0.18067761126293605+/-0.0001066448427428813}},
#  'old_parameter_values': {'Q2': {'ge_drive_amplitude_pi2': 0.1844107701092291}}}
#
# Drive amplitude pi2 ge (error-amplified):  0.18067761126293605
#
# Updated global experiment parameters!

# %% [markdown]
# ### Ramsey

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

detuning = 0.8e6
transition = set_transition('ge')

n_avg_exponent = 13

delay_min = 0
delay_max = 70e-6
n_delay = 101

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = ramsey.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(False) # Plot figures

options.transition(transition)
options.cal_states(transition)

# Note: if neighbouring qubits are physically coupled by a resonator,
# you usually don't want to run Ramsey in parallel on them because
# your result will be skewed by strong residual-ZZ coupling.
# Next-nearest neighbours is typically okay.
# qubits_to_measure = [qubits[0], qubits[2]]
qubits_to_measure = [qubits[0]]

delays = [
    np.linspace(delay_min, delay_max, n_delay)
]
detunings = [
    detuning
]

exp_workflow = ramsey.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    delays=delays,
    detunings=detunings,
    options=options,
    temporary_parameters=temporary_parameters
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.25 15:34:28.959] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:34:28.959] INFO      Workflow 'ramsey': execution started at 2026-08-25 12:34:28.959075Z
# [2026.08.25 15:34:28.959] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:34:29.378] INFO    Task 'temporary_qpu': started at 2026-08-25 12:34:29.378268Z
# [2026.08.25 15:34:29.441] INFO    Task 'temporary_qpu': ended at 2026-08-25 12:34:29.441774Z
# [2026.08.25 15:34:29.642] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 15:34:29.642] INFO    12:34:29.642121Z
# [2026.08.25 15:34:29.940] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 12:34:29.940617Z
# [2026.08.25 15:34:30.058] INFO    Task 'create_experiment': started at 2026-08-25 12:34:30.058804Z
# [2026.08.25 15:34:30.201] INFO    Task 'create_experiment': ended at 2026-08-25 12:34:30.201459Z
# [2026.08.25 15:34:30.295] INFO    Task 'compile_experiment': started at 2026-08-25 12:34:30.295050Z
# [2026.08.25 15:34:30.440] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 15:34:30.440] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 15:34:30.452] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 15:34:30.452] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 15:34:30.455] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 15:34:30.462] INFO    Schedule completed. [0.006 s]
# [2026.08.25 15:34:30.486] INFO    Code generation completed for all AWGs. [0.019 s]
# [2026.08.25 15:34:30.488] INFO    Completed compilation step 1 of 1. [0.030 s]
# [2026.08.25 15:34:30.493] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:34:30.493] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 15:34:30.496] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:34:30.496] INFO      SHFQC_DEV12192        0        415            0           1      8000
# [2026.08.25 15:34:30.496] INFO      SHFQC_DEV12192_sg     0        522           30           3      1632
# [2026.08.25 15:34:30.496] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:34:30.496] INFO      TOTAL                          937           30                  9632
# [2026.08.25 15:34:30.501] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:34:30.539] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 15:34:30.540] INFO    Task 'compile_experiment': ended at 2026-08-25 12:34:30.540476Z
# [2026.08.25 15:34:30.670] INFO    Task 'run_experiment': started at 2026-08-25 12:34:30.670959Z
# [2026.08.25 15:34:30.801] INFO    Starting near-time execution...
# [2026.08.25 15:34:30.882] INFO    Estimated RT execution time: 283.95 s.
# [2026.08.25 15:39:14.894] INFO    Finished near-time execution.
# [2026.08.25 15:39:15.005] INFO    Task 'run_experiment': ended at 2026-08-25 12:39:15.005124Z
# [2026.08.25 15:39:15.119] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:39:15.119] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 15:39:15.119] INFO      12:39:15.119708Z
# [2026.08.25 15:39:15.132] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:39:15.247] INFO    Task 'calculate_qubit_population': started at 2026-08-25 12:39:15.247781Z
# [2026.08.25 15:39:15.340] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 12:39:15.340703Z
# [2026.08.25 15:39:15.458] INFO    Task 'fit_data': started at 2026-08-25 12:39:15.458356Z
# [2026.08.25 15:39:15.634] INFO    Task 'fit_data': ended at 2026-08-25 12:39:15.631478Z
# [2026.08.25 15:39:15.726] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 12:39:15.726586Z
# [2026.08.25 15:39:15.888] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 12:39:15.888699Z
# [2026.08.25 15:39:15.988] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 12:39:15.988952Z
# [2026.08.25 15:39:16.128] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 12:39:16.128426Z
# [2026.08.25 15:39:16.648] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 12:39:16.648429Z
# [2026.08.25 15:39:16.682] INFO    Task 'plot_population': started at 2026-08-25 12:39:16.682208Z
# [2026.08.25 15:39:16.834] INFO    Artifact: 'Ramsey_Q2' of type 'Figure' logged at 2026-08-25 12:39:16.819204Z
# [2026.08.25 15:39:17.301] INFO    Task 'plot_population': ended at 2026-08-25 12:39:17.301485Z
# [2026.08.25 15:39:17.345] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:39:17.345] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 12:39:17.345143Z
# [2026.08.25 15:39:17.345] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:39:17.381] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:39:17.381] INFO      Workflow 'ramsey': execution ended at 2026-08-25 12:39:17.381951Z
# [2026.08.25 15:39:17.381] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)

    ramsey.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nge_T2_star: ", qubit_to_measure.parameters.ge_T2_star)
        print("resonance_frequency_ge: ", qubit_to_measure.parameters.resonance_frequency_ge)
    elif transition == 'ef':
        print("\nef_T2_star: ", qubit_to_measure.parameters.ef_T2_star)
        print("resonance_frequency_ef: ", qubit_to_measure.parameters.resonance_frequency_ef)
    
    print('\nUpdated global experiment parameters!\n')
# Out:
# {'new_parameter_values': {'Q2': {'ge_T2_star': 7.439383035157121e-06+/-2.488130389410491e-07,
#                                  'resonance_frequency_ge': 5008729069.822789+/-1038.7006884343832}},
#  'old_parameter_values': {'Q2': {'ge_T2_star': 0,
#                                  'resonance_frequency_ge': 5008115602.771751}}}
#
# ge_T2_star:  7.439383035157121e-06
# resonance_frequency_ge:  5008729069.822789
#
# Updated global experiment parameters!

# %% [markdown]
# ### T1 Lifetime

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ge')

n_avg_exponent = 13

delay_min = 0
delay_max = 80e-6
n_delay = 51
log_spacing = True

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = lifetime_measurement.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(False) # Plot figures

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

if log_spacing:
    delays = [log_sweep_help(delay_min, delay_max, n_delay)]
else:
    delays = [np.linspace(delay_min, delay_max, n_delay)]

exp_workflow = lifetime_measurement.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    delays=delays,
    options=options,
    temporary_parameters=temporary_parameters 
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.25 14:45:26.044] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 14:45:26.045] INFO      Workflow 'lifetime_measurement': execution started at 2026-08-25
# [2026.08.25 14:45:26.045] INFO      11:45:26.037654Z
# [2026.08.25 14:45:26.045] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 14:45:26.429] INFO    Task 'temporary_qpu': started at 2026-08-25 11:45:26.429522Z
# [2026.08.25 14:45:26.489] INFO    Task 'temporary_qpu': ended at 2026-08-25 11:45:26.489624Z
# [2026.08.25 14:45:26.599] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 14:45:26.600] INFO    11:45:26.589945Z
# [2026.08.25 14:45:26.650] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 11:45:26.641279Z
# [2026.08.25 14:45:26.750] INFO    Task 'create_experiment': started at 2026-08-25 11:45:26.750105Z
# [2026.08.25 14:45:26.927] INFO    Task 'create_experiment': ended at 2026-08-25 11:45:26.927112Z
# [2026.08.25 14:45:27.026] INFO    Task 'compile_experiment': started at 2026-08-25 11:45:27.026670Z
# [2026.08.25 14:45:27.103] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 14:45:27.103] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 14:45:27.103] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 14:45:27.103] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 14:45:27.103] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 14:45:27.103] INFO    Schedule completed. [0.002 s]
# [2026.08.25 14:45:27.125] INFO    Code generation completed for all AWGs. [0.010 s]
# [2026.08.25 14:45:27.134] INFO    Completed compilation step 1 of 1. [0.017 s]
# [2026.08.25 14:45:27.142] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 14:45:27.142] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 14:45:27.142] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 14:45:27.148] INFO      SHFQC_DEV12192        0        215            0           1      8000
# [2026.08.25 14:45:27.152] INFO      SHFQC_DEV12192_sg     0        209           16          15      6432
# [2026.08.25 14:45:27.154] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 14:45:27.154] INFO      TOTAL                          424           16                 14432
# [2026.08.25 14:45:27.156] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 14:45:27.179] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 14:45:27.179] INFO    Task 'compile_experiment': ended at 2026-08-25 11:45:27.179445Z
# [2026.08.25 14:45:27.291] INFO    Task 'run_experiment': started at 2026-08-25 11:45:27.291317Z
# [2026.08.25 14:45:27.450] INFO    Starting near-time execution...
# [2026.08.25 14:45:27.528] INFO    Estimated RT execution time: 136.64 s.
# [2026.08.25 14:47:44.246] INFO    Finished near-time execution.
# [2026.08.25 14:47:44.326] INFO    Task 'run_experiment': ended at 2026-08-25 11:47:44.326228Z
# [2026.08.25 14:47:44.681] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 14:47:44.685] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 14:47:44.685] INFO      11:47:44.680109Z
# [2026.08.25 14:47:44.688] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 14:47:44.984] INFO    Task 'calculate_qubit_population': started at 2026-08-25 11:47:44.972838Z
# [2026.08.25 14:47:45.277] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 11:47:45.277308Z
# [2026.08.25 14:47:45.533] INFO    Task 'fit_data': started at 2026-08-25 11:47:45.533568Z
# [2026.08.25 14:47:45.877] INFO    Task 'fit_data': ended at 2026-08-25 11:47:45.877113Z
# [2026.08.25 14:47:46.129] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 11:47:46.129724Z
# [2026.08.25 14:47:46.499] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 11:47:46.499979Z
# [2026.08.25 14:47:46.728] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 11:47:46.728573Z
# [2026.08.25 14:47:47.093] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 11:47:47.091333Z
# [2026.08.25 14:47:47.730] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 11:47:47.730649Z
# [2026.08.25 14:47:47.853] INFO    Task 'plot_population': started at 2026-08-25 11:47:47.853052Z
# [2026.08.25 14:47:48.233] INFO    Artifact: 'T1_Q2' of type 'Figure' logged at 2026-08-25 11:47:48.233219Z
# [2026.08.25 14:47:48.915] INFO    Task 'plot_population': ended at 2026-08-25 11:47:48.915166Z
# [2026.08.25 14:47:49.034] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 14:47:49.034] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 11:47:49.034461Z
# [2026.08.25 14:47:49.034] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 14:47:49.205] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 14:47:49.205] INFO      Workflow 'lifetime_measurement': execution ended at 2026-08-25
# [2026.08.25 14:47:49.205] INFO      11:47:49.205773Z
# [2026.08.25 14:47:49.215] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)

    lifetime_measurement.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nge_T1: ", qubit_to_measure.parameters.ge_T1)
    elif transition == 'ef':
        print("\nef_T1: ", qubit_to_measure.parameters.ef_T1)
    
    print('\nUpdated global experiment parameters!\n')
# Out:
# {'new_parameter_values': {'Q2': {'ge_T1': 1.2884569729022237e-05+/-1.0503812894630302e-07}},
#  'old_parameter_values': {'Q2': {'ge_T1': 0}}}
#
# ge_T1:  1.2884569729022237e-05
#
# Updated global experiment parameters!

# %%
qubits[0].parameters.reset_delay_length = 300e-6
qubits[0].parameters.readout_range_out = -30

# %% [markdown]
# ### DRAG Calibration

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ge')

n_avg_exponent = 13

q_min = -0.1
q_max = 0.1
n_q = 51

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = drag_q_scaling.experiment_workflow.options()
# options.update(True)  # updates the qubit parameter 'ge_drive_pulse["beta"]'
options.count(2**n_avg_exponent)
options.close_figures(False) # Plot figures

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

exp_workflow = drag_q_scaling.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    q_scalings=[np.linspace(q_min, q_max, n_q) for _ in qubits_to_measure],
    options=options,
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.25 15:39:18.647] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:39:18.650] INFO      Workflow 'drag_q_scaling': execution started at 2026-08-25 12:39:18.647826Z
# [2026.08.25 15:39:18.650] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:39:18.889] INFO    Task 'temporary_qpu': started at 2026-08-25 12:39:18.889062Z
# [2026.08.25 15:39:18.938] INFO    Task 'temporary_qpu': ended at 2026-08-25 12:39:18.938608Z
# [2026.08.25 15:39:19.052] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 15:39:19.052] INFO    12:39:19.049714Z
# [2026.08.25 15:39:19.107] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 12:39:19.107075Z
# [2026.08.25 15:39:19.207] INFO    Task 'create_experiment': started at 2026-08-25 12:39:19.207195Z
# [2026.08.25 15:39:19.353] INFO    Task 'create_experiment': ended at 2026-08-25 12:39:19.353520Z
# [2026.08.25 15:39:19.454] INFO    Task 'compile_experiment': started at 2026-08-25 12:39:19.454045Z
# [2026.08.25 15:39:19.544] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 15:39:19.544] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 15:39:19.544] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 15:39:19.544] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 15:39:19.544] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 15:39:19.554] INFO    Schedule completed. [0.002 s]
# [2026.08.25 15:39:19.597] INFO    Code generation completed for all AWGs. [0.046 s]
# [2026.08.25 15:39:19.597] INFO    Completed compilation step 1 of 1. [0.051 s]
# [2026.08.25 15:39:19.608] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:39:19.608] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 15:39:19.608] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:39:19.608] INFO      SHFQC_DEV12192        0         31            0           1      8000
# [2026.08.25 15:39:19.608] INFO      SHFQC_DEV12192_sg     0        931          155         154    122816
# [2026.08.25 15:39:19.608] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:39:19.608] INFO      TOTAL                          962          155                130816
# [2026.08.25 15:39:19.608] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:39:19.674] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 15:39:19.674] INFO    Task 'compile_experiment': ended at 2026-08-25 12:39:19.674479Z
# [2026.08.25 15:39:19.902] INFO    Task 'run_experiment': started at 2026-08-25 12:39:19.902956Z
# [2026.08.25 15:39:20.033] INFO    Starting near-time execution...
# [2026.08.25 15:39:20.226] INFO    Estimated RT execution time: 383.72 s.
# [2026.08.25 15:45:44.006] INFO    Finished near-time execution.
# [2026.08.25 15:45:44.137] INFO    Task 'run_experiment': ended at 2026-08-25 12:45:44.135407Z
# [2026.08.25 15:45:44.240] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:45:44.243] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 15:45:44.243] INFO      12:45:44.240166Z
# [2026.08.25 15:45:44.243] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:45:44.344] INFO    Task 'calculate_qubit_population_for_pulse_ids': started at 2026-08-25
# [2026.08.25 15:45:44.344] INFO    12:45:44.344041Z
# [2026.08.25 15:45:44.450] INFO    Task 'calculate_qubit_population_for_pulse_ids': ended at 2026-08-25
# [2026.08.25 15:45:44.450] INFO    12:45:44.450052Z
# [2026.08.25 15:45:44.591] INFO    Task 'fit_data': started at 2026-08-25 12:45:44.591796Z
# [2026.08.25 15:45:44.844] INFO    Task 'fit_data': ended at 2026-08-25 12:45:44.844177Z
# [2026.08.25 15:45:44.991] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 12:45:44.991543Z
# [2026.08.25 15:45:45.200] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 12:45:45.200395Z
# [2026.08.25 15:45:45.312] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 12:45:45.312519Z
# [2026.08.25 15:45:45.446] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 12:45:45.446533Z
# [2026.08.25 15:45:45.812] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 12:45:45.812255Z
# [2026.08.25 15:45:45.853] INFO    Task 'plot_population': started at 2026-08-25 12:45:45.853834Z
# [2026.08.25 15:45:45.978] INFO    Artifact: 'Drag_q_scaling_Q2' of type 'Figure' logged at 2026-08-25
# [2026.08.25 15:45:45.978] INFO    12:45:45.978312Z
# [2026.08.25 15:45:46.376] INFO    Task 'plot_population': ended at 2026-08-25 12:45:46.376826Z
# [2026.08.25 15:45:46.407] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:45:46.407] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 12:45:46.407991Z
# [2026.08.25 15:45:46.407] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:45:46.464] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:45:46.464] INFO      Workflow 'drag_q_scaling': execution ended at 2026-08-25 12:45:46.457605Z
# [2026.08.25 15:45:46.464] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])

    drag_q_scaling.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nge_drive_pulse[beta]: ", qubit_to_measure.parameters.ge_drive_pulse["beta"])
    elif transition == 'ef':
        print("\nef_drive_pulse[beta]: ", qubit_to_measure.parameters.ef_drive_pulse["beta"])
    
    print('\nUpdated global experiment parameters!\n')
# Out:
# {'new_parameter_values': {'Q2': {'ge_drive_pulse.beta': 0.01728693103288088+/-0.0003784190809230285}},
#  'old_parameter_values': {'Q2': {'ge_drive_pulse.beta': 0}}}
#
# ge_drive_pulse[beta]:  0.01728693103288088
#
# Updated global experiment parameters!

# %% [markdown]
# ### Hahn-Echo

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ge')

n_avg_exponent = 13

delay_min = 0
delay_max = 100e-6
n_delay = 71
log_spacing = True

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = echo.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(False)

options.transition(transition)
options.cal_states(transition)

# Note: if neighbouring qubits are physically coupled by a resonator,
# you usually don't want to run Echo in parallel on them because
# your result will be skewed by strong residual-ZZ coupling.
# Next-nearest neighbours is typically okay.
qubits_to_measure = [qubits[0]]

delays = [
    np.linspace(delay_min, delay_max, n_delay)
]

exp_workflow = echo.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    delays=delays,
    options=options,
    temporary_parameters=temporary_parameters
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.25 15:45:47.420] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:45:47.420] INFO      Workflow 'echo': execution started at 2026-08-25 12:45:47.420000Z
# [2026.08.25 15:45:47.420] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:45:47.749] INFO    Task 'temporary_qpu': started at 2026-08-25 12:45:47.749728Z
# [2026.08.25 15:45:47.805] INFO    Task 'temporary_qpu': ended at 2026-08-25 12:45:47.805348Z
# [2026.08.25 15:45:47.918] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 15:45:47.918] INFO    12:45:47.918808Z
# [2026.08.25 15:45:47.981] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 12:45:47.981997Z
# [2026.08.25 15:45:48.119] INFO    Task 'create_experiment': started at 2026-08-25 12:45:48.119328Z
# [2026.08.25 15:45:48.259] INFO    Task 'create_experiment': ended at 2026-08-25 12:45:48.259364Z
# [2026.08.25 15:45:48.366] INFO    Task 'compile_experiment': started at 2026-08-25 12:45:48.366599Z
# [2026.08.25 15:45:48.479] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 15:45:48.479] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 15:45:48.479] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 15:45:48.495] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 15:45:48.497] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 15:45:48.497] INFO    Schedule completed. [0.002 s]
# [2026.08.25 15:45:48.513] INFO    Code generation completed for all AWGs. [0.011 s]
# [2026.08.25 15:45:48.513] INFO    Completed compilation step 1 of 1. [0.016 s]
# [2026.08.25 15:45:48.519] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:45:48.526] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 15:45:48.528] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:45:48.528] INFO      SHFQC_DEV12192        0        295            0           1      8000
# [2026.08.25 15:45:48.528] INFO      SHFQC_DEV12192_sg     0        549           17          15      6816
# [2026.08.25 15:45:48.530] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:45:48.531] INFO      TOTAL                          844           17                 14816
# [2026.08.25 15:45:48.531] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:45:48.565] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 15:45:48.566] INFO    Task 'compile_experiment': ended at 2026-08-25 12:45:48.566465Z
# [2026.08.25 15:45:48.702] INFO    Task 'run_experiment': started at 2026-08-25 12:45:48.702837Z
# [2026.08.25 15:45:48.887] INFO    Starting near-time execution...
# [2026.08.25 15:45:48.960] INFO    Estimated RT execution time: 209.86 s.
# [2026.08.25 15:49:18.901] INFO    Finished near-time execution.
# [2026.08.25 15:49:18.994] INFO    Task 'run_experiment': ended at 2026-08-25 12:49:18.994575Z
# [2026.08.25 15:49:19.124] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:49:19.124] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 15:49:19.124] INFO      12:49:19.124988Z
# [2026.08.25 15:49:19.124] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:49:19.238] INFO    Task 'calculate_qubit_population': started at 2026-08-25 12:49:19.238411Z
# [2026.08.25 15:49:19.364] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 12:49:19.364947Z
# [2026.08.25 15:49:19.463] INFO    Task 'fit_data': started at 2026-08-25 12:49:19.463384Z
# [2026.08.25 15:49:19.649] INFO    Task 'fit_data': ended at 2026-08-25 12:49:19.644915Z
# [2026.08.25 15:49:19.749] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 12:49:19.749583Z
# [2026.08.25 15:49:19.893] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 12:49:19.893636Z
# [2026.08.25 15:49:20.024] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 12:49:20.024948Z
# [2026.08.25 15:49:20.218] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 12:49:20.218601Z
# [2026.08.25 15:49:20.958] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 12:49:20.958601Z
# [2026.08.25 15:49:21.037] INFO    Task 'plot_population': started at 2026-08-25 12:49:21.036429Z
# [2026.08.25 15:49:21.212] INFO    Artifact: 'T2_Q2' of type 'Figure' logged at 2026-08-25 12:49:21.212859Z
# [2026.08.25 15:49:21.501] INFO    Task 'plot_population': ended at 2026-08-25 12:49:21.501618Z
# [2026.08.25 15:49:21.550] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:49:21.550] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 12:49:21.550271Z
# [2026.08.25 15:49:21.550] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:49:21.618] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:49:21.618] INFO      Workflow 'echo': execution ended at 2026-08-25 12:49:21.618104Z
# [2026.08.25 15:49:21.618] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)

    echo.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nge_T2: ", qubit_to_measure.parameters.ge_T2)
    elif transition == 'ef':
        print("\nef_T2: ", qubit_to_measure.parameters.ef_T2)
    
    print('\nUpdated global experiment parameters!\n')
# Out:
# {'new_parameter_values': {'Q2': {'ge_T2': 1.257596576271114e-05+/-4.80195775570409e-07}},
#  'old_parameter_values': {'Q2': {'ge_T2': 0}}}
#
# ge_T2:  1.257596576271114e-05
#
# Updated global experiment parameters!

# %%
qpu.quantum_elements
# Out:
# [TunableTransmonQubit(
# │   uid='Q2',
# │   signals={
# │   │   'drive': 'q0/drive',
# │   │   'drive_ef': 'q0/drive_ef',
# │   │   'measure': 'q0/measure',
# │   │   'acquire': 'q0/acquire'
# │   },
# │   parameters=TunableTransmonQubitParameters(
# │   │   custom={},
# │   │   ge_T1=1.2884569729022237e-05,
# │   │   ge_T2=1.257596576271114e-05,
# │   │   ge_T2_star=7.439383035157121e-06,
# │   │   ef_T1=0,
# │   │   ef_T2=0,
# │   │   ef_T2_star=0,
# │   │   drive_lo_frequency=4800000000.0,
# │   │   readout_lo_frequency=6000000000.0,
# │   │   resonance_frequency_ge=5008729069.822789,
# │   │   resonance_frequency_ef=4800000000.0,
# │   │   readout_resonator_frequency=5960170000.0,
# │   │   ge_drive_amplitude_pi=0.3675929365111754,
# │   │   ge_drive_amplitude_pi2=0.18067761126293605,
# │   │   ge_drive_length=1e-07,
# │   │   ge_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0.01728693103288088,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   ef_drive_amplitude_pi=0.2,
# │   │   ef_drive_amplitude_pi2=0.1,
# │   │   ef_drive_length=5e-08,
# │   │   ef_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   qubit_resonator_coupling_strength_g=0,
# │   │   ge_chi_shift=0,
# │   │   readout_amplitude=0.2,
# │   │   readout_length=2e-06,
# │   │   readout_pulse={
# │   │   │   'function': 'const'
# │   │   },
# │   │   readout_integration_length=2e-06,
# │   │   readout_integration_delay=8e-08,
# │   │   readout_integration_kernels_type='default',
# │   │   readout_integration_kernels=None,
# │   │   readout_integration_discrimination_thresholds=None,
# │   │   reset_delay_length=0.0003,
# │   │   drive_range=10,
# │   │   readout_range_out=-30,
# │   │   readout_range_in=-45,
# │   │   flux_range=5,
# │   │   spectroscopy_length=1e-05,
# │   │   spectroscopy_amplitude=0.2,
# │   │   spectroscopy_pulse={
# │   │   │   'function': 'const',
# │   │   │   'can_compress': True
# │   │   },
# │   │   dc_slot=0,
# │   │   dc_voltage_parking=0.0,
# │   │   flux_offset_voltage=0.0,
# │   │   user_defined={}
# │   )
# )
# ]

# %% [markdown]
# ## Second Transition: e-f

# %% [markdown]
# ### Amplitude Rabi

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ef')

drive_range = 10
drive_length = 100e-9
readout_amplitude = 0.3
n_avg_exponent = 13

amp_min = 0
amp_max = 1
n_amp = 31

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temp_pars.drive_range = drive_range
temp_pars.readout_amplitude = readout_amplitude
if transition == 'ge':
    temp_pars.ge_drive_length = drive_length
elif transition == 'ef':
    temp_pars.ef_drive_length = drive_length
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = amplitude_rabi.experiment_workflow.options()

options.count(2**n_avg_exponent)
options.close_figures(False) # Plot figures

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

exp_workflow = amplitude_rabi.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    amplitudes=[np.linspace(amp_min, amp_max, n_amp) for q in qubits_to_measure],
    options=options,
    temporary_parameters=temporary_parameters
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.25 15:52:17.919] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:52:17.919] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 12:52:17.912606Z
# [2026.08.25 15:52:17.919] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:52:18.212] INFO    Task 'temporary_qpu': started at 2026-08-25 12:52:18.212264Z
# [2026.08.25 15:52:18.276] INFO    Task 'temporary_qpu': ended at 2026-08-25 12:52:18.276541Z
# [2026.08.25 15:52:18.420] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 15:52:18.420] INFO    12:52:18.420940Z
# [2026.08.25 15:52:18.489] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 12:52:18.489699Z
# [2026.08.25 15:52:18.629] INFO    Task 'create_experiment': started at 2026-08-25 12:52:18.620009Z
# [2026.08.25 15:52:18.759] INFO    Task 'create_experiment': ended at 2026-08-25 12:52:18.759463Z
# [2026.08.25 15:52:18.886] INFO    Task 'compile_experiment': started at 2026-08-25 12:52:18.886593Z
# [2026.08.25 15:52:19.013] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 15:52:19.013] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 15:52:19.013] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 15:52:19.029] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 15:52:19.031] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 15:52:19.034] INFO    Schedule completed. [0.001 s]
# [2026.08.25 15:52:19.041] INFO    Code generation completed for all AWGs. [0.007 s]
# [2026.08.25 15:52:19.047] INFO    Completed compilation step 1 of 1. [0.015 s]
# [2026.08.25 15:52:19.051] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:52:19.063] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 15:52:19.064] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:52:19.064] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.25 15:52:19.064] INFO      SHFQC_DEV12192_sg     0        146           33           3      1248
# [2026.08.25 15:52:19.064] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:52:19.068] INFO      TOTAL                          168           33                  9248
# [2026.08.25 15:52:19.069] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:52:19.084] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 15:52:19.084] INFO    Task 'compile_experiment': ended at 2026-08-25 12:52:19.084966Z
# [2026.08.25 15:52:19.255] INFO    Task 'run_experiment': started at 2026-08-25 12:52:19.255870Z
# [2026.08.25 15:52:19.463] INFO    Starting near-time execution...
# [2026.08.25 15:52:19.561] INFO    Estimated RT execution time: 81.70 s.
# [2026.08.25 15:53:41.325] INFO    Finished near-time execution.
# [2026.08.25 15:53:41.390] INFO    Task 'run_experiment': ended at 2026-08-25 12:53:41.390362Z
# [2026.08.25 15:53:41.545] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:53:41.549] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 15:53:41.549] INFO      12:53:41.545618Z
# [2026.08.25 15:53:41.549] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:53:41.678] INFO    Task 'calculate_qubit_population': started at 2026-08-25 12:53:41.678834Z
# [2026.08.25 15:53:41.772] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 12:53:41.772685Z
# [2026.08.25 15:53:41.918] INFO    Task 'fit_data': started at 2026-08-25 12:53:41.918842Z
# [2026.08.25 15:53:42.207] INFO    Task 'fit_data': ended at 2026-08-25 12:53:42.207374Z
# [2026.08.25 15:53:42.336] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 12:53:42.336144Z
# [2026.08.25 15:53:42.481] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 12:53:42.481822Z
# [2026.08.25 15:53:42.609] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 12:53:42.609139Z
# [2026.08.25 15:53:42.768] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 12:53:42.768190Z
# [2026.08.25 15:53:43.208] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 12:53:43.202410Z
# [2026.08.25 15:53:43.268] INFO    Task 'plot_population': started at 2026-08-25 12:53:43.266928Z
# [2026.08.25 15:53:43.477] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 12:53:43.477326Z
# [2026.08.25 15:53:43.798] INFO    Task 'plot_population': ended at 2026-08-25 12:53:43.798331Z
# [2026.08.25 15:53:43.876] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:53:43.876] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 12:53:43.876686Z
# [2026.08.25 15:53:43.876] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:53:43.978] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:53:43.989] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 12:53:43.978250Z
# [2026.08.25 15:53:43.993] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)

    amplitude_rabi.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nDrive amplitude pi ge: ", qubit_to_measure.parameters.ge_drive_amplitude_pi)
        print("Drive amplitude pi2 ge: ", qubit_to_measure.parameters.ge_drive_amplitude_pi2)
    elif transition == 'ef':
        print("\nDrive amplitude pi ef: ", qubit_to_measure.parameters.ef_drive_amplitude_pi)
        print("Drive amplitude pi2 ef: ", qubit_to_measure.parameters.ef_drive_amplitude_pi2)
    
    print('\nUpdated global experiment parameters!\n')
# Out:
# {'new_parameter_values': {'Q2': {'ef_drive_amplitude_pi': 0.24940709147532214+/-0.013196996734607407,
#                                  'ef_drive_amplitude_pi2': 0.1195299628236887+/-0.012365783585156642}},
#  'old_parameter_values': {'Q2': {'ef_drive_amplitude_pi': 0.2,
#                                  'ef_drive_amplitude_pi2': 0.1}}}
#
# Drive amplitude pi ef:  0.24940709147532214
# Drive amplitude pi2 ef:  0.1195299628236887
#
# Updated global experiment parameters!

# %% [markdown]
# ### Rabi Chevron

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = False

transition = set_transition('ef')

drive_range = 10
drive_length = 100e-9
readout_amplitude = 0.2
n_avg_exponent = 12

amp_min = 0
amp_max = 1
n_amp = 31

chevron_detuning_min = -3.0e6
chevron_detuning_max = 3.0e6
n_detuning = 7
chevron_detunings = np.linspace(chevron_detuning_min, chevron_detuning_max, n_detuning)

if transition == 'ge':
    base_resonance_frequency = qubit_to_measure.parameters.resonance_frequency_ge
elif transition == 'ef':
    base_resonance_frequency = qubit_to_measure.parameters.resonance_frequency_ef

# %% [markdown]
# #### Run Workflow

# %%
options = amplitude_rabi.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(True)

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

rabi_chevron_results = []

for detuning in chevron_detunings:
    print(f'Measuring chevron point at detuning: {detuning * 1e-6:.3f} MHz')

    temporary_parameters = {}
    temp_pars = deepcopy(qubits[0].parameters)
    temp_pars.drive_range = drive_range
    temp_pars.readout_amplitude = readout_amplitude
    if transition == 'ge':
        temp_pars.ge_drive_length = drive_length
        temp_pars.resonance_frequency_ge = base_resonance_frequency + detuning
    elif transition == 'ef':
        temp_pars.ef_drive_length = drive_length
        temp_pars.resonance_frequency_ef = base_resonance_frequency + detuning
    temporary_parameters[q.uid] = temp_pars

    exp_workflow = amplitude_rabi.experiment_workflow(
        session=session,
        qpu=qpu,
        qubits=[q.uid for q in qubits_to_measure],
        amplitudes=[np.linspace(amp_min, amp_max, n_amp) for q in qubits_to_measure],
        options=options,
        temporary_parameters=temporary_parameters
    )
    workflow_result = exp_workflow.run()

    raw_signal = workflow_result.tasks["run_experiment"].output.get_data(qubit_to_measure.uid+"/result")
    rabi_chevron_results.append(raw_signal)

rabi_chevron_arr = np.array(rabi_chevron_results)
rabi_chevron_amp = np.linspace(amp_min, amp_max, n_amp)
# Out:
# Measuring chevron point at detuning: -3.000 MHz
# [2026.08.25 15:55:27.595] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:55:27.608] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 12:55:27.595034Z
# [2026.08.25 15:55:27.608] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:55:27.895] INFO    Task 'temporary_qpu': started at 2026-08-25 12:55:27.895182Z
# [2026.08.25 15:55:27.954] INFO    Task 'temporary_qpu': ended at 2026-08-25 12:55:27.954897Z
# [2026.08.25 15:55:28.126] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 15:55:28.126] INFO    12:55:28.126815Z
# [2026.08.25 15:55:28.178] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 12:55:28.178781Z
# [2026.08.25 15:55:28.304] INFO    Task 'create_experiment': started at 2026-08-25 12:55:28.304060Z
# [2026.08.25 15:55:28.457] INFO    Task 'create_experiment': ended at 2026-08-25 12:55:28.457926Z
# [2026.08.25 15:55:28.622] INFO    Task 'compile_experiment': started at 2026-08-25 12:55:28.622922Z
# [2026.08.25 15:55:28.745] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 15:55:28.745] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 15:55:28.749] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 15:55:28.749] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 15:55:28.749] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 15:55:28.751] INFO    Schedule completed. [0.001 s]
# [2026.08.25 15:55:28.758] INFO    Code generation completed for all AWGs. [0.004 s]
# [2026.08.25 15:55:28.758] INFO    Completed compilation step 1 of 1. [0.007 s]
# [2026.08.25 15:55:28.767] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:55:28.769] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 15:55:28.769] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:55:28.772] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.25 15:55:28.772] INFO      SHFQC_DEV12192_sg     0        146           34           3      1248
# [2026.08.25 15:55:28.772] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:55:28.774] INFO      TOTAL                          168           34                  9248
# [2026.08.25 15:55:28.774] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:55:28.785] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 15:55:28.786] INFO    Task 'compile_experiment': ended at 2026-08-25 12:55:28.786899Z
# [2026.08.25 15:55:28.928] INFO    Task 'run_experiment': started at 2026-08-25 12:55:28.928313Z
# [2026.08.25 15:55:29.093] INFO    Starting near-time execution...
# [2026.08.25 15:55:29.162] INFO    Estimated RT execution time: 40.85 s.
# [2026.08.25 15:56:10.081] INFO    Finished near-time execution.
# [2026.08.25 15:56:10.142] INFO    Task 'run_experiment': ended at 2026-08-25 12:56:10.142824Z
# [2026.08.25 15:56:10.286] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:56:10.291] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 15:56:10.291] INFO      12:56:10.286873Z
# [2026.08.25 15:56:10.291] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:56:10.398] INFO    Task 'calculate_qubit_population': started at 2026-08-25 12:56:10.398972Z
# [2026.08.25 15:56:10.511] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 12:56:10.511431Z
# [2026.08.25 15:56:10.610] INFO    Task 'fit_data': started at 2026-08-25 12:56:10.610364Z
# [2026.08.25 15:56:10.801] INFO    Task 'fit_data': ended at 2026-08-25 12:56:10.801349Z
# [2026.08.25 15:56:10.900] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 12:56:10.900357Z
# [2026.08.25 15:56:11.025] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 12:56:11.025114Z
# [2026.08.25 15:56:11.120] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 12:56:11.120189Z
# [2026.08.25 15:56:11.295] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 12:56:11.295829Z
# [2026.08.25 15:56:11.780] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 12:56:11.780701Z
# [2026.08.25 15:56:11.828] INFO    Task 'plot_population': started at 2026-08-25 12:56:11.828239Z
# [2026.08.25 15:56:12.038] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 12:56:12.038194Z
# [2026.08.25 15:56:12.537] INFO    Task 'plot_population': ended at 2026-08-25 12:56:12.537095Z
# [2026.08.25 15:56:12.604] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:56:12.604] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 12:56:12.604029Z
# [2026.08.25 15:56:12.604] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:56:12.653] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:56:12.653] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 12:56:12.653084Z
# [2026.08.25 15:56:12.653] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: -2.000 MHz
# [2026.08.25 15:56:12.844] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:56:12.844] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 12:56:12.844189Z
# [2026.08.25 15:56:12.844] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:56:13.206] INFO    Task 'temporary_qpu': started at 2026-08-25 12:56:13.206742Z
# [2026.08.25 15:56:13.258] INFO    Task 'temporary_qpu': ended at 2026-08-25 12:56:13.258725Z
# [2026.08.25 15:56:13.371] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 15:56:13.371] INFO    12:56:13.371724Z
# [2026.08.25 15:56:13.481] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 12:56:13.481964Z
# [2026.08.25 15:56:13.585] INFO    Task 'create_experiment': started at 2026-08-25 12:56:13.583725Z
# [2026.08.25 15:56:13.754] INFO    Task 'create_experiment': ended at 2026-08-25 12:56:13.754050Z
# [2026.08.25 15:56:13.866] INFO    Task 'compile_experiment': started at 2026-08-25 12:56:13.866922Z
# [2026.08.25 15:56:13.983] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 15:56:13.994] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 15:56:13.996] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 15:56:13.996] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 15:56:13.998] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 15:56:14.004] INFO    Schedule completed. [0.002 s]
# [2026.08.25 15:56:14.010] INFO    Code generation completed for all AWGs. [0.004 s]
# [2026.08.25 15:56:14.010] INFO    Completed compilation step 1 of 1. [0.010 s]
# [2026.08.25 15:56:14.016] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:56:14.018] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 15:56:14.019] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:56:14.019] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.25 15:56:14.021] INFO      SHFQC_DEV12192_sg     0        146           34           3      1248
# [2026.08.25 15:56:14.021] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:56:14.022] INFO      TOTAL                          168           34                  9248
# [2026.08.25 15:56:14.022] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:56:14.037] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 15:56:14.039] INFO    Task 'compile_experiment': ended at 2026-08-25 12:56:14.039737Z
# [2026.08.25 15:56:14.186] INFO    Task 'run_experiment': started at 2026-08-25 12:56:14.186731Z
# [2026.08.25 15:56:14.385] INFO    Starting near-time execution...
# [2026.08.25 15:56:14.458] INFO    Estimated RT execution time: 40.85 s.
# [2026.08.25 15:56:55.374] INFO    Finished near-time execution.
# [2026.08.25 15:56:55.453] INFO    Task 'run_experiment': ended at 2026-08-25 12:56:55.453586Z
# [2026.08.25 15:56:55.583] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:56:55.583] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 15:56:55.583] INFO      12:56:55.583457Z
# [2026.08.25 15:56:55.593] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:56:55.741] INFO    Task 'calculate_qubit_population': started at 2026-08-25 12:56:55.740766Z
# [2026.08.25 15:56:55.868] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 12:56:55.868154Z
# [2026.08.25 15:56:55.970] INFO    Task 'fit_data': started at 2026-08-25 12:56:55.970591Z
# [2026.08.25 15:56:56.191] INFO    Task 'fit_data': ended at 2026-08-25 12:56:56.191444Z
# [2026.08.25 15:56:56.305] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 12:56:56.305666Z
# [2026.08.25 15:56:56.477] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 12:56:56.477967Z
# [2026.08.25 15:56:56.831] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 12:56:56.831732Z
# [2026.08.25 15:56:56.961] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 12:56:56.961163Z
# [2026.08.25 15:56:57.420] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 12:56:57.420243Z
# [2026.08.25 15:56:57.477] INFO    Task 'plot_population': started at 2026-08-25 12:56:57.477455Z
# [2026.08.25 15:56:57.652] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 12:56:57.652696Z
# [2026.08.25 15:56:57.931] INFO    Task 'plot_population': ended at 2026-08-25 12:56:57.931917Z
# [2026.08.25 15:56:57.995] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:56:57.995] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 12:56:57.995291Z
# [2026.08.25 15:56:57.995] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:56:58.071] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:56:58.071] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 12:56:58.071511Z
# [2026.08.25 15:56:58.071] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: -1.000 MHz
# [2026.08.25 15:56:58.260] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:56:58.260] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 12:56:58.255516Z
# [2026.08.25 15:56:58.260] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:56:58.602] INFO    Task 'temporary_qpu': started at 2026-08-25 12:56:58.600895Z
# [2026.08.25 15:56:58.648] INFO    Task 'temporary_qpu': ended at 2026-08-25 12:56:58.648605Z
# [2026.08.25 15:56:58.758] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 15:56:58.758] INFO    12:56:58.758309Z
# [2026.08.25 15:56:58.823] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 12:56:58.823068Z
# [2026.08.25 15:56:58.941] INFO    Task 'create_experiment': started at 2026-08-25 12:56:58.935783Z
# [2026.08.25 15:56:59.051] INFO    Task 'create_experiment': ended at 2026-08-25 12:56:59.051039Z
# [2026.08.25 15:56:59.146] INFO    Task 'compile_experiment': started at 2026-08-25 12:56:59.146105Z
# [2026.08.25 15:56:59.258] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 15:56:59.262] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 15:56:59.264] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 15:56:59.266] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 15:56:59.268] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 15:56:59.272] INFO    Schedule completed. [0.003 s]
# [2026.08.25 15:56:59.274] INFO    Code generation completed for all AWGs. [0.007 s]
# [2026.08.25 15:56:59.274] INFO    Completed compilation step 1 of 1. [0.015 s]
# [2026.08.25 15:56:59.297] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:56:59.297] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 15:56:59.297] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:56:59.304] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.25 15:56:59.304] INFO      SHFQC_DEV12192_sg     0        146           34           3      1248
# [2026.08.25 15:56:59.305] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:56:59.306] INFO      TOTAL                          168           34                  9248
# [2026.08.25 15:56:59.306] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:56:59.322] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 15:56:59.323] INFO    Task 'compile_experiment': ended at 2026-08-25 12:56:59.323907Z
# [2026.08.25 15:56:59.468] INFO    Task 'run_experiment': started at 2026-08-25 12:56:59.468533Z
# [2026.08.25 15:56:59.731] INFO    Starting near-time execution...
# [2026.08.25 15:56:59.792] INFO    Estimated RT execution time: 40.85 s.
# [2026.08.25 15:57:40.722] INFO    Finished near-time execution.
# [2026.08.25 15:57:40.784] INFO    Task 'run_experiment': ended at 2026-08-25 12:57:40.784430Z
# [2026.08.25 15:57:40.887] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:57:40.902] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 15:57:40.903] INFO      12:57:40.887565Z
# [2026.08.25 15:57:40.903] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:57:41.000] INFO    Task 'calculate_qubit_population': started at 2026-08-25 12:57:41.000783Z
# [2026.08.25 15:57:41.130] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 12:57:41.130131Z
# [2026.08.25 15:57:41.241] INFO    Task 'fit_data': started at 2026-08-25 12:57:41.241213Z
# [2026.08.25 15:57:41.400] INFO    Task 'fit_data': ended at 2026-08-25 12:57:41.400285Z
# [2026.08.25 15:57:41.487] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 12:57:41.487068Z
# [2026.08.25 15:57:41.657] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 12:57:41.656115Z
# [2026.08.25 15:57:41.769] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 12:57:41.769775Z
# [2026.08.25 15:57:41.913] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 12:57:41.913936Z
# [2026.08.25 15:57:42.429] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 12:57:42.429920Z
# [2026.08.25 15:57:42.476] INFO    Task 'plot_population': started at 2026-08-25 12:57:42.476364Z
# [2026.08.25 15:57:42.673] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 12:57:42.673493Z
# [2026.08.25 15:57:43.122] INFO    Task 'plot_population': ended at 2026-08-25 12:57:43.122165Z
# [2026.08.25 15:57:43.168] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:57:43.168] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 12:57:43.168591Z
# [2026.08.25 15:57:43.168] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:57:43.231] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:57:43.233] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 12:57:43.231676Z
# [2026.08.25 15:57:43.234] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: 0.000 MHz
# [2026.08.25 15:57:43.428] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:57:43.428] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 12:57:43.426633Z
# [2026.08.25 15:57:43.428] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:57:43.734] INFO    Task 'temporary_qpu': started at 2026-08-25 12:57:43.734246Z
# [2026.08.25 15:57:43.794] INFO    Task 'temporary_qpu': ended at 2026-08-25 12:57:43.794931Z
# [2026.08.25 15:57:43.922] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 15:57:43.932] INFO    12:57:43.922182Z
# [2026.08.25 15:57:43.985] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 12:57:43.985812Z
# [2026.08.25 15:57:44.081] INFO    Task 'create_experiment': started at 2026-08-25 12:57:44.081587Z
# [2026.08.25 15:57:44.275] INFO    Task 'create_experiment': ended at 2026-08-25 12:57:44.275538Z
# [2026.08.25 15:57:44.375] INFO    Task 'compile_experiment': started at 2026-08-25 12:57:44.375659Z
# [2026.08.25 15:57:44.465] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 15:57:44.465] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 15:57:44.465] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 15:57:44.465] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 15:57:44.465] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 15:57:44.476] INFO    Schedule completed. [0.001 s]
# [2026.08.25 15:57:44.484] INFO    Code generation completed for all AWGs. [0.009 s]
# [2026.08.25 15:57:44.488] INFO    Completed compilation step 1 of 1. [0.014 s]
# [2026.08.25 15:57:44.498] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:57:44.501] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 15:57:44.504] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:57:44.504] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.25 15:57:44.504] INFO      SHFQC_DEV12192_sg     0        146           34           3      1248
# [2026.08.25 15:57:44.507] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:57:44.507] INFO      TOTAL                          168           34                  9248
# [2026.08.25 15:57:44.507] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:57:44.534] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 15:57:44.534] INFO    Task 'compile_experiment': ended at 2026-08-25 12:57:44.534938Z
# [2026.08.25 15:57:44.610] INFO    Task 'run_experiment': started at 2026-08-25 12:57:44.610242Z
# [2026.08.25 15:57:44.754] INFO    Starting near-time execution...
# [2026.08.25 15:57:44.843] INFO    Estimated RT execution time: 40.85 s.
# [2026.08.25 15:58:25.749] INFO    Finished near-time execution.
# [2026.08.25 15:58:25.817] INFO    Task 'run_experiment': ended at 2026-08-25 12:58:25.817741Z
# [2026.08.25 15:58:25.935] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:58:25.935] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 15:58:25.935] INFO      12:58:25.935686Z
# [2026.08.25 15:58:25.935] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:58:26.038] INFO    Task 'calculate_qubit_population': started at 2026-08-25 12:58:26.038008Z
# [2026.08.25 15:58:26.205] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 12:58:26.205815Z
# [2026.08.25 15:58:26.306] INFO    Task 'fit_data': started at 2026-08-25 12:58:26.306362Z
# [2026.08.25 15:58:26.448] INFO    Task 'fit_data': ended at 2026-08-25 12:58:26.448550Z
# [2026.08.25 15:58:26.549] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 12:58:26.549912Z
# [2026.08.25 15:58:26.758] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 12:58:26.758490Z
# [2026.08.25 15:58:26.838] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 12:58:26.838089Z
# [2026.08.25 15:58:27.016] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 12:58:27.016590Z
# [2026.08.25 15:58:27.495] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 12:58:27.495640Z
# [2026.08.25 15:58:27.559] INFO    Task 'plot_population': started at 2026-08-25 12:58:27.559272Z
# [2026.08.25 15:58:27.737] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 12:58:27.737250Z
# [2026.08.25 15:58:28.126] INFO    Task 'plot_population': ended at 2026-08-25 12:58:28.126899Z
# [2026.08.25 15:58:28.171] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:58:28.171] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 12:58:28.171492Z
# [2026.08.25 15:58:28.171] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:58:28.241] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:58:28.241] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 12:58:28.241518Z
# [2026.08.25 15:58:28.241] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: 1.000 MHz
# [2026.08.25 15:58:28.447] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:58:28.447] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 12:58:28.447054Z
# [2026.08.25 15:58:28.447] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:58:28.736] INFO    Task 'temporary_qpu': started at 2026-08-25 12:58:28.736814Z
# [2026.08.25 15:58:28.796] INFO    Task 'temporary_qpu': ended at 2026-08-25 12:58:28.796894Z
# [2026.08.25 15:58:28.908] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 15:58:28.908] INFO    12:58:28.908992Z
# [2026.08.25 15:58:28.968] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 12:58:28.968285Z
# [2026.08.25 15:58:29.117] INFO    Task 'create_experiment': started at 2026-08-25 12:58:29.117652Z
# [2026.08.25 15:58:29.262] INFO    Task 'create_experiment': ended at 2026-08-25 12:58:29.262327Z
# [2026.08.25 15:58:29.357] INFO    Task 'compile_experiment': started at 2026-08-25 12:58:29.357371Z
# [2026.08.25 15:58:29.453] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 15:58:29.453] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 15:58:29.469] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 15:58:29.469] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 15:58:29.469] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 15:58:29.476] INFO    Schedule completed. [0.001 s]
# [2026.08.25 15:58:29.485] INFO    Code generation completed for all AWGs. [0.009 s]
# [2026.08.25 15:58:29.488] INFO    Completed compilation step 1 of 1. [0.014 s]
# [2026.08.25 15:58:29.488] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:58:29.488] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 15:58:29.488] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:58:29.488] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.25 15:58:29.488] INFO      SHFQC_DEV12192_sg     0        146           34           3      1248
# [2026.08.25 15:58:29.500] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:58:29.502] INFO      TOTAL                          168           34                  9248
# [2026.08.25 15:58:29.502] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:58:29.518] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 15:58:29.520] INFO    Task 'compile_experiment': ended at 2026-08-25 12:58:29.520645Z
# [2026.08.25 15:58:29.648] INFO    Task 'run_experiment': started at 2026-08-25 12:58:29.648105Z
# [2026.08.25 15:58:29.789] INFO    Starting near-time execution...
# [2026.08.25 15:58:29.870] INFO    Estimated RT execution time: 40.85 s.
# [2026.08.25 15:59:10.786] INFO    Finished near-time execution.
# [2026.08.25 15:59:10.864] INFO    Task 'run_experiment': ended at 2026-08-25 12:59:10.864876Z
# [2026.08.25 15:59:10.983] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:59:10.989] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 15:59:10.989] INFO      12:59:10.983940Z
# [2026.08.25 15:59:10.992] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:59:11.152] INFO    Task 'calculate_qubit_population': started at 2026-08-25 12:59:11.152265Z
# [2026.08.25 15:59:11.312] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 12:59:11.312984Z
# [2026.08.25 15:59:11.407] INFO    Task 'fit_data': started at 2026-08-25 12:59:11.407244Z
# [2026.08.25 15:59:11.552] INFO    Task 'fit_data': ended at 2026-08-25 12:59:11.552160Z
# [2026.08.25 15:59:11.626] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 12:59:11.626327Z
# [2026.08.25 15:59:11.736] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 12:59:11.736781Z
# [2026.08.25 15:59:11.803] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 12:59:11.803683Z
# [2026.08.25 15:59:11.890] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 12:59:11.890625Z
# [2026.08.25 15:59:12.970] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 12:59:12.970038Z
# [2026.08.25 15:59:13.022] INFO    Task 'plot_population': started at 2026-08-25 12:59:13.022288Z
# [2026.08.25 15:59:13.169] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 12:59:13.169164Z
# [2026.08.25 15:59:13.567] INFO    Task 'plot_population': ended at 2026-08-25 12:59:13.567937Z
# [2026.08.25 15:59:13.605] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:59:13.605] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 12:59:13.605042Z
# [2026.08.25 15:59:13.605] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:59:13.646] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:59:13.646] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 12:59:13.646750Z
# [2026.08.25 15:59:13.646] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: 2.000 MHz
# [2026.08.25 15:59:13.822] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:59:13.822] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 12:59:13.822741Z
# [2026.08.25 15:59:13.822] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:59:14.152] INFO    Task 'temporary_qpu': started at 2026-08-25 12:59:14.152832Z
# [2026.08.25 15:59:14.208] INFO    Task 'temporary_qpu': ended at 2026-08-25 12:59:14.208537Z
# [2026.08.25 15:59:14.336] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 15:59:14.337] INFO    12:59:14.320801Z
# [2026.08.25 15:59:14.657] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 12:59:14.653490Z
# [2026.08.25 15:59:14.786] INFO    Task 'create_experiment': started at 2026-08-25 12:59:14.786429Z
# [2026.08.25 15:59:14.974] INFO    Task 'create_experiment': ended at 2026-08-25 12:59:14.974172Z
# [2026.08.25 15:59:15.059] INFO    Task 'compile_experiment': started at 2026-08-25 12:59:15.059138Z
# [2026.08.25 15:59:15.173] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 15:59:15.175] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 15:59:15.175] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 15:59:15.175] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 15:59:15.183] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 15:59:15.184] INFO    Schedule completed. [0.001 s]
# [2026.08.25 15:59:15.187] INFO    Code generation completed for all AWGs. [0.003 s]
# [2026.08.25 15:59:15.187] INFO    Completed compilation step 1 of 1. [0.007 s]
# [2026.08.25 15:59:15.196] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:59:15.196] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 15:59:15.198] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:59:15.198] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.25 15:59:15.201] INFO      SHFQC_DEV12192_sg     0        146           34           3      1248
# [2026.08.25 15:59:15.202] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:59:15.203] INFO      TOTAL                          168           34                  9248
# [2026.08.25 15:59:15.204] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 15:59:15.216] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 15:59:15.217] INFO    Task 'compile_experiment': ended at 2026-08-25 12:59:15.217674Z
# [2026.08.25 15:59:15.348] INFO    Task 'run_experiment': started at 2026-08-25 12:59:15.348874Z
# [2026.08.25 15:59:15.497] INFO    Starting near-time execution...
# [2026.08.25 15:59:15.590] INFO    Estimated RT execution time: 40.85 s.
# [2026.08.25 15:59:56.511] INFO    Finished near-time execution.
# [2026.08.25 15:59:56.583] INFO    Task 'run_experiment': ended at 2026-08-25 12:59:56.583864Z
# [2026.08.25 15:59:56.736] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:59:56.736] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 15:59:56.736] INFO      12:59:56.736108Z
# [2026.08.25 15:59:56.736] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:59:56.863] INFO    Task 'calculate_qubit_population': started at 2026-08-25 12:59:56.863549Z
# [2026.08.25 15:59:56.976] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 12:59:56.976565Z
# [2026.08.25 15:59:57.088] INFO    Task 'fit_data': started at 2026-08-25 12:59:57.088955Z
# [2026.08.25 15:59:57.445] INFO    Task 'fit_data': ended at 2026-08-25 12:59:57.445473Z
# [2026.08.25 15:59:57.620] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 12:59:57.620869Z
# [2026.08.25 15:59:57.764] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 12:59:57.764336Z
# [2026.08.25 15:59:57.877] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 12:59:57.877521Z
# [2026.08.25 15:59:58.030] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 12:59:58.028631Z
# [2026.08.25 15:59:58.424] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 12:59:58.424431Z
# [2026.08.25 15:59:58.489] INFO    Task 'plot_population': started at 2026-08-25 12:59:58.489093Z
# [2026.08.25 15:59:58.683] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 12:59:58.683800Z
# [2026.08.25 15:59:59.050] INFO    Task 'plot_population': ended at 2026-08-25 12:59:59.050668Z
# [2026.08.25 15:59:59.114] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:59:59.114] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 12:59:59.114128Z
# [2026.08.25 15:59:59.114] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:59:59.203] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:59:59.203] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 12:59:59.203891Z
# [2026.08.25 15:59:59.203] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: 3.000 MHz
# [2026.08.25 15:59:59.534] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:59:59.534] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 12:59:59.534491Z
# [2026.08.25 15:59:59.551] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 15:59:59.898] INFO    Task 'temporary_qpu': started at 2026-08-25 12:59:59.887916Z
# [2026.08.25 15:59:59.937] INFO    Task 'temporary_qpu': ended at 2026-08-25 12:59:59.937253Z
# [2026.08.25 16:00:00.050] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 16:00:00.051] INFO    13:00:00.050304Z
# [2026.08.25 16:00:00.096] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 13:00:00.096754Z
# [2026.08.25 16:00:00.266] INFO    Task 'create_experiment': started at 2026-08-25 13:00:00.266185Z
# [2026.08.25 16:00:00.400] INFO    Task 'create_experiment': ended at 2026-08-25 13:00:00.400628Z
# [2026.08.25 16:00:00.496] INFO    Task 'compile_experiment': started at 2026-08-25 13:00:00.496955Z
# [2026.08.25 16:00:00.593] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 16:00:00.593] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 16:00:00.593] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 16:00:00.608] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 16:00:00.609] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 16:00:00.611] INFO    Schedule completed. [0.000 s]
# [2026.08.25 16:00:00.621] INFO    Code generation completed for all AWGs. [0.009 s]
# [2026.08.25 16:00:00.625] INFO    Completed compilation step 1 of 1. [0.014 s]
# [2026.08.25 16:00:00.631] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:00:00.633] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 16:00:00.635] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:00:00.635] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.25 16:00:00.635] INFO      SHFQC_DEV12192_sg     0        146           34           3      1248
# [2026.08.25 16:00:00.637] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:00:00.637] INFO      TOTAL                          168           34                  9248
# [2026.08.25 16:00:00.639] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:00:00.657] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 16:00:00.657] INFO    Task 'compile_experiment': ended at 2026-08-25 13:00:00.657065Z
# [2026.08.25 16:00:00.850] INFO    Task 'run_experiment': started at 2026-08-25 13:00:00.850319Z
# [2026.08.25 16:00:01.138] INFO    Starting near-time execution...
# [2026.08.25 16:00:01.235] INFO    Estimated RT execution time: 40.85 s.
# [2026.08.25 16:00:42.159] INFO    Finished near-time execution.
# [2026.08.25 16:00:42.447] INFO    Task 'run_experiment': ended at 2026-08-25 13:00:42.447887Z
# [2026.08.25 16:00:42.561] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:00:42.561] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 16:00:42.567] INFO      13:00:42.561429Z
# [2026.08.25 16:00:42.568] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:00:42.692] INFO    Task 'calculate_qubit_population': started at 2026-08-25 13:00:42.689905Z
# [2026.08.25 16:00:42.793] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 13:00:42.790067Z
# [2026.08.25 16:00:42.883] INFO    Task 'fit_data': started at 2026-08-25 13:00:42.883487Z
# [2026.08.25 16:00:43.043] INFO    Task 'fit_data': ended at 2026-08-25 13:00:43.043925Z
# [2026.08.25 16:00:43.153] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 13:00:43.153603Z
# [2026.08.25 16:00:43.297] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 13:00:43.295339Z
# [2026.08.25 16:00:43.377] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 13:00:43.377339Z
# [2026.08.25 16:00:43.556] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 13:00:43.556670Z
# [2026.08.25 16:00:43.908] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 13:00:43.908885Z
# [2026.08.25 16:00:43.975] INFO    Task 'plot_population': started at 2026-08-25 13:00:43.975074Z
# [2026.08.25 16:00:44.182] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 13:00:44.174579Z
# [2026.08.25 16:00:44.662] INFO    Task 'plot_population': ended at 2026-08-25 13:00:44.662216Z
# [2026.08.25 16:00:44.711] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:00:44.711] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 13:00:44.711333Z
# [2026.08.25 16:00:44.711] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:00:44.792] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:00:44.792] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 13:00:44.792954Z
# [2026.08.25 16:00:44.792] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Plot Chevron Map

# %%
X = rabi_chevron_amp
Y = chevron_detunings * 1e-6
Z = np.absolute(rabi_chevron_arr)

fig, ax = plt.subplots(figsize=(8, 6))
c = ax.pcolormesh(X, Y, Z, cmap='Reds', shading='auto')
fig.colorbar(c, ax=ax, label='Signal amplitude (a.u.)')
ax.set_xlabel('Drive amplitude (a.u.)')
ax.set_ylabel('Detuning (MHz)')
ax.set_title(f'Rabi chevron, {transition}-transition')

figname = f'Rabi_chevron_{transition}_'
file_path = get_path_to_file(figname, '.png')
plt.savefig(file_path, dpi=600, format='png', metadata=None,
        bbox_inches=None, pad_inches=0.1,
        facecolor='auto', edgecolor='auto',
        backend=None,
       )

# %% [markdown]
# #### Save Data

# %%
Data_rabi_chevron = {
    'rabi_chevron': rabi_chevron_arr,
    'detunings': chevron_detunings,
    'rabi_amp': rabi_chevron_amp,
}

file_name = f'Rabi_chevron_{transition}_'
file_path = get_path_to_file(file_name, '.mat')
savemat(file_path, Data_rabi_chevron)

# %% [markdown]
# ### Rabi Frequency Calibration

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = False

transition = set_transition('ef')

drive_range = 10
readout_amplitude = 0.1
n_avg_exponent = 12

amp_min = 0
amp_max = 1.0
n_amp = 101

drive_length_min = 50e-9
drive_length_max = 400e-9
n_drive_length = 36
drive_lengths = np.linspace(drive_length_min, drive_length_max, n_drive_length)

# %% [markdown]
# #### Run Workflow

# %%
options = amplitude_rabi.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(True)

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

fitted_pi_amplitudes = []

for drive_length in drive_lengths:
    print(f'Measuring Rabi with drive length: {drive_length * 1e9:.1f} ns')

    temporary_parameters = {}
    temp_pars = deepcopy(qubits[0].parameters)
    temp_pars.drive_range = drive_range
    temp_pars.readout_amplitude = readout_amplitude
    if transition == 'ge':
        temp_pars.ge_drive_length = drive_length
    elif transition == 'ef':
        temp_pars.ef_drive_length = drive_length
    temporary_parameters[q.uid] = temp_pars

    exp_workflow = amplitude_rabi.experiment_workflow(
        session=session,
        qpu=qpu,
        qubits=[q.uid for q in qubits_to_measure],
        amplitudes=[np.linspace(amp_min, amp_max, n_amp) for q in qubits_to_measure],
        options=options,
        temporary_parameters=temporary_parameters
    )
    workflow_result = exp_workflow.run()

    analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
    new_parameter_values = analysis_workflow_result.output["new_parameter_values"]
    if transition == 'ge':
        fitted_pi_amplitude = new_parameter_values[qubit_to_measure.uid]["ge_drive_amplitude_pi"]
    elif transition == 'ef':
        fitted_pi_amplitude = new_parameter_values[qubit_to_measure.uid]["ef_drive_amplitude_pi"]
    fitted_pi_amplitudes.append(fitted_pi_amplitude)

fitted_pi_amplitudes = np.array(fitted_pi_amplitudes)
# Out:
# Measuring Rabi with drive length: 50.0 ns
# [2026.08.25 16:21:50.268] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:21:50.268] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 13:21:50.268527Z
# [2026.08.25 16:21:50.268] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:21:50.593] INFO    Task 'temporary_qpu': started at 2026-08-25 13:21:50.593579Z
# [2026.08.25 16:21:50.644] INFO    Task 'temporary_qpu': ended at 2026-08-25 13:21:50.643294Z
# [2026.08.25 16:21:50.743] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 16:21:50.744] INFO    13:21:50.743204Z
# [2026.08.25 16:21:50.811] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 13:21:50.809675Z
# [2026.08.25 16:21:50.944] INFO    Task 'create_experiment': started at 2026-08-25 13:21:50.944461Z
# [2026.08.25 16:21:51.102] INFO    Task 'create_experiment': ended at 2026-08-25 13:21:51.102727Z
# [2026.08.25 16:21:51.246] INFO    Task 'compile_experiment': started at 2026-08-25 13:21:51.246950Z
# [2026.08.25 16:21:51.348] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 16:21:51.349] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 16:21:51.351] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 16:21:51.351] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 16:21:51.351] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 16:21:51.358] INFO    Schedule completed. [0.002 s]
# [2026.08.25 16:21:51.374] INFO    Code generation completed for all AWGs. [0.015 s]
# [2026.08.25 16:21:51.374] INFO    Completed compilation step 1 of 1. [0.022 s]
# [2026.08.25 16:21:51.391] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:21:51.392] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 16:21:51.392] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:21:51.392] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.25 16:21:51.392] INFO      SHFQC_DEV12192_sg     0        426          104           3       864
# [2026.08.25 16:21:51.392] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:21:51.392] INFO      TOTAL                          448          104                  8864
# [2026.08.25 16:21:51.401] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:21:51.432] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 16:21:51.435] INFO    Task 'compile_experiment': ended at 2026-08-25 13:21:51.435878Z
# [2026.08.25 16:21:51.629] INFO    Task 'run_experiment': started at 2026-08-25 13:21:51.629076Z
# [2026.08.25 16:21:51.802] INFO    Starting near-time execution...
# [2026.08.25 16:21:51.885] INFO    Estimated RT execution time: 127.48 s.
# [2026.08.25 16:23:59.448] INFO    Finished near-time execution.
# [2026.08.25 16:23:59.530] INFO    Task 'run_experiment': ended at 2026-08-25 13:23:59.530189Z
# [2026.08.25 16:23:59.673] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:23:59.675] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 16:23:59.675] INFO      13:23:59.669620Z
# [2026.08.25 16:23:59.675] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:23:59.836] INFO    Task 'calculate_qubit_population': started at 2026-08-25 13:23:59.835339Z
# [2026.08.25 16:23:59.982] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 13:23:59.982262Z
# [2026.08.25 16:24:00.123] INFO    Task 'fit_data': started at 2026-08-25 13:24:00.123089Z
# [2026.08.25 16:24:00.332] INFO    Task 'fit_data': ended at 2026-08-25 13:24:00.332794Z
# [2026.08.25 16:24:00.484] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 13:24:00.484002Z
# [2026.08.25 16:24:00.716] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 13:24:00.716386Z
# [2026.08.25 16:24:00.851] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 13:24:00.851819Z
# [2026.08.25 16:24:00.989] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 13:24:00.989196Z
# [2026.08.25 16:24:01.488] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 13:24:01.488270Z
# [2026.08.25 16:24:01.551] INFO    Task 'plot_population': started at 2026-08-25 13:24:01.551047Z
# [2026.08.25 16:24:01.763] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 13:24:01.763614Z
# [2026.08.25 16:24:02.195] INFO    Task 'plot_population': ended at 2026-08-25 13:24:02.195555Z
# [2026.08.25 16:24:02.241] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:24:02.241] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 13:24:02.241785Z
# [2026.08.25 16:24:02.255] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:24:02.324] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:24:02.324] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 13:24:02.323005Z
# [2026.08.25 16:24:02.326] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring Rabi with drive length: 60.0 ns
# [2026.08.25 16:24:02.531] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:24:02.531] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 13:24:02.531116Z
# [2026.08.25 16:24:02.531] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:24:02.964] INFO    Task 'temporary_qpu': started at 2026-08-25 13:24:02.964373Z
# [2026.08.25 16:24:03.029] INFO    Task 'temporary_qpu': ended at 2026-08-25 13:24:03.029410Z
# [2026.08.25 16:24:03.196] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 16:24:03.196] INFO    13:24:03.196821Z
# [2026.08.25 16:24:03.271] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 13:24:03.271128Z
# [2026.08.25 16:24:03.399] INFO    Task 'create_experiment': started at 2026-08-25 13:24:03.399426Z
# [2026.08.25 16:24:03.598] INFO    Task 'create_experiment': ended at 2026-08-25 13:24:03.598472Z
# [2026.08.25 16:24:03.758] INFO    Task 'compile_experiment': started at 2026-08-25 13:24:03.752510Z
# [2026.08.25 16:24:03.899] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 16:24:03.899] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 16:24:03.913] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 16:24:03.913] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 16:24:03.913] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 16:24:03.913] INFO    Schedule completed. [0.001 s]
# [2026.08.25 16:24:03.931] INFO    Code generation completed for all AWGs. [0.015 s]
# [2026.08.25 16:24:03.931] INFO    Completed compilation step 1 of 1. [0.021 s]
# [2026.08.25 16:24:03.946] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:24:03.948] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 16:24:03.948] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:24:03.948] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.25 16:24:03.948] INFO      SHFQC_DEV12192_sg     0        426          104           3       928
# [2026.08.25 16:24:03.951] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:24:03.951] INFO      TOTAL                          448          104                  8928
# [2026.08.25 16:24:03.953] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:24:03.969] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 16:24:03.969] INFO    Task 'compile_experiment': ended at 2026-08-25 13:24:03.969802Z
# [2026.08.25 16:24:04.158] INFO    Task 'run_experiment': started at 2026-08-25 13:24:04.158608Z
# [2026.08.25 16:24:04.381] INFO    Starting near-time execution...
# [2026.08.25 16:24:04.477] INFO    Estimated RT execution time: 127.48 s.
# [2026.08.25 16:26:12.012] INFO    Finished near-time execution.
# [2026.08.25 16:26:12.066] INFO    Task 'run_experiment': ended at 2026-08-25 13:26:12.066497Z
# [2026.08.25 16:26:12.258] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:26:12.260] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 16:26:12.260] INFO      13:26:12.258055Z
# [2026.08.25 16:26:12.260] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:26:12.429] INFO    Task 'calculate_qubit_population': started at 2026-08-25 13:26:12.429681Z
# [2026.08.25 16:26:12.558] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 13:26:12.558065Z
# [2026.08.25 16:26:12.704] INFO    Task 'fit_data': started at 2026-08-25 13:26:12.704200Z
# [2026.08.25 16:26:12.928] INFO    Task 'fit_data': ended at 2026-08-25 13:26:12.928038Z
# [2026.08.25 16:26:13.101] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 13:26:13.101230Z
# [2026.08.25 16:26:13.293] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 13:26:13.293610Z
# [2026.08.25 16:26:13.386] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 13:26:13.384757Z
# [2026.08.25 16:26:13.522] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 13:26:13.522172Z
# [2026.08.25 16:26:14.050] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 13:26:14.050829Z
# [2026.08.25 16:26:14.100] INFO    Task 'plot_population': started at 2026-08-25 13:26:14.100185Z
# [2026.08.25 16:26:14.243] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 13:26:14.243546Z
# [2026.08.25 16:26:14.662] INFO    Task 'plot_population': ended at 2026-08-25 13:26:14.662390Z
# [2026.08.25 16:26:14.684] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:26:14.684] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 13:26:14.684220Z
# [2026.08.25 16:26:14.684] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:26:14.711] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:26:14.711] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 13:26:14.711780Z
# [2026.08.25 16:26:14.711] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring Rabi with drive length: 70.0 ns
# [2026.08.25 16:26:14.880] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:26:14.880] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 13:26:14.879468Z
# [2026.08.25 16:26:14.882] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:26:15.239] INFO    Task 'temporary_qpu': started at 2026-08-25 13:26:15.239871Z
# [2026.08.25 16:26:15.313] INFO    Task 'temporary_qpu': ended at 2026-08-25 13:26:15.313741Z
# [2026.08.25 16:26:15.414] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 16:26:15.414] INFO    13:26:15.414314Z
# [2026.08.25 16:26:15.465] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 13:26:15.465455Z
# [2026.08.25 16:26:15.578] INFO    Task 'create_experiment': started at 2026-08-25 13:26:15.578302Z
# [2026.08.25 16:26:15.723] INFO    Task 'create_experiment': ended at 2026-08-25 13:26:15.723531Z
# [2026.08.25 16:26:15.851] INFO    Task 'compile_experiment': started at 2026-08-25 13:26:15.851114Z
# [2026.08.25 16:26:15.935] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 16:26:15.935] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 16:26:15.935] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 16:26:15.947] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 16:26:15.947] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 16:26:15.952] INFO    Schedule completed. [0.004 s]
# [2026.08.25 16:26:15.963] INFO    Code generation completed for all AWGs. [0.010 s]
# [2026.08.25 16:26:15.963] INFO    Completed compilation step 1 of 1. [0.018 s]
# [2026.08.25 16:26:15.963] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:26:15.973] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 16:26:15.973] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:26:15.973] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.25 16:26:15.978] INFO      SHFQC_DEV12192_sg     0        426          104           3       992
# [2026.08.25 16:26:15.979] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:26:15.979] INFO      TOTAL                          448          104                  8992
# [2026.08.25 16:26:15.979] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:26:15.997] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 16:26:15.997] INFO    Task 'compile_experiment': ended at 2026-08-25 13:26:15.997542Z
# [2026.08.25 16:26:16.158] INFO    Task 'run_experiment': started at 2026-08-25 13:26:16.157660Z
# [2026.08.25 16:26:16.348] INFO    Starting near-time execution...
# [2026.08.25 16:26:16.461] INFO    Estimated RT execution time: 127.48 s.
# [2026.08.25 16:28:24.037] INFO    Finished near-time execution.
# [2026.08.25 16:28:24.103] INFO    Task 'run_experiment': ended at 2026-08-25 13:28:24.103901Z
# [2026.08.25 16:28:24.214] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:28:24.215] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 16:28:24.215] INFO      13:28:24.214561Z
# [2026.08.25 16:28:24.215] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:28:24.393] INFO    Task 'calculate_qubit_population': started at 2026-08-25 13:28:24.393893Z
# [2026.08.25 16:28:24.493] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 13:28:24.493875Z
# [2026.08.25 16:28:24.583] INFO    Task 'fit_data': started at 2026-08-25 13:28:24.583830Z
# [2026.08.25 16:28:24.746] INFO    Task 'fit_data': ended at 2026-08-25 13:28:24.746556Z
# [2026.08.25 16:28:24.856] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 13:28:24.856001Z
# [2026.08.25 16:28:25.002] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 13:28:25.002650Z
# [2026.08.25 16:28:25.161] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 13:28:25.161260Z
# [2026.08.25 16:28:25.294] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 13:28:25.294773Z
# [2026.08.25 16:28:26.142] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 13:28:26.127110Z
# [2026.08.25 16:28:26.189] INFO    Task 'plot_population': started at 2026-08-25 13:28:26.189824Z
# [2026.08.25 16:28:26.346] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 13:28:26.346730Z
# [2026.08.25 16:28:26.736] INFO    Task 'plot_population': ended at 2026-08-25 13:28:26.736793Z
# [2026.08.25 16:28:26.798] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:28:26.800] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 13:28:26.784586Z
# [2026.08.25 16:28:26.801] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:28:26.865] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:28:26.865] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 13:28:26.865468Z
# [2026.08.25 16:28:26.865] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring Rabi with drive length: 80.0 ns
# [2026.08.25 16:28:27.057] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:28:27.057] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 13:28:27.057994Z
# [2026.08.25 16:28:27.057] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:28:27.399] INFO    Task 'temporary_qpu': started at 2026-08-25 13:28:27.399364Z
# [2026.08.25 16:28:27.450] INFO    Task 'temporary_qpu': ended at 2026-08-25 13:28:27.450572Z
# [2026.08.25 16:28:27.554] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 16:28:27.554] INFO    13:28:27.554682Z
# [2026.08.25 16:28:27.603] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 13:28:27.603595Z
# [2026.08.25 16:28:27.700] INFO    Task 'create_experiment': started at 2026-08-25 13:28:27.700707Z
# [2026.08.25 16:28:27.829] INFO    Task 'create_experiment': ended at 2026-08-25 13:28:27.829316Z
# [2026.08.25 16:28:27.924] INFO    Task 'compile_experiment': started at 2026-08-25 13:28:27.924888Z
# [2026.08.25 16:28:28.019] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 16:28:28.019] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 16:28:28.019] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 16:28:28.019] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 16:28:28.036] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 16:28:28.040] INFO    Schedule completed. [0.003 s]
# [2026.08.25 16:28:28.062] INFO    Code generation completed for all AWGs. [0.020 s]
# [2026.08.25 16:28:28.064] INFO    Completed compilation step 1 of 1. [0.029 s]
# [2026.08.25 16:28:28.070] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:28:28.070] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 16:28:28.084] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:28:28.084] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.25 16:28:28.084] INFO      SHFQC_DEV12192_sg     0        426          104           3      1056
# [2026.08.25 16:28:28.089] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:28:28.091] INFO      TOTAL                          448          104                  9056
# [2026.08.25 16:28:28.093] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:28:28.116] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 16:28:28.116] INFO    Task 'compile_experiment': ended at 2026-08-25 13:28:28.116542Z
# [2026.08.25 16:28:28.245] INFO    Task 'run_experiment': started at 2026-08-25 13:28:28.245381Z
# [2026.08.25 16:28:28.422] INFO    Starting near-time execution...
# [2026.08.25 16:28:28.550] INFO    Estimated RT execution time: 127.49 s.
# [2026.08.25 16:30:36.120] INFO    Finished near-time execution.
# [2026.08.25 16:30:36.256] INFO    Task 'run_experiment': ended at 2026-08-25 13:30:36.251380Z
# [2026.08.25 16:30:36.358] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:30:36.358] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 16:30:36.358] INFO      13:30:36.358516Z
# [2026.08.25 16:30:36.358] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:30:36.794] INFO    Task 'calculate_qubit_population': started at 2026-08-25 13:30:36.794939Z
# [2026.08.25 16:30:36.941] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 13:30:36.940685Z
# [2026.08.25 16:30:37.036] INFO    Task 'fit_data': started at 2026-08-25 13:30:37.036420Z
# [2026.08.25 16:30:37.182] INFO    Task 'fit_data': ended at 2026-08-25 13:30:37.182547Z
# [2026.08.25 16:30:37.294] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 13:30:37.294936Z
# [2026.08.25 16:30:37.470] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 13:30:37.470181Z
# [2026.08.25 16:30:37.567] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 13:30:37.567017Z
# [2026.08.25 16:30:37.711] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 13:30:37.711442Z
# [2026.08.25 16:30:38.280] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 13:30:38.280626Z
# [2026.08.25 16:30:38.328] INFO    Task 'plot_population': started at 2026-08-25 13:30:38.328795Z
# [2026.08.25 16:30:38.533] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 13:30:38.524799Z
# [2026.08.25 16:30:38.888] INFO    Task 'plot_population': ended at 2026-08-25 13:30:38.888221Z
# [2026.08.25 16:30:38.935] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:30:38.935] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 13:30:38.935447Z
# [2026.08.25 16:30:38.951] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:30:39.000] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:30:39.000] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 13:30:39.000493Z
# [2026.08.25 16:30:39.000] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring Rabi with drive length: 90.0 ns
# [2026.08.25 16:30:39.175] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:30:39.186] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 13:30:39.175735Z
# [2026.08.25 16:30:39.188] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:30:39.546] INFO    Task 'temporary_qpu': started at 2026-08-25 13:30:39.546598Z
# [2026.08.25 16:30:39.594] INFO    Task 'temporary_qpu': ended at 2026-08-25 13:30:39.594643Z
# [2026.08.25 16:30:39.691] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 16:30:39.691] INFO    13:30:39.691369Z
# [2026.08.25 16:30:39.756] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 13:30:39.754846Z
# [2026.08.25 16:30:39.851] INFO    Task 'create_experiment': started at 2026-08-25 13:30:39.851318Z
# [2026.08.25 16:30:40.012] INFO    Task 'create_experiment': ended at 2026-08-25 13:30:40.012794Z
# [2026.08.25 16:30:40.129] INFO    Task 'compile_experiment': started at 2026-08-25 13:30:40.129915Z
# [2026.08.25 16:30:40.254] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 16:30:40.254] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 16:30:40.254] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 16:30:40.254] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 16:30:40.268] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 16:30:40.271] INFO    Schedule completed. [0.002 s]
# [2026.08.25 16:30:40.285] INFO    Code generation completed for all AWGs. [0.015 s]
# [2026.08.25 16:30:40.285] INFO    Completed compilation step 1 of 1. [0.020 s]
# [2026.08.25 16:30:40.301] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:30:40.301] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 16:30:40.301] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:30:40.301] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.25 16:30:40.301] INFO      SHFQC_DEV12192_sg     0        426          104           3      1184
# [2026.08.25 16:30:40.301] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:30:40.301] INFO      TOTAL                          448          104                  9184
# [2026.08.25 16:30:40.301] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:30:40.330] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 16:30:40.335] INFO    Task 'compile_experiment': ended at 2026-08-25 13:30:40.334408Z
# [2026.08.25 16:30:40.495] INFO    Task 'run_experiment': started at 2026-08-25 13:30:40.495141Z
# [2026.08.25 16:30:40.675] INFO    Starting near-time execution...
# [2026.08.25 16:30:40.753] INFO    Estimated RT execution time: 127.49 s.
# [2026.08.25 16:32:48.329] INFO    Finished near-time execution.
# [2026.08.25 16:32:48.423] INFO    Task 'run_experiment': ended at 2026-08-25 13:32:48.423076Z
# [2026.08.25 16:32:48.545] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:32:48.561] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 16:32:48.565] INFO      13:32:48.545710Z
# [2026.08.25 16:32:48.565] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:32:48.714] INFO    Task 'calculate_qubit_population': started at 2026-08-25 13:32:48.714035Z
# [2026.08.25 16:32:48.814] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 13:32:48.814343Z
# [2026.08.25 16:32:48.931] INFO    Task 'fit_data': started at 2026-08-25 13:32:48.931537Z
# [2026.08.25 16:32:49.105] INFO    Task 'fit_data': ended at 2026-08-25 13:32:49.103257Z
# [2026.08.25 16:32:49.218] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 13:32:49.218994Z
# [2026.08.25 16:32:49.402] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 13:32:49.402265Z
# [2026.08.25 16:32:49.515] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 13:32:49.515108Z
# [2026.08.25 16:32:49.676] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 13:32:49.676784Z
# [2026.08.25 16:32:50.099] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 13:32:50.099456Z
# [2026.08.25 16:32:50.150] INFO    Task 'plot_population': started at 2026-08-25 13:32:50.150362Z
# [2026.08.25 16:32:50.341] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 13:32:50.341225Z
# [2026.08.25 16:32:50.716] INFO    Task 'plot_population': ended at 2026-08-25 13:32:50.716482Z
# [2026.08.25 16:32:50.780] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:32:50.780] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 13:32:50.780809Z
# [2026.08.25 16:32:50.788] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:32:50.846] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:32:50.846] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 13:32:50.846330Z
# [2026.08.25 16:32:50.853] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring Rabi with drive length: 100.0 ns
# [2026.08.25 16:32:51.065] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:32:51.067] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 13:32:51.065981Z
# [2026.08.25 16:32:51.070] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:32:51.431] INFO    Task 'temporary_qpu': started at 2026-08-25 13:32:51.431504Z
# [2026.08.25 16:32:51.497] INFO    Task 'temporary_qpu': ended at 2026-08-25 13:32:51.496421Z
# [2026.08.25 16:32:51.612] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 16:32:51.613] INFO    13:32:51.612139Z
# [2026.08.25 16:32:51.668] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 13:32:51.668304Z
# [2026.08.25 16:32:51.819] INFO    Task 'create_experiment': started at 2026-08-25 13:32:51.819542Z
# [2026.08.25 16:32:51.959] INFO    Task 'create_experiment': ended at 2026-08-25 13:32:51.957399Z
# [2026.08.25 16:32:52.096] INFO    Task 'compile_experiment': started at 2026-08-25 13:32:52.093123Z
# [2026.08.25 16:32:52.242] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 16:32:52.242] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 16:32:52.242] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 16:32:52.247] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 16:32:52.249] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 16:32:52.252] INFO    Schedule completed. [0.001 s]
# [2026.08.25 16:32:52.255] INFO    Code generation completed for all AWGs. [0.007 s]
# [2026.08.25 16:32:52.262] INFO    Completed compilation step 1 of 1. [0.012 s]
# [2026.08.25 16:32:52.265] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:32:52.268] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 16:32:52.268] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:32:52.269] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.25 16:32:52.270] INFO      SHFQC_DEV12192_sg     0        426          104           3      1248
# [2026.08.25 16:32:52.270] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:32:52.270] INFO      TOTAL                          448          104                  9248
# [2026.08.25 16:32:52.270] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:32:52.295] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 16:32:52.295] INFO    Task 'compile_experiment': ended at 2026-08-25 13:32:52.295260Z
# [2026.08.25 16:32:52.461] INFO    Task 'run_experiment': started at 2026-08-25 13:32:52.461322Z
# [2026.08.25 16:32:52.620] INFO    Starting near-time execution...
# [2026.08.25 16:32:52.687] INFO    Estimated RT execution time: 127.50 s.
# [2026.08.25 16:35:00.262] INFO    Finished near-time execution.
# [2026.08.25 16:35:00.374] INFO    Task 'run_experiment': ended at 2026-08-25 13:35:00.374875Z
# [2026.08.25 16:35:00.505] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:35:00.505] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 16:35:00.505] INFO      13:35:00.505846Z
# [2026.08.25 16:35:00.505] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:35:00.623] INFO    Task 'calculate_qubit_population': started at 2026-08-25 13:35:00.623251Z
# [2026.08.25 16:35:00.724] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 13:35:00.714961Z
# [2026.08.25 16:35:00.831] INFO    Task 'fit_data': started at 2026-08-25 13:35:00.831338Z
# [2026.08.25 16:35:01.049] INFO    Task 'fit_data': ended at 2026-08-25 13:35:01.049482Z
# [2026.08.25 16:35:01.205] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 13:35:01.204571Z
# [2026.08.25 16:35:01.400] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 13:35:01.398153Z
# [2026.08.25 16:35:01.500] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 13:35:01.500956Z
# [2026.08.25 16:35:01.644] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 13:35:01.644990Z
# [2026.08.25 16:35:02.112] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 13:35:02.112723Z
# [2026.08.25 16:35:02.177] INFO    Task 'plot_population': started at 2026-08-25 13:35:02.177035Z
# [2026.08.25 16:35:02.337] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 13:35:02.337598Z
# [2026.08.25 16:35:02.802] INFO    Task 'plot_population': ended at 2026-08-25 13:35:02.802419Z
# [2026.08.25 16:35:02.883] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:35:02.883] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 13:35:02.883583Z
# [2026.08.25 16:35:02.883] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:35:02.947] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:35:02.947] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 13:35:02.947105Z
# [2026.08.25 16:35:02.947] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring Rabi with drive length: 110.0 ns
# [2026.08.25 16:35:03.156] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:35:03.159] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 13:35:03.156458Z
# [2026.08.25 16:35:03.159] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:35:03.526] INFO    Task 'temporary_qpu': started at 2026-08-25 13:35:03.526914Z
# [2026.08.25 16:35:03.576] INFO    Task 'temporary_qpu': ended at 2026-08-25 13:35:03.576156Z
# [2026.08.25 16:35:03.691] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 16:35:03.691] INFO    13:35:03.691220Z
# [2026.08.25 16:35:03.752] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 13:35:03.752813Z
# [2026.08.25 16:35:03.864] INFO    Task 'create_experiment': started at 2026-08-25 13:35:03.864673Z
# [2026.08.25 16:35:04.026] INFO    Task 'create_experiment': ended at 2026-08-25 13:35:04.026794Z
# [2026.08.25 16:35:04.122] INFO    Task 'compile_experiment': started at 2026-08-25 13:35:04.122926Z
# [2026.08.25 16:35:04.266] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 16:35:04.266] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 16:35:04.270] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 16:35:04.270] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 16:35:04.272] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 16:35:04.279] INFO    Schedule completed. [0.004 s]
# [2026.08.25 16:35:04.293] INFO    Code generation completed for all AWGs. [0.012 s]
# [2026.08.25 16:35:04.295] INFO    Completed compilation step 1 of 1. [0.020 s]
# [2026.08.25 16:35:04.299] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:35:04.299] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 16:35:04.299] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:35:04.299] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.25 16:35:04.299] INFO      SHFQC_DEV12192_sg     0        426          104           3      1312
# [2026.08.25 16:35:04.308] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:35:04.308] INFO      TOTAL                          448          104                  9312
# [2026.08.25 16:35:04.311] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:35:04.346] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 16:35:04.346] INFO    Task 'compile_experiment': ended at 2026-08-25 13:35:04.346533Z
# [2026.08.25 16:35:04.474] INFO    Task 'run_experiment': started at 2026-08-25 13:35:04.474268Z
# [2026.08.25 16:35:04.649] INFO    Starting near-time execution...
# [2026.08.25 16:35:04.715] INFO    Estimated RT execution time: 127.50 s.
# [2026.08.25 16:37:12.303] INFO    Finished near-time execution.
# [2026.08.25 16:37:12.388] INFO    Task 'run_experiment': ended at 2026-08-25 13:37:12.388904Z
# [2026.08.25 16:37:12.500] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:37:12.500] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 16:37:12.500] INFO      13:37:12.500339Z
# [2026.08.25 16:37:12.504] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:37:12.646] INFO    Task 'calculate_qubit_population': started at 2026-08-25 13:37:12.646229Z
# [2026.08.25 16:37:12.758] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 13:37:12.749484Z
# [2026.08.25 16:37:12.837] INFO    Task 'fit_data': started at 2026-08-25 13:37:12.837439Z
# [2026.08.25 16:37:12.982] INFO    Task 'fit_data': ended at 2026-08-25 13:37:12.982689Z
# [2026.08.25 16:37:13.075] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 13:37:13.075954Z
# [2026.08.25 16:37:13.270] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 13:37:13.254949Z
# [2026.08.25 16:37:13.368] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 13:37:13.353391Z
# [2026.08.25 16:37:13.496] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 13:37:13.496120Z
# [2026.08.25 16:37:13.996] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 13:37:13.996532Z
# [2026.08.25 16:37:14.044] INFO    Task 'plot_population': started at 2026-08-25 13:37:14.044049Z
# [2026.08.25 16:37:14.187] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 13:37:14.187571Z
# [2026.08.25 16:37:14.494] INFO    Task 'plot_population': ended at 2026-08-25 13:37:14.494916Z
# [2026.08.25 16:37:14.531] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:37:14.531] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 13:37:14.531183Z
# [2026.08.25 16:37:14.531] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:37:14.557] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:37:14.557] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 13:37:14.557919Z
# [2026.08.25 16:37:14.557] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring Rabi with drive length: 120.0 ns
# [2026.08.25 16:37:14.716] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:37:14.716] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 13:37:14.716608Z
# [2026.08.25 16:37:14.716] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:37:15.054] INFO    Task 'temporary_qpu': started at 2026-08-25 13:37:15.038704Z
# [2026.08.25 16:37:15.103] INFO    Task 'temporary_qpu': ended at 2026-08-25 13:37:15.102447Z
# [2026.08.25 16:37:15.198] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 16:37:15.198] INFO    13:37:15.198886Z
# [2026.08.25 16:37:15.266] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 13:37:15.266063Z
# [2026.08.25 16:37:15.392] INFO    Task 'create_experiment': started at 2026-08-25 13:37:15.392343Z
# [2026.08.25 16:37:15.536] INFO    Task 'create_experiment': ended at 2026-08-25 13:37:15.536146Z
# [2026.08.25 16:37:15.616] INFO    Task 'compile_experiment': started at 2026-08-25 13:37:15.616172Z
# [2026.08.25 16:37:15.713] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 16:37:15.713] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 16:37:15.713] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 16:37:15.729] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 16:37:15.729] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 16:37:15.734] INFO    Schedule completed. [0.005 s]
# [2026.08.25 16:37:15.745] INFO    Code generation completed for all AWGs. [0.015 s]
# [2026.08.25 16:37:15.745] INFO    Completed compilation step 1 of 1. [0.027 s]
# [2026.08.25 16:37:15.762] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:37:15.764] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 16:37:15.764] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:37:15.766] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.25 16:37:15.766] INFO      SHFQC_DEV12192_sg     0        426          104           3      1376
# [2026.08.25 16:37:15.768] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:37:15.768] INFO      TOTAL                          448          104                  9376
# [2026.08.25 16:37:15.770] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:37:15.793] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 16:37:15.793] INFO    Task 'compile_experiment': ended at 2026-08-25 13:37:15.793713Z
# [2026.08.25 16:37:15.937] INFO    Task 'run_experiment': started at 2026-08-25 13:37:15.937682Z
# [2026.08.25 16:37:16.096] INFO    Starting near-time execution...
# [2026.08.25 16:37:16.223] INFO    Estimated RT execution time: 127.50 s.
# [2026.08.25 16:39:23.786] INFO    Finished near-time execution.
# [2026.08.25 16:39:23.882] INFO    Task 'run_experiment': ended at 2026-08-25 13:39:23.882825Z
# [2026.08.25 16:39:23.994] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:39:23.994] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 16:39:23.999] INFO      13:39:23.994993Z
# [2026.08.25 16:39:23.999] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:39:24.123] INFO    Task 'calculate_qubit_population': started at 2026-08-25 13:39:24.123192Z
# [2026.08.25 16:39:24.254] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 13:39:24.254541Z
# [2026.08.25 16:39:24.380] INFO    Task 'fit_data': started at 2026-08-25 13:39:24.380474Z
# [2026.08.25 16:39:24.657] INFO    Task 'fit_data': ended at 2026-08-25 13:39:24.657752Z
# [2026.08.25 16:39:24.834] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 13:39:24.834448Z
# [2026.08.25 16:39:24.977] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 13:39:24.977546Z
# [2026.08.25 16:39:25.074] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 13:39:25.074416Z
# [2026.08.25 16:39:25.268] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 13:39:25.268945Z
# [2026.08.25 16:39:25.644] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 13:39:25.644613Z
# [2026.08.25 16:39:25.702] INFO    Task 'plot_population': started at 2026-08-25 13:39:25.702978Z
# [2026.08.25 16:39:25.903] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 13:39:25.903761Z
# [2026.08.25 16:39:26.312] INFO    Task 'plot_population': ended at 2026-08-25 13:39:26.312619Z
# [2026.08.25 16:39:26.376] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:39:26.392] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 13:39:26.376032Z
# [2026.08.25 16:39:26.394] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:39:26.490] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:39:26.490] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 13:39:26.490647Z
# [2026.08.25 16:39:26.490] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring Rabi with drive length: 130.0 ns
# [2026.08.25 16:39:26.748] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:39:26.748] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 13:39:26.748832Z
# [2026.08.25 16:39:26.748] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:39:27.100] INFO    Task 'temporary_qpu': started at 2026-08-25 13:39:27.100252Z
# [2026.08.25 16:39:27.185] INFO    Task 'temporary_qpu': ended at 2026-08-25 13:39:27.182507Z
# [2026.08.25 16:39:27.308] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 16:39:27.308] INFO    13:39:27.308865Z
# [2026.08.25 16:39:27.356] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 13:39:27.356761Z
# [2026.08.25 16:39:27.454] INFO    Task 'create_experiment': started at 2026-08-25 13:39:27.454309Z
# [2026.08.25 16:39:27.599] INFO    Task 'create_experiment': ended at 2026-08-25 13:39:27.599844Z
# [2026.08.25 16:39:27.709] INFO    Task 'compile_experiment': started at 2026-08-25 13:39:27.709760Z
# [2026.08.25 16:39:27.856] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 16:39:27.856] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 16:39:27.856] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 16:39:27.856] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 16:39:27.856] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 16:39:27.868] INFO    Schedule completed. [0.004 s]
# [2026.08.25 16:39:27.887] INFO    Code generation completed for all AWGs. [0.020 s]
# [2026.08.25 16:39:27.894] INFO    Completed compilation step 1 of 1. [0.029 s]
# [2026.08.25 16:39:27.903] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:39:27.903] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 16:39:27.903] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:39:27.907] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.25 16:39:27.907] INFO      SHFQC_DEV12192_sg     0        426          104           3      1504
# [2026.08.25 16:39:27.910] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:39:27.910] INFO      TOTAL                          448          104                  9504
# ...
# [2026.08.25 16:48:16.671] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 16:48:16.671] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:48:16.675] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.25 16:48:16.676] INFO      SHFQC_DEV12192_sg     0        426          104           3      1824
# [2026.08.25 16:48:16.676] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:48:16.676] INFO      TOTAL                          448          104                  9824
# [2026.08.25 16:48:16.676] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:48:16.709] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 16:48:16.719] INFO    Task 'compile_experiment': ended at 2026-08-25 13:48:16.719480Z
# [2026.08.25 16:48:16.859] INFO    Task 'run_experiment': started at 2026-08-25 13:48:16.859015Z
# [2026.08.25 16:48:16.995] INFO    Starting near-time execution...
# [2026.08.25 16:48:17.099] INFO    Estimated RT execution time: 127.53 s.
# [2026.08.25 16:50:24.689] INFO    Finished near-time execution.
# [2026.08.25 16:50:24.801] INFO    Task 'run_experiment': ended at 2026-08-25 13:50:24.801939Z
# [2026.08.25 16:50:24.913] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:50:24.913] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 16:50:24.913] INFO      13:50:24.913353Z
# [2026.08.25 16:50:24.913] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:50:25.026] INFO    Task 'calculate_qubit_population': started at 2026-08-25 13:50:25.026563Z
# [2026.08.25 16:50:25.121] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 13:50:25.121018Z
# [2026.08.25 16:50:25.217] INFO    Task 'fit_data': started at 2026-08-25 13:50:25.217688Z
# [2026.08.25 16:50:25.364] INFO    Task 'fit_data': ended at 2026-08-25 13:50:25.364901Z
# [2026.08.25 16:50:25.458] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 13:50:25.458942Z
# [2026.08.25 16:50:25.606] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 13:50:25.606381Z
# [2026.08.25 16:50:25.717] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 13:50:25.717992Z
# [2026.08.25 16:50:25.863] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 13:50:25.863494Z
# [2026.08.25 16:50:26.319] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 13:50:26.319389Z
# [2026.08.25 16:50:26.391] INFO    Task 'plot_population': started at 2026-08-25 13:50:26.389837Z
# [2026.08.25 16:50:26.535] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 13:50:26.535735Z
# [2026.08.25 16:50:26.975] INFO    Task 'plot_population': ended at 2026-08-25 13:50:26.975838Z
# [2026.08.25 16:50:27.077] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:50:27.077] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 13:50:27.076221Z
# [2026.08.25 16:50:27.077] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:50:27.163] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:50:27.163] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 13:50:27.163032Z
# [2026.08.25 16:50:27.163] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring Rabi with drive length: 180.0 ns
# [2026.08.25 16:50:27.400] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:50:27.403] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 13:50:27.398568Z
# [2026.08.25 16:50:27.403] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:50:27.683] INFO    Task 'temporary_qpu': started at 2026-08-25 13:50:27.683482Z
# [2026.08.25 16:50:27.737] INFO    Task 'temporary_qpu': ended at 2026-08-25 13:50:27.737182Z
# [2026.08.25 16:50:28.126] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 16:50:28.126] INFO    13:50:28.126017Z
# [2026.08.25 16:50:28.184] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 13:50:28.184412Z
# [2026.08.25 16:50:28.254] INFO    Task 'create_experiment': started at 2026-08-25 13:50:28.254356Z
# [2026.08.25 16:50:28.384] INFO    Task 'create_experiment': ended at 2026-08-25 13:50:28.384787Z
# [2026.08.25 16:50:28.449] INFO    Task 'compile_experiment': started at 2026-08-25 13:50:28.449501Z
# [2026.08.25 16:50:28.512] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 16:50:28.512] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 16:50:28.512] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 16:50:28.512] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 16:50:28.512] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 16:50:28.512] INFO    Schedule completed. [0.001 s]
# [2026.08.25 16:50:28.539] INFO    Code generation completed for all AWGs. [0.014 s]
# [2026.08.25 16:50:28.543] INFO    Completed compilation step 1 of 1. [0.020 s]
# [2026.08.25 16:50:28.552] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:50:28.552] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 16:50:28.552] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:50:28.552] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.25 16:50:28.556] INFO      SHFQC_DEV12192_sg     0        426          104           3      1888
# [2026.08.25 16:50:28.556] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:50:28.556] INFO      TOTAL                          448          104                  9888
# [2026.08.25 16:50:28.556] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:50:28.595] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 16:50:28.602] INFO    Task 'compile_experiment': ended at 2026-08-25 13:50:28.595727Z
# [2026.08.25 16:50:28.703] INFO    Task 'run_experiment': started at 2026-08-25 13:50:28.703811Z
# [2026.08.25 16:50:28.815] INFO    Starting near-time execution...
# [2026.08.25 16:50:28.913] INFO    Estimated RT execution time: 127.53 s.
# [2026.08.25 16:52:36.520] INFO    Finished near-time execution.
# [2026.08.25 16:52:36.597] INFO    Task 'run_experiment': ended at 2026-08-25 13:52:36.585142Z
# [2026.08.25 16:52:36.729] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:52:36.729] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 16:52:36.729] INFO      13:52:36.729733Z
# [2026.08.25 16:52:36.745] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:52:36.876] INFO    Task 'calculate_qubit_population': started at 2026-08-25 13:52:36.876844Z
# [2026.08.25 16:52:37.035] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 13:52:37.035233Z
# [2026.08.25 16:52:37.146] INFO    Task 'fit_data': started at 2026-08-25 13:52:37.146227Z
# [2026.08.25 16:52:37.328] INFO    Task 'fit_data': ended at 2026-08-25 13:52:37.328928Z
# [2026.08.25 16:52:37.500] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 13:52:37.500096Z
# [2026.08.25 16:52:37.691] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 13:52:37.691528Z
# [2026.08.25 16:52:37.837] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 13:52:37.837562Z
# [2026.08.25 16:52:38.014] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 13:52:38.013200Z
# [2026.08.25 16:52:38.795] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 13:52:38.795542Z
# [2026.08.25 16:52:38.866] INFO    Task 'plot_population': started at 2026-08-25 13:52:38.866307Z
# [2026.08.25 16:52:39.077] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 13:52:39.077366Z
# [2026.08.25 16:52:39.528] INFO    Task 'plot_population': ended at 2026-08-25 13:52:39.528353Z
# [2026.08.25 16:52:39.585] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:52:39.585] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 13:52:39.585827Z
# [2026.08.25 16:52:39.585] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:52:39.653] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:52:39.653] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 13:52:39.653812Z
# [2026.08.25 16:52:39.657] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring Rabi with drive length: 190.0 ns
# [2026.08.25 16:52:39.861] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:52:39.861] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-25 13:52:39.861891Z
# [2026.08.25 16:52:39.861] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:52:40.229] INFO    Task 'temporary_qpu': started at 2026-08-25 13:52:40.229716Z
# [2026.08.25 16:52:40.292] INFO    Task 'temporary_qpu': ended at 2026-08-25 13:52:40.281631Z
# [2026.08.25 16:52:40.410] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 16:52:40.425] INFO    13:52:40.410729Z
# [2026.08.25 16:52:40.489] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 13:52:40.489965Z
# [2026.08.25 16:52:40.634] INFO    Task 'create_experiment': started at 2026-08-25 13:52:40.634422Z
# [2026.08.25 16:52:40.800] INFO    Task 'create_experiment': ended at 2026-08-25 13:52:40.800290Z
# [2026.08.25 16:52:40.930] INFO    Task 'compile_experiment': started at 2026-08-25 13:52:40.930912Z
# [2026.08.25 16:52:41.072] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 16:52:41.083] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 16:52:41.084] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 16:52:41.084] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 16:52:41.084] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 16:52:41.089] INFO    Schedule completed. [0.002 s]
# [2026.08.25 16:52:41.099] INFO    Code generation completed for all AWGs. [0.010 s]
# [2026.08.25 16:52:41.101] INFO    Completed compilation step 1 of 1. [0.015 s]
# [2026.08.25 16:52:41.107] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:52:41.107] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 16:52:41.109] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:52:41.111] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.25 16:52:41.111] INFO      SHFQC_DEV12192_sg     0        426          104           3      1952
# [2026.08.25 16:52:41.114] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:52:41.114] INFO      TOTAL                          448          104                  9952
# [2026.08.25 16:52:41.115] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:52:41.131] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 16:52:41.132] INFO    Task 'compile_experiment': ended at 2026-08-25 13:52:41.132678Z
# [2026.08.25 16:52:41.309] INFO    Task 'run_experiment': started at 2026-08-25 13:52:41.309486Z
# [2026.08.25 16:52:41.486] INFO    Starting near-time execution...
# [2026.08.25 16:52:41.567] INFO    Estimated RT execution time: 127.53 s.
# [2026.08.25 16:54:49.162] INFO    Finished near-time execution.
# [2026.08.25 16:54:49.252] INFO    Task 'run_experiment': ended at 2026-08-25 13:54:49.252489Z
# [2026.08.25 16:54:49.412] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:54:49.412] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 16:54:49.412] INFO      13:54:49.409995Z
# [2026.08.25 16:54:49.416] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:54:49.547] INFO    Task 'calculate_qubit_population': started at 2026-08-25 13:54:49.547788Z
# [2026.08.25 16:54:49.677] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 13:54:49.677619Z
# [2026.08.25 16:54:49.794] INFO    Task 'fit_data': started at 2026-08-25 13:54:49.794757Z
# [2026.08.25 16:54:50.000] INFO    Task 'fit_data': ended at 2026-08-25 13:54:50.000928Z
# [2026.08.25 16:54:50.127] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 13:54:50.127171Z
# [2026.08.25 16:54:50.319] ERROR   Could not extract pi- and pi/2-pulse amplitudes for Q2.
# [2026.08.25 16:54:50.319] ERROR   Could not extract pi- and pi/2-pulse amplitudes for Q2.
# [2026.08.25 16:54:50.384] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 13:54:50.384642Z
# [2026.08.25 16:54:50.480] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 13:54:50.480351Z
# [2026.08.25 16:54:50.623] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 13:54:50.623142Z
# [2026.08.25 16:54:51.027] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 13:54:51.027199Z
# [2026.08.25 16:54:51.076] INFO    Task 'plot_population': started at 2026-08-25 13:54:51.076989Z
# [2026.08.25 16:54:51.173] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-25 13:54:51.173022Z
# [2026.08.25 16:54:51.414] INFO    Task 'plot_population': ended at 2026-08-25 13:54:51.414647Z
# [2026.08.25 16:54:51.450] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:54:51.450] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 13:54:51.450936Z
# [2026.08.25 16:54:51.450] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:54:51.493] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:54:51.495] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-25 13:54:51.493836Z
# [2026.08.25 16:54:51.495] INFO     ──────────────────────────────────────────────────────────────────────────────
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[106], line 40
#      36     new_parameter_values = analysis_workflow_result.output["new_parameter_values"]
#      37     if transition == 'ge':
#      38         fitted_pi_amplitude = new_parameter_values[qubit_to_measure.uid]["ge_drive_amplitude_pi"]
#      39     elif transition == 'ef':
# ---> 40         fitted_pi_amplitude = new_parameter_values[qubit_to_measure.uid]["ef_drive_amplitude_pi"]
#      41     fitted_pi_amplitudes.append(fitted_pi_amplitude)
#      42
#      43 fitted_pi_amplitudes = np.array(fitted_pi_amplitudes)
#
# KeyError: 'ef_drive_amplitude_pi'

# %% [markdown]
# #### Fit and Plot Amplitude vs. Drive Length

# %%
from uncertainties import unumpy as unp

x = (1 / drive_lengths).astype('float64')  # proxy for Rabi frequency scaling with drive length
y = unp.nominal_values(fitted_pi_amplitudes).astype('float64')

rabi_freq_calib_popt, rabi_freq_calib_pcov = np.polyfit(x, y, 1, cov=True)
rabi_slope, rabi_intercept = rabi_freq_calib_popt

print('Rabi amplitude-length slope:', rabi_slope)
print('Rabi amplitude-length intercept:', rabi_intercept)

fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(x * 1e-6, y, '.k')
ax.plot(x * 1e-6, np.polyval(rabi_freq_calib_popt, x), '-r')
ax.set_xlabel('1 / drive length (1/us)')
ax.set_ylabel(f'{transition} pi-pulse amplitude (a.u.)')
ax.set_title('Rabi frequency calibration')

figname = f'Rabi_freq_calib_{transition}_'
file_path = get_path_to_file(figname, '.png')
plt.savefig(file_path, dpi=600, format='png', metadata=None,
        bbox_inches=None, pad_inches=0.1,
        facecolor='auto', edgecolor='auto',
        backend=None,
       )

# %% [markdown]
# #### Save Data

# %%
Data_rabi_freq_calib = {
    'drive_lengths': drive_lengths,
    'fitted_pi_amplitudes': unp.nominal_values(fitted_pi_amplitudes).astype('float64'),
    'rabi_slope': rabi_slope,
    'rabi_intercept': rabi_intercept,
}

file_name = f'Rabi_freq_calib_{transition}_'
file_path = get_path_to_file(file_name, '.mat')
savemat(file_path, Data_rabi_freq_calib)

# %% [markdown]
# ### Rabi Error Amplification

# %% [markdown]
# #### x180 pulse

# %% [markdown]
# ##### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ef')

n_avg_exponent = 13

x180_max_repetitions = 16
x180_repetitions = list(range(0, x180_max_repetitions + 1))

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# ##### Run Workflow

# %%
options = amplitude_fine.experiment_workflow_x180.options()
options.count(2**n_avg_exponent)
options.close_figures(False)

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

exp_workflow = amplitude_fine.experiment_workflow_x180(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    repetitions=[x180_repetitions for q in qubits_to_measure],
    options=options,
    temporary_parameters=temporary_parameters
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.25 16:12:27.732] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:12:27.732] INFO      Workflow 'experiment_workflow_x180': execution started at 2026-08-25
# [2026.08.25 16:12:27.732] INFO      13:12:27.726727Z
# [2026.08.25 16:12:27.732] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:12:28.032] INFO    Task 'temporary_qpu': started at 2026-08-25 13:12:28.032756Z
# [2026.08.25 16:12:28.091] INFO    Task 'temporary_qpu': ended at 2026-08-25 13:12:28.091277Z
# [2026.08.25 16:12:28.224] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 16:12:28.225] INFO    13:12:28.224994Z
# [2026.08.25 16:12:28.289] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 13:12:28.289769Z
# [2026.08.25 16:12:28.420] INFO    Task 'create_experiment': started at 2026-08-25 13:12:28.420935Z
# [2026.08.25 16:12:28.616] INFO    Task 'create_experiment': ended at 2026-08-25 13:12:28.616032Z
# [2026.08.25 16:12:28.769] INFO    Task 'compile_experiment': started at 2026-08-25 13:12:28.769326Z
# [2026.08.25 16:12:28.851] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 16:12:28.851] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.25 16:12:28.851] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.25 16:12:28.851] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.25 16:12:28.851] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.25 16:12:28.851] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.25 16:12:28.867] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.25 16:12:28.868] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.25 16:12:28.868] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.25 16:12:28.868] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.25 16:12:28.868] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.25 16:12:28.868] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.25 16:12:28.868] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.25 16:12:28.874] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.25 16:12:28.874] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.25 16:12:28.875] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.25 16:12:28.877] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.25 16:12:28.877] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 16:12:28.877] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 16:12:28.877] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 16:12:28.882] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 16:12:28.884] INFO    Schedule completed. [0.001 s]
# [2026.08.25 16:12:28.885] INFO    Code generation completed for all AWGs. [0.004 s]
# [2026.08.25 16:12:28.885] INFO    Completed compilation step 1 of 1. [0.008 s]
# [2026.08.25 16:12:28.895] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:12:28.901] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 16:12:28.902] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:12:28.902] INFO      SHFQC_DEV12192        0         80            0           1      8000
# [2026.08.25 16:12:28.902] INFO      SHFQC_DEV12192_sg     0        137            5           3      1632
# [2026.08.25 16:12:28.902] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:12:28.902] INFO      TOTAL                          217            5                  9632
# [2026.08.25 16:12:28.902] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:12:28.918] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 16:12:28.918] INFO    Task 'compile_experiment': ended at 2026-08-25 13:12:28.918007Z
# [2026.08.25 16:12:29.045] INFO    Task 'run_experiment': started at 2026-08-25 13:12:29.045568Z
# [2026.08.25 16:12:29.206] INFO    Starting near-time execution...
# [2026.08.25 16:12:29.317] INFO    Estimated RT execution time: 47.15 s.
# [2026.08.25 16:13:16.548] INFO    Finished near-time execution.
# [2026.08.25 16:13:16.676] INFO    Task 'run_experiment': ended at 2026-08-25 13:13:16.674357Z
# [2026.08.25 16:13:16.786] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:13:16.786] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 16:13:16.786] INFO      13:13:16.786278Z
# [2026.08.25 16:13:16.793] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:13:16.901] INFO    Task 'calculate_qubit_population': started at 2026-08-25 13:13:16.901733Z
# [2026.08.25 16:13:17.010] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 13:13:17.010941Z
# [2026.08.25 16:13:17.236] INFO    Task 'fit_data': started at 2026-08-25 13:13:17.236319Z
# [2026.08.25 16:13:17.543] INFO    Task 'fit_data': ended at 2026-08-25 13:13:17.543352Z
# [2026.08.25 16:13:17.674] INFO    Task 'process_fit_results': started at 2026-08-25 13:13:17.674934Z
# [2026.08.25 16:13:17.815] INFO    Task 'process_fit_results': ended at 2026-08-25 13:13:17.815599Z
# [2026.08.25 16:13:17.898] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 13:13:17.898499Z
# [2026.08.25 16:13:18.040] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 13:13:18.040655Z
# [2026.08.25 16:13:18.138] INFO    Task 'xaxis_label': started at 2026-08-25 13:13:18.138235Z
# [2026.08.25 16:13:18.201] INFO    Task 'xaxis_label': ended at 2026-08-25 13:13:18.201391Z
# [2026.08.25 16:13:18.248] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 13:13:18.248405Z
# [2026.08.25 16:13:18.386] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 13:13:18.386229Z
# [2026.08.25 16:13:18.870] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 13:13:18.868607Z
# [2026.08.25 16:13:18.940] INFO    Task 'plot_population': started at 2026-08-25 13:13:18.940203Z
# [2026.08.25 16:13:19.100] INFO    Artifact: 'Amplitude_Fine_Q2' of type 'Figure' logged at 2026-08-25
# [2026.08.25 16:13:19.116] INFO    13:13:19.100840Z
# [2026.08.25 16:13:19.537] INFO    Task 'plot_population': ended at 2026-08-25 13:13:19.537263Z
# [2026.08.25 16:13:19.600] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:13:19.616] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 13:13:19.600843Z
# [2026.08.25 16:13:19.616] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:13:19.665] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:13:19.665] INFO      Workflow 'experiment_workflow_x180': execution ended at 2026-08-25
# [2026.08.25 16:13:19.665] INFO      13:13:19.665506Z
# [2026.08.25 16:13:19.665] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ##### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)

    amplitude_fine.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nDrive amplitude pi ge (error-amplified): ", qubit_to_measure.parameters.ge_drive_amplitude_pi)
    elif transition == 'ef':
        print("\nDrive amplitude pi ef (error-amplified): ", qubit_to_measure.parameters.ef_drive_amplitude_pi)
    
    print('\nUpdated global experiment parameters!\n')
# Out:
# {'new_parameter_values': {'Q2': {'ef_drive_amplitude_pi': 0.2500217645914539+/-0.004743775356932127}},
#  'old_parameter_values': {'Q2': {'ef_drive_amplitude_pi': 0.24940709147532214}}}
#
# Drive amplitude pi ef (error-amplified):  0.2500217645914539
#
# Updated global experiment parameters!

# %% [markdown]
# #### x90 pulse

# %% [markdown]
# ##### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ef')

n_avg_exponent = 13

x90_max_repetitions = 18
x90_repetitions = list(range(1, x90_max_repetitions + 1, 2))

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# ##### Run Workflow

# %%
options = amplitude_fine.experiment_workflow_x90.options()
options.count(2**n_avg_exponent)
options.close_figures(False)

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

exp_workflow = amplitude_fine.experiment_workflow_x90(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    repetitions=[x90_repetitions for q in qubits_to_measure],
    options=options,
    temporary_parameters=temporary_parameters
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.25 16:14:41.675] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:14:41.681] INFO      Workflow 'experiment_workflow_x90': execution started at 2026-08-25
# [2026.08.25 16:14:41.681] INFO      13:14:41.675925Z
# [2026.08.25 16:14:41.683] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:14:41.957] INFO    Task 'temporary_qpu': started at 2026-08-25 13:14:41.957715Z
# [2026.08.25 16:14:42.004] INFO    Task 'temporary_qpu': ended at 2026-08-25 13:14:42.004036Z
# [2026.08.25 16:14:42.116] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 16:14:42.116] INFO    13:14:42.116650Z
# [2026.08.25 16:14:42.183] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 13:14:42.180578Z
# [2026.08.25 16:14:42.310] INFO    Task 'create_experiment': started at 2026-08-25 13:14:42.310879Z
# [2026.08.25 16:14:42.472] INFO    Task 'create_experiment': ended at 2026-08-25 13:14:42.471120Z
# [2026.08.25 16:14:42.603] INFO    Task 'compile_experiment': started at 2026-08-25 13:14:42.599420Z
# [2026.08.25 16:14:42.715] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 16:14:42.715] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.25 16:14:42.715] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.25 16:14:42.715] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.25 16:14:42.729] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.25 16:14:42.731] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.25 16:14:42.731] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.25 16:14:42.731] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.25 16:14:42.731] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.25 16:14:42.731] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.25 16:14:42.731] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 16:14:42.731] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 16:14:42.731] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 16:14:42.731] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 16:14:42.742] INFO    Schedule completed. [0.000 s]
# [2026.08.25 16:14:42.746] INFO    Code generation completed for all AWGs. [0.003 s]
# [2026.08.25 16:14:42.750] INFO    Completed compilation step 1 of 1. [0.007 s]
# [2026.08.25 16:14:42.754] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:14:42.754] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 16:14:42.754] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:14:42.754] INFO      SHFQC_DEV12192        0         48            0           1      8000
# [2026.08.25 16:14:42.754] INFO      SHFQC_DEV12192_sg     0         88            5           3      1632
# [2026.08.25 16:14:42.760] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:14:42.761] INFO      TOTAL                          136            5                  9632
# [2026.08.25 16:14:42.761] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:14:42.768] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 16:14:42.776] INFO    Task 'compile_experiment': ended at 2026-08-25 13:14:42.768957Z
# [2026.08.25 16:14:42.920] INFO    Task 'run_experiment': started at 2026-08-25 13:14:42.920263Z
# [2026.08.25 16:14:43.086] INFO    Starting near-time execution...
# [2026.08.25 16:14:43.164] INFO    Estimated RT execution time: 27.30 s.
# [2026.08.25 16:15:10.529] INFO    Finished near-time execution.
# [2026.08.25 16:15:10.637] INFO    Task 'run_experiment': ended at 2026-08-25 13:15:10.637193Z
# [2026.08.25 16:15:10.756] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:15:10.756] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 16:15:10.756] INFO      13:15:10.756457Z
# [2026.08.25 16:15:10.764] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:15:10.900] INFO    Task 'calculate_qubit_population': started at 2026-08-25 13:15:10.900030Z
# [2026.08.25 16:15:10.982] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 13:15:10.982551Z
# [2026.08.25 16:15:11.061] INFO    Task 'fit_data': started at 2026-08-25 13:15:11.061028Z
# [2026.08.25 16:15:11.189] INFO    Task 'fit_data': ended at 2026-08-25 13:15:11.189797Z
# [2026.08.25 16:15:11.269] INFO    Task 'process_fit_results': started at 2026-08-25 13:15:11.269267Z
# [2026.08.25 16:15:11.356] INFO    Task 'process_fit_results': ended at 2026-08-25 13:15:11.356893Z
# [2026.08.25 16:15:11.397] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 13:15:11.397960Z
# [2026.08.25 16:15:11.509] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 13:15:11.509743Z
# [2026.08.25 16:15:11.586] INFO    Task 'xaxis_label': started at 2026-08-25 13:15:11.586265Z
# [2026.08.25 16:15:11.621] INFO    Task 'xaxis_label': ended at 2026-08-25 13:15:11.621915Z
# [2026.08.25 16:15:11.656] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 13:15:11.656070Z
# [2026.08.25 16:15:11.771] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 13:15:11.771204Z
# [2026.08.25 16:15:12.280] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 13:15:12.280869Z
# [2026.08.25 16:15:12.337] INFO    Task 'plot_population': started at 2026-08-25 13:15:12.337608Z
# [2026.08.25 16:15:12.477] INFO    Artifact: 'Amplitude_Fine_Q2' of type 'Figure' logged at 2026-08-25
# [2026.08.25 16:15:12.477] INFO    13:15:12.477010Z
# [2026.08.25 16:15:12.958] INFO    Task 'plot_population': ended at 2026-08-25 13:15:12.958954Z
# [2026.08.25 16:15:12.990] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:15:13.007] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 13:15:12.990172Z
# [2026.08.25 16:15:13.008] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:15:13.055] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:15:13.055] INFO      Workflow 'experiment_workflow_x90': execution ended at 2026-08-25
# [2026.08.25 16:15:13.062] INFO      13:15:13.055045Z
# [2026.08.25 16:15:13.064] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ##### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)



if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)
    
    amplitude_fine.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nDrive amplitude pi2 ge (error-amplified): ", qubit_to_measure.parameters.ge_drive_amplitude_pi2)
    elif transition == 'ef':
        print("\nDrive amplitude pi2 ef (error-amplified): ", qubit_to_measure.parameters.ef_drive_amplitude_pi2)
    
    print('\nUpdated global experiment parameters!\n')
# Out:
# {'new_parameter_values': {'Q2': {'ef_drive_amplitude_pi2': 0.0009237031489600105+/-7.941138038179512e-05}},
#  'old_parameter_values': {'Q2': {'ef_drive_amplitude_pi2': 0.1195299628236887}}}
#
# Drive amplitude pi2 ef (error-amplified):  0.0009237031489600105
#
# Updated global experiment parameters!

# %% [markdown]
# ### Ramsey

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

detuning = 0.2e6
transition = set_transition('ef')

n_avg_exponent = 13

delay_min = 0
delay_max = 20e-6
n_delay = 51

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = ramsey.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(False) # Plot figures

options.transition(transition)
options.cal_states(transition)

# Note: if neighbouring qubits are physically coupled by a resonator,
# you usually don't want to run Ramsey in parallel on them because
# your result will be skewed by strong residual-ZZ coupling.
# Next-nearest neighbours is typically okay.
# qubits_to_measure = [qubits[0], qubits[2]]
qubits_to_measure = [qubits[0]]

delays = [
    np.linspace(delay_min, delay_max, n_delay)
]
detunings = [
    detuning
]

exp_workflow = ramsey.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    delays=delays,
    detunings=detunings,
    options=options,
    temporary_parameters=temporary_parameters
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.25 16:59:37.152] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:59:37.152] INFO      Workflow 'ramsey': execution started at 2026-08-25 13:59:37.152672Z
# [2026.08.25 16:59:37.152] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:59:37.457] INFO    Task 'temporary_qpu': started at 2026-08-25 13:59:37.457803Z
# [2026.08.25 16:59:37.516] INFO    Task 'temporary_qpu': ended at 2026-08-25 13:59:37.515823Z
# [2026.08.25 16:59:37.601] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 16:59:37.601] INFO    13:59:37.601704Z
# [2026.08.25 16:59:37.650] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 13:59:37.650759Z
# [2026.08.25 16:59:37.748] INFO    Task 'create_experiment': started at 2026-08-25 13:59:37.748975Z
# [2026.08.25 16:59:37.879] INFO    Task 'create_experiment': ended at 2026-08-25 13:59:37.879531Z
# [2026.08.25 16:59:37.974] INFO    Task 'compile_experiment': started at 2026-08-25 13:59:37.974475Z
# [2026.08.25 16:59:38.080] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 16:59:38.082] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 16:59:38.083] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 16:59:38.084] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 16:59:38.084] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 16:59:38.084] INFO    Schedule completed. [0.001 s]
# [2026.08.25 16:59:38.091] INFO    Code generation completed for all AWGs. [0.005 s]
# [2026.08.25 16:59:38.092] INFO    Completed compilation step 1 of 1. [0.007 s]
# [2026.08.25 16:59:38.097] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:59:38.097] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 16:59:38.099] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:59:38.099] INFO      SHFQC_DEV12192        0        216            0           1      8000
# [2026.08.25 16:59:38.099] INFO      SHFQC_DEV12192_sg     0        329           30           4      2048
# [2026.08.25 16:59:38.099] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:59:38.099] INFO      TOTAL                          545           30                 10048
# [2026.08.25 16:59:38.099] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:59:38.142] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 16:59:38.144] INFO    Task 'compile_experiment': ended at 2026-08-25 13:59:38.144797Z
# [2026.08.25 16:59:38.286] INFO    Task 'run_experiment': started at 2026-08-25 13:59:38.286933Z
# [2026.08.25 16:59:38.422] INFO    Starting near-time execution...
# [2026.08.25 16:59:38.500] INFO    Estimated RT execution time: 135.43 s.

# %% [markdown]
# #### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)


if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)

    ramsey.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nge_T2_star: ", qubit_to_measure.parameters.ge_T2_star)
        print("resonance_frequency_ge: ", qubit_to_measure.parameters.resonance_frequency_ge)
    elif transition == 'ef':
        print("\nef_T2_star: ", qubit_to_measure.parameters.ef_T2_star)
        print("resonance_frequency_ef: ", qubit_to_measure.parameters.resonance_frequency_ef)
    
    print('\nUpdated global experiment parameters!\n')

# %% [markdown]
# ### T1 Lifetime

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ef')

n_avg_exponent = 13

delay_min = 0
delay_max = 50e-6
n_delay = 51
log_spacing = True

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = lifetime_measurement.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(False) # Plot figures

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

if log_spacing:
    delays = [log_sweep_help(delay_min, delay_max, n_delay)]
else:
    delays = [np.linspace(delay_min, delay_max, n_delay)]

exp_workflow = lifetime_measurement.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    delays=delays,
    options=options,
    temporary_parameters=temporary_parameters 
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.25 16:57:17.995] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:57:17.995] INFO      Workflow 'lifetime_measurement': execution started at 2026-08-25
# [2026.08.25 16:57:17.995] INFO      13:57:17.995133Z
# [2026.08.25 16:57:17.995] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:57:18.361] INFO    Task 'temporary_qpu': started at 2026-08-25 13:57:18.361068Z
# [2026.08.25 16:57:18.395] INFO    Task 'temporary_qpu': ended at 2026-08-25 13:57:18.395283Z
# [2026.08.25 16:57:18.492] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-25
# [2026.08.25 16:57:18.492] INFO    13:57:18.492341Z
# [2026.08.25 16:57:18.570] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-25 13:57:18.570114Z
# [2026.08.25 16:57:18.679] INFO    Task 'create_experiment': started at 2026-08-25 13:57:18.679650Z
# [2026.08.25 16:57:18.794] INFO    Task 'create_experiment': ended at 2026-08-25 13:57:18.794508Z
# [2026.08.25 16:57:18.893] INFO    Task 'compile_experiment': started at 2026-08-25 13:57:18.893808Z
# [2026.08.25 16:57:18.997] INFO    Starting LabOne Q Compiler run...
# [2026.08.25 16:57:18.997] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.25 16:57:18.997] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.25 16:57:18.997] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.25 16:57:18.997] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.25 16:57:19.014] INFO    Schedule completed. [0.001 s]
# [2026.08.25 16:57:19.014] INFO    Code generation completed for all AWGs. [0.005 s]
# [2026.08.25 16:57:19.014] INFO    Completed compilation step 1 of 1. [0.010 s]
# [2026.08.25 16:57:19.030] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:57:19.030] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.25 16:57:19.030] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:57:19.032] INFO      SHFQC_DEV12192        0        216            0           1      8000
# [2026.08.25 16:57:19.032] INFO      SHFQC_DEV12192_sg     0        223            3           2       832
# [2026.08.25 16:57:19.032] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:57:19.035] INFO      TOTAL                          439            3                  8832
# [2026.08.25 16:57:19.035] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.25 16:57:19.052] INFO    Finished LabOne Q Compiler run.
# [2026.08.25 16:57:19.052] INFO    Task 'compile_experiment': ended at 2026-08-25 13:57:19.052685Z
# [2026.08.25 16:57:19.195] INFO    Task 'run_experiment': started at 2026-08-25 13:57:19.195169Z
# [2026.08.25 16:57:19.361] INFO    Starting near-time execution...
# [2026.08.25 16:57:19.433] INFO    Estimated RT execution time: 134.63 s.
# [2026.08.25 16:59:34.117] INFO    Finished near-time execution.
# [2026.08.25 16:59:34.229] INFO    Task 'run_experiment': ended at 2026-08-25 13:59:34.229321Z
# [2026.08.25 16:59:34.342] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:59:34.342] INFO      Workflow 'analysis_workflow': execution started at 2026-08-25
# [2026.08.25 16:59:34.342] INFO      13:59:34.342687Z
# [2026.08.25 16:59:34.342] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:59:34.488] INFO    Task 'calculate_qubit_population': started at 2026-08-25 13:59:34.488937Z
# [2026.08.25 16:59:34.589] INFO    Task 'calculate_qubit_population': ended at 2026-08-25 13:59:34.584185Z
# [2026.08.25 16:59:34.665] INFO    Task 'fit_data': started at 2026-08-25 13:59:34.665002Z
# [2026.08.25 16:59:34.807] INFO    Task 'fit_data': ended at 2026-08-25 13:59:34.807363Z
# [2026.08.25 16:59:34.904] INFO    Task 'extract_qubit_parameters': started at 2026-08-25 13:59:34.904012Z
# [2026.08.25 16:59:35.051] INFO    Task 'extract_qubit_parameters': ended at 2026-08-25 13:59:35.051297Z
# [2026.08.25 16:59:35.138] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-25 13:59:35.138534Z
# [2026.08.25 16:59:35.292] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-25 13:59:35.292902Z
# [2026.08.25 16:59:35.668] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-25 13:59:35.668902Z
# [2026.08.25 16:59:35.722] INFO    Task 'plot_population': started at 2026-08-25 13:59:35.722902Z
# [2026.08.25 16:59:35.899] INFO    Artifact: 'T1_Q2' of type 'Figure' logged at 2026-08-25 13:59:35.899547Z
# [2026.08.25 16:59:36.155] INFO    Task 'plot_population': ended at 2026-08-25 13:59:36.155762Z
# [2026.08.25 16:59:36.204] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:59:36.204] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-25 13:59:36.204476Z
# [2026.08.25 16:59:36.204] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:59:36.269] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.25 16:59:36.269] INFO      Workflow 'lifetime_measurement': execution ended at 2026-08-25
# [2026.08.25 16:59:36.269] INFO      13:59:36.269443Z
# [2026.08.25 16:59:36.272] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)

    lifetime_measurement.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nge_T1: ", qubit_to_measure.parameters.ge_T1)
    elif transition == 'ef':
        print("\nef_T1: ", qubit_to_measure.parameters.ef_T1)
    
    print('\nUpdated global experiment parameters!\n')
# Out:
# {'new_parameter_values': {'Q2': {'ef_T1': 8.331254743577805e-07+/-2.417160185067394e-06}},
#  'old_parameter_values': {'Q2': {'ef_T1': 0}}}
#
# ef_T1:  8.331254743577805e-07
#
# Updated global experiment parameters!

# %% [markdown]
# ### DRAG Calibration

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ef')

readout_range_out = -30

n_avg_exponent = 13

q_min = -0.1
q_max = 0.15
n_q = 51

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temp_pars.readout_range_out = readout_range_out
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = drag_q_scaling.experiment_workflow.options()
# options.update(True)  # updates the qubit parameter 'ge_drive_pulse["beta"]'
options.count(2**n_avg_exponent)
options.close_figures(False) # Plot figures

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

exp_workflow = drag_q_scaling.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    q_scalings=[np.linspace(q_min, q_max, n_q) for _ in qubits_to_measure],
    options=options,
    temporary_parameters=temporary_parameters,
)
workflow_result = exp_workflow.run()

# %% [markdown]
# #### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)


if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])

    drag_q_scaling.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nge_drive_pulse[beta]: ", qubit_to_measure.parameters.ge_drive_pulse["beta"])
    elif transition == 'ef':
        print("\nef_drive_pulse[beta]: ", qubit_to_measure.parameters.ef_drive_pulse["beta"])
    
    print('\nUpdated global experiment parameters!\n')

# %% [markdown]
# ### Hahn-Echo

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ef')

n_avg_exponent = 13

delay_min = 0
delay_max = 70e-6
n_delay = 71
log_spacing = True

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = echo.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(False)

options.transition(transition)
options.cal_states(transition)

# Note: if neighbouring qubits are physically coupled by a resonator,
# you usually don't want to run Echo in parallel on them because
# your result will be skewed by strong residual-ZZ coupling.
# Next-nearest neighbours is typically okay.
qubits_to_measure = [qubits[0]]

delays = [
    np.linspace(delay_min, delay_max, n_delay)
]

exp_workflow = echo.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    delays=delays,
    options=options,
    temporary_parameters=temporary_parameters
)

workflow_result = exp_workflow.run()

# %% [markdown]
# #### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)

    echo.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nge_T2: ", qubit_to_measure.parameters.ge_T2)
    elif transition == 'ef':
        print("\nef_T2: ", qubit_to_measure.parameters.ef_T2)
    
    print('\nUpdated global experiment parameters!\n')

# %%
qpu.quantum_elements

# %% [markdown]
# # Readout Optimisation

# %% [markdown]
# Optimization of the readout pulse amplitude and of the readout (resonator)
# frequency.
#
# 1. **Readout Amplitude Optimization** — sweep the readout amplitude and run an
#    amplitude-Rabi experiment at each amplitude. The readout amplitude with the
#    smallest relative Rabi-fit errors gives the best signal-to-noise ratio.
# 2. **Dispersive Shift** — resonator spectroscopy with the qubit prepared in
#    g, e (and f). The optimal readout frequency is the frequency of the largest
#    distance between the transmission signals of the different states.
# 3. **Readout Settings Summary** — write the optimized readout parameters into
#    the QPU and save them.

# %% [markdown]
# ## Readout Amplitude Optimisation

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ge')

n_avg_exponent = 12

# readout setting used during the sweep
readout_range_out = -30
readout_range_in = -40
readout_length = 2e-6
readout_integration_length = 2e-6
readout_integration_delay = 80e-9
reset_delay_length = 300e-6

# length and amplitude are taken from readout_length / readout_amplitude
readout_pulse = {
    'function': 'gaussian_square',
    'width': readout_length * 0.95,
}

# readout amplitude sweep
ro_amp_min = 0.0
ro_amp_max = 1.0
n_ro_amp = 11
ro_amp_arr = np.linspace(ro_amp_min, ro_amp_max, n_ro_amp)

# rabi sweep used to benchmark each readout amplitude
drive_range = 5
amp_min = 0
amp_max = 1
n_amp = 21
drive_amplitudes = np.linspace(amp_min, amp_max, n_amp)

qubit_to_measure = qubits[0]

# %% [markdown]
# #### Run Workflow

# %%
options = amplitude_rabi.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.update(False) # never update the qubit parameters during the sweep
options.close_figures(True) # one Rabi figure per readout amplitude

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubit_to_measure]

rabi_ro_sweep_results = []
fit_values_ro_sweep = []
fit_errors_ro_sweep = []
# same order as the old popt/pcov of fit_Rabi
fit_parameter_names = ['frequency', 'phase', 'amplitude', 'offset']

for ro_amp in ro_amp_arr:
    print('Measure at readout amplitude:', round(ro_amp, 5))

    temporary_parameters = {}
    temp_pars = deepcopy(qubits[0].parameters)
    temp_pars.readout_amplitude = round(ro_amp, 5)
    temp_pars.readout_length = readout_length
    temp_pars.readout_pulse = readout_pulse
    temp_pars.readout_integration_length = readout_integration_length
    temp_pars.readout_integration_delay = readout_integration_delay
    temp_pars.readout_range_out = readout_range_out
    temp_pars.readout_range_in = readout_range_in
    temp_pars.reset_delay_length = reset_delay_length
    temp_pars.drive_range = drive_range
    temporary_parameters[qubit_to_measure.uid] = temp_pars

    exp_workflow = amplitude_rabi.experiment_workflow(
        session=session,
        qpu=qpu,
        qubits=[q.uid for q in qubits_to_measure],
        amplitudes=[drive_amplitudes for q in qubits_to_measure],
        options=options,
        temporary_parameters=temporary_parameters,
    )
    workflow_result = exp_workflow.run()
    rabi_ro_sweep_results.append(workflow_result)

    # rotates/projects the raw data and fits a cosine model to the population
    fit_results = get_analysis_task_output(workflow_result, 'fit_data')
    fit_res = fit_results.get(qubit_to_measure.uid)
    if fit_res is None:
        print(f'  Rabi fit failed at readout amplitude {round(ro_amp, 5)}.')
        fit_values_ro_sweep.append([np.nan] * len(fit_parameter_names))
        fit_errors_ro_sweep.append([np.nan] * len(fit_parameter_names))
        continue

    fit_values_ro_sweep.append([fit_res.params[p].value for p in fit_parameter_names])
    fit_errors_ro_sweep.append([fit_res.params[p].stderr for p in fit_parameter_names])

popt_rabi_arr = np.array(fit_values_ro_sweep, dtype=float)
err_arr = np.array(fit_errors_ro_sweep, dtype=float)

# %% [markdown]
# #### Update Parameters

# %%
ll = 1 # skip readout amplitude 0 (no signal)
ul = None
sweep_slice = slice(ll, ul)

# lmfit reports stderr = 0 when the covariance matrix could not be estimated;
# treat those points as invalid instead of "perfect".
err_arr[err_arr == 0] = np.nan
rel_err_arr = np.abs(err_arr / popt_rabi_arr)
fig, ax = plt.subplots(2, 2, sharex=True, figsize=(10, 8))
fig.suptitle(f'Relative errors for Rabi measurements - {qubit_to_measure.uid}', fontsize=16)
fig.supylabel('Relative error (a.u.)')

ax[0, 0].plot(ro_amp_arr[sweep_slice], rel_err_arr[sweep_slice, 0], '.k', label='freq')
ax[1, 0].plot(ro_amp_arr[sweep_slice], rel_err_arr[sweep_slice, 1], '.k', label='phase')
ax[0, 1].plot(ro_amp_arr[sweep_slice], rel_err_arr[sweep_slice, 2], '.k', label='amp')
ax[1, 1].plot(ro_amp_arr[sweep_slice], rel_err_arr[sweep_slice, 3], '.k', label='off')

ax[0, 0].set_title('Frequency')
ax[1, 0].set_title('Phase')
ax[0, 1].set_title('Amplitude')
ax[1, 1].set_title('Offset')

# optimal readout amplitude: smallest mean relative fit error.
mean_rel_err = np.nanmean(rel_err_arr, axis=1)
masked_rel_err = np.full(mean_rel_err.shape, np.nan)
masked_rel_err[sweep_slice] = mean_rel_err[sweep_slice]
optimal_index = int(np.nanargmin(masked_rel_err))
readout_amplitude_opt = float(ro_amp_arr[optimal_index])

for axis in ax.flatten():
    axis.axvline(x=readout_amplitude_opt, ls='-.', color='r', label='optimal')
    axis.legend()

print('Optimal readout amplitude:', round(readout_amplitude_opt, 5))

figname = f'Rabi_optimiz_{readout_range_out}dBm_'
file_path = get_path_to_file(figname, '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %%
# set to a value != None to override the value extracted above.
manual_readout_amplitude = None
if manual_readout_amplitude is not None:
    readout_amplitude_opt = float(manual_readout_amplitude)

if update_global_parameters:
    temporary_parameters[qubit_to_measure.uid].readout_amplitude = readout_amplitude_opt
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)
    print('\nUpdated global experiment parameters!\n')

print('Readout amplitude: ', qubit_to_measure.parameters.readout_amplitude)
print('Readout length: ', qubit_to_measure.parameters.readout_length)
print('Readout pulse: ', qubit_to_measure.parameters.readout_pulse)
print('Readout integration length: ', qubit_to_measure.parameters.readout_integration_length)
print('Readout integration delay: ', qubit_to_measure.parameters.readout_integration_delay)
print('Readout range out / in: ', qubit_to_measure.parameters.readout_range_out,
      '/', qubit_to_measure.parameters.readout_range_in)

# %%
qpu.quantum_elements

# %% [markdown]
# ## Dispersive Shift

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

states = 'gef'

n_avg_exponent = 13

freq_range = 2e6
n_points = 101

# TODO
readout_amplitude = 0.9
readout_range_out = -30
readout_range_in = -35
reset_delay_length = 150e-6

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temp_pars.readout_amplitude = readout_amplitude
temp_pars.readout_range_out = readout_range_out
temp_pars.readout_range_in = readout_range_in
temp_pars.reset_delay_length = reset_delay_length
temporary_parameters[qubits[0].uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = dispersive_shift.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.update(False)  # updated explicitly below
options.close_figures(False)

qubit_to_measure = qubits[0]

frequencies = temporary_parameters[
    qubit_to_measure.uid
].readout_resonator_frequency + np.linspace(-freq_range / 2, freq_range / 2, n_points)

exp_workflow = dispersive_shift.experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=qubit_to_measure.uid,
    frequencies=frequencies,
    states=states,
    options=options,
    temporary_parameters=temporary_parameters,
)
workflow_result = exp_workflow.run()

# %% [markdown]
# #### Analysis Plots

# %%
result = workflow_result.output
res_data = {
    state: result[dsl.handles.result_handle(qubit_to_measure.uid, suffix=state)].data
    for state in states
}
res_freq = frequencies

state_labels = {'g': 'ground', 'e': 'first excited', 'f': 'second excited'}
state_colors = {'g': 'b', 'e': 'r', 'f': 'g'}

fig, ax = plt.subplots(2, 1, sharex=True, figsize=(10, 8))
fig.suptitle('Spectroscopy of readout resonator for the qubit states', fontsize=16)
fig.supxlabel('Readout frequency, GHz')

ax[0].set_title('Amplitude')
ax[1].set_title('Phase')

for state, data in res_data.items():
    ax[0].plot(res_freq * 1e-9, np.abs(data), state_colors[state], label=state_labels[state])
    ax[1].plot(res_freq * 1e-9, np.unwrap(np.angle(data)), state_colors[state],
               label=state_labels[state])

for axis, ylabel in zip(ax, ['Amplitude, a.u.', 'Phase, a.u.']):
    axis.axvline(x=qubit_to_measure.parameters.readout_resonator_frequency * 1e-9,
                 label='current readout')
    axis.set_ylabel(ylabel)
    axis.legend()

file_path = get_path_to_file('Readout_spec_for_g_e', '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

fig_iq, ax_iq = plt.subplots()
ax_iq.set_title('Spectroscopy of readout resonator: IQ plane')
for state, data in res_data.items():
    ax_iq.plot(data.real, data.imag, state_colors[state], label=state_labels[state])
ax_iq.set_xlabel('Real part, a.u.')
ax_iq.set_ylabel('Imaginary part, a.u.')
ax_iq.legend()

file_path = get_path_to_file('Readout_spec_for_g_e_IQ', '.png')
fig_iq.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %%
processed_data_dict = get_analysis_task_output(workflow_result, 'calculate_signal_differences')

fig_dist, ax_dist = plt.subplots(figsize=(10, 5))
ax_dist.set_title('Spectroscopy of readout resonator: state distances')
for state_pair, (distance, max_distance, freq_at_max) in processed_data_dict.items():
    ax_dist.plot(res_freq * 1e-9, distance, label=state_pair)
    print(f'{state_pair}: max distance {max_distance:.4g} at '
          f'{freq_at_max * 1e-9:.6f} GHz')

ax_dist.axvline(x=qubit_to_measure.parameters.readout_resonator_frequency * 1e-9,
                ls='--', label='current readout')
ax_dist.axvline(x=processed_data_dict['sum' if 'sum' in processed_data_dict else
                                      next(iter(processed_data_dict))][2] * 1e-9,
                ls='-.', color='k', label='optimal')
ax_dist.set_xlabel('Readout frequency, GHz')
ax_dist.set_ylabel('Signal distance, a.u.')
ax_dist.legend()

file_path = get_path_to_file('Readout_spec_for_g_e_distance', '.png')
fig_dist.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %% [markdown]
# #### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks['analysis_workflow']
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

readout_resonator_frequency_opt = float(
    qubit_parameters['new_parameter_values'][qubit_to_measure.uid][
        'readout_resonator_frequency'
    ]
)

manual_readout_resonator_frequency = None
if manual_readout_resonator_frequency is not None:
    readout_resonator_frequency_opt = float(manual_readout_resonator_frequency)
    qubit_parameters['new_parameter_values'][qubit_to_measure.uid][
        'readout_resonator_frequency'
    ] = readout_resonator_frequency_opt

print(f'ro freq opt: {readout_resonator_frequency_opt * 1e-9:.6f} GHz')

if update_global_parameters:
    temporary_parameters[qubit_to_measure.uid].readout_resonator_frequency = (
        readout_resonator_frequency_opt
    )
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    dispersive_shift.update_qpu(qpu, qubit_parameters['new_parameter_values'])
    save(qpu, qpu_file_path)
    print('\nUpdated global experiment parameters!\n')

print('Readout resonator frequency: ',
      qubit_to_measure.parameters.readout_resonator_frequency * 1e-9, ' GHz')

# %%
data_gef_spec = {'freq': res_freq}
for state, data in res_data.items():
    data_gef_spec[f'{state}_res'] = data
    data_gef_spec[f'{state}_freq'] = res_freq
data_gef_spec.update(
    {k: v for k, v in attrs.asdict(qubit_to_measure.parameters).items()
     if isinstance(v, (int, float, str))}
)
data_gef_spec['sample_name'] = sample_name
data_gef_spec['qubit_name'] = qubit_name
data_gef_spec['cooldown_start_date'] = cooldown_start_date

file_path = get_path_to_file('ge_spec_readout_', '.mat')
savemat(file_path, data_gef_spec)
print(f'Saved gef readout spectroscopy to: {file_path}')

# %%
readout_opt = {
    'readout_amplitude': qubit_to_measure.parameters.readout_amplitude,
    'readout_length': qubit_to_measure.parameters.readout_length,
    'readout_pulse': qubit_to_measure.parameters.readout_pulse,
    'readout_integration_length': qubit_to_measure.parameters.readout_integration_length,
    'readout_integration_delay': qubit_to_measure.parameters.readout_integration_delay,
    'readout_integration_kernels_type':
        qubit_to_measure.parameters.readout_integration_kernels_type,
    'readout_resonator_frequency': qubit_to_measure.parameters.readout_resonator_frequency,
    'readout_lo_frequency': qubit_to_measure.parameters.readout_lo_frequency,
    'readout_range_out': qubit_to_measure.parameters.readout_range_out,
    'readout_range_in': qubit_to_measure.parameters.readout_range_in,
    'reset_delay_length': qubit_to_measure.parameters.reset_delay_length,
}
pprint(readout_opt)

# %%
qpu.quantum_elements

# %% [markdown]
# # Single Shot 0 and 1 Measurements

# %% [markdown]
# Single-shot (unaveraged) readout of the qubit prepared in g, e (and f).
#
# 1. **One Single Shot Measurement** — acquire the single shots for each prepared
#    state, classify them with a linear discriminant, and quantify the readout
#    with the state distance, the relative shot noise and the correct-state
#    assignment fidelity.
# 2. **Single Shot vs. Drive Pulse Length** — repeat the measurement for a range
#    of pi-pulse lengths (i.e. Rabi frequencies).
# 3. **Single Shot vs. Integration Length and Delay** — repeat the measurement
#    for a range of integration delays and integration lengths at a fixed
#    readout pulse.
# 4. **Single Shot vs. Readout Amplitude and Length** — repeat the measurement
#    for a range of readout amplitudes and readout lengths.
#
# The readout parameters optimized in `# Readout Optimization` are the starting
# point here; the best settings found below are written back into the QPU.

# %% [markdown]
# ## One Single Shot Measurement

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

states = 'gef'

n_avg_exponent = 17

# TODO
# readout settings for the single shots
readout_length = 2e-6
readout_integration_length = 2e-6
readout_amplitude = 0.2
readout_integration_delay = 80e-9
readout_range_out = -30
readout_range_in = -40
# use a long value only if you want to see the thermal population;
# 500e-3 makes 2**17 shots per state extremely slow
reset_delay_length = 300e-6

# length and amplitude come from readout_length / readout_amplitude.
readout_pulse = {
    'function': 'const',
}

qubit_to_measure = qubits[0]

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temp_pars.readout_amplitude = readout_amplitude
temp_pars.readout_length = readout_length
temp_pars.readout_pulse = readout_pulse
temp_pars.readout_integration_length = readout_integration_length
temp_pars.readout_integration_delay = readout_integration_delay
temp_pars.readout_range_out = readout_range_out
temp_pars.readout_range_in = readout_range_in
temp_pars.reset_delay_length = reset_delay_length
temporary_parameters[qubit_to_measure.uid] = temp_pars

print('Readout length:             ', temp_pars.readout_length)
print('Readout integration length: ', temp_pars.readout_integration_length)
print('Readout integration delay:  ', temp_pars.readout_integration_delay)
print('Readout amplitude:          ', temp_pars.readout_amplitude)
print('Reset delay length:         ', temp_pars.reset_delay_length)
print('Readout resonator frequency:', temp_pars.readout_resonator_frequency)
print('Number of shots per state:  ', 2**n_avg_exponent)

# %% [markdown]
# #### Run Workflow

# %%
options = iq_blobs.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(False)
# the analysis classifies the shots with sklearn LinearDiscriminantAnalysis,
# replacing the manual LDA/PCA cells of the old notebook.
options.do_analysis(True)

exp_workflow = iq_blobs.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[qubit_to_measure.uid],
    states=states,
    options=options,
    temporary_parameters=temporary_parameters,
)
workflow_result = exp_workflow.run()

# %% [markdown]
# #### Analysis Plots

# %%
result = workflow_result.output
shots_per_state = collect_shots_from_result(result, qubit_to_measure.uid, states)

# convenience aliases matching the old variable names
zero_data = shots_per_state['g']
one_data = shots_per_state['e']
two_data = shots_per_state.get('f')

shots_arr = np.array([shots_per_state[s] for s in states])
print('Shots array shape (states, shots):', shots_arr.shape)

state_labels = {'g': 'ground', 'e': 'first excited', 'f': 'second excited'}
state_colors = {'g': 'b', 'e': 'r', 'f': 'y'}
state_alphas = {'g': 0.1, 'e': 0.1, 'f': 0.01}

# %%
# plot measurement data on IQ, plus the state means
fig, ax = plt.subplots()
ax.set_title(f'Single shots on the IQ plane - {qubit_to_measure.uid}')
for s in states:
    data = shots_per_state[s]
    ax.plot(data.real, data.imag, '.', color=state_colors[s],
            alpha=state_alphas[s], label=state_labels[s])
for s in states:
    data = shots_per_state[s]
    ax.plot(np.mean(data.real), np.mean(data.imag), 'o',
            mfc=state_colors[s], mec='k')
ax.set_xlabel('Real part, a.u.')
ax.set_ylabel('Imaginary part, a.u.')
ax.legend()

# plt.xlim(-0.1, 0.12); plt.ylim(-0.25, 0.05) - set manually if needed
# ax.set_xlim(-0.1, 0.12)
# ax.set_ylim(-0.25, 0.05)

figname = 'Single_shot_points_'
file_path = get_path_to_file(figname, '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %%
# analize_Single_Shots(SS_results, plot=True)
res_ss = analyze_single_shots(shots_per_state, state_0='g', state_1='e', plot=True)

# assignment matrix / fidelity are new: they come from the iq_blobs analysis
assignment_fidelities = workflow_result.tasks['analysis_workflow'].output
assignment_matrices = get_analysis_task_output(
    workflow_result, 'calculate_assignment_matrices'
)
assignment_fidelity = assignment_fidelities.get(qubit_to_measure.uid)

summarize_single_shot_metrics(res_ss, assignment_fidelity)
pprint({k: v for k, v in res_ss.items()
        if not isinstance(v, np.ndarray) and k != 'figure'})

# %%
# plot the raw (unrotated) distributions
n_bins = 50

fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)
fig.suptitle(f'Single-shot distributions - {qubit_to_measure.uid}')

axs[0].set_title('Real')
axs[1].set_title('Imag')
for s in states:
    data = shots_per_state[s]
    axs[0].hist(data.real, bins=n_bins, alpha=0.5, label=state_labels[s])
    axs[1].hist(data.imag, bins=n_bins, alpha=0.5, label=state_labels[s])
axs[0].legend()
axs[1].legend()

figname = 'Single_shot_hist_'
file_path = get_path_to_file(figname, '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %%
# relative-distance histogram of the projected shots
zero_data_proj = res_ss['shots_0_proj']
one_data_proj = res_ss['shots_1_proj']
r = res_ss['distance']

n_bins = 200

fig, ax = plt.subplots()
ax.set_title(f'Projected single shots - {qubit_to_measure.uid}')
ax.hist(zero_data_proj / r, bins=n_bins, alpha=0.5, label=state_labels['g'])
ax.hist(one_data_proj / r, bins=n_bins, alpha=0.5, label=state_labels['e'])
ax.axvline(1, color='k', ls='--')
ax.axvline(-1, color='k', ls='--')
ax.set_yscale('log')
ax.set_ylabel('N points')
ax.set_xlabel('Relative distance')
ax.legend()

# %%
# single Gaussian fit of the projected state-0 shots
data = zero_data_proj / r

fig, ax = plt.subplots()
n, bins, patches = ax.hist(data, bins=n_bins, alpha=0.5, density=True)

(mu, sigma) = norm.fit(data)

# add a 'best fit' line
y = norm.pdf(bins, mu, sigma)
ax.plot(bins, y, 'r--', linewidth=2)
ax.set_yscale('log')
ax.set_ylabel('Probability density')
ax.set_xlabel('Relative distance')
ax.set_title(f'Gaussian fit state 0: mu = {mu:.4f}, sigma = {sigma:.4f}')
print('mu:', mu, ' sigma:', sigma)

# %%
# bimodal fit of the projected state-1 shots -> residual ground pop.
data = one_data_proj / r

fig, ax = plt.subplots()
y, x, patches = ax.hist(data, bins=n_bins, color='red', alpha=0.25)
x = (x[1:] + x[:-1]) / 2

expected = (-1, .2, 1050, 1, .2, 125)
params, cov = curve_fit(bimodal, x, y, expected)
sigma = np.sqrt(np.diag(cov))
x_fit = np.linspace(x.min(), x.max(), 500)
# plot combined...
ax.plot(x_fit, bimodal(x_fit, *params), color='green', lw=3, label='One+Zero')
# ...and individual Gauss curves
ax.plot(x_fit, gauss(x_fit, *params[:3]), color='red', lw=2, ls='--', label='One')
ax.plot(x_fit, gauss(x_fit, *params[3:]), color='b', lw=2, ls=':', label='Zero')
ax.set_yscale('log')
ax.set_ylabel('N points')
ax.set_xlabel('Relative distance')
ax.set_ylim(1e-1, 5e3)
ax.set_title(f'Bimodal fit state 1 - {qubit_to_measure.uid}')
ax.legend()
print(pd.DataFrame(data={'params': params, 'sigma': sigma},
                   index=bimodal.__code__.co_varnames[1:]))
plt.show()

print('Area ratio:', params[4] * params[5] / (params[1] * params[2]))

# %%
# bimodal fit of the projected state-0 shots -> residual excited pop.
data = zero_data_proj / r

fig, ax = plt.subplots()
y, x, patches = ax.hist(data, bins=n_bins, color='blue', alpha=0.25)
x = (x[1:] + x[:-1]) / 2

expected = (-1.5, 1.0, 250, 1, 1.0, 2025)
params, cov = curve_fit(bimodal, x, y, expected)
sigma = np.sqrt(np.diag(cov))
x_fit = np.linspace(x.min(), x.max(), 500)
# plot combined...
ax.plot(x_fit, bimodal(x_fit, *params), color='green', lw=3, label='One+Zero')
# ...and individual Gauss curves
ax.plot(x_fit, gauss(x_fit, *params[:3]), color='red', lw=2, ls='--', label='One')
ax.plot(x_fit, gauss(x_fit, *params[3:]), color='blue', lw=2, ls=':', label='Zero')
ax.set_yscale('log')
ax.set_ylabel('N points')
ax.set_xlabel('Relative distance')
ax.set_ylim(1e-1, 5e3)
ax.set_title(f'Bimodal fit state 0 - {qubit_to_measure.uid}')
ax.legend()
print(pd.DataFrame(data={'params': params, 'sigma': sigma},
                   index=bimodal.__code__.co_varnames[1:]))
plt.show()

print('Area ratio:', params[1] * params[2] / (params[4] * params[5]))

# %%
# 2D histogram of the shots
n_bins = 50

fig, ax = plt.subplots(tight_layout=True)
ax.set_title(f'Single-shot density - {qubit_to_measure.uid}')
ax.hist2d(zero_data.real, zero_data.imag, n_bins)
ax.hist2d(one_data.real, one_data.imag, n_bins)
ax.set_xlabel('Real part, a.u.')
ax.set_ylabel('Imaginary part, a.u.')

# %%
# the assignment matrix produced by the iq_blobs analysis replaces the manual
# LinearDiscriminantAnalysis / compute_pca cells.
if qubit_to_measure.uid in assignment_matrices:
    print('Correct-state-assignment matrix:')
    print(np.round(assignment_matrices[qubit_to_measure.uid], 4))
    print('Assignment fidelity:', f'{assignment_fidelity * 100:0.2f} %')

# %% [markdown]
# #### Update Parameters

# %%
# Data_SS = {...}; Data_SS.update(qubit_parameters._params);
# savemat(get_path_to_file('Single_shots_all_unsh_', '.mat'), Data_SS)
data_ss = {f'shots_{s}': shots_per_state[s] for s in states}
data_ss['states'] = list(states)
data_ss['shot_index'] = np.arange(shots_arr.shape[-1])
data_ss['n_shots'] = 2**n_avg_exponent
data_ss.update({k: v for k, v in res_ss.items()
                if isinstance(v, (int, float, complex))})
if qubit_to_measure.uid in assignment_matrices:
    data_ss['assignment_matrix'] = assignment_matrices[qubit_to_measure.uid]
    data_ss['assignment_fidelity'] = assignment_fidelity

data_ss.update(
    {k: v for k, v in attrs.asdict(temporary_parameters[qubit_to_measure.uid]).items()
     if isinstance(v, (int, float, str))}
)
data_ss['sample_name'] = sample_name
data_ss['qubit_name'] = qubit_name
data_ss['cooldown_start_date'] = cooldown_start_date

file_path = get_path_to_file('Single_shots_all_unsh_', '.mat')
savemat(file_path, data_ss)
print(f'Saved single shots to: {file_path}')

# %%
if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)
    print('Updated global experiment parameters!\n')

print('Readout amplitude: ', qubit_to_measure.parameters.readout_amplitude)
print('Readout length: ', qubit_to_measure.parameters.readout_length)
print('Readout integration length: ',
      qubit_to_measure.parameters.readout_integration_length)
print('Readout integration delay: ',
      qubit_to_measure.parameters.readout_integration_delay)
print('Reset delay length: ', qubit_to_measure.parameters.reset_delay_length)

# %%
qpu.quantum_elements

# %% [markdown]
# ## Single Shot Measurement for Different Rabi Frequencies

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

n_avg_exponent = 15  # reduce: this is a sweep over 36 pi-pulse lengths

states = 'ge'

drive_length_arr = np.linspace(60e-9, 400e-9, 36)
rabi_freq_arr = 1 / drive_length_arr

ge_drive_pulse = {
    'function': 'gaussian',
    'sigma': 0.25,
}

# The old notebook extrapolated the pi amplitude from a linear
# rabi_slope / rabi_intercept calibration. With the workflow structure the pi
# amplitude for the *current* drive length is a qubit parameter, so scale it
# instead of re-deriving it (or set `ge_drive_amplitude_pi_arr` manually).
rabi_slope = qubit_to_measure.parameters.ge_drive_amplitude_pi * \
    qubit_to_measure.parameters.ge_drive_length
ge_drive_amplitude_pi_arr = np.clip(rabi_slope / drive_length_arr, 0.0, 1.0)

print(pd.DataFrame({
    'ge_drive_length': drive_length_arr,
    'rabi_freq_MHz': rabi_freq_arr * 1e-6,
    'ge_drive_amplitude_pi': ge_drive_amplitude_pi_arr,
}))

qubit_to_measure = qubits[0]

# %% [markdown]
# #### Run Workflow

# %%
options = iq_blobs.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(True)  # one IQ-blob figure per drive length
options.do_analysis(True)

ss_drive_length_sweep_shots = []
ss_drive_length_sweep_metrics = []
ss_drive_length_sweep_fidelities = []

for drive_length, drive_amplitude_pi in zip(drive_length_arr,
                                            ge_drive_amplitude_pi_arr):
    print('Drive length:', round(drive_length * 1e9, 3), 'ns',
          '| pi amplitude:', round(float(drive_amplitude_pi), 5))

    temporary_parameters = {}
    temp_pars = deepcopy(qubit_to_measure.parameters)
    temp_pars.ge_drive_length = float(drive_length)
    temp_pars.ge_drive_amplitude_pi = float(drive_amplitude_pi)
    # temp_pars.ge_drive_pulse = ge_drive_pulse
    temporary_parameters[qubit_to_measure.uid] = temp_pars

    exp_workflow = iq_blobs.experiment_workflow(
        session=session,
        qpu=qpu,
        qubits=[qubit_to_measure.uid],
        states=states,
        options=options,
        temporary_parameters=temporary_parameters,
    )
    workflow_result = exp_workflow.run()

    shots = collect_shots_from_result(
        workflow_result.output, qubit_to_measure.uid, states
    )
    ss_drive_length_sweep_shots.append(np.array([shots[s] for s in states]))

    res = analyze_single_shots(shots, state_0='g', state_1='e', plot=False)
    ss_drive_length_sweep_metrics.append(
        {k: v for k, v in res.items() if isinstance(v, (int, float, complex))}
    )
    ss_drive_length_sweep_fidelities.append(
        workflow_result.tasks['analysis_workflow'].output.get(
            qubit_to_measure.uid, np.nan
        )
    )

ss_drive_length_sweep_arr = np.array(ss_drive_length_sweep_shots)
print('Sweep array shape (drive lengths, states, shots):',
      ss_drive_length_sweep_arr.shape)

# %% [markdown]
# #### Analysis Plots

# %%
rel_std_0_arr = np.array([m['rel_std_0'] for m in ss_drive_length_sweep_metrics])
fidelity_arr = np.array(ss_drive_length_sweep_fidelities, dtype=float)

optimal_index = int(np.nanargmin(rel_std_0_arr))
print('Best drive length:', round(drive_length_arr[optimal_index] * 1e9, 3), 'ns',
      '| Rabi frequency:', round(rabi_freq_arr[optimal_index] * 1e-6, 3), 'MHz',
      '| rel_std_0:', round(float(rel_std_0_arr[optimal_index]), 4))

fig, ax = plt.subplots(2, 1, sharex=True, figsize=(10, 8))
fig.suptitle(f'Single shot vs. Rabi frequency - {qubit_to_measure.uid}', fontsize=16)
fig.supxlabel('Rabi frequency, MHz')

ax[0].plot(rabi_freq_arr * 1e-6, rel_std_0_arr, '.k')
ax[0].set_ylabel('Relative STD state 0')
ax[0].set_yscale('log')

ax[1].plot(rabi_freq_arr * 1e-6, fidelity_arr * 100, '.k')
ax[1].set_ylabel('Assignment fidelity, %')

for axis in ax:
    axis.axvline(x=rabi_freq_arr[optimal_index] * 1e-6, ls='-.', color='r',
                 label='optimal')
    axis.legend()

file_path = get_path_to_file('Single_shots_vs_rabi_freq_', '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %% [markdown]
# #### Update Parameters

# %%
data_ss = {
    'ss_drive_length_sweep_arr': ss_drive_length_sweep_arr,
    'states': list(states),
    'ge_drive_length': drive_length_arr,
    'rabi_freq': rabi_freq_arr,
    'ge_drive_amplitude_pi': ge_drive_amplitude_pi_arr,
    'rel_std_0': rel_std_0_arr,
    'assignment_fidelity': fidelity_arr,
    'n_shots': 2**n_avg_exponent,
    'comment': 'Sweep of the pi-pulse length, array dim [drive_length, state, shot]',
}
data_ss.update(
    {k: v for k, v in attrs.asdict(qubit_to_measure.parameters).items()
     if isinstance(v, (int, float, str))}
)
data_ss['sample_name'] = sample_name
data_ss['qubit_name'] = qubit_name
data_ss['cooldown_start_date'] = cooldown_start_date

file_path = get_path_to_file('Single_shots_0_pi_diff_pipulses_', '.mat')
savemat(file_path, data_ss)
print(f'Saved drive-length sweep to: {file_path}')

# %%
if update_global_parameters:
    temp_pars = deepcopy(qubit_to_measure.parameters)
    temp_pars.ge_drive_length = float(drive_length_arr[optimal_index])
    temp_pars.ge_drive_amplitude_pi = float(ge_drive_amplitude_pi_arr[optimal_index])
    # temp_pars.ge_drive_pulse = ge_drive_pulse
    qubit_to_measure.parameters = temp_pars
    save(qpu, qpu_file_path)
    print('Updated global experiment parameters!\n')

print('ge drive length: ', qubit_to_measure.parameters.ge_drive_length)
print('ge drive amplitude pi: ', qubit_to_measure.parameters.ge_drive_amplitude_pi)

# %%
qpu.quantum_elements

# %% [markdown]
# ## Single Shot Measurement for Different Integration Lengths and Delays

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

n_avg_exponent = 15

states = 'ge'

print('Readout length:            ', qubit_to_measure.parameters.readout_length)
print('Readout integration length:',
      qubit_to_measure.parameters.readout_integration_length)
print('Readout integration delay: ',
      qubit_to_measure.parameters.readout_integration_delay)

# TODO
# Here the readout pulse amplitude and length are fixed and we vary the
# integration delay and integration (weighting) length.
readout_length = qubit_to_measure.parameters.readout_length
readout_integration_delay_arr = np.linspace(60, 100, 5) * 1e-9
readout_integration_length_arr = np.array([readout_length])
# to sweep the integration length as well (old commented-out line
# `ro_len = np.arange(100, 2100 - port_delay_sw[k], 100)*1e-9`):
# readout_integration_length_arr = np.arange(100, 2100, 200) * 1e-9

qubit_to_measure = qubits[0]

# %% [markdown]
# #### Run Workflow

# %%
options = iq_blobs.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(True)
options.do_analysis(False)  # only the projected statistics are needed here

ss_delay_sweep_metrics = []
ss_delay_sweep_shots = []

for integration_delay in readout_integration_delay_arr:
    print('Integration delay:', round(integration_delay * 1e9, 3), 'ns')

    metrics_inner = []
    shots_inner = []

    for integration_length in readout_integration_length_arr:
        print('  Integration length:', round(integration_length * 1e9, 3), 'ns')

        temporary_parameters = {}
        temp_pars = deepcopy(qubit_to_measure.parameters)
        temp_pars.readout_length = readout_length
        temp_pars.readout_integration_delay = float(integration_delay)
        temp_pars.readout_integration_length = float(integration_length)
        temporary_parameters[qubit_to_measure.uid] = temp_pars

        exp_workflow = iq_blobs.experiment_workflow(
            session=session,
            qpu=qpu,
            qubits=[qubit_to_measure.uid],
            states=states,
            options=options,
            temporary_parameters=temporary_parameters,
        )
        workflow_result = exp_workflow.run()

        shots = collect_shots_from_result(
            workflow_result.output, qubit_to_measure.uid, states
        )
        shots_inner.append(np.array([shots[s] for s in states]))

        res = analyze_single_shots(shots, state_0='g', state_1='e', plot=False)
        metrics_inner.append(
            {k: v for k, v in res.items() if isinstance(v, (int, float, complex))}
        )

    ss_delay_sweep_metrics.append(metrics_inner)
    ss_delay_sweep_shots.append(shots_inner)

ss_delay_sweep_arr = np.array(ss_delay_sweep_shots)
print('Sweep array shape (delays, integration lengths, states, shots):',
      ss_delay_sweep_arr.shape)

# %% [markdown]
# #### Analysis Plots

# %%
# min / argmin of Rel_STD_0 over the nested sweep
min_val = []
argmin_val = []

for metrics_inner in ss_delay_sweep_metrics:
    rel_std_0 = np.array([m['rel_std_0'] for m in metrics_inner])
    min_val.append(np.nanmin(rel_std_0))
    argmin_val.append(int(np.nanargmin(rel_std_0)))

optimal_delay_index = int(np.nanargmin(np.array(min_val)))
optimal_length_index = argmin_val[optimal_delay_index]

readout_integration_delay_opt = float(
    readout_integration_delay_arr[optimal_delay_index]
)
readout_integration_length_opt = float(
    readout_integration_length_arr[optimal_length_index]
)

print('Readout length is', readout_length)
print('Minimal relative error value is', np.round(min_val[optimal_delay_index], 3),
      'for delay', np.round(readout_integration_delay_opt * 1e9, 3),
      'ns (index', optimal_delay_index, ') and integration length',
      readout_integration_length_opt, '(index', optimal_length_index, ').')
if 0 < optimal_delay_index < len(readout_integration_delay_arr) - 1:
    print('Optimal integration delay is between',
          np.round(readout_integration_delay_arr[optimal_delay_index - 1] * 1e9, 3),
          'and',
          np.round(readout_integration_delay_arr[optimal_delay_index + 1] * 1e9, 3),
          'ns')

rel_std_0_arr = np.array(
    [[m['rel_std_0'] for m in metrics_inner]
     for metrics_inner in ss_delay_sweep_metrics]
)

fig, ax = plt.subplots(figsize=(10, 5))
ax.set_title(f'Single shot vs. integration delay - {qubit_to_measure.uid}')
for k, integration_length in enumerate(readout_integration_length_arr):
    ax.plot(readout_integration_delay_arr * 1e9, rel_std_0_arr[:, k], '.-',
            label=f'{integration_length * 1e9:.0f} ns')
ax.axvline(x=readout_integration_delay_opt * 1e9, ls='-.', color='r', label='optimal')
ax.set_xlabel('Readout integration delay, ns')
ax.set_ylabel('Relative STD state 0')
ax.set_yscale('log')
ax.legend(title='Integration length')

file_path = get_path_to_file('Single_shots_vs_delay_and_int_len_', '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %% [markdown]
# #### Update Parameters

# %%
# set to a value != None to override the values extracted above.
manual_readout_integration_delay = None
manual_readout_integration_length = None
if manual_readout_integration_delay is not None:
    readout_integration_delay_opt = float(manual_readout_integration_delay)
if manual_readout_integration_length is not None:
    readout_integration_length_opt = float(manual_readout_integration_length)

if update_global_parameters:
    temp_pars = deepcopy(qubit_to_measure.parameters)
    temp_pars.readout_integration_delay = readout_integration_delay_opt
    temp_pars.readout_integration_length = readout_integration_length_opt
    qubit_to_measure.parameters = temp_pars
    save(qpu, qpu_file_path)
    print('Updated global experiment parameters!\n')

print('Readout integration delay: ',
      qubit_to_measure.parameters.readout_integration_delay)
print('Readout integration length: ',
      qubit_to_measure.parameters.readout_integration_length)

# %%
data_ss = {
    'ss_delay_sweep_arr': ss_delay_sweep_arr,
    'states': list(states),
    'readout_integration_delay_sweep': readout_integration_delay_arr,
    'readout_integration_length_sweep': readout_integration_length_arr,
    'readout_length': readout_length,
    'rel_std_0': rel_std_0_arr,
    'n_shots': 2**n_avg_exponent,
    'comment': ('Sweep integration delay and integration length, array dim '
                '[delay, integration_length, state, shot]'),
}
data_ss.update(
    {k: v for k, v in attrs.asdict(qubit_to_measure.parameters).items()
     if isinstance(v, (int, float, str))}
)
data_ss['sample_name'] = sample_name
data_ss['qubit_name'] = qubit_name
data_ss['cooldown_start_date'] = cooldown_start_date

file_path = get_path_to_file('Single_shots_0_pi_sweep_delay_and_ro_len_', '.mat')
savemat(file_path, data_ss)
print(f'Saved delay/integration-length sweep to: {file_path}')

# %%
qpu.quantum_elements

# %% [markdown]
# ## Single Shot Measurement for Different Readout Amplitudes and Lengths

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

n_avg_exponent = 14

states = 'ge'

# TODO
# Sweep power and length of the readout pulse. The integration delay is fixed
# and the integration window is equal to the readout pulse length.
readout_amplitude_arr = np.linspace(0.05, 1, 29)
readout_length_arr = np.linspace(1900, 2000, 10) * 1e-9

readout_integration_delay = qubit_to_measure.parameters.readout_integration_delay

qubit_to_measure = qubits[0]

# %% [markdown]
# #### Run Workflow

# %%
options = iq_blobs.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(True)
options.do_analysis(False)

ss_ro_sweep_metrics = []

for readout_amplitude in readout_amplitude_arr:
    print('Readout amplitude:', round(float(readout_amplitude), 5))

    metrics_inner = []

    for readout_length in readout_length_arr:
        print('  Readout length:', round(readout_length * 1e9, 3), 'ns')

        temporary_parameters = {}
        temp_pars = deepcopy(qubit_to_measure.parameters)
        temp_pars.readout_amplitude = float(readout_amplitude)
        temp_pars.readout_length = float(readout_length)
        # old: readout_weighting_function_i = pulse_library.const(length=ro_len_sw[i])
        temp_pars.readout_integration_length = float(readout_length)
        temp_pars.readout_integration_delay = readout_integration_delay
        temporary_parameters[qubit_to_measure.uid] = temp_pars

        exp_workflow = iq_blobs.experiment_workflow(
            session=session,
            qpu=qpu,
            qubits=[qubit_to_measure.uid],
            states=states,
            options=options,
            temporary_parameters=temporary_parameters,
        )
        workflow_result = exp_workflow.run()

        shots = collect_shots_from_result(
            workflow_result.output, qubit_to_measure.uid, states
        )
        res = analyze_single_shots(shots, state_0='g', state_1='e', plot=False)
        metrics_inner.append(
            {k: v for k, v in res.items() if isinstance(v, (int, float, complex))}
        )

    ss_ro_sweep_metrics.append(metrics_inner)

# %% [markdown]
# #### Analysis Plots

# %%
# min / argmin of Rel_STD_0 and the Rel_STD_0 vs. amplitude plot
rel_std_0_arr = np.array(
    [[m['rel_std_0'] for m in metrics_inner] for metrics_inner in ss_ro_sweep_metrics]
)

optimal_amp_index = int(np.nanargmin(np.nanmin(rel_std_0_arr, axis=1)))
optimal_len_index = int(np.nanargmin(rel_std_0_arr[optimal_amp_index, :]))

readout_amplitude_opt = float(readout_amplitude_arr[optimal_amp_index])
readout_length_opt = float(readout_length_arr[optimal_len_index])

print('Minimal relative error value is',
      np.round(rel_std_0_arr[optimal_amp_index, optimal_len_index], 3),
      'for amplitude', np.round(readout_amplitude_opt, 3),
      '(index', optimal_amp_index, ') and length', readout_length_opt,
      '(index', optimal_len_index, ').')

fig, ax = plt.subplots(figsize=(10, 5))
ax.set_title(f'Single shot vs. readout amplitude - {qubit_to_measure.uid}')
for k, readout_length in enumerate(readout_length_arr):
    ax.plot(readout_amplitude_arr, rel_std_0_arr[:, k], '.-',
            label=f'{readout_length * 1e9:.0f} ns')
ax.axvline(x=readout_amplitude_opt, ls='-.', color='r', label='optimal')
ax.set_xlabel('Readout amplitude, a.u.')
ax.set_ylabel('Relative STD state 0')
ax.set_yscale('log')
ax.legend(title='Readout length', ncol=2)

file_path = get_path_to_file('Single_shots_vs_ro_amp_and_ro_len_', '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.set_title(f'Relative STD state 0 - {qubit_to_measure.uid}')
im = ax.pcolormesh(readout_length_arr * 1e9, readout_amplitude_arr, rel_std_0_arr,
                   shading='nearest')
cb = fig.colorbar(im)
cb.set_label('Relative STD state 0')
ax.plot(readout_length_opt * 1e9, readout_amplitude_opt, 'rx', ms=12, label='optimal')
ax.set_xlabel('Readout length, ns')
ax.set_ylabel('Readout amplitude, a.u.')
ax.legend()

file_path = get_path_to_file('Single_shots_ro_amp_ro_len_map_', '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %% [markdown]
# #### Update Parameters

# %%
# set to a value != None to override the values extracted above.
manual_readout_amplitude = None
manual_readout_length = None
if manual_readout_amplitude is not None:
    readout_amplitude_opt = float(manual_readout_amplitude)
if manual_readout_length is not None:
    readout_length_opt = float(manual_readout_length)

if update_global_parameters:
    temp_pars = deepcopy(qubit_to_measure.parameters)
    temp_pars.readout_amplitude = readout_amplitude_opt
    temp_pars.readout_length = readout_length_opt
    temp_pars.readout_integration_length = readout_length_opt
    qubit_to_measure.parameters = temp_pars
    save(qpu, qpu_file_path)
    print('Updated global experiment parameters!\n')

print('Readout amplitude: ', qubit_to_measure.parameters.readout_amplitude)
print('Readout length: ', qubit_to_measure.parameters.readout_length)
print('Readout integration length: ',
      qubit_to_measure.parameters.readout_integration_length)

# %%
data_ss = {
    'states': list(states),
    'readout_amplitude_sweep': readout_amplitude_arr,
    'readout_length_sweep': readout_length_arr,
    'readout_integration_delay': readout_integration_delay,
    'rel_std_0': rel_std_0_arr,
    'n_shots': 2**n_avg_exponent,
    'comment': ('Sweep readout amplitude and readout length, array dim '
                '[readout_amplitude, readout_length]'),
}
data_ss.update(
    {k: v for k, v in attrs.asdict(qubit_to_measure.parameters).items()
     if isinstance(v, (int, float, str))}
)
data_ss['sample_name'] = sample_name
data_ss['qubit_name'] = qubit_name
data_ss['cooldown_start_date'] = cooldown_start_date

file_path = get_path_to_file('Single_shots_0_pi_sweep_ro_amp_and_ro_len_', '.mat')
savemat(file_path, data_ss)
print(f'Saved readout amplitude/length sweep to: {file_path}')

# %%
readout_opt = {
    'readout_amplitude': qubit_to_measure.parameters.readout_amplitude,
    'readout_length': qubit_to_measure.parameters.readout_length,
    'readout_pulse': qubit_to_measure.parameters.readout_pulse,
    'readout_integration_length': qubit_to_measure.parameters.readout_integration_length,
    'readout_integration_delay': qubit_to_measure.parameters.readout_integration_delay,
    'readout_integration_kernels_type':
        qubit_to_measure.parameters.readout_integration_kernels_type,
    'readout_resonator_frequency': qubit_to_measure.parameters.readout_resonator_frequency,
    'readout_lo_frequency': qubit_to_measure.parameters.readout_lo_frequency,
    'readout_range_out': qubit_to_measure.parameters.readout_range_out,
    'readout_range_in': qubit_to_measure.parameters.readout_range_in,
    'reset_delay_length': qubit_to_measure.parameters.reset_delay_length,
}
pprint(readout_opt)

# %%
qpu.quantum_elements

# %% [markdown]
# # Population Measurements

# %% [markdown]
# Effective-temperature measurements of the qubit.
#
# 1. **Rabi Population Measurements (RPM)** — compare the ef-Rabi amplitude with
#    and without a ge pre-pulse. The ratio of the two oscillation amplitudes
#    gives the residual excited-state population `p_e` and thus the effective
#    temperature. The ef pi-pulse used for the fast (two-point) version is
#    calibrated in `### Setup`.
# 2. **Three Level Population Measurements** — the six-sequence protocol
#    (`x0`, `x1`, `x2`, `y0`, `y1`, `y2`) that yields the nine `A`/`B`/`C`
#    estimators of `p_e/p_g` and the corresponding temperatures `TA1 ... TC3`,
#    including the repeated (statistics) version, the projection-phase
#    optimization and a variant with a ge pre-pulse of swept amplitude.
# 3. **Population Measurements for Different Readout Frequencies** — the same
#    six-sequence protocol repeated for a range of readout resonator
#    frequencies (slow!).
#
# The readout parameters optimized in `# Readout Optimization` and
# `# Single Shot 0 and 1 Measurements` are the starting point here.
#
# `laboneq_applications` has no population experiment, so the experiments and
# workflows are defined in `## Custom Experiment Workflows` below.

# %% [markdown]
# ## Helpers

# %% [markdown]
# #### Additional Imports

# %%
# Needed by the custom population workflows.
from laboneq.workflow.tasks import compile_experiment, run_experiment

from laboneq_applications.core import validation
from laboneq_applications.experiments.options import BaseExperimentOptions
from laboneq_applications.tasks.parameter_updating import (
    temporary_qpu,
    temporary_quantum_elements_from_qpu,
)

from scipy.optimize import fsolve

# %% [markdown]
# #### Fit Helpers

# %%
# Old `lib.helpers.fitting_helper.func_osc` / `fit_Rabi` / `normalize_1d_osc`.DS_Store
def func_osc(x, freq, phase, amp=1, off=0):
    """Old `lib.helpers.fitting_helper.func_osc`, unchanged."""
    return amp * np.cos(freq * x + phase) + off


def fit_rabi_osc(x, y, freq, phase, amp=None, off=None, plot=False, bounds=None):
    """New-structure replacement for the old `fit_Rabi`.

    Same maths (scipy `curve_fit` of `func_osc`), snake_case name. The RPM
    section fits the *raw* magnitude/phase traces, so this stays a manual fit
    instead of the lmfit result of an `analysis_workflow`.
    """
    p0 = [freq, phase]
    if amp is not None:
        p0.append(amp)
        if off is not None:
            p0.append(off)

    kwargs = {} if bounds is None else {'bounds': bounds}
    popt, pcov = curve_fit(func_osc, x, y, p0=p0, **kwargs)

    if plot:
        plt.plot(x, y, '.k')
        plt.plot(x, func_osc(x, *popt), '-r')
        plt.xlabel('Amplitude, a.u.')
        plt.ylabel('Signal, a.u.')
        plt.show()

    return popt, pcov


def normalize_1d_osc(osc, offset=None, norm=None):
    """Old `lib.helpers.fitting_helper.normalize_1d_osc`, unchanged."""
    if offset is None:
        offset = np.mean(osc)
    if norm is None:
        norm = 1 / np.abs(osc.max() - osc.min())

    return 2 * (osc - offset) * norm, offset, norm


def qrpm_dict_from_results(results):
    """New-structure replacement for `get_qrpm_dict_from_list_of_results`.

    Takes a list of `rpm_res` dicts (as built in `#### Analysis Plots` of
    `### Population Measurement`) and flattens them into one dict of arrays,
    with the same keys as the old helper.
    """
    keys = ['I_max', 'I_min', 'Q_max', 'Q_min',
            'mag_max', 'mag_min', 'pha_max', 'pha_min']
    out = {}
    for key in keys:
        for pre_pulse in ['with', 'wo']:
            out[f'{key}_{pre_pulse}'] = np.array(
                [np.mean(res[pre_pulse][key]) for res in results]
            )
    return out

# %% [markdown]
# #### Temperature Helpers

# %%
# Old `lib.helpers.pop_temp_helper_v2`: populations -> pe/pg -> temperature.
# The six population labels of the three-level protocol.
pop_label_list = ['x0', 'x1', 'x2', 'y0', 'y1', 'y2']


def T_calc(C, f_q):
    """Old `T_calc`, unchanged: pe/pg (= C) and f_q in GHz -> temperature in K."""
    h = 6.628e-2
    k = 1.381
    return -(h * f_q / k) / np.log(C)


def A_temp(T, A, f_q, anharm):
    """Old `A_temp`, unchanged. `f_q` and `anharm` in GHz."""
    h = 6.628e-2
    k = 1.381
    f_g2 = 2 * f_q - anharm
    num = 1 - np.exp(-h * f_q / k / T)
    denum = 1 - np.exp(-h * f_g2 / k / T)
    return A - num / denum


def B_temp(T, B, f_q, anharm):
    """Old `B_temp`, unchanged."""
    h = 6.628e-2
    k = 1.381
    f_g2 = 2 * f_q - anharm
    num = np.exp(-h * f_q / k / T) - np.exp(-h * f_g2 / k / T)
    denum = 1 - np.exp(-h * f_q / k / T)
    return B - num / denum


def C_temp(T, C, f_q, anharm):
    """Old `C_temp`, unchanged."""
    h = 6.628e-2
    k = 1.381
    f_g2 = 2 * f_q - anharm
    num = np.exp(-h * f_q / k / T) - np.exp(-h * f_g2 / k / T)
    denum = 1 - np.exp(-h * f_g2 / k / T)
    return C - num / denum


def get_qubit_temperature_parameters(qubit):
    """`f_q` and `anharm` (both in GHz) of the new qubit parameters.

    New-structure replacement for
    `f_q = (lo_settings["qb_lo"] + qubit_parameters["qb_freq"]) * 1e-9` and
    `anharm = qubit_parameters['qb_anharm'] * 1e-9`: both resonance frequencies
    are absolute now, so the anharmonicity is their difference.
    """
    f_q = qubit.parameters.resonance_frequency_ge * 1e-9
    anharm = (
        qubit.parameters.resonance_frequency_ge
        - qubit.parameters.resonance_frequency_ef
    ) * 1e-9
    return f_q, anharm

# %%
def get_ABC(pop_proj):
    """Old `get_ABC`, unchanged: the nine estimators from projected data."""
    x0 = pop_proj['x0']
    x1 = pop_proj['x1']
    x2 = pop_proj['x2']
    y0 = pop_proj['y0']
    y1 = pop_proj['y1']
    y2 = pop_proj['y2']

    result = {}
    result['A1'] = (x0 - x1) / (y0 - y1)
    result['B1'] = (x2 - y2) / (x0 - x1)
    result['C1'] = result['A1'] * result['B1']

    result['A2'] = (y0 - x2) / (x0 - y2)
    result['B2'] = (x1 - y1) / (y0 - x2)
    result['C2'] = result['A2'] * result['B2']

    result['A3'] = (y1 - y2) / (x1 - x2)
    result['B3'] = (x0 - y0) / (y1 - y2)
    result['C3'] = result['A3'] * result['B3']

    return result


def make_projection(pop_full_results, phase):
    """Old `make_projection`, unchanged: rotate and project onto I and Q."""
    res_I = {}
    res_Q = {}
    for k in pop_full_results:
        rot = pop_full_results[k] * np.exp(1j * phase)
        res_I[k] = rot.real
        res_Q[k] = rot.imag

    return res_I, res_Q


def get_temperature(ABC, f_q, anharm=None, three_levels=False):
    """Old `get_temperature`, with `anharm` now optional.

    N.B: with `three_levels=False` the simple low-temperature limit is used and
    `anharm` is ignored (the old notebook called
    `get_temperature(ABC_I, f_q)`, which used to raise a TypeError).
    """
    if three_levels and anharm is None:
        raise ValueError("`anharm` is required when `three_levels=True`.")

    def _pick(val, index):
        """Scalar for this element, whether `val` is a single scalar
        or an array shaped like ABC[k]."""
        arr = np.asarray(val)
        if arr.ndim == 0:
            return arr.item()
        return float(arr[index])

    result = {}
    for k in ABC:
        new_k = 'T' + k
        if k[0] == 'A':
            result[new_k] = T_calc(1 - ABC[k], f_q) * 1e3
            solve_fn = A_temp
        elif k[0] == 'B':
            result[new_k] = T_calc(ABC[k] / (ABC[k] + 1), f_q) * 1e3
            solve_fn = B_temp
        elif k[0] == 'C':
            result[new_k] = T_calc(ABC[k], f_q) * 1e3
            solve_fn = C_temp
        else:
            print('Wrong key in ABC dictionary!')
            continue

        if three_levels:
            for index, x in np.ndenumerate(ABC[k]):
                x0 = float(result[new_k][index]) * 1e-3
                f_q_i = _pick(f_q, index)
                anharm_i = _pick(anharm, index)
                root = fsolve(solve_fn, x0, args=(float(x), f_q_i, anharm_i))
                result[new_k][index] = float(root[0]) * 1e3
                
    return result


def get_stat(data):
    """Old `get_stat`, unchanged: [mean, std, relative error] per key."""
    stat = {}
    for k in data:
        arr = np.asarray(data[k], dtype=float)
        M = np.nanmean(arr)
        V = np.sqrt(np.var(arr, ddof=1))
        stat[k] = np.array([M, V, V / M], dtype=float)
        if stat[k].shape != (3,):
            raise RuntimeError(f"Unexpected stat shape for key {k!r}: "
                               f"{stat[k].shape}, data shape was {arr.shape}")
    return stat


def get_stat_nan(data):
    """Old `get_stat_nan`, unchanged: same as `get_stat` but nan-aware."""
    stat = {}
    for k in data:
        M = np.nanmean(data[k])
        V = np.sqrt(np.nanvar(data[k], ddof=1))
        stat[k] = np.array([M, V, V / M])
    return stat


def make_all_temperatures(pop_full_results, f_q, anharm, phase=0,
                          three_levels=True):
    """Old `make_all_temperatures`, unchanged."""
    proj_I, proj_Q = make_projection(pop_full_results, phase)

    ABC_I = get_ABC(proj_I)
    ABC_Q = get_ABC(proj_Q)

    TABC_I = get_temperature(ABC_I, f_q, anharm, three_levels=three_levels)
    TABC_Q = get_temperature(ABC_Q, f_q, anharm, three_levels=three_levels)
    return TABC_I, TABC_Q

# %%
# Old `get_diff` / `get_axes_and_rotate` / `get_ABC_parallel` / `get_C_from_ABC`:
# the 'parallel' way of processing the data (rotation per difference vector).
def get_diff(pop_proj):
    """Old `get_diff`, unchanged."""
    x0 = pop_proj['x0']
    x1 = pop_proj['x1']
    x2 = pop_proj['x2']
    y0 = pop_proj['y0']
    y1 = pop_proj['y1']
    y2 = pop_proj['y2']
    diff_dict = {}
    # parallel to ge, index 1
    diff_dict['x0x1'] = x0 - x1  # order1, mid
    diff_dict['y0y1'] = y0 - y1  # order1, max
    diff_dict['x2y2'] = x2 - y2  # order0, min

    # parallel to gf, index 2
    diff_dict['y0x2'] = y0 - x2  # order1, mid
    diff_dict['x0y2'] = x0 - y2  # order1, max
    diff_dict['x1y1'] = x1 - y1  # order0, min

    # parallel to ef, index 3
    diff_dict['y1y2'] = y1 - y2  # order1, mid
    diff_dict['x1x2'] = x1 - x2  # order1, max
    diff_dict['x0y0'] = x0 - y0  # order0, min
    return diff_dict


def get_axes_and_rotate(D1, D2, D3):
    """Old `get_axes_and_rotate`, unchanged."""
    Angle1 = np.angle(D1)
    Angle2 = np.angle(D2)
    angle = (Angle1 + Angle2) / 2
    D1_rot = D1 * np.exp(-1j * angle)
    D2_rot = D2 * np.exp(-1j * angle)
    D3_rot = D3 * np.exp(-1j * angle)

    A = D1_rot.real / D2_rot.real
    B = D3_rot.real / D1_rot.real
    C = D3_rot.real / D2_rot.real

    return A, B, C


def get_ABC_parallel(pop_full_results):
    """Old `get_ABC_parallel`, unchanged."""
    diff_dict = get_diff(pop_full_results)

    result = {}
    result['A1'], result['B1'], result['C1'] = get_axes_and_rotate(
        diff_dict['x0x1'], diff_dict['y0y1'], diff_dict['x2y2']
    )
    result['A2'], result['B2'], result['C2'] = get_axes_and_rotate(
        diff_dict['y0x2'], diff_dict['x0y2'], diff_dict['x1y1']
    )
    result['A3'], result['B3'], result['C3'] = get_axes_and_rotate(
        diff_dict['y1y2'], diff_dict['x1x2'], diff_dict['x0y0']
    )
    return result


def get_C_from_ABC(ABC_dict):
    """Old `get_C_from_ABC`, unchanged: every estimator expressed as pe/pg."""
    CCC_dict = {}
    for k in ABC_dict:
        kn = 'C' + k
        if 'A' in k:
            CCC_dict[kn] = 1 - ABC_dict[k]
        elif 'B' in k:
            CCC_dict[kn] = ABC_dict[k] / (1 + ABC_dict[k])
        else:
            CCC_dict[kn] = ABC_dict[k]
    return CCC_dict

# %%
# Old `make_rotation_temperature` / `make_optimal_temperature` /
# `find_optimal_temperature`: projection-phase optimization.
def make_rotation_temperature(data, phase_arr, f_q, anharm, three_levels=True):
    """Old `make_rotation_temperature`, unchanged."""
    STAT_I = {}
    STAT_Q = {}

    for i in range(len(phase_arr)):
        proj_I, proj_Q = make_projection(data, phase_arr[i])

        ABC_I = get_ABC(proj_I)
        ABC_Q = get_ABC(proj_Q)

        TABC_I = get_temperature(ABC_I, f_q, anharm, three_levels=three_levels)
        TABC_Q = get_temperature(ABC_Q, f_q, anharm, three_levels=three_levels)

        stat_TABC_I = get_stat(TABC_I)
        stat_TABC_Q = get_stat(TABC_Q)
        for k in stat_TABC_I:
            if i == 0:
                STAT_I[k] = [stat_TABC_I[k]]
                STAT_Q[k] = [stat_TABC_Q[k]]
            else:
                STAT_I[k].append(stat_TABC_I[k])
                STAT_Q[k].append(stat_TABC_Q[k])

    for k in stat_TABC_I:
        STAT_I[k] = np.array(STAT_I[k])
        STAT_Q[k] = np.array(STAT_Q[k])

    return STAT_I, STAT_Q


def make_optimal_temperature(data, phase_arr, f_q, anharm, skip=(),
                             info_type='rel_err', three_levels=True):
    """Old `make_optimal_temperature`, unchanged."""
    STAT_I, STAT_Q = make_rotation_temperature(
        data, phase_arr, f_q, anharm, three_levels=three_levels
    )

    optimal_method = {'rel_err': 1000, 'phase': 0, 'ph_p': 0,
                      'method': '0', 'axes': '0'}
    it = {'mean': 0, 'error': 1, 'rel_err': 2}[info_type]

    for k in STAT_I:
        if k in skip:
            continue
        rel_Q = np.nanmin(STAT_Q[k][:, it])
        ph_p_Q = np.nanargmin(STAT_Q[k][:, it])
        rel_I = np.nanmin(STAT_I[k][:, it])
        ph_p_I = np.nanargmin(STAT_I[k][:, it])

        if (rel_I or ph_p_Q) < optimal_method['rel_err']:
            optimal_method['method'] = k
            if abs(phase_arr[ph_p_Q]) < abs(phase_arr[ph_p_I]):
                optimal_method['rel_err'] = rel_Q
                optimal_method['phase'] = phase_arr[ph_p_Q]
                optimal_method['ph_p'] = ph_p_Q
                optimal_method['axes'] = 'Q'
            else:
                optimal_method['rel_err'] = rel_I
                optimal_method['phase'] = phase_arr[ph_p_I]
                optimal_method['ph_p'] = ph_p_I
                optimal_method['axes'] = 'I'
    return optimal_method


def find_optimal_temperature(pop_full_results, optimal_method, f_q, anharm,
                             three_levels=True):
    """Old `find_optimal_temperature`, unchanged."""
    proj_I, proj_Q = make_projection(pop_full_results, optimal_method['phase'])

    if optimal_method['axes'] == 'I':
        ABC = get_ABC(proj_I)
    elif optimal_method['axes'] == 'Q':
        ABC = get_ABC(proj_Q)
    else:
        print('Wrong axe in optimal_parameters!')
        return None

    TABC = get_temperature(ABC, f_q, anharm, three_levels=three_levels)
    return TABC[optimal_method['method']]

# %%
# Old `plot_temperatures` / `plot_temp_single` / `plot_stat` /
# `plot_rotation_stat`.
_TEMP_COLOR_CYCLE = ['red', 'orange', 'gold', 'green', 'limegreen', 'cyan',
                     'blue', 'darkviolet', 'magenta']


def plot_temperatures(TABC_I, TABC_Q, skip=(), xlim=None, ylim=None):
    """Old `plot_temperatures`, unchanged (returns the figure now)."""
    fig, ax = plt.subplots(2, 1, sharex=True, figsize=(10, 8))

    ax[0].set_prop_cycle(color=_TEMP_COLOR_CYCLE)
    ax[1].set_prop_cycle(color=_TEMP_COLOR_CYCLE)

    fig.supxlabel('Point number')
    fig.supylabel('Effective temperature, mK')

    ax[0].set_title('I component')
    ax[1].set_title('Q component')

    for k in TABC_I:
        if k in skip:
            continue
        ax[0].plot(TABC_I[k], 'o-', label=k)
    ax[0].legend()

    for k in TABC_Q:
        if k in skip:
            continue
        ax[1].plot(TABC_Q[k], 'o-', label=k)
    ax[1].legend()

    if xlim is not None:
        ax[0].set_xlim(xlim)
        ax[1].set_xlim(xlim)
    if ylim is not None:
        ax[0].set_ylim(ylim)
        ax[1].set_ylim(ylim)

    return fig, ax


def plot_temp_single(TABC, skip=(), xlim=None, ylim=None, xdata=None,
                     xlabel='Point Number'):
    """Old `plot_temp_single`, unchanged."""
    if xdata is not None:
        assert len(xdata) == len(TABC[next(iter(TABC))]), \
            'Provide xdata array of proper length!'
    fig, ax = plt.subplots(1, 1, figsize=(8, 6))

    ax.set_prop_cycle(color=_TEMP_COLOR_CYCLE)

    fig.supxlabel(xlabel)
    fig.supylabel('Effective temperature, mK')

    for k in TABC:
        if k in skip:
            continue
        if xdata is None:
            ax.plot(TABC[k], 'o-', label=k)
        else:
            ax.plot(xdata, TABC[k], 'o-', label=k)
    ax.legend()

    if xlim is not None:
        ax.set_xlim(xlim)
    if ylim is not None:
        ax.set_ylim(ylim)

    return fig, ax


def plot_stat(STAT_I, STAT_Q):
    labels = list(STAT_I.keys())
    
    I_mean = [STAT_I[k][0] for k in labels]
    Q_mean = [STAT_Q[k][0] for k in labels]
    I_err = [STAT_I[k][0] for k in labels]
    Q_err = [STAT_Q[k][0] for k in labels]

    fig, ax = plt.subplots(1, 2, sharex=True, figsize=(10, 8))

    fig.supylabel('Effective temperature, mK')

    ax[0].set_title('I component')
    ax[1].set_title('Q component')

    ax[0].bar(labels, I_mean)
    ax[0].errorbar(labels, I_mean, yerr=I_err, fmt='o', color='r')

    ax[1].bar(labels, Q_mean)
    ax[1].errorbar(labels, Q_mean, yerr=Q_err, fmt='o', color='r')

    return fig, ax


def plot_rotation_stat(phase_arr, STAT_I, STAT_Q, info_type='rel_err'):
    """Old `plot_rotation_stat`, unchanged (3x3 grid of the estimators).

    This also replaces the three hand-written 3x3 plotting cells of the old
    notebook (cells 390-392), which only differed in `info_type`
    ('mean' / 'error' / 'rel_err').
    """
    it, title, ylabel = {
        'mean': (0, 'Mean of effective temperature vs. phase rotation',
                 'Effective temperature, mK'),
        'error': (1, 'Absolute errors for effective temperature vs. phase rotation',
                  'Absolute error'),
        'rel_err': (2, 'Relative errors for effective temperature vs. phase rotation',
                    'Relative error'),
    }[info_type]

    fig, ax = plt.subplots(3, 3, sharex=True, figsize=(10, 8))

    fig.suptitle(title, fontsize=16)
    fig.supylabel(ylabel)
    fig.supxlabel('Phase')

    for row, letter in enumerate(['A', 'B', 'C']):
        for col, index in enumerate(['1', '2', '3']):
            k = f'T{letter}{index}'
            ax[row, col].plot(phase_arr, STAT_I[k][:, it], label='I')
            ax[row, col].plot(phase_arr, STAT_Q[k][:, it], label='Q')
            ax[row, col].set_title(f'{letter}{index}')

    fig.legend(*ax[0, 0].get_legend_handles_labels())

    return fig, ax

# %% [markdown]
# ## Custom Experiment Workflows

# %% [markdown]
# `laboneq_applications` does not provide a population-measurement experiment,
# so the three experiments of this section are defined here in the same way as
# the built-in ones:
#
# - `population` — the six-sequence three-level protocol (old
#   `make_exp_population_full`), optionally with a ge pre-pulse of swept
#   amplitude in front of every sequence (old `make_exp_population_prepulse`).
# - `rabi_population` — the ef-amplitude sweep with and without a ge pre-pulse
#   (old `get_rabi_population_calibration_measurement`).
# - `quick_rabi_population` — only the two extreme points of that sweep, with
#   and without ge pre-pulse (old `get_quick_rabi_population_measurement`).
#
# All three use the qubit parameters (through `temporary_parameters`) and the
# quantum operations of the QPU, so the old `readout_*` dictionaries, signal
# maps and calibration objects are no longer needed.

# %% [markdown]
# #### Three Level Population Experiment

# %%
# Old `make_exp_population_full` / `make_exp_population_prepulse`
# (lib/helpers/meas_helper_mod.py) + `create_exp_population_full`
# (lib/helpers/create_meas_helper.py).

# The six sequences of the three-level protocol, as lists of pi-pulse
# transitions played before the readout:
#   x0: -                 (thermal state)
#   x1: X_ge
#   x2: X_ge, X_ef
#   y0: X_ef
#   y1: X_ef, X_ge
#   y2: X_ef, X_ge, X_ef
POPULATION_SEQUENCES = {
    'x0': (),
    'x1': ('ge',),
    'x2': ('ge', 'ef'),
    'y0': ('ef',),
    'y1': ('ef', 'ge'),
    'y2': ('ef', 'ge', 'ef'),
}


@workflow.workflow_options
class PopulationWorkflowOptions:
    """Options for the population-measurement workflows.

    There is no analysis workflow for these experiments, so only the options of
    the `create_experiment` task (`count`, `averaging_mode`, ...) are relevant.
    """


@workflow.task
@dsl.qubit_experiment
def create_population_experiment(
    qpu,
    qubit,
    prepulse_amplitudes=None,
    options: BaseExperimentOptions | None = None,
):
    """Create the three-level population experiment.

    Arguments:
        qpu: The QPU consisting of the qubits and quantum operations.
        qubit: The qubit to run the experiment on.
        prepulse_amplitudes: If not None, a ge drive pulse with these amplitudes
            is played in front of every sequence and swept in real time
            (old `make_exp_population_prepulse`). If None, the plain
            six-sequence experiment is created (old `make_exp_population_full`).
        options: `BaseExperimentOptions`. The defaults (`AveragingMode.CYCLIC`,
            `AcquisitionType.INTEGRATION`) are what the old experiment used.
    """
    opts = BaseExperimentOptions() if options is None else options
    if prepulse_amplitudes is None:
        qubit = validation.validate_and_convert_single_qubit_sweeps(qubit)
    else:
        qubit, prepulse_amplitudes = (
            validation.validate_and_convert_single_qubit_sweeps(
                qubit, prepulse_amplitudes
            )
        )

    max_measure_section_length = qpu.measure_section_length([qubit])
    qop = qpu.quantum_operations

    def _sequences(prepulse_amplitude=None):
        for label, transitions in POPULATION_SEQUENCES.items():
            with dsl.section(name=f'main_{label}',
                             alignment=SectionAlignment.RIGHT):
                if prepulse_amplitude is not None or transitions:
                    with dsl.section(name=f'drive_{label}',
                                     alignment=SectionAlignment.RIGHT):
                        if prepulse_amplitude is not None:
                            sec = qop.x180(qubit, transition='ge',
                                           amplitude=prepulse_amplitude)
                            sec.alignment = SectionAlignment.RIGHT
                        for transition in transitions:
                            sec = qop.x180(qubit, transition=transition)
                            sec.alignment = SectionAlignment.RIGHT
                with dsl.section(name=f'measure_{label}',
                                 alignment=SectionAlignment.LEFT):
                    sec = qop.measure(
                        qubit,
                        dsl.handles.result_handle(qubit.uid, suffix=label),
                    )
                    sec.length = max_measure_section_length
                    qop.passive_reset(qubit)

    with dsl.acquire_loop_rt(
        count=opts.count,
        averaging_mode=opts.averaging_mode,
        acquisition_type=opts.acquisition_type,
        repetition_mode=opts.repetition_mode,
        repetition_time=opts.repetition_time,
        reset_oscillator_phase=opts.reset_oscillator_phase,
    ):
        if prepulse_amplitudes is None:
            _sequences()
        else:
            with dsl.sweep(
                name=f'prepulse_amplitude_sweep_{qubit.uid}',
                parameter=SweepParameter(
                    f'prepulse_amplitude_{qubit.uid}', prepulse_amplitudes
                ),
            ) as prepulse_amplitude:
                _sequences(prepulse_amplitude)


@workflow.workflow(name='population')
def population_experiment_workflow(
    session,
    qpu,
    qubit,
    prepulse_amplitudes=None,
    temporary_parameters=None,
    options: PopulationWorkflowOptions | None = None,
):
    """The three-level population measurement workflow.

    Replaces the old
    `create_exp_population_full(x180, x180_ef, readout_opt, n_average)` +
    `my_session.compile()` + `my_session.run()` and, with
    `prepulse_amplitudes`, `make_exp_population_prepulse(pulse_sweep, ...)`.
    """
    temp_qpu = temporary_qpu(qpu, temporary_parameters)
    qubit = temporary_quantum_elements_from_qpu(temp_qpu, qubit)
    exp = create_population_experiment(
        temp_qpu,
        qubit,
        prepulse_amplitudes=prepulse_amplitudes,
    )
    compiled_exp = compile_experiment(session, exp)
    result = run_experiment(session, compiled_exp)
    workflow.return_(result)


def collect_population_from_result(result, qubit_uid, labels=pop_label_list):
    """The six population traces of a population workflow result.

    New-structure replacement for
    `results_population_full.get_data('x0_readout')` etc.
    """
    return {
        label: result[dsl.handles.result_handle(qubit_uid, suffix=label)].data
        for label in labels
    }

# %% [markdown]
# #### Rabi Population Experiment

# %%
# Old `get_rabi_population_calibration_measurement`
# (lib/helpers/meas_helper_mod.py).
#   wo:   X_ef(theta), X_ge          -> handle '<uid>/result/wo'
#   with: X_ge, X_ef(theta), X_ge    -> handle '<uid>/result/with'
@workflow.task
@dsl.qubit_experiment
def create_rabi_population_experiment(
    qpu,
    qubit,
    ef_amplitudes,
    options: BaseExperimentOptions | None = None,
):
    """Create the RPM calibration experiment (ef-amplitude sweep).

    Arguments:
        qpu: The QPU consisting of the qubits and quantum operations.
        qubit: The qubit to run the experiment on.
        ef_amplitudes: The ef drive amplitudes to sweep over
            (old `theta_ef_sweep`).
        options: `BaseExperimentOptions`.
    """
    opts = BaseExperimentOptions() if options is None else options
    qubit, ef_amplitudes = validation.validate_and_convert_single_qubit_sweeps(
        qubit, ef_amplitudes
    )

    max_measure_section_length = qpu.measure_section_length([qubit])
    qop = qpu.quantum_operations

    with dsl.acquire_loop_rt(
        count=opts.count,
        averaging_mode=opts.averaging_mode,
        acquisition_type=opts.acquisition_type,
        repetition_mode=opts.repetition_mode,
        repetition_time=opts.repetition_time,
        reset_oscillator_phase=opts.reset_oscillator_phase,
    ):
        with dsl.sweep(
            name=f'ef_amplitude_sweep_{qubit.uid}',
            parameter=SweepParameter(f'ef_amplitude_{qubit.uid}', ef_amplitudes),
        ) as ef_amplitude:
            # without ge pre-pulse
            with dsl.section(name='main_wo', alignment=SectionAlignment.RIGHT):
                with dsl.section(name='drive_wo',
                                 alignment=SectionAlignment.RIGHT):
                    sec = qop.x180(qubit, transition='ef',
                                   amplitude=ef_amplitude)
                    sec.alignment = SectionAlignment.RIGHT
                    sec = qop.x180(qubit, transition='ge')
                    sec.alignment = SectionAlignment.RIGHT
                with dsl.section(name='measure_wo',
                                 alignment=SectionAlignment.LEFT):
                    sec = qop.measure(
                        qubit, dsl.handles.result_handle(qubit.uid, suffix='wo')
                    )
                    sec.length = max_measure_section_length
                    qop.passive_reset(qubit)

            # with ge pre-pulse
            with dsl.section(name='main_with', alignment=SectionAlignment.RIGHT):
                with dsl.section(name='drive_with',
                                 alignment=SectionAlignment.RIGHT):
                    sec = qop.x180(qubit, transition='ge')
                    sec.alignment = SectionAlignment.RIGHT
                    sec = qop.x180(qubit, transition='ef',
                                   amplitude=ef_amplitude)
                    sec.alignment = SectionAlignment.RIGHT
                    sec = qop.x180(qubit, transition='ge')
                    sec.alignment = SectionAlignment.RIGHT
                with dsl.section(name='measure_with',
                                 alignment=SectionAlignment.LEFT):
                    sec = qop.measure(
                        qubit,
                        dsl.handles.result_handle(qubit.uid, suffix='with'),
                    )
                    sec.length = max_measure_section_length
                    qop.passive_reset(qubit)


@workflow.workflow(name='rabi_population')
def rabi_population_experiment_workflow(
    session,
    qpu,
    qubit,
    ef_amplitudes,
    temporary_parameters=None,
    options: PopulationWorkflowOptions | None = None,
):
    """The Rabi-population-measurement calibration workflow."""
    temp_qpu = temporary_qpu(qpu, temporary_parameters)
    qubit = temporary_quantum_elements_from_qpu(temp_qpu, qubit)
    exp = create_rabi_population_experiment(
        temp_qpu,
        qubit,
        ef_amplitudes=ef_amplitudes,
    )
    compiled_exp = compile_experiment(session, exp)
    result = run_experiment(session, compiled_exp)
    workflow.return_(result)

# %% [markdown]
# #### Quick Rabi Population Experiment

# %%
# Old `get_quick_rabi_population_measurement`
# (lib/helpers/meas_helper_mod.py). Only the two extreme points of the
# ef-Rabi are measured, `repetitions` times:
#   wo_min:   X_ef(0),  X_ge                 -> '<uid>/result/wo_min'
#   wo_max:   X_ef(pi), X_ge                 -> '<uid>/result/wo_max'
#   with_min: X_ge,     X_ge                 -> '<uid>/result/with_min'
#   with_max: X_ge, X_ef(pi), X_ge           -> '<uid>/result/with_max'
QUICK_RPM_SEQUENCES = {
    'wo_min': (('ef', 0.0), ('ge', None)),
    'wo_max': (('ef', None), ('ge', None)),
    'with_min': (('ge', None), ('ge', None)),
    'with_max': (('ge', None), ('ef', None), ('ge', None)),
}


@workflow.task
@dsl.qubit_experiment
def create_quick_rabi_population_experiment(
    qpu,
    qubit,
    repetitions=1,
    options: BaseExperimentOptions | None = None,
):
    """Create the quick (two-point) RPM experiment.

    Arguments:
        qpu: The QPU consisting of the qubits and quantum operations.
        qubit: The qubit to run the experiment on.
        repetitions: How many times the four points are repeated
            (old `rep_count` of the `mock_sweep`).
        options: `BaseExperimentOptions`.
    """
    opts = BaseExperimentOptions() if options is None else options
    qubit = validation.validate_and_convert_single_qubit_sweeps(qubit)

    max_measure_section_length = qpu.measure_section_length([qubit])
    qop = qpu.quantum_operations

    with dsl.acquire_loop_rt(
        count=opts.count,
        averaging_mode=opts.averaging_mode,
        acquisition_type=opts.acquisition_type,
        repetition_mode=opts.repetition_mode,
        repetition_time=opts.repetition_time,
        reset_oscillator_phase=opts.reset_oscillator_phase,
    ):
        with dsl.sweep(
            name=f'repetition_sweep_{qubit.uid}',
            parameter=SweepParameter(
                f'repetition_{qubit.uid}', np.arange(repetitions)
            ),
        ):
            for label, pulses in QUICK_RPM_SEQUENCES.items():
                with dsl.section(name=f'main_{label}',
                                 alignment=SectionAlignment.RIGHT):
                    with dsl.section(name=f'drive_{label}',
                                     alignment=SectionAlignment.RIGHT):
                        for transition, amplitude in pulses:
                            sec = qop.x180(qubit, transition=transition,
                                           amplitude=amplitude)
                            sec.alignment = SectionAlignment.RIGHT
                    with dsl.section(name=f'measure_{label}',
                                     alignment=SectionAlignment.LEFT):
                        sec = qop.measure(
                            qubit,
                            dsl.handles.result_handle(qubit.uid, suffix=label),
                        )
                        sec.length = max_measure_section_length
                        qop.passive_reset(qubit)


@workflow.workflow(name='quick_rabi_population')
def quick_rabi_population_experiment_workflow(
    session,
    qpu,
    qubit,
    repetitions=1,
    temporary_parameters=None,
    options: PopulationWorkflowOptions | None = None,
):
    """The quick Rabi-population-measurement workflow."""
    temp_qpu = temporary_qpu(qpu, temporary_parameters)
    qubit = temporary_quantum_elements_from_qpu(temp_qpu, qubit)
    exp = create_quick_rabi_population_experiment(
        temp_qpu,
        qubit,
        repetitions=repetitions,
    )
    compiled_exp = compile_experiment(session, exp)
    result = run_experiment(session, compiled_exp)
    workflow.return_(result)

# %% [markdown]
# ## Rabi Population Measurements (RPM)

# %% [markdown]
# ### Setup

# %% [markdown]
# #### Oscillations Check

# %% [markdown]
# ##### Experiment Parameters

# %%
update_global_parameters = True

n_avg_exponent = 16

# TODO
# range of the ef pulse amplitude scan (old amp_min / amp_max / amp_num)
ef_amp_min = 0
ef_amp_max = 1
n_ef_amp = 51
ef_amplitudes = np.linspace(ef_amp_min, ef_amp_max, n_ef_amp)

# old: detuning_ef = 0; drive_ef_Oscillator_q0.frequency =
#      qubit_parameters["qb_ef_freq"] + detuning_ef
ef_detuning = 0.0

# old: gaussian_pulse_qrpm = pulse_library.gaussian(
#          length=qubit_parameters["qb_ef_len_qrpm"], amplitude=1.0)
# length comes from ef_drive_length, the amplitude is the swept quantity.
ef_drive_pulse = {
    'function': 'gaussian',
    'sigma': 0.25,
}
ef_drive_length = qubits[0].parameters.ef_drive_length

qubit_to_measure = qubits[0]

temporary_parameters = {}
temp_pars = deepcopy(qubit_to_measure.parameters)
temp_pars.ef_drive_pulse = ef_drive_pulse
temp_pars.ef_drive_length = ef_drive_length
temp_pars.resonance_frequency_ef = (
    qubit_to_measure.parameters.resonance_frequency_ef + ef_detuning
)
temporary_parameters[qubit_to_measure.uid] = temp_pars

print('ef drive length:            ', temp_pars.ef_drive_length)
print('ef drive pulse:             ', temp_pars.ef_drive_pulse)
print('ef resonance frequency:     ', temp_pars.resonance_frequency_ef * 1e-9, 'GHz')
print('ge drive amplitude pi:      ', temp_pars.ge_drive_amplitude_pi)
print('Reset delay length:         ', temp_pars.reset_delay_length)
print('Readout amplitude:          ', temp_pars.readout_amplitude)
print('Number of averages:         ', 2**n_avg_exponent)

# %% [markdown]
# ##### Run Workflows

# %%
options = rabi_population_experiment_workflow.options()
options.count(2**n_avg_exponent)

exp_workflow = rabi_population_experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=qubit_to_measure.uid,
    ef_amplitudes=ef_amplitudes,
    options=options,
    temporary_parameters=temporary_parameters,
)
workflow_result = exp_workflow.run()

# %% [markdown]
# ##### Analysis Plots

# %%
result = workflow_result.output

# old: rpm_res[key] = {'amp': my_results.get_axis(f"rpm_{key}")[0], ...}
rpm_res = {}
for pre_pulse in ['with', 'wo']:
    data = result[
        dsl.handles.result_handle(qubit_to_measure.uid, suffix=pre_pulse)
    ].data
    rpm_res[pre_pulse] = {
        'amp': ef_amplitudes,
        'mag': np.abs(data),
        'pha': np.unwrap(np.angle(data)),
    }

# %%
rpm_popt, rpm_pcov = {'with': {}, 'wo': {}}, {'with': {}, 'wo': {}}

freq_estimate = 8

for pre_pulse in ['with', 'wo']:
    rpm_popt[pre_pulse]['mag'], rpm_pcov[pre_pulse]['mag'] = fit_rabi_osc(
        x=rpm_res[pre_pulse]['amp'], y=rpm_res[pre_pulse]['mag'],
        freq=freq_estimate, phase=1.0, amp=1.0, off=0.018, plot=False,
    )
    rpm_popt[pre_pulse]['pha'], rpm_pcov[pre_pulse]['pha'] = fit_rabi_osc(
        x=rpm_res[pre_pulse]['amp'], y=rpm_res[pre_pulse]['pha'],
        freq=freq_estimate, phase=1.0, amp=0.01, off=-0.12, plot=False,
    )

rpm_amp_plot = np.linspace(
    rpm_res['with']['amp'][0], rpm_res['with']['amp'][-1],
    int(rpm_res['with']['amp'].shape[0] * 20),
)

# %%
rpm_fig, rpm_ax = plt.subplots(6, 1, figsize=(10, 18), sharex=True)
rpm_fig.suptitle(f'Rabi population measurement - {qubit_to_measure.uid}')

rpm_ax[0].scatter(rpm_res['with']['amp'], rpm_res['with']['mag'])
rpm_ax[0].set_ylabel('Amplitude with pre-pulse')
rpm_ax[0].plot(rpm_amp_plot, func_osc(rpm_amp_plot, *rpm_popt['with']['mag']),
               color='tab:red', linestyle='dashed')

rpm_ax[1].scatter(rpm_res['wo']['amp'], rpm_res['wo']['mag'])
rpm_ax[1].set_ylabel('Amplitude without pre-pulse')
rpm_ax[1].plot(rpm_amp_plot, func_osc(rpm_amp_plot, *rpm_popt['wo']['mag']),
               color='tab:red', linestyle='dashed')

rpm_ax[2].scatter(rpm_res['with']['amp'], rpm_res['with']['pha'])
rpm_ax[2].set_ylabel('Phase with pre-pulse')
rpm_ax[2].plot(rpm_amp_plot, func_osc(rpm_amp_plot, *rpm_popt['with']['pha']),
               color='tab:red', linestyle='dashed')

rpm_ax[3].scatter(rpm_res['wo']['amp'], rpm_res['wo']['pha'])
rpm_ax[3].set_ylabel('Phase without pre-pulse')
rpm_ax[3].plot(rpm_amp_plot, func_osc(rpm_amp_plot, *rpm_popt['wo']['pha']),
               color='tab:red', linestyle='dashed')

_, offset, norm = normalize_1d_osc(rpm_res['with']['mag'])

rpm_ax[4].scatter(rpm_res['with']['amp'],
                  normalize_1d_osc(rpm_res['with']['mag'])[0],
                  label='with', color='salmon')
rpm_ax[4].plot(rpm_amp_plot,
               normalize_1d_osc(func_osc(rpm_amp_plot, *rpm_popt['with']['mag']),
                                offset, norm)[0],
               color='tab:red', linestyle='dashed')
rpm_ax[4].scatter(rpm_res['wo']['amp'],
                  normalize_1d_osc(rpm_res['wo']['mag'], norm=norm)[0],
                  label='w/o', color='skyblue')
rpm_ax[4].set_ylabel('Amplitude (normalized)')
rpm_ax[4].plot(rpm_amp_plot,
               normalize_1d_osc(func_osc(rpm_amp_plot, *rpm_popt['wo']['mag']),
                                norm=norm)[0],
               color='tab:blue', linestyle='dashed')
rpm_ax[4].legend()

_, offset, norm = normalize_1d_osc(rpm_res['with']['pha'])

rpm_ax[5].scatter(rpm_res['with']['amp'],
                  normalize_1d_osc(rpm_res['with']['pha'])[0],
                  label='with', color='salmon')
rpm_ax[5].plot(rpm_amp_plot,
               normalize_1d_osc(func_osc(rpm_amp_plot, *rpm_popt['with']['pha']),
                                offset, norm)[0],
               color='tab:red', linestyle='dashed')
rpm_ax[5].scatter(rpm_res['wo']['amp'],
                  normalize_1d_osc(rpm_res['wo']['pha'], norm=norm)[0],
                  label='w/o', color='skyblue')
rpm_ax[5].set_ylabel('Phase (normalized)')
rpm_ax[5].plot(rpm_amp_plot,
               normalize_1d_osc(func_osc(rpm_amp_plot, *rpm_popt['wo']['pha']),
                                norm=norm)[0],
               color='tab:blue', linestyle='dashed')
rpm_ax[5].legend()

rpm_ax[-1].set_xlabel('ef-amplitude')

file_path = get_path_to_file('RPM_full_amp_sweep_', '.png')
rpm_fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %% [markdown]
# #### Pi Pulse Check

# %% [markdown]
# ##### Analysis Plots

# %%
# extract min / max pulse amplitudes (old cell 346)
signal_in_mag = True

if signal_in_mag:
    fit_params_with = rpm_popt['with']['mag']
    fit_params_wo = rpm_popt['wo']['mag']
    with_dat = rpm_res['with']['mag']
    wo_dat = rpm_res['wo']['mag']
    ylabel = 'Amplitude'
else:
    fit_params_with = rpm_popt['with']['pha']
    fit_params_wo = rpm_popt['wo']['pha']
    with_dat = rpm_res['with']['pha']
    wo_dat = rpm_res['wo']['pha']
    ylabel = 'Phase'

# alternatives, kept from the old notebook:
# amp_with = fit_params_with[1] / fit_params_with[0]
# amp_wo = fit_params_wo[1] / fit_params_wo[0]
# amp_with = rpm_amp_plot[np.argmax(func_osc(rpm_amp_plot, *fit_params_with))]

amp_with = 0.22
amp_wo = amp_with

amp_avg = (amp_with + amp_wo) / 2

cal_fig, cal_axs = plt.subplots(2, 1, figsize=(10, 7), sharex=True)
cal_fig.suptitle(f'RPM ef pi-pulse calibration - {qubit_to_measure.uid}')

cal_axs[0].scatter(rpm_res['wo']['amp'], with_dat)
cal_axs[0].plot(rpm_amp_plot, func_osc(rpm_amp_plot, *fit_params_with),
                color='tab:red', linestyle='dashed')
cal_axs[0].vlines([amp_with], with_dat.min(), with_dat.max(), color='black',
                  linestyle='dashed', label='with')
cal_axs[0].vlines([amp_avg], with_dat.min(), with_dat.max(), color='tab:green',
                  linestyle='dashed', label='avg')
cal_axs[0].vlines([amp_wo], with_dat.min(), with_dat.max(), color='tab:purple',
                  linestyle='dashed', label='wo')
cal_axs[0].legend()
cal_axs[0].set_ylabel(ylabel)
cal_axs[0].set_title('with ge pre pulse')

cal_axs[1].scatter(rpm_res['wo']['amp'], wo_dat)
cal_axs[1].plot(rpm_amp_plot, func_osc(rpm_amp_plot, *fit_params_wo),
                color='tab:red', linestyle='dashed')
cal_axs[1].vlines([amp_with], wo_dat.min(), wo_dat.max(), color='black',
                  linestyle='dashed', label='with')
cal_axs[1].vlines([amp_avg], wo_dat.min(), wo_dat.max(), color='tab:green',
                  linestyle='dashed', label='avg')
cal_axs[1].vlines([amp_wo], wo_dat.min(), wo_dat.max(), color='tab:purple',
                  linestyle='dashed', label='wo')
cal_axs[1].legend()
cal_axs[1].set_xlabel('ef amplitude')
cal_axs[1].set_ylabel(ylabel)
cal_axs[1].set_title('without ge pre pulse')

file_path = get_path_to_file('RPM_x180_ef_calibration_', '.png')
cal_fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %% [markdown]
# ##### Update Parameters

# %%
# old: x180_ef_rpm = pulse_library.gaussian(
#          uid="x180_ef", length=qubit_parameters["qb_ef_len_qrpm"],
#          amplitude=amp_avg)
#      qubit_parameters["pi_ef_amp_qrpm"] = amp_avg
# set to a value != None to override the value extracted above.
manual_ef_drive_amplitude_pi = None
ef_drive_amplitude_pi_rpm = float(amp_avg)
if manual_ef_drive_amplitude_pi is not None:
    ef_drive_amplitude_pi_rpm = float(manual_ef_drive_amplitude_pi)

temporary_parameters[qubit_to_measure.uid].ef_drive_amplitude_pi = (
    ef_drive_amplitude_pi_rpm
)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(
        temporary_parameters[qubit_to_measure.uid]
    )
    save(qpu, qpu_file_path)
    print('Updated global experiment parameters!\n')

print('RPM ef drive amplitude pi: ', ef_drive_amplitude_pi_rpm)
print('ef drive amplitude pi (QPU): ',
      qubit_to_measure.parameters.ef_drive_amplitude_pi)

# %% [markdown]
# ### Population Measurement

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

n_avg_exponent = 17

# old: rep_count = 1 of the mock_sweep
repetitions = 5

qubit_to_measure = qubits[0]

# the RPM pi-pulse calibrated above; the rest of the RPM parameters
# (ef_drive_pulse / ef_drive_length / resonance_frequency_ef) is unchanged.
temporary_parameters = {}
temp_pars = deepcopy(qubit_to_measure.parameters)
temp_pars.ef_drive_pulse = ef_drive_pulse
temp_pars.ef_drive_length = ef_drive_length
temp_pars.ef_drive_amplitude_pi = ef_drive_amplitude_pi_rpm
temporary_parameters[qubit_to_measure.uid] = temp_pars

print('ef drive amplitude pi: ', temp_pars.ef_drive_amplitude_pi)
print('Number of averages:    ', 2**n_avg_exponent)
print('Repetitions:           ', repetitions)

# %% [markdown]
# #### Run Workflow

# %%
options = quick_rabi_population_experiment_workflow.options()
options.count(2**n_avg_exponent)

exp_workflow = quick_rabi_population_experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=qubit_to_measure.uid,
    repetitions=repetitions,
    options=options,
    temporary_parameters=temporary_parameters,
)
workflow_result = exp_workflow.run()

# %% [markdown]
# #### Analysis Plots

# %%
result = workflow_result.output

# old: rpm_res[key] = {'mag_min': np.abs(my_results.get_data(f"rpm_{key}_min")), ...}
rpm_res = {}
for pre_pulse in ['with', 'wo']:
    data = {
        point: result[
            dsl.handles.result_handle(qubit_to_measure.uid,
                                      suffix=f'{pre_pulse}_{point}')
        ].data
        for point in ['min', 'max']
    }
    rpm_res[pre_pulse] = {
        'mag_min': np.abs(data['min']),
        'pha_min': np.angle(data['min']),
        'mag_max': np.abs(data['max']),
        'pha_max': np.angle(data['max']),
        'I_max': np.real(data['max']),
        'Q_max': np.imag(data['max']),
        'I_min': np.real(data['min']),
        'Q_min': np.imag(data['min']),
    }

qrpm_dict = qrpm_dict_from_results([rpm_res])

# %%
quick_rpm_fig_iq, quick_rpm_axs_iq = plt.subplots(2, 1, figsize=(10, 12))

quick_rpm_axs_iq[0].scatter(rpm_res['with']['I_max'], rpm_res['with']['Q_max'])
quick_rpm_axs_iq[0].scatter(rpm_res['with']['I_min'], rpm_res['with']['Q_min'])
quick_rpm_axs_iq[0].set_xlabel('I')
quick_rpm_axs_iq[0].set_ylabel('Q')
quick_rpm_axs_iq[0].set_title('Quick RPM with ge pre-pulse')

quick_rpm_axs_iq[1].scatter(rpm_res['wo']['I_max'], rpm_res['wo']['Q_max'])
quick_rpm_axs_iq[1].scatter(rpm_res['wo']['I_min'], rpm_res['wo']['Q_min'])
quick_rpm_axs_iq[1].set_xlabel('I')
quick_rpm_axs_iq[1].set_ylabel('Q')
quick_rpm_axs_iq[1].set_title('Quick RPM without ge pre-pulse')

file_path = get_path_to_file('Quick_RPM_IQ_', '.png')
quick_rpm_fig_iq.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %%
quick_rpm_fig, quick_rpm_axs = plt.subplots(4, 1, figsize=(10, 12), sharex=True)
quick_rpm_fig.suptitle(f'Quick RPM - {qubit_to_measure.uid}')

y_min = np.repeat(0, rpm_res['with']['mag_min'].size)
# old: y_max = np.repeat(x180_ef_rpm.amplitude, ...)
y_max = np.repeat(ef_drive_amplitude_pi_rpm, rpm_res['with']['mag_min'].size)

for axis, pre_pulse, key in zip(
    quick_rpm_axs,
    ['with', 'wo', 'with', 'wo'],
    ['mag', 'mag', 'pha', 'pha'],
):
    axis.scatter(y_min, rpm_res[pre_pulse][f'{key}_min'])
    axis.scatter(y_max, rpm_res[pre_pulse][f'{key}_max'])
    axis.scatter(np.mean(y_min), np.mean(rpm_res[pre_pulse][f'{key}_min']),
                 marker='x', color='black', s=200)
    axis.scatter(np.mean(y_max), np.mean(rpm_res[pre_pulse][f'{key}_max']),
                 marker='x', color='black', s=200)
    axis.plot(rpm_amp_plot, func_osc(rpm_amp_plot, *rpm_popt[pre_pulse][key]),
              color='tab:red', linestyle='dashed')

for axis, ylabel, title in zip(
    quick_rpm_axs,
    ['Amplitude', 'Amplitude', 'Phase', 'Phase'],
    ['with ge pre-pulse', 'without ge pre-pulse',
     'with ge pre-pulse', 'without ge pre-pulse'],
):
    axis.set_ylabel(ylabel)
    axis.set_title(title)

quick_rpm_axs[-1].set_xlabel('ef amplitude')

amps_with_mag = np.abs(rpm_res['with']['mag_min'] - rpm_res['with']['mag_max'])
amps_with_pha = np.abs(rpm_res['with']['pha_min'] - rpm_res['with']['pha_max'])

amps_wo_mag = np.abs(rpm_res['wo']['mag_min'] - rpm_res['wo']['mag_max'])
amps_wo_pha = np.abs(rpm_res['wo']['pha_min'] - rpm_res['wo']['pha_max'])

mean_amps_with_mag = np.mean(amps_with_mag)
mean_amps_with_pha = np.mean(amps_with_pha)

mean_amps_wo_mag = np.mean(amps_wo_mag)
mean_amps_wo_pha = np.mean(amps_wo_pha)

file_path = get_path_to_file('Quick_RPM_', '.png')
quick_rpm_fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %%
max_iq_with = np.column_stack((rpm_res['with']['I_max'], rpm_res['with']['Q_max']))
min_iq_with = np.column_stack((rpm_res['with']['I_min'], rpm_res['with']['Q_min']))
iq_amp_with = np.linalg.norm(max_iq_with - min_iq_with, axis=1)

max_iq_wo = np.column_stack((rpm_res['wo']['I_max'], rpm_res['wo']['Q_max']))
min_iq_wo = np.column_stack((rpm_res['wo']['I_min'], rpm_res['wo']['Q_min']))
iq_amp_wo = np.linalg.norm(max_iq_wo - min_iq_wo, axis=1)

iq_amp_fig, iq_amp_axs = plt.subplots(2, 1, figsize=(10, 8))
iq_amp_fig.suptitle(f'Quick RPM IQ distances - {qubit_to_measure.uid}')
iq_amp_axs[0].plot(iq_amp_with, marker='o')
iq_amp_axs[0].set_ylabel('with pre-pulse')
iq_amp_axs[1].plot(iq_amp_wo, marker='o')
iq_amp_axs[1].set_ylabel('without pre-pulse')
iq_amp_axs[1].set_xlabel('Measurement')

# %% [markdown]
# ### Temperature

# %% [markdown]
# #### Analysis Plots

# %%
f_q, anharm = get_qubit_temperature_parameters(qubit_to_measure)
print('f_q:   ', f_q, 'GHz')
print('anharm:', anharm, 'GHz')

# old: rpm_pe = amps_wo_mag / (amps_with_mag + amps_wo_mag)
rpm_pe = iq_amp_wo / (iq_amp_wo + iq_amp_with)

rpm_temp = T_calc(C=rpm_pe / (1 - rpm_pe), f_q=f_q)

quick_rpm_temps_fig, quick_rpm_temps_axs = plt.subplots(figsize=(15, 5))
quick_rpm_temps_axs.plot(np.arange(len(rpm_pe)), rpm_temp, marker='o')
quick_rpm_temps_axs.hlines([np.mean(rpm_temp)], 0, len(rpm_pe), color='black',
                           linestyle='dashed', label='average')
quick_rpm_temps_axs.set_ylabel('temp (K)')
quick_rpm_temps_axs.set_xlabel('Measurement')
quick_rpm_temps_axs.set_title(
    f'Quick Rabi Population Measurement - {qubit_to_measure.uid}'
)
quick_rpm_temps_axs.legend()

quick_rpm_temps_hist_fig, quick_rpm_temps_hist_ax = plt.subplots()
quick_rpm_temps_hist_ax.hist(rpm_temp, bins=75)
quick_rpm_temps_hist_ax.set_xlabel('Temperature')
quick_rpm_temps_hist_ax.set_ylabel('Counts')
quick_rpm_temps_hist_ax.set_title(
    f'Quick Rabi Population Measurement - {qubit_to_measure.uid}'
)

print('Mean pe:          ', np.mean(rpm_pe))
print('Mean temperature: ', np.mean(rpm_temp) * 1e3, 'mK')

file_path = get_path_to_file('Quick_RPM_temperature_', '.png')
quick_rpm_temps_fig.savefig(file_path, dpi=600, format='png',
                            bbox_inches='tight')

# %% [markdown]
# #### Update Parameters

# %%
data_rpm = {
    'ef_amplitude_sweep': ef_amplitudes,
    'rpm_mag_with': rpm_res['with']['mag_max'],
    'rpm_mag_wo': rpm_res['wo']['mag_max'],
    'iq_amp_with': iq_amp_with,
    'iq_amp_wo': iq_amp_wo,
    'rpm_pe': rpm_pe,
    'rpm_temp': rpm_temp,
    'ef_drive_amplitude_pi_rpm': ef_drive_amplitude_pi_rpm,
    'n_shots': 2**n_avg_exponent,
    'repetitions': repetitions,
    'f_q': f_q,
    'anharm': anharm,
    'comment': 'Quick Rabi population measurement, temperature in K',
}
data_rpm.update(qrpm_dict)
data_rpm.update(
    {k: v for k, v in attrs.asdict(qubit_to_measure.parameters).items()
     if isinstance(v, (int, float, str))}
)
data_rpm['sample_name'] = sample_name
data_rpm['qubit_name'] = qubit_name
data_rpm['cooldown_start_date'] = cooldown_start_date

file_path = get_path_to_file('RPM_temperature_', '.mat')
savemat(file_path, data_rpm)
print(f'Saved Rabi population measurement to: {file_path}')

# %% [markdown]
# ## Three Level Population Measurements

# %% [markdown]
# ### Single-Point Experiment

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

n_avg_exponent = 15

qubit_to_measure = qubits[0]

# old: readout_opt / readout_low passed to create_exp_population_full
temporary_parameters = {}
temp_pars = deepcopy(qubit_to_measure.parameters)
temporary_parameters[qubit_to_measure.uid] = temp_pars

print('ge drive amplitude pi:      ', temp_pars.ge_drive_amplitude_pi)
print('ef drive amplitude pi:      ', temp_pars.ef_drive_amplitude_pi)
print('Readout amplitude:          ', temp_pars.readout_amplitude)
print('Readout length:             ', temp_pars.readout_length)
print('Readout resonator frequency:', temp_pars.readout_resonator_frequency)
print('Reset delay length:         ', temp_pars.reset_delay_length)
print('Number of averages:         ', 2**n_avg_exponent)

# %% [markdown]
# #### Run Workflow

# %%
options = population_experiment_workflow.options()
options.count(2**n_avg_exponent)

exp_workflow = population_experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=qubit_to_measure.uid,
    options=options,
    temporary_parameters=temporary_parameters,
)
workflow_result = exp_workflow.run()

# %% [markdown]
# #### Analysis Plots

# %%
# old: print(results_population_full.get_data('x0_readout'))
pop_result = collect_population_from_result(
    workflow_result.output, qubit_to_measure.uid
)
for label in pop_label_list:
    print(f'{label}: {pop_result[label]}')

# %% [markdown]
# ### Population Statistics

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

n_avg_exponent = 15

# old: N = 3 #Number of measurements
n_measurements = 3

# estimators that are excluded from the plots (old `skip = ['TC2']`)
skip = ['TC2']

three_levels = True

qubit_to_measure = qubits[0]

temporary_parameters = {}
temp_pars = deepcopy(qubit_to_measure.parameters)
temporary_parameters[qubit_to_measure.uid] = temp_pars

f_q, anharm = get_qubit_temperature_parameters(qubit_to_measure)
print('f_q:               ', f_q, 'GHz')
print('anharm:            ', anharm, 'GHz')
print('Number of averages:', 2**n_avg_exponent)
print('Number of runs:    ', n_measurements)

# %% [markdown]
# #### Run Workflow

# %%
options = population_experiment_workflow.options()
options.count(2**n_avg_exponent)

pop_full_results = {}
pop_workflow_results = []

for i in range(n_measurements):
    print('Iteration: ', i)

    exp_workflow = population_experiment_workflow(
        session=session,
        qpu=qpu,
        qubit=qubit_to_measure.uid,
        options=options,
        temporary_parameters=temporary_parameters,
    )
    workflow_result = exp_workflow.run()
    pop_workflow_results.append(workflow_result)

    pop_result = collect_population_from_result(
        workflow_result.output, qubit_to_measure.uid
    )
    for label in pop_label_list:
        pop_full_results.setdefault(label, []).append(pop_result[label])

for label in pop_label_list:
    pop_full_results[label] = np.array(pop_full_results[label])

print('Population array shape (runs,):', pop_full_results['x0'].shape)

# %% [markdown]
# #### Analysis Plots

# %%
# fast temperature extraction (projection onto I and Q at phase 0)
TABC_I, TABC_Q = make_all_temperatures(pop_full_results, f_q, anharm,
                                       three_levels=three_levels)

fig, ax = plot_temperatures(TABC_I, TABC_Q, skip=skip)

file_path = get_path_to_file('Population_stat_', '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %%
STAT_I = get_stat(TABC_I)
STAT_Q = get_stat(TABC_Q)

# give plot_stat copies so it cannot modify the original statistis
STAT_I_plot = {k: v.copy() for k, v in STAT_I.items()}
STAT_Q_plot = {k: v.copy() for k, v in STAT_Q.items()}

fig, ax = plot_stat(STAT_I_plot, STAT_Q_plot)

for k in STAT_I:
    print(k, '| I mean:', np.round(STAT_I[k][0], 3),
          'rel. err:', np.round(STAT_I[k][2], 4),
          '| Q mean:', np.round(STAT_Q[k][0], 3),
          'rel. err:', np.round(STAT_Q[k][2], 4))

file_path = get_path_to_file('Population_stat_bars_', '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %%
# population, 3-level method, proper rotation ('parallel' approach)
ABC = get_ABC_parallel(pop_full_results)
TABC = get_temperature(ABC, f_q, anharm, three_levels=three_levels)

fig, ax = plot_temp_single(TABC, skip=skip)

STAT = get_stat(TABC)
fig_stat, ax_stat = plot_stat(STAT, STAT)

file_path = get_path_to_file('Population_stat_parallel_', '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %%
fig, ax = plt.subplots()
ax.set_title(f'Population measurements on the IQ plane - {qubit_to_measure.uid}')
for label in pop_label_list:
    ax.plot(pop_full_results[label].real, pop_full_results[label].imag, 'o-',
            label=label)
ax.set_xlabel('Real part, a.u.')
ax.set_ylabel('Imaginary part, a.u.')
ax.legend()

file_path = get_path_to_file('Population_stat_IQ_', '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %%
# pe/pg and temperature per estimator, written out explicitly (old cells
# 407-410). `get_C_from_ABC` does the same for a whole ABC dictionary.
A_real = ((pop_full_results['x0'].real - pop_full_results['x1'].real)
          / (pop_full_results['y0'].real - pop_full_results['y1'].real))
A_imag = ((pop_full_results['x0'].imag - pop_full_results['x1'].imag)
          / (pop_full_results['y0'].imag - pop_full_results['y1'].imag))

B_real = ((pop_full_results['x1'].real - pop_full_results['y1'].real)
          / (pop_full_results['y0'].real - pop_full_results['x2'].real))
B_imag = ((pop_full_results['x1'].imag - pop_full_results['y1'].imag)
          / (pop_full_results['y0'].imag - pop_full_results['x2'].imag))

C_real = ((pop_full_results['x0'].real - pop_full_results['y0'].real)
          / (pop_full_results['x1'].real - pop_full_results['x2'].real))
C_imag = ((pop_full_results['x0'].imag - pop_full_results['y0'].imag)
          / (pop_full_results['x1'].imag - pop_full_results['x2'].imag))

fig, ax = plt.subplots()
ax.plot(C_real, '-o', label='C_Q')
ax.plot(C_imag, '-o', label='C_I')
ax.plot(1 - A_real, '-o', label='A_Q')
ax.plot(1 - A_imag, '-o', label='A_I')
ax.plot(B_real / (B_real + 1), '-o', label='B_Q')
ax.plot(B_imag / (B_imag + 1), '-o', label='B_I')
ax.set_xlabel('Experiment number')
ax.set_ylabel('$p_e/p_g$')
ax.legend()

print('Mean pe/pg C_real:', np.mean(C_real) * 1e2)
print('Mean pe/pg C_imag:', np.mean(C_imag) * 1e2)
print('Mean pe/pg A_real:', np.mean(1 - A_real) * 1e2)
print('Mean pe/pg A_imag:', np.mean(1 - A_imag) * 1e2)
print('Mean pe/pg B_real:', np.mean(B_real / (B_real + 1)) * 1e2)
print('Mean pe/pg B_imag:', np.mean(B_imag / (B_imag + 1)) * 1e2)

T_A_real = T_calc(1 - A_real, f_q) * 1e3
T_A_imag = T_calc(1 - A_imag, f_q) * 1e3
T_B_real = T_calc(B_real / (B_real + 1), f_q) * 1e3
T_B_imag = T_calc(B_imag / (B_imag + 1), f_q) * 1e3
T_C_real = T_calc(C_real, f_q) * 1e3
T_C_imag = T_calc(C_imag, f_q) * 1e3

fig, ax = plt.subplots()
ax.plot(T_A_real, '-o', label='A_Q', color='red')
ax.plot(T_A_imag, '-D', mfc='w', label='A_I', color='red')
ax.plot(T_B_real, '-o', label='B_Q', color='blue')
ax.plot(T_B_imag, '-D', mfc='w', label='B_I', color='blue')
ax.plot(T_C_real, '-o', label='C_Q', color='green')
ax.plot(T_C_imag, '-D', mfc='w', label='C_I', color='green')
ax.set_xlabel('Experiment number')
ax.set_ylabel('T_eff, mK')
ax.axhline(100, linestyle='dashed', color='grey')
ax.axhspan(90, 110, color='lightgrey')
ax.legend()

file_path = get_path_to_file('Population_stat_temperatures_', '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %% [markdown]
# #### Update Parameters

# %%
# old: Data_T_stat.update(pop_full_results);
#      Data_T_stat.update(qubit_parameters._params);
#      Data_T_stat.update(lo_settings._params)
data_t_stat = {f'pop_{label}': pop_full_results[label]
               for label in pop_label_list}
data_t_stat.update({f'{k}_I': v for k, v in TABC_I.items()})
data_t_stat.update({f'{k}_Q': v for k, v in TABC_Q.items()})
data_t_stat.update({f'{k}_parallel': v for k, v in TABC.items()})
data_t_stat.update({
    'T_A_real': T_A_real,
    'T_A_imag': T_A_imag,
    'T_B_real': T_B_real,
    'T_B_imag': T_B_imag,
    'T_C_real': T_C_real,
    'T_C_imag': T_C_imag,
    'n_measurements': n_measurements,
    'n_shots': 2**n_avg_exponent,
    'f_q': f_q,
    'anharm': anharm,
    'three_levels': three_levels,
    'comment': ('Three level population statistics, array dim [run]; '
                'temperatures in mK'),
})
data_t_stat.update(
    {k: v for k, v in attrs.asdict(qubit_to_measure.parameters).items()
     if isinstance(v, (int, float, str))}
)
data_t_stat['sample_name'] = sample_name
data_t_stat['qubit_name'] = qubit_name
data_t_stat['cooldown_start_date'] = cooldown_start_date

file_path = get_path_to_file('Teff_stat_all_unsh_', '.mat')
savemat(file_path, data_t_stat)
print(f'Saved population statistics to: {file_path}')

# %% [markdown]
# ### Rotation and Measurement Optimisation

# %% [markdown]
# #### Experiment Parameters

# %%
# No new experiment is run here: the projection phase of the data acquired in
# `### Population Statistics` is optimized.
phase_arr = np.linspace(-1, 1, 65) * np.pi / 2

# estimators that are excluded from the optimization (old skip = ['TA1','TA3'])
skip_optimization = ['TA1', 'TA3']

# optional: use only a slice of the runs (old `pop_slice`)
# pop_slice = {k: v[1:33] for k, v in pop_full_results.items()}
pop_data = pop_full_results

# %% [markdown]
# #### Analysis Plots

# %%
STAT_I, STAT_Q = make_rotation_temperature(pop_data, phase_arr, f_q, anharm,
                                           three_levels=three_levels)

for info_type in ['mean', 'error', 'rel_err']:
    fig, ax = plot_rotation_stat(phase_arr, STAT_I, STAT_Q,
                                 info_type=info_type)
    file_path = get_path_to_file(f'Population_rotation_{info_type}_', '.png')
    fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %%
for k in STAT_I:
    print('For', k)
    print('  I: min rel. err:', np.nanmin(STAT_I[k][:, 2]),
          'at phase point', np.nanargmin(STAT_I[k][:, 2]))
    print('  Q: min rel. err:', np.nanmin(STAT_Q[k][:, 2]),
          'at phase point', np.nanargmin(STAT_Q[k][:, 2]))

# %%
optimal_method = make_optimal_temperature(pop_data, phase_arr, f_q, anharm,
                                          skip=skip_optimization,
                                          three_levels=three_levels)
pprint(optimal_method)

Teff = find_optimal_temperature(pop_data, optimal_method, f_q, anharm,
                                three_levels=three_levels)

fig, ax = plt.subplots()
ax.plot(Teff, 'o-')
ax.set_xlabel('Experiment number')
ax.set_ylabel('T_eff, mK')
ax.set_title(f"Optimal method {optimal_method['method']} "
             f"({optimal_method['axes']}) - {qubit_to_measure.uid}")

print('Mean optimal temperature:', np.nanmean(Teff), 'mK')

file_path = get_path_to_file('Population_optimal_temperature_', '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %% [markdown]
# !stop here

# %%
# statistics at a single (zero) phase, for comparison
STAT_I_0, STAT_Q_0 = make_rotation_temperature(pop_data, [0], f_q, anharm,
                                               three_levels=three_levels)

# give plot_stat copies so it cannot modify the original statistis
STAT_I_0_plot = {k: v.copy() for k, v in STAT_I_0.items()}
STAT_Q_0_plot = {k: v.copy() for k, v in STAT_Q_0.items()}

fig, ax = plot_stat(STAT_I_0_plot, STAT_Q_0_plot)

# %% [markdown]
# #### Update Parameters

# %%
data_t_opt = {
    'phase_arr': phase_arr,
    'optimal_phase': optimal_method['phase'],
    'optimal_method': optimal_method['method'],
    'optimal_axes': optimal_method['axes'],
    'optimal_rel_err': optimal_method['rel_err'],
    'Teff': Teff,
    'f_q': f_q,
    'anharm': anharm,
    'comment': 'Projection-phase optimization of the population statistics',
}
data_t_opt.update({f'STAT_{k}_I': v for k, v in STAT_I.items()})
data_t_opt.update({f'STAT_{k}_Q': v for k, v in STAT_Q.items()})
data_t_opt.update(
    {k: v for k, v in attrs.asdict(qubit_to_measure.parameters).items()
     if isinstance(v, (int, float, str))}
)
data_t_opt['sample_name'] = sample_name
data_t_opt['qubit_name'] = qubit_name
data_t_opt['cooldown_start_date'] = cooldown_start_date

file_path = get_path_to_file('Teff_rotation_optimization_', '.mat')
savemat(file_path, data_t_opt)
print(f'Saved rotation optimization to: {file_path}')

# %% [markdown]
# ### Population with Prepulse

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = False

n_avg_exponent = 17

qubit_to_measure = qubits[0]

# range of the ge pre-pulse amplitude scan (old amp_min / amp_max / amp_num)
prepulse_amp_min = 0
prepulse_amp_max = qubit_to_measure.parameters.ge_drive_amplitude_pi
n_prepulse_amp = 51
prepulse_amplitudes = np.linspace(prepulse_amp_min, prepulse_amp_max,
                                  n_prepulse_amp)

# old: gaussian_pulse = pulse_library.gaussian(
#          length=qubit_parameters["qb_len"], amplitude=1.0)
ge_drive_pulse = {
    'function': 'gaussian',
    'sigma': 0.25,
}

temporary_parameters = {}
temp_pars = deepcopy(qubit_to_measure.parameters)
temp_pars.ge_drive_pulse = ge_drive_pulse
temporary_parameters[qubit_to_measure.uid] = temp_pars

print('ge drive pulse:        ', temp_pars.ge_drive_pulse)
print('ge drive length:       ', temp_pars.ge_drive_length)
print('ge drive amplitude pi: ', temp_pars.ge_drive_amplitude_pi)
print('Number of averages:    ', 2**n_avg_exponent)

# %% [markdown]
# #### Run Workflow

# %%
options = population_experiment_workflow.options()
options.count(2**n_avg_exponent)

exp_workflow = population_experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=qubit_to_measure.uid,
    prepulse_amplitudes=prepulse_amplitudes,
    options=options,
    temporary_parameters=temporary_parameters,
)
workflow_result = exp_workflow.run()

# %% [markdown]
# #### Analysis Plots

# %%
# old: pulse_amp = results_population_prepulse.get_axis("x0_readout")[0]
pulse_amp = prepulse_amplitudes

pop_prepulse_results = collect_population_from_result(
    workflow_result.output, qubit_to_measure.uid
)

# convenience aliases matching the old variable names
x0 = pop_prepulse_results['x0']
x1 = pop_prepulse_results['x1']
x2 = pop_prepulse_results['x2']
y0 = pop_prepulse_results['y0']
y1 = pop_prepulse_results['y1']
y2 = pop_prepulse_results['y2']

fig, ax = plt.subplots()
ax.plot(pulse_amp,
        (abs(x0) - np.min(abs(x0))) / (np.max(abs(x0)) - np.min(abs(x0))),
        'o-')
ax.set_xlabel('Pre-pulse amplitude, a.u.')
ax.set_ylabel('Normalized $|x0|$')
ax.set_title(f'Population with pre-pulse - {qubit_to_measure.uid}')

# %%
A_real = (x0.real - x1.real) / (y0.real - y1.real)
A_imag = (x0.imag - x1.imag) / (y0.imag - y1.imag)

B_real = (x1.real - y1.real) / (y0.real - x2.real)
B_imag = (x1.imag - y1.imag) / (y0.imag - x2.imag)

C_real = (x0.real - y0.real) / (x1.real - x2.real)
C_imag = (x0.imag - y0.imag) / (x1.imag - x2.imag)

pe0 = 1 - A_real[0]
print('Residual excited population at zero pre-pulse amplitude:', pe0)

fig, ax = plt.subplots()
# ax.plot(pulse_amp, C_real, '-o', label='C_Q')
# ax.plot(pulse_amp, C_imag, '-o', label='C_I')
ax.plot(pulse_amp, 1 - A_real, '-o', label='A_Q')
# ax.plot(pulse_amp, 1 - A_imag, '-o', label='A_I')
ax.plot(pulse_amp, B_real / (B_real + 1), '-o', label='B_Q')
# ax.plot(pulse_amp, B_imag / (B_imag + 1), '-o', label='B_I')

pe = (abs(x0) - np.min(abs(x0))) / (np.max(abs(x0)) - np.min(abs(x0)))
pe_sh = (1 - 2 * pe0) * pe + pe0
ax.plot(pulse_amp, pe_sh / (1 - pe_sh), '-')

ax.set_xlabel('Pre-pulse amplitude, a.u.')
ax.set_ylabel('$p_e/p_g$')
ax.set_ylim(0.0, 1.0)
ax.legend()

file_path = get_path_to_file('Population_prepulse_', '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %% [markdown]
# #### Update Parameters

# %%
data_pop_prep = {f'pop_{label}': pop_prepulse_results[label]
                 for label in pop_label_list}
data_pop_prep.update({
    'prepulse_amplitude_sweep': pulse_amp,
    'pe0': pe0,
    'n_shots': 2**n_avg_exponent,
    'comment': ('Three level population vs. ge pre-pulse amplitude, array dim '
                '[prepulse_amplitude]'),
})
data_pop_prep.update(
    {k: v for k, v in attrs.asdict(qubit_to_measure.parameters).items()
     if isinstance(v, (int, float, str))}
)
data_pop_prep['sample_name'] = sample_name
data_pop_prep['qubit_name'] = qubit_name
data_pop_prep['cooldown_start_date'] = cooldown_start_date

file_path = get_path_to_file('Population_prep_', '.mat')
savemat(file_path, data_pop_prep)
print(f'Saved population with pre-pulse to: {file_path}')

# %% [markdown]
# ## Population Measurements for Different Readout Frequencies

# %% [markdown]
# The three-level protocol repeated for a range of readout resonator
# frequencies. Every frequency needs its own compilation, so this is slow.

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = False

n_avg_exponent = 12

# frequency range around the current readout resonator frequency
freq_range = 10e6
n_points = 25

qubit_to_measure = qubits[0]

# old: ro_freq_arr = np.linspace(qubit_parameters["ro_freq"] - spec_range / 2,
#                                qubit_parameters["ro_freq"] + spec_range / 2,
#                                spec_num)
readout_resonator_frequency_arr = (
    qubit_to_measure.parameters.readout_resonator_frequency
    + np.linspace(-freq_range / 2, freq_range / 2, n_points)
)

# old readout_i dict: readout_range / readout_delay / relax_time
readout_range_out = -25
readout_integration_delay = qubit_to_measure.parameters.readout_integration_delay

print('Readout resonator frequencies: ',
      readout_resonator_frequency_arr[0] * 1e-9, '...',
      readout_resonator_frequency_arr[-1] * 1e-9, 'GHz')
print('Number of averages:            ', 2**n_avg_exponent)

# %% [markdown]
# #### Run Workflow

# %%
options = population_experiment_workflow.options()
options.count(2**n_avg_exponent)

pop_i_results = {}

for readout_resonator_frequency in readout_resonator_frequency_arr:
    print('Readout resonator frequency:',
          round(readout_resonator_frequency * 1e-9, 6), 'GHz')

    temporary_parameters = {}
    temp_pars = deepcopy(qubit_to_measure.parameters)
    temp_pars.readout_resonator_frequency = float(readout_resonator_frequency)
    temp_pars.readout_range_out = readout_range_out
    temp_pars.readout_integration_delay = readout_integration_delay
    temporary_parameters[qubit_to_measure.uid] = temp_pars

    exp_workflow = population_experiment_workflow(
        session=session,
        qpu=qpu,
        qubit=qubit_to_measure.uid,
        options=options,
        temporary_parameters=temporary_parameters,
    )
    workflow_result = exp_workflow.run()

    pop_result = collect_population_from_result(
        workflow_result.output, qubit_to_measure.uid
    )
    for label in pop_label_list:
        pop_i_results.setdefault(label, []).append(pop_result[label])

for label in pop_label_list:
    pop_i_results[label] = np.array(pop_i_results[label])

print('Population array shape (frequencies,):', pop_i_results['x0'].shape)

# %% [markdown]
# #### Analysis Plots

# %%
fig, ax = plt.subplots()
ax.set_title(f'Population vs. readout frequency: IQ - {qubit_to_measure.uid}')
ax.plot(pop_i_results['x0'].real, pop_i_results['x0'].imag, label='x0')
ax.plot(pop_i_results['x1'].real, pop_i_results['x1'].imag, label='x1')
ax.set_xlabel('Real part, a.u.')
ax.set_ylabel('Imaginary part, a.u.')
ax.legend()

fig, ax = plt.subplots(2, 1, sharex=True, figsize=(10, 8))
fig.suptitle(f'Population vs. readout frequency - {qubit_to_measure.uid}')
fig.supxlabel('Readout resonator frequency, GHz')

ax[0].plot(readout_resonator_frequency_arr * 1e-9,
           np.abs(pop_i_results['x0'] - pop_i_results['x1']), 'o-',
           label='|x0 - x1|')
ax[0].set_ylabel('Signal distance, a.u.')
ax[0].legend()

ax[1].plot(readout_resonator_frequency_arr * 1e-9,
           np.unwrap(np.angle(pop_i_results['x0']))
           - np.unwrap(np.angle(pop_i_results['x1'])), 'o-',
           label='phase(x0) - phase(x1)')
ax[1].plot(readout_resonator_frequency_arr * 1e-9,
           np.unwrap(np.angle(pop_i_results['x0']))
           - np.unwrap(np.angle(pop_i_results['y0'])), 'o-',
           label='phase(x0) - phase(y0)')
ax[1].set_ylabel('Phase difference, rad')
ax[1].legend()

file_path = get_path_to_file('Population_vs_ro_freq_', '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %%
# fast temperature extraction per readout frequency
skip = ['TC3']

TABC_I, TABC_Q = make_all_temperatures(pop_i_results, f_q, anharm,
                                       three_levels=three_levels)

fig, ax = plot_temperatures(TABC_I, TABC_Q, skip=skip)

fig_i, ax_i = plt.subplots(1, 2, sharey=True, figsize=(12, 5))
fig_i.suptitle(f'Temperature vs. readout frequency - {qubit_to_measure.uid}')
for k in TABC_I:
    ax_i[0].plot(readout_resonator_frequency_arr * 1e-9, TABC_I[k], label=k)
    ax_i[1].plot(readout_resonator_frequency_arr * 1e-9, TABC_Q[k], label=k)
ax_i[0].set_title('I component')
ax_i[1].set_title('Q component')
for axis in ax_i:
    axis.set_xlabel('Readout resonator frequency, GHz')
    axis.set_ylim(0, 200)
    axis.legend()
ax_i[0].set_ylabel('Effective temperature, mK')

fig_iq, ax_iq = plt.subplots()
ax_iq.set_title(f'Temperature I vs. Q - {qubit_to_measure.uid}')
for k in TABC_I:
    ax_iq.plot(TABC_I[k], TABC_Q[k], 'o', label=k)
ax_iq.set_xlim(0, 200)
ax_iq.set_ylim(0, 200)
ax_iq.set_xlabel('T_eff (I), mK')
ax_iq.set_ylabel('T_eff (Q), mK')
ax_iq.legend()

STAT_I = get_stat_nan(TABC_I)
STAT_Q = get_stat_nan(TABC_Q)
fig_stat, ax_stat = plot_stat(STAT_I, STAT_Q)

file_path = get_path_to_file('Population_vs_ro_freq_temperature_', '.png')
fig_i.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %% [markdown]
# #### Update Parameters

# %%
data_pop_ro_freq = {f'pop_{label}': pop_i_results[label]
                    for label in pop_label_list}
data_pop_ro_freq.update({f'{k}_I': v for k, v in TABC_I.items()})
data_pop_ro_freq.update({f'{k}_Q': v for k, v in TABC_Q.items()})
data_pop_ro_freq.update({
    'readout_resonator_frequency_sweep': readout_resonator_frequency_arr,
    'readout_range_out': readout_range_out,
    'readout_integration_delay': readout_integration_delay,
    'n_shots': 2**n_avg_exponent,
    'f_q': f_q,
    'anharm': anharm,
    'comment': ('Three level population vs. readout resonator frequency, array '
                'dim [readout_resonator_frequency]; temperatures in mK'),
})
data_pop_ro_freq.update(
    {k: v for k, v in attrs.asdict(qubit_to_measure.parameters).items()
     if isinstance(v, (int, float, str))}
)
data_pop_ro_freq['sample_name'] = sample_name
data_pop_ro_freq['qubit_name'] = qubit_name
data_pop_ro_freq['cooldown_start_date'] = cooldown_start_date

file_path = get_path_to_file('Population_vs_ro_freq_', '.mat')
savemat(file_path, data_pop_ro_freq)
print(f'Saved population vs. readout frequency to: {file_path}')

# %%
# set to a value != None to move the readout to the frequency with the lowest
# temperature spread (old notebook did this by hand).
manual_readout_resonator_frequency = None

# spread of the estimators at every readout frequency, as a figure of merit
temperature_matrix = np.array(
    [TABC_I[k] for k in TABC_I if k not in skip], dtype=float
)
rel_err_vs_freq = np.abs(
    np.nanstd(temperature_matrix, axis=0) / np.nanmean(temperature_matrix, axis=0)
)
optimal_index = int(np.nanargmin(rel_err_vs_freq))
readout_resonator_frequency_opt = float(
    readout_resonator_frequency_arr[optimal_index]
)
if manual_readout_resonator_frequency is not None:
    readout_resonator_frequency_opt = float(manual_readout_resonator_frequency)

print('Optimal readout resonator frequency:',
      round(readout_resonator_frequency_opt * 1e-9, 6), 'GHz',
      '(index', optimal_index, ')')

if update_global_parameters:
    temp_pars = deepcopy(qubit_to_measure.parameters)
    temp_pars.readout_resonator_frequency = readout_resonator_frequency_opt
    qubit_to_measure.parameters = temp_pars
    save(qpu, qpu_file_path)
    print('Updated global experiment parameters!\n')

print('Readout resonator frequency: ',
      qubit_to_measure.parameters.readout_resonator_frequency * 1e-9, ' GHz')

# %%
qubits[0].parameters
