# %% [markdown]
# # Imports & Inits

# %%
# LabOne Q:
from laboneq.simple import *
from laboneq.dsl.quantum import QPU
from laboneq.contrib.example_helpers.generate_descriptor import generate_descriptor
from laboneq.workflow.logbook import LoggingStore

# LabOne Q Applications:
from laboneq_applications.qpu_types.tunable_transmon import (
    TunableTransmonQubit,
    TunableTransmonOperations,
)

# Packages:
from copy import deepcopy
from pprint import pprint
import numpy as np
import time
from pathlib import Path

# Plot:
from laboneq.contrib.example_helpers.plotting.plot_helpers import plot_results, plot_simulation

# Workflows:
from laboneq_applications.experiments import (
    resonator_spectroscopy,
    resonator_spectroscopy_amplitude,
    qubit_spectroscopy,
    amplitude_rabi,
    ramsey,
    drag_q_scaling,
    lifetime_measurement,
    echo,
)

# %%
number_of_qubits = 2

descriptor = generate_descriptor(
    #pqsc=["DEV10001"],
    shfqc_2=["DEV12192"],
    number_data_qubits=number_of_qubits,
    multiplex=True,
    number_multiplex=number_of_qubits,
    include_cr_lines=False,
    ip_address="localhost",
    #options = "SHFQC/QC2CH",
)

setup = DeviceSetup.from_descriptor(descriptor, "localhost")
setup.instruments[0].device_options = "SHFQC/QC2CH"

# %%
setup.logical_signal_groups
# Out:
# {'q0': LogicalSignalGroup(
# │   uid='q0',
# │   logical_signals={
# │   │   'drive': LogicalSignal(
# │   │   │   uid='q0/drive',
# │   │   │   direction=IODirection.OUT,
# │   │   │   name='drive',
# │   │   │   calibration=None,
# │   │   │   path='/logical_signal_groups/q0/drive',
# │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   uid='SHFQC_DEV12192/sgchannels_0_output',
# │   │   │   │   name='sgchannels_0_output',
# │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   path='/physical_channel_groups/SHFQC_DEV12192/sgchannels_0_output',
# │   │   │   │   calibration=None
# │   │   │   )
# │   │   ),
# │   │   'drive_ef': LogicalSignal(
# │   │   │   uid='q0/drive_ef',
# │   │   │   direction=IODirection.OUT,
# │   │   │   name='drive_ef',
# │   │   │   calibration=None,
# │   │   │   path='/logical_signal_groups/q0/drive_ef',
# │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   uid='SHFQC_DEV12192/sgchannels_0_output',
# │   │   │   │   name='sgchannels_0_output',
# │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   path='/physical_channel_groups/SHFQC_DEV12192/sgchannels_0_output',
# │   │   │   │   calibration=None
# │   │   │   )
# │   │   ),
# │   │   'measure': LogicalSignal(
# │   │   │   uid='q0/measure',
# │   │   │   direction=IODirection.OUT,
# │   │   │   name='measure',
# │   │   │   calibration=None,
# │   │   │   path='/logical_signal_groups/q0/measure',
# │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   uid='SHFQC_DEV12192/qachannels_0_output',
# │   │   │   │   name='qachannels_0_output',
# │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   path='/physical_channel_groups/SHFQC_DEV12192/qachannels_0_output',
# │   │   │   │   calibration=None
# │   │   │   )
# │   │   ),
# │   │   'acquire': LogicalSignal(
# │   │   │   uid='q0/acquire',
# │   │   │   direction=IODirection.IN,
# │   │   │   name='acquire',
# │   │   │   calibration=None,
# │   │   │   path='/logical_signal_groups/q0/acquire',
# │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   uid='SHFQC_DEV12192/qachannels_0_input',
# │   │   │   │   name='qachannels_0_input',
# │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   path='/physical_channel_groups/SHFQC_DEV12192/qachannels_0_input',
# │   │   │   │   calibration=None
# │   │   │   )
# │   │   )
# │   }
# )
# ,
#  'q1': LogicalSignalGroup(
# │   uid='q1',
# │   logical_signals={
# │   │   'drive': LogicalSignal(
# │   │   │   uid='q1/drive',
# │   │   │   direction=IODirection.OUT,
# │   │   │   name='drive',
# │   │   │   calibration=None,
# │   │   │   path='/logical_signal_groups/q1/drive',
# │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   uid='SHFQC_DEV12192/sgchannels_1_output',
# │   │   │   │   name='sgchannels_1_output',
# │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   path='/physical_channel_groups/SHFQC_DEV12192/sgchannels_1_output',
# │   │   │   │   calibration=None
# │   │   │   )
# │   │   ),
# │   │   'drive_ef': LogicalSignal(
# │   │   │   uid='q1/drive_ef',
# │   │   │   direction=IODirection.OUT,
# │   │   │   name='drive_ef',
# │   │   │   calibration=None,
# │   │   │   path='/logical_signal_groups/q1/drive_ef',
# │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   uid='SHFQC_DEV12192/sgchannels_1_output',
# │   │   │   │   name='sgchannels_1_output',
# │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   path='/physical_channel_groups/SHFQC_DEV12192/sgchannels_1_output',
# │   │   │   │   calibration=None
# │   │   │   )
# │   │   ),
# │   │   'measure': LogicalSignal(
# │   │   │   uid='q1/measure',
# │   │   │   direction=IODirection.OUT,
# │   │   │   name='measure',
# │   │   │   calibration=None,
# │   │   │   path='/logical_signal_groups/q1/measure',
# │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   uid='SHFQC_DEV12192/qachannels_0_output',
# │   │   │   │   name='qachannels_0_output',
# │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   path='/physical_channel_groups/SHFQC_DEV12192/qachannels_0_output',
# │   │   │   │   calibration=None
# │   │   │   )
# │   │   ),
# │   │   'acquire': LogicalSignal(
# │   │   │   uid='q1/acquire',
# │   │   │   direction=IODirection.IN,
# │   │   │   name='acquire',
# │   │   │   calibration=None,
# │   │   │   path='/logical_signal_groups/q1/acquire',
# │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   uid='SHFQC_DEV12192/qachannels_0_input',
# │   │   │   │   name='qachannels_0_input',
# │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   path='/physical_channel_groups/SHFQC_DEV12192/qachannels_0_input',
# │   │   │   │   calibration=None
# │   │   │   )
# │   │   )
# │   }
# )
# }

# %%
qubits = TunableTransmonQubit.from_device_setup(setup)

for q in qubits:
    print("-------------")
    print("Qubit UID:", q.uid)
    print("Qubit logical signals:")
    for sig, lsg in q.signals.items():
        print(f"  {sig:<10} ('{lsg:>10}')")
# Out:
# -------------
# Qubit UID: q0
# Qubit logical signals:
#   drive      ('  q0/drive')
#   drive_ef   ('q0/drive_ef')
#   measure    ('q0/measure')
#   acquire    ('q0/acquire')
# -------------
# Qubit UID: q1
# Qubit logical signals:
#   drive      ('  q1/drive')
#   drive_ef   ('q1/drive_ef')
#   measure    ('q1/measure')
#   acquire    ('q1/acquire')

# %%
for q in qubits:
    q.parameters.ge_drive_pulse["sigma"] = 0.25
    q.parameters.readout_amplitude = 0.5
    q.parameters.reset_delay_length = 100e-6
    q.parameters.readout_range_out = -30
    q.parameters.readout_lo_frequency = 5e9
    q.parameters.drive_range = 5
    q.parameters.readout_range_in = -45
    q.parameters.readout_integration_delay = 80e-9

qubits[0].parameters.drive_lo_frequency = 3.6e9
qubits[0].parameters.resonance_frequency_ge = 3.748e9
qubits[0].parameters.resonance_frequency_ef = 3.51e9
qubits[0].parameters.readout_resonator_frequency = 5.037e9
# qubits[0].parameters.spectroscopy_amplitude = 0.1

qubits[1].parameters.drive_lo_frequency = 6.4e9
qubits[1].parameters.resonance_frequency_ge = 6.5e9
qubits[1].parameters.resonance_frequency_ef = 6.3e9
qubits[1].parameters.readout_resonator_frequency = 7.3e9

# %%
qops = TunableTransmonOperations()
qpu = QPU(qubits, quantum_operations=qops)
qpu.quantum_elements
# Out:
# [TunableTransmonQubit(
# │   uid='q0',
# │   signals={
# │   │   'drive': 'q0/drive',
# │   │   'drive_ef': 'q0/drive_ef',
# │   │   'measure': 'q0/measure',
# │   │   'acquire': 'q0/acquire'
# │   },
# │   parameters=TunableTransmonQubitParameters(
# │   │   custom={},
# │   │   ge_T1=0,
# │   │   ge_T2=0,
# │   │   ge_T2_star=0,
# │   │   ef_T1=0,
# │   │   ef_T2=0,
# │   │   ef_T2_star=0,
# │   │   drive_lo_frequency=3600000000.0,
# │   │   readout_lo_frequency=5000000000.0,
# │   │   resonance_frequency_ge=3748000000.0,
# │   │   resonance_frequency_ef=3510000000.0,
# │   │   readout_resonator_frequency=5037000000.0,
# │   │   ge_drive_amplitude_pi=0.2,
# │   │   ge_drive_amplitude_pi2=0.1,
# │   │   ge_drive_length=5e-08,
# │   │   ge_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   ef_drive_amplitude_pi=0.2,
# │   │   ef_drive_amplitude_pi2=0.1,
# │   │   ef_drive_length=5e-08,
# │   │   ef_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   qubit_resonator_coupling_strength_g=0,
# │   │   ge_chi_shift=0,
# │   │   readout_amplitude=0.5,
# │   │   readout_length=2e-06,
# │   │   readout_pulse={
# │   │   │   'function': 'const'
# │   │   },
# │   │   readout_integration_length=2e-06,
# │   │   readout_integration_delay=8e-08,
# │   │   readout_integration_kernels_type='default',
# │   │   readout_integration_kernels=None,
# │   │   readout_integration_discrimination_thresholds=None,
# │   │   reset_delay_length=0.0001,
# │   │   drive_range=5,
# │   │   readout_range_out=-30,
# │   │   readout_range_in=-45,
# │   │   flux_range=5,
# │   │   spectroscopy_length=5e-06,
# │   │   spectroscopy_amplitude=1,
# │   │   spectroscopy_pulse={
# │   │   │   'function': 'const',
# │   │   │   'can_compress': True
# │   │   },
# │   │   dc_slot=0,
# │   │   dc_voltage_parking=0.0,
# │   │   flux_offset_voltage=0.0,
# │   │   user_defined={}
# │   )
# )
# ,
#  TunableTransmonQubit(
# │   uid='q1',
# │   signals={
# │   │   'drive': 'q1/drive',
# │   │   'drive_ef': 'q1/drive_ef',
# │   │   'measure': 'q1/measure',
# │   │   'acquire': 'q1/acquire'
# │   },
# │   parameters=TunableTransmonQubitParameters(
# │   │   custom={},
# │   │   ge_T1=0,
# │   │   ge_T2=0,
# │   │   ge_T2_star=0,
# │   │   ef_T1=0,
# │   │   ef_T2=0,
# │   │   ef_T2_star=0,
# │   │   drive_lo_frequency=6400000000.0,
# │   │   readout_lo_frequency=5000000000.0,
# │   │   resonance_frequency_ge=6500000000.0,
# │   │   resonance_frequency_ef=6300000000.0,
# │   │   readout_resonator_frequency=7300000000.0,
# │   │   ge_drive_amplitude_pi=0.2,
# │   │   ge_drive_amplitude_pi2=0.1,
# │   │   ge_drive_length=5e-08,
# │   │   ge_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   ef_drive_amplitude_pi=0.2,
# │   │   ef_drive_amplitude_pi2=0.1,
# │   │   ef_drive_length=5e-08,
# │   │   ef_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   qubit_resonator_coupling_strength_g=0,
# │   │   ge_chi_shift=0,
# │   │   readout_amplitude=0.5,
# │   │   readout_length=2e-06,
# │   │   readout_pulse={
# │   │   │   'function': 'const'
# │   │   },
# │   │   readout_integration_length=2e-06,
# │   │   readout_integration_delay=8e-08,
# │   │   readout_integration_kernels_type='default',
# │   │   readout_integration_kernels=None,
# │   │   readout_integration_discrimination_thresholds=None,
# │   │   reset_delay_length=0.0001,
# │   │   drive_range=5,
# │   │   readout_range_out=-30,
# │   │   readout_range_in=-45,
# │   │   flux_range=5,
# │   │   spectroscopy_length=5e-06,
# │   │   spectroscopy_amplitude=1,
# │   │   spectroscopy_pulse={
# │   │   │   'function': 'const',
# │   │   │   'can_compress': True
# │   │   },
# │   │   dc_slot=0,
# │   │   dc_voltage_parking=0.0,
# │   │   flux_offset_voltage=0.0,
# │   │   user_defined={}
# │   )
# )
# ]

# %%
session = Session(setup)
session.connect(do_emulation=False)  # do_emulation=False when at a real setup
# Out:
# [2026.07.14 16:12:57.215] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is C:\Users\phys-pico-lab\Documents\Python_virtual_environments\meas_venv_workflow_py312\Scripts\meas\laboneq_output\log
# [2026.07.14 16:12:57.256] INFO    VERSION: laboneq 26.4.0
# [2026.07.14 16:12:57.264] INFO    Connecting to data server at localhost:8004
# [2026.07.14 16:12:57.285] INFO    Connected to Zurich Instruments LabOne Data Server version 26.04.1.6 at localhost:8004
# [2026.07.14 16:12:57.304] INFO    Configuring the device setup
# [2026.07.14 16:12:57.320] INFO    The device setup is configured
# [2026.07.14 16:12:57.569] INFO    System profile saved to C:\Users\phys-pico-lab\AppData\Local\laboneq\profiles\unknown-613335402d7b7f78058d100a7c9ddd62592a6fd7431fa79c3e5a4ab0cfd13ec3.yaml

# %% [markdown]
# # Saving Data

# %%
# import FolderStore from the `workflow` namespace of LabOne Q, which was imported
# from `laboneq.simple`
folder_store = workflow.logbook.FolderStore(Path.cwd())
folder_store.activate()

logging_store = LoggingStore()
logging_store.activate()

# %% [markdown]
# # Resonator Spectroscopy

# %%
options = resonator_spectroscopy.experiment_workflow.options()
options.count(2**12)
# options.update(True) # updates the qubit parameter "readout_resonator_frequency"
options.close_figures(False)

# our qubits live here in the demo setup:
qubit_to_measure = qubits[0]

frequencies = qubit_to_measure.parameters.readout_resonator_frequency + np.linspace(
    -40e6, 40e6, 1001
)
# np.linspace(5.0325e9, 5.0425e9, 201)

exp_workflow = resonator_spectroscopy.experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=qubit_to_measure.uid,
    frequencies=frequencies,
    options=options,
)
workflow_result = exp_workflow.run()
# Out:
# [2026.07.14 16:14:32.299] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 16:14:32.299] INFO      Workflow 'resonator_spectroscopy': execution started at 2026-07-14
# [2026.07.14 16:14:32.299] INFO      13:14:32.299713Z
# [2026.07.14 16:14:32.299] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 16:14:32.359] INFO    Task 'temporary_qpu': started at 2026-07-14 13:14:32.350536Z
# [2026.07.14 16:14:32.362] INFO    Task 'temporary_qpu': ended at 2026-07-14 13:14:32.362085Z
# [2026.07.14 16:14:32.377] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-07-14
# [2026.07.14 16:14:32.380] INFO    13:14:32.367187Z
# [2026.07.14 16:14:32.382] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-07-14 13:14:32.380012Z
# [2026.07.14 16:14:32.382] INFO    Task 'create_experiment': started at 2026-07-14 13:14:32.382099Z
# [2026.07.14 16:14:32.419] INFO    Task 'create_experiment': ended at 2026-07-14 13:14:32.419365Z
# [2026.07.14 16:14:32.424] INFO    Task 'compile_experiment': started at 2026-07-14 13:14:32.424956Z
# [2026.07.14 16:14:32.430] INFO    Starting LabOne Q Compiler run...
# [2026.07.14 16:14:32.432] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.07.14 16:14:32.434] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.07.14 16:14:32.441] INFO    Schedule completed. [0.007 s]
# [2026.07.14 16:14:32.475] INFO    Code generation completed for all AWGs. [0.035 s]
# [2026.07.14 16:14:32.480] INFO    Completed compilation step 1 of 1. [0.046 s]
# [2026.07.14 16:14:32.483] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.14 16:14:32.483] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.07.14 16:14:32.483] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.14 16:14:32.483] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.07.14 16:14:32.490] INFO      SHFQC_DEV12192_sg     0          9            1           0         0
# [2026.07.14 16:14:32.490] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.14 16:14:32.490] INFO      TOTAL                           30            1                  8000
# [2026.07.14 16:14:32.490] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.14 16:14:32.501] INFO    Finished LabOne Q Compiler run.
# [2026.07.14 16:14:32.506] INFO    Task 'compile_experiment': ended at 2026-07-14 13:14:32.501672Z
# [2026.07.14 16:14:32.527] INFO    Task 'run_experiment': started at 2026-07-14 13:14:32.527464Z
# [2026.07.14 16:14:32.585] INFO    Starting near-time execution...
# [2026.07.14 16:14:32.663] INFO    Estimated RT execution time: 12.66 s.
# [2026.07.14 16:14:45.392] INFO    Finished near-time execution.
# [2026.07.14 16:14:45.461] INFO    Task 'run_experiment': ended at 2026-07-14 13:14:45.461600Z
# [2026.07.14 16:14:45.461] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 16:14:45.461] INFO      Workflow 'analysis_workflow': execution started at 2026-07-14
# [2026.07.14 16:14:45.461] INFO      13:14:45.461600Z
# [2026.07.14 16:14:45.461] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 16:14:45.490] INFO    Task 'calculate_signal_magnitude_and_phase': started at 2026-07-14
# [2026.07.14 16:14:45.493] INFO    13:14:45.490739Z
# [2026.07.14 16:14:45.495] INFO    Task 'calculate_signal_magnitude_and_phase': ended at 2026-07-14
# [2026.07.14 16:14:45.495] INFO    13:14:45.493819Z
# [2026.07.14 16:14:45.509] INFO    Task 'fit_data': started at 2026-07-14 13:14:45.509236Z
# [2026.07.14 16:14:45.517] INFO    Task 'fit_data': ended at 2026-07-14 13:14:45.514883Z
# [2026.07.14 16:14:45.520] INFO    Task 'extract_qubit_parameters': started at 2026-07-14 13:14:45.520566Z
# [2026.07.14 16:14:45.530] INFO    Task 'extract_qubit_parameters': ended at 2026-07-14 13:14:45.530138Z
# [2026.07.14 16:14:45.535] INFO    Task 'plot_raw_complex_data_1d': started at 2026-07-14 13:14:45.535705Z
# [2026.07.14 16:14:45.565] INFO    Artifact: 'Raw_data_q0' of type 'Figure' logged at 2026-07-14 13:14:45.565648Z
# [2026.07.14 16:14:45.866] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-07-14 13:14:45.864115Z
# [2026.07.14 16:14:45.872] INFO    Task 'plot_magnitude_phase': started at 2026-07-14 13:14:45.866533Z
# [2026.07.14 16:14:45.897] INFO    Artifact: 'Magnitude_Phase_q0' of type 'Figure' logged at 2026-07-14
# [2026.07.14 16:14:45.897] INFO    13:14:45.897499Z
# [2026.07.14 16:14:46.099] INFO    Task 'plot_magnitude_phase': ended at 2026-07-14 13:14:46.099747Z
# [2026.07.14 16:14:46.105] INFO    Task 'plot_real_imaginary': started at 2026-07-14 13:14:46.105038Z
# [2026.07.14 16:14:46.121] INFO    Artifact: 'Real_Imaginary_q0' of type 'Figure' logged at 2026-07-14
# [2026.07.14 16:14:46.138] INFO    13:14:46.121206Z
# [2026.07.14 16:14:46.331] INFO    Task 'plot_real_imaginary': ended at 2026-07-14 13:14:46.330016Z
# [2026.07.14 16:14:46.332] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 16:14:46.332] INFO      Workflow 'analysis_workflow': execution ended at 2026-07-14 13:14:46.332850Z
# [2026.07.14 16:14:46.332] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 16:14:46.346] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 16:14:46.346] INFO      Workflow 'resonator_spectroscopy': execution ended at 2026-07-14
# [2026.07.14 16:14:46.346] INFO      13:14:46.342363Z
# [2026.07.14 16:14:46.352] INFO     ──────────────────────────────────────────────────────────────────────────────

# %%
print("Readout resonator frequency: ", qubit_to_measure.parameters.readout_resonator_frequency)
analysis_workflow_result= workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

# compiled_experiment = workflow_result.tasks["compile_experiment"].output
# plot_simulation(compiled_experiment, length=50e-6, signal_names_to_show=["measure"])
# Out:
# Readout resonator frequency:  5037000000.0
# {'new_parameter_values': {'q0': {'readout_resonator_frequency': 5037480000.0+/-0}},
#  'old_parameter_values': {'q0': {'readout_resonator_frequency': 5037000000.0}}}

# %%
resonator_spectroscopy.update_qpu(qpu, qubit_parameters["new_parameter_values"])
qpu.quantum_elements[0].parameters.readout_resonator_frequency
# Out:
# 5037480000.0

# %% [markdown]
# # Resonator Frequency & Amplitude Spectroscopy

# %%
options = resonator_spectroscopy_amplitude.experiment_workflow.options()
options.count(2**12)
options.update(True) # updates the qubit parameter "readout_resonator_frequency"
options.close_figures(False)

# our qubits live here in the demo setup:
qubit_to_measure = qubits[0]

frequencies = qubit_to_measure.parameters.readout_resonator_frequency + np.linspace(
    -40e6, 40e6, 1001
)
# np.linspace(5.03e9, 5.045e9, 201)

exp_workflow_amp = resonator_spectroscopy_amplitude.experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=qubit_to_measure.uid,
    frequencies=frequencies,
    amplitudes=np.linspace(0.1, 0.9, 10),
    options=options,
)

workflow_result_amp = exp_workflow_amp.run()
# Out:
# [2026.07.14 16:29:45.412] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 16:29:45.414] INFO      Workflow 'resonator_spectroscopy_amplitude': execution started at 2026-07-14
# [2026.07.14 16:29:45.414] INFO      13:29:45.412314Z
# [2026.07.14 16:29:45.414] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 16:29:45.474] INFO    Task 'temporary_qpu': started at 2026-07-14 13:29:45.474938Z
# [2026.07.14 16:29:45.484] INFO    Task 'temporary_qpu': ended at 2026-07-14 13:29:45.482702Z
# [2026.07.14 16:29:45.491] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-07-14
# [2026.07.14 16:29:45.493] INFO    13:29:45.491146Z
# [2026.07.14 16:29:45.495] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-07-14 13:29:45.495943Z
# [2026.07.14 16:29:45.495] INFO    Task 'create_experiment': started at 2026-07-14 13:29:45.495943Z
# [2026.07.14 16:29:45.540] INFO    Task 'create_experiment': ended at 2026-07-14 13:29:45.540215Z
# [2026.07.14 16:29:45.548] INFO    Task 'compile_experiment': started at 2026-07-14 13:29:45.548365Z
# [2026.07.14 16:29:45.559] INFO    Starting LabOne Q Compiler run...
# [2026.07.14 16:29:45.559] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.07.14 16:29:45.564] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.07.14 16:29:45.588] INFO    Schedule completed. [0.021 s]
# [2026.07.14 16:29:45.636] INFO    Code generation completed for all AWGs. [0.046 s]
# [2026.07.14 16:29:45.636] INFO    Completed compilation step 1 of 10. [0.071 s]
# [2026.07.14 16:29:45.636] INFO    Skipping compilation for next step(s)...
# [2026.07.14 16:29:45.636] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.14 16:29:45.636] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.07.14 16:29:45.648] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.14 16:29:45.648] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.07.14 16:29:45.648] INFO      SHFQC_DEV12192_sg     0          9            1           0         0
# [2026.07.14 16:29:45.651] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.14 16:29:45.651] INFO      TOTAL                           30            1                  8000
# [2026.07.14 16:29:45.651] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.14 16:29:45.665] INFO    Finished LabOne Q Compiler run.
# [2026.07.14 16:29:45.667] INFO    Task 'compile_experiment': ended at 2026-07-14 13:29:45.665934Z
# [2026.07.14 16:29:45.685] INFO    Task 'run_experiment': started at 2026-07-14 13:29:45.685808Z
# [2026.07.14 16:29:45.748] INFO    Starting near-time execution...
# [2026.07.14 16:29:45.811] INFO    Estimated RT execution time: 12.66 s.
# [2026.07.14 16:29:58.573] INFO    Estimated RT execution time: 12.66 s.
# [2026.07.14 16:30:11.315] INFO    Estimated RT execution time: 12.66 s.
# [2026.07.14 16:30:24.100] INFO    Estimated RT execution time: 12.66 s.
# [2026.07.14 16:30:36.908] INFO    Estimated RT execution time: 12.66 s.
# [2026.07.14 16:30:49.700] INFO    Estimated RT execution time: 12.66 s.
# [2026.07.14 16:31:02.494] INFO    Estimated RT execution time: 12.66 s.
# [2026.07.14 16:31:15.287] INFO    Estimated RT execution time: 12.66 s.
# [2026.07.14 16:31:28.082] INFO    Estimated RT execution time: 12.66 s.
# [2026.07.14 16:31:40.851] INFO    Estimated RT execution time: 12.66 s.
# [2026.07.14 16:31:53.587] INFO    Finished near-time execution.
# [2026.07.14 16:31:53.746] INFO    Task 'run_experiment': ended at 2026-07-14 13:31:53.746267Z
# [2026.07.14 16:31:53.764] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 16:31:53.777] INFO      Workflow 'analysis_workflow': execution started at 2026-07-14
# [2026.07.14 16:31:53.779] INFO      13:31:53.764327Z
# [2026.07.14 16:31:53.780] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 16:31:53.782] INFO    Task 'plot_raw_complex_data_2d': started at 2026-07-14 13:31:53.782453Z
# [2026.07.14 16:31:53.861] INFO    Artifact: 'Raw_data_q0' of type 'Figure' logged at 2026-07-14 13:31:53.859503Z
# [2026.07.14 16:31:54.257] INFO    Task 'plot_raw_complex_data_2d': ended at 2026-07-14 13:31:54.257764Z
# [2026.07.14 16:31:54.257] INFO    Task 'plot_signal_magnitude_and_phase_2d': started at 2026-07-14
# [2026.07.14 16:31:54.266] INFO    13:31:54.257764Z
# [2026.07.14 16:31:54.369] INFO    Artifact: 'Magnitude_Phase_q0' of type 'Figure' logged at 2026-07-14
# [2026.07.14 16:31:54.369] INFO    13:31:54.369969Z
# [2026.07.14 16:31:54.851] INFO    Task 'plot_signal_magnitude_and_phase_2d': ended at 2026-07-14 13:31:54.851881Z
# [2026.07.14 16:31:54.851] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 16:31:54.851] INFO      Workflow 'analysis_workflow': execution ended at 2026-07-14 13:31:54.851881Z
# [2026.07.14 16:31:54.860] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 16:31:54.863] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 16:31:54.865] INFO      Workflow 'resonator_spectroscopy_amplitude': execution ended at 2026-07-14
# [2026.07.14 16:31:54.866] INFO      13:31:54.861110Z
# [2026.07.14 16:31:54.867] INFO     ──────────────────────────────────────────────────────────────────────────────

# %%
print("Readout resonator frequency: ", qubit_to_measure.parameters.readout_resonator_frequency)
print("Readout resonator amplitude: ", qubit_to_measure.parameters.readout_amplitude)
analysis_workflow_result_amp = workflow_result_amp.tasks["analysis_workflow"]
qubit_parameters_amp = analysis_workflow_result_amp.output
pprint(qubit_parameters_amp)

# compiled_experiment = workflow_result.tasks["compile_experiment"].output
# plot_simulation(compiled_experiment, length=50e-6, signal_names_to_show=["measure"])
# Out:
# Readout resonator frequency:  5037480000.0
# Readout resonator amplitude:  0.5
# None

# %%
# resonator_spectroscopy.update_qpu(qpu, qubit_parameters_amp["new_parameter_values"])
# print(qpu.quantum_elements[0].parameters.readout_resonator_frequency)
# print(qpu.quantum_elements[0].parameters.readout_amplitude)

# %% [markdown]
# # Qubit Spectroscopy

# %%
options = qubit_spectroscopy.experiment_workflow.options()
options.count(2**12)
# options.update(True)  # updates the qubit parameter "resonance_frequency_ge"
options.close_figures(False)

qubits_to_measure = [qubits[0]]

temporary_parameters = {}
for q in qubits_to_measure:
    temp_pars = deepcopy(q.parameters)
    temp_pars.drive_range = -30
    temp_pars.spectroscopy_amplitude = 1
    temporary_parameters[q.uid] = temp_pars

frequencies = [
    q.parameters.resonance_frequency_ge + np.linspace(-20e6, 20e6, 201)
    for q in qubits_to_measure
]
exp_workflow = qubit_spectroscopy.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    temporary_parameters=temporary_parameters,
    frequencies=frequencies,
    options=options,
)
workflow_result = exp_workflow.run()
# Out:
# [2026.07.14 16:36:19.701] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 16:36:19.701] INFO      Workflow 'qubit_spectroscopy': execution started at 2026-07-14
# [2026.07.14 16:36:19.701] INFO      13:36:19.701067Z
# [2026.07.14 16:36:19.701] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 16:36:19.738] INFO    Task 'temporary_qpu': started at 2026-07-14 13:36:19.738097Z
# [2026.07.14 16:36:19.743] INFO    Task 'temporary_qpu': ended at 2026-07-14 13:36:19.743127Z
# [2026.07.14 16:36:19.753] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-07-14
# [2026.07.14 16:36:19.756] INFO    13:36:19.753732Z
# [2026.07.14 16:36:19.756] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-07-14 13:36:19.756065Z
# [2026.07.14 16:36:19.765] INFO    Task 'create_experiment': started at 2026-07-14 13:36:19.764050Z
# [2026.07.14 16:36:19.781] INFO    Task 'create_experiment': ended at 2026-07-14 13:36:19.781819Z
# [2026.07.14 16:36:19.781] INFO    Task 'compile_experiment': started at 2026-07-14 13:36:19.781819Z
# [2026.07.14 16:36:19.797] INFO    Starting LabOne Q Compiler run...
# [2026.07.14 16:36:19.797] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.07.14 16:36:19.808] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.07.14 16:36:19.808] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.07.14 16:36:19.808] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.07.14 16:36:19.816] INFO    Schedule completed. [0.004 s]
# [2026.07.14 16:36:19.829] INFO    Code generation completed for all AWGs. [0.012 s]
# [2026.07.14 16:36:19.831] INFO    Completed compilation step 1 of 1. [0.019 s]
# [2026.07.14 16:36:19.831] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.14 16:36:19.831] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.07.14 16:36:19.845] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.14 16:36:19.846] INFO      SHFQC_DEV12192        0         10            0           1      8000
# [2026.07.14 16:36:19.846] INFO      SHFQC_DEV12192_sg     0         25            2           1        64
# [2026.07.14 16:36:19.846] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.14 16:36:19.846] INFO      TOTAL                           35            2                  8064
# [2026.07.14 16:36:19.846] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.14 16:36:19.861] INFO    Finished LabOne Q Compiler run.
# [2026.07.14 16:36:19.862] INFO    Task 'compile_experiment': ended at 2026-07-14 13:36:19.862486Z
# [2026.07.14 16:36:19.878] INFO    Task 'run_experiment': started at 2026-07-14 13:36:19.863664Z
# [2026.07.14 16:36:19.925] INFO    Starting near-time execution...
# [2026.07.14 16:36:20.016] INFO    Estimated RT execution time: 6.66 s.
# [2026.07.14 16:36:26.830] INFO    Finished near-time execution.
# [2026.07.14 16:36:26.929] INFO    Task 'run_experiment': ended at 2026-07-14 13:36:26.929173Z
# [2026.07.14 16:36:26.946] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 16:36:26.948] INFO      Workflow 'analysis_workflow': execution started at 2026-07-14
# [2026.07.14 16:36:26.948] INFO      13:36:26.946829Z
# [2026.07.14 16:36:26.948] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 16:36:26.956] INFO    Task 'calculate_signal_magnitude_and_phase': started at 2026-07-14
# [2026.07.14 16:36:26.956] INFO    13:36:26.956378Z
# [2026.07.14 16:36:26.956] INFO    Task 'calculate_signal_magnitude_and_phase': ended at 2026-07-14
# [2026.07.14 16:36:26.956] INFO    13:36:26.956378Z
# [2026.07.14 16:36:26.972] INFO    Task 'fit_data': started at 2026-07-14 13:36:26.972025Z
# [2026.07.14 16:36:27.678] INFO    Task 'fit_data': ended at 2026-07-14 13:36:27.678005Z
# [2026.07.14 16:36:27.694] INFO    Task 'extract_qubit_parameters': started at 2026-07-14 13:36:27.678005Z
# [2026.07.14 16:36:27.704] INFO    Task 'extract_qubit_parameters': ended at 2026-07-14 13:36:27.703083Z
# [2026.07.14 16:36:27.709] INFO    Task 'plot_raw_complex_data_1d': started at 2026-07-14 13:36:27.709884Z
# [2026.07.14 16:36:27.731] INFO    Artifact: 'Raw_data_q0' of type 'Figure' logged at 2026-07-14 13:36:27.731241Z
# [2026.07.14 16:36:28.042] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-07-14 13:36:28.042177Z
# [2026.07.14 16:36:28.049] INFO    Task 'plot_qubit_spectroscopy': started at 2026-07-14 13:36:28.049917Z
# [2026.07.14 16:36:28.070] INFO    Artifact: 'Qubit_Spectroscopy_q0' of type 'Figure' logged at 2026-07-14
# [2026.07.14 16:36:28.081] INFO    13:36:28.070971Z
# [2026.07.14 16:36:28.406] INFO    Task 'plot_qubit_spectroscopy': ended at 2026-07-14 13:36:28.406685Z
# [2026.07.14 16:36:28.406] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 16:36:28.420] INFO      Workflow 'analysis_workflow': execution ended at 2026-07-14 13:36:28.406685Z
# [2026.07.14 16:36:28.420] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 16:36:28.426] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 16:36:28.426] INFO      Workflow 'qubit_spectroscopy': execution ended at 2026-07-14
# [2026.07.14 16:36:28.426] INFO      13:36:28.426094Z
# [2026.07.14 16:36:28.426] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ## Dealy Opt

# %%
delay_sweep = LinearSweepParameter(
    uid="delay_sweep_param", start=0, stop=0.2e-6, count=101
)

# define number of averages
# used for 2^num_averages, maximum: num_averages = 17
num_averages = 14

# readout pulse parameters and definition
envelope_duration = 2.048e-6
envelope_rise_fall_time = 0.05e-6
readout_pulse = pulse_library.gaussian_square(
    uid="readout_pulse", length=envelope_duration, amplitude=0.9
)

# %%
readout_pulse
# Out:
# PulseFunctional(
# │   function='gaussian_square',
# │   uid='readout_pulse',
# │   amplitude=0.9,
# │   length=2.048e-06,
# │   can_compress=False,
# │   pulse_parameters=None
# )

# %%
# function that defines a resonator spectroscopy experiment, and takes the frequency sweep as a parameter


def propagation_delay(readout_pulse, delay_sweep):
    # Create resonator spectroscopy experiment - uses only readout drive and signal acquisition
    exp_prop_delay = Experiment(
        uid="Propagation Delay Measurement",
        signals=[
            ExperimentSignal("measure"),
            ExperimentSignal("acquire"),
        ],
    )

    ## define experimental sequence
    # outer loop - vary drive frequency
    with exp_prop_delay.sweep(uid="del_sweep", parameter=delay_sweep):
        with exp_prop_delay.acquire_loop_rt(
            uid="shots",
            count=2**num_averages,
            acquisition_type=AcquisitionType.INTEGRATION,
        ):
            # readout pulse and data acquisition
            with exp_prop_delay.section(uid="spectroscopy"):
                # play resonator excitation pulse
                exp_prop_delay.play(signal="measure", pulse=readout_pulse)
                # resonator signal readout
                exp_prop_delay.acquire(
                    signal="acquire", handle="res_prop_delay", kernel=readout_pulse
                )
            # relax time after readout - for signal processing and qubit relaxation to ground state
            with exp_prop_delay.section(uid="relax", length=1e-6):
                exp_prop_delay.reserve(signal="measure")

        cal = Calibration()
        cal["acquire"] = SignalCalibration(port_delay=delay_sweep)
        exp_prop_delay.set_calibration(cal)

    return exp_prop_delay

# %%
# signal maps for a qubit - maps the logical signal of the device setup to the experimental signals of the experiment


def res_spec_map(qubit):
    signal_map = {
        "measure": setup.logical_signal_groups[f"{qubit}"].logical_signals[
            "measure"
        ],
        "acquire": setup.logical_signal_groups[f"{qubit}"].logical_signals[
            "acquire"
        ],
    }
    return signal_map


# pass sweep and pulse to experiment and apply signal map
exp_prop_delay = propagation_delay(readout_pulse, delay_sweep)
exp_prop_delay.set_signal_map(res_spec_map("q0"))

# %%
# compile the experiment on the open instrument session
compiled_prop_delay = session.compile(exp_prop_delay)

Path("Pulse_Sheets").mkdir(parents=True, exist_ok=True)
# generate a pulse sheet to inspect experiment before runtime
show_pulse_sheet("Pulse_Sheets/Propagation_Delay", compiled_prop_delay)
# Out:
# [2026.07.14 14:00:45.662] INFO    Starting LabOne Q Compiler run...
# [2026.07.14 14:00:45.673] INFO    Schedule completed. [0.000 s]
# [2026.07.14 14:00:45.673] INFO    Code generation completed for all AWGs. [0.001 s]
# [2026.07.14 14:00:45.678] INFO    Completed compilation step 1 of 101. [0.004 s]
# [2026.07.14 14:00:45.679] INFO    Skipping compilation for next step(s)...
# [2026.07.14 14:00:45.681] INFO     ────────────────────────────────────────────────────────────────────
# [2026.07.14 14:00:45.681] INFO      Device           AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.07.14 14:00:45.696] INFO     ────────────────────────────────────────────────────────────────────
# [2026.07.14 14:00:45.696] INFO      SHFQC_DEV12192     0          7            0           1      8192
# [2026.07.14 14:00:45.698] INFO     ────────────────────────────────────────────────────────────────────
# [2026.07.14 14:00:45.698] INFO      TOTAL                         7            0                  8192
# [2026.07.14 14:00:45.698] INFO     ────────────────────────────────────────────────────────────────────
# [2026.07.14 14:00:45.712] INFO    Finished LabOne Q Compiler run.
# [2026.07.14 14:00:45.712] INFO    Recompiling the experiment due to missing extra information in the compiled experiment. Compile with `OUTPUT_EXTRAS=True` and `MAX_EVENTS_TO_PUBLISH=1000` to bypass this step with a small impact on the compilation time.
# [2026.07.14 14:00:45.717] INFO    Starting LabOne Q Compiler run...
# [2026.07.14 14:00:45.732] INFO    Schedule completed. [0.012 s]
# [2026.07.14 14:00:45.732] INFO    Code generation completed for all AWGs. [0.002 s]
# [2026.07.14 14:00:45.732] INFO    Completed compilation step 1 of 101. [0.020 s]
# [2026.07.14 14:00:45.732] INFO    Skipping compilation for next step(s)...
# [2026.07.14 14:00:45.744] INFO    Finished LabOne Q Compiler run.
# [2026.07.14 14:00:45.744] WARNING Pulse sheet viewer: The event list was truncated to 998 events. Some later events are not shown. Increase `max_events_to_publish` in `show_pulse_sheet()` to display the full schedule.
# [2026.07.14 14:00:45.775] INFO    Writing html file to C:\Users\phys-pico-lab\Documents\Python_virtual_environments\meas_venv_workflow_py312\Scripts\meas\Pulse_Sheets\Propagation_Delay_2026-07-14-14-00-45.html
# C:\Users\phys-pico-lab\Documents\Python_virtual_environments\meas_venv_workflow_py312\Scripts\meas\Pulse_Sheets\Propagation_Delay_2026-07-14-14-00-45.html

# %%
# run the compiled experiemnt
prop_delay_results = session.run(compiled_prop_delay)
timestamp = time.strftime("%Y%m%dT%H%M%S")
Path("Results").mkdir(parents=True, exist_ok=True)
save(prop_delay_results, f"Results/{timestamp}_prop_delay_results.json")
print(f"File saved as Results/{timestamp}_prop_delay_results.json")
# Out:
# [2026.07.14 14:00:46.871] INFO    Starting near-time execution...
# [2026.07.14 14:01:07.098] INFO    Finished near-time execution.
# File saved as Results/20260714T140108_prop_delay_results.json

# %%
plot_results(prop_delay_results, phase=True, plot_width=5, plot_height=8)
