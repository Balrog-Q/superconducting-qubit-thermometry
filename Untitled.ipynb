# %% [markdown]
# # Imports & Inits

# %%
# LabOne Q:
from laboneq.simple import *
from laboneq.dsl.quantum import QPU
from laboneq.contrib.example_helpers.generate_descriptor import generate_descriptor
from laboneq.workflow.logbook import LoggingStore

# LabOne Q Applications:
from laboneq_applications.qpu_types.tunable_transmon import (
    TunableTransmonQubit,
    TunableTransmonOperations,
)

# Packages:
from copy import deepcopy
from pprint import pprint
import numpy as np
import time
from pathlib import Path

# Plot:
from laboneq.contrib.example_helpers.plotting.plot_helpers import plot_results, plot_simulation

# Workflows:
from laboneq_applications.experiments import (
    resonator_spectroscopy,
    resonator_spectroscopy_amplitude,
    qubit_spectroscopy,
    amplitude_rabi,
    ramsey,
    drag_q_scaling,
    lifetime_measurement,
    echo,
)

# %%
number_of_qubits = 1

descriptor = generate_descriptor(
    #pqsc=["DEV10001"],
    shfqc_2=["DEV12192"],
    number_data_qubits=number_of_qubits,
    multiplex=True,
    number_multiplex=number_of_qubits,
    include_cr_lines=False,
    ip_address="localhost",
    #options = "SHFQC/QC2CH",
)

setup = DeviceSetup.from_descriptor(descriptor, "localhost")
setup.instruments[0].device_options = "SHFQC/QC2CH"

# %%
setup.logical_signal_groups
# Out:
# {'q0': LogicalSignalGroup(
# │   uid='q0',
# │   logical_signals={
# │   │   'drive': LogicalSignal(
# │   │   │   uid='q0/drive',
# │   │   │   direction=IODirection.OUT,
# │   │   │   name='drive',
# │   │   │   calibration=None,
# │   │   │   path='/logical_signal_groups/q0/drive',
# │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   uid='SHFQC_DEV12192/sgchannels_0_output',
# │   │   │   │   name='sgchannels_0_output',
# │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   path='/physical_channel_groups/SHFQC_DEV12192/sgchannels_0_output',
# │   │   │   │   calibration=None
# │   │   │   )
# │   │   ),
# │   │   'drive_ef': LogicalSignal(
# │   │   │   uid='q0/drive_ef',
# │   │   │   direction=IODirection.OUT,
# │   │   │   name='drive_ef',
# │   │   │   calibration=None,
# │   │   │   path='/logical_signal_groups/q0/drive_ef',
# │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   uid='SHFQC_DEV12192/sgchannels_0_output',
# │   │   │   │   name='sgchannels_0_output',
# │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   path='/physical_channel_groups/SHFQC_DEV12192/sgchannels_0_output',
# │   │   │   │   calibration=None
# │   │   │   )
# │   │   ),
# │   │   'measure': LogicalSignal(
# │   │   │   uid='q0/measure',
# │   │   │   direction=IODirection.OUT,
# │   │   │   name='measure',
# │   │   │   calibration=None,
# │   │   │   path='/logical_signal_groups/q0/measure',
# │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   uid='SHFQC_DEV12192/qachannels_0_output',
# │   │   │   │   name='qachannels_0_output',
# │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   path='/physical_channel_groups/SHFQC_DEV12192/qachannels_0_output',
# │   │   │   │   calibration=None
# │   │   │   )
# │   │   ),
# │   │   'acquire': LogicalSignal(
# │   │   │   uid='q0/acquire',
# │   │   │   direction=IODirection.IN,
# │   │   │   name='acquire',
# │   │   │   calibration=None,
# │   │   │   path='/logical_signal_groups/q0/acquire',
# │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   uid='SHFQC_DEV12192/qachannels_0_input',
# │   │   │   │   name='qachannels_0_input',
# │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   path='/physical_channel_groups/SHFQC_DEV12192/qachannels_0_input',
# │   │   │   │   calibration=None
# │   │   │   )
# │   │   )
# │   }
# )
# }

# %%
qubits = TunableTransmonQubit.from_device_setup(setup)

for q in qubits:
    print("-------------")
    print("Qubit UID:", q.uid)
    print("Qubit logical signals:")
    for sig, lsg in q.signals.items():
        print(f"  {sig:<10} ('{lsg:>10}')")
# Out:
# -------------
# Qubit UID: q0
# Qubit logical signals:
#   drive      ('  q0/drive')
#   drive_ef   ('q0/drive_ef')
#   measure    ('q0/measure')
#   acquire    ('q0/acquire')

# %%
for q in qubits:
    q.parameters.ge_drive_pulse["sigma"] = 0.25
    q.parameters.readout_amplitude = 0.5
    q.parameters.reset_delay_length = 150e-6
    q.parameters.readout_range_out = -30
    q.parameters.readout_lo_frequency = 5e9
    q.parameters.drive_range = -30
    q.parameters.readout_range_in = -45
    q.parameters.readout_integration_delay = 80e-9

qubits[0].parameters.drive_lo_frequency = 3.6e9
qubits[0].parameters.resonance_frequency_ge = 3.748e9
qubits[0].parameters.resonance_frequency_ef = 3.51e9
qubits[0].parameters.readout_resonator_frequency = 5.037e9
qubits[0].parameters.spectroscopy_length = 20e-6
qubits[0].parameters.spectroscopy_amplitude = 0.5

# qubits[1].parameters.drive_lo_frequency = 6.4e9
# qubits[1].parameters.resonance_frequency_ge = 6.5e9
# qubits[1].parameters.resonance_frequency_ef = 6.3e9
# qubits[1].parameters.readout_resonator_frequency = 7.3e9

# %%
qops = TunableTransmonOperations()
qpu = QPU(qubits, quantum_operations=qops)
qpu.quantum_elements
# Out:
# [TunableTransmonQubit(
# │   uid='q0',
# │   signals={
# │   │   'drive': 'q0/drive',
# │   │   'drive_ef': 'q0/drive_ef',
# │   │   'measure': 'q0/measure',
# │   │   'acquire': 'q0/acquire'
# │   },
# │   parameters=TunableTransmonQubitParameters(
# │   │   custom={},
# │   │   ge_T1=0,
# │   │   ge_T2=0,
# │   │   ge_T2_star=0,
# │   │   ef_T1=0,
# │   │   ef_T2=0,
# │   │   ef_T2_star=0,
# │   │   drive_lo_frequency=3600000000.0,
# │   │   readout_lo_frequency=5000000000.0,
# │   │   resonance_frequency_ge=3748000000.0,
# │   │   resonance_frequency_ef=3510000000.0,
# │   │   readout_resonator_frequency=5037000000.0,
# │   │   ge_drive_amplitude_pi=0.2,
# │   │   ge_drive_amplitude_pi2=0.1,
# │   │   ge_drive_length=5e-08,
# │   │   ge_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   ef_drive_amplitude_pi=0.2,
# │   │   ef_drive_amplitude_pi2=0.1,
# │   │   ef_drive_length=5e-08,
# │   │   ef_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   qubit_resonator_coupling_strength_g=0,
# │   │   ge_chi_shift=0,
# │   │   readout_amplitude=0.5,
# │   │   readout_length=2e-06,
# │   │   readout_pulse={
# │   │   │   'function': 'const'
# │   │   },
# │   │   readout_integration_length=2e-06,
# │   │   readout_integration_delay=8e-08,
# │   │   readout_integration_kernels_type='default',
# │   │   readout_integration_kernels=None,
# │   │   readout_integration_discrimination_thresholds=None,
# │   │   reset_delay_length=0.0001,
# │   │   drive_range=5,
# │   │   readout_range_out=-30,
# │   │   readout_range_in=-45,
# │   │   flux_range=5,
# │   │   spectroscopy_length=5e-06,
# │   │   spectroscopy_amplitude=1,
# │   │   spectroscopy_pulse={
# │   │   │   'function': 'const',
# │   │   │   'can_compress': True
# │   │   },
# │   │   dc_slot=0,
# │   │   dc_voltage_parking=0.0,
# │   │   flux_offset_voltage=0.0,
# │   │   user_defined={}
# │   )
# )
# ]

# %%
session = Session(setup)
session.connect(do_emulation=False)  # do_emulation=False when at a real setup
# Out:
# [2026.07.14 17:42:45.351] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is C:\Users\phys-pico-lab\Documents\Python_virtual_environments\meas_venv_workflow_py312\Scripts\meas\laboneq_output\log
# [2026.07.14 17:42:45.389] INFO    VERSION: laboneq 26.4.0
# [2026.07.14 17:42:45.393] INFO    Connecting to data server at localhost:8004
# [2026.07.14 17:42:45.428] INFO    Connected to Zurich Instruments LabOne Data Server version 26.04.1.6 at localhost:8004
# [2026.07.14 17:42:45.446] INFO    Configuring the device setup
# [2026.07.14 17:42:45.471] INFO    The device setup is configured
# [2026.07.14 17:42:45.709] INFO    System profile saved to C:\Users\phys-pico-lab\AppData\Local\laboneq\profiles\unknown-613335402d7b7f78058d100a7c9ddd62592a6fd7431fa79c3e5a4ab0cfd13ec3.yaml

# %% [markdown]
# # Saving Data

# %%
# import FolderStore from the `workflow` namespace of LabOne Q, which was imported
# from `laboneq.simple`
folder_store = workflow.logbook.FolderStore(Path.cwd())
folder_store.activate()

logging_store = LoggingStore()
logging_store.activate()

# %% [markdown]
# # Resonator Spectroscopy

# %%
options = resonator_spectroscopy.experiment_workflow.options()
options.count(2**12)
# options.update(True) # updates the qubit parameter "readout_resonator_frequency"
options.close_figures(False)

# our qubits live here in the demo setup:
qubit_to_measure = qubits[0]

frequencies = qubit_to_measure.parameters.readout_resonator_frequency + np.linspace(
    -10e6, 10e6, 201
)
# np.linspace(5.0325e9, 5.0425e9, 201)

exp_workflow = resonator_spectroscopy.experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=qubit_to_measure.uid,
    frequencies=frequencies,
    options=options,
)
workflow_result = exp_workflow.run()
# Out:
# [2026.07.14 17:42:45.751] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 17:42:45.763] INFO      Workflow 'resonator_spectroscopy': execution started at 2026-07-14
# [2026.07.14 17:42:45.765] INFO      14:42:45.751935Z
# [2026.07.14 17:42:45.765] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 17:42
INFO    Artifact: 'Raw_data_q0' of type 'Figure' logged at 2026-07-14 14:42:48.893121Z
# [2026.07.14 17:42:49.831] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-07-14 14:42:49.831697Z
# [2026.07.14 17:42:49.835] INFO    Task 'plot_magnitude_phase': started at 2026-07-14 14:42:49.835738Z
# [2026.07.14 17:42:49.875] INFO    Artifact: 'Magnitude_Phase_q0' of type 'Figure' logged at 2026-07-14
# [2026.07.14 17:42:49.877] INFO    14:42:49.875557Z
# [2026.07.14 17:42:50.145] INFO    Task 'plot_magnitude_phase': ended at 2026-07-14 14:42:50.145092Z
# [2026.07.14 17:42:50.145] INFO    Task 'plot_real_imaginary': started at 2026-07-14 14:42:50.145092Z
# [2026.07.14 17:42:50.169] INFO    Artifact: 'Real_Imaginary_q0' of type 'Figure' logged at 2026-07-14
# [2026.07.14 17:42:50.169] INFO    14:42:50.169296Z
# [2026.07.14 17:42:50.332] INFO    Task 'plot_real_imaginary': ended at 2026-07-14 14:42:50.332625Z
# [2026.07.14 17:42:50.346] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 17:42:50.347] INFO      Workflow 'analysis_workflow': execution ended at 2026-07-14 14:42:50.344517Z
# [2026.07.14 17:42:50.347] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 17:42:50.347] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 17:42:50.347] INFO      Workflow 'resonator_spectroscopy': execution ended at 2026-07-14
# [2026.07.14 17:42:50.347] INFO      14:42:50.347084Z
# [2026.07.14 17:42:50.347] INFO     ──────────────────────────────────────────────────────────────────────────────

# %%
analysis_workflow_result= workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)
resonator_spectroscopy.update_qpu(qpu, qubit_parameters["new_parameter_values"])
print("Readout resonator frequency: ", qubit_to_measure.parameters.readout_resonator_frequency)

# compiled_experiment = workflow_result.tasks["compile_experiment"].output
# plot_simulation(compiled_experiment, length=50e-6, signal_names_to_show=["measure"])
# Out:
# {'new_parameter_values': {'q0': {'readout_resonator_frequency': 5037400000.0+/-0}},
#  'old_parameter_values': {'q0': {'readout_resonator_frequency': 5037000000.0}}}
# Readout resonator frequency:  5037400000.0

# %% [markdown]
# # Resonator Frequency & Amplitude Spectroscopy

# %%
options = resonator_spectroscopy_amplitude.experiment_workflow.options()
options.count(2**12)
options.update(True) # updates the qubit parameter "readout_resonator_frequency"
options.close_figures(False)

# our qubits live here in the demo setup:
qubit_to_measure = qubits[0]

frequencies = qubit_to_measure.parameters.readout_resonator_frequency + np.linspace(
    -40e6, 40e6, 1001
)
# np.linspace(5.03e9, 5.045e9, 201)

exp_workflow_amp = resonator_spectroscopy_amplitude.experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=qubit_to_measure.uid,
    frequencies=frequencies,
    amplitudes=np.linspace(0.1, 0.9, 10),
    options=options,
)

workflow_result_amp = exp_workflow_amp.run()
# Out:
# [2026.07.14 17:43:19.986] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 17:43:19.988] INFO      Workflow 'resonator_spectroscopy_amplitude': execution started at 2026-07-14
# [2026.07.14 17:43:19.988] INFO      14:43:19.986376Z
# [2026.07.14 17:43:19.988] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 17:43:20.020] INFO    Task 'temporary_qpu': started at 2026-07-14 14:43:20.017698Z
# [2026.07.14 17:43:20.021] INFO    Task 'temporary_qpu': ended at 2026-07-14 14:43:20.021741Z
# [2026.07.14 17:43:20.029] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026
INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 17:45:29.841] INFO      Workflow 'analysis_workflow': execution ended at 2026-07-14 14:45:29.830906Z
# [2026.07.14 17:45:29.841] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 17:45:29.841] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 17:45:29.841] INFO      Workflow 'resonator_spectroscopy_amplitude': execution ended at 2026-07-14
# [2026.07.14 17:45:29.841] INFO      14:45:29.841814Z
# [2026.07.14 17:45:29.850] INFO     ──────────────────────────────────────────────────────────────────────────────

# %%
analysis_workflow_result_amp = workflow_result_amp.tasks["analysis_workflow"]
qubit_parameters_amp = analysis_workflow_result_amp.output
pprint(qubit_parameters_amp)
# resonator_spectroscopy.update_qpu(qpu, qubit_parameters_amp["new_parameter_values"])
print("Readout resonator frequency: ", qubit_to_measure.parameters.readout_resonator_frequency)
print("Readout resonator amplitude: ", qubit_to_measure.parameters.readout_amplitude)

# compiled_experiment = workflow_result.tasks["compile_experiment"].output
# plot_simulation(compiled_experiment, length=50e-6, signal_names_to_show=["measure"])
# Out:
# None
# Readout resonator frequency:  5037400000.0
# Readout resonator amplitude:  0.5

# %% [markdown]
# # Qubit Spectroscopy

# %%
qubits[0].parameters.spectroscopy_length = 2e-6

# %%
options = qubit_spectroscopy.experiment_workflow.options()
options.count(2**12)
options.update(True)  # updates the qubit parameter "resonance_frequency_ge"
options.close_figures(False)

qubits_to_measure = [qubits[0]]

temporary_parameters = {}
for q in qubits_to_measure:
    temp_pars = deepcopy(q.parameters)
    temp_pars.drive_range = -30
    temp_pars.spectroscopy_amplitude = 0.5
    temporary_parameters[q.uid] = temp_pars

frequencies = [
    q.parameters.resonance_frequency_ge + np.linspace(-50e6, 50e6, 201)
    for q in qubits_to_measure
]
exp_workflow = qubit_spectroscopy.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    temporary_parameters=temporary_parameters,
    frequencies=frequencies,
    options=options,
)
workflow_result = exp_workflow.run()
# Out:
# [2026.07.14 17:45:40.230] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 17:45:40.230] INFO      Workflow 'qubit_spectroscopy': execution started at 2026-07-14
# [2026.07.14 17:45:40.246] INFO      14:45:40.230547Z
# [2026.07.14 17:45:40.246] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 17:45:40.295] INFO    Task 'temporary_qpu': started at 2026-07-14 14:45:40.295920Z
# [2026.07.14 17:45:40.301] INFO    Task 'temporary_qpu': ended at 2026-07-14 14:45:40.301293Z
# [2026.07.14 17:45:40.311] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-07-14
# [2026.07.14 17:45:40.311] INFO    14:45:40.311078Z
# [2026.07.14 17:45:40.314] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-07-14 14:45:40.314867Z
# [2026.07.14 17:45:40.319] INFO    Task 'create_experiment': started at 2026-07-14 14:45:40.319056Z
# [2026.07.14 17:45:40.349] INFO    Task 'create_experiment': ended at 2026-07-14 14:45:40.349091Z
# [2026.07.14 17:45:40.358] INFO    Task 'compile_experiment': started at 2026-07-14 14:45:40.358978Z
# [2026.07.14 17:45:40.362] INFO    Starting LabOne Q Compiler run...
# [2026.07.14 17:45:40.362] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.07.14 17:45:40.366] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.07.14 17:45:40.366] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.07.14 17:45:40.366] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.07.14 17:45:40.368] INFO    Schedule completed. [0.001 s]
# [2026.07.14 17:45:40.380] INFO    Code generation completed for all AWGs. [0.008 s]
# [2026.07.14 17:45:40.380] INFO    Completed compilation step 1 of 1. [0.013 s]
# [2026.07.14 17:45:40.380] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.14 17:45
INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 17:45:45.567] INFO      Workflow 'qubit_spectroscopy': execution ended at 2026-07-14
# [2026.07.14 17:45:45.569] INFO      14:45:45.565173Z
# [2026.07.14 17:45:45.569] INFO     ──────────────────────────────────────────────────────────────────────────────

# %%
analysis_workflow_result= workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)
qubit_spectroscopy.update_qpu(qpu, qubit_parameters["new_parameter_values"])
print("Readout resonance frequency ge: ", qubit_to_measure.parameters.resonance_frequency_ge)

# compiled_experiment = workflow_result.tasks["compile_experiment"].output
# plot_simulation(compiled_experiment, length=50e-6, signal_names_to_show=["measure"])
# Out:
# {'new_parameter_values': {'q0': {'resonance_frequency_ge': 3736378183.411701+/-239048.13284487402}},
#  'old_parameter_values': {'q0': {'resonance_frequency_ge': 3748000000.0}}}
# Readout resonance frequency ge:  3736378183.411701

# %% [markdown]
# ## Midway Checking

# %%
qpu.quantum_elements
# Out:
# [TunableTransmonQubit(
# │   uid='q0',
# │   signals={
# │   │   'drive': 'q0/drive',
# │   │   'drive_ef': 'q0/drive_ef',
# │   │   'measure': 'q0/measure',
# │   │   'acquire': 'q0/acquire'
# │   },
# │   parameters=TunableTransmonQubitParameters(
# │   │   custom={},
# │   │   ge_T1=0,
# │   │   ge_T2=0,
# │   │   ge_T2_star=0,
# │   │   ef_T1=0,
# │   │   ef_T2=0,
# │   │   ef_T2_star=0,
# │   │   drive_lo_frequency=3600000000.0,
# │   │   readout_lo_frequency=5000000000.0,
# │   │   resonance_frequency_ge=3736378183.411701,
# │   │   resonance_frequency_ef=3510000000.0,
# │   │   readout_resonator_frequency=5037400000.0,
# │   │   ge_drive_amplitude_pi=0.2,
# │   │   ge_drive_amplitude_pi2=0.1,
# │   │   ge_drive_length=5e-08,
# │   │   ge_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   ef_drive_amplitude_pi=0.2,
# │   │   ef_drive_amplitude_pi2=0.1,
# │   │   ef_drive_length=5e-08,
# │   │   ef_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   qubit_resonator_coupling_strength_g=0,
# │   │   ge_chi_shift=0,
# │   │   readout_amplitude=0.5,
# │   │   readout_length=2e-06,
# │   │   readout_pulse={
# │   │   │   'function': 'const'
# │   │   },
# │   │   readout_integration_length=2e-06,
# │   │   readout_integration_delay=8e-08,
# │   │   readout_integration_kernels_type='default',
# │   │   readout_integration_kernels=None,
# │   │   readout_integration_discrimination_thresholds=None,
# │   │   reset_delay_length=0.0001,
# │   │   drive_range=5,
# │   │   readout_range_out=-30,
# │   │   readout_range_in=-45,
# │   │   flux_range=5,
# │   │   spectroscopy_length=2e-06,
# │   │   spectroscopy_amplitude=1,
# │   │   spectroscopy_pulse={
# │   │   │   'function': 'const',
# │   │   │   'can_compress': True
# │   │   },
# │   │   dc_slot=0,
# │   │   dc_voltage_parking=0.0,
# │   │   flux_offset_voltage=0.0,
# │   │   user_defined={}
# │   )
# )
# ]

# %% [markdown]
# # Amplitude Rabi

# %%
options = amplitude_rabi.experiment_workflow.options()
# updates the qubit parameters "ge_drive_amplitude_pi" and ge_drive_amplitude_pi2
# options.update(False)
options.count(2**12)
options.close_figures(False) # Plot figures

transition_to_calibrate = "ge"
options.transition(transition_to_calibrate)
options.cal_states(transition_to_calibrate)

qubits_to_measure = [qubits[0]]

exp_workflow = amplitude_rabi.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    amplitudes=[np.linspace(0, 1, 101) for q in qubits_to_measure],
    options=options,
)
workflow_result = exp_workflow.run()
# Out:
# [2026.07.14 18:16:58.659] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 18:16:58.661] INFO      Workflow 'amplitude_rabi': execution started at 2026-07-14 15:16:58.659467Z
# [2026.07.14 18:16:58.663] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 18:16:58.738] INFO    Task 'temporary_qpu': started at 2026-07-14 15:16:58.736661Z
# [2026.07.14 18:16:58.741] INFO    Task 'temporary_qpu': ended at 2026-07-14 15:16:58.739721Z
# [2026.07.14 18:16:58.747] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-07-14
# [2026.07.14 18:16:58.749] INFO    15:16:58.747505Z
# [2026.07.14 18:16:58.751] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-07-14 15:16:58.750552Z
# [2026.07.14 18:16:58.759] INFO    Task 'create_experiment': started at 2026-07-14 15:16:58.758054Z
# [2026.07.14 18:16:58.784] INFO    Task 'create_experiment': ended at 2026-07-14 15:16:58.784135Z
# [2026.07.14 18:16:58.791] INFO    Task 'compile_experiment': started at 2026-07-14 15:16:58.791829Z
# [2026.07.14 18:16:58.796] INFO    Starting LabOne Q Compiler run...
# [2026.07.14 18:16:58.799] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.07.14 18:16:58.799] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.07.14 18:16:58.799] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.07.14 18:16:58.803] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.07.14 18:16:58.806] INFO    Schedule completed. [0.002 s]
# [2026.07.14 18:16:58.810] INFO    Code generation completed for all AWGs. [0.004 s]
# [2026.07.14 18:16:58.810] INFO    Completed compilation step 1 of 1. [0.009 s]
# [2026.07.14 18:16:58.819] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.14 18:16:58.819] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.07.14 18:16:58.821] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.14 18:16:58.821] INFO      SHFQC_DEV12192        0         17            0           1      8000
# [2026.07.14 18:16:58.821] INFO      SHFQC_DEV12192_sg     0        217          103           2       448
# [2026.07.14 18:16:58.824] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.14 18:16:58.824] INFO      TOTAL                          234          103                  8448
# [2026.07.14 18:16:58.826] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.14 18:16:58.841] INFO    Finished LabOne Q Compiler run.
# [2026.07.14 18:16:58.842] INFO    Task 'compile_experiment': ended at 2026-07-14 15:16:58.842801Z
# [2026.07.14 18:16:58.868] INFO    Task 'run_experiment': started at 2026-07-14 15:16:58.868631Z
# [2026.07.14 18:16:58.906] INFO    Starting near-time execution...
# [2026.07.14 18:16:59.011] INFO    Estimated RT execution time: 43.06 s.
# [2026.07.14 18:17:42.144] INFO    Finished near-time execution.
# [2026.07.14 18:17:42.257] INFO    Task 'run_experiment': ended at 2026-07-14 15:17:42.257412Z
# [2026.07.14 18:17:42.271] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 18:17:42.276] INFO      Workflow 'analysis_workflow': execution started at 2026-07-14
# [2026.07.14 18:17:42.277] INFO      15:17:42.270746Z
# [2026.07.14 18:17:42.278] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 18:17:42.295] INFO    Task 'calculate_qubit_population': started at 2026-07-14 15:17:42.295442Z
# [2026.07.14 18:17:42.306] INFO    Task 'calculate_qubit_population': ended at 2026-07-14 15:17:42.306206Z
# [2026.07.14 18:17:42.307] INFO    Task 'fit_data': started at 2026-07-14 15:17:42.307424Z
# [2026.07.14 18:17:42.337] INFO    Task 'fit_data': ended at 2026-07-14 15:17:42.334548Z
# [2026.07.14 18:17:42.338] INFO    Task 'extract_qubit_parameters': started at 2026-07-14 15:17:42.338280Z
# [2026.07.14 18:17:42.353] INFO    Task 'extract_qubit_parameters': ended at 2026-07-14 15:17:42.353454Z
# [2026.07.14 18:17:42.353] INFO    Task 'plot_raw_complex_data_1d': started at 2026-07-14 15:17:42.353454Z
# [2026.07.14 18:17:42.404] INFO    Artifact: 'Raw_data_q0' of type 'Figure' logged at 2026-07-14 15:17:42.403320Z
# [2026.07.14 18:17:42.787] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-07-14 15:17:42.786756Z
# [2026.07.14 18:17:42.787] INFO    Task 'plot_population': started at 2026-07-14 15:17:42.787903Z
# [2026.07.14 18:17:42.816] INFO    Artifact: 'Rabi_q0' of type 'Figure' logged at 2026-07-14 15:17:42.816049Z
# [2026.07.14 18:17:43.062] INFO    Task 'plot_population': ended at 2026-07-14 15:17:43.061346Z
# [2026.07.14 18:17:43.068] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 18:17:43.070] INFO      Workflow 'analysis_workflow': execution ended at 2026-07-14 15:17:43.062483Z
# [2026.07.14 18:17:43.070] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 18:17:43.077] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 18:17:43.077] INFO      Workflow 'amplitude_rabi': execution ended at 2026-07-14 15:17:43.077095Z
# [2026.07.14 18:17:43.077] INFO     ──────────────────────────────────────────────────────────────────────────────

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)
amplitude_rabi.update_qpu(qpu, qubit_parameters["new_parameter_values"])
print("Drive amplitude pi ge: ", qubit_to_measure.parameters.ge_drive_amplitude_pi)
print("Drive amplitude pi2 ge: ", qubit_to_measure.parameters.ge_drive_amplitude_pi2)

# compiled_experiment = workflow_result.tasks["compile_experiment"].output
# plot_simulation(compiled_experiment, length=50e-6, signal_names_to_show=["measure"])
# Out:
# {'new_parameter_values': {'q0': {'ge_drive_amplitude_pi': 0.13711561326807822+/-0.0014429608752281671,
#                                  'ge_drive_amplitude_pi2': 0.06589433919368456+/-0.0014124448794472864}},
#  'old_parameter_values': {'q0': {'ge_drive_amplitude_pi': 0.16971080476820302,
#                                  'ge_drive_amplitude_pi2': 0.07810637875703104}}}
# Drive amplitude pi ge:  0.13711561326807822
# Drive amplitude pi2 ge:  0.06589433919368456

# %% [markdown]
# # Ramsey

# %%
options = ramsey.experiment_workflow.options()
# updates the qubit parameters "resonance_frequency_ge" and ge_T2_star
# options.update(True)
options.count(2**12)
options.close_figures(False) # Plot figures

transition_to_calibrate = "ge"
options.transition(transition_to_calibrate)
options.cal_states(transition_to_calibrate)

# Note: if neighbouring qubits are physically coupled by a resonator,
# you usually don't want to run Ramsey in parallel on them because
# your result will be skewed by strong residual-ZZ coupling.
# Next-nearest neighbours is typically okay.
# qubits_to_measure = [qubits[0], qubits[2]]
qubits_to_measure = [qubits[0]]

delays = [
    np.linspace(0, 1e-6, 101)
    if transition_to_calibrate == "ef"
    else np.linspace(0, 60e-6, 501)
    for q in qubits_to_measure
]
detunings = [
    11.76e6 if transition_to_calibrate == "ef" else 0.673e6 for q in qubits_to_measure
]

exp_workflow = ramsey.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits
INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 18:22:16.663] INFO    Task 'calculate_qubit_population': started at 2026-07-14 15:22:16.663354Z
# [2026.07.14 18:22:16.668] INFO    Task 'calculate_qubit_population': ended at 2026-07-14 15:22:16.668172Z
# [2026.07.14 18:22:16.673] INFO    Task 'fit_data': started at 2026-07-14 15:22:16.672681Z
# [2026.07.14 18:22:16.689] INFO    Task 'fit_data': ended at 2026-07-14 15:22:16.689730Z
# [2026.07.14 18:22:16.692] INFO    Task 'extract_qubit_parameters': started at 2026-07-14 15:22:16.692721Z
# [2026.07.14 18:22:16.699] INFO    Task 'extract_qubit_parameters': ended at 2026-07-14 15:22:16.697318Z
# [2026.07.14 18:22:16.702] INFO    Task 'plot_raw_complex_data_1d': started at 2026-07-14 15:22:16.702798Z
# [2026.07.14 18:22:16.726] INFO    Artifact: 'Raw_data_q0' of type 'Figure' logged at 2026-07-14 15:22:16.726792Z
# [2026.07.14 18:22:17.009] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-07-14 15:22:17.007563Z
# [2026.07.14 18:22:17.015] INFO    Task 'plot_population': started at 2026-07-14 15:22:17.013601Z
# [2026.07.14 18:22:17.023] INFO    Artifact: 'Ramsey_q0' of type 'Figure' logged at 2026-07-14 15:22:17.023382Z
# [2026.07.14 18:22:17.324] INFO    Task 'plot_population': ended at 2026-07-14 15:22:17.312257Z
# [2026.07.14 18:22:17.324] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 18:22:17.328] INFO      Workflow 'analysis_workflow': execution ended at 2026-07-14 15:22:17.324287Z
# [2026.07.14 18:22:17.328] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 18:22:17.333] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 18:22:17.333] INFO      Workflow 'ramsey': execution ended at 2026-07-14 15:22:17.328375Z
# [2026.07.14 18:22:17.333] INFO     ──────────────────────────────────────────────────────────────────────────────

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)
ramsey.update_qpu(qpu, qubit_parameters["new_parameter_values"])
print("ge_T2_star: ", qubit_to_measure.parameters.ge_T2_star)
print("resonance_frequency_ge: ", qubit_to_measure.parameters.resonance_frequency_ge)

# compiled_experiment = workflow_result.tasks["compile_experiment"].output
# plot_simulation(compiled_experiment, length=50e-6, signal_names_to_show=["measure"])
# Out:
# {'new_parameter_values': {'q0': {'ge_T2_star': 1.1903497340037816e-05+/-2.863584747035948e-07,
#                                  'resonance_frequency_ge': 3732023705.1644483+/-457.602876362585}},
#  'old_parameter_values': {'q0': {'ge_T2_star': 1.269872683384854e-05,
#                                  'resonance_frequency_ge': 3734845044.8386836}}}
# ge_T2_star:  1.1903497340037816e-05
# resonance_frequency_ge:  3732023705.1644483

# %% [markdown]
# # DRAG Calibration

# %%
options = drag_q_scaling.experiment_workflow.options()
# options.update(True)  # updates the qubit parameter 'ge_drive_pulse["beta"]'
options.count(2**12)
options.close_figures(False) # Plot figures

transition_to_calibrate = "ge"
options.transition(transition_to_calibrate)
options.cal_states(transition_to_calibrate)

qubits_to_measure = [qubits[0]]

exp_workflow = drag_q_scaling.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    q_scalings=[np.linspace(-0.03, 0.03, 11) for _ in qubits_to_measure],
    options=options,
)
workflow_result = exp_workflow.run()
# Out:
# [2026.07.14 18:23:17.801] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 18:23
INFO    Artifact: 'Raw_data_q0' of type 'Figure' logged at 2026-07-14 15:23:33.098440Z
# [2026.07.14 18:23:33.464] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-07-14 15:23:33.462010Z
# [2026.07.14 18:23:33.470] INFO    Task 'plot_population': started at 2026-07-14 15:23:33.470461Z
# [2026.07.14 18:23:33.484] INFO    Artifact: 'Drag_q_scaling_q0' of type 'Figure' logged at 2026-07-14
# [2026.07.14 18:23:33.484] INFO    15:23:33.484964Z
# [2026.07.14 18:23:33.723] INFO    Task 'plot_population': ended at 2026-07-14 15:23:33.713571Z
# [2026.07.14 18:23:33.724] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 18:23:33.728] INFO      Workflow 'analysis_workflow': execution ended at 2026-07-14 15:23:33.724949Z
# [2026.07.14 18:23:33.729] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 18:23:33.733] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 18:23:33.733] INFO      Workflow 'drag_q_scaling': execution ended at 2026-07-14 15:23:33.731979Z
# [2026.07.14 18:23:33.736] INFO     ──────────────────────────────────────────────────────────────────────────────

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)
ramsey.update_qpu(qpu, qubit_parameters["new_parameter_values"])
print("ge_drive_pulse[beta]: ", qubit_to_measure.parameters.ge_drive_pulse["beta"])

# compiled_experiment = workflow_result.tasks["compile_experiment"].output
# plot_simulation(compiled_experiment, length=50e-6, signal_names_to_show=["measure"])
# Out:
# {'new_parameter_values': {'q0': {'ge_drive_pulse.beta': -4.412166737067171+/-22.251155029387576}},
#  'old_parameter_values': {'q0': {'ge_drive_pulse.beta': 0.23045329059540862}}}
# ge_drive_pulse[beta]:  -4.412166737067171

# %% [markdown]
# # T1

# %%
options = lifetime_measurement.experiment_workflow.options()
# options.update(True)  # updates the qubit parameter "ge_T1"
options.count(2**12)
options.close_figures(False) # Plot figures

qubits_to_measure = [qubits[0]]

exp_workflow = lifetime_measurement.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    temporary_parameters=temporary_parameters,
    delays=[np.linspace(0, 100e-6, 50) for q in qubits_to_measure],
    options=options,
)
workflow_result = exp_workflow.run()
# Out:
# [2026.07.14 18:24:18.786] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 18:24:18.786] INFO      Workflow 'lifetime_measurement': execution started at 2026-07-14
# [2026.07.14 18:24:18.786] INFO      15:24:18.786016Z
# [2026.07.14 18:24:18.786] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 18:24:18.830] INFO    Task 'temporary_qpu': started at 2026-07-14 15:24:18.828179Z
# [2026.07.14 18:24:18.833] INFO    Task 'temporary_qpu': ended at 2026-07-14 15:24:18.833958Z
# [2026.07.14 18:24:18.842] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-07-14
# [2026.07.14 18:24:18.842] INFO    15:24:18.840006Z
# [2026.07.14 18:24:18.846] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-07-14 15:24:18.844023Z
# [2026.07.14 18:24:18.851] INFO    Task 'create_experiment': started at 2026-07-14 15:24:18.851279Z
# [2026.07.14 18:24:18.878] INFO    Task 'create_experiment': ended at 2026-07-14 15:24:18.868654Z
# [2026.07.14 18:24:18.883] INFO    Task 'compile_experiment': started at 2026-07-14 15:24:18.883144Z
# [2026.07.14 18:24:18.889] INFO    Starting LabOne Q Compiler run...
# [2026.07.14
INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 18:24:51.942] INFO      Workflow 'analysis_workflow': execution ended at 2026-07-14 15:24:51.941448Z
# [2026.07.14 18:24:51.942] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 18:24:51.950] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 18:24:51.950] INFO      Workflow 'lifetime_measurement': execution ended at 2026-07-14
# [2026.07.14 18:24:51.950] INFO      15:24:51.949426Z
# [2026.07.14 18:24:51.950] INFO     ──────────────────────────────────────────────────────────────────────────────

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)
ramsey.update_qpu(qpu, qubit_parameters["new_parameter_values"])
print("ge_T1: ", qubit_to_measure.parameters.ge_T1)

# compiled_experiment = workflow_result.tasks["compile_experiment"].output
# plot_simulation(compiled_experiment, length=50e-6, signal_names_to_show=["measure"])
# Out:
# {'new_parameter_values': {'q0': {'ge_T1': -0.0008769942226633204+/-0.0025004644571951016}},
#  'old_parameter_values': {'q0': {'ge_T1': 0}}}
# ge_T1:  -0.0008769942226633204

# %% [markdown]
# # Echo

# %%
options = echo.experiment_workflow.options()
# options.update(True)  # updates the qubit parameter "ge_T2"
options.count(2**12)
options.close_figures(False)

# Note: if neighbouring qubits are physically coupled by a resonator,
# you usually don't want to run Echo in parallel on them because
# your result will be skewed by strong residual-ZZ coupling.
# Next-nearest neighbours is typically okay.
qubits_to_measure = [qubits[0]]

exp_workflow = echo.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    delays=[np.linspace(0, 100e-6, 50) for q in qubits_to_measure],
    options=options,
)
workflow_result = exp_workflow.run()
# Out:
# [2026.07.14 18:24:52.817] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 18:24:52.817] INFO      Workflow 'echo': execution started at 2026-07-14 15:24:52.817184Z
# [2026.07.14 18:24:52.817] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 18:24:52.866] INFO    Task 'temporary_qpu': started at 2026-07-14 15:24:52.866947Z
# [2026.07.14 18:24:52.872] INFO    Task 'temporary_qpu': ended at 2026-07-14 15:24:52.872466Z
# [2026.07.14 18:24:52.879] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-07-14
# [2026.07.14 18:24:52.881] INFO    15:24:52.879295Z
# [2026.07.14 18:24:52.882] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-07-14 15:24:52.882842Z
# [2026.07.14 18:24:52.890] INFO    Task 'create_experiment': started at 2026-07-14 15:24:52.890535Z
# [2026.07.14 18:24:52.923] INFO    Task 'create_experiment': ended at 2026-07-14 15:24:52.923238Z
# [2026.07.14 18:24:52.923] INFO    Task 'compile_experiment': started at 2026-07-14 15:24:52.923238Z
# [2026.07.14 18:24:52.939] INFO    Starting LabOne Q Compiler run...
# [2026.07.14 18:24:52.941] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.07.14 18:24:52.942] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.07.14 18:24:52.944] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.07.14 18:24:52.944] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.07.14 18:24:52.948] INFO    Schedule completed. [0.002 s]
# [2026.07.14 18:24:52.953] WARNING Pulse 'ry_pulse_0' on signal q0/drive_q0/drive_ef exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:52.959] WARNING A waveform on signal 'q0/drive_q0/drive_ef' exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:52.965] WARNING Pulse 'rx_pulse_0' on signal q0/drive_ef_q0/drive exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:52.967] WARNING A waveform on signal 'q0/drive_ef_q0/drive' exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:52.969] WARNING Pulse 'ry_pulse_0' on signal q0/drive_ef_q0/drive exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:52.969] WARNING A waveform on signal 'q0/drive_ef_q0/drive' exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:52.972] WARNING Pulse 'ry_pulse_0' on signal q0/drive_ef_q0/drive exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:52.972] WARNING A waveform on signal 'q0/drive_ef_q0/drive' exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:52.972] WARNING Pulse 'ry_pulse_0' on signal q0/drive_ef_q0/drive exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:52.972] WARNING A waveform on signal 'q0/drive_ef_q0/drive' exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:52.978] WARNING Pulse 'rx_pulse_0' on signal q0/drive_ef_q0/drive exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:52.978] WARNING A waveform on signal 'q0/drive_ef_q0/drive' exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:52.979] WARNING Pulse 'ry_pulse_0' on signal q0/drive_q0/drive_ef exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:52.979] WARNING A waveform on signal 'q0/drive_q0/drive_ef' exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:52.979] WARNING Pulse 'ry_pulse_0' on signal q0/drive_ef_q0/drive exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:52.979] WARNING A waveform on signal 'q0/drive_ef_q0/drive' exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:52.986] WARNING Pulse 'ry_pulse_0' on signal q0/drive_ef_q0/drive exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:52.987] WARNING A waveform on signal 'q0/drive_ef_q0/drive' exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:52.987] WARNING Pulse 'rx_pulse_0' on signal q0/drive_ef_q0/drive exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:52.987] WARNING A waveform on signal 'q0/drive_ef_q0/drive' exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:52.990] WARNING Pulse 'ry_pulse_0' on signal q0/drive_ef_q0/drive exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:52.992] WARNING A waveform on signal 'q0/drive_ef_q0/drive' exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:52.994] WARNING Pulse 'rx_pulse_0' on signal q0/drive_ef_q0/drive exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:52.995] WARNING Pulse 'ry_pulse_0' on signal q0/drive_ef_q0/drive exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:52.995] WARNING Pulse 'rx_pulse_0' on signal q0/drive_ef_q0/drive exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:52.995] WARNING A waveform on signal 'q0/drive_ef_q0/drive' exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:52.997] WARNING Pulse 'ry_pulse_0' on signal q0/drive_ef_q0/drive exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:52.999] WARNING A waveform on signal 'q0/drive_ef_q0/drive' exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:53.000] WARNING Pulse 'ry_pulse_0' on signal q0/drive_ef_q0/drive exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:53.000] WARNING A waveform on signal 'q0/drive_ef_q0/drive' exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:53.000] WARNING Pulse 'rx_pulse_0' on signal q0/drive_q0/drive_ef exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:53.000] WARNING A waveform on signal 'q0/drive_q0/drive_ef' exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:53.000] WARNING Pulse 'ry_pulse_0' on signal q0/drive_ef_q0/drive exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:53.005] WARNING A waveform on signal 'q0/drive_ef_q0/drive' exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:53.006] WARNING Pulse 'ry_pulse_0' on signal q0/drive_ef_q0/drive exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:53.006] WARNING A waveform on signal 'q0/drive_ef_q0/drive' exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:53.006] WARNING Pulse 'ry_pulse_0' on signal q0/drive_q0/drive_ef exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:53.006] WARNING A waveform on signal 'q0/drive_q0/drive_ef' exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:53.006] WARNING Pulse 'rx_pulse_0' on signal q0/drive_ef_q0/drive exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:53.006] WARNING A waveform on signal 'q0/drive_ef_q0/drive' exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:53.006] WARNING Pulse 'ry_pulse_0' on signal q0/drive_q0/drive_ef exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:53.006] WARNING A waveform on signal 'q0/drive_q0/drive_ef' exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:53.006] WARNING Pulse 'rx_pulse_0' on signal q0/drive_q0/drive_ef exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:53.017] WARNING A waveform on signal 'q0/drive_q0/drive_ef' exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:53.018] WARNING Pulse 'rx_pulse_0' on signal q0/drive_q0/drive_ef exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:53.018] WARNING A waveform on signal 'q0/drive_q0/drive_ef' exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:53.018] WARNING Pulse 'rx_pulse_0' on signal q0/drive_q0/drive_ef exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:53.018] WARNING A waveform on signal 'q0/drive_q0/drive_ef' exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:53.022] WARNING Pulse 'ry_pulse_0' on signal q0/drive_q0/drive_ef exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:53.022] WARNING A waveform on signal 'q0/drive_q0/drive_ef' exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:53.025] WARNING Pulse 'ry_pulse_0' on signal q0/drive_q0/drive_ef exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:53.025] WARNING A waveform on signal 'q0/drive_q0/drive_ef' exceeds the max allowed amplitude. Signal will be clipped on the device.
# [2026.07.14 18:24:53.027] INFO    Code generation completed for all AWGs. [0.079 s]
# [2026.07.14 18:24:53.027] INFO    Completed compilation step 1 of 1. [0.086 s]
# [2026.07.14 18:24:53.036] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.14 18:24:53.036] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.07.14 18:24:53.036] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.14 18:24:53.040] INFO      SHFQC_DEV12192        0        159            0           1      8000
# [2026.07.14 18:24:53.040] INFO      SHFQC_DEV12192_sg     0        380           27          25      6112
# [2026.07.14 18:24:53.040] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.14 18:24:53.043] INFO      TOTAL                          539           27                 14112
# [2026.07.14 18:24:53.043] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.07.14 18:24:53.055] INFO    Finished LabOne Q Compiler run.
# [2026.07.14 18:24:53.055] INFO    Task 'compile_experiment': ended at 2026-07-14 15:24:53.055693Z
# [2026.07.14 18:24:53.081] INFO    Task 'run_experiment': started at 2026-07-14 15:24:53.081667Z
# [2026.07.14 18:24:53.130] INFO    Starting near-time execution...
# [2026.07.14 18:24:53.227] INFO    Estimated RT execution time: 32.00 s.
# [2026.07.14 18:25:25.551] INFO    Finished near-time execution.
# [2026.07.14 18:25:25.709] INFO    Task 'run_experiment': ended at 2026-07-14 15:25:25.707143Z
# [2026.07.14 18:25:25.718] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 18:25:25.723] INFO      Workflow 'analysis_workflow': execution started at 2026-07-14
# [2026.07.14 18:25:25.723] INFO      15:25:25.718702Z
# [2026.07.14 18:25:25.728] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 18:25:25.753] INFO    Task 'calculate_qubit_population': started at 2026-07-14 15:25:25.753362Z
# [2026.07.14 18:25:25.760] INFO    Task 'calculate_qubit_population': ended at 2026-07-14 15:25:25.760715Z
# [2026.07.14 18:25:25.765] INFO    Task 'fit_data': started at 2026-07-14 15:25:25.765325Z
# [2026.07.14 18:25:25.779] INFO    Task 'fit_data': ended at 2026-07-14 15:25:25.779452Z
# [2026.07.14 18:25:25.789] INFO    Task 'extract_qubit_parameters': started at 2026-07-14 15:25:25.787517Z
# [2026.07.14 18:25:25.793] INFO    Task 'extract_qubit_parameters': ended at 2026-07-14 15:25:25.793336Z
# [2026.07.14 18:25:25.799] INFO    Task 'plot_raw_complex_data_1d': started at 2026-07-14 15:25:25.797207Z
# [2026.07.14 18:25:25.834] INFO    Artifact: 'Raw_data_q0' of type 'Figure' logged at 2026-07-14 15:25:25.834767Z
# [2026.07.14 18:25:26.189] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-07-14 15:25:26.188483Z
# [2026.07.14 18:25:26.190] INFO    Task 'plot_population': started at 2026-07-14 15:25:26.190384Z
# [2026.07.14 18:25:26.225] INFO    Artifact: 'T2_q0' of type 'Figure' logged at 2026-07-14 15:25:26.225302Z
# [2026.07.14 18:25:26.418] INFO    Task 'plot_population': ended at 2026-07-14 15:25:26.418189Z
# [2026.07.14 18:25:26.418] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 18:25:26.427] INFO      Workflow 'analysis_workflow': execution ended at 2026-07-14 15:25:26.418189Z
# [2026.07.14 18:25:26.427] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 18:25:26.431] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.07.14 18:25:26.431] INFO      Workflow 'echo': execution ended at 2026-07-14 15:25:26.429814Z
# [2026.07.14 18:25:26.431] INFO     ──────────────────────────────────────────────────────────────────────────────

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)
ramsey.update_qpu(qpu, qubit_parameters["new_parameter_values"])
print("ge_T2: ", qubit_to_measure.parameters.ge_T2)

# compiled_experiment = workflow_result.tasks["compile_experiment"].output
# plot_simulation(compiled_experiment, length=50e-6, signal_names_to_show=["measure"])
# Out:
# {'new_parameter_values': {'q0': {'ge_T2': 2.865003631408705e-05+/-2.6286374163271202e-06}},
#  'old_parameter_values': {'q0': {'ge_T2': 8.424515603372109e-05}}}
# ge_T2:  2.865003631408705e-05

# %% [markdown]
# ## Final Checking

# %%
qpu.quantum_elements
# Out:
# [TunableTransmonQubit(
# │   uid='q0',
# │   signals={
# │   │   'drive': 'q0/drive',
# │   │   'drive_ef': 'q0/drive_ef',
# │   │   'measure': 'q0/measure',
# │   │   'acquire': 'q0/acquire'
# │   },
# │   parameters=TunableTransmonQubitParameters(
# │   │   custom={},
# │   │   ge_T1=-0.0008769942226633204,
# │   │   ge_T2=2.865003631408705e-05,
# │   │   ge_T2_star=1.1903497340037816e-05,
# │   │   ef_T1=0,
# │   │   ef_T2=0,
# │   │   ef_T2_star=0,
# │   │   drive_lo_frequency=3600000000.0,
# │   │   readout_lo_frequency=5000000000.0,
# │   │   resonance_frequency_ge=3732023705.1644483,
# │   │   resonance_frequency_ef=3510000000.0,
# │   │   readout_resonator_frequency=5037400000.0,
# │   │   ge_drive_amplitude_pi=0.13711561326807822,
# │   │   ge_drive_amplitude_pi2=0.06589433919368456,
# │   │   ge_drive_length=5e-08,
# │   │   ge_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': -4.412166737067171,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   ef_drive_amplitude_pi=0.2,
# │   │   ef_drive_amplitude_pi2=0.1,
# │   │   ef_drive_length=5e-08,
# │   │   ef_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   qubit_resonator_coupling_strength_g=0,
# │   │   ge_chi_shift=0,
# │   │   readout_amplitude=0.5,
# │   │   readout_length=2e-06,
# │   │   readout_pulse={
# │   │   │   'function': 'const'
# │   │   },
# │   │   readout_integration_length=2e-06,
# │   │   readout_integration_delay=8e-08,
# │   │   readout_integration_kernels_type='default',
# │   │   readout_integration_kernels=None,
# │   │   readout_integration_discrimination_thresholds=None,
# │   │   reset_delay_length=0.0001,
# │   │   drive_range=5,
# │   │   readout_range_out=-30,
# │   │   readout_range_in=-45,
# │   │   flux_range=5,
# │   │   spectroscopy_length=2e-06,
# │   │   spectroscopy_amplitude=1,
# │   │   spectroscopy_pulse={
# │   │   │   'function': 'const',
# │   │   │   'can_compress': True
# │   │   },
# │   │   dc_slot=0,
# │   │   dc_voltage_parking=0.0,
# │   │   flux_offset_voltage=0.0,
# │   │   user_defined={}
# │   )
# )
# ]

# %% [markdown]
# # Dealy Opt

# %%
delay_sweep = LinearSweepParameter(
    uid="delay_sweep_param", start=0, stop=0.2e-6, count=101
)

# define number of averages
# used for 2^num_averages, maximum: num_averages = 17
num_averages = 14

# readout pulse parameters and definition
envelope_duration = 2.048e-6
envelope_rise_fall_time = 0.05e-6
readout_pulse = pulse_library.gaussian_square(
    uid="readout_pulse", length=envelope_duration, amplitude=0.9
)

# %%
readout_pulse
# Out:
# PulseFunctional(
# │   function='gaussian_square',
# │   uid='readout_pulse',
# │   amplitude=0.9,
# │   length=2.048e-06,
# │   can_compress=False,
# │   pulse_parameters=None
# )

# %%
# function that defines a resonator spectroscopy experiment, and takes the frequency sweep as a parameter


def propagation_delay(readout_pulse, delay_sweep):
    # Create resonator spectroscopy experiment - uses only readout drive and signal acquisition
    exp_prop_delay = Experiment(
        uid="Propagation Delay Measurement",
        signals=[
            ExperimentSignal("measure"),
            ExperimentSignal("acquire"),
        ],
    )

    ## define experimental sequence
    # outer loop - vary drive frequency
    with exp_prop_delay.sweep(uid="del_sweep", parameter=delay_sweep):
        with exp_prop_delay.acquire_loop_rt(
            uid="shots",
            count=2**num_averages,
            acquisition_type=AcquisitionType.INTEGRATION,
        ):
            # readout pulse and data acquisition
            with exp_prop_delay.section(uid="spectroscopy"):
                # play resonator excitation pulse
                exp_prop_delay.play(signal="measure", pulse=readout_pulse)
                # resonator signal readout
                exp_prop_delay.acquire(
                    signal="acquire", handle="res_prop_delay", kernel=readout_pulse
                )
            # relax time after readout - for signal processing and qubit relaxation to ground state
            with exp_prop_delay.section(uid="relax", length=1e-6):
                exp_prop_delay.reserve(signal="measure")

        cal = Calibration()
        cal["acquire"] = SignalCalibration(port_delay=delay_sweep)
        exp_prop_delay.set_calibration(cal)

    return exp_prop_delay

# %%
# signal maps for a qubit - maps the logical signal of the device setup to the experimental signals of the experiment


def res_spec_map(qubit):
    signal_map = {
        "measure": setup.logical_signal_groups[f"{qubit}"].logical_signals[
            "measure"
        ],
        "acquire": setup.logical_signal_groups[f"{qubit}"].logical_signals[
            "acquire"
        ],
    }
    return signal_map


# pass sweep and pulse to experiment and apply signal map
exp_prop_delay = propagation_delay(readout_pulse, delay_sweep)
exp_prop_delay.set_signal_map(res_spec_map("q0"))

# %%
# compile the experiment on the open instrument session
compiled_prop_delay = session.compile(exp_prop_delay)

Path("Pulse_Sheets").mkdir(parents=True, exist_ok=True)
# generate a pulse sheet to inspect experiment before runtime
show_pulse_sheet("Pulse_Sheets/Propagation_Delay", compiled_prop_delay)
# Out:
# [2026.07.14 14:00:45.662] INFO    Starting LabOne Q Compiler run...
# [2026.07.14 14:00:45.673] INFO    Schedule completed. [0.000 s]
# [2026.07.14 14:00:45.673] INFO    Code generation completed for all AWGs. [0.001 s]
# [2026.07.14 14:00:45.678] INFO    Completed compilation step 1 of 101. [0.004 s]
# [2026.07.14 14:00:45.679] INFO    Skipping compilation for next step(s)...
# [2026.07.14 14:00:45.681] INFO     ────────────────────────────────────────────────────────────────────
# [2026.07.14 14:00:45.681] INFO      Device           AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.07.14 14:00:45.696] INFO     ────────────────────────────────────────────────────────────────────
# [2026.07.14 14:00:45.696] INFO      SHFQC_DEV12192     0          7            0           1      8192
# [2026.07.14 14:00:45.698] INFO     ────────────────────────────────────────────────────────────────────
# [2026.07.14 14:00:45.698] INFO      TOTAL                         7            0                  8192
# [2026.07.14 14:00:45.698] INFO     ────────────────────────────────────────────────────────────────────
# [2026.07.14 14:00:45.712] INFO    Finished LabOne Q Compiler run.
# [2026.07.14 14:00:45.712] INFO    Recompiling the experiment due to missing extra information in the compiled experiment. Compile with `OUTPUT_EXTRAS=True` and `MAX_EVENTS_TO_PUBLISH=1000` to bypass this step with a small impact on the compilation time.
# [2026.07.14 14:00:45.717] INFO    Starting LabOne Q Compiler run...
# [2026.07.14 14:00:45.732] INFO    Schedule completed. [0.012 s]
# [2026.07.14 14:00:45.732] INFO    Code generation completed for all AWGs. [0.002 s]
# [2026.07.14 14:00:45.732] INFO    Completed compilation step 1 of 101. [0.020 s]
# [2026.07.14 14:00:45.732] INFO    Skipping compilation for next step(s)...
# [2026.07.14 14:00:45.744] INFO    Finished LabOne Q Compiler run.
# [2026.07.14 14:00:45.744] WARNING Pulse sheet viewer: The event list was truncated to 998 events. Some later events are not shown. Increase `max_events_to_publish` in `show_pulse_sheet()` to display the full schedule.
# [2026.07.14 14:00:45.775] INFO    Writing html file to C:\Users\phys-pico-lab\Documents\Python_virtual_environments\meas_venv_workflow_py312\Scripts\meas\Pulse_Sheets\Propagation_Delay_2026-07-14-14-00-45.html
# C:\Users\phys-pico-lab\Documents\Python_virtual_environments\meas_venv_workflow_py312\Scripts\meas\Pulse_Sheets\Propagation_Delay_2026-07-14-14-00-45.html

# %%
# run the compiled experiemnt
prop_delay_results = session.run(compiled_prop_delay)
timestamp = time.strftime("%Y%m%dT%H%M%S")
Path("Results").mkdir(parents=True, exist_ok=True)
save(prop_delay_results, f"Results/{timestamp}_prop_delay_results.json")
print(f"File saved as Results/{timestamp}_prop_delay_results.json")
# Out:
# [2026.07.14 14:00:46.871] INFO    Starting near-time execution...
# [2026.07.14 14:01:07.098] INFO    Finished near-time execution.
# File saved as Results/20260714T140108_prop_delay_results.json

# %%
plot_results(prop_delay_results, phase=True, plot_width=5, plot_height=8)
