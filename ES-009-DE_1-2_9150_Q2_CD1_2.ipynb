# %% [markdown]
# # Overview

# %% [markdown]
# ## Description
#
# This is a template notebook to tune up a single qubit using the LabOneQ workflow architecture. The following tune-up experiments are implemented:
#
# 1. [Resonator Spectroscopy](#resonator-spectroscopy)
# 2. [Qubit Spectroscopy](#qubit-spectroscopy)
# 3. [Amplitude Rabi](#amplitude-rabi-ge) ([2nd](#amplitude-rabi-ef))
# 4. [Amplitude Rabi Chevron]() ([2nd]())
# 5. [Rabi Chevron](#rabi-chevron-ge) ([2nd](#rabi-shevron-ef))
# 6. [Rabi Frequency Calibration](#rabi-frequency-calibration-ge) ([2nd](#rabi-frequency-calibration-ef))
# 7. [Rabi Error Amplification](#rabi-error-amplification-ge) ([2nd](#rabi-error-amplification-ef))
# 8. [Ramsey](#ramsey-ge) ([2nd](#ramsey-ef))
# 9. [T1 Lifetime](#t1-lifetime-ge) ([2nd](#t1-lifetime-ef))
# 10. [DRAG Calibration](#drag-calibration-ge) ([2nd](#drag-calibration-ef))
# 11. [Hahn-Echo](#hahn-echo-ge) ([2nd](#hahn-echo-ef))
# 12. [Readout Optimisation](#readout-optimisation)
# 13. [Single Shot 0 & 1 Measurements](#single-shot-0-and-1-measurements)
# 14. [Population Measurements](#population-measurements)

# %% [markdown]
# ## Changelog
#
# All changes must be logged here! Do not make changes to this notebook other than expanding or modifying the standard experiments in a meaningful! All device-specific parameters and measurements have to be done in a different notebook!
#
# Stick to semantic versioning:
# - **Last Digit**: Fix a bug that does not add any new features and is backwards compatible -> increment last digit by one (e.g. 0.0.4 to 0.0.5)
#
# - **Middle Digit**: Add a new feature while keeping backwards compatibility (older versions can still be executed without any modifications) -> increment middle digit by one and set last digit to 0 (e.g. 1.2.12 to 1.3.0)
#
# - **First Digit**: Make changes that will break older versions, making them incompatible with the new version -> increment first digit by one and set all other digits to 0 (e.g. 3.2.9 to 4.0.0)
#
# **Current Version:** 1.4.5
#
# **2026-07-23**, *Elias*: Created this template notebook and added resonator and qubit spectroscopy, amplitude Rabi, Ramsey T1 and DRAG
#
# **2026-08-07**, *Kha*: Updated Hahn Echo, added Readout Optimisation, Single Shots, Population Measurements
#
# **2026-08-13**, *Kha*: Added Rabi Shevron, Rabi Frequency Calibration, Rabi Error Amplification
#
# **2026-08-26**, *Kha*: Update code output, visualization, and Amplitude Rabi Chevron

# %% [markdown]
# # Package Imports and Initialization

# %% [markdown]
# ## LabOne Q Libraries

# %%
# LabOne Q:
from laboneq.simple import *
from laboneq.dsl.quantum import QPU
from laboneq.contrib.example_helpers.generate_descriptor import generate_descriptor
from laboneq.workflow.logbook import LoggingStore
from laboneq.serializers import load, save

# LabOne Q Applications:
from laboneq_applications.qpu_types.tunable_transmon import (
    TunableTransmonQubit,
    TunableTransmonOperations,
)

# Plot:
from laboneq.contrib.example_helpers.plotting.plot_helpers import plot_results, plot_simulation

# Workflows:
from laboneq_applications.experiments import (
    resonator_spectroscopy,
    qubit_spectroscopy,
    amplitude_rabi,
    amplitude_fine,
    ramsey,
    drag_q_scaling,
    lifetime_measurement,
    echo,
    dispersive_shift,
    iq_blobs,
)
from laboneq_applications.contrib.experiments import (
    amplitude_rabi_chevron,
)

# %% [markdown]
# ## Other Imports

# %%
from copy import deepcopy
from pprint import pprint
from pathlib import Path

import os
import attrs
import numpy as np
import time
import pandas as pd
import matplotlib.pyplot as plt

from scipy.io import savemat
from scipy.optimize import curve_fit
from scipy.stats import norm

# %% [markdown]
# ## Helpers

# %%
def set_transition(transition: str):
    assert transition in ['ge', 'ef'], "Choose transition from 'ge' or 'ef'!"
    return transition

def log_sweep_help(t1_min: float, t1_max: float, t1_num: int):
    t1_log_sweep = np.logspace(np.log10(t1_max / t1_num / 10), np.log10(t1_max), t1_num - 1)
    t1_log_sweep_arr = np.append([0.0], t1_log_sweep)
    return t1_log_sweep_arr

# %%
def get_path_to_file(file_name: str, extension: str, directory: str | None = None) -> str:
    """Timestamped file path inside the cooldown data directory.

    New-structure replacement for the old
    `get_path_to_file(figname, '.png', sample_parameters)`.
    """
    directory = data_root_directory if directory is None else directory
    timestamp = time.strftime('%Y%m%d_%H%M%S')
    return os.path.join(directory, f'{timestamp}_{file_name}{extension}')

def get_analysis_task_output(workflow_result, task_name: str):
    """Output of a task inside the nested `analysis_workflow` of a workflow result.
    
    Used to reach the raw lmfit results (`fit_data`) and the pair-wise signal
    distances (`calculate_signal_differences`), which are not part of the
    analysis-workflow output itself.
    """
    return workflow_result.tasks['analysis_workflow'].tasks[task_name].output

# %%
def gauss(x, mu, sigma, A):
    """Old `lib.helpers.fitting_helper.gauss`, unchanged."""
    return A * np.exp(-((x - mu) ** 2) / 2 / sigma** 2)

def bimodal(x, mu1, sigma1, A1, mu2, sigma2, A2):
    """Old `lib.helpers.fitting_helper.bimodal`, unchanged."""
    return gauss(x, mu1, sigma1, A1) + gauss(x, mu2, sigma2, A2)

def collect_shots_from_result(result, qubit_uid: str, states: str) -> dict:
    """Single shots per prepared state from an `iq_blobs` workflow result.
    
    New-structure replacement for the old
    `SS_results.get_data("SS_rabi")[:, 0]` / `[:, 1]` (two-point sweep) and
    `SS_results.get_data("shots")` (one experiment per state).
    """
    return {
        s: result[dsl.handles.calibration_trace_handle(qubit_uid, s)].data
        for s in states
    }

def analyze_single_shots(shots_per_state, state_0='g', state_1='e',
                         plot=False, n_bins=50):
    """Rotate the shots onto the state-discrimination axis and get its statistics.

    New-structure replacement for the old `analize_Single_Shots(SS_results)`.
    Same maths, but it takes the `shots_per_state` dict instead of a
    `Results` object, and returns snake_case keys plus the rotated/projected
    shots (old `zero_data_proj` / `one_data_proj`).

    After the rotation, state_0 sits on the negative and state_1 on the positive
    real axis, so `shots_0_proj > 0` counts the misassigned state_0 shots.
    """
    data_0 = np.asarray(shots_per_state[state_0])
    data_1 = np.asarray(shots_per_state[state_1])

    mean_0 = np.mean(data_0)
    mean_1 = np.mean(data_1)

    mid_point = 0.5 * (mean_0 + mean_1)

    data_0_corr = data_0 - mid_point
    data_1_corr = data_1 - mid_point

    # old: r = np.abs(zero_mean - one_mean) / 2
    distance = np.abs(mean_0 - mean_1) / 2
    phi = np.angle(mean_0 - mid_point)

    data_0_rot = data_0_corr * np.exp(1j * (np.pi - phi))
    data_1_rot = data_1_corr * np.exp(1j * (np.pi - phi))

    std_x_0 = np.sqrt(np.var(data_0_rot.real, ddof=1))
    std_y_0 = np.sqrt(np.var(data_0_rot.imag, ddof=1))
    std_x_1 = np.sqrt(np.var(data_1_rot.real, ddof=1))
    std_y_1 = np.sqrt(np.var(data_1_rot.imag, ddof=1))

    results = {
        'distance': distance,
        'mean_0': np.mean(data_0_rot),
        'mean_1': np.mean(data_1_rot),
        'std_x_0': std_x_0,
        'std_y_0': std_y_0,
        'std_x_1': std_x_1,
        'std_y_1': std_y_1,
        'rel_std_0': std_x_0 / distance,
        'rel_std_1': std_x_1 / distance,
        'shots_0_rot': data_0_rot,
        'shots_1_rot': data_1_rot,
        'shots_0_proj': data_0_rot.real,
        'shots_1_proj': data_1_rot.real,
        'n_misassigned_0': int(np.sum(data_0_rot.real > 0)),
        'n_assigned_0': int(np.sum(data_0_rot.real <= 0)),
    }

    if plot:
        fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)
        fig.suptitle(f'Rotated single shots - {state_0} vs {state_1}')

        axs[0].set_title('Real')
        axs[0].hist(data_0_rot.real, bins=n_bins, alpha=0.5, label=state_0)
        axs[0].hist(data_1_rot.real, bins=n_bins, alpha=0.5, label=state_1)
        axs[0].set_yscale('log')
        axs[0].legend()

        axs[1].set_title('Imag')
        axs[1].hist(data_0_rot.imag, bins=n_bins, alpha=0.5, label=state_0)
        axs[1].hist(data_1_rot.imag, bins=n_bins, alpha=0.5, label=state_1)
        axs[1].set_yscale('log')
        axs[1].legend()

        results['figure'] = fig

    return results


def summarize_single_shot_metrics(res_ss, assignment_fidelity=None):
    """Compact printout of the figures of merit of one single-shot measurement."""
    print('State distance:          ', round(float(res_ss['distance']), 6))
    print('Relative STD state 0:    ', round(float(res_ss['rel_std_0']), 4))
    print('Relative STD state 1:    ', round(float(res_ss['rel_std_1']), 4))
    print('Misassigned state-0 shots:', res_ss['n_misassigned_0'],
          '/', res_ss['n_misassigned_0'] + res_ss['n_assigned_0'])
    if assignment_fidelity is not None:
        print('Assignment fidelity:     ', f'{assignment_fidelity * 100:0.2f} %')

# %% [markdown]
# ## Descriptor and Device Setup

# %%
number_of_qubits = 1

descriptor = generate_descriptor(
    #pqsc=["DEV10001"],
    shfqc_2=["DEV12192"],
    number_data_qubits=number_of_qubits,
    multiplex=True,
    number_multiplex=number_of_qubits,
    include_cr_lines=False,
    ip_address="localhost",
    #options = "SHFQC/QC2CH",
)

setup = DeviceSetup.from_descriptor(descriptor, "localhost")
setup.instruments[0].device_options = "SHFQC/QC2CH"

# %%
qubits = TunableTransmonQubit.from_device_setup(setup)

# %% [markdown]
# ## Qubit Initialization

# %%
cooldown_start_date = '2026-08-26' # YYYY-MM-DD
sample_name = 'ES-009-DE_1-2_9150'
qubit_name = 'Q2'

assert cooldown_start_date != '', 'Enter cooldown name'
assert sample_name != '', 'Enter sample name'
assert qubit_name != '', 'Enter qubit name'

# %%
qubits # Check in
# Out:
# [TunableTransmonQubit(
# │   uid='q0',
# │   signals={
# │   │   'drive': 'q0/drive',
# │   │   'drive_ef': 'q0/drive_ef',
# │   │   'measure': 'q0/measure',
# │   │   'acquire': 'q0/acquire'
# │   },
# │   parameters=TunableTransmonQubitParameters(
# │   │   custom={},
# │   │   ge_T1=0,
# │   │   ge_T2=0,
# │   │   ge_T2_star=0,
# │   │   ef_T1=0,
# │   │   ef_T2=0,
# │   │   ef_T2_star=0,
# │   │   drive_lo_frequency=None,
# │   │   readout_lo_frequency=None,
# │   │   resonance_frequency_ge=None,
# │   │   resonance_frequency_ef=None,
# │   │   readout_resonator_frequency=None,
# │   │   ge_drive_amplitude_pi=0.2,
# │   │   ge_drive_amplitude_pi2=0.1,
# │   │   ge_drive_length=5e-08,
# │   │   ge_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   ef_drive_amplitude_pi=0.2,
# │   │   ef_drive_amplitude_pi2=0.1,
# │   │   ef_drive_length=5e-08,
# │   │   ef_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   qubit_resonator_coupling_strength_g=0,
# │   │   ge_chi_shift=0,
# │   │   readout_amplitude=1.0,
# │   │   readout_length=2e-06,
# │   │   readout_pulse={
# │   │   │   'function': 'const'
# │   │   },
# │   │   readout_integration_length=2e-06,
# │   │   readout_integration_delay=2e-08,
# │   │   readout_integration_kernels_type='default',
# │   │   readout_integration_kernels=None,
# │   │   readout_integration_discrimination_thresholds=None,
# │   │   reset_delay_length=1e-06,
# │   │   drive_range=10,
# │   │   readout_range_out=5,
# │   │   readout_range_in=10,
# │   │   flux_range=5,
# │   │   spectroscopy_length=5e-06,
# │   │   spectroscopy_amplitude=1,
# │   │   spectroscopy_pulse={
# │   │   │   'function': 'const',
# │   │   │   'can_compress': True
# │   │   },
# │   │   dc_slot=0,
# │   │   dc_voltage_parking=0.0,
# │   │   flux_offset_voltage=0.0,
# │   │   user_defined={}
# │   )
# )
# ]

# %%
for q in qubits:
    q.parameters.ge_drive_pulse["sigma"] = 0.25
    q.parameters.readout_amplitude = 0.2
    q.parameters.reset_delay_length = 150e-6
    q.parameters.readout_range_out = -30
    q.parameters.readout_lo_frequency = 6e9
    q.parameters.drive_range = 0
    q.parameters.readout_range_in = -35
    q.parameters.readout_integration_delay = 80e-9

qubits[0].parameters.drive_lo_frequency = 4.8e9
qubits[0].parameters.resonance_frequency_ge = 5.01e9
qubits[0].parameters.resonance_frequency_ef = 4.8e9
qubits[0].parameters.readout_resonator_frequency = 5.9591e9
qubits[0].parameters.spectroscopy_length = 10e-6
qubits[0].parameters.spectroscopy_amplitude = 0.2
qubits[0].uid = qubit_name

# %%
qops = TunableTransmonOperations()
qpu = QPU(qubits, quantum_operations=qops)

# %%
for q in qubits:
    print("-------------")
    print("Qubit UID:", q.uid)
    print("Qubit logical signals:")
    for sig, lsg in q.signals.items():
        print(f"  {sig:<10} ('{lsg:>10}')")
# Out:
# -------------
# Qubit UID: Q2
# Qubit logical signals:
#   drive      ('  q0/drive')
#   drive_ef   ('q0/drive_ef')
#   measure    ('q0/measure')
#   acquire    ('q0/acquire')

# %% [markdown]
# ## LabOne Q Session Connection

# %%
session = Session(setup)
session.connect(do_emulation=False)
# Out:
# [2026.08.26 15:52:14.718] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is C:\Users\phys-pico-lab\Documents\laboneq_workflow_notebooks\samples\ES-009-DE_1-2_9150\laboneq_output\log
# [2026.08.26 15:52:14.736] INFO    VERSION: laboneq 26.4.0
# [2026.08.26 15:52:14.740] INFO    Connecting to data server at localhost:8004
# [2026.08.26 15:52:14.751] INFO    Connected to Zurich Instruments LabOne Data Server version 26.04.1.6 at localhost:8004
# [2026.08.26 15:52:14.768] INFO    Configuring the device setup
# [2026.08.26 15:52:14.790] INFO    The device setup is configured
# [2026.08.26 15:52:15.061] INFO    System profile saved to C:\Users\phys-pico-lab\AppData\Local\laboneq\profiles\unknown-613335402d7b7f78058d100a7c9ddd62592a6fd7431fa79c3e5a4ab0cfd13ec3.yaml

# %% [markdown]
# ## Data Saving

# %%
data_root_directory = os.path.join('N:\\', 'xld', 'qubit_thermometry_v2', sample_name, f'COOLDOWN_{cooldown_start_date}', qubit_name)
qpu_file_path = os.path.join('N:\\', 'xld', 'qubit_thermometry_v2', sample_name, f'COOLDOWN_{cooldown_start_date}', f'{sample_name}_qpu.json')

if not os.path.isdir(data_root_directory):
    os.makedirs(data_root_directory, exist_ok=True)

print(f'Saving data to: {data_root_directory}')
# Out:
# Saving data to: N:\xld\qubit_thermometry_v2\ES-009-DE_1-2_9150\COOLDOWN_2026-08-26\Q2

# %%
folder_store = workflow.logbook.FolderStore(data_root_directory)
folder_store.activate()
# folder_store.deactivate()

logging_store = LoggingStore()
logging_store.activate()
# logging_store.deactivate()

# %%
qpu.quantum_elements
# Out:
# [TunableTransmonQubit(
# │   uid='Q2',
# │   signals={
# │   │   'drive': 'q0/drive',
# │   │   'drive_ef': 'q0/drive_ef',
# │   │   'measure': 'q0/measure',
# │   │   'acquire': 'q0/acquire'
# │   },
# │   parameters=TunableTransmonQubitParameters(
# │   │   custom={},
# │   │   ge_T1=0,
# │   │   ge_T2=0,
# │   │   ge_T2_star=0,
# │   │   ef_T1=0,
# │   │   ef_T2=0,
# │   │   ef_T2_star=0,
# │   │   drive_lo_frequency=4800000000.0,
# │   │   readout_lo_frequency=6000000000.0,
# │   │   resonance_frequency_ge=5010000000.0,
# │   │   resonance_frequency_ef=4800000000.0,
# │   │   readout_resonator_frequency=5960100000.0,
# │   │   ge_drive_amplitude_pi=0.2,
# │   │   ge_drive_amplitude_pi2=0.1,
# │   │   ge_drive_length=5e-08,
# │   │   ge_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   ef_drive_amplitude_pi=0.2,
# │   │   ef_drive_amplitude_pi2=0.1,
# │   │   ef_drive_length=5e-08,
# │   │   ef_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   qubit_resonator_coupling_strength_g=0,
# │   │   ge_chi_shift=0,
# │   │   readout_amplitude=0.2,
# │   │   readout_length=2e-06,
# │   │   readout_pulse={
# │   │   │   'function': 'const'
# │   │   },
# │   │   readout_integration_length=2e-06,
# │   │   readout_integration_delay=8e-08,
# │   │   readout_integration_kernels_type='default',
# │   │   readout_integration_kernels=None,
# │   │   readout_integration_discrimination_thresholds=None,
# │   │   reset_delay_length=0.00015,
# │   │   drive_range=0,
# │   │   readout_range_out=-30,
# │   │   readout_range_in=-35,
# │   │   flux_range=5,
# │   │   spectroscopy_length=1e-05,
# │   │   spectroscopy_amplitude=0.2,
# │   │   spectroscopy_pulse={
# │   │   │   'function': 'const',
# │   │   │   'can_compress': True
# │   │   },
# │   │   dc_slot=0,
# │   │   dc_voltage_parking=0.0,
# │   │   flux_offset_voltage=0.0,
# │   │   user_defined={}
# │   )
# )
# ]

# %% [markdown]
# # Spectroscopy

# %% [markdown]
# ## Resonator Spectroscopy <a class="anchor" id="resonator-spectroscopy"></a>

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

# readout_range_out = -30
# readout_range_in = -35
# readout_amplitude = 0.2
n_avg_exponent = 15

freq_range = 10e6
n_points = 1001

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
# temp_pars.readout_range_out = readout_range_out
# temp_pars.readout_range_in = readout_range_in
# temp_pars.readout_amplitude = readout_amplitude
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = resonator_spectroscopy.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(False)

qubit_to_measure = qubits[0]

frequencies = temporary_parameters[q.uid].readout_resonator_frequency + np.linspace(
    -freq_range / 2, freq_range / 2, n_points
)

exp_workflow = resonator_spectroscopy.experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=qubit_to_measure.uid,
    frequencies=frequencies,
    options=options,
    temporary_parameters=temporary_parameters
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.26 15:56:26.326] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.26 15:56:26.326] INFO      Workflow 'resonator_spectroscopy': execution started at 2026-08-26
# [2026.08.26 15:56:26.334] INFO      12:56:26.326574Z
# [2026.08.26 15:56:26.334] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.26 15:56:26.687] INFO    Task 'temporary_qpu': started at 2026-08-26 12:56:26.687200Z
# [2026.08.26 15:56:26.758] INFO    Task 'temporary_qpu': ended at 2026-08-26 12:56:26.758669Z
# [2026.08.26 15:56:26.887] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-26
# [2026.08.26 15:56:26.887] INFO    12:56:26.887947Z
# [2026.08.26 15:56:26.936] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-26 12:56:26.936019Z
# [2026.08.26 15:56:27.051] INFO    Task 'create_experiment': started at 2026-08-26 12:56:27.051613Z
# [2026.08.26 15:56:27.174] INFO    Task 'create_experiment': ended at 2026-08-26 12:56:27.174392Z
# [2026.08.26 15:56:27.328] INFO    Task 'compile_experiment': started at 2026-08-26 12:56:27.328464Z
# [2026.08.26 15:56:27.457] INFO    Starting LabOne Q Compiler run...
# [2026.08.26 15:56:27.461] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.26 15:56:27.461] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.26 15:56:27.470] INFO    Schedule completed. [0.008 s]
# [2026.08.26 15:56:27.501] INFO    Code generation completed for all AWGs. [0.028 s]
# [2026.08.26 15:56:27.503] INFO    Completed compilation step 1 of 1. [0.039 s]
# [2026.08.26 15:56:27.508] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.26 15:56:27.509] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.26 15:56:27.511] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.26 15:56:27.511] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.26 15:56:27.513] INFO      SHFQC_DEV12192_sg     0          9            1           0         0
# [2026.08.26 15:56:27.515] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.26 15:56:27.515] INFO      TOTAL                           30            1                  8000
# [2026.08.26 15:56:27.516] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.26 15:56:27.526] INFO    Finished LabOne Q Compiler run.
# [2026.08.26 15:56:27.526] INFO    Task 'compile_experiment': ended at 2026-08-26 12:56:27.526361Z
# [2026.08.26 15:56:27.683] INFO    Task 'run_experiment': started at 2026-08-26 12:56:27.683482Z
# [2026.08.26 15:56:27.839] INFO    Starting near-time execution...
# [2026.08.26 15:56:27.887] INFO    Estimated RT execution time: 101.29 s.
# [2026.08.26 15:58:09.227] INFO    Finished near-time execution.
# [2026.08.26 15:58:09.305] INFO    Task 'run_experiment': ended at 2026-08-26 12:58:09.304601Z
# [2026.08.26 15:58:09.435] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.26 15:58:09.435] INFO      Workflow 'analysis_workflow': execution started at 2026-08-26
# [2026.08.26 15:58:09.437] INFO      12:58:09.434573Z
# [2026.08.26 15:58:09.437] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.26 15:58:09.647] INFO    Task 'calculate_signal_magnitude_and_phase': started at 2026-08-26
# [2026.08.26 15:58:09.648] INFO    12:58:09.646287Z
# [2026.08.26 15:58:09.705] INFO    Task 'calculate_signal_magnitude_and_phase': ended at 2026-08-26
# [2026.08.26 15:58:09.706] INFO    12:58:09.705064Z
# [2026.08.26 15:58:10.039] INFO    Task 'fit_data': started at 2026-08-26 12:58:10.039223Z
# [2026.08.26 15:58:10.259] INFO    Task 'fit_data': ended at 2026-08-26 12:58:10.258133Z
# [2026.08.26 15:58:10.360] INFO    Task 'extract_qubit_parameters': started at 2026-08-26 12:58:10.359873Z
# [2026.08.26 15:58:10.651] INFO    Task 'extract_qubit_parameters': ended at 2026-08-26 12:58:10.650553Z
# [2026.08.26 15:58:10.773] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-26 12:58:10.773248Z
# [2026.08.26 15:58:10.887] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-26 12:58:10.887109Z
# [2026.08.26 15:58:11.239] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-26 12:58:11.239791Z
# [2026.08.26 15:58:11.287] INFO    Task 'plot_magnitude_phase': started at 2026-08-26 12:58:11.287906Z
# [2026.08.26 15:58:11.466] INFO    Artifact: 'Magnitude_Phase_Q2' of type 'Figure' logged at 2026-08-26
# [2026.08.26 15:58:11.467] INFO    12:58:11.465380Z
# [2026.08.26 15:58:11.836] INFO    Task 'plot_magnitude_phase': ended at 2026-08-26 12:58:11.836144Z
# [2026.08.26 15:58:11.895] INFO    Task 'plot_real_imaginary': started at 2026-08-26 12:58:11.894330Z
# [2026.08.26 15:58:12.073] INFO    Artifact: 'Real_Imaginary_Q2' of type 'Figure' logged at 2026-08-26
# [2026.08.26 15:58:12.075] INFO    12:58:12.071779Z
# [2026.08.26 15:58:12.360] INFO    Task 'plot_real_imaginary': ended at 2026-08-26 12:58:12.359401Z
# [2026.08.26 15:58:12.396] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.26 15:58:12.397] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-26 12:58:12.395679Z
# [2026.08.26 15:58:12.397] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.26 15:58:12.447] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.26 15:58:12.448] INFO      Workflow 'resonator_spectroscopy': execution ended at 2026-08-26
# [2026.08.26 15:58:12.449] INFO      12:58:12.446032Z
# [2026.08.26 15:58:12.450] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)

    resonator_spectroscopy.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    print("\nReadout resonator frequency: ", qubit_to_measure.parameters.readout_resonator_frequency * 1e-9, ' GHz')
    
    print('\nUpdated global experiment parameters!\n')
# Out:
# {'new_parameter_values': {'Q2': {'readout_resonator_frequency': 5960100000.0+/-0}},
#  'old_parameter_values': {'Q2': {'readout_resonator_frequency': 5959100000.0}}}
#
# Readout resonator frequency:  5.960100000000001  GHz
#
# Updated global experiment parameters!

# %% [markdown]
# ## Qubit Spectroscopy <a class="anchor" id="qubit-spectroscopy"></a>

# %% [markdown]
# ### First Transition: g-e

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

spectroscopy_length = 20e-6
spectroscopy_amplitude = 0.4
readout_amplitude = 0.2
readout_length = 2e-6
drive_range = 10
n_avg_exponent = 13

freq_range = 100e6
n_points = 251

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temp_pars.spectroscopy_length = spectroscopy_length
temp_pars.spectroscopy_amplitude = spectroscopy_amplitude
temp_pars.readout_amplitude = readout_amplitude
temp_pars.readout_length = readout_length
temp_pars.drive_range = drive_range
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = qubit_spectroscopy.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.update(False) 
options.close_figures(False)

qubits_to_measure = [qubits[0]]

frequencies = [
    temporary_parameters[q.uid].resonance_frequency_ge + np.linspace(- freq_range / 2, freq_range / 2, n_points)
    for q in qubits_to_measure
]
exp_workflow = qubit_spectroscopy.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    frequencies=frequencies,
    options=options,
    temporary_parameters=temporary_parameters
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.26 16:16:05.478] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.26 16:16:05.478] INFO      Workflow 'qubit_spectroscopy': execution started at 2026-08-26
# [2026.08.26 16:16:05.478] INFO      13:16:05.478891Z
# [2026.08.26 16:16:05.478] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.26 16:16:05.820] INFO    Task 'temporary_qpu': started at 2026-08-26 13:16:05.820488Z
# [2026.08.26 16:16:05.878] INFO    Task 'temporary_qpu': ended at 2026-08-26 13:16:05.878850Z
# [2026.08.26 16:16:05.973] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-26
# [2026.08.26 16:16:05.973] INFO    13:16:05.973433Z
# [2026.08.26 16:16:06.022] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-26 13:16:06.022714Z
# [2026.08.26 16:16:06.134] INFO    Task 'create_experiment': started at 2026-08-26 13:16:06.134176Z
# [2026.08.26 16:16:06.265] INFO    Task 'create_experiment': ended at 2026-08-26 13:16:06.265539Z
# [2026.08.26 16:16:06.374] INFO    Task 'compile_experiment': started at 2026-08-26 13:16:06.374723Z
# [2026.08.26 16:16:06.482] INFO    Starting LabOne Q Compiler run...
# [2026.08.26 16:16:06.484] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.26 16:16:06.484] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.26 16:16:06.486] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.26 16:16:06.486] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.26 16:16:06.491] INFO    Schedule completed. [0.002 s]
# [2026.08.26 16:16:06.504] INFO    Code generation completed for all AWGs. [0.015 s]
# [2026.08.26 16:16:06.504] INFO    Completed compilation step 1 of 1. [0.022 s]
# [2026.08.26 16:16:06.519] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.26 16:16:06.519] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.26 16:16:06.523] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.26 16:16:06.523] INFO      SHFQC_DEV12192        0         10            0           1      8000
# [2026.08.26 16:16:06.524] INFO      SHFQC_DEV12192_sg     0         25            2           1        64
# [2026.08.26 16:16:06.524] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.26 16:16:06.524] INFO      TOTAL                           35            2                  8064
# [2026.08.26 16:16:06.524] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.26 16:16:06.536] INFO    Finished LabOne Q Compiler run.
# [2026.08.26 16:16:06.536] INFO    Task 'compile_experiment': ended at 2026-08-26 13:16:06.536128Z
# [2026.08.26 16:16:06.665] INFO    Task 'run_experiment': started at 2026-08-26 13:16:06.665886Z
# [2026.08.26 16:16:06.779] WARNING SHFQC/SG:dev12192: Output channel 0 range 20.0 is not on the list of allowed ranges: [-30. -25. -20. -15. -10.  -5.   0.   5.  10.]. Nearest allowed range will be used.
# [2026.08.26 16:16:06.825] INFO    Starting near-time execution...
# [2026.08.26 16:16:06.891] INFO    Estimated RT execution time: 47.47 s.
# [2026.08.26 16:16:54.440] INFO    Finished near-time execution.
# [2026.08.26 16:16:54.511] INFO    Task 'run_experiment': ended at 2026-08-26 13:16:54.511993Z
# [2026.08.26 16:16:54.662] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.26 16:16:54.662] INFO      Workflow 'analysis_workflow': execution started at 2026-08-26
# [2026.08.26 16:16:54.662] INFO      13:16:54.658671Z
# [2026.08.26 16:16:54.662] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.26 16:16:54.854] INFO    Task 'calculate_signal_magnitude_and_phase': started at 2026-08-26
# [2026.08.26 16:16:54.854] INFO    13:16:54.852462Z
# [2026.08.26 16:16:54.919] INFO    Task 'calculate_signal_magnitude_and_phase': ended at 2026-08-26
# [2026.08.26 16:16:54.919] INFO    13:16:54.919987Z
# [2026.08.26 16:16:55.051] INFO    Task 'fit_data': started at 2026-08-26 13:16:55.050128Z
# [2026.08.26 16:16:55.220] INFO    Task 'fit_data': ended at 2026-08-26 13:16:55.220644Z
# [2026.08.26 16:16:55.321] INFO    Task 'extract_qubit_parameters': started at 2026-08-26 13:16:55.321676Z
# [2026.08.26 16:16:55.463] INFO    Task 'extract_qubit_parameters': ended at 2026-08-26 13:16:55.463693Z
# [2026.08.26 16:16:55.559] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-26 13:16:55.559102Z
# [2026.08.26 16:16:55.676] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-26 13:16:55.675841Z
# [2026.08.26 16:16:56.020] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-26 13:16:56.020551Z
# [2026.08.26 16:16:56.069] INFO    Task 'plot_qubit_spectroscopy': started at 2026-08-26 13:16:56.068518Z
# [2026.08.26 16:16:56.231] INFO    Artifact: 'Qubit_Spectroscopy_Q2' of type 'Figure' logged at 2026-08-26
# [2026.08.26 16:16:56.246] INFO    13:16:56.231592Z
# [2026.08.26 16:16:56.958] INFO    Task 'plot_qubit_spectroscopy': ended at 2026-08-26 13:16:56.955583Z
# [2026.08.26 16:16:57.044] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.26 16:16:57.044] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-26 13:16:57.042291Z
# [2026.08.26 16:16:57.047] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.26 16:16:57.154] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.26 16:16:57.155] INFO      Workflow 'qubit_spectroscopy': execution ended at 2026-08-26
# [2026.08.26 16:16:57.155] INFO      13:16:57.154002Z
# [2026.08.26 16:16:57.157] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
manual_center_frequency = 5.0048e9
temporary_parameters[qubit_to_measure.uid].resonance_frequency_ge = manual_center_frequency

# %%
analysis_workflow_result= workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)

    qubit_spectroscopy.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    print("\nReadout resonance frequency ge: ", qubit_to_measure.parameters.resonance_frequency_ge)
    
    print('\nUpdated global experiment parameters!\n')
# Out:
# {'new_parameter_values': {'Q2': {'resonance_frequency_ge': 5004774146.703883+/-194876.21794345218}},
#  'old_parameter_values': {'Q2': {'resonance_frequency_ge': 5004800000.0}}}
#
# Readout resonance frequency ge:  5004774146.703883
#
# Updated global experiment parameters!

# %% [markdown]
# ### Second Transition: e-f

# %%
## define pulses

# qubit pi-pulse for first excited state
x180 = pulse_library.drag(uid="x180", length=5e-8, amplitude=0.2, sigma=0.25, beta=0)

# long spectroscopy pulse for e-f transition - frequency will be swept
ef_spec_pulse = pulse_library.const(uid="ef_pulse", length=10e-6, amplitude=0.2)

# readout drive pulse
readout_pulse = pulse_library.const(uid="readout_pulse", length=2e-6, amplitude=0.2)
# readout integration weights
readout_weighting_function = pulse_library.const(
    uid="readout_weighting_function", length=2e-6, amplitude=0.2
)

# %%
# set up sweep parameter - drive amplitude
start = 4.7e9
stop = 5e9
count = 70
frequency_sweep = LinearSweepParameter(
    uid="frequency", start=start, stop=stop, count=count
)

# number of averages
average_exponent = 12  # used for 2^n averages, n=average_exponent, maximum: n = 17

# Create Experiment
exp_ef_spec = Experiment(
    uid="e-f spectroscopy",
    signals=[
        ExperimentSignal("drive"),
        ExperimentSignal("drive_ef"),
        ExperimentSignal("measure"),
        ExperimentSignal("acquire"),
    ],
)
## experimental pulse sequence
# outer loop - real-time, cyclic averaging in standard integration mode
with exp_ef_spec.acquire_loop_rt(
    uid="shots",
    count=pow(2, average_exponent),
    averaging_mode=AveragingMode.CYCLIC,
    acquisition_type=AcquisitionType.INTEGRATION,
):
    # inner loop - real-time frequency sweep of qubit e-f drive pulse
    with exp_ef_spec.sweep(uid="sweep", parameter=frequency_sweep):
        # qubit excitation - pulse amplitude will be swept
        with exp_ef_spec.section(
            uid="qubit_excitation",
            on_system_grid=True,
            alignment=SectionAlignment.RIGHT,
        ):
            exp_ef_spec.play(signal="drive", pulse=x180)
        with exp_ef_spec.section(
            uid="qubit_ef_excitation",
            play_after="qubit_excitation",
            on_system_grid=True,
            alignment=SectionAlignment.RIGHT,
        ):
            exp_ef_spec.play(signal="drive_ef", pulse=ef_spec_pulse)
        # qubit readout pulse and data acquisition
        with exp_ef_spec.section(uid="qubit_readout", play_after="qubit_ef_excitation"):
            # play readout pulse
            exp_ef_spec.play(signal="measure", pulse=readout_pulse)
            # signal data acquisition
            exp_ef_spec.acquire(
                signal="acquire",
                handle="ac_0",
                kernel=readout_weighting_function,
            )
        # relax time after readout - for signal processing and qubit relaxation to groundstate
        with exp_ef_spec.section(uid="relax", length=150e-6):
            exp_ef_spec.reserve(signal="measure")

# %%
# define signal maps for qubit 0
map_q0 = {
    "drive": qubits[0].signals["drive"],
    "drive_ef": qubits[0].signals["drive_ef"],
    "measure": qubits[0].signals["measure"],
    "acquire": qubits[0].signals["acquire"],
}

# %%
# define experiment calibration
exp_calibration = Calibration(
    {
        "drive_ef": SignalCalibration(
            oscillator=Oscillator(
                # WORKAROUND: when sweeping an oscillator on a logical line using the oscillator switching feature, need to ensure that the uid of the swept oscillator is sorted() first
                uid="ef_drive_osc",
                frequency=frequency_sweep,
                modulation_type=ModulationType.HARDWARE,
            )
        )
    }
)

# %%
# set signal map to qubit 0
exp_ef_spec.set_signal_map(map_q0)
exp_ef_spec.set_calibration(exp_calibration)

# run experiment on qubit 0
compiled_exp_ef_spec = session.compile(exp_ef_spec)

ef_espec_results = session.run(compiled_exp_ef_spec)
# Out:
# [2026.08.26 16:22:20.651] INFO    Starting LabOne Q Compiler run...
# [2026.08.26 16:22:20.653] INFO    Schedule completed. [0.001 s]
# [2026.08.26 16:22:20.660] INFO    Code generation completed for all AWGs. [0.007 s]
# [2026.08.26 16:22:20.660] INFO    Completed compilation step 1 of 1. [0.011 s]
# [2026.08.26 16:22:20.660] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.26 16:22:20.660] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.26 16:22:20.660] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.26 16:22:20.660] INFO      SHFQC_DEV12192        0         10            0           1      8000
# [2026.08.26 16:22:20.674] INFO      SHFQC_DEV12192_sg     0         28            3           2     40224
# [2026.08.26 16:22:20.675] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.26 16:22:20.675] INFO      TOTAL                           38            3                 48224
# [2026.08.26 16:22:20.678] INFO     ───────────────────────────────────────────────────────────────────────
# ---------------------------------------------------------------------------
# LabOneQException                          Traceback (most recent call last)
# Cell In[59], line 6
#       2 exp_ef_spec.set_signal_map(map_q0)
#       3 exp_ef_spec.set_calibration(exp_calibration)
#       4
#       5 # run experiment on qubit 0
# ----> 6 compiled_exp_ef_spec = session.compile(exp_ef_spec)
#       7
#       8 ef_espec_results = session.run(compiled_exp_ef_spec)
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\dsl\session.py:419, in Session.compile(self, experiment, compiler_settings)
#     410 """Compiles the specified experiment and stores it in the compiled_experiment property.
#     411
#     412 Requires connected LabOne Q session (`session.connect()`) either with or without emulation mode.
#    (...)    416     compiler_settings: Extra options passed to the compiler.
#     417 """
#     418 self._experiment_definition = experiment
# --> 419 self._compiled_experiment = compile_experiment(
#     420     device_setup=self.device_setup,
#     421     experiment=self.experiment,
#     422     compiler_settings={
#     423         **(compiler_settings or {}),
#     424     },
#     425 )
#     426 self._last_results = None
#     427 return self._compiled_experiment
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\core\utilities\compile_experiment.py:37, in compile_experiment(device_setup, experiment, compiler_settings)
#      34 new_setup = convert_device_setup_to_setup(device_setup)
#      35 signal_mapping = convert_signal_map(experiment)
# ---> 37 scheduled_experiment = compile_experiment_impl(
#      38     device_setup=new_setup,
#      39     experiment=experiment,
#      40     signal_mappings=signal_mapping,
#      41     compiler_settings=compiler_settings,
#      42 )
#      43 compiled_experiment = CompiledExperiment(
#      44     device_setup=device_setup,
#      45     experiment=experiment,
#    (...)     48     scheduled_experiment=scheduled_experiment,
#      49 )
#      50 return compiled_experiment
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\implementation\payload_builder\payload_builder.py:38, in compile_experiment(device_setup, experiment, signal_mappings, compiler_settings)
#      33 execution = ExecutionFactoryFromExperiment().make(
#      34     experiment,
#      35     driver_parameter_map=driver_parameter_map,
#      36 )
#      37 compiler = Compiler(compiler_settings)
# ---> 38 return compiler.run(
#      39     CompilationJob(experiment_info=experiment_info, execution=execution)
#      40 )
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\compiler\workflow\compiler.py:297, in Compiler.run(self, data)
#     294 self._chunking_info = data.experiment_info.chunking
#     296 self._analyze_setup(self._experiment_dao)
# --> 297 compiler_output = self._process_experiment(compiler_module, device_class)
#     299 assert compiler_output is not None
#     300 _logger.info("Finished LabOne Q Compiler run.")
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\compiler\workflow\compiler.py:231, in Compiler._process_experiment(self, compiler_module, device_class)
#     226         raise LabOneQException(
#     227             f"Chunk count ({chunk_count}) does not evenly divide sweep length ({chunking.sweep_iterations})"
#     228         )
#     230 try:
# --> 231     return self._compile_whole_or_with_chunks(
#     232         experiment=experiment,
#     233         chunk_count=chunk_count,
#     234         device_class=device_class,
#     235         compiler_module=compiler_module,
#     236     )
#     237 except ResourceLimitationError as err:
#     238     msg = (
#     239         "Compilation error - resource limitation exceeded.\n"
#     240         "To circumvent this, try one or more of the following:\n"
#    (...)    245         "- If chunking is already enabled, increase the chunk count or switch to automatic chunking"
#     246     )
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\compiler\workflow\compiler.py:167, in Compiler._compile_whole_or_with_chunks(self, experiment, chunk_count, device_class, compiler_module)
#     161 assert combined_compiler_output is not None, (
#     162     "Internal error: missing real-time compiler output"
#     163 )
#     165 rt_loop_properties = executor.rt_loop_properties()
# --> 167 executor.finalize()
#     169 combined_output = combined_compiler_output.get_first_combined_output()
#     170 if combined_output is None:
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\compiler\workflow\neartime_execution.py:271, in NtCompilerExecutor.finalize(self)
#     269 for delegate in self._delegates:
#     270     delegate.after_final_run(self._combined_compiler_output)
# --> 271 rt_linker.finalize(self._combined_compiler_output, self._settings)
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\compiler\workflow\rt_linker.py:51, in finalize(this, settings)
#      50 def finalize(this: CombinedRTCompilerOutputContainer, settings: CompilerSettings):
# ---> 51     get_compiler_hooks(this.device_class).linker().finalize(
#      52         this.combined_output, settings
#      53     )
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\compiler\seqc\linker.py:414, in SeqCLinker.finalize(this, settings)
#     399 @staticmethod
#     400 def finalize(this: CombinedRTOutputSeqC, settings: CompilerSettings):
#     401     seqc_items = [
#     402         SeqCCompileItem(
#     403             dev_type=seqc_program.dev_type,
#    (...)    412         if seqc_program.dev_type is not None
#     413     ]
# --> 414     seqc_compile.awg_compile(seqc_items, settings)
#     415     for seqc_item in seqc_items:
#     416         this.src[seqc_item.filename].elf = seqc_item.elf
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\core\utilities\seqc_compile.py:124, in awg_compile(awg_data, settings)
#     118     concurrent.futures.wait(futures)
#     119     error_msgs = [
#     120         str(future.exception())
#     121         for future in futures
#     122         if future.exception() is not None
#     123     ]
# --> 124     _process_errors(error_msgs, settings)
#     125 _logger.debug("Finished compilation.")
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\laboneq\core\utilities\seqc_compile.py:108, in _process_errors(messages, settings)
#     106 if other_errors:
#     107     combined_messages = "\n".join([e for e in messages])
# --> 108     raise LabOneQException(f"Compilation failed.\n{combined_messages}")
#
# LabOneQException: Compilation failed.
# seq_SHFQC_DEV12192_sg_0_[].seqc: AWG compilation failed.
# Compilation failed: Compiler Error (line: 7): invalid value for argument 1 of function configFreqSweep

# %% [markdown]
# # Control Pulses

# %% [markdown]
# ## First Transision: g-e

# %% [markdown]
# ### Amplitude Rabi <a class="anchor" id="amplitude-rabi-ge"></a>

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ge')

drive_range = 10
drive_length = 100e-9
readout_amplitude = 0.2
n_avg_exponent = 13

amp_min = 0
amp_max = 1
n_amp = 41

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temp_pars.drive_range = drive_range
temp_pars.readout_amplitude = readout_amplitude
if transition == 'ge':
    temp_pars.ge_drive_length = drive_length
elif transition == 'ef':
    temp_pars.ef_drive_length = drive_length
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = amplitude_rabi.experiment_workflow.options()

options.count(2**n_avg_exponent)
options.close_figures(False) # Plot figures

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

exp_workflow = amplitude_rabi.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    amplitudes=[np.linspace(amp_min, amp_max, n_amp) for q in qubits_to_measure],
    options=options,
    temporary_parameters=temporary_parameters
)
workflow_result = exp_workflow.run()
# Out:
# [2026.09.01 14:14:54.945] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 14:14:54.945] INFO      Workflow 'amplitude_rabi': execution started at 2026-09-01 11:14:54.945382Z
# [2026.09.01 14:14:54.945] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 14:14:55.248] INFO    Task 'temporary_qpu': started at 2026-09-01 11:14:55.248214Z
# [2026.09.01 14:14:55.286] INFO    Task 'temporary_qpu': ended at 2026-09-01 11:14:55.286529Z
# [2026.09.01 14:14:55.379] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-09-01
# [2026.09.01 14:14:55.379] INFO    11:14:55.379679Z
# [2026.09.01 14:14:55.427] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-09-01 11:14:55.427178Z
# [2026.09.01 14:14:55.507] INFO    Task 'create_experiment': started at 2026-09-01 11:14:55.507491Z
# [2026.09.01 14:14:55.651] INFO    Task 'create_experiment': ended at 2026-09-01 11:14:55.651901Z
# [2026.09.01 14:14:55.762] INFO    Task 'compile_experiment': started at 2026-09-01 11:14:55.762681Z
# [2026.09.01 14:14:55.877] INFO    Starting LabOne Q Compiler run...
# [2026.09.01 14:14:55.877] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.09.01 14:14:55.877] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.09.01 14:14:55.877] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.09.01 14:14:55.877] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.09.01 14:14:55.884] INFO    Schedule completed. [0.001 s]
# [2026.09.01 14:14:55.895] INFO    Code generation completed for all AWGs. [0.009 s]
# [2026.09.01 14:14:55.895] INFO    Completed compilation step 1 of 1. [0.013 s]
# [2026.09.01 14:14:55.897] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.09.01 14:14:55.897] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.09.01 14:14:55.897] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.09.01 14:14:55.897] INFO      SHFQC_DEV12192        0         21            0           1      7616
# [2026.09.01 14:14:55.906] INFO      SHFQC_DEV12192_sg     0        139           43           2       832
# [2026.09.01 14:14:55.906] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.09.01 14:14:55.908] INFO      TOTAL                          160           43                  8448
# [2026.09.01 14:14:55.908] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.09.01 14:14:55.910] INFO    Finished LabOne Q Compiler run.
# [2026.09.01 14:14:55.926] INFO    Task 'compile_experiment': ended at 2026-09-01 11:14:55.926106Z
# [2026.09.01 14:14:56.088] INFO    Task 'run_experiment': started at 2026-09-01 11:14:56.088312Z
# [2026.09.01 14:14:56.263] INFO    Starting near-time execution...
# [2026.09.01 14:14:56.335] INFO    Estimated RT execution time: 106.38 s.
# [2026.09.01 14:16:42.781] INFO    Finished near-time execution.
# [2026.09.01 14:16:47.806] INFO    Task 'run_experiment': ended at 2026-09-01 11:16:47.806865Z
# [2026.09.01 14:16:47.934] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 14:16:47.936] INFO      Workflow 'analysis_workflow': execution started at 2026-09-01
# [2026.09.01 14:16:47.936] INFO      11:16:47.934702Z
# [2026.09.01 14:16:47.936] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 14:16:48.094] INFO    Task 'calculate_qubit_population': started at 2026-09-01 11:16:48.094287Z
# [2026.09.01 14:16:48.288] INFO    Task 'calculate_qubit_population': ended at 2026-09-01 11:16:48.288681Z
# [2026.09.01 14:16:48.461] INFO    Task 'fit_data': started at 2026-09-01 11:16:48.460001Z
# [2026.09.01 14:16:48.742] INFO    Task 'fit_data': ended at 2026-09-01 11:16:48.742259Z
# [2026.09.01 14:16:48.886] INFO    Task 'extract_qubit_parameters': started at 2026-09-01 11:16:48.886829Z
# [2026.09.01 14:16:49.111] INFO    Task 'extract_qubit_parameters': ended at 2026-09-01 11:16:49.111707Z
# [2026.09.01 14:16:49.225] INFO    Task 'plot_raw_complex_data_1d': started at 2026-09-01 11:16:49.225767Z
# [2026.09.01 14:16:49.337] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-09-01 11:16:49.337122Z
# [2026.09.01 14:16:49.802] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-09-01 11:16:49.801545Z
# [2026.09.01 14:16:49.849] INFO    Task 'plot_population': started at 2026-09-01 11:16:49.849857Z
# [2026.09.01 14:16:49.994] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-09-01 11:16:49.994292Z
# [2026.09.01 14:16:50.494] INFO    Task 'plot_population': ended at 2026-09-01 11:16:50.494231Z
# [2026.09.01 14:16:50.526] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 14:16:50.526] INFO      Workflow 'analysis_workflow': execution ended at 2026-09-01 11:16:50.525820Z
# [2026.09.01 14:16:50.526] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 14:16:50.557] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 14:16:50.557] INFO      Workflow 'amplitude_rabi': execution ended at 2026-09-01 11:16:50.557238Z
# [2026.09.01 14:16:50.573] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)
    
    amplitude_rabi.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nDrive amplitude pi ge: ", qubit_to_measure.parameters.ge_drive_amplitude_pi)
        print("Drive amplitude pi2 ge: ", qubit_to_measure.parameters.ge_drive_amplitude_pi2)
    elif transition == 'ef':
        print("\nDrive amplitude pi ef: ", qubit_to_measure.parameters.ef_drive_amplitude_pi)
        print("Drive amplitude pi2 ef: ", qubit_to_measure.parameters.ef_drive_amplitude_pi2)
    
    print('\nUpdated global experiment parameters!\n')
# Out:
# {'new_parameter_values': {'Q2': {'ge_drive_amplitude_pi': 0.21209885848954124+/-0.008941671190214,
#                                  'ge_drive_amplitude_pi2': 0.06206463372669052+/-0.008455434774034126}},
#  'old_parameter_values': {'Q2': {'ge_drive_amplitude_pi': 0.14880729338309864,
#                                  'ge_drive_amplitude_pi2': 0.0038312010088328015}}}
#
# Drive amplitude pi ge:  0.21209885848954124
# Drive amplitude pi2 ge:  0.06206463372669052
#
# Updated global experiment parameters!

# %% [markdown]
# ### Amplitude Rabi Chevron

# %% [markdown]
# #### Experiment Paramters

# %%
update_global_parameters = True

transition = set_transition('ge')

drive_range = 10
drive_length = 100e-9
readout_amplitude = 0.2
n_avg_exponent = 13

freq_range = 100e6
n_points = 251

amp_min = 0
amp_max = 1
n_amp = 41

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temp_pars.drive_range = drive_range
temp_pars.readout_amplitude = readout_amplitude
if transition == 'ge':
    temp_pars.ge_drive_length = drive_length
elif transition == 'ef':
    temp_pars.ef_drive_length = drive_length
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = amplitude_rabi_chevron.experiment_workflow.options()

options.count(2**n_avg_exponent)
options.close_figures(False) # Plot figures

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

frequencies = [
    temporary_parameters[q.uid].resonance_frequency_ge + np.linspace(- freq_range / 2, freq_range / 2, n_points)
    for q in qubits_to_measure
]

exp_workflow = amplitude_rabi_chevron.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    frequencies=frequencies,
    amplitudes=[np.linspace(amp_min, amp_max, n_amp) for q in qubits_to_measure],
    options=options,
    temporary_parameters=temporary_parameters
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.26 16:52:44.458] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.26 16:52:44.458] INFO      Workflow 'amplitude_rabi_chevron': execution started at 2026-08-26
# [2026.08.26 16:52:44.458] INFO      13:52:44.458857Z
# [2026.08.26 16:52:44.458] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.26 16:52:44.829] INFO    Task 'temporary_qpu': started at 2026-08-26 13:52:44.829371Z
# [2026.08.26 16:52:44.907] INFO    Task 'temporary_qpu': ended at 2026-08-26 13:52:44.907791Z
# [2026.08.26 16:52:45.031] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-26
# [2026.08.26 16:52:45.036] INFO    13:52:45.031762Z
# [2026.08.26 16:52:45.115] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-26 13:52:45.113016Z
# [2026.08.26 16:52:45.226] INFO    Task 'create_experiment': started at 2026-08-26 13:52:45.226658Z
# [2026.08.26 16:52:45.379] INFO    Task 'create_experiment': ended at 2026-08-26 13:52:45.373457Z
# [2026.08.26 16:52:45.484] INFO    Task 'compile_experiment': started at 2026-08-26 13:52:45.484517Z
# [2026.08.26 16:52:45.602] INFO    Starting LabOne Q Compiler run...
# [2026.08.26 16:52:45.602] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.26 16:52:45.608] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.26 16:52:45.611] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.26 16:52:45.612] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.26 16:52:45.951] INFO    Schedule completed. [0.341 s]
# [2026.08.26 16:52:46.978] INFO    Code generation completed for all AWGs. [1.024 s]
# [2026.08.26 16:52:47.010] INFO    Completed compilation step 1 of 1. [1.396 s]
# [2026.08.26 16:52:47.010] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.26 16:52:47.010] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.26 16:52:47.010] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.26 16:52:47.010] INFO      SHFQC_DEV12192        0         17            0           1      8000
# [2026.08.26 16:52:47.021] INFO      SHFQC_DEV12192_sg     0        958           43           2       832
# [2026.08.26 16:52:47.021] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.26 16:52:47.021] INFO      TOTAL                          975           43                  8832
# [2026.08.26 16:52:47.021] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.26 16:52:47.108] INFO    Finished LabOne Q Compiler run.
# [2026.08.26 16:52:47.108] INFO    Task 'compile_experiment': ended at 2026-08-26 13:52:47.108109Z
# [2026.08.26 16:52:47.301] INFO    Task 'run_experiment': started at 2026-08-26 13:52:47.301311Z
# [2026.08.26 16:52:47.513] INFO    Starting near-time execution...
# [2026.08.26 16:52:47.587] INFO    Estimated RT execution time: 76404.26 s.
# [2026.08.27 14:06:12.080] INFO    Finished near-time execution.
# [2026.08.27 14:06:17.815] INFO    Task 'run_experiment': ended at 2026-08-27 11:06:17.812506Z
# [2026.08.27 14:06:18.005] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:06:18.005] INFO      Workflow 'analysis_workflow': execution started at 2026-08-27
# [2026.08.27 14:06:18.005] INFO      11:06:18.005002Z
# [2026.08.27 14:06:18.005] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:06:18.088] INFO    Task 'calculate_qubit_population_2d': started at 2026-08-27 11:06:18.088383Z
# [2026.08.27 14:06:18.173] INFO    Task 'calculate_qubit_population_2d': ended at 2026-08-27 11:06:18.173393Z
# [2026.08.27 14:06:18.260] INFO    Task 'plot_population': started at 2026-08-27 11:06:18.260623Z
# [2026.08.27 14:06:18.477] INFO    Artifact: 'Amplitude_Rabi_Chevron_Q2' of type 'Figure' logged at 2026-08-27
# [2026.08.27 14:06:18.477] INFO    11:06:18.477742Z
# [2026.08.27 14:06:18.775] INFO    Task 'plot_population': ended at 2026-08-27 11:06:18.775146Z
# [2026.08.27 14:06:18.806] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:06:18.806] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-27 11:06:18.806423Z
# [2026.08.27 14:06:18.822] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:06:18.863] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:06:18.863] INFO      Workflow 'amplitude_rabi_chevron': execution ended at 2026-08-27
# [2026.08.27 14:06:18.863] INFO      11:06:18.863135Z
# [2026.08.27 14:06:18.863] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)
    
    amplitude_rabi.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nDrive amplitude pi ge: ", qubit_to_measure.parameters.ge_drive_amplitude_pi)
        print("Drive amplitude pi2 ge: ", qubit_to_measure.parameters.ge_drive_amplitude_pi2)
    elif transition == 'ef':
        print("\nDrive amplitude pi ef: ", qubit_to_measure.parameters.ef_drive_amplitude_pi)
        print("Drive amplitude pi2 ef: ", qubit_to_measure.parameters.ef_drive_amplitude_pi2)
    
    print('\nUpdated global experiment parameters!\n')

# %% [markdown]
# ### Rabi Chevron

# %% [markdown]
# #### Experiment Parameters

# %%
# Rabi chevron is a diagnostic 2D scan (amplitude vs. detuning) - it is not expected
# to update the global qubit parameters directly, so I leave this False by default.
update_global_parameters = False

transition = set_transition('ge')

drive_range = 10
drive_length = 100e-9
readout_amplitude = 0.2
n_avg_exponent = 13

amp_min = 0
amp_max = 1
n_amp = 41

# frequency detuning range swept around the qubit's current resonance frequency
chevron_detuning_min = -6e6
chevron_detuning_max = 6e6
n_detuning = 9
chevron_detunings = np.linspace(chevron_detuning_min, chevron_detuning_max, n_detuning)

if transition == 'ge':
    base_resonance_frequency = qubits[0].parameters.resonance_frequency_ge
elif transition == 'ef':
    base_resonance_frequency = qubits[0].parameters.resonance_frequency_ef

# %% [markdown]
# #### Run Workflow

# %%
options = amplitude_rabi.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(True)  # suppress per-detuning plots; we build one 2D map below

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

rabi_chevron_results = []

for detuning in chevron_detunings:
    print(f'Measuring chevron point at detuning: {detuning * 1e-6:.3f} MHz')

    temporary_parameters = {}
    temp_pars = deepcopy(qubits[0].parameters)
    temp_pars.drive_range = drive_range
    temp_pars.readout_amplitude = readout_amplitude
    if transition == 'ge':
        temp_pars.ge_drive_length = drive_length
        temp_pars.resonance_frequency_ge = base_resonance_frequency + detuning
    elif transition == 'ef':
        temp_pars.ef_drive_length = drive_length
        temp_pars.resonance_frequency_ef = base_resonance_frequency + detuning
    temporary_parameters[q.uid] = temp_pars

    exp_workflow = amplitude_rabi.experiment_workflow(
        session=session,
        qpu=qpu,
        qubits=[q.uid for q in qubits_to_measure],
        amplitudes=[np.linspace(amp_min, amp_max, n_amp) for q in qubits_to_measure],
        options=options,
        temporary_parameters=temporary_parameters
    )
    workflow_result = exp_workflow.run()

    # Raw acquired signal for the qubit under test.
    # NOTE: adjust the accessor below if `get_data` does not match the acquire
    # handle used internally by the installed version of `amplitude_rabi`.
    raw_signal = workflow_result.tasks["run_experiment"].output.get_data(qubit_to_measure.uid+"/result")
    rabi_chevron_results.append(raw_signal)

rabi_chevron_arr = np.array(rabi_chevron_results)
rabi_chevron_amp = np.linspace(amp_min, amp_max, n_amp)
# Out:
# Measuring chevron point at detuning: -6.000 MHz
# [2026.08.27 14:06:19.594] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:06:19.594] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-27 11:06:19.594664Z
# [2026.08.27 14:06:19.594] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:06:19.860] INFO    Task 'temporary_qpu': started at 2026-08-27 11:06:19.860176Z
# [2026.08.27 14:06:19.900] INFO    Task 'temporary_qpu': ended at 2026-08-27 11:06:19.900023Z
# [2026.08.27 14:06:19.979] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-27
# [2026.08.27 14:06:19.979] INFO    11:06:19.979862Z
# [2026.08.27 14:06:20.031] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-27 11:06:20.029023Z
# [2026.08.27 14:06:20.124] INFO    Task 'create_experiment': started at 2026-08-27 11:06:20.124264Z
# [2026.08.27 14:06:20.252] INFO    Task 'create_experiment': ended at 2026-08-27 11:06:20.252503Z
# [2026.08.27 14:06:20.339] INFO    Task 'compile_experiment': started at 2026-08-27 11:06:20.339691Z
# [2026.08.27 14:06:20.412] INFO    Starting LabOne Q Compiler run...
# [2026.08.27 14:06:20.412] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.27 14:06:20.416] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.27 14:06:20.416] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.27 14:06:20.416] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.27 14:06:20.422] INFO    Schedule completed. [0.001 s]
# [2026.08.27 14:06:20.429] INFO    Code generation completed for all AWGs. [0.015 s]
# [2026.08.27 14:06:20.429] INFO    Completed compilation step 1 of 1. [0.020 s]
# [2026.08.27 14:06:20.445] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:06:20.445] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.27 14:06:20.445] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:06:20.460] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.27 14:06:20.462] INFO      SHFQC_DEV12192_sg     0        139           43           2       832
# [2026.08.27 14:06:20.462] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:06:20.464] INFO      TOTAL                          160           43                  8832
# [2026.08.27 14:06:20.464] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:06:20.492] INFO    Finished LabOne Q Compiler run.
# [2026.08.27 14:06:20.492] INFO    Task 'compile_experiment': ended at 2026-08-27 11:06:20.492433Z
# [2026.08.27 14:06:20.604] INFO    Task 'run_experiment': started at 2026-08-27 11:06:20.604717Z
# [2026.08.27 14:06:20.765] INFO    Starting near-time execution...
# [2026.08.27 14:06:20.853] INFO    Estimated RT execution time: 106.42 s.
# [2026.08.27 14:08:07.357] INFO    Finished near-time execution.
# [2026.08.27 14:08:07.430] INFO    Task 'run_experiment': ended at 2026-08-27 11:08:07.430343Z
# [2026.08.27 14:08:07.534] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:08:07.534] INFO      Workflow 'analysis_workflow': execution started at 2026-08-27
# [2026.08.27 14:08:07.534] INFO      11:08:07.534060Z
# [2026.08.27 14:08:07.534] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:08:07.640] INFO    Task 'calculate_qubit_population': started at 2026-08-27 11:08:07.638992Z
# [2026.08.27 14:08:07.732] INFO    Task 'calculate_qubit_population': ended at 2026-08-27 11:08:07.730959Z
# [2026.08.27 14:08:07.814] INFO    Task 'fit_data': started at 2026-08-27 11:08:07.814772Z
# [2026.08.27 14:08:07.958] INFO    Task 'fit_data': ended at 2026-08-27 11:08:07.958559Z
# [2026.08.27 14:08:08.062] INFO    Task 'extract_qubit_parameters': started at 2026-08-27 11:08:08.062442Z
# [2026.08.27 14:08:08.165] INFO    Task 'extract_qubit_parameters': ended at 2026-08-27 11:08:08.164757Z
# [2026.08.27 14:08:08.236] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-27 11:08:08.234331Z
# [2026.08.27 14:08:08.360] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-27 11:08:08.358842Z
# [2026.08.27 14:08:08.891] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-27 11:08:08.891052Z
# [2026.08.27 14:08:08.923] INFO    Task 'plot_population': started at 2026-08-27 11:08:08.923078Z
# [2026.08.27 14:08:09.053] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-27 11:08:09.053881Z
# [2026.08.27 14:08:09.374] INFO    Task 'plot_population': ended at 2026-08-27 11:08:09.374855Z
# [2026.08.27 14:08:09.408] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:08:09.408] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-27 11:08:09.408953Z
# [2026.08.27 14:08:09.408] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:08:09.456] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:08:09.456] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-27 11:08:09.456562Z
# [2026.08.27 14:08:09.456] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: -4.500 MHz
# [2026.08.27 14:08:09.583] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:08:09.585] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-27 11:08:09.583022Z
# [2026.08.27 14:08:09.585] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:08:09.824] INFO    Task 'temporary_qpu': started at 2026-08-27 11:08:09.824553Z
# [2026.08.27 14:08:09.858] INFO    Task 'temporary_qpu': ended at 2026-08-27 11:08:09.858603Z
# [2026.08.27 14:08:09.938] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-27
# [2026.08.27 14:08:09.938] INFO    11:08:09.938000Z
# [2026.08.27 14:08:09.986] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-27 11:08:09.986411Z
# [2026.08.27 14:08:10.082] INFO    Task 'create_experiment': started at 2026-08-27 11:08:10.081187Z
# [2026.08.27 14:08:10.194] INFO    Task 'create_experiment': ended at 2026-08-27 11:08:10.194402Z
# [2026.08.27 14:08:10.257] INFO    Task 'compile_experiment': started at 2026-08-27 11:08:10.254282Z
# [2026.08.27 14:08:10.307] INFO    Starting LabOne Q Compiler run...
# [2026.08.27 14:08:10.322] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.27 14:08:10.322] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.27 14:08:10.322] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.27 14:08:10.322] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.27 14:08:10.329] INFO    Schedule completed. [0.001 s]
# [2026.08.27 14:08:10.338] INFO    Code generation completed for all AWGs. [0.007 s]
# [2026.08.27 14:08:10.340] INFO    Completed compilation step 1 of 1. [0.013 s]
# [2026.08.27 14:08:10.340] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:08:10.347] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.27 14:08:10.349] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:08:10.349] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.27 14:08:10.349] INFO      SHFQC_DEV12192_sg     0        139           43           2       832
# [2026.08.27 14:08:10.351] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:08:10.353] INFO      TOTAL                          160           43                  8832
# [2026.08.27 14:08:10.353] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:08:10.369] INFO    Finished LabOne Q Compiler run.
# [2026.08.27 14:08:10.370] INFO    Task 'compile_experiment': ended at 2026-08-27 11:08:10.370864Z
# [2026.08.27 14:08:10.455] INFO    Task 'run_experiment': started at 2026-08-27 11:08:10.455107Z
# [2026.08.27 14:08:10.570] INFO    Starting near-time execution...
# [2026.08.27 14:08:10.645] INFO    Estimated RT execution time: 106.42 s.
# [2026.08.27 14:09:57.145] INFO    Finished near-time execution.
# [2026.08.27 14:09:57.225] INFO    Task 'run_experiment': ended at 2026-08-27 11:09:57.225878Z
# [2026.08.27 14:09:57.323] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:09:57.323] INFO      Workflow 'analysis_workflow': execution started at 2026-08-27
# [2026.08.27 14:09:57.338] INFO      11:09:57.323677Z
# [2026.08.27 14:09:57.338] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:09:57.451] INFO    Task 'calculate_qubit_population': started at 2026-08-27 11:09:57.451638Z
# [2026.08.27 14:09:57.535] INFO    Task 'calculate_qubit_population': ended at 2026-08-27 11:09:57.535963Z
# [2026.08.27 14:09:57.613] INFO    Task 'fit_data': started at 2026-08-27 11:09:57.613289Z
# [2026.08.27 14:09:57.749] INFO    Task 'fit_data': ended at 2026-08-27 11:09:57.746402Z
# [2026.08.27 14:09:57.820] INFO    Task 'extract_qubit_parameters': started at 2026-08-27 11:09:57.820666Z
# [2026.08.27 14:09:57.948] INFO    Task 'extract_qubit_parameters': ended at 2026-08-27 11:09:57.948568Z
# [2026.08.27 14:09:58.031] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-27 11:09:58.031138Z
# [2026.08.27 14:09:58.141] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-27 11:09:58.141234Z
# [2026.08.27 14:09:58.787] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-27 11:09:58.786094Z
# [2026.08.27 14:09:58.819] INFO    Task 'plot_population': started at 2026-08-27 11:09:58.819531Z
# [2026.08.27 14:09:58.961] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-27 11:09:58.961859Z
# [2026.08.27 14:09:59.368] INFO    Task 'plot_population': ended at 2026-08-27 11:09:59.368479Z
# [2026.08.27 14:09:59.414] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:09:59.414] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-27 11:09:59.414090Z
# [2026.08.27 14:09:59.414] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:09:59.463] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:09:59.463] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-27 11:09:59.461746Z
# [2026.08.27 14:09:59.463] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: -3.000 MHz
# [2026.08.27 14:09:59.591] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:09:59.591] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-27 11:09:59.591350Z
# [2026.08.27 14:09:59.591] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:09:59.848] INFO    Task 'temporary_qpu': started at 2026-08-27 11:09:59.848251Z
# [2026.08.27 14:09:59.897] INFO    Task 'temporary_qpu': ended at 2026-08-27 11:09:59.897236Z
# [2026.08.27 14:09:59.985] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-27
# [2026.08.27 14:09:59.985] INFO    11:09:59.985589Z
# [2026.08.27 14:10:00.027] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-27 11:10:00.027347Z
# [2026.08.27 14:10:00.125] INFO    Task 'create_experiment': started at 2026-08-27 11:10:00.125498Z
# [2026.08.27 14:10:00.252] INFO    Task 'create_experiment': ended at 2026-08-27 11:10:00.252542Z
# [2026.08.27 14:10:00.331] INFO    Task 'compile_experiment': started at 2026-08-27 11:10:00.331774Z
# [2026.08.27 14:10:00.421] INFO    Starting LabOne Q Compiler run...
# [2026.08.27 14:10:00.428] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.27 14:10:00.428] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.27 14:10:00.428] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.27 14:10:00.428] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.27 14:10:00.435] INFO    Schedule completed. [0.000 s]
# [2026.08.27 14:10:00.448] INFO    Code generation completed for all AWGs. [0.011 s]
# [2026.08.27 14:10:00.448] INFO    Completed compilation step 1 of 1. [0.016 s]
# [2026.08.27 14:10:00.456] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:10:00.463] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.27 14:10:00.464] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:10:00.464] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.27 14:10:00.464] INFO      SHFQC_DEV12192_sg     0        139           43           2       832
# [2026.08.27 14:10:00.464] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:10:00.464] INFO      TOTAL                          160           43                  8832
# [2026.08.27 14:10:00.464] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:10:00.479] INFO    Finished LabOne Q Compiler run.
# [2026.08.27 14:10:00.479] INFO    Task 'compile_experiment': ended at 2026-08-27 11:10:00.479139Z
# [2026.08.27 14:10:00.597] INFO    Task 'run_experiment': started at 2026-08-27 11:10:00.597434Z
# [2026.08.27 14:10:00.738] INFO    Starting near-time execution...
# [2026.08.27 14:10:00.827] INFO    Estimated RT execution time: 106.42 s.
# [2026.08.27 14:11:47.321] INFO    Finished near-time execution.
# [2026.08.27 14:11:47.394] INFO    Task 'run_experiment': ended at 2026-08-27 11:11:47.394791Z
# [2026.08.27 14:11:47.483] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:11:47.483] INFO      Workflow 'analysis_workflow': execution started at 2026-08-27
# [2026.08.27 14:11:47.483] INFO      11:11:47.483573Z
# [2026.08.27 14:11:47.483] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:11:47.579] INFO    Task 'calculate_qubit_population': started at 2026-08-27 11:11:47.579177Z
# [2026.08.27 14:11:47.664] INFO    Task 'calculate_qubit_population': ended at 2026-08-27 11:11:47.664859Z
# [2026.08.27 14:11:47.740] INFO    Task 'fit_data': started at 2026-08-27 11:11:47.740106Z
# [2026.08.27 14:11:47.903] INFO    Task 'fit_data': ended at 2026-08-27 11:11:47.900198Z
# [2026.08.27 14:11:47.980] INFO    Task 'extract_qubit_parameters': started at 2026-08-27 11:11:47.980632Z
# [2026.08.27 14:11:48.118] INFO    Task 'extract_qubit_parameters': ended at 2026-08-27 11:11:48.118940Z
# [2026.08.27 14:11:48.204] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-27 11:11:48.204555Z
# [2026.08.27 14:11:48.348] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-27 11:11:48.348849Z
# [2026.08.27 14:11:48.980] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-27 11:11:48.980166Z
# [2026.08.27 14:11:49.026] INFO    Task 'plot_population': started at 2026-08-27 11:11:49.026101Z
# [2026.08.27 14:11:49.181] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-27 11:11:49.179544Z
# [2026.08.27 14:11:49.603] INFO    Task 'plot_population': ended at 2026-08-27 11:11:49.603420Z
# [2026.08.27 14:11:49.636] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:11:49.636] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-27 11:11:49.636274Z
# [2026.08.27 14:11:49.636] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:11:49.678] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:11:49.684] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-27 11:11:49.678773Z
# [2026.08.27 14:11:49.684] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: -1.500 MHz
# [2026.08.27 14:11:49.827] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:11:49.827] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-27 11:11:49.827944Z
# [2026.08.27 14:11:49.827] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:11:50.086] INFO    Task 'temporary_qpu': started at 2026-08-27 11:11:50.086035Z
# [2026.08.27 14:11:50.118] INFO    Task 'temporary_qpu': ended at 2026-08-27 11:11:50.118594Z
# [2026.08.27 14:11:50.198] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-27
# [2026.08.27 14:11:50.198] INFO    11:11:50.198635Z
# [2026.08.27 14:11:50.260] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-27 11:11:50.248321Z
# [2026.08.27 14:11:50.341] INFO    Task 'create_experiment': started at 2026-08-27 11:11:50.341457Z
# [2026.08.27 14:11:50.456] INFO    Task 'create_experiment': ended at 2026-08-27 11:11:50.456846Z
# [2026.08.27 14:11:50.539] INFO    Task 'compile_experiment': started at 2026-08-27 11:11:50.539368Z
# [2026.08.27 14:11:50.614] INFO    Starting LabOne Q Compiler run...
# [2026.08.27 14:11:50.614] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.27 14:11:50.614] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.27 14:11:50.630] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.27 14:11:50.630] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.27 14:11:50.630] INFO    Schedule completed. [0.002 s]
# [2026.08.27 14:11:50.639] INFO    Code generation completed for all AWGs. [0.007 s]
# [2026.08.27 14:11:50.639] INFO    Completed compilation step 1 of 1. [0.013 s]
# [2026.08.27 14:11:50.648] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:11:50.648] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.27 14:11:50.648] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:11:50.648] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.27 14:11:50.648] INFO      SHFQC_DEV12192_sg     0        139           43           2       832
# [2026.08.27 14:11:50.648] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:11:50.648] INFO      TOTAL                          160           43                  8832
# [2026.08.27 14:11:50.648] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:11:50.665] INFO    Finished LabOne Q Compiler run.
# [2026.08.27 14:11:50.665] INFO    Task 'compile_experiment': ended at 2026-08-27 11:11:50.665447Z
# [2026.08.27 14:11:50.777] INFO    Task 'run_experiment': started at 2026-08-27 11:11:50.775937Z
# [2026.08.27 14:11:50.938] INFO    Starting near-time execution...
# [2026.08.27 14:11:51.006] INFO    Estimated RT execution time: 106.42 s.
# [2026.08.27 14:13:37.504] INFO    Finished near-time execution.
# [2026.08.27 14:13:37.562] INFO    Task 'run_experiment': ended at 2026-08-27 11:13:37.562170Z
# [2026.08.27 14:13:37.651] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:13:37.651] INFO      Workflow 'analysis_workflow': execution started at 2026-08-27
# [2026.08.27 14:13:37.651] INFO      11:13:37.651223Z
# [2026.08.27 14:13:37.651] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:13:37.749] INFO    Task 'calculate_qubit_population': started at 2026-08-27 11:13:37.749249Z
# [2026.08.27 14:13:37.828] INFO    Task 'calculate_qubit_population': ended at 2026-08-27 11:13:37.827476Z
# [2026.08.27 14:13:37.898] INFO    Task 'fit_data': started at 2026-08-27 11:13:37.898982Z
# [2026.08.27 14:13:38.020] INFO    Task 'fit_data': ended at 2026-08-27 11:13:38.020343Z
# [2026.08.27 14:13:38.101] INFO    Task 'extract_qubit_parameters': started at 2026-08-27 11:13:38.101334Z
# [2026.08.27 14:13:38.228] INFO    Task 'extract_qubit_parameters': ended at 2026-08-27 11:13:38.228759Z
# [2026.08.27 14:13:38.309] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-27 11:13:38.309454Z
# [2026.08.27 14:13:38.422] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-27 11:13:38.422554Z
# [2026.08.27 14:13:39.002] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-27 11:13:39.002719Z
# [2026.08.27 14:13:39.052] INFO    Task 'plot_population': started at 2026-08-27 11:13:39.050508Z
# [2026.08.27 14:13:39.209] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-27 11:13:39.207728Z
# [2026.08.27 14:13:39.583] INFO    Task 'plot_population': ended at 2026-08-27 11:13:39.583352Z
# [2026.08.27 14:13:39.631] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:13:39.631] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-27 11:13:39.631033Z
# [2026.08.27 14:13:39.631] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:13:39.677] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:13:39.679] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-27 11:13:39.670620Z
# [2026.08.27 14:13:39.679] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: 0.000 MHz
# [2026.08.27 14:13:39.831] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:13:39.833] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-27 11:13:39.827852Z
# [2026.08.27 14:13:39.833] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:13:40.128] INFO    Task 'temporary_qpu': started at 2026-08-27 11:13:40.128165Z
# [2026.08.27 14:13:40.162] INFO    Task 'temporary_qpu': ended at 2026-08-27 11:13:40.162642Z
# [2026.08.27 14:13:40.255] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-27
# [2026.08.27 14:13:40.255] INFO    11:13:40.255815Z
# [2026.08.27 14:13:40.305] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-27 11:13:40.305734Z
# [2026.08.27 14:13:40.384] INFO    Task 'create_experiment': started at 2026-08-27 11:13:40.384036Z
# [2026.08.27 14:13:40.497] INFO    Task 'create_experiment': ended at 2026-08-27 11:13:40.480762Z
# [2026.08.27 14:13:40.579] INFO    Task 'compile_experiment': started at 2026-08-27 11:13:40.577446Z
# [2026.08.27 14:13:40.678] INFO    Starting LabOne Q Compiler run...
# [2026.08.27 14:13:40.678] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.27 14:13:40.678] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.27 14:13:40.688] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.27 14:13:40.689] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.27 14:13:40.691] INFO    Schedule completed. [0.001 s]
# [2026.08.27 14:13:40.694] INFO    Code generation completed for all AWGs. [0.005 s]
# [2026.08.27 14:13:40.694] INFO    Completed compilation step 1 of 1. [0.009 s]
# [2026.08.27 14:13:40.707] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:13:40.710] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.27 14:13:40.710] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:13:40.710] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.27 14:13:40.710] INFO      SHFQC_DEV12192_sg     0        139           43           2       832
# [2026.08.27 14:13:40.710] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:13:40.710] INFO      TOTAL                          160           43                  8832
# [2026.08.27 14:13:40.710] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:13:40.730] INFO    Finished LabOne Q Compiler run.
# [2026.08.27 14:13:40.732] INFO    Task 'compile_experiment': ended at 2026-08-27 11:13:40.732584Z
# [2026.08.27 14:13:40.832] INFO    Task 'run_experiment': started at 2026-08-27 11:13:40.832895Z
# [2026.08.27 14:13:40.978] INFO    Starting near-time execution...
# [2026.08.27 14:13:41.066] INFO    Estimated RT execution time: 106.42 s.
# [2026.08.27 14:15:27.562] INFO    Finished near-time execution.
# [2026.08.27 14:15:27.634] INFO    Task 'run_experiment': ended at 2026-08-27 11:15:27.634194Z
# [2026.08.27 14:15:27.729] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:15:27.729] INFO      Workflow 'analysis_workflow': execution started at 2026-08-27
# [2026.08.27 14:15:27.729] INFO      11:15:27.729489Z
# [2026.08.27 14:15:27.729] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:15:27.841] INFO    Task 'calculate_qubit_population': started at 2026-08-27 11:15:27.841601Z
# [2026.08.27 14:15:27.922] INFO    Task 'calculate_qubit_population': ended at 2026-08-27 11:15:27.922492Z
# [2026.08.27 14:15:28.017] INFO    Task 'fit_data': started at 2026-08-27 11:15:28.014390Z
# [2026.08.27 14:15:28.146] INFO    Task 'fit_data': ended at 2026-08-27 11:15:28.146446Z
# [2026.08.27 14:15:28.243] INFO    Task 'extract_qubit_parameters': started at 2026-08-27 11:15:28.228790Z
# [2026.08.27 14:15:28.373] INFO    Task 'extract_qubit_parameters': ended at 2026-08-27 11:15:28.373080Z
# [2026.08.27 14:15:28.452] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-27 11:15:28.452109Z
# [2026.08.27 14:15:28.582] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-27 11:15:28.582433Z
# [2026.08.27 14:15:29.178] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-27 11:15:29.178053Z
# [2026.08.27 14:15:29.223] INFO    Task 'plot_population': started at 2026-08-27 11:15:29.223790Z
# [2026.08.27 14:15:29.384] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-27 11:15:29.384833Z
# [2026.08.27 14:15:29.854] INFO    Task 'plot_population': ended at 2026-08-27 11:15:29.854496Z
# [2026.08.27 14:15:29.907] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:15:29.909] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-27 11:15:29.907086Z
# [2026.08.27 14:15:29.911] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:15:29.948] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:15:29.948] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-27 11:15:29.948996Z
# [2026.08.27 14:15:29.948] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: 1.500 MHz
# [2026.08.27 14:15:30.126] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:15:30.126] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-27 11:15:30.126167Z
# [2026.08.27 14:15:30.126] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:15:30.407] INFO    Task 'temporary_qpu': started at 2026-08-27 11:15:30.405399Z
# [2026.08.27 14:15:30.453] INFO    Task 'temporary_qpu': ended at 2026-08-27 11:15:30.453527Z
# [2026.08.27 14:15:30.536] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-27
# [2026.08.27 14:15:30.538] INFO    11:15:30.534943Z
# [2026.08.27 14:15:30.580] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-27 11:15:30.580532Z
# [2026.08.27 14:15:30.681] INFO    Task 'create_experiment': started at 2026-08-27 11:15:30.680166Z
# [2026.08.27 14:15:30.798] INFO    Task 'create_experiment': ended at 2026-08-27 11:15:30.797471Z
# [2026.08.27 14:15:30.892] INFO    Task 'compile_experiment': started at 2026-08-27 11:15:30.891437Z
# [2026.08.27 14:15:30.976] INFO    Starting LabOne Q Compiler run...
# [2026.08.27 14:15:30.976] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.27 14:15:30.976] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.27 14:15:30.979] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.27 14:15:30.979] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.27 14:15:30.981] INFO    Schedule completed. [0.001 s]
# [2026.08.27 14:15:30.988] INFO    Code generation completed for all AWGs. [0.006 s]
# [2026.08.27 14:15:30.991] INFO    Completed compilation step 1 of 1. [0.009 s]
# [2026.08.27 14:15:31.001] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:15:31.004] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.27 14:15:31.006] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:15:31.006] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.27 14:15:31.009] INFO      SHFQC_DEV12192_sg     0        139           43           2       832
# [2026.08.27 14:15:31.010] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:15:31.010] INFO      TOTAL                          160           43                  8832
# [2026.08.27 14:15:31.013] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:15:31.031] INFO    Finished LabOne Q Compiler run.
# [2026.08.27 14:15:31.032] INFO    Task 'compile_experiment': ended at 2026-08-27 11:15:31.032912Z
# [2026.08.27 14:15:31.182] INFO    Task 'run_experiment': started at 2026-08-27 11:15:31.181704Z
# [2026.08.27 14:15:31.334] INFO    Starting near-time execution...
# [2026.08.27 14:15:31.409] INFO    Estimated RT execution time: 106.42 s.
# [2026.08.27 14:17:17.902] INFO    Finished near-time execution.
# [2026.08.27 14:17:17.986] INFO    Task 'run_experiment': ended at 2026-08-27 11:17:17.978344Z
# [2026.08.27 14:17:18.083] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:17:18.083] INFO      Workflow 'analysis_workflow': execution started at 2026-08-27
# [2026.08.27 14:17:18.083] INFO      11:17:18.083047Z
# [2026.08.27 14:17:18.098] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:17:18.198] INFO    Task 'calculate_qubit_population': started at 2026-08-27 11:17:18.198022Z
# [2026.08.27 14:17:18.275] INFO    Task 'calculate_qubit_population': ended at 2026-08-27 11:17:18.275450Z
# [2026.08.27 14:17:18.370] INFO    Task 'fit_data': started at 2026-08-27 11:17:18.370708Z
# [2026.08.27 14:17:18.499] INFO    Task 'fit_data': ended at 2026-08-27 11:17:18.499935Z
# [2026.08.27 14:17:18.580] INFO    Task 'extract_qubit_parameters': started at 2026-08-27 11:17:18.580372Z
# [2026.08.27 14:17:18.720] INFO    Task 'extract_qubit_parameters': ended at 2026-08-27 11:17:18.720876Z
# [2026.08.27 14:17:18.801] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-27 11:17:18.801013Z
# [2026.08.27 14:17:18.934] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-27 11:17:18.934889Z
# [2026.08.27 14:17:19.352] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-27 11:17:19.352113Z
# [2026.08.27 14:17:19.386] INFO    Task 'plot_population': started at 2026-08-27 11:17:19.386517Z
# [2026.08.27 14:17:19.533] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-27 11:17:19.533019Z
# [2026.08.27 14:17:19.876] INFO    Task 'plot_population': ended at 2026-08-27 11:17:19.876538Z
# [2026.08.27 14:17:19.914] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:17:19.914] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-27 11:17:19.914901Z
# [2026.08.27 14:17:19.914] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:17:19.979] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:17:19.986] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-27 11:17:19.979597Z
# [2026.08.27 14:17:19.987] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: 3.000 MHz
# [2026.08.27 14:17:20.143] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:17:20.143] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-27 11:17:20.143299Z
# [2026.08.27 14:17:20.143] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:17:20.414] INFO    Task 'temporary_qpu': started at 2026-08-27 11:17:20.414411Z
# [2026.08.27 14:17:20.446] INFO    Task 'temporary_qpu': ended at 2026-08-27 11:17:20.446557Z
# [2026.08.27 14:17:20.542] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-27
# [2026.08.27 14:17:20.542] INFO    11:17:20.542915Z
# [2026.08.27 14:17:20.580] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-27 11:17:20.580172Z
# [2026.08.27 14:17:20.671] INFO    Task 'create_experiment': started at 2026-08-27 11:17:20.671357Z
# [2026.08.27 14:17:20.785] INFO    Task 'create_experiment': ended at 2026-08-27 11:17:20.785884Z
# [2026.08.27 14:17:20.865] INFO    Task 'compile_experiment': started at 2026-08-27 11:17:20.865566Z
# [2026.08.27 14:17:20.915] INFO    Starting LabOne Q Compiler run...
# [2026.08.27 14:17:20.915] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.27 14:17:20.915] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.27 14:17:20.915] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.27 14:17:20.915] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.27 14:17:20.921] INFO    Schedule completed. [0.000 s]
# [2026.08.27 14:17:20.924] INFO    Code generation completed for all AWGs. [0.004 s]
# [2026.08.27 14:17:20.924] INFO    Completed compilation step 1 of 1. [0.007 s]
# [2026.08.27 14:17:20.932] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:17:20.932] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.27 14:17:20.932] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:17:20.932] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.27 14:17:20.932] INFO      SHFQC_DEV12192_sg     0        139           43           2       832
# [2026.08.27 14:17:20.932] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:17:20.932] INFO      TOTAL                          160           43                  8832
# [2026.08.27 14:17:20.944] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:17:20.958] INFO    Finished LabOne Q Compiler run.
# [2026.08.27 14:17:20.962] INFO    Task 'compile_experiment': ended at 2026-08-27 11:17:20.962721Z
# [2026.08.27 14:17:21.058] INFO    Task 'run_experiment': started at 2026-08-27 11:17:21.058235Z
# [2026.08.27 14:17:21.207] INFO    Starting near-time execution...
# [2026.08.27 14:17:21.301] INFO    Estimated RT execution time: 106.42 s.
# [2026.08.27 14:19:07.787] INFO    Finished near-time execution.
# [2026.08.27 14:19:07.850] INFO    Task 'run_experiment': ended at 2026-08-27 11:19:07.850945Z
# [2026.08.27 14:19:07.936] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:19:07.936] INFO      Workflow 'analysis_workflow': execution started at 2026-08-27
# [2026.08.27 14:19:07.938] INFO      11:19:07.920824Z
# [2026.08.27 14:19:07.940] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:19:08.016] INFO    Task 'calculate_qubit_population': started at 2026-08-27 11:19:08.016846Z
# [2026.08.27 14:19:08.108] INFO    Task 'calculate_qubit_population': ended at 2026-08-27 11:19:08.108399Z
# [2026.08.27 14:19:08.186] INFO    Task 'fit_data': started at 2026-08-27 11:19:08.186000Z
# [2026.08.27 14:19:08.321] INFO    Task 'fit_data': ended at 2026-08-27 11:19:08.321968Z
# [2026.08.27 14:19:08.435] INFO    Task 'extract_qubit_parameters': started at 2026-08-27 11:19:08.435563Z
# [2026.08.27 14:19:08.580] INFO    Task 'extract_qubit_parameters': ended at 2026-08-27 11:19:08.580112Z
# [2026.08.27 14:19:08.650] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-27 11:19:08.650184Z
# [2026.08.27 14:19:08.774] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-27 11:19:08.774339Z
# [2026.08.27 14:19:09.160] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-27 11:19:09.160225Z
# [2026.08.27 14:19:09.225] INFO    Task 'plot_population': started at 2026-08-27 11:19:09.225018Z
# [2026.08.27 14:19:09.369] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-27 11:19:09.369664Z
# [2026.08.27 14:19:09.651] INFO    Task 'plot_population': ended at 2026-08-27 11:19:09.651489Z
# [2026.08.27 14:19:09.691] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:19:09.691] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-27 11:19:09.691775Z
# [2026.08.27 14:19:09.691] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:19:09.751] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:19:09.751] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-27 11:19:09.751705Z
# [2026.08.27 14:19:09.756] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: 4.500 MHz
# [2026.08.27 14:19:09.900] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:19:09.900] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-27 11:19:09.886519Z
# [2026.08.27 14:19:09.900] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:19:10.174] INFO    Task 'temporary_qpu': started at 2026-08-27 11:19:10.174599Z
# [2026.08.27 14:19:10.210] INFO    Task 'temporary_qpu': ended at 2026-08-27 11:19:10.210560Z
# [2026.08.27 14:19:10.303] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-27
# [2026.08.27 14:19:10.303] INFO    11:19:10.303691Z
# [2026.08.27 14:19:10.353] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-27 11:19:10.353290Z
# [2026.08.27 14:19:10.466] INFO    Task 'create_experiment': started at 2026-08-27 11:19:10.464849Z
# [2026.08.27 14:19:10.607] INFO    Task 'create_experiment': ended at 2026-08-27 11:19:10.607697Z
# [2026.08.27 14:19:10.690] INFO    Task 'compile_experiment': started at 2026-08-27 11:19:10.690509Z
# [2026.08.27 14:19:10.770] INFO    Starting LabOne Q Compiler run...
# [2026.08.27 14:19:10.770] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.27 14:19:10.770] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.27 14:19:10.782] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.27 14:19:10.782] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.27 14:19:10.786] INFO    Schedule completed. [0.002 s]
# [2026.08.27 14:19:10.795] INFO    Code generation completed for all AWGs. [0.008 s]
# [2026.08.27 14:19:10.799] INFO    Completed compilation step 1 of 1. [0.015 s]
# [2026.08.27 14:19:10.802] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:19:10.802] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.27 14:19:10.802] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:19:10.802] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.27 14:19:10.802] INFO      SHFQC_DEV12192_sg     0        139           43           2       832
# [2026.08.27 14:19:10.811] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:19:10.811] INFO      TOTAL                          160           43                  8832
# [2026.08.27 14:19:10.811] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:19:10.818] INFO    Finished LabOne Q Compiler run.
# [2026.08.27 14:19:10.834] INFO    Task 'compile_experiment': ended at 2026-08-27 11:19:10.818193Z
# [2026.08.27 14:19:10.931] INFO    Task 'run_experiment': started at 2026-08-27 11:19:10.931093Z
# [2026.08.27 14:19:11.074] INFO    Starting near-time execution...
# [2026.08.27 14:19:11.162] INFO    Estimated RT execution time: 106.42 s.
# [2026.08.27 14:20:57.638] INFO    Finished near-time execution.
# [2026.08.27 14:20:57.754] INFO    Task 'run_experiment': ended at 2026-08-27 11:20:57.754478Z
# [2026.08.27 14:20:57.835] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:20:57.849] INFO      Workflow 'analysis_workflow': execution started at 2026-08-27
# [2026.08.27 14:20:57.849] INFO      11:20:57.835092Z
# [2026.08.27 14:20:57.856] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:20:57.945] INFO    Task 'calculate_qubit_population': started at 2026-08-27 11:20:57.930442Z
# [2026.08.27 14:20:58.030] INFO    Task 'calculate_qubit_population': ended at 2026-08-27 11:20:58.030417Z
# [2026.08.27 14:20:58.110] INFO    Task 'fit_data': started at 2026-08-27 11:20:58.110642Z
# [2026.08.27 14:20:58.235] INFO    Task 'fit_data': ended at 2026-08-27 11:20:58.235188Z
# [2026.08.27 14:20:58.315] INFO    Task 'extract_qubit_parameters': started at 2026-08-27 11:20:58.315602Z
# [2026.08.27 14:20:58.459] INFO    Task 'extract_qubit_parameters': ended at 2026-08-27 11:20:58.459288Z
# [2026.08.27 14:20:58.530] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-27 11:20:58.530851Z
# [2026.08.27 14:20:58.652] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-27 11:20:58.652758Z
# [2026.08.27 14:20:59.125] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-27 11:20:59.125120Z
# [2026.08.27 14:20:59.165] INFO    Task 'plot_population': started at 2026-08-27 11:20:59.165589Z
# [2026.08.27 14:20:59.305] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-27 11:20:59.305109Z
# [2026.08.27 14:20:59.711] INFO    Task 'plot_population': ended at 2026-08-27 11:20:59.711119Z
# [2026.08.27 14:20:59.759] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:20:59.759] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-27 11:20:59.759881Z
# [2026.08.27 14:20:59.759] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:20:59.807] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:20:59.807] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-27 11:20:59.807548Z
# [2026.08.27 14:20:59.807] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: 6.000 MHz
# [2026.08.27 14:20:59.954] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:20:59.954] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-27 11:20:59.954414Z
# [2026.08.27 14:20:59.964] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:21:00.225] INFO    Task 'temporary_qpu': started at 2026-08-27 11:21:00.225537Z
# [2026.08.27 14:21:00.273] INFO    Task 'temporary_qpu': ended at 2026-08-27 11:21:00.273534Z
# [2026.08.27 14:21:00.354] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-27
# [2026.08.27 14:21:00.354] INFO    11:21:00.354207Z
# [2026.08.27 14:21:00.401] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-27 11:21:00.401881Z
# [2026.08.27 14:21:00.497] INFO    Task 'create_experiment': started at 2026-08-27 11:21:00.497304Z
# [2026.08.27 14:21:00.592] INFO    Task 'create_experiment': ended at 2026-08-27 11:21:00.592720Z
# [2026.08.27 14:21:00.672] INFO    Task 'compile_experiment': started at 2026-08-27 11:21:00.672883Z
# [2026.08.27 14:21:00.770] INFO    Starting LabOne Q Compiler run...
# [2026.08.27 14:21:00.770] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.27 14:21:00.770] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.27 14:21:00.770] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.27 14:21:00.770] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.27 14:21:00.770] INFO    Schedule completed. [0.000 s]
# [2026.08.27 14:21:00.786] INFO    Code generation completed for all AWGs. [0.009 s]
# [2026.08.27 14:21:00.795] INFO    Completed compilation step 1 of 1. [0.014 s]
# [2026.08.27 14:21:00.802] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:21:00.802] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.27 14:21:00.802] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:21:00.802] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.27 14:21:00.802] INFO      SHFQC_DEV12192_sg     0        139           43           2       832
# [2026.08.27 14:21:00.811] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:21:00.811] INFO      TOTAL                          160           43                  8832
# [2026.08.27 14:21:00.811] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:21:00.830] INFO    Finished LabOne Q Compiler run.
# [2026.08.27 14:21:00.833] INFO    Task 'compile_experiment': ended at 2026-08-27 11:21:00.833176Z
# [2026.08.27 14:21:00.944] INFO    Task 'run_experiment': started at 2026-08-27 11:21:00.944505Z
# [2026.08.27 14:21:01.084] INFO    Starting near-time execution...
# [2026.08.27 14:21:01.169] INFO    Estimated RT execution time: 106.42 s.
# [2026.08.27 14:22:47.665] INFO    Finished near-time execution.
# [2026.08.27 14:22:47.798] INFO    Task 'run_experiment': ended at 2026-08-27 11:22:47.798722Z
# [2026.08.27 14:22:47.923] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:22:47.925] INFO      Workflow 'analysis_workflow': execution started at 2026-08-27
# [2026.08.27 14:22:47.925] INFO      11:22:47.922375Z
# [2026.08.27 14:22:47.926] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:22:48.036] INFO    Task 'calculate_qubit_population': started at 2026-08-27 11:22:48.036205Z
# [2026.08.27 14:22:48.123] INFO    Task 'calculate_qubit_population': ended at 2026-08-27 11:22:48.123378Z
# [2026.08.27 14:22:48.202] INFO    Task 'fit_data': started at 2026-08-27 11:22:48.202785Z
# [2026.08.27 14:22:48.323] INFO    Task 'fit_data': ended at 2026-08-27 11:22:48.323809Z
# [2026.08.27 14:22:48.405] INFO    Task 'extract_qubit_parameters': started at 2026-08-27 11:22:48.405685Z
# [2026.08.27 14:22:48.532] INFO    Task 'extract_qubit_parameters': ended at 2026-08-27 11:22:48.532881Z
# [2026.08.27 14:22:48.611] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-27 11:22:48.611135Z
# [2026.08.27 14:22:48.741] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-27 11:22:48.741597Z
# [2026.08.27 14:22:49.173] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-27 11:22:49.173379Z
# [2026.08.27 14:22:49.224] INFO    Task 'plot_population': started at 2026-08-27 11:22:49.224941Z
# [2026.08.27 14:22:49.379] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-27 11:22:49.379530Z
# [2026.08.27 14:22:49.723] INFO    Task 'plot_population': ended at 2026-08-27 11:22:49.723462Z
# [2026.08.27 14:22:49.769] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:22:49.769] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-27 11:22:49.769670Z
# [2026.08.27 14:22:49.769] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:22:49.817] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:22:49.817] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-27 11:22:49.817002Z
# [2026.08.27 14:22:49.817] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Plot Chevron Map

# %%
X = rabi_chevron_amp
Y = chevron_detunings * 1e-6
Z = np.absolute(rabi_chevron_arr)

fig, ax = plt.subplots(figsize=(8, 6))
c = ax.pcolormesh(X, Y, Z, cmap='Reds', shading='auto')
fig.colorbar(c, ax=ax, label='Signal amplitude (a.u.)')
ax.set_xlabel('Drive amplitude (a.u.)')
ax.set_ylabel('Detuning (MHz)')
ax.set_title(f'Rabi chevron, {transition}-transition')

figname = f'Rabi_chevron_{transition}_'
file_path = get_path_to_file(figname, '.png')
plt.savefig(file_path, dpi=600, format='png', metadata=None,
        bbox_inches=None, pad_inches=0.1,
        facecolor='auto', edgecolor='auto',
        backend=None,
       )

# %% [markdown]
# #### Save Data

# %%
Data_rabi_chevron = {
    'rabi_chevron': rabi_chevron_arr,
    'detunings': chevron_detunings,
    'rabi_amp': rabi_chevron_amp,
}

file_name = f'Rabi_chevron_{transition}_'
file_path = get_path_to_file(file_name, '.mat')
savemat(file_path, Data_rabi_chevron)

# %% [markdown]
# ### Rabi Frequency Calibration

# %% [markdown]
# #### Experiment Parameters

# %%
# This experiment derives a slope/intercept relation between drive-pulse length and
# the required pi-pulse amplitude. It is diagnostic/informational (used to
# extrapolate the amplitude needed for a target pulse length or Rabi frequency), so
# it does not directly overwrite `qubit_to_measure.parameters` below.
update_global_parameters = False

transition = set_transition('ge')

drive_range = 10
readout_amplitude = 0.2
n_avg_exponent = 12

amp_min = 0
amp_max = 1.0
n_amp = 101

drive_length_min = 50e-9
drive_length_max = 400e-9
n_drive_length = 36
drive_lengths = np.linspace(drive_length_min, drive_length_max, n_drive_length)

# %% [markdown]
# #### Run Workflow

# %%
options = amplitude_rabi.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(True)  # suppress per-length plots; we build one summary plot below

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

fitted_pi_amplitudes = []

for drive_length in drive_lengths:
    print(f'Measuring Rabi with drive length: {drive_length * 1e9:.1f} ns')

    temporary_parameters = {}
    temp_pars = deepcopy(qubits[0].parameters)
    temp_pars.drive_range = drive_range
    temp_pars.readout_amplitude = readout_amplitude
    if transition == 'ge':
        temp_pars.ge_drive_length = drive_length
    elif transition == 'ef':
        temp_pars.ef_drive_length = drive_length
    temporary_parameters[q.uid] = temp_pars

    exp_workflow = amplitude_rabi.experiment_workflow(
        session=session,
        qpu=qpu,
        qubits=[q.uid for q in qubits_to_measure],
        amplitudes=[np.linspace(amp_min, amp_max, n_amp) for q in qubits_to_measure],
        options=options,
        temporary_parameters=temporary_parameters
    )
    workflow_result = exp_workflow.run()

    analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
    # NOTE: adjust the key names below to match the installed library version if
    # `new_parameter_values` is not nested exactly this way.
    new_parameter_values = analysis_workflow_result.output["new_parameter_values"]
    if transition == 'ge':
        fitted_pi_amplitude = new_parameter_values[qubit_to_measure.uid]["ge_drive_amplitude_pi"]
    elif transition == 'ef':
        fitted_pi_amplitude = new_parameter_values[qubit_to_measure.uid]["ef_drive_amplitude_pi"]
    fitted_pi_amplitudes.append(fitted_pi_amplitude)

fitted_pi_amplitudes = np.array(fitted_pi_amplitudes)

# %% [markdown]
# #### Fit and Plot Amplitude vs. Drive Length

# %%
from uncertainties import unumpy as unp

x = (1 / drive_lengths).astype('float64')  # proxy for Rabi frequency scaling with drive length
y = unp.nominal_values(fitted_pi_amplitudes).astype('float64')

rabi_freq_calib_popt, rabi_freq_calib_pcov = np.polyfit(x, y, 1, cov=True)
rabi_slope, rabi_intercept = rabi_freq_calib_popt

print('Rabi amplitude-length slope:', rabi_slope)
print('Rabi amplitude-length intercept:', rabi_intercept)

fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(x * 1e-6, y, '.k')
ax.plot(x * 1e-6, np.polyval(rabi_freq_calib_popt, x), '-r')
ax.set_xlabel('1 / drive length (1/us)')
ax.set_ylabel(f'{transition} pi-pulse amplitude (a.u.)')
ax.set_title('Rabi frequency calibration')

figname = f'Rabi_freq_calib_{transition}_'
file_path = get_path_to_file(figname, '.png')
plt.savefig(file_path, dpi=600, format='png', metadata=None,
        bbox_inches=None, pad_inches=0.1,
        facecolor='auto', edgecolor='auto',
        backend=None,
       )

# %% [markdown]
# #### Save Data

# %%
Data_rabi_freq_calib = {
    'drive_lengths': drive_lengths,
    'fitted_pi_amplitudes':  unp.nominal_values(fitted_pi_amplitudes).astype('float64'),
    'rabi_slope': rabi_slope,
    'rabi_intercept': rabi_intercept,
}

file_name = f'Rabi_freq_calib_{transition}_'
file_path = get_path_to_file(file_name, '.mat')
savemat(file_path, Data_rabi_freq_calib)

# %% [markdown]
# ### Rabi Error Amplification

# %% [markdown]
# #### x180 pulse

# %% [markdown]
# ##### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ge')

n_avg_exponent = 13

x180_max_repetitions = 20
x180_repetitions = list(range(0, x180_max_repetitions + 1))

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# ##### Run Workflow

# %%
options = amplitude_fine.experiment_workflow_x180.options()
options.count(2**n_avg_exponent)
options.close_figures(False)  # Plot figures

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

exp_workflow = amplitude_fine.experiment_workflow_x180(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    repetitions=[x180_repetitions for q in qubits_to_measure],
    options=options,
    temporary_parameters=temporary_parameters
)
workflow_result = exp_workflow.run()
# Out:
# [2026.09.01 13:05:32.920] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 13:05:32.929] INFO      Workflow 'experiment_workflow_x180': execution started at 2026-09-01
# [2026.09.01 13:05:32.929] INFO      10:05:32.920029Z
# [2026.09.01 13:05:32.929] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 13:05:33.253] INFO    Task 'temporary_qpu': started at 2026-09-01 10:05:33.253035Z
# [2026.09.01 13:05:33.316] INFO    Task 'temporary_qpu': ended at 2026-09-01 10:05:33.314917Z
# [2026.09.01 13:05:33.411] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-09-01
# [2026.09.01 13:05:33.411] INFO    10:05:33.411551Z
# [2026.09.01 13:05:33.460] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-09-01 10:05:33.460614Z
# [2026.09.01 13:05:33.573] INFO    Task 'create_experiment': started at 2026-09-01 10:05:33.573499Z
# [2026.09.01 13:05:33.719] INFO    Task 'create_experiment': ended at 2026-09-01 10:05:33.719540Z
# [2026.09.01 13:05:33.857] INFO    Task 'compile_experiment': started at 2026-09-01 10:05:33.857058Z
# [2026.09.01 13:05:33.957] INFO    Starting LabOne Q Compiler run...
# [2026.09.01 13:05:33.963] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.09.01 13:05:33.963] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.09.01 13:05:33.965] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.09.01 13:05:33.965] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.09.01 13:05:33.965] INFO    Schedule completed. [0.003 s]
# [2026.09.01 13:05:34.006] INFO    Code generation completed for all AWGs. [0.038 s]
# [2026.09.01 13:05:34.006] INFO    Completed compilation step 1 of 1. [0.045 s]
# [2026.09.01 13:05:34.006] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.09.01 13:05:34.006] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.09.01 13:05:34.022] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.09.01 13:05:34.022] INFO      SHFQC_DEV12192        0         95            0           1      7616
# [2026.09.01 13:05:34.022] INFO      SHFQC_DEV12192_sg     0        129           19          17    148896
# [2026.09.01 13:05:34.022] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.09.01 13:05:34.022] INFO      TOTAL                          224           19                156512
# [2026.09.01 13:05:34.022] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.09.01 13:05:34.038] INFO    Finished LabOne Q Compiler run.
# [2026.09.01 13:05:34.051] INFO    Task 'compile_experiment': ended at 2026-09-01 10:05:34.038714Z
# [2026.09.01 13:05:34.230] INFO    Task 'run_experiment': started at 2026-09-01 10:05:34.230674Z
# [2026.09.01 13:05:34.421] INFO    Starting near-time execution...
# [2026.09.01 13:05:34.500] INFO    Estimated RT execution time: 57.35 s.
# [2026.09.01 13:06:31.901] INFO    Finished near-time execution.
# [2026.09.01 13:06:36.905] INFO    Task 'run_experiment': ended at 2026-09-01 10:06:36.905576Z
# [2026.09.01 13:06:37.038] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 13:06:37.038] INFO      Workflow 'analysis_workflow': execution started at 2026-09-01
# [2026.09.01 13:06:37.038] INFO      10:06:37.038139Z
# [2026.09.01 13:06:37.038] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 13:06:37.210] INFO    Task 'calculate_qubit_population': started at 2026-09-01 10:06:37.210616Z
# [2026.09.01 13:06:37.307] INFO    Task 'calculate_qubit_population': ended at 2026-09-01 10:06:37.307648Z
# [2026.09.01 13:06:37.387] INFO    Task 'fit_data': started at 2026-09-01 10:06:37.387866Z
# [2026.09.01 13:06:37.500] INFO    Task 'fit_data': ended at 2026-09-01 10:06:37.500246Z
# [2026.09.01 13:06:37.581] INFO    Task 'process_fit_results': started at 2026-09-01 10:06:37.565308Z
# [2026.09.01 13:06:37.694] INFO    Task 'process_fit_results': ended at 2026-09-01 10:06:37.694210Z
# [2026.09.01 13:06:37.757] INFO    Task 'extract_qubit_parameters': started at 2026-09-01 10:06:37.757526Z
# [2026.09.01 13:06:37.853] INFO    Task 'extract_qubit_parameters': ended at 2026-09-01 10:06:37.853607Z
# [2026.09.01 13:06:37.939] INFO    Task 'xaxis_label': started at 2026-09-01 10:06:37.939204Z
# [2026.09.01 13:06:37.966] INFO    Task 'xaxis_label': ended at 2026-09-01 10:06:37.966611Z
# [2026.09.01 13:06:38.002] INFO    Task 'plot_raw_complex_data_1d': started at 2026-09-01 10:06:38.002228Z
# [2026.09.01 13:06:38.110] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-09-01 10:06:38.110719Z
# [2026.09.01 13:06:38.672] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-09-01 10:06:38.672139Z
# [2026.09.01 13:06:38.702] INFO    Task 'plot_population': started at 2026-09-01 10:06:38.702661Z
# [2026.09.01 13:06:38.818] INFO    Artifact: 'Amplitude_Fine_Q2' of type 'Figure' logged at 2026-09-01
# [2026.09.01 13:06:38.824] INFO    10:06:38.818238Z
# [2026.09.01 13:06:39.163] INFO    Task 'plot_population': ended at 2026-09-01 10:06:39.163679Z
# [2026.09.01 13:06:39.204] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 13:06:39.208] INFO      Workflow 'analysis_workflow': execution ended at 2026-09-01 10:06:39.204776Z
# [2026.09.01 13:06:39.210] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 13:06:39.252] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 13:06:39.252] INFO      Workflow 'experiment_workflow_x180': execution ended at 2026-09-01
# [2026.09.01 13:06:39.252] INFO      10:06:39.252518Z
# [2026.09.01 13:06:39.252] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ##### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)
    
    amplitude_fine.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nDrive amplitude pi ge (error-amplified): ", qubit_to_measure.parameters.ge_drive_amplitude_pi)
    elif transition == 'ef':
        print("\nDrive amplitude pi ef (error-amplified): ", qubit_to_measure.parameters.ef_drive_amplitude_pi)
        
    print('\nUpdated global experiment parameters!\n')
# Out:
# {'new_parameter_values': {'Q2': {'ge_drive_amplitude_pi': 0.14880729338309864+/-0.008655644508361962}},
#  'old_parameter_values': {'Q2': {'ge_drive_amplitude_pi': 0.1450703458642064}}}
#
# Drive amplitude pi ge (error-amplified):  0.14880729338309864
#
# Updated global experiment parameters!

# %% [markdown]
# #### x90 pulse

# %% [markdown]
# ##### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ge')

n_avg_exponent = 13

x90_max_repetitions = 40
x90_repetitions = list(range(1, x90_max_repetitions + 1, 2))

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# ##### Run Workflow

# %%
options = amplitude_fine.experiment_workflow_x90.options()
options.count(2**n_avg_exponent)
options.close_figures(False)  # Plot figures

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

exp_workflow = amplitude_fine.experiment_workflow_x90(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    repetitions=[x90_repetitions for q in qubits_to_measure],
    options=options,
    temporary_parameters=temporary_parameters
)
workflow_result = exp_workflow.run()
# Out:
# [2026.09.01 13:06:40.478] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 13:06:40.478] INFO      Workflow 'experiment_workflow_x90': execution started at 2026-09-01
# [2026.09.01 13:06:40.478] INFO      10:06:40.478894Z
# [2026.09.01 13:06:40.478] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 13:06:40.841] INFO    Task 'temporary_qpu': started at 2026-09-01 10:06:40.841496Z
# [2026.09.01 13:06:40.919] INFO    Task 'temporary_qpu': ended at 2026-09-01 10:06:40.919962Z
# [2026.09.01 13:06:41.043] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-09-01
# [2026.09.01 13:06:41.044] INFO    10:06:41.043436Z
# [2026.09.01 13:06:41.088] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-09-01 10:06:41.087082Z
# [2026.09.01 13:06:41.197] INFO    Task 'create_experiment': started at 2026-09-01 10:06:41.196266Z
# [2026.09.01 13:06:41.451] INFO    Task 'create_experiment': ended at 2026-09-01 10:06:41.451584Z
# [2026.09.01 13:06:41.598] INFO    Task 'compile_experiment': started at 2026-09-01 10:06:41.597229Z
# [2026.09.01 13:06:41.726] INFO    Starting LabOne Q Compiler run...
# [2026.09.01 13:06:41.732] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.09.01 13:06:41.732] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.09.01 13:06:41.734] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.09.01 13:06:41.736] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.09.01 13:06:41.737] INFO    Schedule completed. [0.001 s]
# [2026.09.01 13:06:41.759] INFO    Code generation completed for all AWGs. [0.019 s]
# [2026.09.01 13:06:41.762] INFO    Completed compilation step 1 of 1. [0.025 s]
# [2026.09.01 13:06:41.763] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.09.01 13:06:41.763] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.09.01 13:06:41.763] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.09.01 13:06:41.773] INFO      SHFQC_DEV12192        0         91            0           1      7616
# [2026.09.01 13:06:41.773] INFO      SHFQC_DEV12192_sg     0        113           10           9     71520
# [2026.09.01 13:06:41.777] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.09.01 13:06:41.777] INFO      TOTAL                          204           10                 79136
# [2026.09.01 13:06:41.777] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.09.01 13:06:41.789] INFO    Finished LabOne Q Compiler run.
# [2026.09.01 13:06:41.789] INFO    Task 'compile_experiment': ended at 2026-09-01 10:06:41.789553Z
# [2026.09.01 13:06:41.980] INFO    Task 'run_experiment': started at 2026-09-01 10:06:41.979377Z
# [2026.09.01 13:06:42.147] INFO    Starting near-time execution...
# [2026.09.01 13:06:42.226] INFO    Estimated RT execution time: 55.25 s.
# [2026.09.01 13:07:37.550] INFO    Finished near-time execution.
# [2026.09.01 13:07:42.602] INFO    Task 'run_experiment': ended at 2026-09-01 10:07:42.602448Z
# [2026.09.01 13:07:42.713] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 13:07:42.715] INFO      Workflow 'analysis_workflow': execution started at 2026-09-01
# [2026.09.01 13:07:42.715] INFO      10:07:42.713652Z
# [2026.09.01 13:07:42.719] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 13:07:42.840] INFO    Task 'calculate_qubit_population': started at 2026-09-01 10:07:42.840691Z
# [2026.09.01 13:07:42.938] INFO    Task 'calculate_qubit_population': ended at 2026-09-01 10:07:42.938099Z
# [2026.09.01 13:07:43.049] INFO    Task 'fit_data': started at 2026-09-01 10:07:43.049416Z
# [2026.09.01 13:07:43.147] INFO    Task 'fit_data': ended at 2026-09-01 10:07:43.147196Z
# [2026.09.01 13:07:43.225] INFO    Task 'process_fit_results': started at 2026-09-01 10:07:43.225226Z
# [2026.09.01 13:07:43.332] INFO    Task 'process_fit_results': ended at 2026-09-01 10:07:43.330402Z
# [2026.09.01 13:07:43.387] INFO    Task 'extract_qubit_parameters': started at 2026-09-01 10:07:43.387238Z
# [2026.09.01 13:07:43.485] INFO    Task 'extract_qubit_parameters': ended at 2026-09-01 10:07:43.485075Z
# [2026.09.01 13:07:43.579] INFO    Task 'xaxis_label': started at 2026-09-01 10:07:43.579533Z
# [2026.09.01 13:07:43.628] INFO    Task 'xaxis_label': ended at 2026-09-01 10:07:43.612241Z
# [2026.09.01 13:07:43.660] INFO    Task 'plot_raw_complex_data_1d': started at 2026-09-01 10:07:43.660254Z
# [2026.09.01 13:07:43.755] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-09-01 10:07:43.755972Z
# [2026.09.01 13:07:44.405] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-09-01 10:07:44.405848Z
# [2026.09.01 13:07:44.456] INFO    Task 'plot_population': started at 2026-09-01 10:07:44.456145Z
# [2026.09.01 13:07:44.610] INFO    Artifact: 'Amplitude_Fine_Q2' of type 'Figure' logged at 2026-09-01
# [2026.09.01 13:07:44.610] INFO    10:07:44.609422Z
# [2026.09.01 13:07:44.914] INFO    Task 'plot_population': ended at 2026-09-01 10:07:44.914747Z
# [2026.09.01 13:07:44.947] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 13:07:44.947] INFO      Workflow 'analysis_workflow': execution ended at 2026-09-01 10:07:44.947255Z
# [2026.09.01 13:07:44.947] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 13:07:44.994] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 13:07:44.994] INFO      Workflow 'experiment_workflow_x90': execution ended at 2026-09-01
# [2026.09.01 13:07:44.994] INFO      10:07:44.992337Z
# [2026.09.01 13:07:44.994] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ##### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)

    amplitude_fine.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nDrive amplitude pi2 ge (error-amplified): ", qubit_to_measure.parameters.ge_drive_amplitude_pi2)
    elif transition == 'ef':
        print("\nDrive amplitude pi2 ef (error-amplified): ", qubit_to_measure.parameters.ef_drive_amplitude_pi2)
    
    print('\nUpdated global experiment parameters!\n')
# Out:
# {'new_parameter_values': {'Q2': {'ge_drive_amplitude_pi2': 0.0038312010088328015+/-0.00010205082667890313}},
#  'old_parameter_values': {'Q2': {'ge_drive_amplitude_pi2': 0.07343142790133057}}}
#
# Drive amplitude pi2 ge (error-amplified):  0.0038312010088328015
#
# Updated global experiment parameters!

# %% [markdown]
# ### Ramsey

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

detuning = 0.5e6
transition = set_transition('ge')

n_avg_exponent = 13

delay_min = 0
delay_max = 20e-6
n_delay = 401

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = ramsey.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(False) # Plot figures

options.transition(transition)
options.cal_states(transition)

# Note: if neighbouring qubits are physically coupled by a resonator,
# you usually don't want to run Ramsey in parallel on them because
# your result will be skewed by strong residual-ZZ coupling.
# Next-nearest neighbours is typically okay.
# qubits_to_measure = [qubits[0], qubits[2]]
qubits_to_measure = [qubits[0]]

delays = [
    np.linspace(delay_min, delay_max, n_delay)
]
detunings = [
    detuning
]

exp_workflow = ramsey.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    delays=delays,
    detunings=detunings,
    options=options,
    temporary_parameters=temporary_parameters
)
workflow_result = exp_workflow.run()
# Out:
# [2026.09.01 14:16:51.759] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 14:16:51.759] INFO      Workflow 'ramsey': execution started at 2026-09-01 11:16:51.759800Z
# [2026.09.01 14:16:51.759] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 14:16:52.078] INFO    Task 'temporary_qpu': started at 2026-09-01 11:16:52.078401Z
# [2026.09.01 14:16:52.096] INFO    Task 'temporary_qpu': ended at 2026-09-01 11:16:52.096599Z
# [2026.09.01 14:16:52.197] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-09-01
# [2026.09.01 14:16:52.199] INFO    11:16:52.197403Z
# [2026.09.01 14:16:52.224] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-09-01 11:16:52.224705Z
# [2026.09.01 14:16:52.323] INFO    Task 'create_experiment': started at 2026-09-01 11:16:52.323303Z
# [2026.09.01 14:16:52.419] INFO    Task 'create_experiment': ended at 2026-09-01 11:16:52.419420Z
# [2026.09.01 14:16:52.481] INFO    Task 'compile_experiment': started at 2026-09-01 11:16:52.481049Z
# [2026.09.01 14:16:52.546] INFO    Starting LabOne Q Compiler run...
# [2026.09.01 14:16:52.546] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.09.01 14:16:52.554] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.09.01 14:16:52.554] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.09.01 14:16:52.554] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.09.01 14:16:52.562] INFO    Schedule completed. [0.008 s]
# [2026.09.01 14:16:52.595] INFO    Code generation completed for all AWGs. [0.037 s]
# [2026.09.01 14:16:52.609] INFO    Completed compilation step 1 of 1. [0.049 s]
# [2026.09.01 14:16:52.611] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.09.01 14:16:52.611] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.09.01 14:16:52.611] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.09.01 14:16:52.611] INFO      SHFQC_DEV12192        0       1615            0           1      7616
# [2026.09.01 14:16:52.611] INFO      SHFQC_DEV12192_sg     0       2028           47           5      2496
# [2026.09.01 14:16:52.611] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.09.01 14:16:52.611] INFO      TOTAL                         3643           47                 10112
# [2026.09.01 14:16:52.611] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.09.01 14:16:52.771] INFO    Finished LabOne Q Compiler run.
# [2026.09.01 14:16:52.771] INFO    Task 'compile_experiment': ended at 2026-09-01 11:16:52.771361Z
# [2026.09.01 14:16:52.883] INFO    Task 'run_experiment': started at 2026-09-01 11:16:52.883188Z
# [2026.09.01 14:16:53.011] INFO    Starting near-time execution...
# [2026.09.01 14:16:53.107] INFO    Estimated RT execution time: 1030.22 s.
# [2026.09.01 14:34:03.374] INFO    Finished near-time execution.
# [2026.09.01 14:34:08.415] INFO    Task 'run_experiment': ended at 2026-09-01 11:34:08.415086Z
# [2026.09.01 14:34:08.560] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 14:34:08.560] INFO      Workflow 'analysis_workflow': execution started at 2026-09-01
# [2026.09.01 14:34:08.560] INFO      11:34:08.560722Z
# [2026.09.01 14:34:08.560] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 14:34:08.688] INFO    Task 'calculate_qubit_population': started at 2026-09-01 11:34:08.688342Z
# [2026.09.01 14:34:08.847] INFO    Task 'calculate_qubit_population': ended at 2026-09-01 11:34:08.847586Z
# [2026.09.01 14:34:08.975] INFO    Task 'fit_data': started at 2026-09-01 11:34:08.975980Z
# [2026.09.01 14:34:09.154] INFO    Task 'fit_data': ended at 2026-09-01 11:34:09.154296Z
# [2026.09.01 14:34:09.282] INFO    Task 'extract_qubit_parameters': started at 2026-09-01 11:34:09.274564Z
# [2026.09.01 14:34:09.491] INFO    Task 'extract_qubit_parameters': ended at 2026-09-01 11:34:09.491011Z
# [2026.09.01 14:34:09.587] INFO    Task 'plot_raw_complex_data_1d': started at 2026-09-01 11:34:09.587131Z
# [2026.09.01 14:34:09.780] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-09-01 11:34:09.780108Z
# [2026.09.01 14:34:10.164] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-09-01 11:34:10.164566Z
# [2026.09.01 14:34:10.212] INFO    Task 'plot_population': started at 2026-09-01 11:34:10.212253Z
# [2026.09.01 14:34:10.405] INFO    Artifact: 'Ramsey_Q2' of type 'Figure' logged at 2026-09-01 11:34:10.405912Z
# [2026.09.01 14:34:10.858] INFO    Task 'plot_population': ended at 2026-09-01 11:34:10.858877Z
# [2026.09.01 14:34:10.922] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 14:34:10.922] INFO      Workflow 'analysis_workflow': execution ended at 2026-09-01 11:34:10.922077Z
# [2026.09.01 14:34:10.922] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 14:34:10.978] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 14:34:10.978] INFO      Workflow 'ramsey': execution ended at 2026-09-01 11:34:10.978259Z
# [2026.09.01 14:34:10.984] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)

    ramsey.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nge_T2_star: ", qubit_to_measure.parameters.ge_T2_star)
        print("resonance_frequency_ge: ", qubit_to_measure.parameters.resonance_frequency_ge)
    elif transition == 'ef':
        print("\nef_T2_star: ", qubit_to_measure.parameters.ef_T2_star)
        print("resonance_frequency_ef: ", qubit_to_measure.parameters.resonance_frequency_ef)
    
    print('\nUpdated global experiment parameters!\n')
# Out:
# {'new_parameter_values': {'Q2': {'ge_T2_star': 3.896923872925839e-06+/-1.2300944469069717e-07,
#                                  'resonance_frequency_ge': 4988698990.469763+/-1810.1946712154522}},
#  'old_parameter_values': {'Q2': {'ge_T2_star': 2.9402507472076067e-05,
#                                  'resonance_frequency_ge': 4995763781.449274}}}
#
# ge_T2_star:  3.896923872925839e-06
# resonance_frequency_ge:  4988698990.469763
#
# Updated global experiment parameters!

# %% [markdown]
# ### T1 Lifetime

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ge')

n_avg_exponent = 13

delay_min = 0
delay_max = 60e-6
n_delay = 51
log_spacing = True

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = lifetime_measurement.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(False) # Plot figures

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

if log_spacing:
    delays = [log_sweep_help(delay_min, delay_max, n_delay)]
else:
    delays = [np.linspace(delay_min, delay_max, n_delay)]

exp_workflow = lifetime_measurement.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    delays=delays,
    options=options,
    temporary_parameters=temporary_parameters 
)
workflow_result = exp_workflow.run()
# Out:
# [2026.09.01 13:03:07.040] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 13:03:07.040] INFO      Workflow 'lifetime_measurement': execution started at 2026-09-01
# [2026.09.01 13:03:07.040] INFO      10:03:07.040682Z
# [2026.09.01 13:03:07.056] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 13:03:07.443] INFO    Task 'temporary_qpu': started at 2026-09-01 10:03:07.443947Z
# [2026.09.01 13:03:07.491] INFO    Task 'temporary_qpu': ended at 2026-09-01 10:03:07.491604Z
# [2026.09.01 13:03:07.588] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-09-01
# [2026.09.01 13:03:07.604] INFO    10:03:07.588671Z
# [2026.09.01 13:03:07.653] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-09-01 10:03:07.653630Z
# [2026.09.01 13:03:07.751] INFO    Task 'create_experiment': started at 2026-09-01 10:03:07.751320Z
# [2026.09.01 13:03:07.911] INFO    Task 'create_experiment': ended at 2026-09-01 10:03:07.911341Z
# [2026.09.01 13:03:08.023] INFO    Task 'compile_experiment': started at 2026-09-01 10:03:08.023348Z
# [2026.09.01 13:03:08.145] INFO    Starting LabOne Q Compiler run...
# [2026.09.01 13:03:08.149] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.09.01 13:03:08.149] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.09.01 13:03:08.151] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.09.01 13:03:08.151] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.09.01 13:03:08.153] INFO    Schedule completed. [0.001 s]
# [2026.09.01 13:03:08.162] INFO    Code generation completed for all AWGs. [0.007 s]
# [2026.09.01 13:03:08.164] INFO    Completed compilation step 1 of 1. [0.012 s]
# [2026.09.01 13:03:08.171] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.09.01 13:03:08.173] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.09.01 13:03:08.173] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.09.01 13:03:08.173] INFO      SHFQC_DEV12192        0        215            0           1      7616
# [2026.09.01 13:03:08.176] INFO      SHFQC_DEV12192_sg     0        206           15          14     14144
# [2026.09.01 13:03:08.176] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.09.01 13:03:08.178] INFO      TOTAL                          421           15                 21760
# [2026.09.01 13:03:08.179] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.09.01 13:03:08.193] INFO    Finished LabOne Q Compiler run.
# [2026.09.01 13:03:08.196] INFO    Task 'compile_experiment': ended at 2026-09-01 10:03:08.196058Z
# [2026.09.01 13:03:08.343] INFO    Task 'run_experiment': started at 2026-09-01 10:03:08.343260Z
# [2026.09.01 13:03:08.526] INFO    Starting near-time execution...
# [2026.09.01 13:03:08.606] INFO    Estimated RT execution time: 135.29 s.
# [2026.09.01 13:05:23.964] INFO    Finished near-time execution.
# [2026.09.01 13:05:28.970] INFO    Task 'run_experiment': ended at 2026-09-01 10:05:28.970688Z
# [2026.09.01 13:05:29.085] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 13:05:29.099] INFO      Workflow 'analysis_workflow': execution started at 2026-09-01
# [2026.09.01 13:05:29.099] INFO      10:05:29.085274Z
# [2026.09.01 13:05:29.099] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 13:05:29.218] INFO    Task 'calculate_qubit_population': started at 2026-09-01 10:05:29.218890Z
# [2026.09.01 13:05:29.325] INFO    Task 'calculate_qubit_population': ended at 2026-09-01 10:05:29.325296Z
# [2026.09.01 13:05:29.453] INFO    Task 'fit_data': started at 2026-09-01 10:05:29.453811Z
# [2026.09.01 13:05:29.615] INFO    Task 'fit_data': ended at 2026-09-01 10:05:29.615900Z
# [2026.09.01 13:05:29.744] INFO    Task 'extract_qubit_parameters': started at 2026-09-01 10:05:29.744383Z
# [2026.09.01 13:05:29.919] INFO    Task 'extract_qubit_parameters': ended at 2026-09-01 10:05:29.919605Z
# [2026.09.01 13:05:30.031] INFO    Task 'plot_raw_complex_data_1d': started at 2026-09-01 10:05:30.031922Z
# [2026.09.01 13:05:30.193] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-09-01 10:05:30.193305Z
# [2026.09.01 13:05:30.724] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-09-01 10:05:30.724764Z
# [2026.09.01 13:05:30.787] INFO    Task 'plot_population': started at 2026-09-01 10:05:30.787760Z
# [2026.09.01 13:05:30.983] INFO    Artifact: 'T1_Q2' of type 'Figure' logged at 2026-09-01 10:05:30.983362Z
# [2026.09.01 13:05:31.401] INFO    Task 'plot_population': ended at 2026-09-01 10:05:31.401163Z
# [2026.09.01 13:05:31.463] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 13:05:31.463] INFO      Workflow 'analysis_workflow': execution ended at 2026-09-01 10:05:31.463121Z
# [2026.09.01 13:05:31.463] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 13:05:31.528] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.09.01 13:05:31.543] INFO      Workflow 'lifetime_measurement': execution ended at 2026-09-01
# [2026.09.01 13:05:31.543] INFO      10:05:31.528280Z
# [2026.09.01 13:05:31.543] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)

    lifetime_measurement.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nge_T1: ", qubit_to_measure.parameters.ge_T1)
    elif transition == 'ef':
        print("\nef_T1: ", qubit_to_measure.parameters.ef_T1)
    
    print('\nUpdated global experiment parameters!\n')
# Out:
# {'new_parameter_values': {'Q2': {'ge_T1': -7.585504722277174e-05+/-5.0876170950345736e-05}},
#  'old_parameter_values': {'Q2': {'ge_T1': 1.3645176509647932e-05}}}
#
# ge_T1:  -7.585504722277174e-05
#
# Updated global experiment parameters!

# %%
qubits[0].parameters.reset_delay_length = 300e-6
# qubits[0].parameters.readout_range_out = -30

# %% [markdown]
# ### DRAG Calibration

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ge')

n_avg_exponent = 13

q_min = -0.1
q_max = 0.1
n_q = 51

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = drag_q_scaling.experiment_workflow.options()
# options.update(True)  # updates the qubit parameter 'ge_drive_pulse["beta"]'
options.count(2**n_avg_exponent)
options.close_figures(False) # Plot figures

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

exp_workflow = drag_q_scaling.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    q_scalings=[np.linspace(q_min, q_max, n_q) for _ in qubits_to_measure],
    options=options,
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.27 14:25:45.206] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:25:45.206] INFO      Workflow 'drag_q_scaling': execution started at 2026-08-27 11:25:45.206025Z
# [2026.08.27 14:25:45.217] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:25:45.389] INFO    Task 'temporary_qpu': started at 2026-08-27 11:25:45.389523Z
# [2026.08.27 14:25:45.416] INFO    Task 'temporary_qpu': ended at 2026-08-27 11:25:45.416477Z
# [2026.08.27 14:25:45.500] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-27
# [2026.08.27 14:25:45.500] INFO    11:25:45.500437Z
# [2026.08.27 14:25:45.546] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-27 11:25:45.546091Z
# [2026.08.27 14:25:45.626] INFO    Task 'create_experiment': started at 2026-08-27 11:25:45.626587Z
# [2026.08.27 14:25:45.739] INFO    Task 'create_experiment': ended at 2026-08-27 11:25:45.739545Z
# [2026.08.27 14:25:45.818] INFO    Task 'compile_experiment': started at 2026-08-27 11:25:45.818146Z
# [2026.08.27 14:25:45.884] INFO    Starting LabOne Q Compiler run...
# [2026.08.27 14:25:45.884] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.27 14:25:45.899] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.27 14:25:45.900] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.27 14:25:45.900] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.27 14:25:45.906] INFO    Schedule completed. [0.003 s]
# [2026.08.27 14:25:45.963] INFO    Code generation completed for all AWGs. [0.057 s]
# [2026.08.27 14:25:45.966] INFO    Completed compilation step 1 of 1. [0.063 s]
# [2026.08.27 14:25:45.971] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:25:45.971] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.27 14:25:45.971] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:25:45.971] INFO      SHFQC_DEV12192        0         31            0           1      8000
# [2026.08.27 14:25:45.971] INFO      SHFQC_DEV12192_sg     0        931          155         154    122816
# [2026.08.27 14:25:45.971] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:25:45.971] INFO      TOTAL                          962          155                130816
# [2026.08.27 14:25:45.971] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:25:46.011] INFO    Finished LabOne Q Compiler run.
# [2026.08.27 14:25:46.011] INFO    Task 'compile_experiment': ended at 2026-08-27 11:25:46.011269Z
# [2026.08.27 14:25:46.171] INFO    Task 'run_experiment': started at 2026-08-27 11:25:46.171370Z
# [2026.08.27 14:25:46.297] INFO    Starting near-time execution...
# [2026.08.27 14:25:46.436] INFO    Estimated RT execution time: 383.72 s.
# [2026.08.27 14:32:10.225] INFO    Finished near-time execution.
# [2026.08.27 14:32:10.345] INFO    Task 'run_experiment': ended at 2026-08-27 11:32:10.345839Z
# [2026.08.27 14:32:10.435] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:32:10.435] INFO      Workflow 'analysis_workflow': execution started at 2026-08-27
# [2026.08.27 14:32:10.435] INFO      11:32:10.425639Z
# [2026.08.27 14:32:10.437] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:32:10.510] INFO    Task 'calculate_qubit_population_for_pulse_ids': started at 2026-08-27
# [2026.08.27 14:32:10.510] INFO    11:32:10.510594Z
# [2026.08.27 14:32:10.566] INFO    Task 'calculate_qubit_population_for_pulse_ids': ended at 2026-08-27
# [2026.08.27 14:32:10.566] INFO    11:32:10.566223Z
# [2026.08.27 14:32:10.630] INFO    Task 'fit_data': started at 2026-08-27 11:32:10.630599Z
# [2026.08.27 14:32:10.711] INFO    Task 'fit_data': ended at 2026-08-27 11:32:10.711323Z
# [2026.08.27 14:32:10.758] INFO    Task 'extract_qubit_parameters': started at 2026-08-27 11:32:10.758453Z
# [2026.08.27 14:32:10.842] INFO    Task 'extract_qubit_parameters': ended at 2026-08-27 11:32:10.842144Z
# [2026.08.27 14:32:10.902] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-27 11:32:10.902295Z
# [2026.08.27 14:32:10.999] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-27 11:32:10.999110Z
# [2026.08.27 14:32:11.529] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-27 11:32:11.529405Z
# [2026.08.27 14:32:11.545] INFO    Task 'plot_population': started at 2026-08-27 11:32:11.545091Z
# [2026.08.27 14:32:11.660] INFO    Artifact: 'Drag_q_scaling_Q2' of type 'Figure' logged at 2026-08-27
# [2026.08.27 14:32:11.660] INFO    11:32:11.660779Z
# [2026.08.27 14:32:12.061] INFO    Task 'plot_population': ended at 2026-08-27 11:32:12.061805Z
# [2026.08.27 14:32:12.075] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:32:12.075] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-27 11:32:12.075305Z
# [2026.08.27 14:32:12.091] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:32:12.107] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:32:12.122] INFO      Workflow 'drag_q_scaling': execution ended at 2026-08-27 11:32:12.107029Z
# [2026.08.27 14:32:12.125] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])

    drag_q_scaling.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nge_drive_pulse[beta]: ", qubit_to_measure.parameters.ge_drive_pulse["beta"])
    elif transition == 'ef':
        print("\nef_drive_pulse[beta]: ", qubit_to_measure.parameters.ef_drive_pulse["beta"])
    
    print('\nUpdated global experiment parameters!\n')
# Out:
# {'new_parameter_values': {'Q2': {'ge_drive_pulse.beta': 0.2413462769901743+/-0.03307349726580956}},
#  'old_parameter_values': {'Q2': {'ge_drive_pulse.beta': 0}}}
#
# ge_drive_pulse[beta]:  0.2413462769901743
#
# Updated global experiment parameters!

# %% [markdown]
# ### Hahn-Echo

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ge')

n_avg_exponent = 13

delay_min = 0
delay_max = 30e-6
n_delay = 71
log_spacing = True

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = echo.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(False)

options.transition(transition)
options.cal_states(transition)

# Note: if neighbouring qubits are physically coupled by a resonator,
# you usually don't want to run Echo in parallel on them because
# your result will be skewed by strong residual-ZZ coupling.
# Next-nearest neighbours is typically okay.
qubits_to_measure = [qubits[0]]

delays = [
    np.linspace(delay_min, delay_max, n_delay)
]

exp_workflow = echo.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    delays=delays,
    options=options,
    temporary_parameters=temporary_parameters
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.27 14:32:13.150] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:32:13.152] INFO      Workflow 'echo': execution started at 2026-08-27 11:32:13.150919Z
# [2026.08.27 14:32:13.152] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:32:13.396] INFO    Task 'temporary_qpu': started at 2026-08-27 11:32:13.396858Z
# [2026.08.27 14:32:13.448] INFO    Task 'temporary_qpu': ended at 2026-08-27 11:32:13.442162Z
# [2026.08.27 14:32:13.537] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-27
# [2026.08.27 14:32:13.539] INFO    11:32:13.537870Z
# [2026.08.27 14:32:13.578] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-27 11:32:13.578668Z
# [2026.08.27 14:32:13.666] INFO    Task 'create_experiment': started at 2026-08-27 11:32:13.666915Z
# [2026.08.27 14:32:13.777] INFO    Task 'create_experiment': ended at 2026-08-27 11:32:13.777017Z
# [2026.08.27 14:32:13.840] INFO    Task 'compile_experiment': started at 2026-08-27 11:32:13.840814Z
# [2026.08.27 14:32:13.947] INFO    Starting LabOne Q Compiler run...
# [2026.08.27 14:32:13.947] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.27 14:32:13.947] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.27 14:32:13.953] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.27 14:32:13.954] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.27 14:32:13.954] INFO    Schedule completed. [0.001 s]
# [2026.08.27 14:32:13.972] INFO    Code generation completed for all AWGs. [0.014 s]
# [2026.08.27 14:32:13.972] INFO    Completed compilation step 1 of 1. [0.019 s]
# [2026.08.27 14:32:13.972] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:32:13.986] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.27 14:32:13.986] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:32:13.986] INFO      SHFQC_DEV12192        0        295            0           1      8000
# [2026.08.27 14:32:13.986] INFO      SHFQC_DEV12192_sg     0        570           24          22      9824
# [2026.08.27 14:32:13.986] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:32:13.997] INFO      TOTAL                          865           24                 17824
# [2026.08.27 14:32:14.000] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.27 14:32:14.037] INFO    Finished LabOne Q Compiler run.
# [2026.08.27 14:32:14.037] INFO    Task 'compile_experiment': ended at 2026-08-27 11:32:14.037720Z
# [2026.08.27 14:32:14.165] INFO    Task 'run_experiment': started at 2026-08-27 11:32:14.164530Z
# [2026.08.27 14:32:14.324] INFO    Starting near-time execution...
# [2026.08.27 14:32:14.407] INFO    Estimated RT execution time: 189.50 s.
# [2026.08.27 14:35:23.983] INFO    Finished near-time execution.
# [2026.08.27 14:35:24.061] INFO    Task 'run_experiment': ended at 2026-08-27 11:35:24.061987Z
# [2026.08.27 14:35:24.199] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:35:24.205] INFO      Workflow 'analysis_workflow': execution started at 2026-08-27
# [2026.08.27 14:35:24.206] INFO      11:35:24.199721Z
# [2026.08.27 14:35:24.207] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:35:24.299] INFO    Task 'calculate_qubit_population': started at 2026-08-27 11:35:24.299777Z
# [2026.08.27 14:35:24.395] INFO    Task 'calculate_qubit_population': ended at 2026-08-27 11:35:24.390570Z
# [2026.08.27 14:35:24.478] INFO    Task 'fit_data': started at 2026-08-27 11:35:24.478974Z
# [2026.08.27 14:35:24.591] INFO    Task 'fit_data': ended at 2026-08-27 11:35:24.591449Z
# [2026.08.27 14:35:24.692] INFO    Task 'extract_qubit_parameters': started at 2026-08-27 11:35:24.692053Z
# [2026.08.27 14:35:24.816] INFO    Task 'extract_qubit_parameters': ended at 2026-08-27 11:35:24.816970Z
# [2026.08.27 14:35:24.899] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-27 11:35:24.899013Z
# [2026.08.27 14:35:25.040] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-27 11:35:25.040755Z
# [2026.08.27 14:35:25.542] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-27 11:35:25.542231Z
# [2026.08.27 14:35:25.573] INFO    Task 'plot_population': started at 2026-08-27 11:35:25.573445Z
# [2026.08.27 14:35:25.742] INFO    Artifact: 'T2_Q2' of type 'Figure' logged at 2026-08-27 11:35:25.737829Z
# [2026.08.27 14:35:26.070] INFO    Task 'plot_population': ended at 2026-08-27 11:35:26.070429Z
# [2026.08.27 14:35:26.137] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:35:26.137] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-27 11:35:26.135296Z
# [2026.08.27 14:35:26.137] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:35:26.194] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.27 14:35:26.195] INFO      Workflow 'echo': execution ended at 2026-08-27 11:35:26.190289Z
# [2026.08.27 14:35:26.195] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)

    echo.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nge_T2: ", qubit_to_measure.parameters.ge_T2)
    elif transition == 'ef':
        print("\nef_T2: ", qubit_to_measure.parameters.ef_T2)
    
    print('\nUpdated global experiment parameters!\n')
# Out:
# {'new_parameter_values': {'Q2': {'ge_T2': 5.227829805594839e-06+/-6.651888397819423e-07}},
#  'old_parameter_values': {'Q2': {'ge_T2': 0}}}
#
# ge_T2:  5.227829805594839e-06
#
# Updated global experiment parameters!

# %%
qpu.quantum_elements
# Out:
# [TunableTransmonQubit(
# │   uid='Q2',
# │   signals={
# │   │   'drive': 'q0/drive',
# │   │   'drive_ef': 'q0/drive_ef',
# │   │   'measure': 'q0/measure',
# │   │   'acquire': 'q0/acquire'
# │   },
# │   parameters=TunableTransmonQubitParameters(
# │   │   custom={},
# │   │   ge_T1=1.3645176509647932e-05,
# │   │   ge_T2=5.227829805594839e-06,
# │   │   ge_T2_star=8.607061549037454e-06,
# │   │   ef_T1=0,
# │   │   ef_T2=0,
# │   │   ef_T2_star=0,
# │   │   drive_lo_frequency=4800000000.0,
# │   │   readout_lo_frequency=6000000000.0,
# │   │   resonance_frequency_ge=5004729039.10699,
# │   │   resonance_frequency_ef=4800000000.0,
# │   │   readout_resonator_frequency=5960100000.0,
# │   │   ge_drive_amplitude_pi=0.35706358771612356,
# │   │   ge_drive_amplitude_pi2=0.07343142790133057,
# │   │   ge_drive_length=1e-07,
# │   │   ge_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0.2413462769901743,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   ef_drive_amplitude_pi=0.2,
# │   │   ef_drive_amplitude_pi2=0.1,
# │   │   ef_drive_length=5e-08,
# │   │   ef_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   qubit_resonator_coupling_strength_g=0,
# │   │   ge_chi_shift=0,
# │   │   readout_amplitude=0.2,
# │   │   readout_length=2e-06,
# │   │   readout_pulse={
# │   │   │   'function': 'const'
# │   │   },
# │   │   readout_integration_length=2e-06,
# │   │   readout_integration_delay=8e-08,
# │   │   readout_integration_kernels_type='default',
# │   │   readout_integration_kernels=None,
# │   │   readout_integration_discrimination_thresholds=None,
# │   │   reset_delay_length=0.0003,
# │   │   drive_range=10,
# │   │   readout_range_out=-30,
# │   │   readout_range_in=-35,
# │   │   flux_range=5,
# │   │   spectroscopy_length=2e-05,
# │   │   spectroscopy_amplitude=0.4,
# │   │   spectroscopy_pulse={
# │   │   │   'function': 'const',
# │   │   │   'can_compress': True
# │   │   },
# │   │   dc_slot=0,
# │   │   dc_voltage_parking=0.0,
# │   │   flux_offset_voltage=0.0,
# │   │   user_defined={}
# │   )
# )
# ]

# %% [markdown]
# ## Second Transition: e-f

# %% [markdown]
# ### Amplitude Rabi

# %% [markdown]
# #### Experiment Parameters

# %%
qpu.quantum_elements
# Out:
# [TunableTransmonQubit(
# │   uid='Q2',
# │   signals={
# │   │   'drive': 'q0/drive',
# │   │   'drive_ef': 'q0/drive_ef',
# │   │   'measure': 'q0/measure',
# │   │   'acquire': 'q0/acquire'
# │   },
# │   parameters=TunableTransmonQubitParameters(
# │   │   custom={},
# │   │   ge_T1=1.3645176509647932e-05,
# │   │   ge_T2=5.227829805594839e-06,
# │   │   ge_T2_star=8.607061549037454e-06,
# │   │   ef_T1=0,
# │   │   ef_T2=0,
# │   │   ef_T2_star=0,
# │   │   drive_lo_frequency=4800000000.0,
# │   │   readout_lo_frequency=6000000000.0,
# │   │   resonance_frequency_ge=5004729039.10699,
# │   │   resonance_frequency_ef=4811929098.0324335,
# │   │   readout_resonator_frequency=np.float64(5959580000.0),
# │   │   ge_drive_amplitude_pi=0.1450703458642064,
# │   │   ge_drive_amplitude_pi2=0.07343142790133057,
# │   │   ge_drive_length=2.4457142857142856e-07,
# │   │   ge_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0.2413462769901743,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   ef_drive_amplitude_pi=0.2,
# │   │   ef_drive_amplitude_pi2=0.1,
# │   │   ef_drive_length=1e-07,
# │   │   ef_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   qubit_resonator_coupling_strength_g=0,
# │   │   ge_chi_shift=0,
# │   │   readout_amplitude=0.25,
# │   │   readout_length=1.9e-06,
# │   │   readout_pulse={
# │   │   │   'function': 'gaussian_square',
# │   │   │   'width': 1.7599999999999999e-06
# │   │   },
# │   │   readout_integration_length=1.9e-06,
# │   │   readout_integration_delay=6.000000000000001e-08,
# │   │   readout_integration_kernels_type='default',
# │   │   readout_integration_kernels=None,
# │   │   readout_integration_discrimination_thresholds=None,
# │   │   reset_delay_length=0.0003,
# │   │   drive_range=0,
# │   │   readout_range_out=-20,
# │   │   readout_range_in=-40,
# │   │   flux_range=5,
# │   │   spectroscopy_length=2e-05,
# │   │   spectroscopy_amplitude=0.4,
# │   │   spectroscopy_pulse={
# │   │   │   'function': 'const',
# │   │   │   'can_compress': True
# │   │   },
# │   │   dc_slot=0,
# │   │   dc_voltage_parking=0.0,
# │   │   flux_offset_voltage=0.0,
# │   │   user_defined={}
# │   )
# )
# ]

# %%
qubits[0].parameters.ef_T1 = 0
qubits[0].parameters.ef_T2 = 0
qubits[0].parameters.ef_T2_star = 0
qubits[0].parameters.ef_drive_amplitude_pi = 0.2
qubits[0].parameters.ef_drive_amplitude_pi2 = 0.1
qubits[0].parameters.resonance_frequency_ef = 4811929098.0324335
qubits[0].parameters.ef_drive_pulse = {
    'function': 'drag',
    'beta': 0,
    'sigma': 0.25
}

# %%
update_global_parameters = True

transition = set_transition('ef')

drive_range = 10
drive_length = 60e-9
readout_amplitude = 0.25
n_avg_exponent = 13
readout_range_in = -40
readout_range_out = -25
# resonance_frequency_ef = 4.785e9
# ef_drive_amplitude_pi = 0.85

amp_min = 0
amp_max = 1
n_amp = 31

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temp_pars.drive_range = drive_range
temp_pars.readout_amplitude = readout_amplitude
# temp_pars.resonance_frequency_ef = resonance_frequency_ef
# temp_pars.ef_drive_amplitude_pi = ef_drive_amplitude_pi
temp_pars.readout_range_in = readout_range_in
temp_pars.readout_range_out = readout_range_out
if transition == 'ge':
    temp_pars.ge_drive_length = drive_length
elif transition == 'ef':
    temp_pars.ef_drive_length = drive_length
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = amplitude_rabi.experiment_workflow.options()

options.count(2**n_avg_exponent)
options.close_figures(False) # Plot figures

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

exp_workflow = amplitude_rabi.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    amplitudes=[np.linspace(amp_min, amp_max, n_amp) for q in qubits_to_measure],
    options=options,
    temporary_parameters=temporary_parameters
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.31 15:00:54.582] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 15:00:54.587] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-31 12:00:54.582260Z
# [2026.08.31 15:00:54.589] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 15:00:55.114] INFO    Task 'temporary_qpu': started at 2026-08-31 12:00:55.114016Z
# [2026.08.31 15:00:55.194] INFO    Task 'temporary_qpu': ended at 2026-08-31 12:00:55.194749Z
# [2026.08.31 15:00:55.395] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 15:00:55.395] INFO    12:00:55.395531Z
# [2026.08.31 15:00:55.502] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 12:00:55.500551Z
# [2026.08.31 15:00:55.726] INFO    Task 'create_experiment': started at 2026-08-31 12:00:55.726919Z
# [2026.08.31 15:00:55.933] INFO    Task 'create_experiment': ended at 2026-08-31 12:00:55.933625Z
# [2026.08.31 15:00:56.094] INFO    Task 'compile_experiment': started at 2026-08-31 12:00:56.094851Z
# [2026.08.31 15:00:56.254] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 15:00:56.254] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 15:00:56.270] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 15:00:56.270] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 15:00:56.270] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 15:00:56.270] INFO    Schedule completed. [0.001 s]
# [2026.08.31 15:00:56.287] INFO    Code generation completed for all AWGs. [0.009 s]
# [2026.08.31 15:00:56.291] INFO    Completed compilation step 1 of 1. [0.015 s]
# [2026.08.31 15:00:56.303] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 15:00:56.303] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 15:00:56.303] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 15:00:56.303] INFO      SHFQC_DEV12192        0         22            0           1      7616
# [2026.08.31 15:00:56.309] INFO      SHFQC_DEV12192_sg     0        146           33           3      1504
# [2026.08.31 15:00:56.311] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 15:00:56.311] INFO      TOTAL                          168           33                  9120
# [2026.08.31 15:00:56.315] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 15:00:56.327] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 15:00:56.331] INFO    Task 'compile_experiment': ended at 2026-08-31 12:00:56.331301Z
# [2026.08.31 15:00:56.514] INFO    Task 'run_experiment': started at 2026-08-31 12:00:56.514205Z
# [2026.08.31 15:00:56.734] INFO    Starting near-time execution...
# [2026.08.31 15:00:56.834] INFO    Estimated RT execution time: 81.70 s.
# [2026.08.31 15:02:18.621] INFO    Finished near-time execution.
# [2026.08.31 15:02:23.663] INFO    Task 'run_experiment': ended at 2026-08-31 12:02:23.663779Z
# [2026.08.31 15:02:23.824] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 15:02:23.824] INFO      Workflow 'analysis_workflow': execution started at 2026-08-31
# [2026.08.31 15:02:23.824] INFO      12:02:23.824295Z
# [2026.08.31 15:02:23.824] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 15:02:24.005] INFO    Task 'calculate_qubit_population': started at 2026-08-31 12:02:24.001696Z
# [2026.08.31 15:02:24.166] INFO    Task 'calculate_qubit_population': ended at 2026-08-31 12:02:24.166662Z
# [2026.08.31 15:02:24.340] INFO    Task 'fit_data': started at 2026-08-31 12:02:24.340650Z
# [2026.08.31 15:02:24.645] INFO    Task 'fit_data': ended at 2026-08-31 12:02:24.645415Z
# [2026.08.31 15:02:24.806] INFO    Task 'extract_qubit_parameters': started at 2026-08-31 12:02:24.806045Z
# [2026.08.31 15:02:25.062] INFO    Task 'extract_qubit_parameters': ended at 2026-08-31 12:02:25.062643Z
# [2026.08.31 15:02:25.253] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-31 12:02:25.253949Z
# [2026.08.31 15:02:25.480] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-31 12:02:25.480567Z
# [2026.08.31 15:02:26.027] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-31 12:02:26.027039Z
# [2026.08.31 15:02:26.090] INFO    Task 'plot_population': started at 2026-08-31 12:02:26.090291Z
# [2026.08.31 15:02:26.358] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-31 12:02:26.358287Z
# [2026.08.31 15:02:26.751] INFO    Task 'plot_population': ended at 2026-08-31 12:02:26.751205Z
# [2026.08.31 15:02:26.814] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 15:02:26.814] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-31 12:02:26.814691Z
# [2026.08.31 15:02:26.814] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 15:02:26.877] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 15:02:26.877] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-31 12:02:26.877746Z
# [2026.08.31 15:02:26.877] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)

    amplitude_rabi.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nDrive amplitude pi ge: ", qubit_to_measure.parameters.ge_drive_amplitude_pi)
        print("Drive amplitude pi2 ge: ", qubit_to_measure.parameters.ge_drive_amplitude_pi2)
    elif transition == 'ef':
        print("\nDrive amplitude pi ef: ", qubit_to_measure.parameters.ef_drive_amplitude_pi)
        print("Drive amplitude pi2 ef: ", qubit_to_measure.parameters.ef_drive_amplitude_pi2)
    
    print('\nUpdated global experiment parameters!\n')
# Out:
# {'new_parameter_values': {'Q2': {'ef_drive_amplitude_pi': 0.42263698202577965+/-0.006868351379270424,
#                                  'ef_drive_amplitude_pi2': 0.22057562044741538+/-0.005978115452701976}},
#  'old_parameter_values': {'Q2': {'ef_drive_amplitude_pi': 0.2,
#                                  'ef_drive_amplitude_pi2': 0.1}}}
#
# Drive amplitude pi ef:  0.42263698202577965
# Drive amplitude pi2 ef:  0.22057562044741538
#
# Updated global experiment parameters!

# %% [markdown]
# ### Amplitude Rabi Chevron

# %% [markdown]
# #### Experiment Paramters

# %%
update_global_parameters = True

transition = set_transition('ef')

drive_range = 0
drive_length = 100e-9
readout_amplitude = 0.25
n_avg_exponent = 13

freq_range = 10e6
n_points = 101

amp_min = 0
amp_max = 1
n_amp = 51

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temp_pars.drive_range = drive_range
temp_pars.readout_amplitude = readout_amplitude
if transition == 'ge':
    temp_pars.ge_drive_length = drive_length
elif transition == 'ef':
    temp_pars.ef_drive_length = drive_length
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = amplitude_rabi_chevron.experiment_workflow.options()

options.count(2**n_avg_exponent)
options.close_figures(False) # Plot figures

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

frequencies = [
    temporary_parameters[q.uid].resonance_frequency_ef + np.linspace(- freq_range / 2, freq_range / 2, n_points)
    for q in qubits_to_measure
]

exp_workflow = amplitude_rabi_chevron.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    frequencies=frequencies,
    amplitudes=[np.linspace(amp_min, amp_max, n_amp) for q in qubits_to_measure],
    options=options,
    temporary_parameters=temporary_parameters
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.28 16:28:08.173] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 16:28:08.181] INFO      Workflow 'amplitude_rabi_chevron': execution started at 2026-08-28
# [2026.08.28 16:28:08.181] INFO      13:28:08.173948Z
# [2026.08.28 16:28:08.183] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 16:28:08.557] INFO    Task 'temporary_qpu': started at 2026-08-28 13:28:08.554253Z
# [2026.08.28 16:28:08.626] INFO    Task 'temporary_qpu': ended at 2026-08-28 13:28:08.624338Z
# [2026.08.28 16:28:08.706] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-28
# [2026.08.28 16:28:08.706] INFO    13:28:08.706068Z
# [2026.08.28 16:28:08.735] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-28 13:28:08.735631Z
# [2026.08.28 16:28:08.815] INFO    Task 'create_experiment': started at 2026-08-28 13:28:08.815181Z
# [2026.08.28 16:28:08.926] INFO    Task 'create_experiment': ended at 2026-08-28 13:28:08.926981Z
# [2026.08.28 16:28:09.013] INFO    Task 'compile_experiment': started at 2026-08-28 13:28:09.013203Z
# [2026.08.28 16:28:09.101] INFO    Starting LabOne Q Compiler run...
# [2026.08.28 16:28:09.113] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.28 16:28:09.113] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.28 16:28:09.117] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.28 16:28:09.119] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.28 16:28:09.358] INFO    Schedule completed. [0.237 s]
# [2026.08.28 16:28:09.986] INFO    Code generation completed for all AWGs. [0.628 s]
# [2026.08.28 16:28:10.018] INFO    Completed compilation step 1 of 1. [0.906 s]
# [2026.08.28 16:28:10.035] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 16:28:10.035] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.28 16:28:10.035] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 16:28:10.042] INFO      SHFQC_DEV12192        0         17            0           1      8000
# [2026.08.28 16:28:10.042] INFO      SHFQC_DEV12192_sg     0       1395           54           3      1696
# [2026.08.28 16:28:10.042] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 16:28:10.044] INFO      TOTAL                         1412           54                  9696
# [2026.08.28 16:28:10.044] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 16:28:10.129] INFO    Finished LabOne Q Compiler run.
# [2026.08.28 16:28:10.147] INFO    Task 'compile_experiment': ended at 2026-08-28 13:28:10.146991Z
# [2026.08.28 16:28:10.283] INFO    Task 'run_experiment': started at 2026-08-28 13:28:10.283298Z
# [2026.08.28 16:28:10.420] INFO    Starting near-time execution...
# [2026.08.28 16:28:10.506] INFO    Estimated RT execution time: 38258.83 s.
# [2026.08.29 03:05:49.456] INFO    Finished near-time execution.
# [2026.08.29 03:05:52.317] INFO    Task 'run_experiment': ended at 2026-08-29 00:05:52.303017Z
# [2026.08.29 03:05:52.464] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.29 03:05:52.464] INFO      Workflow 'analysis_workflow': execution started at 2026-08-29
# [2026.08.29 03:05:52.466] INFO      00:05:52.463506Z
# [2026.08.29 03:05:52.469] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.29 03:05:52.543] INFO    Task 'calculate_qubit_population_2d': started at 2026-08-29 00:05:52.543264Z
# [2026.08.29 03:05:52.593] INFO    Task 'calculate_qubit_population_2d': ended at 2026-08-29 00:05:52.593432Z
# [2026.08.29 03:05:52.672] INFO    Task 'plot_population': started at 2026-08-29 00:05:52.671552Z
# [2026.08.29 03:05:52.814] INFO    Artifact: 'Amplitude_Rabi_Chevron_Q2' of type 'Figure' logged at 2026-08-29
# [2026.08.29 03:05:52.814] INFO    00:05:52.799292Z
# [2026.08.29 03:05:53.187] INFO    Task 'plot_population': ended at 2026-08-29 00:05:53.187045Z
# [2026.08.29 03:05:53.217] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.29 03:05:53.223] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-29 00:05:53.217776Z
# [2026.08.29 03:05:53.223] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.29 03:05:53.245] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.29 03:05:53.245] INFO      Workflow 'amplitude_rabi_chevron': execution ended at 2026-08-29
# [2026.08.29 03:05:53.249] INFO      00:05:53.245082Z
# [2026.08.29 03:05:53.253] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)
    
    amplitude_rabi.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nDrive amplitude pi ge: ", qubit_to_measure.parameters.ge_drive_amplitude_pi)
        print("Drive amplitude pi2 ge: ", qubit_to_measure.parameters.ge_drive_amplitude_pi2)
    elif transition == 'ef':
        print("\nDrive amplitude pi ef: ", qubit_to_measure.parameters.ef_drive_amplitude_pi)
        print("Drive amplitude pi2 ef: ", qubit_to_measure.parameters.ef_drive_amplitude_pi2)
    
    print('\nUpdated global experiment parameters!\n')

# %% [markdown]
# ### Rabi Chevron

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = False

transition = set_transition('ef')

drive_range = 10
drive_length = 100e-9
readout_amplitude = 0.25
n_avg_exponent = 13

amp_min = 0
amp_max = 1
n_amp = 31

chevron_detuning_min = -8.0e6
chevron_detuning_max = 8.0e6
n_detuning = 10
chevron_detunings = np.linspace(chevron_detuning_min, chevron_detuning_max, n_detuning)

if transition == 'ge':
    base_resonance_frequency = qubit_to_measure.parameters.resonance_frequency_ge
elif transition == 'ef':
    base_resonance_frequency = qubit_to_measure.parameters.resonance_frequency_ef

# %% [markdown]
# #### Run Workflow

# %%
options = amplitude_rabi.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(True)

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

rabi_chevron_results = []

for detuning in chevron_detunings:
    print(f'Measuring chevron point at detuning: {detuning * 1e-6:.3f} MHz')

    temporary_parameters = {}
    temp_pars = deepcopy(qubits[0].parameters)
    temp_pars.drive_range = drive_range
    temp_pars.readout_amplitude = readout_amplitude
    if transition == 'ge':
        temp_pars.ge_drive_length = drive_length
        temp_pars.resonance_frequency_ge = base_resonance_frequency + detuning
    elif transition == 'ef':
        temp_pars.ef_drive_length = drive_length
        temp_pars.resonance_frequency_ef = base_resonance_frequency + detuning
    temporary_parameters[q.uid] = temp_pars

    exp_workflow = amplitude_rabi.experiment_workflow(
        session=session,
        qpu=qpu,
        qubits=[q.uid for q in qubits_to_measure],
        amplitudes=[np.linspace(amp_min, amp_max, n_amp) for q in qubits_to_measure],
        options=options,
        temporary_parameters=temporary_parameters
    )
    workflow_result = exp_workflow.run()

    raw_signal = workflow_result.tasks["run_experiment"].output.get_data(qubit_to_measure.uid+"/result")
    rabi_chevron_results.append(raw_signal)

rabi_chevron_arr = np.array(rabi_chevron_results)
rabi_chevron_amp = np.linspace(amp_min, amp_max, n_amp)
# Out:
# Measuring chevron point at detuning: -8.000 MHz
# [2026.08.28 05:06:32.810] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:06:32.812] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-28 02:06:32.810125Z
# [2026.08.28 05:06:32.812] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:06:33.096] INFO    Task 'temporary_qpu': started at 2026-08-28 02:06:33.096031Z
# [2026.08.28 05:06:33.149] INFO    Task 'temporary_qpu': ended at 2026-08-28 02:06:33.149887Z
# [2026.08.28 05:06:33.246] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-28
# [2026.08.28 05:06:33.247] INFO    02:06:33.244099Z
# [2026.08.28 05:06:33.308] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-28 02:06:33.308883Z
# [2026.08.28 05:06:33.383] INFO    Task 'create_experiment': started at 2026-08-28 02:06:33.382662Z
# [2026.08.28 05:06:33.485] INFO    Task 'create_experiment': ended at 2026-08-28 02:06:33.482604Z
# [2026.08.28 05:06:33.555] INFO    Task 'compile_experiment': started at 2026-08-28 02:06:33.555123Z
# [2026.08.28 05:06:33.632] INFO    Starting LabOne Q Compiler run...
# [2026.08.28 05:06:33.634] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.28 05:06:33.634] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.28 05:06:33.634] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.28 05:06:33.634] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.28 05:06:33.639] INFO    Schedule completed. [0.002 s]
# [2026.08.28 05:06:33.650] INFO    Code generation completed for all AWGs. [0.010 s]
# [2026.08.28 05:06:33.652] INFO    Completed compilation step 1 of 1. [0.014 s]
# [2026.08.28 05:06:33.656] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:06:33.659] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.28 05:06:33.659] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:06:33.661] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.28 05:06:33.661] INFO      SHFQC_DEV12192_sg     0        146           34           3      1248
# [2026.08.28 05:06:33.664] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:06:33.665] INFO      TOTAL                          168           34                  9248
# [2026.08.28 05:06:33.665] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:06:33.682] INFO    Finished LabOne Q Compiler run.
# [2026.08.28 05:06:33.685] INFO    Task 'compile_experiment': ended at 2026-08-28 02:06:33.685478Z
# [2026.08.28 05:06:33.793] INFO    Task 'run_experiment': started at 2026-08-28 02:06:33.791580Z
# [2026.08.28 05:06:33.925] INFO    Starting near-time execution...
# [2026.08.28 05:06:33.999] INFO    Estimated RT execution time: 81.70 s.
# [2026.08.28 05:07:55.752] INFO    Finished near-time execution.
# [2026.08.28 05:07:55.834] INFO    Task 'run_experiment': ended at 2026-08-28 02:07:55.834787Z
# [2026.08.28 05:07:55.971] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:07:55.975] INFO      Workflow 'analysis_workflow': execution started at 2026-08-28
# [2026.08.28 05:07:55.975] INFO      02:07:55.971231Z
# [2026.08.28 05:07:55.975] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:07:56.062] INFO    Task 'calculate_qubit_population': started at 2026-08-28 02:07:56.062728Z
# [2026.08.28 05:07:56.158] INFO    Task 'calculate_qubit_population': ended at 2026-08-28 02:07:56.158039Z
# [2026.08.28 05:07:56.250] INFO    Task 'fit_data': started at 2026-08-28 02:07:56.250621Z
# [2026.08.28 05:07:56.383] INFO    Task 'fit_data': ended at 2026-08-28 02:07:56.383837Z
# [2026.08.28 05:07:56.462] INFO    Task 'extract_qubit_parameters': started at 2026-08-28 02:07:56.462550Z
# [2026.08.28 05:07:56.572] INFO    Task 'extract_qubit_parameters': ended at 2026-08-28 02:07:56.572867Z
# [2026.08.28 05:07:56.645] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-28 02:07:56.645653Z
# [2026.08.28 05:07:56.751] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-28 02:07:56.751881Z
# [2026.08.28 05:07:57.322] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-28 02:07:57.322333Z
# [2026.08.28 05:07:57.362] INFO    Task 'plot_population': started at 2026-08-28 02:07:57.362900Z
# [2026.08.28 05:07:57.495] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-28 02:07:57.495935Z
# [2026.08.28 05:07:57.970] INFO    Task 'plot_population': ended at 2026-08-28 02:07:57.970320Z
# [2026.08.28 05:07:58.002] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:07:58.002] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-28 02:07:58.002042Z
# [2026.08.28 05:07:58.005] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:07:58.031] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:07:58.031] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-28 02:07:58.031004Z
# [2026.08.28 05:07:58.031] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: -6.222 MHz
# [2026.08.28 05:07:58.147] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:07:58.151] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-28 02:07:58.147611Z
# [2026.08.28 05:07:58.151] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:07:58.404] INFO    Task 'temporary_qpu': started at 2026-08-28 02:07:58.404009Z
# [2026.08.28 05:07:58.442] INFO    Task 'temporary_qpu': ended at 2026-08-28 02:07:58.442932Z
# [2026.08.28 05:07:58.520] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-28
# [2026.08.28 05:07:58.520] INFO    02:07:58.520105Z
# [2026.08.28 05:07:58.559] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-28 02:07:58.559932Z
# [2026.08.28 05:07:58.629] INFO    Task 'create_experiment': started at 2026-08-28 02:07:58.629110Z
# [2026.08.28 05:07:58.743] INFO    Task 'create_experiment': ended at 2026-08-28 02:07:58.743634Z
# [2026.08.28 05:07:58.817] INFO    Task 'compile_experiment': started at 2026-08-28 02:07:58.817901Z
# [2026.08.28 05:07:58.897] INFO    Starting LabOne Q Compiler run...
# [2026.08.28 05:07:58.901] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.28 05:07:58.901] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.28 05:07:58.901] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.28 05:07:58.905] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.28 05:07:58.905] INFO    Schedule completed. [0.001 s]
# [2026.08.28 05:07:58.915] INFO    Code generation completed for all AWGs. [0.008 s]
# [2026.08.28 05:07:58.919] INFO    Completed compilation step 1 of 1. [0.012 s]
# [2026.08.28 05:07:58.923] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:07:58.925] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.28 05:07:58.925] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:07:58.929] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.28 05:07:58.931] INFO      SHFQC_DEV12192_sg     0        146           34           3      1248
# [2026.08.28 05:07:58.932] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:07:58.932] INFO      TOTAL                          168           34                  9248
# [2026.08.28 05:07:58.932] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:07:58.948] INFO    Finished LabOne Q Compiler run.
# [2026.08.28 05:07:58.949] INFO    Task 'compile_experiment': ended at 2026-08-28 02:07:58.949724Z
# [2026.08.28 05:07:59.054] INFO    Task 'run_experiment': started at 2026-08-28 02:07:59.054832Z
# [2026.08.28 05:07:59.200] INFO    Starting near-time execution...
# [2026.08.28 05:07:59.281] INFO    Estimated RT execution time: 81.70 s.
# [2026.08.28 05:09:21.052] INFO    Finished near-time execution.
# [2026.08.28 05:09:21.130] INFO    Task 'run_experiment': ended at 2026-08-28 02:09:21.130995Z
# [2026.08.28 05:09:21.239] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:09:21.239] INFO      Workflow 'analysis_workflow': execution started at 2026-08-28
# [2026.08.28 05:09:21.239] INFO      02:09:21.239356Z
# [2026.08.28 05:09:21.243] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:09:21.356] INFO    Task 'calculate_qubit_population': started at 2026-08-28 02:09:21.356336Z
# [2026.08.28 05:09:21.465] INFO    Task 'calculate_qubit_population': ended at 2026-08-28 02:09:21.465433Z
# [2026.08.28 05:09:21.566] INFO    Task 'fit_data': started at 2026-08-28 02:09:21.566456Z
# [2026.08.28 05:09:21.697] INFO    Task 'fit_data': ended at 2026-08-28 02:09:21.697196Z
# [2026.08.28 05:09:21.775] INFO    Task 'extract_qubit_parameters': started at 2026-08-28 02:09:21.772430Z
# [2026.08.28 05:09:21.922] INFO    Task 'extract_qubit_parameters': ended at 2026-08-28 02:09:21.922687Z
# [2026.08.28 05:09:22.015] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-28 02:09:22.015819Z
# [2026.08.28 05:09:22.155] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-28 02:09:22.151515Z
# [2026.08.28 05:09:22.582] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-28 02:09:22.582899Z
# [2026.08.28 05:09:22.628] INFO    Task 'plot_population': started at 2026-08-28 02:09:22.628647Z
# [2026.08.28 05:09:22.788] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-28 02:09:22.788138Z
# [2026.08.28 05:09:23.235] INFO    Task 'plot_population': ended at 2026-08-28 02:09:23.235759Z
# [2026.08.28 05:09:23.279] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:09:23.282] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-28 02:09:23.279355Z
# [2026.08.28 05:09:23.283] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:09:23.322] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:09:23.322] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-28 02:09:23.322970Z
# [2026.08.28 05:09:23.327] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: -4.444 MHz
# [2026.08.28 05:09:23.465] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:09:23.469] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-28 02:09:23.465065Z
# [2026.08.28 05:09:23.469] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:09:23.694] INFO    Task 'temporary_qpu': started at 2026-08-28 02:09:23.694169Z
# [2026.08.28 05:09:23.733] INFO    Task 'temporary_qpu': ended at 2026-08-28 02:09:23.732421Z
# [2026.08.28 05:09:23.808] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-28
# [2026.08.28 05:09:23.808] INFO    02:09:23.808482Z
# [2026.08.28 05:09:23.852] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-28 02:09:23.852870Z
# [2026.08.28 05:09:23.931] INFO    Task 'create_experiment': started at 2026-08-28 02:09:23.927276Z
# [2026.08.28 05:09:24.048] INFO    Task 'create_experiment': ended at 2026-08-28 02:09:24.045193Z
# [2026.08.28 05:09:24.120] INFO    Task 'compile_experiment': started at 2026-08-28 02:09:24.120202Z
# [2026.08.28 05:09:24.203] INFO    Starting LabOne Q Compiler run...
# [2026.08.28 05:09:24.203] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.28 05:09:24.203] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.28 05:09:24.203] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.28 05:09:24.203] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.28 05:09:24.207] INFO    Schedule completed. [0.001 s]
# [2026.08.28 05:09:24.216] INFO    Code generation completed for all AWGs. [0.008 s]
# [2026.08.28 05:09:24.220] INFO    Completed compilation step 1 of 1. [0.013 s]
# [2026.08.28 05:09:24.225] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:09:24.226] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.28 05:09:24.229] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:09:24.231] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.28 05:09:24.231] INFO      SHFQC_DEV12192_sg     0        146           34           3      1248
# [2026.08.28 05:09:24.234] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:09:24.234] INFO      TOTAL                          168           34                  9248
# [2026.08.28 05:09:24.236] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:09:24.257] INFO    Finished LabOne Q Compiler run.
# [2026.08.28 05:09:24.260] INFO    Task 'compile_experiment': ended at 2026-08-28 02:09:24.260190Z
# [2026.08.28 05:09:24.374] INFO    Task 'run_experiment': started at 2026-08-28 02:09:24.374537Z
# [2026.08.28 05:09:24.505] INFO    Starting near-time execution...
# [2026.08.28 05:09:24.574] INFO    Estimated RT execution time: 81.70 s.
# [2026.08.28 05:10:46.344] INFO    Finished near-time execution.
# [2026.08.28 05:10:46.431] INFO    Task 'run_experiment': ended at 2026-08-28 02:10:46.431689Z
# [2026.08.28 05:10:46.505] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:10:46.510] INFO      Workflow 'analysis_workflow': execution started at 2026-08-28
# [2026.08.28 05:10:46.510] INFO      02:10:46.505987Z
# [2026.08.28 05:10:46.510] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:10:46.602] INFO    Task 'calculate_qubit_population': started at 2026-08-28 02:10:46.602057Z
# [2026.08.28 05:10:46.675] INFO    Task 'calculate_qubit_population': ended at 2026-08-28 02:10:46.675823Z
# [2026.08.28 05:10:46.749] INFO    Task 'fit_data': started at 2026-08-28 02:10:46.749152Z
# [2026.08.28 05:10:46.879] INFO    Task 'fit_data': ended at 2026-08-28 02:10:46.879738Z
# [2026.08.28 05:10:46.957] INFO    Task 'extract_qubit_parameters': started at 2026-08-28 02:10:46.957564Z
# [2026.08.28 05:10:47.079] INFO    Task 'extract_qubit_parameters': ended at 2026-08-28 02:10:47.079390Z
# [2026.08.28 05:10:47.157] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-28 02:10:47.157031Z
# [2026.08.28 05:10:47.267] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-28 02:10:47.267211Z
# [2026.08.28 05:10:47.642] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-28 02:10:47.641272Z
# [2026.08.28 05:10:47.682] INFO    Task 'plot_population': started at 2026-08-28 02:10:47.682917Z
# [2026.08.28 05:10:47.813] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-28 02:10:47.811159Z
# [2026.08.28 05:10:48.262] INFO    Task 'plot_population': ended at 2026-08-28 02:10:48.259371Z
# [2026.08.28 05:10:48.340] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:10:48.344] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-28 02:10:48.340771Z
# [2026.08.28 05:10:48.348] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:10:48.375] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:10:48.377] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-28 02:10:48.375430Z
# [2026.08.28 05:10:48.377] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: -2.667 MHz
# [2026.08.28 05:10:48.494] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:10:48.498] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-28 02:10:48.494591Z
# [2026.08.28 05:10:48.499] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:10:48.773] INFO    Task 'temporary_qpu': started at 2026-08-28 02:10:48.773426Z
# [2026.08.28 05:10:48.817] INFO    Task 'temporary_qpu': ended at 2026-08-28 02:10:48.816449Z
# [2026.08.28 05:10:48.912] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-28
# [2026.08.28 05:10:48.913] INFO    02:10:48.911006Z
# [2026.08.28 05:10:48.957] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-28 02:10:48.957795Z
# [2026.08.28 05:10:49.040] INFO    Task 'create_experiment': started at 2026-08-28 02:10:49.036962Z
# [2026.08.28 05:10:49.137] INFO    Task 'create_experiment': ended at 2026-08-28 02:10:49.137875Z
# [2026.08.28 05:10:49.225] INFO    Task 'compile_experiment': started at 2026-08-28 02:10:49.225037Z
# [2026.08.28 05:10:49.302] INFO    Starting LabOne Q Compiler run...
# [2026.08.28 05:10:49.302] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.28 05:10:49.302] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.28 05:10:49.302] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.28 05:10:49.306] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.28 05:10:49.306] INFO    Schedule completed. [0.000 s]
# [2026.08.28 05:10:49.313] INFO    Code generation completed for all AWGs. [0.005 s]
# [2026.08.28 05:10:49.317] INFO    Completed compilation step 1 of 1. [0.010 s]
# [2026.08.28 05:10:49.323] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:10:49.326] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.28 05:10:49.328] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:10:49.329] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.28 05:10:49.330] INFO      SHFQC_DEV12192_sg     0        146           34           3      1248
# [2026.08.28 05:10:49.332] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:10:49.332] INFO      TOTAL                          168           34                  9248
# [2026.08.28 05:10:49.332] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:10:49.349] INFO    Finished LabOne Q Compiler run.
# [2026.08.28 05:10:49.349] INFO    Task 'compile_experiment': ended at 2026-08-28 02:10:49.349473Z
# [2026.08.28 05:10:49.449] INFO    Task 'run_experiment': started at 2026-08-28 02:10:49.445182Z
# [2026.08.28 05:10:49.563] INFO    Starting near-time execution...
# [2026.08.28 05:10:49.633] INFO    Estimated RT execution time: 81.70 s.
# [2026.08.28 05:12:11.402] INFO    Finished near-time execution.
# [2026.08.28 05:12:11.459] INFO    Task 'run_experiment': ended at 2026-08-28 02:12:11.459568Z
# [2026.08.28 05:12:11.564] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:12:11.566] INFO      Workflow 'analysis_workflow': execution started at 2026-08-28
# [2026.08.28 05:12:11.566] INFO      02:12:11.564171Z
# [2026.08.28 05:12:11.566] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:12:11.662] INFO    Task 'calculate_qubit_population': started at 2026-08-28 02:12:11.662474Z
# [2026.08.28 05:12:11.742] INFO    Task 'calculate_qubit_population': ended at 2026-08-28 02:12:11.742246Z
# [2026.08.28 05:12:11.822] INFO    Task 'fit_data': started at 2026-08-28 02:12:11.820544Z
# [2026.08.28 05:12:11.900] INFO    Task 'fit_data': ended at 2026-08-28 02:12:11.900669Z
# [2026.08.28 05:12:11.962] INFO    Task 'extract_qubit_parameters': started at 2026-08-28 02:12:11.957520Z
# [2026.08.28 05:12:12.047] INFO    Task 'extract_qubit_parameters': ended at 2026-08-28 02:12:12.047651Z
# [2026.08.28 05:12:12.096] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-28 02:12:12.096943Z
# [2026.08.28 05:12:12.171] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-28 02:12:12.170233Z
# [2026.08.28 05:12:12.645] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-28 02:12:12.645770Z
# [2026.08.28 05:12:12.671] INFO    Task 'plot_population': started at 2026-08-28 02:12:12.671602Z
# [2026.08.28 05:12:12.825] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-28 02:12:12.824542Z
# [2026.08.28 05:12:13.260] INFO    Task 'plot_population': ended at 2026-08-28 02:12:13.260578Z
# [2026.08.28 05:12:13.291] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:12:13.293] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-28 02:12:13.291334Z
# [2026.08.28 05:12:13.294] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:12:13.317] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:12:13.317] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-28 02:12:13.317238Z
# [2026.08.28 05:12:13.317] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: -0.889 MHz
# [2026.08.28 05:12:13.442] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:12:13.443] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-28 02:12:13.439711Z
# [2026.08.28 05:12:13.444] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:12:13.672] INFO    Task 'temporary_qpu': started at 2026-08-28 02:12:13.672564Z
# [2026.08.28 05:12:13.716] INFO    Task 'temporary_qpu': ended at 2026-08-28 02:12:13.716477Z
# [2026.08.28 05:12:13.822] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-28
# [2026.08.28 05:12:13.826] INFO    02:12:13.822006Z
# [2026.08.28 05:12:13.864] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-28 02:12:13.864489Z
# [2026.08.28 05:12:13.952] INFO    Task 'create_experiment': started at 2026-08-28 02:12:13.952554Z
# [2026.08.28 05:12:14.044] INFO    Task 'create_experiment': ended at 2026-08-28 02:12:14.044049Z
# [2026.08.28 05:12:14.126] INFO    Task 'compile_experiment': started at 2026-08-28 02:12:14.126359Z
# [2026.08.28 05:12:14.205] INFO    Starting LabOne Q Compiler run...
# [2026.08.28 05:12:14.210] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.28 05:12:14.210] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.28 05:12:14.210] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.28 05:12:14.210] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.28 05:12:14.214] INFO    Schedule completed. [0.001 s]
# [2026.08.28 05:12:14.219] INFO    Code generation completed for all AWGs. [0.005 s]
# [2026.08.28 05:12:14.221] INFO    Completed compilation step 1 of 1. [0.007 s]
# [2026.08.28 05:12:14.227] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:12:14.227] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.28 05:12:14.231] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:12:14.231] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.28 05:12:14.236] INFO      SHFQC_DEV12192_sg     0        146           34           3      1248
# [2026.08.28 05:12:14.236] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:12:14.236] INFO      TOTAL                          168           34                  9248
# [2026.08.28 05:12:14.236] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:12:14.253] INFO    Finished LabOne Q Compiler run.
# [2026.08.28 05:12:14.253] INFO    Task 'compile_experiment': ended at 2026-08-28 02:12:14.253948Z
# [2026.08.28 05:12:14.360] INFO    Task 'run_experiment': started at 2026-08-28 02:12:14.360179Z
# [2026.08.28 05:12:14.504] INFO    Starting near-time execution...
# [2026.08.28 05:12:14.579] INFO    Estimated RT execution time: 81.70 s.
# [2026.08.28 05:13:36.351] INFO    Finished near-time execution.
# [2026.08.28 05:13:36.440] INFO    Task 'run_experiment': ended at 2026-08-28 02:13:36.440676Z
# [2026.08.28 05:13:36.529] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:13:36.533] INFO      Workflow 'analysis_workflow': execution started at 2026-08-28
# [2026.08.28 05:13:36.533] INFO      02:13:36.529575Z
# [2026.08.28 05:13:36.533] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:13:36.616] INFO    Task 'calculate_qubit_population': started at 2026-08-28 02:13:36.616111Z
# [2026.08.28 05:13:36.703] INFO    Task 'calculate_qubit_population': ended at 2026-08-28 02:13:36.698679Z
# [2026.08.28 05:13:36.778] INFO    Task 'fit_data': started at 2026-08-28 02:13:36.773871Z
# [2026.08.28 05:13:36.892] INFO    Task 'fit_data': ended at 2026-08-28 02:13:36.892988Z
# [2026.08.28 05:13:36.976] INFO    Task 'extract_qubit_parameters': started at 2026-08-28 02:13:36.976299Z
# [2026.08.28 05:13:37.091] INFO    Task 'extract_qubit_parameters': ended at 2026-08-28 02:13:37.091974Z
# [2026.08.28 05:13:37.164] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-28 02:13:37.164765Z
# [2026.08.28 05:13:37.261] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-28 02:13:37.261428Z
# [2026.08.28 05:13:37.788] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-28 02:13:37.788250Z
# [2026.08.28 05:13:37.828] INFO    Task 'plot_population': started at 2026-08-28 02:13:37.828621Z
# [2026.08.28 05:13:37.954] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-28 02:13:37.954154Z
# [2026.08.28 05:13:38.351] INFO    Task 'plot_population': ended at 2026-08-28 02:13:38.351206Z
# [2026.08.28 05:13:38.396] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:13:38.396] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-28 02:13:38.392614Z
# [2026.08.28 05:13:38.399] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:13:38.438] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:13:38.438] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-28 02:13:38.438242Z
# [2026.08.28 05:13:38.441] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: 0.889 MHz
# [2026.08.28 05:13:38.577] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:13:38.577] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-28 02:13:38.577378Z
# [2026.08.28 05:13:38.581] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:13:38.832] INFO    Task 'temporary_qpu': started at 2026-08-28 02:13:38.832920Z
# [2026.08.28 05:13:38.872] INFO    Task 'temporary_qpu': ended at 2026-08-28 02:13:38.872206Z
# [2026.08.28 05:13:38.954] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-28
# [2026.08.28 05:13:38.954] INFO    02:13:38.954370Z
# [2026.08.28 05:13:38.993] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-28 02:13:38.993509Z
# [2026.08.28 05:13:39.074] INFO    Task 'create_experiment': started at 2026-08-28 02:13:39.074735Z
# [2026.08.28 05:13:39.180] INFO    Task 'create_experiment': ended at 2026-08-28 02:13:39.176535Z
# [2026.08.28 05:13:39.268] INFO    Task 'compile_experiment': started at 2026-08-28 02:13:39.263721Z
# [2026.08.28 05:13:39.347] INFO    Starting LabOne Q Compiler run...
# [2026.08.28 05:13:39.347] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.28 05:13:39.347] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.28 05:13:39.347] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.28 05:13:39.351] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.28 05:13:39.352] INFO    Schedule completed. [0.001 s]
# [2026.08.28 05:13:39.355] INFO    Code generation completed for all AWGs. [0.004 s]
# [2026.08.28 05:13:39.357] INFO    Completed compilation step 1 of 1. [0.006 s]
# [2026.08.28 05:13:39.363] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:13:39.363] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.28 05:13:39.363] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:13:39.363] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.28 05:13:39.363] INFO      SHFQC_DEV12192_sg     0        146           34           3      1248
# [2026.08.28 05:13:39.363] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:13:39.368] INFO      TOTAL                          168           34                  9248
# [2026.08.28 05:13:39.368] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:13:39.381] INFO    Finished LabOne Q Compiler run.
# [2026.08.28 05:13:39.381] INFO    Task 'compile_experiment': ended at 2026-08-28 02:13:39.381954Z
# [2026.08.28 05:13:39.507] INFO    Task 'run_experiment': started at 2026-08-28 02:13:39.507851Z
# [2026.08.28 05:13:39.634] INFO    Starting near-time execution...
# [2026.08.28 05:13:39.721] INFO    Estimated RT execution time: 81.70 s.
# [2026.08.28 05:15:01.482] INFO    Finished near-time execution.
# [2026.08.28 05:15:01.546] INFO    Task 'run_experiment': ended at 2026-08-28 02:15:01.546307Z
# [2026.08.28 05:15:01.636] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:15:01.637] INFO      Workflow 'analysis_workflow': execution started at 2026-08-28
# [2026.08.28 05:15:01.638] INFO      02:15:01.636496Z
# [2026.08.28 05:15:01.639] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:15:01.731] INFO    Task 'calculate_qubit_population': started at 2026-08-28 02:15:01.730102Z
# [2026.08.28 05:15:01.814] INFO    Task 'calculate_qubit_population': ended at 2026-08-28 02:15:01.814300Z
# [2026.08.28 05:15:01.898] INFO    Task 'fit_data': started at 2026-08-28 02:15:01.898198Z
# [2026.08.28 05:15:02.024] INFO    Task 'fit_data': ended at 2026-08-28 02:15:02.024866Z
# [2026.08.28 05:15:02.104] INFO    Task 'extract_qubit_parameters': started at 2026-08-28 02:15:02.104508Z
# [2026.08.28 05:15:02.219] INFO    Task 'extract_qubit_parameters': ended at 2026-08-28 02:15:02.219981Z
# [2026.08.28 05:15:02.303] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-28 02:15:02.303523Z
# [2026.08.28 05:15:02.409] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-28 02:15:02.409819Z
# [2026.08.28 05:15:02.933] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-28 02:15:02.932525Z
# [2026.08.28 05:15:02.990] INFO    Task 'plot_population': started at 2026-08-28 02:15:02.990162Z
# [2026.08.28 05:15:03.126] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-28 02:15:03.123324Z
# [2026.08.28 05:15:03.557] INFO    Task 'plot_population': ended at 2026-08-28 02:15:03.557483Z
# [2026.08.28 05:15:03.597] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:15:03.597] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-28 02:15:03.597538Z
# [2026.08.28 05:15:03.601] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:15:03.637] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:15:03.637] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-28 02:15:03.637357Z
# [2026.08.28 05:15:03.637] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: 2.667 MHz
# [2026.08.28 05:15:03.796] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:15:03.796] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-28 02:15:03.796359Z
# [2026.08.28 05:15:03.796] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:15:04.054] INFO    Task 'temporary_qpu': started at 2026-08-28 02:15:04.054938Z
# [2026.08.28 05:15:04.098] INFO    Task 'temporary_qpu': ended at 2026-08-28 02:15:04.098194Z
# [2026.08.28 05:15:04.213] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-28
# [2026.08.28 05:15:04.213] INFO    02:15:04.213018Z
# [2026.08.28 05:15:04.257] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-28 02:15:04.255246Z
# [2026.08.28 05:15:04.333] INFO    Task 'create_experiment': started at 2026-08-28 02:15:04.333647Z
# [2026.08.28 05:15:04.455] INFO    Task 'create_experiment': ended at 2026-08-28 02:15:04.455866Z
# [2026.08.28 05:15:04.535] INFO    Task 'compile_experiment': started at 2026-08-28 02:15:04.535349Z
# [2026.08.28 05:15:04.619] INFO    Starting LabOne Q Compiler run...
# [2026.08.28 05:15:04.619] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.28 05:15:04.619] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.28 05:15:04.625] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.28 05:15:04.627] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.28 05:15:04.632] INFO    Schedule completed. [0.001 s]
# [2026.08.28 05:15:04.645] INFO    Code generation completed for all AWGs. [0.010 s]
# [2026.08.28 05:15:04.645] INFO    Completed compilation step 1 of 1. [0.016 s]
# [2026.08.28 05:15:04.649] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:15:04.649] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.28 05:15:04.649] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:15:04.654] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.28 05:15:04.654] INFO      SHFQC_DEV12192_sg     0        146           34           3      1248
# [2026.08.28 05:15:04.655] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:15:04.655] INFO      TOTAL                          168           34                  9248
# [2026.08.28 05:15:04.655] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:15:04.680] INFO    Finished LabOne Q Compiler run.
# [2026.08.28 05:15:04.684] INFO    Task 'compile_experiment': ended at 2026-08-28 02:15:04.683822Z
# [2026.08.28 05:15:04.781] INFO    Task 'run_experiment': started at 2026-08-28 02:15:04.781064Z
# [2026.08.28 05:15:04.918] INFO    Starting near-time execution...
# [2026.08.28 05:15:05.005] INFO    Estimated RT execution time: 81.70 s.
# [2026.08.28 05:16:26.777] INFO    Finished near-time execution.
# [2026.08.28 05:16:26.874] INFO    Task 'run_experiment': ended at 2026-08-28 02:16:26.872904Z
# [2026.08.28 05:16:26.972] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:16:26.972] INFO      Workflow 'analysis_workflow': execution started at 2026-08-28
# [2026.08.28 05:16:26.972] INFO      02:16:26.972711Z
# [2026.08.28 05:16:26.972] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:16:27.075] INFO    Task 'calculate_qubit_population': started at 2026-08-28 02:16:27.073125Z
# [2026.08.28 05:16:27.162] INFO    Task 'calculate_qubit_population': ended at 2026-08-28 02:16:27.162132Z
# [2026.08.28 05:16:27.253] INFO    Task 'fit_data': started at 2026-08-28 02:16:27.250497Z
# [2026.08.28 05:16:27.387] INFO    Task 'fit_data': ended at 2026-08-28 02:16:27.385212Z
# [2026.08.28 05:16:27.460] INFO    Task 'extract_qubit_parameters': started at 2026-08-28 02:16:27.456115Z
# [2026.08.28 05:16:27.578] INFO    Task 'extract_qubit_parameters': ended at 2026-08-28 02:16:27.578027Z
# [2026.08.28 05:16:27.652] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-28 02:16:27.648923Z
# [2026.08.28 05:16:27.782] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-28 02:16:27.780860Z
# [2026.08.28 05:16:28.158] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-28 02:16:28.155178Z
# [2026.08.28 05:16:28.197] INFO    Task 'plot_population': started at 2026-08-28 02:16:28.197626Z
# [2026.08.28 05:16:28.328] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-28 02:16:28.328979Z
# [2026.08.28 05:16:28.690] INFO    Task 'plot_population': ended at 2026-08-28 02:16:28.688838Z
# [2026.08.28 05:16:28.728] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:16:28.732] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-28 02:16:28.728110Z
# [2026.08.28 05:16:28.733] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:16:28.767] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:16:28.771] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-28 02:16:28.767228Z
# [2026.08.28 05:16:28.775] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: 4.444 MHz
# [2026.08.28 05:16:28.916] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:16:28.920] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-28 02:16:28.913636Z
# [2026.08.28 05:16:28.920] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:16:29.174] INFO    Task 'temporary_qpu': started at 2026-08-28 02:16:29.174189Z
# [2026.08.28 05:16:29.213] INFO    Task 'temporary_qpu': ended at 2026-08-28 02:16:29.213549Z
# [2026.08.28 05:16:29.291] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-28
# [2026.08.28 05:16:29.291] INFO    02:16:29.291506Z
# [2026.08.28 05:16:29.335] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-28 02:16:29.335981Z
# [2026.08.28 05:16:29.415] INFO    Task 'create_experiment': started at 2026-08-28 02:16:29.415146Z
# [2026.08.28 05:16:29.523] INFO    Task 'create_experiment': ended at 2026-08-28 02:16:29.523891Z
# [2026.08.28 05:16:29.610] INFO    Task 'compile_experiment': started at 2026-08-28 02:16:29.610716Z
# [2026.08.28 05:16:29.685] INFO    Starting LabOne Q Compiler run...
# [2026.08.28 05:16:29.686] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.28 05:16:29.687] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.28 05:16:29.687] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.28 05:16:29.689] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.28 05:16:29.693] INFO    Schedule completed. [0.003 s]
# [2026.08.28 05:16:29.699] INFO    Code generation completed for all AWGs. [0.005 s]
# [2026.08.28 05:16:29.702] INFO    Completed compilation step 1 of 1. [0.011 s]
# [2026.08.28 05:16:29.706] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:16:29.706] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.28 05:16:29.706] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:16:29.706] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.28 05:16:29.711] INFO      SHFQC_DEV12192_sg     0        146           34           3      1248
# [2026.08.28 05:16:29.711] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:16:29.711] INFO      TOTAL                          168           34                  9248
# [2026.08.28 05:16:29.711] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:16:29.735] INFO    Finished LabOne Q Compiler run.
# [2026.08.28 05:16:29.735] INFO    Task 'compile_experiment': ended at 2026-08-28 02:16:29.735686Z
# [2026.08.28 05:16:29.842] INFO    Task 'run_experiment': started at 2026-08-28 02:16:29.838519Z
# [2026.08.28 05:16:29.986] INFO    Starting near-time execution...
# [2026.08.28 05:16:30.069] INFO    Estimated RT execution time: 81.70 s.
# [2026.08.28 05:17:51.828] INFO    Finished near-time execution.
# [2026.08.28 05:17:51.890] INFO    Task 'run_experiment': ended at 2026-08-28 02:17:51.890341Z
# [2026.08.28 05:17:51.991] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:17:51.991] INFO      Workflow 'analysis_workflow': execution started at 2026-08-28
# [2026.08.28 05:17:51.995] INFO      02:17:51.991116Z
# [2026.08.28 05:17:51.995] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:17:52.115] INFO    Task 'calculate_qubit_population': started at 2026-08-28 02:17:52.115209Z
# [2026.08.28 05:17:52.193] INFO    Task 'calculate_qubit_population': ended at 2026-08-28 02:17:52.193449Z
# [2026.08.28 05:17:52.276] INFO    Task 'fit_data': started at 2026-08-28 02:17:52.276927Z
# [2026.08.28 05:17:52.397] INFO    Task 'fit_data': ended at 2026-08-28 02:17:52.397706Z
# [2026.08.28 05:17:52.479] INFO    Task 'extract_qubit_parameters': started at 2026-08-28 02:17:52.479821Z
# [2026.08.28 05:17:52.615] INFO    Task 'extract_qubit_parameters': ended at 2026-08-28 02:17:52.612080Z
# [2026.08.28 05:17:52.698] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-28 02:17:52.693847Z
# [2026.08.28 05:17:52.820] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-28 02:17:52.820760Z
# [2026.08.28 05:17:53.728] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-28 02:17:53.726621Z
# [2026.08.28 05:17:53.775] INFO    Task 'plot_population': started at 2026-08-28 02:17:53.771465Z
# [2026.08.28 05:17:53.920] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-28 02:17:53.920190Z
# [2026.08.28 05:17:54.246] INFO    Task 'plot_population': ended at 2026-08-28 02:17:54.246132Z
# [2026.08.28 05:17:54.283] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:17:54.283] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-28 02:17:54.283565Z
# [2026.08.28 05:17:54.283] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:17:54.323] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:17:54.326] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-28 02:17:54.323616Z
# [2026.08.28 05:17:54.326] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: 6.222 MHz
# [2026.08.28 05:17:54.476] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:17:54.476] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-28 02:17:54.472509Z
# [2026.08.28 05:17:54.481] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:17:54.719] INFO    Task 'temporary_qpu': started at 2026-08-28 02:17:54.718074Z
# [2026.08.28 05:17:54.770] INFO    Task 'temporary_qpu': ended at 2026-08-28 02:17:54.769119Z
# [2026.08.28 05:17:54.852] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-28
# [2026.08.28 05:17:54.857] INFO    02:17:54.852997Z
# [2026.08.28 05:17:54.896] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-28 02:17:54.896777Z
# [2026.08.28 05:17:54.974] INFO    Task 'create_experiment': started at 2026-08-28 02:17:54.974815Z
# [2026.08.28 05:17:55.102] INFO    Task 'create_experiment': ended at 2026-08-28 02:17:55.102651Z
# [2026.08.28 05:17:55.180] INFO    Task 'compile_experiment': started at 2026-08-28 02:17:55.180393Z
# [2026.08.28 05:17:55.263] INFO    Starting LabOne Q Compiler run...
# [2026.08.28 05:17:55.268] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.28 05:17:55.268] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.28 05:17:55.268] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.28 05:17:55.268] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.28 05:17:55.268] INFO    Schedule completed. [0.000 s]
# [2026.08.28 05:17:55.272] INFO    Code generation completed for all AWGs. [0.003 s]
# [2026.08.28 05:17:55.278] INFO    Completed compilation step 1 of 1. [0.007 s]
# [2026.08.28 05:17:55.285] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:17:55.285] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.28 05:17:55.285] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:17:55.289] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.28 05:17:55.290] INFO      SHFQC_DEV12192_sg     0        146           34           3      1248
# [2026.08.28 05:17:55.290] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:17:55.293] INFO      TOTAL                          168           34                  9248
# [2026.08.28 05:17:55.293] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:17:55.311] INFO    Finished LabOne Q Compiler run.
# [2026.08.28 05:17:55.315] INFO    Task 'compile_experiment': ended at 2026-08-28 02:17:55.315561Z
# [2026.08.28 05:17:55.414] INFO    Task 'run_experiment': started at 2026-08-28 02:17:55.414769Z
# [2026.08.28 05:17:55.553] INFO    Starting near-time execution...
# [2026.08.28 05:17:55.638] INFO    Estimated RT execution time: 81.70 s.
# [2026.08.28 05:19:17.396] INFO    Finished near-time execution.
# [2026.08.28 05:19:17.450] INFO    Task 'run_experiment': ended at 2026-08-28 02:19:17.450831Z
# [2026.08.28 05:19:17.571] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:19:17.572] INFO      Workflow 'analysis_workflow': execution started at 2026-08-28
# [2026.08.28 05:19:17.573] INFO      02:19:17.569419Z
# [2026.08.28 05:19:17.573] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:19:17.669] INFO    Task 'calculate_qubit_population': started at 2026-08-28 02:19:17.669687Z
# [2026.08.28 05:19:17.762] INFO    Task 'calculate_qubit_population': ended at 2026-08-28 02:19:17.762134Z
# [2026.08.28 05:19:17.859] INFO    Task 'fit_data': started at 2026-08-28 02:19:17.859253Z
# [2026.08.28 05:19:18.004] INFO    Task 'fit_data': ended at 2026-08-28 02:19:18.003022Z
# [2026.08.28 05:19:18.099] INFO    Task 'extract_qubit_parameters': started at 2026-08-28 02:19:18.099623Z
# [2026.08.28 05:19:18.231] INFO    Task 'extract_qubit_parameters': ended at 2026-08-28 02:19:18.231071Z
# [2026.08.28 05:19:18.319] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-28 02:19:18.319559Z
# [2026.08.28 05:19:18.484] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-28 02:19:18.484557Z
# [2026.08.28 05:19:18.875] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-28 02:19:18.875371Z
# [2026.08.28 05:19:18.917] INFO    Task 'plot_population': started at 2026-08-28 02:19:18.917512Z
# [2026.08.28 05:19:19.063] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-28 02:19:19.063070Z
# [2026.08.28 05:19:19.564] INFO    Task 'plot_population': ended at 2026-08-28 02:19:19.563373Z
# [2026.08.28 05:19:19.643] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:19:19.648] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-28 02:19:19.643948Z
# [2026.08.28 05:19:19.652] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:19:19.693] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:19:19.697] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-28 02:19:19.693384Z
# [2026.08.28 05:19:19.697] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measuring chevron point at detuning: 8.000 MHz
# [2026.08.28 05:19:19.844] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:19:19.844] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-28 02:19:19.844025Z
# [2026.08.28 05:19:19.844] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:19:20.090] INFO    Task 'temporary_qpu': started at 2026-08-28 02:19:20.090099Z
# [2026.08.28 05:19:20.142] INFO    Task 'temporary_qpu': ended at 2026-08-28 02:19:20.142262Z
# [2026.08.28 05:19:20.224] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-28
# [2026.08.28 05:19:20.224] INFO    02:19:20.224194Z
# [2026.08.28 05:19:20.277] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-28 02:19:20.277251Z
# [2026.08.28 05:19:20.370] INFO    Task 'create_experiment': started at 2026-08-28 02:19:20.370831Z
# [2026.08.28 05:19:20.492] INFO    Task 'create_experiment': ended at 2026-08-28 02:19:20.492748Z
# [2026.08.28 05:19:20.574] INFO    Task 'compile_experiment': started at 2026-08-28 02:19:20.574171Z
# [2026.08.28 05:19:20.656] INFO    Starting LabOne Q Compiler run...
# [2026.08.28 05:19:20.660] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.28 05:19:20.660] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.28 05:19:20.660] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.28 05:19:20.660] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.28 05:19:20.665] INFO    Schedule completed. [0.002 s]
# [2026.08.28 05:19:20.670] INFO    Code generation completed for all AWGs. [0.004 s]
# [2026.08.28 05:19:20.674] INFO    Completed compilation step 1 of 1. [0.009 s]
# [2026.08.28 05:19:20.679] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:19:20.681] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.28 05:19:20.684] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:19:20.686] INFO      SHFQC_DEV12192        0         22            0           1      8000
# [2026.08.28 05:19:20.687] INFO      SHFQC_DEV12192_sg     0        146           34           3      1248
# [2026.08.28 05:19:20.687] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:19:20.690] INFO      TOTAL                          168           34                  9248
# [2026.08.28 05:19:20.690] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 05:19:20.703] INFO    Finished LabOne Q Compiler run.
# [2026.08.28 05:19:20.703] INFO    Task 'compile_experiment': ended at 2026-08-28 02:19:20.703731Z
# [2026.08.28 05:19:20.859] INFO    Task 'run_experiment': started at 2026-08-28 02:19:20.854834Z
# [2026.08.28 05:19:20.977] INFO    Starting near-time execution...
# [2026.08.28 05:19:21.053] INFO    Estimated RT execution time: 81.70 s.
# [2026.08.28 05:20:42.823] INFO    Finished near-time execution.
# [2026.08.28 05:20:42.898] INFO    Task 'run_experiment': ended at 2026-08-28 02:20:42.898626Z
# [2026.08.28 05:20:42.985] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:20:42.985] INFO      Workflow 'analysis_workflow': execution started at 2026-08-28
# [2026.08.28 05:20:42.985] INFO      02:20:42.985551Z
# [2026.08.28 05:20:42.990] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:20:43.084] INFO    Task 'calculate_qubit_population': started at 2026-08-28 02:20:43.080154Z
# [2026.08.28 05:20:43.227] INFO    Task 'calculate_qubit_population': ended at 2026-08-28 02:20:43.227690Z
# [2026.08.28 05:20:43.304] INFO    Task 'fit_data': started at 2026-08-28 02:20:43.304684Z
# [2026.08.28 05:20:43.464] INFO    Task 'fit_data': ended at 2026-08-28 02:20:43.463275Z
# [2026.08.28 05:20:43.538] INFO    Task 'extract_qubit_parameters': started at 2026-08-28 02:20:43.538359Z
# [2026.08.28 05:20:43.657] INFO    Task 'extract_qubit_parameters': ended at 2026-08-28 02:20:43.657879Z
# [2026.08.28 05:20:43.737] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-28 02:20:43.737435Z
# [2026.08.28 05:20:43.858] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-28 02:20:43.858380Z
# [2026.08.28 05:20:44.305] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-28 02:20:44.305871Z
# [2026.08.28 05:20:44.350] INFO    Task 'plot_population': started at 2026-08-28 02:20:44.350665Z
# [2026.08.28 05:20:44.484] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-28 02:20:44.484971Z
# [2026.08.28 05:20:44.922] INFO    Task 'plot_population': ended at 2026-08-28 02:20:44.922829Z
# [2026.08.28 05:20:44.971] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:20:44.975] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-28 02:20:44.971185Z
# [2026.08.28 05:20:44.979] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:20:45.027] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 05:20:45.029] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-28 02:20:45.022751Z
# [2026.08.28 05:20:45.029] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Plot Chevron Map

# %%
X = rabi_chevron_amp
Y = chevron_detunings * 1e-6
Z = np.absolute(rabi_chevron_arr)

fig, ax = plt.subplots(figsize=(8, 6))
c = ax.pcolormesh(X, Y, Z, cmap='Reds', shading='auto')
fig.colorbar(c, ax=ax, label='Signal amplitude (a.u.)')
ax.set_xlabel('Drive amplitude (a.u.)')
ax.set_ylabel('Detuning (MHz)')
ax.set_title(f'Rabi chevron, {transition}-transition')

figname = f'Rabi_chevron_{transition}_'
file_path = get_path_to_file(figname, '.png')
plt.savefig(file_path, dpi=600, format='png', metadata=None,
        bbox_inches=None, pad_inches=0.1,
        facecolor='auto', edgecolor='auto',
        backend=None,
       )

# %% [markdown]
# #### Save Data

# %%
Data_rabi_chevron = {
    'rabi_chevron': rabi_chevron_arr,
    'detunings': chevron_detunings,
    'rabi_amp': rabi_chevron_amp,
}

file_name = f'Rabi_chevron_{transition}_'
file_path = get_path_to_file(file_name, '.mat')
savemat(file_path, Data_rabi_chevron)

# %% [markdown]
# ### Rabi Frequency Calibration

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = False

transition = set_transition('ef')

drive_range = 10
readout_amplitude = 0.1
n_avg_exponent = 12

amp_min = 0
amp_max = 1.0
n_amp = 101

drive_length_min = 50e-9
drive_length_max = 400e-9
n_drive_length = 36
drive_lengths = np.linspace(drive_length_min, drive_length_max, n_drive_length)

# %% [markdown]
# #### Run Workflow

# %%
options = amplitude_rabi.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(True)

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

fitted_pi_amplitudes = []

for drive_length in drive_lengths:
    print(f'Measuring Rabi with drive length: {drive_length * 1e9:.1f} ns')

    temporary_parameters = {}
    temp_pars = deepcopy(qubits[0].parameters)
    temp_pars.drive_range = drive_range
    temp_pars.readout_amplitude = readout_amplitude
    if transition == 'ge':
        temp_pars.ge_drive_length = drive_length
    elif transition == 'ef':
        temp_pars.ef_drive_length = drive_length
    temporary_parameters[q.uid] = temp_pars

    exp_workflow = amplitude_rabi.experiment_workflow(
        session=session,
        qpu=qpu,
        qubits=[q.uid for q in qubits_to_measure],
        amplitudes=[np.linspace(amp_min, amp_max, n_amp) for q in qubits_to_measure],
        options=options,
        temporary_parameters=temporary_parameters
    )
    workflow_result = exp_workflow.run()

    analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
    new_parameter_values = analysis_workflow_result.output["new_parameter_values"]
    if transition == 'ge':
        fitted_pi_amplitude = new_parameter_values[qubit_to_measure.uid]["ge_drive_amplitude_pi"]
    elif transition == 'ef':
        fitted_pi_amplitude = new_parameter_values[qubit_to_measure.uid]["ef_drive_amplitude_pi"]
    fitted_pi_amplitudes.append(fitted_pi_amplitude)

fitted_pi_amplitudes = np.array(fitted_pi_amplitudes)

# %% [markdown]
# #### Fit and Plot Amplitude vs. Drive Length

# %%
from uncertainties import unumpy as unp

x = (1 / drive_lengths).astype('float64')  # proxy for Rabi frequency scaling with drive length
y = unp.nominal_values(fitted_pi_amplitudes).astype('float64')

rabi_freq_calib_popt, rabi_freq_calib_pcov = np.polyfit(x, y, 1, cov=True)
rabi_slope, rabi_intercept = rabi_freq_calib_popt

print('Rabi amplitude-length slope:', rabi_slope)
print('Rabi amplitude-length intercept:', rabi_intercept)

fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(x * 1e-6, y, '.k')
ax.plot(x * 1e-6, np.polyval(rabi_freq_calib_popt, x), '-r')
ax.set_xlabel('1 / drive length (1/us)')
ax.set_ylabel(f'{transition} pi-pulse amplitude (a.u.)')
ax.set_title('Rabi frequency calibration')

figname = f'Rabi_freq_calib_{transition}_'
file_path = get_path_to_file(figname, '.png')
plt.savefig(file_path, dpi=600, format='png', metadata=None,
        bbox_inches=None, pad_inches=0.1,
        facecolor='auto', edgecolor='auto',
        backend=None,
       )

# %% [markdown]
# #### Save Data

# %%
Data_rabi_freq_calib = {
    'drive_lengths': drive_lengths,
    'fitted_pi_amplitudes': unp.nominal_values(fitted_pi_amplitudes).astype('float64'),
    'rabi_slope': rabi_slope,
    'rabi_intercept': rabi_intercept,
}

file_name = f'Rabi_freq_calib_{transition}_'
file_path = get_path_to_file(file_name, '.mat')
savemat(file_path, Data_rabi_freq_calib)

# %% [markdown]
# ### Rabi Error Amplification

# %% [markdown]
# #### x180 pulse

# %% [markdown]
# ##### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ef')

n_avg_exponent = 13

ef_drive_amplitude_pi = 0.6494061086341071

x180_max_repetitions = 16
x180_repetitions = list(range(0, x180_max_repetitions + 1))

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temp_pars.ef_drive_amplitude_pi = ef_drive_amplitude_pi
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# ##### Run Workflow

# %%
options = amplitude_fine.experiment_workflow_x180.options()
options.count(2**n_avg_exponent)
options.close_figures(False)

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

exp_workflow = amplitude_fine.experiment_workflow_x180(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    repetitions=[x180_repetitions for q in qubits_to_measure],
    options=options,
    temporary_parameters=temporary_parameters
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.31 11:45:44.861] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 11:45:44.862] INFO      Workflow 'experiment_workflow_x180': execution started at 2026-08-31
# [2026.08.31 11:45:44.862] INFO      08:45:44.860181Z
# [2026.08.31 11:45:44.862] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 11:45:45.249] INFO    Task 'temporary_qpu': started at 2026-08-31 08:45:45.249712Z
# [2026.08.31 11:45:45.285] INFO    Task 'temporary_qpu': ended at 2026-08-31 08:45:45.285965Z
# [2026.08.31 11:45:45.354] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 11:45:45.360] INFO    08:45:45.354202Z
# [2026.08.31 11:45:45.402] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 08:45:45.402090Z
# [2026.08.31 11:45:45.489] INFO    Task 'create_experiment': started at 2026-08-31 08:45:45.489025Z
# [2026.08.31 11:45:45.673] INFO    Task 'create_experiment': ended at 2026-08-31 08:45:45.673228Z
# [2026.08.31 11:45:45.750] INFO    Task 'compile_experiment': started at 2026-08-31 08:45:45.750613Z
# [2026.08.31 11:45:45.868] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 11:45:45.868] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.31 11:45:45.876] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.31 11:45:45.876] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.31 11:45:45.877] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.31 11:45:45.877] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.31 11:45:45.880] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.31 11:45:45.882] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.31 11:45:45.882] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.31 11:45:45.882] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.31 11:45:45.882] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.31 11:45:45.882] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.31 11:45:45.882] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.31 11:45:45.882] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.31 11:45:45.882] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.31 11:45:45.890] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.31 11:45:45.890] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.31 11:45:45.892] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 11:45:45.892] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 11:45:45.892] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 11:45:45.892] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 11:45:45.897] INFO    Schedule completed. [0.001 s]
# [2026.08.31 11:45:45.904] INFO    Code generation completed for all AWGs. [0.007 s]
# [2026.08.31 11:45:45.904] INFO    Completed compilation step 1 of 1. [0.010 s]
# [2026.08.31 11:45:45.908] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 11:45:45.912] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 11:45:45.915] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 11:45:45.915] INFO      SHFQC_DEV12192        0         80            0           1      7616
# [2026.08.31 11:45:45.915] INFO      SHFQC_DEV12192_sg     0        137            5           3      1856
# [2026.08.31 11:45:45.917] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 11:45:45.919] INFO      TOTAL                          217            5                  9472
# [2026.08.31 11:45:45.919] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 11:45:45.936] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 11:45:45.939] INFO    Task 'compile_experiment': ended at 2026-08-31 08:45:45.939004Z
# [2026.08.31 11:45:46.052] INFO    Task 'run_experiment': started at 2026-08-31 08:45:46.052875Z
# [2026.08.31 11:45:46.195] INFO    Starting near-time execution...
# [2026.08.31 11:45:46.266] INFO    Estimated RT execution time: 47.14 s.
# [2026.08.31 11:46:33.508] INFO    Finished near-time execution.
# [2026.08.31 11:46:33.604] INFO    Task 'run_experiment': ended at 2026-08-31 08:46:33.598208Z
# [2026.08.31 11:46:33.712] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 11:46:33.712] INFO      Workflow 'analysis_workflow': execution started at 2026-08-31
# [2026.08.31 11:46:33.716] INFO      08:46:33.712733Z
# [2026.08.31 11:46:33.716] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 11:46:33.828] INFO    Task 'calculate_qubit_population': started at 2026-08-31 08:46:33.828819Z
# [2026.08.31 11:46:33.898] INFO    Task 'calculate_qubit_population': ended at 2026-08-31 08:46:33.898512Z
# [2026.08.31 11:46:33.974] INFO    Task 'fit_data': started at 2026-08-31 08:46:33.974999Z
# [2026.08.31 11:46:34.100] INFO    Task 'fit_data': ended at 2026-08-31 08:46:34.100143Z
# [2026.08.31 11:46:34.199] INFO    Task 'process_fit_results': started at 2026-08-31 08:46:34.199026Z
# [2026.08.31 11:46:34.308] INFO    Task 'process_fit_results': ended at 2026-08-31 08:46:34.308012Z
# [2026.08.31 11:46:34.374] INFO    Task 'extract_qubit_parameters': started at 2026-08-31 08:46:34.374631Z
# [2026.08.31 11:46:34.485] INFO    Task 'extract_qubit_parameters': ended at 2026-08-31 08:46:34.485455Z
# [2026.08.31 11:46:34.564] INFO    Task 'xaxis_label': started at 2026-08-31 08:46:34.564209Z
# [2026.08.31 11:46:34.612] INFO    Task 'xaxis_label': ended at 2026-08-31 08:46:34.608932Z
# [2026.08.31 11:46:34.659] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-31 08:46:34.659284Z
# [2026.08.31 11:46:34.757] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-31 08:46:34.757370Z
# [2026.08.31 11:46:35.211] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-31 08:46:35.211053Z
# [2026.08.31 11:46:35.258] INFO    Task 'plot_population': started at 2026-08-31 08:46:35.258931Z
# [2026.08.31 11:46:35.398] INFO    Artifact: 'Amplitude_Fine_Q2' of type 'Figure' logged at 2026-08-31
# [2026.08.31 11:46:35.398] INFO    08:46:35.396133Z
# [2026.08.31 11:46:35.821] INFO    Task 'plot_population': ended at 2026-08-31 08:46:35.821604Z
# [2026.08.31 11:46:35.853] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 11:46:35.853] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-31 08:46:35.853424Z
# [2026.08.31 11:46:35.853] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 11:46:35.902] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 11:46:35.902] INFO      Workflow 'experiment_workflow_x180': execution ended at 2026-08-31
# [2026.08.31 11:46:35.902] INFO      08:46:35.902404Z
# [2026.08.31 11:46:35.902] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ##### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)

    amplitude_fine.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nDrive amplitude pi ge (error-amplified): ", qubit_to_measure.parameters.ge_drive_amplitude_pi)
    elif transition == 'ef':
        print("\nDrive amplitude pi ef (error-amplified): ", qubit_to_measure.parameters.ef_drive_amplitude_pi)
    
    print('\nUpdated global experiment parameters!\n')
# Out:
# {'new_parameter_values': {'Q2': {'ef_drive_amplitude_pi': 0.6507087790475553+/-0.009376519097039467}},
#  'old_parameter_values': {'Q2': {'ef_drive_amplitude_pi': 0.6494061086341071}}}
#
# Drive amplitude pi ef (error-amplified):  0.6507087790475553
#
# Updated global experiment parameters!

# %% [markdown]
# #### x90 pulse

# %% [markdown]
# ##### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ef')

n_avg_exponent = 13

ef_drive_amplitude_pi2 = 0.3099951813175842

x90_max_repetitions = 18
x90_repetitions = list(range(1, x90_max_repetitions + 1, 2))

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temp_pars.ef_drive_amplitude_pi2 = ef_drive_amplitude_pi2
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# ##### Run Workflow

# %%
options = amplitude_fine.experiment_workflow_x90.options()
options.count(2**n_avg_exponent)
options.close_figures(False)

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

exp_workflow = amplitude_fine.experiment_workflow_x90(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    repetitions=[x90_repetitions for q in qubits_to_measure],
    options=options,
    temporary_parameters=temporary_parameters
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.31 11:48:02.323] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 11:48:02.330] INFO      Workflow 'experiment_workflow_x90': execution started at 2026-08-31
# [2026.08.31 11:48:02.332] INFO      08:48:02.323307Z
# [2026.08.31 11:48:02.332] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 11:48:02.539] INFO    Task 'temporary_qpu': started at 2026-08-31 08:48:02.539603Z
# [2026.08.31 11:48:02.572] INFO    Task 'temporary_qpu': ended at 2026-08-31 08:48:02.572006Z
# [2026.08.31 11:48:02.656] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 11:48:02.656] INFO    08:48:02.656340Z
# [2026.08.31 11:48:02.686] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 08:48:02.686495Z
# [2026.08.31 11:48:02.763] INFO    Task 'create_experiment': started at 2026-08-31 08:48:02.763756Z
# [2026.08.31 11:48:02.876] INFO    Task 'create_experiment': ended at 2026-08-31 08:48:02.876211Z
# [2026.08.31 11:48:02.956] INFO    Task 'compile_experiment': started at 2026-08-31 08:48:02.956648Z
# [2026.08.31 11:48:03.037] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 11:48:03.037] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.31 11:48:03.050] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.31 11:48:03.050] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.31 11:48:03.053] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.31 11:48:03.053] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.31 11:48:03.055] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.31 11:48:03.056] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.31 11:48:03.056] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.31 11:48:03.058] WARNING Case does not support 'on_system_grid' — value will be ignored
# [2026.08.31 11:48:03.060] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 11:48:03.062] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 11:48:03.064] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 11:48:03.064] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 11:48:03.068] INFO    Schedule completed. [0.001 s]
# [2026.08.31 11:48:03.068] INFO    Code generation completed for all AWGs. [0.005 s]
# [2026.08.31 11:48:03.068] INFO    Completed compilation step 1 of 1. [0.010 s]
# [2026.08.31 11:48:03.089] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 11:48:03.089] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 11:48:03.089] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 11:48:03.096] INFO      SHFQC_DEV12192        0         48            0           1      7616
# [2026.08.31 11:48:03.096] INFO      SHFQC_DEV12192_sg     0         88            5           3      1856
# [2026.08.31 11:48:03.096] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 11:48:03.096] INFO      TOTAL                          136            5                  9472
# [2026.08.31 11:48:03.100] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 11:48:03.117] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 11:48:03.118] INFO    Task 'compile_experiment': ended at 2026-08-31 08:48:03.118935Z
# [2026.08.31 11:48:03.231] INFO    Task 'run_experiment': started at 2026-08-31 08:48:03.230002Z
# [2026.08.31 11:48:03.374] INFO    Starting near-time execution...
# [2026.08.31 11:48:03.453] INFO    Estimated RT execution time: 27.29 s.
# [2026.08.31 11:48:30.819] INFO    Finished near-time execution.
# [2026.08.31 11:48:30.899] INFO    Task 'run_experiment': ended at 2026-08-31 08:48:30.899608Z
# [2026.08.31 11:48:30.996] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 11:48:30.996] INFO      Workflow 'analysis_workflow': execution started at 2026-08-31
# [2026.08.31 11:48:30.996] INFO      08:48:30.996472Z
# [2026.08.31 11:48:31.012] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 11:48:31.142] INFO    Task 'calculate_qubit_population': started at 2026-08-31 08:48:31.142990Z
# [2026.08.31 11:48:31.227] INFO    Task 'calculate_qubit_population': ended at 2026-08-31 08:48:31.227169Z
# [2026.08.31 11:48:31.317] INFO    Task 'fit_data': started at 2026-08-31 08:48:31.316046Z
# [2026.08.31 11:48:31.449] INFO    Task 'fit_data': ended at 2026-08-31 08:48:31.449734Z
# [2026.08.31 11:48:31.547] INFO    Task 'process_fit_results': started at 2026-08-31 08:48:31.547429Z
# [2026.08.31 11:48:31.672] INFO    Task 'process_fit_results': ended at 2026-08-31 08:48:31.672694Z
# [2026.08.31 11:48:31.767] INFO    Task 'extract_qubit_parameters': started at 2026-08-31 08:48:31.767975Z
# [2026.08.31 11:48:31.897] INFO    Task 'extract_qubit_parameters': ended at 2026-08-31 08:48:31.897787Z
# [2026.08.31 11:48:31.992] INFO    Task 'xaxis_label': started at 2026-08-31 08:48:31.991563Z
# [2026.08.31 11:48:32.056] INFO    Task 'xaxis_label': ended at 2026-08-31 08:48:32.040547Z
# [2026.08.31 11:48:32.100] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-31 08:48:32.100602Z
# [2026.08.31 11:48:32.218] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-31 08:48:32.218697Z
# [2026.08.31 11:48:32.585] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-31 08:48:32.585258Z
# [2026.08.31 11:48:32.642] INFO    Task 'plot_population': started at 2026-08-31 08:48:32.642382Z
# [2026.08.31 11:48:32.781] INFO    Artifact: 'Amplitude_Fine_Q2' of type 'Figure' logged at 2026-08-31
# [2026.08.31 11:48:32.793] INFO    08:48:32.781147Z
# [2026.08.31 11:48:33.109] INFO    Task 'plot_population': ended at 2026-08-31 08:48:33.109786Z
# [2026.08.31 11:48:33.150] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 11:48:33.150] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-31 08:48:33.150694Z
# [2026.08.31 11:48:33.150] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 11:48:33.205] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 11:48:33.205] INFO      Workflow 'experiment_workflow_x90': execution ended at 2026-08-31
# [2026.08.31 11:48:33.205] INFO      08:48:33.205158Z
# [2026.08.31 11:48:33.212] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ##### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)



if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)
    
    amplitude_fine.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nDrive amplitude pi2 ge (error-amplified): ", qubit_to_measure.parameters.ge_drive_amplitude_pi2)
    elif transition == 'ef':
        print("\nDrive amplitude pi2 ef (error-amplified): ", qubit_to_measure.parameters.ef_drive_amplitude_pi2)
    
    print('\nUpdated global experiment parameters!\n')
# Out:
# {'new_parameter_values': {'Q2': {'ef_drive_amplitude_pi2': 0.3099951813175842+/-1639.3076476128492}},
#  'old_parameter_values': {'Q2': {'ef_drive_amplitude_pi2': 0.3099951813175842}}}
#
# Drive amplitude pi2 ef (error-amplified):  0.3099951813175842
#
# Updated global experiment parameters!

# %%
#qubits[0].parameters.ef_drive_amplitude_pi = 0.6494061086341071
#qubits[0].parameters.ef_drive_amplitude_pi2 = 0.3099951813175842

# %% [markdown]
# ### Ramsey

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

detuning = 1e6
transition = set_transition('ef')

n_avg_exponent = 13

delay_min = 0
delay_max = 10e-6
n_delay = 201

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = ramsey.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(False) # Plot figures

options.transition(transition)
options.cal_states(transition)

# Note: if neighbouring qubits are physically coupled by a resonator,
# you usually don't want to run Ramsey in parallel on them because
# your result will be skewed by strong residual-ZZ coupling.
# Next-nearest neighbours is typically okay.
# qubits_to_measure = [qubits[0], qubits[2]]
qubits_to_measure = [qubits[0]]

delays = [
    np.linspace(delay_min, delay_max, n_delay)
]
detunings = [
    detuning
]

exp_workflow = ramsey.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    delays=delays,
    detunings=detunings,
    options=options,
    temporary_parameters=temporary_parameters
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.31 15:40:05.075] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 15:40:05.075] INFO      Workflow 'ramsey': execution started at 2026-08-31 12:40:05.075423Z
# [2026.08.31 15:40:05.075] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 15:40:05.347] INFO    Task 'temporary_qpu': started at 2026-08-31 12:40:05.347265Z
# [2026.08.31 15:40:05.396] INFO    Task 'temporary_qpu': ended at 2026-08-31 12:40:05.396026Z
# [2026.08.31 15:40:05.492] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 15:40:05.492] INFO    12:40:05.492431Z
# [2026.08.31 15:40:05.540] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 12:40:05.540693Z
# [2026.08.31 15:40:05.635] INFO    Task 'create_experiment': started at 2026-08-31 12:40:05.635054Z
# [2026.08.31 15:40:05.798] INFO    Task 'create_experiment': ended at 2026-08-31 12:40:05.798073Z
# [2026.08.31 15:40:05.917] INFO    Task 'compile_experiment': started at 2026-08-31 12:40:05.917751Z
# [2026.08.31 15:40:06.011] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 15:40:06.011] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 15:40:06.011] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 15:40:06.011] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 15:40:06.021] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 15:40:06.032] INFO    Schedule completed. [0.012 s]
# [2026.08.31 15:40:06.057] INFO    Code generation completed for all AWGs. [0.020 s]
# [2026.08.31 15:40:06.059] INFO    Completed compilation step 1 of 1. [0.036 s]
# [2026.08.31 15:40:06.067] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 15:40:06.071] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 15:40:06.071] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 15:40:06.071] INFO      SHFQC_DEV12192        0        816            0           1      7616
# [2026.08.31 15:40:06.071] INFO      SHFQC_DEV12192_sg     0       1235           28           6      2528
# [2026.08.31 15:40:06.075] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 15:40:06.075] INFO      TOTAL                         2051           28                 10144
# [2026.08.31 15:40:06.075] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 15:40:06.150] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 15:40:06.150] INFO    Task 'compile_experiment': ended at 2026-08-31 12:40:06.150947Z
# [2026.08.31 15:40:06.311] INFO    Task 'run_experiment': started at 2026-08-31 12:40:06.311354Z
# [2026.08.31 15:40:06.453] INFO    Starting near-time execution...
# [2026.08.31 15:40:06.549] INFO    Estimated RT execution time: 510.91 s.
# [2026.08.31 15:48:37.539] INFO    Finished near-time execution.
# [2026.08.31 15:48:42.564] INFO    Task 'run_experiment': ended at 2026-08-31 12:48:42.564934Z
# [2026.08.31 15:48:42.693] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 15:48:42.693] INFO      Workflow 'analysis_workflow': execution started at 2026-08-31
# [2026.08.31 15:48:42.693] INFO      12:48:42.693056Z
# [2026.08.31 15:48:42.693] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 15:48:42.805] INFO    Task 'calculate_qubit_population': started at 2026-08-31 12:48:42.805088Z
# [2026.08.31 15:48:42.906] INFO    Task 'calculate_qubit_population': ended at 2026-08-31 12:48:42.906087Z
# [2026.08.31 15:48:43.023] INFO    Task 'fit_data': started at 2026-08-31 12:48:43.023293Z
# [2026.08.31 15:48:43.239] INFO    Task 'fit_data': ended at 2026-08-31 12:48:43.239854Z
# [2026.08.31 15:48:43.384] INFO    Task 'extract_qubit_parameters': started at 2026-08-31 12:48:43.384927Z
# [2026.08.31 15:48:43.554] INFO    Task 'extract_qubit_parameters': ended at 2026-08-31 12:48:43.554248Z
# [2026.08.31 15:48:43.667] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-31 12:48:43.658331Z
# [2026.08.31 15:48:43.833] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-31 12:48:43.833866Z
# [2026.08.31 15:48:44.221] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-31 12:48:44.221864Z
# [2026.08.31 15:48:44.271] INFO    Task 'plot_population': started at 2026-08-31 12:48:44.271169Z
# [2026.08.31 15:48:44.417] INFO    Artifact: 'Ramsey_Q2' of type 'Figure' logged at 2026-08-31 12:48:44.417977Z
# [2026.08.31 15:48:44.872] INFO    Task 'plot_population': ended at 2026-08-31 12:48:44.867381Z
# [2026.08.31 15:48:44.917] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 15:48:44.917] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-31 12:48:44.917916Z
# [2026.08.31 15:48:44.917] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 15:48:44.980] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 15:48:44.980] INFO      Workflow 'ramsey': execution ended at 2026-08-31 12:48:44.980269Z
# [2026.08.31 15:48:44.980] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)


if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)

    ramsey.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nge_T2_star: ", qubit_to_measure.parameters.ge_T2_star)
        print("resonance_frequency_ge: ", qubit_to_measure.parameters.resonance_frequency_ge)
    elif transition == 'ef':
        print("\nef_T2_star: ", qubit_to_measure.parameters.ef_T2_star)
        print("resonance_frequency_ef: ", qubit_to_measure.parameters.resonance_frequency_ef)
    
    print('\nUpdated global experiment parameters!\n')
# Out:
# {'new_parameter_values': {'Q2': {'ge_T2_star': 3.896923872925839e-06+/-1.2300944469069717e-07,
#                                  'resonance_frequency_ge': 4988698990.469763+/-1810.1946712154522}},
#  'old_parameter_values': {'Q2': {'ge_T2_star': 2.9402507472076067e-05,
#                                  'resonance_frequency_ge': 4995763781.449274}}}
#
# ge_T2_star:  3.896923872925839e-06
# resonance_frequency_ge:  4988698990.469763
#
# Updated global experiment parameters!

# %% [markdown]
# ### T1 Lifetime

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ef')

n_avg_exponent = 13

delay_min = 0
delay_max = 30e-6
n_delay = 51
log_spacing = True

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = lifetime_measurement.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(False) # Plot figures

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

if log_spacing:
    delays = [log_sweep_help(delay_min, delay_max, n_delay)]
else:
    delays = [np.linspace(delay_min, delay_max, n_delay)]

exp_workflow = lifetime_measurement.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    delays=delays,
    options=options,
    temporary_parameters=temporary_parameters 
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.31 13:24:34.505] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:24:34.505] INFO      Workflow 'lifetime_measurement': execution started at 2026-08-31
# [2026.08.31 13:24:34.505] INFO      10:24:34.502337Z
# [2026.08.31 13:24:34.511] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:24:35.592] INFO    Task 'temporary_qpu': started at 2026-08-31 10:24:35.592148Z
# [2026.08.31 13:24:35.720] INFO    Task 'temporary_qpu': ended at 2026-08-31 10:24:35.720658Z
# [2026.08.31 13:24:36.221] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 13:24:36.222] INFO    10:24:36.219990Z
# [2026.08.31 13:24:36.287] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 10:24:36.286365Z
# [2026.08.31 13:24:36.404] INFO    Task 'create_experiment': started at 2026-08-31 10:24:36.404625Z
# [2026.08.31 13:24:36.623] INFO    Task 'create_experiment': ended at 2026-08-31 10:24:36.623178Z
# [2026.08.31 13:24:36.885] INFO    Task 'compile_experiment': started at 2026-08-31 10:24:36.881840Z
# [2026.08.31 13:24:37.265] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 13:24:37.266] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 13:24:37.266] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 13:24:37.266] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 13:24:37.266] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 13:24:37.277] INFO    Schedule completed. [0.001 s]
# [2026.08.31 13:24:37.288] INFO    Code generation completed for all AWGs. [0.010 s]
# [2026.08.31 13:24:37.291] INFO    Completed compilation step 1 of 1. [0.015 s]
# [2026.08.31 13:24:37.296] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:24:37.297] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 13:24:37.297] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:24:37.300] INFO      SHFQC_DEV12192        0        216            0           1      7616
# [2026.08.31 13:24:37.301] INFO      SHFQC_DEV12192_sg     0        223            3           2      1408
# [2026.08.31 13:24:37.301] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:24:37.303] INFO      TOTAL                          439            3                  9024
# [2026.08.31 13:24:37.305] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:24:37.327] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 13:24:37.327] INFO    Task 'compile_experiment': ended at 2026-08-31 10:24:37.327622Z
# [2026.08.31 13:24:37.515] INFO    Task 'run_experiment': started at 2026-08-31 10:24:37.513583Z
# [2026.08.31 13:24:37.858] INFO    Starting near-time execution...
# [2026.08.31 13:24:37.946] INFO    Estimated RT execution time: 133.29 s.
# [2026.08.31 13:26:51.294] INFO    Finished near-time execution.
# [2026.08.31 13:26:51.397] INFO    Task 'run_experiment': ended at 2026-08-31 10:26:51.397551Z
# [2026.08.31 13:26:51.600] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:26:51.605] INFO      Workflow 'analysis_workflow': execution started at 2026-08-31
# [2026.08.31 13:26:51.608] INFO      10:26:51.600184Z
# [2026.08.31 13:26:51.608] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:26:52.378] INFO    Task 'calculate_qubit_population': started at 2026-08-31 10:26:52.378824Z
# [2026.08.31 13:26:52.492] INFO    Task 'calculate_qubit_population': ended at 2026-08-31 10:26:52.492557Z
# [2026.08.31 13:26:52.746] INFO    Task 'fit_data': started at 2026-08-31 10:26:52.746820Z
# [2026.08.31 13:26:53.392] INFO    Task 'fit_data': ended at 2026-08-31 10:26:53.375973Z
# [2026.08.31 13:26:53.487] INFO    Task 'extract_qubit_parameters': started at 2026-08-31 10:26:53.487811Z
# [2026.08.31 13:26:54.120] INFO    Task 'extract_qubit_parameters': ended at 2026-08-31 10:26:54.120713Z
# [2026.08.31 13:26:54.343] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-31 10:26:54.343671Z
# [2026.08.31 13:26:54.473] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-31 10:26:54.473998Z
# [2026.08.31 13:26:55.103] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-31 10:26:55.101192Z
# [2026.08.31 13:26:55.376] INFO    Task 'plot_population': started at 2026-08-31 10:26:55.376426Z
# [2026.08.31 13:26:55.582] INFO    Artifact: 'T1_Q2' of type 'Figure' logged at 2026-08-31 10:26:55.582774Z
# [2026.08.31 13:26:56.242] INFO    Task 'plot_population': ended at 2026-08-31 10:26:56.242221Z
# [2026.08.31 13:26:56.324] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:26:56.324] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-31 10:26:56.321602Z
# [2026.08.31 13:26:56.324] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:26:56.374] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:26:56.379] INFO      Workflow 'lifetime_measurement': execution ended at 2026-08-31
# [2026.08.31 13:26:56.379] INFO      10:26:56.374927Z
# [2026.08.31 13:26:56.384] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)

    lifetime_measurement.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nge_T1: ", qubit_to_measure.parameters.ge_T1)
    elif transition == 'ef':
        print("\nef_T1: ", qubit_to_measure.parameters.ef_T1)
    
    print('\nUpdated global experiment parameters!\n')
# Out:
# {'new_parameter_values': {'Q2': {'ef_T1': -1.4854255847467251e-05+/-1.2002898031980604e-06}},
#  'old_parameter_values': {'Q2': {'ef_T1': 3.823989734157484e-06}}}
#
# ef_T1:  -1.4854255847467251e-05
#
# Updated global experiment parameters!

# %% [markdown]
# ### DRAG Calibration

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ef')

# readout_range_out = -30

n_avg_exponent = 13

q_min = -0.1
q_max = 0.1
n_q = 51

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
# temp_pars.readout_range_out = readout_range_out
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = drag_q_scaling.experiment_workflow.options()
# options.update(True)  # updates the qubit parameter 'ge_drive_pulse["beta"]'
options.count(2**n_avg_exponent)
options.close_figures(False) # Plot figures

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubits[0]]

exp_workflow = drag_q_scaling.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    q_scalings=[np.linspace(q_min, q_max, n_q) for _ in qubits_to_measure],
    options=options,
    temporary_parameters=temporary_parameters,
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.31 13:31:25.965] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:31:25.965] INFO      Workflow 'drag_q_scaling': execution started at 2026-08-31 10:31:25.965987Z
# [2026.08.31 13:31:25.980] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:31:26.434] INFO    Task 'temporary_qpu': started at 2026-08-31 10:31:26.434445Z
# [2026.08.31 13:31:26.498] INFO    Task 'temporary_qpu': ended at 2026-08-31 10:31:26.498464Z
# [2026.08.31 13:31:26.666] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 13:31:26.666] INFO    10:31:26.666373Z
# [2026.08.31 13:31:26.751] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 10:31:26.735356Z
# [2026.08.31 13:31:26.927] INFO    Task 'create_experiment': started at 2026-08-31 10:31:26.915546Z
# [2026.08.31 13:31:27.123] INFO    Task 'create_experiment': ended at 2026-08-31 10:31:27.123975Z
# [2026.08.31 13:31:27.282] INFO    Task 'compile_experiment': started at 2026-08-31 10:31:27.282167Z
# [2026.08.31 13:31:27.445] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 13:31:27.449] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 13:31:27.449] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 13:31:27.452] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 13:31:27.452] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 13:31:27.459] INFO    Schedule completed. [0.002 s]
# [2026.08.31 13:31:27.492] INFO    Code generation completed for all AWGs. [0.047 s]
# [2026.08.31 13:31:27.508] INFO    Completed compilation step 1 of 1. [0.053 s]
# [2026.08.31 13:31:27.516] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:31:27.516] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 13:31:27.516] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:31:27.516] INFO      SHFQC_DEV12192        0         32            0           1      7616
# [2026.08.31 13:31:27.516] INFO      SHFQC_DEV12192_sg     0       1243          207         155     65056
# [2026.08.31 13:31:27.524] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:31:27.524] INFO      TOTAL                         1275          207                 72672
# [2026.08.31 13:31:27.527] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:31:27.590] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 13:31:27.590] INFO    Task 'compile_experiment': ended at 2026-08-31 10:31:27.590199Z
# [2026.08.31 13:31:27.817] INFO    Task 'run_experiment': started at 2026-08-31 10:31:27.817319Z
# [2026.08.31 13:31:28.039] INFO    Starting near-time execution...
# [2026.08.31 13:31:28.183] INFO    Estimated RT execution time: 383.92 s.
# [2026.08.31 13:37:52.168] INFO    Finished near-time execution.
# [2026.08.31 13:37:52.296] INFO    Task 'run_experiment': ended at 2026-08-31 10:37:52.296795Z
# [2026.08.31 13:37:52.537] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:37:52.539] INFO      Workflow 'analysis_workflow': execution started at 2026-08-31
# [2026.08.31 13:37:52.539] INFO      10:37:52.537728Z
# [2026.08.31 13:37:52.545] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:37:52.715] INFO    Task 'calculate_qubit_population_for_pulse_ids': started at 2026-08-31
# [2026.08.31 13:37:52.715] INFO    10:37:52.715325Z
# [2026.08.31 13:37:52.828] INFO    Task 'calculate_qubit_population_for_pulse_ids': ended at 2026-08-31
# [2026.08.31 13:37:52.828] INFO    10:37:52.828963Z
# [2026.08.31 13:37:53.007] INFO    Task 'fit_data': started at 2026-08-31 10:37:53.007614Z
# [2026.08.31 13:37:53.302] INFO    Task 'fit_data': ended at 2026-08-31 10:37:53.302658Z
# [2026.08.31 13:37:53.478] INFO    Task 'extract_qubit_parameters': started at 2026-08-31 10:37:53.478959Z
# [2026.08.31 13:37:53.727] INFO    Task 'extract_qubit_parameters': ended at 2026-08-31 10:37:53.725173Z
# [2026.08.31 13:37:53.890] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-31 10:37:53.890527Z
# [2026.08.31 13:37:54.066] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-31 10:37:54.066683Z
# [2026.08.31 13:37:54.809] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-31 10:37:54.808741Z
# [2026.08.31 13:37:54.870] INFO    Task 'plot_population': started at 2026-08-31 10:37:54.870861Z
# [2026.08.31 13:37:55.164] INFO    Artifact: 'Drag_q_scaling_Q2' of type 'Figure' logged at 2026-08-31
# [2026.08.31 13:37:55.167] INFO    10:37:55.164810Z
# [2026.08.31 13:37:55.690] INFO    Task 'plot_population': ended at 2026-08-31 10:37:55.690511Z
# [2026.08.31 13:37:55.765] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:37:55.765] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-31 10:37:55.765889Z
# [2026.08.31 13:37:55.771] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:37:55.836] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:37:55.851] INFO      Workflow 'drag_q_scaling': execution ended at 2026-08-31 10:37:55.836681Z
# [2026.08.31 13:37:55.852] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])

    drag_q_scaling.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nge_drive_pulse[beta]: ", qubit_to_measure.parameters.ge_drive_pulse["beta"])
    elif transition == 'ef':
        print("\nef_drive_pulse[beta]: ", qubit_to_measure.parameters.ef_drive_pulse["beta"])
    
    print('\nUpdated global experiment parameters!\n')
# Out:
# {'new_parameter_values': {'Q2': {'ef_drive_pulse.beta': 0.043192309135097876+/-0.048577857685799475}},
#  'old_parameter_values': {'Q2': {'ef_drive_pulse.beta': 0.08010717043720025}}}
#
# ef_drive_pulse[beta]:  0.043192309135097876
#
# Updated global experiment parameters!

# %% [markdown]
# ### Hahn-Echo

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ef')

n_avg_exponent = 13

delay_min = 0
delay_max = 10e-6
n_delay = 51
log_spacing = True

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
temporary_parameters[q.uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = echo.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(False)

options.transition(transition)
options.cal_states(transition)

# Note: if neighbouring qubits are physically coupled by a resonator,
# you usually don't want to run Echo in parallel on them because
# your result will be skewed by strong residual-ZZ coupling.
# Next-nearest neighbours is typically okay.
qubits_to_measure = [qubits[0]]

delays = [
    np.linspace(delay_min, delay_max, n_delay)
]

exp_workflow = echo.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q.uid for q in qubits_to_measure],
    delays=delays,
    options=options,
    temporary_parameters=temporary_parameters
)

workflow_result = exp_workflow.run()
# Out:
# [2026.08.31 13:37:57.432] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:37:57.432] INFO      Workflow 'echo': execution started at 2026-08-31 10:37:57.432840Z
# [2026.08.31 13:37:57.448] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:37:57.870] INFO    Task 'temporary_qpu': started at 2026-08-31 10:37:57.870061Z
# [2026.08.31 13:37:57.955] INFO    Task 'temporary_qpu': ended at 2026-08-31 10:37:57.955280Z
# [2026.08.31 13:37:58.091] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 13:37:58.091] INFO    10:37:58.091882Z
# [2026.08.31 13:37:58.158] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 10:37:58.158695Z
# [2026.08.31 13:37:58.305] INFO    Task 'create_experiment': started at 2026-08-31 10:37:58.305123Z
# [2026.08.31 13:37:58.545] INFO    Task 'create_experiment': ended at 2026-08-31 10:37:58.536050Z
# [2026.08.31 13:37:58.705] INFO    Task 'compile_experiment': started at 2026-08-31 10:37:58.705347Z
# [2026.08.31 13:37:58.892] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 13:37:58.896] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 13:37:58.896] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 13:37:58.899] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 13:37:58.899] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 13:37:58.903] INFO    Schedule completed. [0.001 s]
# [2026.08.31 13:37:58.915] INFO    Code generation completed for all AWGs. [0.008 s]
# [2026.08.31 13:37:58.915] INFO    Completed compilation step 1 of 1. [0.014 s]
# [2026.08.31 13:37:58.921] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:37:58.921] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 13:37:58.921] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:37:58.921] INFO      SHFQC_DEV12192        0        216            0           1      7616
# [2026.08.31 13:37:58.928] INFO      SHFQC_DEV12192_sg     0        433            7           5      3040
# [2026.08.31 13:37:58.928] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:37:58.930] INFO      TOTAL                          649            7                 10656
# [2026.08.31 13:37:58.930] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:37:58.956] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 13:37:58.963] INFO    Task 'compile_experiment': ended at 2026-08-31 10:37:58.956114Z
# [2026.08.31 13:37:59.156] INFO    Task 'run_experiment': started at 2026-08-31 10:37:59.156899Z
# [2026.08.31 13:37:59.434] INFO    Starting near-time execution...
# [2026.08.31 13:37:59.515] INFO    Estimated RT execution time: 133.40 s.
# [2026.08.31 13:40:12.987] INFO    Finished near-time execution.
# [2026.08.31 13:40:13.060] INFO    Task 'run_experiment': ended at 2026-08-31 10:40:13.060035Z
# [2026.08.31 13:40:13.202] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:40:13.202] INFO      Workflow 'analysis_workflow': execution started at 2026-08-31
# [2026.08.31 13:40:13.202] INFO      10:40:13.200956Z
# [2026.08.31 13:40:13.210] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:40:13.428] INFO    Task 'calculate_qubit_population': started at 2026-08-31 10:40:13.428040Z
# [2026.08.31 13:40:13.572] INFO    Task 'calculate_qubit_population': ended at 2026-08-31 10:40:13.572373Z
# [2026.08.31 13:40:13.752] INFO    Task 'fit_data': started at 2026-08-31 10:40:13.752988Z
# [2026.08.31 13:40:14.007] INFO    Task 'fit_data': ended at 2026-08-31 10:40:14.007452Z
# [2026.08.31 13:40:14.169] INFO    Task 'extract_qubit_parameters': started at 2026-08-31 10:40:14.169564Z
# [2026.08.31 13:40:14.443] INFO    Task 'extract_qubit_parameters': ended at 2026-08-31 10:40:14.443959Z
# [2026.08.31 13:40:14.586] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-31 10:40:14.586345Z
# [2026.08.31 13:40:14.837] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-31 10:40:14.837401Z
# [2026.08.31 13:40:15.262] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-31 10:40:15.262907Z
# [2026.08.31 13:40:15.327] INFO    Task 'plot_population': started at 2026-08-31 10:40:15.327860Z
# [2026.08.31 13:40:15.601] INFO    Artifact: 'T2_Q2' of type 'Figure' logged at 2026-08-31 10:40:15.601943Z
# [2026.08.31 13:40:16.052] INFO    Task 'plot_population': ended at 2026-08-31 10:40:16.052624Z
# [2026.08.31 13:40:16.138] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:40:16.138] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-31 10:40:16.138565Z
# [2026.08.31 13:40:16.138] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:40:16.234] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:40:16.234] INFO      Workflow 'echo': execution ended at 2026-08-31 10:40:16.234217Z
# [2026.08.31 13:40:16.234] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks["analysis_workflow"]
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)

    echo.update_qpu(qpu, qubit_parameters["new_parameter_values"])
    if transition == 'ge':
        print("\nge_T2: ", qubit_to_measure.parameters.ge_T2)
    elif transition == 'ef':
        print("\nef_T2: ", qubit_to_measure.parameters.ef_T2)
    
    print('\nUpdated global experiment parameters!\n')
# Out:
# {'new_parameter_values': {'Q2': {'ef_T2': 1.8708273053987378e-08+/-0.0015425231031124752}},
#  'old_parameter_values': {'Q2': {'ef_T2': 1.0727739619875858e-06}}}
#
# ef_T2:  1.8708273053987378e-08
#
# Updated global experiment parameters!

# %%
qpu.quantum_elements
# Out:
# [TunableTransmonQubit(
# │   uid='Q2',
# │   signals={
# │   │   'drive': 'q0/drive',
# │   │   'drive_ef': 'q0/drive_ef',
# │   │   'measure': 'q0/measure',
# │   │   'acquire': 'q0/acquire'
# │   },
# │   parameters=TunableTransmonQubitParameters(
# │   │   custom={},
# │   │   ge_T1=1.3645176509647932e-05,
# │   │   ge_T2=5.227829805594839e-06,
# │   │   ge_T2_star=8.607061549037454e-06,
# │   │   ef_T1=-1.4854255847467251e-05,
# │   │   ef_T2=1.8708273053987378e-08,
# │   │   ef_T2_star=1.574907620871535e-05,
# │   │   drive_lo_frequency=4800000000.0,
# │   │   readout_lo_frequency=6000000000.0,
# │   │   resonance_frequency_ge=5004729039.10699,
# │   │   resonance_frequency_ef=4813736214.210726,
# │   │   readout_resonator_frequency=np.float64(5959580000.0),
# │   │   ge_drive_amplitude_pi=0.1450703458642064,
# │   │   ge_drive_amplitude_pi2=0.07343142790133057,
# │   │   ge_drive_length=2.4457142857142856e-07,
# │   │   ge_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0.2413462769901743,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   ef_drive_amplitude_pi=0.06139719997191931,
# │   │   ef_drive_amplitude_pi2=0.035333300376113264,
# │   │   ef_drive_length=1e-07,
# │   │   ef_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0.043192309135097876,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   qubit_resonator_coupling_strength_g=0,
# │   │   ge_chi_shift=0,
# │   │   readout_amplitude=0.25,
# │   │   readout_length=1.9e-06,
# │   │   readout_pulse={
# │   │   │   'function': 'gaussian_square',
# │   │   │   'width': 1.7599999999999999e-06
# │   │   },
# │   │   readout_integration_length=1.9e-06,
# │   │   readout_integration_delay=6.000000000000001e-08,
# │   │   readout_integration_kernels_type='default',
# │   │   readout_integration_kernels=None,
# │   │   readout_integration_discrimination_thresholds=None,
# │   │   reset_delay_length=0.0003,
# │   │   drive_range=0,
# │   │   readout_range_out=-20,
# │   │   readout_range_in=-40,
# │   │   flux_range=5,
# │   │   spectroscopy_length=2e-05,
# │   │   spectroscopy_amplitude=0.4,
# │   │   spectroscopy_pulse={
# │   │   │   'function': 'const',
# │   │   │   'can_compress': True
# │   │   },
# │   │   dc_slot=0,
# │   │   dc_voltage_parking=0.0,
# │   │   flux_offset_voltage=0.0,
# │   │   user_defined={}
# │   )
# )
# ]

# %% [markdown]
# # Readout Optimisation

# %% [markdown]
# Optimization of the readout pulse amplitude and of the readout (resonator)
# frequency.
#
# 1. **Readout Amplitude Optimization** — sweep the readout amplitude and run an
#    amplitude-Rabi experiment at each amplitude. The readout amplitude with the
#    smallest relative Rabi-fit errors gives the best signal-to-noise ratio.
# 2. **Dispersive Shift** — resonator spectroscopy with the qubit prepared in
#    g, e (and f). The optimal readout frequency is the frequency of the largest
#    distance between the transmission signals of the different states.
# 3. **Readout Settings Summary** — write the optimized readout parameters into
#    the QPU and save them.

# %% [markdown]
# ## Readout Amplitude Optimisation

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

transition = set_transition('ge')

n_avg_exponent = 13

# readout setting used during the sweep
readout_range_out = -20
readout_range_in = -40
readout_length = 2.0e-6
readout_integration_length = 2.0e-6
readout_integration_delay = 81e-9
reset_delay_length = 300e-6

# length and amplitude are taken from readout_length / readout_amplitude
readout_pulse = {
    'function': 'gaussian_square',
    'width': readout_length * 0.88,
}

# readout amplitude sweep
ro_amp_min = 0.0
ro_amp_max = 1.0
n_ro_amp = 21
ro_amp_arr = np.linspace(ro_amp_min, ro_amp_max, n_ro_amp)

# rabi sweep used to benchmark each readout amplitude
drive_range = 0
amp_min = 0
amp_max = 1
n_amp = 21
drive_amplitudes = np.linspace(amp_min, amp_max, n_amp)

qubit_to_measure = qubits[0]

# %% [markdown]
# #### Run Workflow

# %%
options = amplitude_rabi.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.update(False) # never update the qubit parameters during the sweep
options.close_figures(True) # one Rabi figure per readout amplitude

options.transition(transition)
options.cal_states(transition)

qubits_to_measure = [qubit_to_measure]

rabi_ro_sweep_results = []
fit_values_ro_sweep = []
fit_errors_ro_sweep = []
# same order as the old popt/pcov of fit_Rabi
fit_parameter_names = ['frequency', 'phase', 'amplitude', 'offset']

for ro_amp in ro_amp_arr:
    print('Measure at readout amplitude:', round(ro_amp, 5))

    temporary_parameters = {}
    temp_pars = deepcopy(qubits[0].parameters)
    temp_pars.readout_amplitude = round(ro_amp, 5)
    temp_pars.readout_length = readout_length
    temp_pars.readout_pulse = readout_pulse
    temp_pars.readout_integration_length = readout_integration_length
    temp_pars.readout_integration_delay = readout_integration_delay
    temp_pars.readout_range_out = readout_range_out
    temp_pars.readout_range_in = readout_range_in
    temp_pars.reset_delay_length = reset_delay_length
    temp_pars.drive_range = drive_range
    temporary_parameters[qubit_to_measure.uid] = temp_pars

    exp_workflow = amplitude_rabi.experiment_workflow(
        session=session,
        qpu=qpu,
        qubits=[q.uid for q in qubits_to_measure],
        amplitudes=[drive_amplitudes for q in qubits_to_measure],
        options=options,
        temporary_parameters=temporary_parameters,
    )
    workflow_result = exp_workflow.run()
    rabi_ro_sweep_results.append(workflow_result)

    # rotates/projects the raw data and fits a cosine model to the population
    fit_results = get_analysis_task_output(workflow_result, 'fit_data')
    fit_res = fit_results.get(qubit_to_measure.uid)
    if fit_res is None:
        print(f'  Rabi fit failed at readout amplitude {round(ro_amp, 5)}.')
        fit_values_ro_sweep.append([np.nan] * len(fit_parameter_names))
        fit_errors_ro_sweep.append([np.nan] * len(fit_parameter_names))
        continue

    fit_values_ro_sweep.append([fit_res.params[p].value for p in fit_parameter_names])
    fit_errors_ro_sweep.append([fit_res.params[p].stderr for p in fit_parameter_names])

popt_rabi_arr = np.array(fit_values_ro_sweep, dtype=float)
err_arr = np.array(fit_errors_ro_sweep, dtype=float)
# Out:
# Measure at readout amplitude: 0.0
# [2026.08.28 11:28:31.836] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:28:31.836] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-28 08:28:31.836598Z
# [2026.08.28 11:28:31.836] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:28:32.160] INFO    Task 'temporary_qpu': started at 2026-08-28 08:28:32.160328Z
# [2026.08.28 11:28:32.203] INFO    Task 'temporary_qpu': ended at 2026-08-28 08:28:32.203589Z
# [2026.08.28 11:28:32.296] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-28
# [2026.08.28 11:28:32.312] INFO    08:28:32.296130Z
# [2026.08.28 11:28:32.384] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-28 08:28:32.379391Z
# [2026.08.28 11:28:32.495] INFO    Task 'create_experiment': started at 2026-08-28 08:28:32.495066Z
# [2026.08.28 11:28:32.632] INFO    Task 'create_experiment': ended at 2026-08-28 08:28:32.628683Z
# [2026.08.28 11:28:32.764] INFO    Task 'compile_experiment': started at 2026-08-28 08:28:32.764075Z
# [2026.08.28 11:28:32.858] INFO    Starting LabOne Q Compiler run...
# [2026.08.28 11:28:32.859] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.28 11:28:32.859] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.28 11:28:32.859] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.28 11:28:32.859] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.28 11:28:32.862] INFO    Schedule completed. [0.000 s]
# [2026.08.28 11:28:32.867] INFO    Code generation completed for all AWGs. [0.003 s]
# [2026.08.28 11:28:32.869] INFO    Completed compilation step 1 of 1. [0.006 s]
# [2026.08.28 11:28:32.875] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:28:32.876] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.28 11:28:32.876] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:28:32.876] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.28 11:28:32.876] INFO      SHFQC_DEV12192_sg     0         79           23           2       832
# [2026.08.28 11:28:32.880] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:28:32.880] INFO      TOTAL                          100           23                  8832
# [2026.08.28 11:28:32.880] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:28:32.890] INFO    Finished LabOne Q Compiler run.
# [2026.08.28 11:28:32.895] INFO    Task 'compile_experiment': ended at 2026-08-28 08:28:32.895025Z
# [2026.08.28 11:28:33.003] INFO    Task 'run_experiment': started at 2026-08-28 08:28:33.003055Z
# [2026.08.28 11:28:33.147] INFO    Starting near-time execution...
# [2026.08.28 11:28:33.227] INFO    Estimated RT execution time: 56.92 s.
# [2026.08.28 11:29:30.209] INFO    Finished near-time execution.
# [2026.08.28 11:29:30.253] INFO    Task 'run_experiment': ended at 2026-08-28 08:29:30.253841Z
# [2026.08.28 11:29:30.366] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:29:30.366] INFO      Workflow 'analysis_workflow': execution started at 2026-08-28
# [2026.08.28 11:29:30.366] INFO      08:29:30.366223Z
# [2026.08.28 11:29:30.366] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:29:30.462] INFO    Task 'calculate_qubit_population': started at 2026-08-28 08:29:30.462458Z
# [2026.08.28 11:29:30.542] INFO    Task 'calculate_qubit_population': ended at 2026-08-28 08:29:30.542551Z
# [2026.08.28 11:29:30.623] INFO    Task 'fit_data': started at 2026-08-28 08:29:30.623939Z
# [2026.08.28 11:29:30.756] INFO    Task 'fit_data': ended at 2026-08-28 08:29:30.756479Z
# [2026.08.28 11:29:30.841] INFO    Task 'extract_qubit_parameters': started at 2026-08-28 08:29:30.841547Z
# [2026.08.28 11:29:30.984] INFO    Task 'extract_qubit_parameters': ended at 2026-08-28 08:29:30.984547Z
# [2026.08.28 11:29:31.082] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-28 08:29:31.082191Z
# [2026.08.28 11:29:31.183] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-28 08:29:31.183998Z
# [2026.08.28 11:29:31.625] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-28 08:29:31.625094Z
# [2026.08.28 11:29:31.676] INFO    Task 'plot_population': started at 2026-08-28 08:29:31.676402Z
# [2026.08.28 11:29:31.867] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-28 08:29:31.867999Z
# [2026.08.28 11:29:32.246] INFO    Task 'plot_population': ended at 2026-08-28 08:29:32.246015Z
# [2026.08.28 11:29:32.295] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:29:32.298] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-28 08:29:32.295767Z
# [2026.08.28 11:29:32.298] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:29:32.342] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:29:32.342] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-28 08:29:32.342055Z
# [2026.08.28 11:29:32.342] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measure at readout amplitude: 0.05
# [2026.08.28 11:29:32.502] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:29:32.502] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-28 08:29:32.502404Z
# [2026.08.28 11:29:32.502] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:29:32.862] INFO    Task 'temporary_qpu': started at 2026-08-28 08:29:32.862865Z
# [2026.08.28 11:29:32.933] INFO    Task 'temporary_qpu': ended at 2026-08-28 08:29:32.923240Z
# [2026.08.28 11:29:32.999] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-28
# [2026.08.28 11:29:32.999] INFO    08:29:32.999490Z
# [2026.08.28 11:29:33.048] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-28 08:29:33.048285Z
# [2026.08.28 11:29:33.142] INFO    Task 'create_experiment': started at 2026-08-28 08:29:33.142698Z
# [2026.08.28 11:29:33.270] INFO    Task 'create_experiment': ended at 2026-08-28 08:29:33.270732Z
# [2026.08.28 11:29:33.359] INFO    Task 'compile_experiment': started at 2026-08-28 08:29:33.359630Z
# [2026.08.28 11:29:33.459] INFO    Starting LabOne Q Compiler run...
# [2026.08.28 11:29:33.464] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.28 11:29:33.464] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.28 11:29:33.466] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.28 11:29:33.466] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.28 11:29:33.466] INFO    Schedule completed. [0.000 s]
# [2026.08.28 11:29:33.466] INFO    Code generation completed for all AWGs. [0.003 s]
# [2026.08.28 11:29:33.466] INFO    Completed compilation step 1 of 1. [0.006 s]
# [2026.08.28 11:29:33.479] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:29:33.479] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.28 11:29:33.479] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:29:33.485] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.28 11:29:33.485] INFO      SHFQC_DEV12192_sg     0         79           23           2       832
# [2026.08.28 11:29:33.485] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:29:33.485] INFO      TOTAL                          100           23                  8832
# [2026.08.28 11:29:33.485] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:29:33.495] INFO    Finished LabOne Q Compiler run.
# [2026.08.28 11:29:33.495] INFO    Task 'compile_experiment': ended at 2026-08-28 08:29:33.495440Z
# [2026.08.28 11:29:33.638] INFO    Task 'run_experiment': started at 2026-08-28 08:29:33.638987Z
# [2026.08.28 11:29:33.769] INFO    Starting near-time execution...
# [2026.08.28 11:29:33.844] INFO    Estimated RT execution time: 56.92 s.
# [2026.08.28 11:30:30.837] INFO    Finished near-time execution.
# [2026.08.28 11:30:30.914] INFO    Task 'run_experiment': ended at 2026-08-28 08:30:30.914216Z
# [2026.08.28 11:30:31.008] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:30:31.024] INFO      Workflow 'analysis_workflow': execution started at 2026-08-28
# [2026.08.28 11:30:31.024] INFO      08:30:31.008599Z
# [2026.08.28 11:30:31.024] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:30:31.162] INFO    Task 'calculate_qubit_population': started at 2026-08-28 08:30:31.162649Z
# [2026.08.28 11:30:31.270] INFO    Task 'calculate_qubit_population': ended at 2026-08-28 08:30:31.270675Z
# [2026.08.28 11:30:31.362] INFO    Task 'fit_data': started at 2026-08-28 08:30:31.362707Z
# [2026.08.28 11:30:31.490] INFO    Task 'fit_data': ended at 2026-08-28 08:30:31.490385Z
# [2026.08.28 11:30:31.575] INFO    Task 'extract_qubit_parameters': started at 2026-08-28 08:30:31.575922Z
# [2026.08.28 11:30:31.723] INFO    Task 'extract_qubit_parameters': ended at 2026-08-28 08:30:31.715334Z
# [2026.08.28 11:30:31.796] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-28 08:30:31.796423Z
# [2026.08.28 11:30:31.921] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-28 08:30:31.919980Z
# [2026.08.28 11:30:32.308] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-28 08:30:32.308564Z
# [2026.08.28 11:30:32.364] INFO    Task 'plot_population': started at 2026-08-28 08:30:32.364378Z
# [2026.08.28 11:30:32.500] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-28 08:30:32.500482Z
# [2026.08.28 11:30:32.936] INFO    Task 'plot_population': ended at 2026-08-28 08:30:32.936452Z
# [2026.08.28 11:30:32.981] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:30:32.981] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-28 08:30:32.981300Z
# [2026.08.28 11:30:32.981] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:30:33.045] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:30:33.045] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-28 08:30:33.045642Z
# [2026.08.28 11:30:33.045] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measure at readout amplitude: 0.1
# [2026.08.28 11:30:33.208] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:30:33.208] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-28 08:30:33.208843Z
# [2026.08.28 11:30:33.222] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:30:33.470] INFO    Task 'temporary_qpu': started at 2026-08-28 08:30:33.470864Z
# [2026.08.28 11:30:33.534] INFO    Task 'temporary_qpu': ended at 2026-08-28 08:30:33.534544Z
# [2026.08.28 11:30:33.607] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-28
# [2026.08.28 11:30:33.607] INFO    08:30:33.607748Z
# [2026.08.28 11:30:33.669] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-28 08:30:33.669413Z
# [2026.08.28 11:30:33.752] INFO    Task 'create_experiment': started at 2026-08-28 08:30:33.752636Z
# [2026.08.28 11:30:33.866] INFO    Task 'create_experiment': ended at 2026-08-28 08:30:33.866545Z
# [2026.08.28 11:30:33.966] INFO    Task 'compile_experiment': started at 2026-08-28 08:30:33.966854Z
# [2026.08.28 11:30:34.042] INFO    Starting LabOne Q Compiler run...
# [2026.08.28 11:30:34.042] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.28 11:30:34.042] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.28 11:30:34.042] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.28 11:30:34.042] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.28 11:30:34.042] INFO    Schedule completed. [0.000 s]
# [2026.08.28 11:30:34.058] INFO    Code generation completed for all AWGs. [0.003 s]
# [2026.08.28 11:30:34.058] INFO    Completed compilation step 1 of 1. [0.007 s]
# [2026.08.28 11:30:34.074] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:30:34.074] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.28 11:30:34.074] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:30:34.074] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.28 11:30:34.074] INFO      SHFQC_DEV12192_sg     0         79           23           2       832
# [2026.08.28 11:30:34.074] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:30:34.074] INFO      TOTAL                          100           23                  8832
# [2026.08.28 11:30:34.074] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:30:34.101] INFO    Finished LabOne Q Compiler run.
# [2026.08.28 11:30:34.104] INFO    Task 'compile_experiment': ended at 2026-08-28 08:30:34.104872Z
# [2026.08.28 11:30:34.207] INFO    Task 'run_experiment': started at 2026-08-28 08:30:34.207808Z
# [2026.08.28 11:30:34.366] INFO    Starting near-time execution...
# [2026.08.28 11:30:34.435] INFO    Estimated RT execution time: 56.92 s.
# [2026.08.28 11:31:31.428] INFO    Finished near-time execution.
# [2026.08.28 11:31:31.503] INFO    Task 'run_experiment': ended at 2026-08-28 08:31:31.503697Z
# [2026.08.28 11:31:31.600] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:31:31.600] INFO      Workflow 'analysis_workflow': execution started at 2026-08-28
# [2026.08.28 11:31:31.600] INFO      08:31:31.600699Z
# [2026.08.28 11:31:31.600] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:31:31.677] INFO    Task 'calculate_qubit_population': started at 2026-08-28 08:31:31.677563Z
# [2026.08.28 11:31:31.762] INFO    Task 'calculate_qubit_population': ended at 2026-08-28 08:31:31.762217Z
# [2026.08.28 11:31:31.854] INFO    Task 'fit_data': started at 2026-08-28 08:31:31.854830Z
# [2026.08.28 11:31:31.996] INFO    Task 'fit_data': ended at 2026-08-28 08:31:31.996230Z
# [2026.08.28 11:31:32.076] INFO    Task 'extract_qubit_parameters': started at 2026-08-28 08:31:32.076424Z
# [2026.08.28 11:31:32.206] INFO    Task 'extract_qubit_parameters': ended at 2026-08-28 08:31:32.206842Z
# [2026.08.28 11:31:32.285] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-28 08:31:32.285561Z
# [2026.08.28 11:31:32.430] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-28 08:31:32.430061Z
# [2026.08.28 11:31:32.818] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-28 08:31:32.818244Z
# [2026.08.28 11:31:32.873] INFO    Task 'plot_population': started at 2026-08-28 08:31:32.873240Z
# [2026.08.28 11:31:33.028] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-28 08:31:33.028060Z
# [2026.08.28 11:31:33.362] INFO    Task 'plot_population': ended at 2026-08-28 08:31:33.362769Z
# [2026.08.28 11:31:33.433] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:31:33.435] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-28 08:31:33.433905Z
# [2026.08.28 11:31:33.435] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:31:33.475] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:31:33.475] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-28 08:31:33.475447Z
# [2026.08.28 11:31:33.475] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measure at readout amplitude: 0.15
# [2026.08.28 11:31:33.667] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:31:33.667] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-28 08:31:33.667724Z
# [2026.08.28 11:31:33.667] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:31:33.900] INFO    Task 'temporary_qpu': started at 2026-08-28 08:31:33.900155Z
# [2026.08.28 11:31:33.940] INFO    Task 'temporary_qpu': ended at 2026-08-28 08:31:33.940826Z
# [2026.08.28 11:31:34.024] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-28
# [2026.08.28 11:31:34.024] INFO    08:31:34.018356Z
# [2026.08.28 11:31:34.067] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-28 08:31:34.067523Z
# [2026.08.28 11:31:34.167] INFO    Task 'create_experiment': started at 2026-08-28 08:31:34.167873Z
# [2026.08.28 11:31:34.294] INFO    Task 'create_experiment': ended at 2026-08-28 08:31:34.294608Z
# [2026.08.28 11:31:34.390] INFO    Task 'compile_experiment': started at 2026-08-28 08:31:34.390234Z
# [2026.08.28 11:31:34.497] INFO    Starting LabOne Q Compiler run...
# [2026.08.28 11:31:34.498] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.28 11:31:34.499] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.28 11:31:34.499] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.28 11:31:34.501] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.28 11:31:34.502] INFO    Schedule completed. [0.000 s]
# [2026.08.28 11:31:34.505] INFO    Code generation completed for all AWGs. [0.006 s]
# [2026.08.28 11:31:34.505] INFO    Completed compilation step 1 of 1. [0.010 s]
# [2026.08.28 11:31:34.521] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:31:34.525] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.28 11:31:34.527] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:31:34.529] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.28 11:31:34.530] INFO      SHFQC_DEV12192_sg     0         79           23           2       832
# [2026.08.28 11:31:34.530] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:31:34.530] INFO      TOTAL                          100           23                  8832
# [2026.08.28 11:31:34.530] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:31:34.542] INFO    Finished LabOne Q Compiler run.
# [2026.08.28 11:31:34.544] INFO    Task 'compile_experiment': ended at 2026-08-28 08:31:34.544583Z
# [2026.08.28 11:31:34.627] INFO    Task 'run_experiment': started at 2026-08-28 08:31:34.627372Z
# [2026.08.28 11:31:34.785] INFO    Starting near-time execution...
# [2026.08.28 11:31:34.883] INFO    Estimated RT execution time: 56.92 s.
# [2026.08.28 11:32:31.878] INFO    Finished near-time execution.
# [2026.08.28 11:32:31.950] INFO    Task 'run_experiment': ended at 2026-08-28 08:32:31.950891Z
# [2026.08.28 11:32:32.054] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:32:32.054] INFO      Workflow 'analysis_workflow': execution started at 2026-08-28
# [2026.08.28 11:32:32.054] INFO      08:32:32.054577Z
# [2026.08.28 11:32:32.054] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:32:32.184] INFO    Task 'calculate_qubit_population': started at 2026-08-28 08:32:32.183558Z
# [2026.08.28 11:32:32.274] INFO    Task 'calculate_qubit_population': ended at 2026-08-28 08:32:32.274741Z
# [2026.08.28 11:32:32.367] INFO    Task 'fit_data': started at 2026-08-28 08:32:32.367859Z
# [2026.08.28 11:32:32.504] INFO    Task 'fit_data': ended at 2026-08-28 08:32:32.504077Z
# [2026.08.28 11:32:32.593] INFO    Task 'extract_qubit_parameters': started at 2026-08-28 08:32:32.593133Z
# [2026.08.28 11:32:32.727] INFO    Task 'extract_qubit_parameters': ended at 2026-08-28 08:32:32.727124Z
# [2026.08.28 11:32:32.823] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-28 08:32:32.823535Z
# [2026.08.28 11:32:32.980] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-28 08:32:32.980441Z
# [2026.08.28 11:32:33.725] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-28 08:32:33.725061Z
# [2026.08.28 11:32:33.789] INFO    Task 'plot_population': started at 2026-08-28 08:32:33.789864Z
# [2026.08.28 11:32:33.934] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-28 08:32:33.934866Z
# [2026.08.28 11:32:34.240] INFO    Task 'plot_population': ended at 2026-08-28 08:32:34.240684Z
# [2026.08.28 11:32:34.272] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:32:34.272] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-28 08:32:34.272127Z
# [2026.08.28 11:32:34.272] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:32:34.304] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:32:34.304] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-28 08:32:34.304747Z
# [2026.08.28 11:32:34.318] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measure at readout amplitude: 0.2
# [2026.08.28 11:32:34.440] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:32:34.440] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-28 08:32:34.440105Z
# [2026.08.28 11:32:34.440] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:32:34.688] INFO    Task 'temporary_qpu': started at 2026-08-28 08:32:34.688279Z
# [2026.08.28 11:32:34.737] INFO    Task 'temporary_qpu': ended at 2026-08-28 08:32:34.737305Z
# [2026.08.28 11:32:34.827] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-28
# [2026.08.28 11:32:34.827] INFO    08:32:34.827447Z
# [2026.08.28 11:32:34.885] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-28 08:32:34.885863Z
# [2026.08.28 11:32:34.984] INFO    Task 'create_experiment': started at 2026-08-28 08:32:34.984222Z
# [2026.08.28 11:32:35.137] INFO    Task 'create_experiment': ended at 2026-08-28 08:32:35.137903Z
# [2026.08.28 11:32:35.231] INFO    Task 'compile_experiment': started at 2026-08-28 08:32:35.231540Z
# [2026.08.28 11:32:35.317] INFO    Starting LabOne Q Compiler run...
# [2026.08.28 11:32:35.317] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.28 11:32:35.317] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.28 11:32:35.317] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.28 11:32:35.329] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.28 11:32:35.331] INFO    Schedule completed. [0.000 s]
# [2026.08.28 11:32:35.336] INFO    Code generation completed for all AWGs. [0.003 s]
# [2026.08.28 11:32:35.336] INFO    Completed compilation step 1 of 1. [0.007 s]
# [2026.08.28 11:32:35.345] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:32:35.345] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.28 11:32:35.345] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:32:35.345] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.28 11:32:35.345] INFO      SHFQC_DEV12192_sg     0         79           23           2       832
# [2026.08.28 11:32:35.345] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:32:35.345] INFO      TOTAL                          100           23                  8832
# [2026.08.28 11:32:35.356] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:32:35.367] INFO    Finished LabOne Q Compiler run.
# [2026.08.28 11:32:35.369] INFO    Task 'compile_experiment': ended at 2026-08-28 08:32:35.367745Z
# [2026.08.28 11:32:35.473] INFO    Task 'run_experiment': started at 2026-08-28 08:32:35.473771Z
# [2026.08.28 11:32:35.633] INFO    Starting near-time execution...
# [2026.08.28 11:32:35.724] INFO    Estimated RT execution time: 56.92 s.
# [2026.08.28 11:33:32.704] INFO    Finished near-time execution.
# [2026.08.28 11:33:32.784] INFO    Task 'run_experiment': ended at 2026-08-28 08:33:32.784815Z
# [2026.08.28 11:33:32.918] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:33:32.918] INFO      Workflow 'analysis_workflow': execution started at 2026-08-28
# [2026.08.28 11:33:32.918] INFO      08:33:32.918386Z
# [2026.08.28 11:33:32.918] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:33:33.035] INFO    Task 'calculate_qubit_population': started at 2026-08-28 08:33:33.035421Z
# [2026.08.28 11:33:33.129] INFO    Task 'calculate_qubit_population': ended at 2026-08-28 08:33:33.129852Z
# [2026.08.28 11:33:33.217] INFO    Task 'fit_data': started at 2026-08-28 08:33:33.217950Z
# [2026.08.28 11:33:33.334] INFO    Task 'fit_data': ended at 2026-08-28 08:33:33.334697Z
# [2026.08.28 11:33:33.437] INFO    Task 'extract_qubit_parameters': started at 2026-08-28 08:33:33.437146Z
# [2026.08.28 11:33:33.554] INFO    Task 'extract_qubit_parameters': ended at 2026-08-28 08:33:33.554702Z
# [2026.08.28 11:33:33.651] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-28 08:33:33.651496Z
# [2026.08.28 11:33:33.763] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-28 08:33:33.763103Z
# [2026.08.28 11:33:34.094] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-28 08:33:34.094890Z
# [2026.08.28 11:33:34.132] INFO    Task 'plot_population': started at 2026-08-28 08:33:34.132961Z
# [2026.08.28 11:33:34.234] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-28 08:33:34.234920Z
# [2026.08.28 11:33:34.633] INFO    Task 'plot_population': ended at 2026-08-28 08:33:34.633902Z
# [2026.08.28 11:33:34.668] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:33:34.668] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-28 08:33:34.668131Z
# [2026.08.28 11:33:34.668] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:33:34.714] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:33:34.714] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-28 08:33:34.714387Z
# [2026.08.28 11:33:34.714] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measure at readout amplitude: 0.25
# [2026.08.28 11:33:34.868] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:33:34.868] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-28 08:33:34.868321Z
# [2026.08.28 11:33:34.868] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:33:35.114] INFO    Task 'temporary_qpu': started at 2026-08-28 08:33:35.114085Z
# [2026.08.28 11:33:35.162] INFO    Task 'temporary_qpu': ended at 2026-08-28 08:33:35.162003Z
# [2026.08.28 11:33:35.256] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-28
# [2026.08.28 11:33:35.258] INFO    08:33:35.244116Z
# [2026.08.28 11:33:35.290] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-28 08:33:35.290024Z
# [2026.08.28 11:33:35.386] INFO    Task 'create_experiment': started at 2026-08-28 08:33:35.386310Z
# [2026.08.28 11:33:35.544] INFO    Task 'create_experiment': ended at 2026-08-28 08:33:35.543391Z
# [2026.08.28 11:33:35.645] INFO    Task 'compile_experiment': started at 2026-08-28 08:33:35.643769Z
# [2026.08.28 11:33:35.745] INFO    Starting LabOne Q Compiler run...
# [2026.08.28 11:33:35.751] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.28 11:33:35.751] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.28 11:33:35.756] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.28 11:33:35.756] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.28 11:33:35.762] INFO    Schedule completed. [0.001 s]
# [2026.08.28 11:33:35.772] INFO    Code generation completed for all AWGs. [0.007 s]
# [2026.08.28 11:33:35.773] INFO    Completed compilation step 1 of 1. [0.012 s]
# [2026.08.28 11:33:35.778] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:33:35.778] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.28 11:33:35.778] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:33:35.778] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.28 11:33:35.786] INFO      SHFQC_DEV12192_sg     0         79           23           2       832
# [2026.08.28 11:33:35.786] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:33:35.788] INFO      TOTAL                          100           23                  8832
# [2026.08.28 11:33:35.788] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:33:35.798] INFO    Finished LabOne Q Compiler run.
# [2026.08.28 11:33:35.798] INFO    Task 'compile_experiment': ended at 2026-08-28 08:33:35.798463Z
# [2026.08.28 11:33:35.916] INFO    Task 'run_experiment': started at 2026-08-28 08:33:35.916448Z
# [2026.08.28 11:33:36.061] INFO    Starting near-time execution...
# [2026.08.28 11:33:36.147] INFO    Estimated RT execution time: 56.92 s.
# [2026.08.28 11:34:33.139] INFO    Finished near-time execution.
# [2026.08.28 11:34:33.204] INFO    Task 'run_experiment': ended at 2026-08-28 08:34:33.204821Z
# [2026.08.28 11:34:33.301] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:34:33.301] INFO      Workflow 'analysis_workflow': execution started at 2026-08-28
# [2026.08.28 11:34:33.301] INFO      08:34:33.301547Z
# [2026.08.28 11:34:33.301] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:34:33.427] INFO    Task 'calculate_qubit_population': started at 2026-08-28 08:34:33.425873Z
# [2026.08.28 11:34:33.494] INFO    Task 'calculate_qubit_population': ended at 2026-08-28 08:34:33.494237Z
# [2026.08.28 11:34:33.589] INFO    Task 'fit_data': started at 2026-08-28 08:34:33.589711Z
# [2026.08.28 11:34:33.702] INFO    Task 'fit_data': ended at 2026-08-28 08:34:33.702019Z
# [2026.08.28 11:34:33.782] INFO    Task 'extract_qubit_parameters': started at 2026-08-28 08:34:33.782229Z
# [2026.08.28 11:34:33.917] INFO    Task 'extract_qubit_parameters': ended at 2026-08-28 08:34:33.917600Z
# [2026.08.28 11:34:34.007] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-28 08:34:34.007859Z
# [2026.08.28 11:34:34.104] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-28 08:34:34.104636Z
# [2026.08.28 11:34:34.463] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-28 08:34:34.463835Z
# [2026.08.28 11:34:34.505] INFO    Task 'plot_population': started at 2026-08-28 08:34:34.505198Z
# [2026.08.28 11:34:34.663] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-28 08:34:34.663196Z
# [2026.08.28 11:34:34.917] INFO    Task 'plot_population': ended at 2026-08-28 08:34:34.917905Z
# [2026.08.28 11:34:34.957] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:34:34.957] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-28 08:34:34.957511Z
# [2026.08.28 11:34:34.957] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:34:35.005] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:34:35.005] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-28 08:34:35.005012Z
# [2026.08.28 11:34:35.005] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measure at readout amplitude: 0.3
# [2026.08.28 11:34:35.165] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:34:35.165] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-28 08:34:35.165858Z
# [2026.08.28 11:34:35.165] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:34:35.455] INFO    Task 'temporary_qpu': started at 2026-08-28 08:34:35.455175Z
# [2026.08.28 11:34:35.503] INFO    Task 'temporary_qpu': ended at 2026-08-28 08:34:35.503875Z
# [2026.08.28 11:34:35.601] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-28
# [2026.08.28 11:34:35.613] INFO    08:34:35.601281Z
# [2026.08.28 11:34:35.662] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-28 08:34:35.662980Z
# [2026.08.28 11:34:35.759] INFO    Task 'create_experiment': started at 2026-08-28 08:34:35.759243Z
# [2026.08.28 11:34:35.856] INFO    Task 'create_experiment': ended at 2026-08-28 08:34:35.856779Z
# [2026.08.28 11:34:35.951] INFO    Task 'compile_experiment': started at 2026-08-28 08:34:35.951177Z
# [2026.08.28 11:34:36.036] INFO    Starting LabOne Q Compiler run...
# [2026.08.28 11:34:36.047] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.28 11:34:36.050] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.28 11:34:36.051] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.28 11:34:36.054] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.28 11:34:36.054] INFO    Schedule completed. [0.001 s]
# [2026.08.28 11:34:36.063] INFO    Code generation completed for all AWGs. [0.008 s]
# [2026.08.28 11:34:36.063] INFO    Completed compilation step 1 of 1. [0.014 s]
# [2026.08.28 11:34:36.081] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:34:36.084] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.28 11:34:36.086] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:34:36.088] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.28 11:34:36.090] INFO      SHFQC_DEV12192_sg     0         79           23           2       832
# [2026.08.28 11:34:36.092] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:34:36.092] INFO      TOTAL                          100           23                  8832
# [2026.08.28 11:34:36.092] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:34:36.104] INFO    Finished LabOne Q Compiler run.
# [2026.08.28 11:34:36.104] INFO    Task 'compile_experiment': ended at 2026-08-28 08:34:36.104825Z
# [2026.08.28 11:34:36.232] INFO    Task 'run_experiment': started at 2026-08-28 08:34:36.224949Z
# [2026.08.28 11:34:36.367] INFO    Starting near-time execution...
# [2026.08.28 11:34:36.465] INFO    Estimated RT execution time: 56.92 s.
# [2026.08.28 11:35:33.465] INFO    Finished near-time execution.
# [2026.08.28 11:35:33.586] INFO    Task 'run_experiment': ended at 2026-08-28 08:35:33.586529Z
# [2026.08.28 11:35:33.690] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:35:33.690] INFO      Workflow 'analysis_workflow': execution started at 2026-08-28
# [2026.08.28 11:35:33.690] INFO      08:35:33.690613Z
# [2026.08.28 11:35:33.694] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:35:33.795] INFO    Task 'calculate_qubit_population': started at 2026-08-28 08:35:33.795202Z
# [2026.08.28 11:35:33.873] INFO    Task 'calculate_qubit_population': ended at 2026-08-28 08:35:33.873354Z
# [2026.08.28 11:35:33.944] INFO    Task 'fit_data': started at 2026-08-28 08:35:33.944753Z
# [2026.08.28 11:35:34.088] INFO    Task 'fit_data': ended at 2026-08-28 08:35:34.088383Z
# [2026.08.28 11:35:34.168] INFO    Task 'extract_qubit_parameters': started at 2026-08-28 08:35:34.168845Z
# [2026.08.28 11:35:34.312] INFO    Task 'extract_qubit_parameters': ended at 2026-08-28 08:35:34.312852Z
# [2026.08.28 11:35:34.395] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-28 08:35:34.395572Z
# [2026.08.28 11:35:34.530] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-28 08:35:34.530961Z
# [2026.08.28 11:35:35.021] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-28 08:35:35.021405Z
# [2026.08.28 11:35:35.070] INFO    Task 'plot_population': started at 2026-08-28 08:35:35.070777Z
# [2026.08.28 11:35:35.212] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-28 08:35:35.212329Z
# [2026.08.28 11:35:35.598] INFO    Task 'plot_population': ended at 2026-08-28 08:35:35.598833Z
# [2026.08.28 11:35:35.648] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:35:35.648] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-28 08:35:35.648446Z
# [2026.08.28 11:35:35.648] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:35:35.701] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:35:35.701] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-28 08:35:35.701395Z
# [2026.08.28 11:35:35.713] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measure at readout amplitude: 0.35
# [2026.08.28 11:35:35.888] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:35:35.888] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-28 08:35:35.888453Z
# [2026.08.28 11:35:35.891] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:35:36.165] INFO    Task 'temporary_qpu': started at 2026-08-28 08:35:36.165724Z
# [2026.08.28 11:35:36.219] INFO    Task 'temporary_qpu': ended at 2026-08-28 08:35:36.213336Z
# [2026.08.28 11:35:36.308] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-28
# [2026.08.28 11:35:36.308] INFO    08:35:36.308532Z
# [2026.08.28 11:35:36.373] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-28 08:35:36.373445Z
# [2026.08.28 11:35:36.486] INFO    Task 'create_experiment': started at 2026-08-28 08:35:36.486382Z
# [2026.08.28 11:35:36.614] INFO    Task 'create_experiment': ended at 2026-08-28 08:35:36.614101Z
# [2026.08.28 11:35:36.710] INFO    Task 'compile_experiment': started at 2026-08-28 08:35:36.710721Z
# [2026.08.28 11:35:36.807] INFO    Starting LabOne Q Compiler run...
# [2026.08.28 11:35:36.807] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.28 11:35:36.807] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.28 11:35:36.807] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.28 11:35:36.807] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.28 11:35:36.817] INFO    Schedule completed. [0.000 s]
# [2026.08.28 11:35:36.827] INFO    Code generation completed for all AWGs. [0.006 s]
# [2026.08.28 11:35:36.827] INFO    Completed compilation step 1 of 1. [0.012 s]
# [2026.08.28 11:35:36.838] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:35:36.838] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.28 11:35:36.838] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:35:36.838] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.28 11:35:36.838] INFO      SHFQC_DEV12192_sg     0         79           23           2       832
# [2026.08.28 11:35:36.838] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:35:36.838] INFO      TOTAL                          100           23                  8832
# [2026.08.28 11:35:36.838] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:35:36.854] INFO    Finished LabOne Q Compiler run.
# [2026.08.28 11:35:36.854] INFO    Task 'compile_experiment': ended at 2026-08-28 08:35:36.854495Z
# [2026.08.28 11:35:37.001] INFO    Task 'run_experiment': started at 2026-08-28 08:35:37.001267Z
# [2026.08.28 11:35:37.141] INFO    Starting near-time execution...
# [2026.08.28 11:35:37.207] INFO    Estimated RT execution time: 56.92 s.
# [2026.08.28 11:36:34.206] INFO    Finished near-time execution.
# [2026.08.28 11:36:34.276] INFO    Task 'run_experiment': ended at 2026-08-28 08:36:34.276962Z
# [2026.08.28 11:36:34.368] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:36:34.368] INFO      Workflow 'analysis_workflow': execution started at 2026-08-28
# [2026.08.28 11:36:34.368] INFO      08:36:34.356183Z
# [2026.08.28 11:36:34.368] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:36:34.451] INFO    Task 'calculate_qubit_population': started at 2026-08-28 08:36:34.451481Z
# [2026.08.28 11:36:34.564] INFO    Task 'calculate_qubit_population': ended at 2026-08-28 08:36:34.564451Z
# [2026.08.28 11:36:34.645] INFO    Task 'fit_data': started at 2026-08-28 08:36:34.645379Z
# [2026.08.28 11:36:34.771] INFO    Task 'fit_data': ended at 2026-08-28 08:36:34.771696Z
# [2026.08.28 11:36:34.877] INFO    Task 'extract_qubit_parameters': started at 2026-08-28 08:36:34.877818Z
# [2026.08.28 11:36:35.038] INFO    Task 'extract_qubit_parameters': ended at 2026-08-28 08:36:35.037113Z
# [2026.08.28 11:36:35.121] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-28 08:36:35.120775Z
# [2026.08.28 11:36:35.225] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-28 08:36:35.225665Z
# [2026.08.28 11:36:35.580] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-28 08:36:35.577789Z
# [2026.08.28 11:36:35.624] INFO    Task 'plot_population': started at 2026-08-28 08:36:35.624794Z
# [2026.08.28 11:36:35.782] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-28 08:36:35.782475Z
# [2026.08.28 11:36:36.197] INFO    Task 'plot_population': ended at 2026-08-28 08:36:36.197739Z
# [2026.08.28 11:36:36.257] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:36:36.257] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-28 08:36:36.256262Z
# [2026.08.28 11:36:36.257] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:36:36.302] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:36:36.303] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-28 08:36:36.302407Z
# [2026.08.28 11:36:36.303] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measure at readout amplitude: 0.4
# [2026.08.28 11:36:36.491] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:36:36.493] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-28 08:36:36.491122Z
# [2026.08.28 11:36:36.493] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:36:36.743] INFO    Task 'temporary_qpu': started at 2026-08-28 08:36:36.743252Z
# [2026.08.28 11:36:36.795] INFO    Task 'temporary_qpu': ended at 2026-08-28 08:36:36.795139Z
# [2026.08.28 11:36:36.895] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-28
# [2026.08.28 11:36:36.898] INFO    08:36:36.895582Z
# [2026.08.28 11:36:36.951] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-28 08:36:36.950560Z
# [2026.08.28 11:36:37.038] INFO    Task 'create_experiment': started at 2026-08-28 08:36:37.035707Z
# [2026.08.28 11:36:37.159] INFO    Task 'create_experiment': ended at 2026-08-28 08:36:37.159773Z
# [2026.08.28 11:36:37.253] INFO    Task 'compile_experiment': started at 2026-08-28 08:36:37.250983Z
# [2026.08.28 11:36:37.356] INFO    Starting LabOne Q Compiler run...
# [2026.08.28 11:36:37.356] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.28 11:36:37.365] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.28 11:36:37.367] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.28 11:36:37.369] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.28 11:36:37.371] INFO    Schedule completed. [0.001 s]
# [2026.08.28 11:36:37.379] INFO    Code generation completed for all AWGs. [0.006 s]
# [2026.08.28 11:36:37.381] INFO    Completed compilation step 1 of 1. [0.012 s]
# [2026.08.28 11:36:37.393] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:36:37.397] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.28 11:36:37.399] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:36:37.401] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.28 11:36:37.403] INFO      SHFQC_DEV12192_sg     0         79           23           2       832
# [2026.08.28 11:36:37.403] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:36:37.406] INFO      TOTAL                          100           23                  8832
# [2026.08.28 11:36:37.406] INFO     ───────────────────────────────────────────────────────────────────────
# ...
# [2026.08.28 11:46:42.851] INFO    Task 'compile_experiment': started at 2026-08-28 08:46:42.851730Z
# [2026.08.28 11:46:42.939] INFO    Starting LabOne Q Compiler run...
# [2026.08.28 11:46:42.939] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.28 11:46:42.939] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.28 11:46:42.939] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.28 11:46:42.955] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.28 11:46:42.956] INFO    Schedule completed. [0.001 s]
# [2026.08.28 11:46:42.962] INFO    Code generation completed for all AWGs. [0.007 s]
# [2026.08.28 11:46:42.962] INFO    Completed compilation step 1 of 1. [0.012 s]
# [2026.08.28 11:46:42.972] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:46:42.972] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.28 11:46:42.972] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:46:42.972] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.28 11:46:42.972] INFO      SHFQC_DEV12192_sg     0         79           23           2       832
# [2026.08.28 11:46:42.988] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:46:42.988] INFO      TOTAL                          100           23                  8832
# [2026.08.28 11:46:42.990] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:46:43.003] INFO    Finished LabOne Q Compiler run.
# [2026.08.28 11:46:43.003] INFO    Task 'compile_experiment': ended at 2026-08-28 08:46:43.003669Z
# [2026.08.28 11:46:43.140] INFO    Task 'run_experiment': started at 2026-08-28 08:46:43.140141Z
# [2026.08.28 11:46:43.244] INFO    Starting near-time execution...
# [2026.08.28 11:46:43.320] INFO    Estimated RT execution time: 56.92 s.
# [2026.08.28 11:47:40.299] INFO    Finished near-time execution.
# [2026.08.28 11:47:40.362] INFO    Task 'run_experiment': ended at 2026-08-28 08:47:40.362691Z
# [2026.08.28 11:47:40.471] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:47:40.475] INFO      Workflow 'analysis_workflow': execution started at 2026-08-28
# [2026.08.28 11:47:40.479] INFO      08:47:40.471344Z
# [2026.08.28 11:47:40.479] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:47:40.580] INFO    Task 'calculate_qubit_population': started at 2026-08-28 08:47:40.580267Z
# [2026.08.28 11:47:40.659] INFO    Task 'calculate_qubit_population': ended at 2026-08-28 08:47:40.659867Z
# [2026.08.28 11:47:40.734] INFO    Task 'fit_data': started at 2026-08-28 08:47:40.734969Z
# [2026.08.28 11:47:40.860] INFO    Task 'fit_data': ended at 2026-08-28 08:47:40.859977Z
# [2026.08.28 11:47:40.933] INFO    Task 'extract_qubit_parameters': started at 2026-08-28 08:47:40.933892Z
# [2026.08.28 11:47:41.074] INFO    Task 'extract_qubit_parameters': ended at 2026-08-28 08:47:41.074098Z
# [2026.08.28 11:47:41.160] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-28 08:47:41.160227Z
# [2026.08.28 11:47:41.260] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-28 08:47:41.257313Z
# [2026.08.28 11:47:41.646] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-28 08:47:41.646102Z
# [2026.08.28 11:47:41.692] INFO    Task 'plot_population': started at 2026-08-28 08:47:41.692698Z
# [2026.08.28 11:47:41.826] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-28 08:47:41.824025Z
# [2026.08.28 11:47:42.125] INFO    Task 'plot_population': ended at 2026-08-28 08:47:42.125805Z
# [2026.08.28 11:47:42.161] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:47:42.161] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-28 08:47:42.161596Z
# [2026.08.28 11:47:42.173] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:47:42.221] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:47:42.221] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-28 08:47:42.221539Z
# [2026.08.28 11:47:42.221] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measure at readout amplitude: 0.95
# [2026.08.28 11:47:42.383] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:47:42.384] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-28 08:47:42.383127Z
# [2026.08.28 11:47:42.384] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:47:42.640] INFO    Task 'temporary_qpu': started at 2026-08-28 08:47:42.640792Z
# [2026.08.28 11:47:42.696] INFO    Task 'temporary_qpu': ended at 2026-08-28 08:47:42.694237Z
# [2026.08.28 11:47:42.781] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-28
# [2026.08.28 11:47:42.781] INFO    08:47:42.781293Z
# [2026.08.28 11:47:42.864] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-28 08:47:42.864273Z
# [2026.08.28 11:47:42.935] INFO    Task 'create_experiment': started at 2026-08-28 08:47:42.935041Z
# [2026.08.28 11:47:43.042] INFO    Task 'create_experiment': ended at 2026-08-28 08:47:43.042759Z
# [2026.08.28 11:47:43.138] INFO    Task 'compile_experiment': started at 2026-08-28 08:47:43.138553Z
# [2026.08.28 11:47:43.220] INFO    Starting LabOne Q Compiler run...
# [2026.08.28 11:47:43.220] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.28 11:47:43.220] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.28 11:47:43.220] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.28 11:47:43.220] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.28 11:47:43.235] INFO    Schedule completed. [0.000 s]
# [2026.08.28 11:47:43.235] INFO    Code generation completed for all AWGs. [0.006 s]
# [2026.08.28 11:47:43.235] INFO    Completed compilation step 1 of 1. [0.011 s]
# [2026.08.28 11:47:43.251] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:47:43.251] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.28 11:47:43.251] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:47:43.251] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.28 11:47:43.251] INFO      SHFQC_DEV12192_sg     0         79           23           2       832
# [2026.08.28 11:47:43.263] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:47:43.265] INFO      TOTAL                          100           23                  8832
# [2026.08.28 11:47:43.265] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:47:43.283] INFO    Finished LabOne Q Compiler run.
# [2026.08.28 11:47:43.286] INFO    Task 'compile_experiment': ended at 2026-08-28 08:47:43.285135Z
# [2026.08.28 11:47:43.432] INFO    Task 'run_experiment': started at 2026-08-28 08:47:43.432632Z
# [2026.08.28 11:47:43.631] INFO    Starting near-time execution...
# [2026.08.28 11:47:43.721] INFO    Estimated RT execution time: 56.92 s.
# [2026.08.28 11:48:40.724] INFO    Finished near-time execution.
# [2026.08.28 11:48:40.817] INFO    Task 'run_experiment': ended at 2026-08-28 08:48:40.817639Z
# [2026.08.28 11:48:40.914] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:48:40.915] INFO      Workflow 'analysis_workflow': execution started at 2026-08-28
# [2026.08.28 11:48:40.915] INFO      08:48:40.905132Z
# [2026.08.28 11:48:40.916] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:48:41.026] INFO    Task 'calculate_qubit_population': started at 2026-08-28 08:48:41.026601Z
# [2026.08.28 11:48:41.107] INFO    Task 'calculate_qubit_population': ended at 2026-08-28 08:48:41.105893Z
# [2026.08.28 11:48:41.202] INFO    Task 'fit_data': started at 2026-08-28 08:48:41.202869Z
# [2026.08.28 11:48:41.321] INFO    Task 'fit_data': ended at 2026-08-28 08:48:41.321211Z
# [2026.08.28 11:48:41.421] INFO    Task 'extract_qubit_parameters': started at 2026-08-28 08:48:41.421292Z
# [2026.08.28 11:48:41.540] INFO    Task 'extract_qubit_parameters': ended at 2026-08-28 08:48:41.540763Z
# [2026.08.28 11:48:41.629] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-28 08:48:41.629247Z
# [2026.08.28 11:48:41.750] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-28 08:48:41.750940Z
# [2026.08.28 11:48:42.235] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-28 08:48:42.235988Z
# [2026.08.28 11:48:42.314] INFO    Task 'plot_population': started at 2026-08-28 08:48:42.314864Z
# [2026.08.28 11:48:42.485] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-28 08:48:42.485360Z
# [2026.08.28 11:48:42.959] INFO    Task 'plot_population': ended at 2026-08-28 08:48:42.959817Z
# [2026.08.28 11:48:43.025] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:48:43.025] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-28 08:48:43.025648Z
# [2026.08.28 11:48:43.025] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:48:43.055] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:48:43.055] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-28 08:48:43.055868Z
# [2026.08.28 11:48:43.055] INFO     ──────────────────────────────────────────────────────────────────────────────
# Measure at readout amplitude: 1.0
# [2026.08.28 11:48:43.235] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:48:43.235] INFO      Workflow 'amplitude_rabi': execution started at 2026-08-28 08:48:43.235038Z
# [2026.08.28 11:48:43.235] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:48:43.527] INFO    Task 'temporary_qpu': started at 2026-08-28 08:48:43.527835Z
# [2026.08.28 11:48:43.605] INFO    Task 'temporary_qpu': ended at 2026-08-28 08:48:43.605790Z
# [2026.08.28 11:48:43.702] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-28
# [2026.08.28 11:48:43.702] INFO    08:48:43.701053Z
# [2026.08.28 11:48:43.759] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-28 08:48:43.759297Z
# [2026.08.28 11:48:43.834] INFO    Task 'create_experiment': started at 2026-08-28 08:48:43.834332Z
# [2026.08.28 11:48:43.972] INFO    Task 'create_experiment': ended at 2026-08-28 08:48:43.972959Z
# [2026.08.28 11:48:44.053] INFO    Task 'compile_experiment': started at 2026-08-28 08:48:44.053581Z
# [2026.08.28 11:48:44.185] INFO    Starting LabOne Q Compiler run...
# [2026.08.28 11:48:44.191] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.28 11:48:44.193] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.28 11:48:44.197] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.28 11:48:44.197] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.28 11:48:44.200] INFO    Schedule completed. [0.000 s]
# [2026.08.28 11:48:44.204] INFO    Code generation completed for all AWGs. [0.006 s]
# [2026.08.28 11:48:44.204] INFO    Completed compilation step 1 of 1. [0.009 s]
# [2026.08.28 11:48:44.213] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:48:44.213] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.28 11:48:44.213] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:48:44.213] INFO      SHFQC_DEV12192        0         21            0           1      8000
# [2026.08.28 11:48:44.213] INFO      SHFQC_DEV12192_sg     0         79           23           2       832
# [2026.08.28 11:48:44.213] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:48:44.213] INFO      TOTAL                          100           23                  8832
# [2026.08.28 11:48:44.224] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.28 11:48:44.235] INFO    Finished LabOne Q Compiler run.
# [2026.08.28 11:48:44.237] INFO    Task 'compile_experiment': ended at 2026-08-28 08:48:44.235221Z
# [2026.08.28 11:48:44.374] INFO    Task 'run_experiment': started at 2026-08-28 08:48:44.374689Z
# [2026.08.28 11:48:44.566] INFO    Starting near-time execution...
# [2026.08.28 11:48:44.664] INFO    Estimated RT execution time: 56.92 s.
# [2026.08.28 11:49:41.661] INFO    Finished near-time execution.
# [2026.08.28 11:49:41.735] INFO    Task 'run_experiment': ended at 2026-08-28 08:49:41.727320Z
# [2026.08.28 11:49:41.837] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:49:41.837] INFO      Workflow 'analysis_workflow': execution started at 2026-08-28
# [2026.08.28 11:49:41.837] INFO      08:49:41.837939Z
# [2026.08.28 11:49:41.842] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:49:41.967] INFO    Task 'calculate_qubit_population': started at 2026-08-28 08:49:41.967355Z
# [2026.08.28 11:49:42.062] INFO    Task 'calculate_qubit_population': ended at 2026-08-28 08:49:42.062126Z
# [2026.08.28 11:49:42.159] INFO    Task 'fit_data': started at 2026-08-28 08:49:42.159648Z
# [2026.08.28 11:49:42.303] INFO    Task 'fit_data': ended at 2026-08-28 08:49:42.303986Z
# [2026.08.28 11:49:42.398] INFO    Task 'extract_qubit_parameters': started at 2026-08-28 08:49:42.398001Z
# [2026.08.28 11:49:42.542] INFO    Task 'extract_qubit_parameters': ended at 2026-08-28 08:49:42.542978Z
# [2026.08.28 11:49:42.623] INFO    Task 'plot_raw_complex_data_1d': started at 2026-08-28 08:49:42.623472Z
# [2026.08.28 11:49:42.752] INFO    Artifact: 'Raw_data_Q2' of type 'Figure' logged at 2026-08-28 08:49:42.752122Z
# [2026.08.28 11:49:43.131] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-08-28 08:49:43.131244Z
# [2026.08.28 11:49:43.185] INFO    Task 'plot_population': started at 2026-08-28 08:49:43.185232Z
# [2026.08.28 11:49:43.347] INFO    Artifact: 'Rabi_Q2' of type 'Figure' logged at 2026-08-28 08:49:43.347095Z
# [2026.08.28 11:49:43.699] INFO    Task 'plot_population': ended at 2026-08-28 08:49:43.699288Z
# [2026.08.28 11:49:43.762] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:49:43.762] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-28 08:49:43.762833Z
# [2026.08.28 11:49:43.762] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:49:43.797] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.28 11:49:43.797] INFO      Workflow 'amplitude_rabi': execution ended at 2026-08-28 08:49:43.797130Z
# [2026.08.28 11:49:43.797] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Update Parameters

# %%
ll = 1 # skip readout amplitude 0 (no signal)
ul = None
sweep_slice = slice(ll, ul)

# lmfit reports stderr = 0 when the covariance matrix could not be estimated;
# treat those points as invalid instead of "perfect".
err_arr[err_arr == 0] = np.nan
rel_err_arr = np.abs(err_arr / popt_rabi_arr)
fig, ax = plt.subplots(2, 2, sharex=True, figsize=(10, 8))
fig.suptitle(f'Relative errors for Rabi measurements - {qubit_to_measure.uid}', fontsize=16)
fig.supylabel('Relative error (a.u.)')

ax[0, 0].plot(ro_amp_arr[sweep_slice], rel_err_arr[sweep_slice, 0], '.k', label='freq')
ax[1, 0].plot(ro_amp_arr[sweep_slice], rel_err_arr[sweep_slice, 1], '.k', label='phase')
ax[0, 1].plot(ro_amp_arr[sweep_slice], rel_err_arr[sweep_slice, 2], '.k', label='amp')
ax[1, 1].plot(ro_amp_arr[sweep_slice], rel_err_arr[sweep_slice, 3], '.k', label='off')

ax[0, 0].set_title('Frequency')
ax[1, 0].set_title('Phase')
ax[0, 1].set_title('Amplitude')
ax[1, 1].set_title('Offset')

# optimal readout amplitude: smallest mean relative fit error.
mean_rel_err = np.nanmean(rel_err_arr, axis=1)
masked_rel_err = np.full(mean_rel_err.shape, np.nan)
masked_rel_err[sweep_slice] = mean_rel_err[sweep_slice]
optimal_index = int(np.nanargmin(masked_rel_err))
readout_amplitude_opt = float(ro_amp_arr[optimal_index])

for axis in ax.flatten():
    axis.axvline(x=readout_amplitude_opt, ls='-.', color='r', label='optimal')
    axis.legend()

print('Optimal readout amplitude:', round(readout_amplitude_opt, 5))

figname = f'Rabi_optimiz_{readout_range_out}dBm_'
file_path = get_path_to_file(figname, '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')
# Out:
# Optimal readout amplitude: 0.8

# %%
# set to a value != None to override the value extracted above.
manual_readout_amplitude = None
if manual_readout_amplitude is not None:
    readout_amplitude_opt = float(manual_readout_amplitude)

if update_global_parameters:
    temporary_parameters[qubit_to_measure.uid].readout_amplitude = readout_amplitude_opt
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)
    print('\nUpdated global experiment parameters!\n')

print('Readout amplitude: ', qubit_to_measure.parameters.readout_amplitude)
print('Readout length: ', qubit_to_measure.parameters.readout_length)
print('Readout pulse: ', qubit_to_measure.parameters.readout_pulse)
print('Readout integration length: ', qubit_to_measure.parameters.readout_integration_length)
print('Readout integration delay: ', qubit_to_measure.parameters.readout_integration_delay)
print('Readout range out / in: ', qubit_to_measure.parameters.readout_range_out,
      '/', qubit_to_measure.parameters.readout_range_in)
# Out:
# Updated global experiment parameters!
#
# Readout amplitude:  0.8
# Readout length:  2e-06
# Readout pulse:  {'function': 'gaussian_square', 'width': 1.7599999999999999e-06}
# Readout integration length:  2e-06
# Readout integration delay:  8.1e-08
# Readout range out / in:  -30 / -35

# %%
qpu.quantum_elements
# Out:
# [TunableTransmonQubit(
# │   uid='Q2',
# │   signals={
# │   │   'drive': 'q0/drive',
# │   │   'drive_ef': 'q0/drive_ef',
# │   │   'measure': 'q0/measure',
# │   │   'acquire': 'q0/acquire'
# │   },
# │   parameters=TunableTransmonQubitParameters(
# │   │   custom={},
# │   │   ge_T1=1.3645176509647932e-05,
# │   │   ge_T2=5.227829805594839e-06,
# │   │   ge_T2_star=8.607061549037454e-06,
# │   │   ef_T1=-6.934636333312367e-05,
# │   │   ef_T2=-3.90495002546569e-05,
# │   │   ef_T2_star=1.493050064516055e-05,
# │   │   drive_lo_frequency=4800000000.0,
# │   │   readout_lo_frequency=6000000000.0,
# │   │   resonance_frequency_ge=5004729039.10699,
# │   │   resonance_frequency_ef=4802699999.518822,
# │   │   readout_resonator_frequency=5960100000.0,
# │   │   ge_drive_amplitude_pi=0.3548006173136019,
# │   │   ge_drive_amplitude_pi2=0.07343142790133057,
# │   │   ge_drive_length=1e-07,
# │   │   ge_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0.2413462769901743,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   ef_drive_amplitude_pi=0.2492158737460119,
# │   │   ef_drive_amplitude_pi2=2.182708926414717e-05,
# │   │   ef_drive_length=1e-07,
# │   │   ef_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0.20099572576625233,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   qubit_resonator_coupling_strength_g=0,
# │   │   ge_chi_shift=0,
# │   │   readout_amplitude=0.8,
# │   │   readout_length=2e-06,
# │   │   readout_pulse={
# │   │   │   'function': 'gaussian_square',
# │   │   │   'width': 1.7599999999999999e-06
# │   │   },
# │   │   readout_integration_length=2e-06,
# │   │   readout_integration_delay=8.1e-08,
# │   │   readout_integration_kernels_type='default',
# │   │   readout_integration_kernels=None,
# │   │   readout_integration_discrimination_thresholds=None,
# │   │   reset_delay_length=0.0003,
# │   │   drive_range=10,
# │   │   readout_range_out=-30,
# │   │   readout_range_in=-35,
# │   │   flux_range=5,
# │   │   spectroscopy_length=2e-05,
# │   │   spectroscopy_amplitude=0.4,
# │   │   spectroscopy_pulse={
# │   │   │   'function': 'const',
# │   │   │   'can_compress': True
# │   │   },
# │   │   dc_slot=0,
# │   │   dc_voltage_parking=0.0,
# │   │   flux_offset_voltage=0.0,
# │   │   user_defined={}
# │   )
# )
# ]

# %%
qubits[0].parameters.ef_drive_amplitude_pi = 0.2492158737460119

# %% [markdown]
# ## Dispersive Shift

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

states = 'gef'

n_avg_exponent = 13

freq_range = 2e6
n_points = 101

# TODO
# readout_amplitude = 0.2
# readout_range_out = -30
# readout_range_in = -35
# reset_delay_length = 150e-6

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
# temp_pars.readout_amplitude = readout_amplitude
# temp_pars.readout_range_out = readout_range_out
# temp_pars.readout_range_in = readout_range_in
# temp_pars.reset_delay_length = reset_delay_length
temporary_parameters[qubits[0].uid] = temp_pars

# %% [markdown]
# #### Run Workflow

# %%
options = dispersive_shift.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.update(False)  # updated explicitly below
options.close_figures(False)

qubit_to_measure = qubits[0]

frequencies = temporary_parameters[
    qubit_to_measure.uid
].readout_resonator_frequency + np.linspace(-freq_range / 2, freq_range / 2, n_points)

exp_workflow = dispersive_shift.experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=qubit_to_measure.uid,
    frequencies=frequencies,
    states=states,
    options=options,
    temporary_parameters=temporary_parameters,
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.31 13:40:17.472] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:40:17.472] INFO      Workflow 'dispersive_shift': execution started at 2026-08-31
# [2026.08.31 13:40:17.472] INFO      10:40:17.472760Z
# [2026.08.31 13:40:17.482] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:40:17.935] INFO    Task 'temporary_qpu': started at 2026-08-31 10:40:17.935494Z
# [2026.08.31 13:40:18.032] INFO    Task 'temporary_qpu': ended at 2026-08-31 10:40:18.032520Z
# [2026.08.31 13:40:18.193] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 13:40:18.193] INFO    10:40:18.193195Z
# [2026.08.31 13:40:18.272] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 10:40:18.272924Z
# [2026.08.31 13:40:18.466] INFO    Task 'create_experiment': started at 2026-08-31 10:40:18.465027Z
# [2026.08.31 13:40:18.642] INFO    Task 'create_experiment': ended at 2026-08-31 10:40:18.642407Z
# [2026.08.31 13:40:18.852] INFO    Task 'compile_experiment': started at 2026-08-31 10:40:18.852279Z
# [2026.08.31 13:40:19.034] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 13:40:19.034] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 13:40:19.034] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 13:40:19.046] INFO    Schedule completed. [0.005 s]
# [2026.08.31 13:40:19.062] INFO    Code generation completed for all AWGs. [0.014 s]
# [2026.08.31 13:40:19.062] INFO    Completed compilation step 1 of 1. [0.025 s]
# [2026.08.31 13:40:19.062] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:40:19.076] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 13:40:19.076] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:40:19.076] INFO      SHFQC_DEV12192        0         39            0           1      7616
# [2026.08.31 13:40:19.076] INFO      SHFQC_DEV12192_sg     0         23            3           2      1408
# [2026.08.31 13:40:19.076] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:40:19.076] INFO      TOTAL                           62            3                  9024
# [2026.08.31 13:40:19.086] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:40:19.105] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 13:40:19.107] INFO    Task 'compile_experiment': ended at 2026-08-31 10:40:19.105405Z
# [2026.08.31 13:40:19.319] INFO    Task 'run_experiment': started at 2026-08-31 10:40:19.319321Z
# [2026.08.31 13:40:19.462] INFO    Starting near-time execution...
# [2026.08.31 13:40:19.525] INFO    Estimated RT execution time: 749.95 s.
# [2026.08.31 13:52:50.463] INFO    Finished near-time execution.
# [2026.08.31 13:52:50.641] INFO    Task 'run_experiment': ended at 2026-08-31 10:52:50.641904Z
# [2026.08.31 13:52:50.854] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:52:50.856] INFO      Workflow 'analysis_workflow': execution started at 2026-08-31
# [2026.08.31 13:52:50.856] INFO      10:52:50.854840Z
# [2026.08.31 13:52:50.858] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:52:51.008] INFO    Task 'calculate_signal_differences': started at 2026-08-31 10:52:51.008418Z
# [2026.08.31 13:52:51.097] INFO    Task 'calculate_signal_differences': ended at 2026-08-31 10:52:51.097152Z
# [2026.08.31 13:52:51.489] INFO    Task 'extract_qubit_parameters': started at 2026-08-31 10:52:51.473020Z
# [2026.08.31 13:52:51.650] INFO    Task 'extract_qubit_parameters': ended at 2026-08-31 10:52:51.650720Z
# [2026.08.31 13:52:51.718] INFO    Task 'plot_dispersive_shift': started at 2026-08-31 10:52:51.718351Z
# [2026.08.31 13:52:51.892] INFO    Artifact: 'Dispersive_shift_Q2' of type 'Figure' logged at 2026-08-31
# [2026.08.31 13:52:51.892] INFO    10:52:51.892181Z
# [2026.08.31 13:52:52.276] INFO    Task 'plot_dispersive_shift': ended at 2026-08-31 10:52:52.276893Z
# [2026.08.31 13:52:52.359] INFO    Task 'plot_signal_distances': started at 2026-08-31 10:52:52.359648Z
# [2026.08.31 13:52:52.551] INFO    Artifact: 'Signal_distances_Q2' of type 'Figure' logged at 2026-08-31
# [2026.08.31 13:52:52.551] INFO    10:52:52.550649Z
# [2026.08.31 13:52:53.000] INFO    Task 'plot_signal_distances': ended at 2026-08-31 10:52:53.000528Z
# [2026.08.31 13:52:53.080] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:52:53.080] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-31 10:52:53.080194Z
# [2026.08.31 13:52:53.080] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:52:53.176] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:52:53.176] INFO      Workflow 'dispersive_shift': execution ended at 2026-08-31 10:52:53.176492Z
# [2026.08.31 13:52:53.183] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Analysis Plots

# %%
result = workflow_result.output
res_data = {
    state: result[dsl.handles.result_handle(qubit_to_measure.uid, suffix=state)].data
    for state in states
}
res_freq = frequencies

state_labels = {'g': 'ground', 'e': 'first excited', 'f': 'second excited'}
state_colors = {'g': 'b', 'e': 'r', 'f': 'g'}

fig, ax = plt.subplots(2, 1, sharex=True, figsize=(10, 8))
fig.suptitle('Spectroscopy of readout resonator for the qubit states', fontsize=16)
fig.supxlabel('Readout frequency, GHz')

ax[0].set_title('Amplitude')
ax[1].set_title('Phase')

for state, data in res_data.items():
    ax[0].plot(res_freq * 1e-9, np.abs(data), state_colors[state], label=state_labels[state])
    ax[1].plot(res_freq * 1e-9, np.unwrap(np.angle(data)), state_colors[state],
               label=state_labels[state])

for axis, ylabel in zip(ax, ['Amplitude, a.u.', 'Phase, a.u.']):
    axis.axvline(x=qubit_to_measure.parameters.readout_resonator_frequency * 1e-9,
                 label='current readout')
    axis.set_ylabel(ylabel)
    axis.legend()

file_path = get_path_to_file('Readout_spec_for_g_e', '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

fig_iq, ax_iq = plt.subplots()
ax_iq.set_title('Spectroscopy of readout resonator: IQ plane')
for state, data in res_data.items():
    ax_iq.plot(data.real, data.imag, state_colors[state], label=state_labels[state])
ax_iq.set_xlabel('Real part, a.u.')
ax_iq.set_ylabel('Imaginary part, a.u.')
ax_iq.legend()

file_path = get_path_to_file('Readout_spec_for_g_e_IQ', '.png')
fig_iq.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %%
processed_data_dict = get_analysis_task_output(workflow_result, 'calculate_signal_differences')

fig_dist, ax_dist = plt.subplots(figsize=(10, 5))
ax_dist.set_title('Spectroscopy of readout resonator: state distances')
for state_pair, (distance, max_distance, freq_at_max) in processed_data_dict.items():
    ax_dist.plot(res_freq * 1e-9, distance, label=state_pair)
    print(f'{state_pair}: max distance {max_distance:.4g} at '
          f'{freq_at_max * 1e-9:.6f} GHz')

ax_dist.axvline(x=qubit_to_measure.parameters.readout_resonator_frequency * 1e-9,
                ls='--', label='current readout')
ax_dist.axvline(x=processed_data_dict['sum' if 'sum' in processed_data_dict else
                                      next(iter(processed_data_dict))][2] * 1e-9,
                ls='-.', color='k', label='optimal')
ax_dist.set_xlabel('Readout frequency, GHz')
ax_dist.set_ylabel('Signal distance, a.u.')
ax_dist.legend()

file_path = get_path_to_file('Readout_spec_for_g_e_distance', '.png')
fig_dist.savefig(file_path, dpi=600, format='png', bbox_inches='tight')
# Out:
# ge: max distance 2.493e-06 at 5.959620 GHz
# gf: max distance 2.534e-06 at 5.959580 GHz
# ef: max distance 1.21e-07 at 5.959540 GHz
# sum: max distance 5.073e-06 at 5.959580 GHz

# %% [markdown]
# #### Update Parameters

# %%
analysis_workflow_result = workflow_result.tasks['analysis_workflow']
qubit_parameters = analysis_workflow_result.output
pprint(qubit_parameters)

readout_resonator_frequency_opt = float(
    qubit_parameters['new_parameter_values'][qubit_to_measure.uid][
        'readout_resonator_frequency'
    ]
)

manual_readout_resonator_frequency = None
if manual_readout_resonator_frequency is not None:
    readout_resonator_frequency_opt = float(manual_readout_resonator_frequency)
    qubit_parameters['new_parameter_values'][qubit_to_measure.uid][
        'readout_resonator_frequency'
    ] = readout_resonator_frequency_opt

print(f'ro freq opt: {readout_resonator_frequency_opt * 1e-9:.6f} GHz')

if update_global_parameters:
    temporary_parameters[qubit_to_measure.uid].readout_resonator_frequency = (
        readout_resonator_frequency_opt
    )
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    dispersive_shift.update_qpu(qpu, qubit_parameters['new_parameter_values'])
    save(qpu, qpu_file_path)
    print('\nUpdated global experiment parameters!\n')

print('Readout resonator frequency: ',
      qubit_to_measure.parameters.readout_resonator_frequency * 1e-9, ' GHz')
# Out:
# {'new_parameter_values': {'Q2': {'readout_resonator_frequency': np.float64(5959580000.0)}},
#  'old_parameter_values': {'Q2': {'readout_resonator_frequency': np.float64(5959580000.0)}}}
# ro freq opt: 5.959580 GHz
#
# Updated global experiment parameters!
#
# Readout resonator frequency:  5.959580000000001  GHz

# %%
data_gef_spec = {'freq': res_freq}
for state, data in res_data.items():
    data_gef_spec[f'{state}_res'] = data
    data_gef_spec[f'{state}_freq'] = res_freq
data_gef_spec.update(
    {k: v for k, v in attrs.asdict(qubit_to_measure.parameters).items()
     if isinstance(v, (int, float, str))}
)
data_gef_spec['sample_name'] = sample_name
data_gef_spec['qubit_name'] = qubit_name
data_gef_spec['cooldown_start_date'] = cooldown_start_date

file_path = get_path_to_file('ge_spec_readout_', '.mat')
savemat(file_path, data_gef_spec)
print(f'Saved gef readout spectroscopy to: {file_path}')
# Out:
# Saved gef readout spectroscopy to: N:\xld\qubit_thermometry_v2\ES-009-DE_1-2_9150\COOLDOWN_2026-08-26\Q2\20260831_135259_ge_spec_readout_.mat

# %%
readout_opt = {
    'readout_amplitude': qubit_to_measure.parameters.readout_amplitude,
    'readout_length': qubit_to_measure.parameters.readout_length,
    'readout_pulse': qubit_to_measure.parameters.readout_pulse,
    'readout_integration_length': qubit_to_measure.parameters.readout_integration_length,
    'readout_integration_delay': qubit_to_measure.parameters.readout_integration_delay,
    'readout_integration_kernels_type':
        qubit_to_measure.parameters.readout_integration_kernels_type,
    'readout_resonator_frequency': qubit_to_measure.parameters.readout_resonator_frequency,
    'readout_lo_frequency': qubit_to_measure.parameters.readout_lo_frequency,
    'readout_range_out': qubit_to_measure.parameters.readout_range_out,
    'readout_range_in': qubit_to_measure.parameters.readout_range_in,
    'reset_delay_length': qubit_to_measure.parameters.reset_delay_length,
}
pprint(readout_opt)
# Out:
# {'readout_amplitude': 0.25,
#  'readout_integration_delay': 6.000000000000001e-08,
#  'readout_integration_kernels_type': 'default',
#  'readout_integration_length': 1.9e-06,
#  'readout_length': 1.9e-06,
#  'readout_lo_frequency': 6000000000.0,
#  'readout_pulse': {'function': 'gaussian_square',
#                    'width': 1.7599999999999999e-06},
#  'readout_range_in': -40,
#  'readout_range_out': -20,
#  'readout_resonator_frequency': np.float64(5959580000.0),
#  'reset_delay_length': 0.0003}

# %%
qpu.quantum_elements
# Out:
# [TunableTransmonQubit(
# │   uid='Q2',
# │   signals={
# │   │   'drive': 'q0/drive',
# │   │   'drive_ef': 'q0/drive_ef',
# │   │   'measure': 'q0/measure',
# │   │   'acquire': 'q0/acquire'
# │   },
# │   parameters=TunableTransmonQubitParameters(
# │   │   custom={},
# │   │   ge_T1=1.3645176509647932e-05,
# │   │   ge_T2=5.227829805594839e-06,
# │   │   ge_T2_star=8.607061549037454e-06,
# │   │   ef_T1=-1.4854255847467251e-05,
# │   │   ef_T2=1.8708273053987378e-08,
# │   │   ef_T2_star=1.574907620871535e-05,
# │   │   drive_lo_frequency=4800000000.0,
# │   │   readout_lo_frequency=6000000000.0,
# │   │   resonance_frequency_ge=5004729039.10699,
# │   │   resonance_frequency_ef=4813736214.210726,
# │   │   readout_resonator_frequency=np.float64(5959580000.0),
# │   │   ge_drive_amplitude_pi=0.1450703458642064,
# │   │   ge_drive_amplitude_pi2=0.07343142790133057,
# │   │   ge_drive_length=2.4457142857142856e-07,
# │   │   ge_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0.2413462769901743,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   ef_drive_amplitude_pi=0.06139719997191931,
# │   │   ef_drive_amplitude_pi2=0.035333300376113264,
# │   │   ef_drive_length=1e-07,
# │   │   ef_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0.043192309135097876,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   qubit_resonator_coupling_strength_g=0,
# │   │   ge_chi_shift=0,
# │   │   readout_amplitude=0.25,
# │   │   readout_length=1.9e-06,
# │   │   readout_pulse={
# │   │   │   'function': 'gaussian_square',
# │   │   │   'width': 1.7599999999999999e-06
# │   │   },
# │   │   readout_integration_length=1.9e-06,
# │   │   readout_integration_delay=6.000000000000001e-08,
# │   │   readout_integration_kernels_type='default',
# │   │   readout_integration_kernels=None,
# │   │   readout_integration_discrimination_thresholds=None,
# │   │   reset_delay_length=0.0003,
# │   │   drive_range=0,
# │   │   readout_range_out=-20,
# │   │   readout_range_in=-40,
# │   │   flux_range=5,
# │   │   spectroscopy_length=2e-05,
# │   │   spectroscopy_amplitude=0.4,
# │   │   spectroscopy_pulse={
# │   │   │   'function': 'const',
# │   │   │   'can_compress': True
# │   │   },
# │   │   dc_slot=0,
# │   │   dc_voltage_parking=0.0,
# │   │   flux_offset_voltage=0.0,
# │   │   user_defined={}
# │   )
# )
# ]

# %% [markdown]
# # Single Shot 0 and 1 Measurements

# %% [markdown]
# Single-shot (unaveraged) readout of the qubit prepared in g, e (and f).
#
# 1. **One Single Shot Measurement** — acquire the single shots for each prepared
#    state, classify them with a linear discriminant, and quantify the readout
#    with the state distance, the relative shot noise and the correct-state
#    assignment fidelity.
# 2. **Single Shot vs. Drive Pulse Length** — repeat the measurement for a range
#    of pi-pulse lengths (i.e. Rabi frequencies).
# 3. **Single Shot vs. Integration Length and Delay** — repeat the measurement
#    for a range of integration delays and integration lengths at a fixed
#    readout pulse.
# 4. **Single Shot vs. Readout Amplitude and Length** — repeat the measurement
#    for a range of readout amplitudes and readout lengths.
#
# The readout parameters optimized in `# Readout Optimization` are the starting
# point here; the best settings found below are written back into the QPU.

# %% [markdown]
# ## One Single Shot Measurement

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

states = 'gef'

n_avg_exponent = 17

# TODO
# readout settings for the single shots
# readout_length = 2e-6
# readout_integration_length = 2e-6
# readout_amplitude = 0.2
# readout_integration_delay = 80e-9
# readout_range_out = -30
# readout_range_in = -40
# use a long value only if you want to see the thermal population;
# 500e-3 makes 2**17 shots per state extremely slow
# reset_delay_length = 300e-6

# length and amplitude come from readout_length / readout_amplitude.
# readout_pulse = {
#     'function': 'const',
# }

qubit_to_measure = qubits[0]

temporary_parameters = {}
temp_pars = deepcopy(qubits[0].parameters)
# temp_pars.readout_amplitude = readout_amplitude
# temp_pars.readout_length = readout_length
# temp_pars.readout_pulse = readout_pulse
# temp_pars.readout_integration_length = readout_integration_length
# temp_pars.readout_integration_delay = readout_integration_delay
# temp_pars.readout_range_out = readout_range_out
# temp_pars.readout_range_in = readout_range_in
# temp_pars.reset_delay_length = reset_delay_length
temporary_parameters[qubit_to_measure.uid] = temp_pars

print('Readout length:             ', temp_pars.readout_length)
print('Readout integration length: ', temp_pars.readout_integration_length)
print('Readout integration delay:  ', temp_pars.readout_integration_delay)
print('Readout amplitude:          ', temp_pars.readout_amplitude)
print('Reset delay length:         ', temp_pars.reset_delay_length)
print('Readout resonator frequency:', temp_pars.readout_resonator_frequency)
print('Number of shots per state:  ', 2**n_avg_exponent)
# Out:
# Readout length:              1.9e-06
# Readout integration length:  1.9e-06
# Readout integration delay:   6.000000000000001e-08
# Readout amplitude:           0.25
# Reset delay length:          0.0003
# Readout resonator frequency: 5959580000.0
# Number of shots per state:   131072

# %% [markdown]
# #### Run Workflow

# %%
options = iq_blobs.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(False)
# the analysis classifies the shots with sklearn LinearDiscriminantAnalysis,
# replacing the manual LDA/PCA cells of the old notebook.
options.do_analysis(True)

exp_workflow = iq_blobs.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[qubit_to_measure.uid],
    states=states,
    options=options,
    temporary_parameters=temporary_parameters,
)
workflow_result = exp_workflow.run()
# Out:
# [2026.08.31 13:53:00.584] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:53:00.584] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 10:53:00.584889Z
# [2026.08.31 13:53:00.584] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:53:01.033] INFO    Task 'temporary_qpu': started at 2026-08-31 10:53:01.029574Z
# [2026.08.31 13:53:01.126] INFO    Task 'temporary_qpu': ended at 2026-08-31 10:53:01.126340Z
# [2026.08.31 13:53:01.319] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 13:53:01.319] INFO    10:53:01.319679Z
# [2026.08.31 13:53:01.422] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 10:53:01.422448Z
# [2026.08.31 13:53:01.607] INFO    Task 'create_experiment': started at 2026-08-31 10:53:01.607624Z
# [2026.08.31 13:53:01.864] INFO    Task 'create_experiment': ended at 2026-08-31 10:53:01.864955Z
# [2026.08.31 13:53:02.074] INFO    Task 'compile_experiment': started at 2026-08-31 10:53:02.074601Z
# [2026.08.31 13:53:02.262] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 13:53:02.264] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 13:53:02.266] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 13:53:02.267] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 13:53:02.267] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 13:53:02.269] INFO    Schedule completed. [0.000 s]
# [2026.08.31 13:53:02.275] INFO    Code generation completed for all AWGs. [0.007 s]
# [2026.08.31 13:53:02.277] INFO    Completed compilation step 1 of 1. [0.009 s]
# [2026.08.31 13:53:02.287] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:53:02.287] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 13:53:02.287] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:53:02.287] INFO      SHFQC_DEV12192        0         14            0           1      7616
# [2026.08.31 13:53:02.299] INFO      SHFQC_DEV12192_sg     0         21            3           2      1408
# [2026.08.31 13:53:02.299] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:53:02.299] INFO      TOTAL                           35            3                  9024
# [2026.08.31 13:53:02.304] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:53:02.365] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 13:53:02.365] INFO    Task 'compile_experiment': ended at 2026-08-31 10:53:02.365028Z
# [2026.08.31 13:53:02.636] INFO    Task 'run_experiment': started at 2026-08-31 10:53:02.636931Z
# [2026.08.31 13:53:02.885] INFO    Starting near-time execution...
# [2026.08.31 13:53:02.990] INFO    Estimated RT execution time: 118.79 s.
# [2026.08.31 13:55:03.441] INFO    Finished near-time execution.
# [2026.08.31 13:55:03.587] INFO    Task 'run_experiment': ended at 2026-08-31 10:55:03.587225Z
# [2026.08.31 13:55:04.040] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:55:04.041] INFO      Workflow 'analysis_workflow': execution started at 2026-08-31
# [2026.08.31 13:55:04.041] INFO      10:55:04.040100Z
# [2026.08.31 13:55:04.041] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:55:04.244] INFO    Task 'collect_shots': started at 2026-08-31 10:55:04.242338Z
# [2026.08.31 13:55:04.340] INFO    Task 'collect_shots': ended at 2026-08-31 10:55:04.340142Z
# [2026.08.31 13:55:04.920] INFO    Task 'fit_data': started at 2026-08-31 10:55:04.920477Z
# [2026.08.31 13:55:05.673] INFO    Task 'fit_data': ended at 2026-08-31 10:55:05.673356Z
# [2026.08.31 13:55:05.814] INFO    Task 'calculate_assignment_matrices': started at 2026-08-31 10:55:05.814221Z
# [2026.08.31 13:55:06.214] INFO    Task 'calculate_assignment_matrices': ended at 2026-08-31 10:55:06.214727Z
# [2026.08.31 13:55:06.361] INFO    Task 'calculate_assignment_fidelities': started at 2026-08-31 10:55:06.361366Z
# [2026.08.31 13:55:06.535] INFO    Task 'calculate_assignment_fidelities': ended at 2026-08-31 10:55:06.521568Z
# [2026.08.31 13:55:06.584] INFO    Task 'plot_iq_blobs': started at 2026-08-31 10:55:06.584106Z
# [2026.08.31 13:55:06.938] INFO    Artifact: 'IQ_blobs_Q2' of type 'Figure' logged at 2026-08-31 10:55:06.922369Z
# [2026.08.31 13:55:09.853] INFO    Task 'plot_iq_blobs': ended at 2026-08-31 10:55:09.853832Z
# [2026.08.31 13:55:09.914] INFO    Task 'plot_assignment_matrices': started at 2026-08-31 10:55:09.914316Z
# [2026.08.31 13:55:10.116] INFO    Artifact: 'Assignment_matrix_Q2' of type 'Figure' logged at 2026-08-31
# [2026.08.31 13:55:10.116] INFO    10:55:10.106608Z
# [2026.08.31 13:55:10.590] INFO    Task 'plot_assignment_matrices': ended at 2026-08-31 10:55:10.590598Z
# [2026.08.31 13:55:10.688] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:55:10.699] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-31 10:55:10.688235Z
# [2026.08.31 13:55:10.702] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:55:10.782] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:55:10.787] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 10:55:10.782277Z
# [2026.08.31 13:55:10.787] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Analysis Plots

# %%
result = workflow_result.output
shots_per_state = collect_shots_from_result(result, qubit_to_measure.uid, states)

# convenience aliases matching the old variable names
zero_data = shots_per_state['g']
one_data = shots_per_state['e']
two_data = shots_per_state.get('f')

shots_arr = np.array([shots_per_state[s] for s in states])
print('Shots array shape (states, shots):', shots_arr.shape)

state_labels = {'g': 'ground', 'e': 'first excited', 'f': 'second excited'}
state_colors = {'g': 'b', 'e': 'r', 'f': 'y'}
state_alphas = {'g': 0.1, 'e': 0.1, 'f': 0.01}
# Out:
# Shots array shape (states, shots): (3, 131072)

# %%
# plot measurement data on IQ, plus the state means
fig, ax = plt.subplots()
ax.set_title(f'Single shots on the IQ plane - {qubit_to_measure.uid}')
for s in states:
    data = shots_per_state[s]
    ax.plot(data.real, data.imag, '.', color=state_colors[s],
            alpha=state_alphas[s], label=state_labels[s])
for s in states:
    data = shots_per_state[s]
    ax.plot(np.mean(data.real), np.mean(data.imag), 'o',
            mfc=state_colors[s], mec='k')
ax.set_xlabel('Real part, a.u.')
ax.set_ylabel('Imaginary part, a.u.')
ax.legend()

# plt.xlim(-0.1, 0.12); plt.ylim(-0.25, 0.05) - set manually if needed
# ax.set_xlim(-0.1, 0.12)
# ax.set_ylim(-0.25, 0.05)

figname = 'Single_shot_points_'
file_path = get_path_to_file(figname, '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %%
# analize_Single_Shots(SS_results, plot=True)
res_ss = analyze_single_shots(shots_per_state, state_0='g', state_1='e', plot=True)

# assignment matrix / fidelity are new: they come from the iq_blobs analysis
assignment_fidelities = workflow_result.tasks['analysis_workflow'].output
assignment_matrices = get_analysis_task_output(
    workflow_result, 'calculate_assignment_matrices'
)
assignment_fidelity = assignment_fidelities.get(qubit_to_measure.uid)

summarize_single_shot_metrics(res_ss, assignment_fidelity)
pprint({k: v for k, v in res_ss.items()
        if not isinstance(v, np.ndarray) and k != 'figure'})
# Out:
# State distance:           0.004914
# Relative STD state 0:     1.2642
# Relative STD state 1:     3.3318
# Misassigned state-0 shots: 19698 / 131072
# Assignment fidelity:      41.82 %
# {'distance': np.float64(0.004914020366650949),
#  'mean_0': np.complex128(-0.004914020366650944+3.4558944247975454e-18j),
#  'mean_1': np.complex128(0.004914020366650955+1.2617402782300058e-17j),
#  'n_assigned_0': 111374,
#  'n_misassigned_0': 19698,
#  'rel_std_0': np.float64(1.2641988282050407),
#  'rel_std_1': np.float64(3.331842153856859),
#  'std_x_0': np.float64(0.006212298789295834),
#  'std_x_1': np.float64(0.01637274020251877),
#  'std_y_0': np.float64(0.005034985141917579),
#  'std_y_1': np.float64(0.006945521284315979)}

# %%
# plot the raw (unrotated) distributions
n_bins = 50

fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)
fig.suptitle(f'Single-shot distributions - {qubit_to_measure.uid}')

axs[0].set_title('Real')
axs[1].set_title('Imag')
for s in states:
    data = shots_per_state[s]
    axs[0].hist(data.real, bins=n_bins, alpha=0.5, label=state_labels[s])
    axs[1].hist(data.imag, bins=n_bins, alpha=0.5, label=state_labels[s])
axs[0].legend()
axs[1].legend()

figname = 'Single_shot_hist_'
file_path = get_path_to_file(figname, '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %%
# relative-distance histogram of the projected shots
zero_data_proj = res_ss['shots_0_proj']
one_data_proj = res_ss['shots_1_proj']
r = res_ss['distance']

n_bins = 200

fig, ax = plt.subplots()
ax.set_title(f'Projected single shots - {qubit_to_measure.uid}')
ax.hist(zero_data_proj / r, bins=n_bins, alpha=0.5, label=state_labels['g'])
ax.hist(one_data_proj / r, bins=n_bins, alpha=0.5, label=state_labels['e'])
ax.axvline(1, color='k', ls='--')
ax.axvline(-1, color='k', ls='--')
ax.set_yscale('log')
ax.set_ylabel('N points')
ax.set_xlabel('Relative distance')
ax.legend()

# %%
# single Gaussian fit of the projected state-0 shots
data = zero_data_proj / r

fig, ax = plt.subplots()
n, bins, patches = ax.hist(data, bins=n_bins, alpha=0.5, density=True)

(mu, sigma) = norm.fit(data)

# add a 'best fit' line
y = norm.pdf(bins, mu, sigma)
ax.plot(bins, y, 'r--', linewidth=2)
ax.set_yscale('log')
ax.set_ylabel('Probability density')
ax.set_xlabel('Relative distance')
ax.set_title(f'Gaussian fit state 0: mu = {mu:.4f}, sigma = {sigma:.4f}')
print('mu:', mu, ' sigma:', sigma)
# Out:
# mu: -0.999999999999999  sigma: 1.2641940056600292

# %%
# bimodal fit of the projected state-1 shots -> residual ground pop.
data = one_data_proj / r

fig, ax = plt.subplots()
y, x, patches = ax.hist(data, bins=n_bins, color='red', alpha=0.25)
x = (x[1:] + x[:-1]) / 2

expected = (-1, .2, 1050, 1, .2, 125)
params, cov = curve_fit(bimodal, x, y, expected)
sigma = np.sqrt(np.diag(cov))
x_fit = np.linspace(x.min(), x.max(), 500)
# plot combined...
ax.plot(x_fit, bimodal(x_fit, *params), color='green', lw=3, label='One+Zero')
# ...and individual Gauss curves
ax.plot(x_fit, gauss(x_fit, *params[:3]), color='red', lw=2, ls='--', label='One')
ax.plot(x_fit, gauss(x_fit, *params[3:]), color='b', lw=2, ls=':', label='Zero')
ax.set_yscale('log')
ax.set_ylabel('N points')
ax.set_xlabel('Relative distance')
ax.set_ylim(1e-1, 5e3)
ax.set_title(f'Bimodal fit state 1 - {qubit_to_measure.uid}')
ax.legend()
print(pd.DataFrame(data={'params': params, 'sigma': sigma},
                   index=bimodal.__code__.co_varnames[1:]))
plt.show()

print('Area ratio:', params[4] * params[5] / (params[1] * params[2]))
# Out:
#              params     sigma
# mu1       -1.093202  0.003754
# sigma1     1.006204  0.003754
# A1      2878.657379  9.299831
# mu2        5.834211  0.013221
# sigma2     1.352642  0.013225
# A2       947.553807  8.021228
# Area ratio: 0.4424976423809693

# %%
# bimodal fit of the projected state-0 shots -> residual excited pop.
data = zero_data_proj / r

fig, ax = plt.subplots()
y, x, patches = ax.hist(data, bins=n_bins, color='blue', alpha=0.25)
x = (x[1:] + x[:-1]) / 2

expected = (-1.5, 1.0, 250, 1, 1.0, 2025)
params, cov = curve_fit(bimodal, x, y, expected)
sigma = np.sqrt(np.diag(cov))
x_fit = np.linspace(x.min(), x.max(), 500)
# plot combined...
ax.plot(x_fit, bimodal(x_fit, *params), color='green', lw=3, label='One+Zero')
# ...and individual Gauss curves
ax.plot(x_fit, gauss(x_fit, *params[:3]), color='red', lw=2, ls='--', label='One')
ax.plot(x_fit, gauss(x_fit, *params[3:]), color='blue', lw=2, ls=':', label='Zero')
ax.set_yscale('log')
ax.set_ylabel('N points')
ax.set_xlabel('Relative distance')
ax.set_ylim(1e-1, 5e3)
ax.set_title(f'Bimodal fit state 0 - {qubit_to_measure.uid}')
ax.legend()
print(pd.DataFrame(data={'params': params, 'sigma': sigma},
                   index=bimodal.__code__.co_varnames[1:]))
plt.show()

print('Area ratio:', params[1] * params[2] / (params[4] * params[5]))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[408], line 9
#       5 y, x, patches = ax.hist(data, bins=n_bins, color='blue', alpha=0.25)
#       6 x = (x[1:] + x[:-1]) / 2
#       7
#       8 expected = (-1.5, 1.0, 250, 1, 1.0, 2025)
# ----> 9 params, cov = curve_fit(bimodal, x, y, expected)
#      10 sigma = np.sqrt(np.diag(cov))
#      11 x_fit = np.linspace(x.min(), x.max(), 500)
#      12 # plot combined...
#
# File ~\Documents\Python_virtual_environments\meas_venv_workflow_py312\Lib\site-packages\scipy\optimize\_minpack_py.py:1029, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#    1027     cost = np.sum(infodict['fvec'] ** 2)
#    1028     if ier not in [1, 2, 3, 4]:
# -> 1029         raise RuntimeError("Optimal parameters not found: " + errmsg)
#    1030 else:
#    1031     # Rename maxfev (leastsq) to max_nfev (least_squares), if specified.
#    1032     if 'max_nfev' not in kwargs:
#
# RuntimeError: Optimal parameters not found: Number of calls to function has reached maxfev = 1400.

# %%
# 2D histogram of the shots
n_bins = 50

fig, ax = plt.subplots(tight_layout=True)
ax.set_title(f'Single-shot density - {qubit_to_measure.uid}')
ax.hist2d(zero_data.real, zero_data.imag, n_bins)
ax.hist2d(one_data.real, one_data.imag, n_bins)
ax.set_xlabel('Real part, a.u.')
ax.set_ylabel('Imaginary part, a.u.')

# %%
# the assignment matrix produced by the iq_blobs analysis replaces the manual
# LinearDiscriminantAnalysis / compute_pca cells.
if qubit_to_measure.uid in assignment_matrices:
    print('Correct-state-assignment matrix:')
    print(np.round(assignment_matrices[qubit_to_measure.uid], 4))
    print('Assignment fidelity:', f'{assignment_fidelity * 100:0.2f} %')

# %% [markdown]
# #### Update Parameters

# %%
# Data_SS = {...}; Data_SS.update(qubit_parameters._params);
# savemat(get_path_to_file('Single_shots_all_unsh_', '.mat'), Data_SS)
data_ss = {f'shots_{s}': shots_per_state[s] for s in states}
data_ss['states'] = list(states)
data_ss['shot_index'] = np.arange(shots_arr.shape[-1])
data_ss['n_shots'] = 2**n_avg_exponent
data_ss.update({k: v for k, v in res_ss.items()
                if isinstance(v, (int, float, complex))})
if qubit_to_measure.uid in assignment_matrices:
    data_ss['assignment_matrix'] = assignment_matrices[qubit_to_measure.uid]
    data_ss['assignment_fidelity'] = assignment_fidelity

data_ss.update(
    {k: v for k, v in attrs.asdict(temporary_parameters[qubit_to_measure.uid]).items()
     if isinstance(v, (int, float, str))}
)
data_ss['sample_name'] = sample_name
data_ss['qubit_name'] = qubit_name
data_ss['cooldown_start_date'] = cooldown_start_date

file_path = get_path_to_file('Single_shots_all_unsh_', '.mat')
savemat(file_path, data_ss)
print(f'Saved single shots to: {file_path}')

# %%
if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(temporary_parameters[qubit_to_measure.uid])
    save(qpu, qpu_file_path)
    print('Updated global experiment parameters!\n')

print('Readout amplitude: ', qubit_to_measure.parameters.readout_amplitude)
print('Readout length: ', qubit_to_measure.parameters.readout_length)
print('Readout integration length: ',
      qubit_to_measure.parameters.readout_integration_length)
print('Readout integration delay: ',
      qubit_to_measure.parameters.readout_integration_delay)
print('Reset delay length: ', qubit_to_measure.parameters.reset_delay_length)

# %%
qpu.quantum_elements
# Out:
# [TunableTransmonQubit(
# │   uid='Q2',
# │   signals={
# │   │   'drive': 'q0/drive',
# │   │   'drive_ef': 'q0/drive_ef',
# │   │   'measure': 'q0/measure',
# │   │   'acquire': 'q0/acquire'
# │   },
# │   parameters=TunableTransmonQubitParameters(
# │   │   custom={},
# │   │   ge_T1=1.3645176509647932e-05,
# │   │   ge_T2=5.227829805594839e-06,
# │   │   ge_T2_star=8.607061549037454e-06,
# │   │   ef_T1=3.823989734157484e-06,
# │   │   ef_T2=1.0727739619875858e-06,
# │   │   ef_T2_star=7.980095959592148e-06,
# │   │   drive_lo_frequency=4800000000.0,
# │   │   readout_lo_frequency=6000000000.0,
# │   │   resonance_frequency_ge=5004729039.10699,
# │   │   resonance_frequency_ef=4811929098.0324335,
# │   │   readout_resonator_frequency=np.float64(5959580000.0),
# │   │   ge_drive_amplitude_pi=0.2257822110177467,
# │   │   ge_drive_amplitude_pi2=0.07343142790133057,
# │   │   ge_drive_length=1.571428571428571e-07,
# │   │   ge_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0.2413462769901743,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   ef_drive_amplitude_pi=0.6507087790475553,
# │   │   ef_drive_amplitude_pi2=0.3099951813175842,
# │   │   ef_drive_length=1e-07,
# │   │   ef_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0.08010717043720025,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   qubit_resonator_coupling_strength_g=0,
# │   │   ge_chi_shift=0,
# │   │   readout_amplitude=0.25357142857142856,
# │   │   readout_length=1.9e-06,
# │   │   readout_pulse={
# │   │   │   'function': 'gaussian_square',
# │   │   │   'width': 1.7599999999999999e-06
# │   │   },
# │   │   readout_integration_length=1.9e-06,
# │   │   readout_integration_delay=8e-08,
# │   │   readout_integration_kernels_type='default',
# │   │   readout_integration_kernels=None,
# │   │   readout_integration_discrimination_thresholds=None,
# │   │   reset_delay_length=0.0003,
# │   │   drive_range=0,
# │   │   readout_range_out=-20,
# │   │   readout_range_in=-40,
# │   │   flux_range=5,
# │   │   spectroscopy_length=2e-05,
# │   │   spectroscopy_amplitude=0.4,
# │   │   spectroscopy_pulse={
# │   │   │   'function': 'const',
# │   │   │   'can_compress': True
# │   │   },
# │   │   dc_slot=0,
# │   │   dc_voltage_parking=0.0,
# │   │   flux_offset_voltage=0.0,
# │   │   user_defined={}
# │   )
# )
# ]

# %% [markdown]
# ## Single Shot Measurement for Different Rabi Frequencies

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

n_avg_exponent = 15  # reduce: this is a sweep over 36 pi-pulse lengths

states = 'ge'

drive_length_arr = np.linspace(60e-9, 400e-9, 36)
rabi_freq_arr = 1 / drive_length_arr

# ge_drive_pulse = {
#     'function': 'gaussian',
#     'sigma': 0.25,
# }

# The old notebook extrapolated the pi amplitude from a linear
# rabi_slope / rabi_intercept calibration. With the workflow structure the pi
# amplitude for the *current* drive length is a qubit parameter, so scale it
# instead of re-deriving it (or set `ge_drive_amplitude_pi_arr` manually).
rabi_slope = qubit_to_measure.parameters.ge_drive_amplitude_pi * \
    qubit_to_measure.parameters.ge_drive_length
ge_drive_amplitude_pi_arr = np.clip(rabi_slope / drive_length_arr, 0.0, 1.0)

print(pd.DataFrame({
    'ge_drive_length': drive_length_arr,
    'rabi_freq_MHz': rabi_freq_arr * 1e-6,
    'ge_drive_amplitude_pi': ge_drive_amplitude_pi_arr,
}))

qubit_to_measure = qubits[0]
# Out:
#     ge_drive_length  rabi_freq_MHz  ge_drive_amplitude_pi
# 0      6.000000e-08      16.666667               0.591334
# 1      6.971429e-08      14.344262               0.508935
# 2      7.942857e-08      12.589928               0.446691
# 3      8.914286e-08      11.217949               0.398014
# 4      9.885714e-08      10.115607               0.358902
# 5      1.085714e-07       9.210526               0.326790
# 6      1.182857e-07       8.454106               0.299952
# 7      1.280000e-07       7.812500               0.277188
# 8      1.377143e-07       7.261411               0.257635
# 9      1.474286e-07       6.782946               0.240659
# 10     1.571429e-07       6.363636               0.225782
# 11     1.668571e-07       5.993151               0.212637
# 12     1.765714e-07       5.663430               0.200939
# 13     1.862857e-07       5.368098               0.190460
# 14     1.960000e-07       5.102041               0.181021
# 15     2.057143e-07       4.861111               0.172473
# 16     2.154286e-07       4.641910               0.164695
# 17     2.251429e-07       4.441624               0.157589
# 18     2.348571e-07       4.257908               0.151071
# 19     2.445714e-07       4.088785               0.145070
# 20     2.542857e-07       3.932584               0.139528
# 21     2.640000e-07       3.787879               0.134394
# 22     2.737143e-07       3.653445               0.129624
# 23     2.834286e-07       3.528226               0.125182
# 24     2.931429e-07       3.411306               0.121033
# 25     3.028571e-07       3.301887               0.117151
# 26     3.125714e-07       3.199269               0.113510
# 27     3.222857e-07       3.102837               0.110089
# 28     3.320000e-07       3.012048               0.106868
# 29     3.417143e-07       2.926421               0.103830
# 30     3.514286e-07       2.845528               0.100960
# 31     3.611429e-07       2.768987               0.098244
# 32     3.708571e-07       2.696456               0.095670
# 33     3.805714e-07       2.627628               0.093228
# 34     3.902857e-07       2.562225               0.090908
# 35     4.000000e-07       2.500000               0.088700

# %% [markdown]
# #### Run Workflow

# %%
options = iq_blobs.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(True)  # one IQ-blob figure per drive length
options.do_analysis(True)

ss_drive_length_sweep_shots = []
ss_drive_length_sweep_metrics = []
ss_drive_length_sweep_fidelities = []

for drive_length, drive_amplitude_pi in zip(drive_length_arr,
                                            ge_drive_amplitude_pi_arr):
    print('Drive length:', round(drive_length * 1e9, 3), 'ns',
          '| pi amplitude:', round(float(drive_amplitude_pi), 5))

    temporary_parameters = {}
    temp_pars = deepcopy(qubit_to_measure.parameters)
    temp_pars.ge_drive_length = float(drive_length)
    temp_pars.ge_drive_amplitude_pi = float(drive_amplitude_pi)
    # temp_pars.ge_drive_pulse = ge_drive_pulse
    temporary_parameters[qubit_to_measure.uid] = temp_pars

    exp_workflow = iq_blobs.experiment_workflow(
        session=session,
        qpu=qpu,
        qubits=[qubit_to_measure.uid],
        states=states,
        options=options,
        temporary_parameters=temporary_parameters,
    )
    workflow_result = exp_workflow.run()

    shots = collect_shots_from_result(
        workflow_result.output, qubit_to_measure.uid, states
    )
    ss_drive_length_sweep_shots.append(np.array([shots[s] for s in states]))

    res = analyze_single_shots(shots, state_0='g', state_1='e', plot=False)
    ss_drive_length_sweep_metrics.append(
        {k: v for k, v in res.items() if isinstance(v, (int, float, complex))}
    )
    ss_drive_length_sweep_fidelities.append(
        workflow_result.tasks['analysis_workflow'].output.get(
            qubit_to_measure.uid, np.nan
        )
    )

ss_drive_length_sweep_arr = np.array(ss_drive_length_sweep_shots)
print('Sweep array shape (drive lengths, states, shots):',
      ss_drive_length_sweep_arr.shape)
# Out:
# Drive length: 60.0 ns | pi amplitude: 0.59133
# [2026.08.31 12:09:16.088] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:09:16.088] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:09:16.088332Z
# [2026.08.31 12:09:16.103] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:09:16.290] INFO    Task 'temporary_qpu': started at 2026-08-31 09:09:16.290981Z
# [2026.08.31 12:09:16.330] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:09:16.330398Z
# [2026.08.31 12:09:16.407] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:09:16.407] INFO    09:09:16.407652Z
# [2026.08.31 12:09:16.456] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:09:16.456306Z
# [2026.08.31 12:09:16.544] INFO    Task 'create_experiment': started at 2026-08-31 09:09:16.544902Z
# [2026.08.31 12:09:16.672] INFO    Task 'create_experiment': ended at 2026-08-31 09:09:16.670642Z
# [2026.08.31 12:09:16.762] INFO    Task 'compile_experiment': started at 2026-08-31 09:09:16.762213Z
# [2026.08.31 12:09:16.842] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:09:16.845] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:09:16.847] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:09:16.847] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:09:16.847] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:09:16.851] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:09:16.853] INFO    Code generation completed for all AWGs. [0.002 s]
# [2026.08.31 12:09:16.856] INFO    Completed compilation step 1 of 1. [0.005 s]
# [2026.08.31 12:09:16.863] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:09:16.866] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:09:16.867] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:09:16.867] INFO      SHFQC_DEV12192        0         11            0           1      7616
# [2026.08.31 12:09:16.871] INFO      SHFQC_DEV12192_sg     0         14            2           1       256
# [2026.08.31 12:09:16.874] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:09:16.874] INFO      TOTAL                           25            2                  7872
# [2026.08.31 12:09:16.877] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:09:16.889] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:09:16.889] INFO    Task 'compile_experiment': ended at 2026-08-31 09:09:16.889998Z
# [2026.08.31 12:09:17.061] INFO    Task 'run_experiment': started at 2026-08-31 09:09:17.060183Z
# [2026.08.31 12:09:17.191] INFO    Starting near-time execution...
# [2026.08.31 12:09:17.269] INFO    Estimated RT execution time: 19.79 s.
# [2026.08.31 12:09:37.348] INFO    Finished near-time execution.
# [2026.08.31 12:09:37.397] INFO    Task 'run_experiment': ended at 2026-08-31 09:09:37.397995Z
# [2026.08.31 12:09:37.541] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:09:37.541] INFO      Workflow 'analysis_workflow': execution started at 2026-08-31
# [2026.08.31 12:09:37.541] INFO      09:09:37.541980Z
# [2026.08.31 12:09:37.541] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:09:37.635] INFO    Task 'collect_shots': started at 2026-08-31 09:09:37.635599Z
# [2026.08.31 12:09:37.682] INFO    Task 'collect_shots': ended at 2026-08-31 09:09:37.668602Z
# [2026.08.31 12:09:37.852] INFO    Task 'fit_data': started at 2026-08-31 09:09:37.852550Z
# [2026.08.31 12:09:38.037] INFO    Task 'fit_data': ended at 2026-08-31 09:09:38.037434Z
# [2026.08.31 12:09:38.120] INFO    Task 'calculate_assignment_matrices': started at 2026-08-31 09:09:38.120081Z
# [2026.08.31 12:09:38.248] INFO    Task 'calculate_assignment_matrices': ended at 2026-08-31 09:09:38.248962Z
# [2026.08.31 12:09:38.328] INFO    Task 'calculate_assignment_fidelities': started at 2026-08-31 09:09:38.328685Z
# [2026.08.31 12:09:38.406] INFO    Task 'calculate_assignment_fidelities': ended at 2026-08-31 09:09:38.406650Z
# [2026.08.31 12:09:38.454] INFO    Task 'plot_iq_blobs': started at 2026-08-31 09:09:38.452228Z
# [2026.08.31 12:09:38.568] INFO    Artifact: 'IQ_blobs_Q2' of type 'Figure' logged at 2026-08-31 09:09:38.568505Z
# [2026.08.31 12:09:39.326] INFO    Task 'plot_iq_blobs': ended at 2026-08-31 09:09:39.326897Z
# [2026.08.31 12:09:39.374] INFO    Task 'plot_assignment_matrices': started at 2026-08-31 09:09:39.374602Z
# [2026.08.31 12:09:39.490] INFO    Artifact: 'Assignment_matrix_Q2' of type 'Figure' logged at 2026-08-31
# [2026.08.31 12:09:39.494] INFO    09:09:39.490995Z
# [2026.08.31 12:09:39.984] INFO    Task 'plot_assignment_matrices': ended at 2026-08-31 09:09:39.984310Z
# [2026.08.31 12:09:40.017] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:09:40.017] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-31 09:09:40.017872Z
# [2026.08.31 12:09:40.017] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:09:40.048] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:09:40.048] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:09:40.048890Z
# [2026.08.31 12:09:40.048] INFO     ──────────────────────────────────────────────────────────────────────────────
# Drive length: 69.714 ns | pi amplitude: 0.50894
# [2026.08.31 12:09:40.198] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:09:40.198] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:09:40.198689Z
# [2026.08.31 12:09:40.198] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:09:40.415] INFO    Task 'temporary_qpu': started at 2026-08-31 09:09:40.415807Z
# [2026.08.31 12:09:40.505] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:09:40.505028Z
# [2026.08.31 12:09:40.593] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:09:40.593] INFO    09:09:40.593388Z
# [2026.08.31 12:09:40.629] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:09:40.629995Z
# [2026.08.31 12:09:40.720] INFO    Task 'create_experiment': started at 2026-08-31 09:09:40.720836Z
# [2026.08.31 12:09:40.820] INFO    Task 'create_experiment': ended at 2026-08-31 09:09:40.820318Z
# [2026.08.31 12:09:40.907] INFO    Task 'compile_experiment': started at 2026-08-31 09:09:40.907348Z
# [2026.08.31 12:09:41.012] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:09:41.018] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:09:41.018] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:09:41.018] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:09:41.018] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:09:41.023] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:09:41.029] INFO    Code generation completed for all AWGs. [0.004 s]
# [2026.08.31 12:09:41.030] INFO    Completed compilation step 1 of 1. [0.009 s]
# [2026.08.31 12:09:41.037] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:09:41.037] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:09:41.037] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:09:41.037] INFO      SHFQC_DEV12192        0         11            0           1      7616
# [2026.08.31 12:09:41.045] INFO      SHFQC_DEV12192_sg     0         14            2           1       288
# [2026.08.31 12:09:41.045] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:09:41.047] INFO      TOTAL                           25            2                  7904
# [2026.08.31 12:09:41.047] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:09:41.061] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:09:41.071] INFO    Task 'compile_experiment': ended at 2026-08-31 09:09:41.071864Z
# [2026.08.31 12:09:41.189] INFO    Task 'run_experiment': started at 2026-08-31 09:09:41.189891Z
# [2026.08.31 12:09:41.349] INFO    Starting near-time execution...
# [2026.08.31 12:09:41.431] INFO    Estimated RT execution time: 19.79 s.
# [2026.08.31 12:10:01.530] INFO    Finished near-time execution.
# [2026.08.31 12:10:01.605] INFO    Task 'run_experiment': ended at 2026-08-31 09:10:01.605797Z
# [2026.08.31 12:10:01.767] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:01.767] INFO      Workflow 'analysis_workflow': execution started at 2026-08-31
# [2026.08.31 12:10:01.767] INFO      09:10:01.767869Z
# [2026.08.31 12:10:01.767] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:01.881] INFO    Task 'collect_shots': started at 2026-08-31 09:10:01.881049Z
# [2026.08.31 12:10:01.940] INFO    Task 'collect_shots': ended at 2026-08-31 09:10:01.940341Z
# [2026.08.31 12:10:02.122] INFO    Task 'fit_data': started at 2026-08-31 09:10:02.122227Z
# [2026.08.31 12:10:02.310] INFO    Task 'fit_data': ended at 2026-08-31 09:10:02.310882Z
# [2026.08.31 12:10:02.396] INFO    Task 'calculate_assignment_matrices': started at 2026-08-31 09:10:02.396354Z
# [2026.08.31 12:10:02.551] INFO    Task 'calculate_assignment_matrices': ended at 2026-08-31 09:10:02.549496Z
# [2026.08.31 12:10:02.655] INFO    Task 'calculate_assignment_fidelities': started at 2026-08-31 09:10:02.655470Z
# [2026.08.31 12:10:02.749] INFO    Task 'calculate_assignment_fidelities': ended at 2026-08-31 09:10:02.749319Z
# [2026.08.31 12:10:02.813] INFO    Task 'plot_iq_blobs': started at 2026-08-31 09:10:02.812691Z
# [2026.08.31 12:10:03.005] INFO    Artifact: 'IQ_blobs_Q2' of type 'Figure' logged at 2026-08-31 09:10:03.005864Z
# [2026.08.31 12:10:03.699] INFO    Task 'plot_iq_blobs': ended at 2026-08-31 09:10:03.699348Z
# [2026.08.31 12:10:03.746] INFO    Task 'plot_assignment_matrices': started at 2026-08-31 09:10:03.746167Z
# [2026.08.31 12:10:03.875] INFO    Artifact: 'Assignment_matrix_Q2' of type 'Figure' logged at 2026-08-31
# [2026.08.31 12:10:03.875] INFO    09:10:03.875003Z
# [2026.08.31 12:10:04.344] INFO    Task 'plot_assignment_matrices': ended at 2026-08-31 09:10:04.344097Z
# [2026.08.31 12:10:04.390] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:04.390] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-31 09:10:04.374354Z
# [2026.08.31 12:10:04.391] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:04.423] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:04.423] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:10:04.423541Z
# [2026.08.31 12:10:04.423] INFO     ──────────────────────────────────────────────────────────────────────────────
# Drive length: 79.429 ns | pi amplitude: 0.44669
# [2026.08.31 12:10:04.586] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:04.586] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:10:04.584004Z
# [2026.08.31 12:10:04.587] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:04.809] INFO    Task 'temporary_qpu': started at 2026-08-31 09:10:04.793717Z
# [2026.08.31 12:10:04.845] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:10:04.845088Z
# [2026.08.31 12:10:04.937] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:10:04.937] INFO    09:10:04.937111Z
# [2026.08.31 12:10:04.969] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:10:04.969964Z
# [2026.08.31 12:10:05.049] INFO    Task 'create_experiment': started at 2026-08-31 09:10:05.049414Z
# [2026.08.31 12:10:05.161] INFO    Task 'create_experiment': ended at 2026-08-31 09:10:05.161118Z
# [2026.08.31 12:10:05.241] INFO    Task 'compile_experiment': started at 2026-08-31 09:10:05.241731Z
# [2026.08.31 12:10:05.323] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:10:05.323] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:10:05.323] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:10:05.323] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:10:05.337] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:10:05.337] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:10:05.341] INFO    Code generation completed for all AWGs. [0.004 s]
# [2026.08.31 12:10:05.345] INFO    Completed compilation step 1 of 1. [0.010 s]
# [2026.08.31 12:10:05.355] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:05.355] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:10:05.355] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:05.363] INFO      SHFQC_DEV12192        0         11            0           1      7616
# [2026.08.31 12:10:05.363] INFO      SHFQC_DEV12192_sg     0         14            2           1       320
# [2026.08.31 12:10:05.363] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:05.363] INFO      TOTAL                           25            2                  7936
# [2026.08.31 12:10:05.368] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:05.387] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:10:05.387] INFO    Task 'compile_experiment': ended at 2026-08-31 09:10:05.387451Z
# [2026.08.31 12:10:05.499] INFO    Task 'run_experiment': started at 2026-08-31 09:10:05.499145Z
# [2026.08.31 12:10:05.686] INFO    Starting near-time execution...
# [2026.08.31 12:10:05.788] INFO    Estimated RT execution time: 19.79 s.
# [2026.08.31 12:10:25.850] INFO    Finished near-time execution.
# [2026.08.31 12:10:25.903] INFO    Task 'run_experiment': ended at 2026-08-31 09:10:25.903385Z
# [2026.08.31 12:10:26.038] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:26.038] INFO      Workflow 'analysis_workflow': execution started at 2026-08-31
# [2026.08.31 12:10:26.038] INFO      09:10:26.038158Z
# [2026.08.31 12:10:26.038] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:26.149] INFO    Task 'collect_shots': started at 2026-08-31 09:10:26.149310Z
# [2026.08.31 12:10:26.202] INFO    Task 'collect_shots': ended at 2026-08-31 09:10:26.202175Z
# [2026.08.31 12:10:26.358] INFO    Task 'fit_data': started at 2026-08-31 09:10:26.358053Z
# [2026.08.31 12:10:26.560] INFO    Task 'fit_data': ended at 2026-08-31 09:10:26.560110Z
# [2026.08.31 12:10:26.647] INFO    Task 'calculate_assignment_matrices': started at 2026-08-31 09:10:26.647978Z
# [2026.08.31 12:10:26.778] INFO    Task 'calculate_assignment_matrices': ended at 2026-08-31 09:10:26.778790Z
# [2026.08.31 12:10:26.874] INFO    Task 'calculate_assignment_fidelities': started at 2026-08-31 09:10:26.874477Z
# [2026.08.31 12:10:26.956] INFO    Task 'calculate_assignment_fidelities': ended at 2026-08-31 09:10:26.956412Z
# [2026.08.31 12:10:26.997] INFO    Task 'plot_iq_blobs': started at 2026-08-31 09:10:26.997863Z
# [2026.08.31 12:10:27.121] INFO    Artifact: 'IQ_blobs_Q2' of type 'Figure' logged at 2026-08-31 09:10:27.121062Z
# [2026.08.31 12:10:27.893] INFO    Task 'plot_iq_blobs': ended at 2026-08-31 09:10:27.893767Z
# [2026.08.31 12:10:27.938] INFO    Task 'plot_assignment_matrices': started at 2026-08-31 09:10:27.938342Z
# [2026.08.31 12:10:28.036] INFO    Artifact: 'Assignment_matrix_Q2' of type 'Figure' logged at 2026-08-31
# [2026.08.31 12:10:28.036] INFO    09:10:28.036188Z
# [2026.08.31 12:10:28.374] INFO    Task 'plot_assignment_matrices': ended at 2026-08-31 09:10:28.374202Z
# [2026.08.31 12:10:28.414] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:28.414] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-31 09:10:28.414807Z
# [2026.08.31 12:10:28.414] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:28.455] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:28.455] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:10:28.455274Z
# [2026.08.31 12:10:28.455] INFO     ──────────────────────────────────────────────────────────────────────────────
# Drive length: 89.143 ns | pi amplitude: 0.39801
# [2026.08.31 12:10:28.615] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:28.615] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:10:28.615735Z
# [2026.08.31 12:10:28.615] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:28.855] INFO    Task 'temporary_qpu': started at 2026-08-31 09:10:28.855341Z
# [2026.08.31 12:10:28.904] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:10:28.904517Z
# [2026.08.31 12:10:28.987] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:10:28.987] INFO    09:10:28.987036Z
# [2026.08.31 12:10:29.023] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:10:29.023171Z
# [2026.08.31 12:10:29.099] INFO    Task 'create_experiment': started at 2026-08-31 09:10:29.099377Z
# [2026.08.31 12:10:29.216] INFO    Task 'create_experiment': ended at 2026-08-31 09:10:29.216259Z
# [2026.08.31 12:10:29.296] INFO    Task 'compile_experiment': started at 2026-08-31 09:10:29.296204Z
# [2026.08.31 12:10:29.372] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:10:29.388] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:10:29.388] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:10:29.388] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:10:29.388] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:10:29.396] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:10:29.400] INFO    Code generation completed for all AWGs. [0.002 s]
# [2026.08.31 12:10:29.400] INFO    Completed compilation step 1 of 1. [0.006 s]
# [2026.08.31 12:10:29.408] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:29.408] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:10:29.415] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:29.415] INFO      SHFQC_DEV12192        0         11            0           1      7616
# [2026.08.31 12:10:29.415] INFO      SHFQC_DEV12192_sg     0         14            2           1       384
# [2026.08.31 12:10:29.415] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:29.415] INFO      TOTAL                           25            2                  8000
# [2026.08.31 12:10:29.415] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:29.438] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:10:29.448] INFO    Task 'compile_experiment': ended at 2026-08-31 09:10:29.438794Z
# [2026.08.31 12:10:29.565] INFO    Task 'run_experiment': started at 2026-08-31 09:10:29.565825Z
# [2026.08.31 12:10:29.710] INFO    Starting near-time execution...
# [2026.08.31 12:10:29.796] INFO    Estimated RT execution time: 19.79 s.
# [2026.08.31 12:10:49.867] INFO    Finished near-time execution.
# [2026.08.31 12:10:49.938] INFO    Task 'run_experiment': ended at 2026-08-31 09:10:49.938375Z
# [2026.08.31 12:10:50.072] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:50.072] INFO      Workflow 'analysis_workflow': execution started at 2026-08-31
# [2026.08.31 12:10:50.074] INFO      09:10:50.069765Z
# [2026.08.31 12:10:50.074] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:50.163] INFO    Task 'collect_shots': started at 2026-08-31 09:10:50.163378Z
# [2026.08.31 12:10:50.194] INFO    Task 'collect_shots': ended at 2026-08-31 09:10:50.194817Z
# [2026.08.31 12:10:50.386] INFO    Task 'fit_data': started at 2026-08-31 09:10:50.386859Z
# [2026.08.31 12:10:50.579] INFO    Task 'fit_data': ended at 2026-08-31 09:10:50.579479Z
# [2026.08.31 12:10:50.674] INFO    Task 'calculate_assignment_matrices': started at 2026-08-31 09:10:50.674254Z
# [2026.08.31 12:10:50.851] INFO    Task 'calculate_assignment_matrices': ended at 2026-08-31 09:10:50.851954Z
# [2026.08.31 12:10:50.952] INFO    Task 'calculate_assignment_fidelities': started at 2026-08-31 09:10:50.952437Z
# [2026.08.31 12:10:51.031] INFO    Task 'calculate_assignment_fidelities': ended at 2026-08-31 09:10:51.031814Z
# [2026.08.31 12:10:51.092] INFO    Task 'plot_iq_blobs': started at 2026-08-31 09:10:51.092700Z
# [2026.08.31 12:10:51.237] INFO    Artifact: 'IQ_blobs_Q2' of type 'Figure' logged at 2026-08-31 09:10:51.237511Z
# [2026.08.31 12:10:52.092] INFO    Task 'plot_iq_blobs': ended at 2026-08-31 09:10:52.092442Z
# [2026.08.31 12:10:52.133] INFO    Task 'plot_assignment_matrices': started at 2026-08-31 09:10:52.133226Z
# [2026.08.31 12:10:52.255] INFO    Artifact: 'Assignment_matrix_Q2' of type 'Figure' logged at 2026-08-31
# [2026.08.31 12:10:52.258] INFO    09:10:52.255656Z
# [2026.08.31 12:10:52.542] INFO    Task 'plot_assignment_matrices': ended at 2026-08-31 09:10:52.542985Z
# [2026.08.31 12:10:52.578] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:52.589] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-31 09:10:52.578187Z
# [2026.08.31 12:10:52.589] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:52.637] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:52.640] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:10:52.628295Z
# [2026.08.31 12:10:52.640] INFO     ──────────────────────────────────────────────────────────────────────────────
# Drive length: 98.857 ns | pi amplitude: 0.3589
# [2026.08.31 12:10:52.797] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:52.797] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:10:52.797526Z
# [2026.08.31 12:10:52.797] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:53.022] INFO    Task 'temporary_qpu': started at 2026-08-31 09:10:53.022473Z
# [2026.08.31 12:10:53.071] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:10:53.071298Z
# [2026.08.31 12:10:53.149] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:10:53.149] INFO    09:10:53.149744Z
# [2026.08.31 12:10:53.191] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:10:53.191955Z
# [2026.08.31 12:10:53.279] INFO    Task 'create_experiment': started at 2026-08-31 09:10:53.278071Z
# [2026.08.31 12:10:53.390] INFO    Task 'create_experiment': ended at 2026-08-31 09:10:53.390123Z
# [2026.08.31 12:10:53.470] INFO    Task 'compile_experiment': started at 2026-08-31 09:10:53.470539Z
# [2026.08.31 12:10:53.598] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:10:53.598] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:10:53.598] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:10:53.598] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:10:53.598] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:10:53.598] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:10:53.616] INFO    Code generation completed for all AWGs. [0.005 s]
# [2026.08.31 12:10:53.616] INFO    Completed compilation step 1 of 1. [0.007 s]
# [2026.08.31 12:10:53.616] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:53.616] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:10:53.616] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:53.616] INFO      SHFQC_DEV12192        0         11            0           1      7616
# [2026.08.31 12:10:53.616] INFO      SHFQC_DEV12192_sg     0         14            2           1       416
# [2026.08.31 12:10:53.632] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:53.632] INFO      TOTAL                           25            2                  8032
# [2026.08.31 12:10:53.632] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:10:53.649] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:10:53.649] INFO    Task 'compile_experiment': ended at 2026-08-31 09:10:53.649089Z
# [2026.08.31 12:10:53.798] INFO    Task 'run_experiment': started at 2026-08-31 09:10:53.798764Z
# [2026.08.31 12:10:54.003] INFO    Starting near-time execution...
# [2026.08.31 12:10:54.099] INFO    Estimated RT execution time: 19.79 s.
# [2026.08.31 12:11:14.205] INFO    Finished near-time execution.
# [2026.08.31 12:11:14.273] INFO    Task 'run_experiment': ended at 2026-08-31 09:11:14.273935Z
# [2026.08.31 12:11:14.414] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:11:14.414] INFO      Workflow 'analysis_workflow': execution started at 2026-08-31
# [2026.08.31 12:11:14.414] INFO      09:11:14.414316Z
# [2026.08.31 12:11:14.414] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:11:14.525] INFO    Task 'collect_shots': started at 2026-08-31 09:11:14.525068Z
# [2026.08.31 12:11:14.572] INFO    Task 'collect_shots': ended at 2026-08-31 09:11:14.572881Z
# [2026.08.31 12:11:14.781] INFO    Task 'fit_data': started at 2026-08-31 09:11:14.781783Z
# [2026.08.31 12:11:14.964] INFO    Task 'fit_data': ended at 2026-08-31 09:11:14.964885Z
# [2026.08.31 12:11:15.039] INFO    Task 'calculate_assignment_matrices': started at 2026-08-31 09:11:15.039514Z
# [2026.08.31 12:11:15.150] INFO    Task 'calculate_assignment_matrices': ended at 2026-08-31 09:11:15.150729Z
# [2026.08.31 12:11:15.229] INFO    Task 'calculate_assignment_fidelities': started at 2026-08-31 09:11:15.229326Z
# [2026.08.31 12:11:15.326] INFO    Task 'calculate_assignment_fidelities': ended at 2026-08-31 09:11:15.326027Z
# [2026.08.31 12:11:15.366] INFO    Task 'plot_iq_blobs': started at 2026-08-31 09:11:15.366376Z
# [2026.08.31 12:11:15.503] INFO    Artifact: 'IQ_blobs_Q2' of type 'Figure' logged at 2026-08-31 09:11:15.503126Z
# [2026.08.31 12:11:16.310] INFO    Task 'plot_iq_blobs': ended at 2026-08-31 09:11:16.310983Z
# [2026.08.31 12:11:16.356] INFO    Task 'plot_assignment_matrices': started at 2026-08-31 09:11:16.356392Z
# [2026.08.31 12:11:16.481] INFO    Artifact: 'Assignment_matrix_Q2' of type 'Figure' logged at 2026-08-31
# [2026.08.31 12:11:16.481] INFO    09:11:16.468626Z
# [2026.08.31 12:11:16.808] INFO    Task 'plot_assignment_matrices': ended at 2026-08-31 09:11:16.807060Z
# [2026.08.31 12:11:16.855] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:11:16.855] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-31 09:11:16.855881Z
# [2026.08.31 12:11:16.855] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:11:16.919] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:11:16.919] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:11:16.919737Z
# [2026.08.31 12:11:16.919] INFO     ──────────────────────────────────────────────────────────────────────────────
# Drive length: 108.571 ns | pi amplitude: 0.32679
# [2026.08.31 12:11:17.065] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:11:17.065] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:11:17.065912Z
# [2026.08.31 12:11:17.065] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:11:17.302] INFO    Task 'temporary_qpu': started at 2026-08-31 09:11:17.302845Z
# [2026.08.31 12:11:17.339] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:11:17.339627Z
# [2026.08.31 12:11:17.451] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:11:17.451] INFO    09:11:17.451644Z
# [2026.08.31 12:11:17.499] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:11:17.499308Z
# [2026.08.31 12:11:17.599] INFO    Task 'create_experiment': started at 2026-08-31 09:11:17.599679Z
# [2026.08.31 12:11:17.743] INFO    Task 'create_experiment': ended at 2026-08-31 09:11:17.743410Z
# [2026.08.31 12:11:17.854] INFO    Task 'compile_experiment': started at 2026-08-31 09:11:17.853318Z
# [2026.08.31 12:11:17.934] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:11:17.934] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:11:17.950] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:11:17.950] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:11:17.952] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:11:17.952] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:11:17.955] INFO    Code generation completed for all AWGs. [0.002 s]
# [2026.08.31 12:11:17.955] INFO    Completed compilation step 1 of 1. [0.005 s]
# [2026.08.31 12:11:17.967] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:11:17.967] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:11:17.967] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:11:17.967] INFO      SHFQC_DEV12192        0         11            0           1      7616
# [2026.08.31 12:11:17.967] INFO      SHFQC_DEV12192_sg     0         14            2           1       448
# [2026.08.31 12:11:17.967] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:11:17.967] INFO      TOTAL                           25            2                  8064
# [2026.08.31 12:11:17.967] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:11:18.000] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:11:18.002] INFO    Task 'compile_experiment': ended at 2026-08-31 09:11:18.000676Z
# [2026.08.31 12:11:18.114] INFO    Task 'run_experiment': started at 2026-08-31 09:11:18.114189Z
# [2026.08.31 12:11:18.257] INFO    Starting near-time execution...
# [2026.08.31 12:11:18.351] INFO    Estimated RT execution time: 19.79 s.
# [2026.08.31 12:11:38.428] INFO    Finished near-time execution.
# [2026.08.31 12:11:38.526] INFO    Task 'run_experiment': ended at 2026-08-31 09:11:38.526815Z
# [2026.08.31 12:11:38.683] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:11:38.683] INFO      Workflow 'analysis_workflow': execution started at 2026-08-31
# [2026.08.31 12:11:38.683] INFO      09:11:38.683960Z
# [2026.08.31 12:11:38.683] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:11:38.781] INFO    Task 'collect_shots': started at 2026-08-31 09:11:38.781974Z
# [2026.08.31 12:11:38.828] INFO    Task 'collect_shots': ended at 2026-08-31 09:11:38.812496Z
# [2026.08.31 12:11:38.989] INFO    Task 'fit_data': started at 2026-08-31 09:11:38.989614Z
# [2026.08.31 12:11:39.181] INFO    Task 'fit_data': ended at 2026-08-31 09:11:39.181204Z
# [2026.08.31 12:11:39.261] INFO    Task 'calculate_assignment_matrices': started at 2026-08-31 09:11:39.261645Z
# [2026.08.31 12:11:39.390] INFO    Task 'calculate_assignment_matrices': ended at 2026-08-31 09:11:39.390206Z
# [2026.08.31 12:11:39.486] INFO    Task 'calculate_assignment_fidelities': started at 2026-08-31 09:11:39.486569Z
# [2026.08.31 12:11:39.583] INFO    Task 'calculate_assignment_fidelities': ended at 2026-08-31 09:11:39.583041Z
# [2026.08.31 12:11:39.630] INFO    Task 'plot_iq_blobs': started at 2026-08-31 09:11:39.630803Z
# [2026.08.31 12:11:39.789] INFO    Artifact: 'IQ_blobs_Q2' of type 'Figure' logged at 2026-08-31 09:11:39.789747Z
# [2026.08.31 12:11:40.455] INFO    Task 'plot_iq_blobs': ended at 2026-08-31 09:11:40.455706Z
# [2026.08.31 12:11:40.504] INFO    Task 'plot_assignment_matrices': started at 2026-08-31 09:11:40.504541Z
# [2026.08.31 12:11:40.665] INFO    Artifact: 'Assignment_matrix_Q2' of type 'Figure' logged at 2026-08-31
# [2026.08.31 12:11:40.678] INFO    09:11:40.665898Z
# [2026.08.31 12:11:41.014] INFO    Task 'plot_assignment_matrices': ended at 2026-08-31 09:11:41.014476Z
# [2026.08.31 12:11:41.062] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:11:41.062] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-31 09:11:41.062278Z
# [2026.08.31 12:11:41.062] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:11:41.111] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:11:41.111] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:11:41.111050Z
# [2026.08.31 12:11:41.111] INFO     ──────────────────────────────────────────────────────────────────────────────
# Drive length: 118.286 ns | pi amplitude: 0.29995
# [2026.08.31 12:11:41.257] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:11:41.257] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:11:41.257170Z
# [2026.08.31 12:11:41.257] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:11:41.483] INFO    Task 'temporary_qpu': started at 2026-08-31 09:11:41.483806Z
# [2026.08.31 12:11:41.530] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:11:41.530383Z
# [2026.08.31 12:11:41.609] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:11:41.609] INFO    09:11:41.609792Z
# [2026.08.31 12:11:41.657] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:11:41.657349Z
# [2026.08.31 12:11:41.754] INFO    Task 'create_experiment': started at 2026-08-31 09:11:41.754152Z
# [2026.08.31 12:11:41.885] INFO    Task 'create_experiment': ended at 2026-08-31 09:11:41.885875Z
# [2026.08.31 12:11:42.001] INFO    Task 'compile_experiment': started at 2026-08-31 09:11:41.999568Z
# [2026.08.31 12:11:42.106] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:11:42.106] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:11:42.115] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:11:42.115] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:11:42.117] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:11:42.117] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:11:42.123] INFO    Code generation completed for all AWGs. [0.005 s]
# [2026.08.31 12:11:42.124] INFO    Completed compilation step 1 of 1. [0.008 s]
# [2026.08.31 12:11:42.132] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:11:42.132] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:11:42.132] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:11:42.139] INFO      SHFQC_DEV12192        0         11            0           1      7616
# [2026.08.31 12:11:42.140] INFO      SHFQC_DEV12192_sg     0         14            2           1       480
# [2026.08.31 12:11:42.140] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:11:42.140] INFO      TOTAL                           25            2                  8096
# [2026.08.31 12:11:42.140] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:11:42.160] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:11:42.160] INFO    Task 'compile_experiment': ended at 2026-08-31 09:11:42.160198Z
# [2026.08.31 12:11:42.317] INFO    Task 'run_experiment': started at 2026-08-31 09:11:42.317784Z
# [2026.08.31 12:11:42.464] INFO    Starting near-time execution...
# [2026.08.31 12:11:42.546] INFO    Estimated RT execution time: 19.79 s.
# [2026.08.31 12:12:02.652] INFO    Finished near-time execution.
# [2026.08.31 12:12:02.717] INFO    Task 'run_experiment': ended at 2026-08-31 09:12:02.717533Z
# [2026.08.31 12:12:02.904] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:12:02.904] INFO      Workflow 'analysis_workflow': execution started at 2026-08-31
# [2026.08.31 12:12:02.904] INFO      09:12:02.904719Z
# [2026.08.31 12:12:02.910] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:12:03.070] INFO    Task 'collect_shots': started at 2026-08-31 09:12:03.070960Z
# [2026.08.31 12:12:03.131] INFO    Task 'collect_shots': ended at 2026-08-31 09:12:03.131016Z
# [2026.08.31 12:12:03.298] INFO    Task 'fit_data': started at 2026-08-31 09:12:03.298296Z
# [2026.08.31 12:12:03.486] INFO    Task 'fit_data': ended at 2026-08-31 09:12:03.486486Z
# [2026.08.31 12:12:03.594] INFO    Task 'calculate_assignment_matrices': started at 2026-08-31 09:12:03.583943Z
# [2026.08.31 12:12:03.748] INFO    Task 'calculate_assignment_matrices': ended at 2026-08-31 09:12:03.748440Z
# [2026.08.31 12:12:03.905] INFO    Task 'calculate_assignment_fidelities': started at 2026-08-31 09:12:03.905628Z
# [2026.08.31 12:12:04.034] INFO    Task 'calculate_assignment_fidelities': ended at 2026-08-31 09:12:04.031873Z
# [2026.08.31 12:12:04.111] INFO    Task 'plot_iq_blobs': started at 2026-08-31 09:12:04.111515Z
# [2026.08.31 12:12:04.265] INFO    Artifact: 'IQ_blobs_Q2' of type 'Figure' logged at 2026-08-31 09:12:04.265328Z
# [2026.08.31 12:12:04.870] INFO    Task 'plot_iq_blobs': ended at 2026-08-31 09:12:04.870977Z
# [2026.08.31 12:12:04.968] INFO    Task 'plot_assignment_matrices': started at 2026-08-31 09:12:04.968045Z
# [2026.08.31 12:12:05.100] INFO    Artifact: 'Assignment_matrix_Q2' of type 'Figure' logged at 2026-08-31
# [2026.08.31 12:12:05.100] INFO    09:12:05.100203Z
# [2026.08.31 12:12:05.508] INFO    Task 'plot_assignment_matrices': ended at 2026-08-31 09:12:05.508220Z
# [2026.08.31 12:12:05.560] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:12:05.565] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-31 09:12:05.560207Z
# [2026.08.31 12:12:05.565] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:12:05.609] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:12:05.609] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:12:05.609440Z
# [2026.08.31 12:12:05.609] INFO     ──────────────────────────────────────────────────────────────────────────────
# Drive length: 128.0 ns | pi amplitude: 0.27719
# [2026.08.31 12:12:05.770] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:12:05.770] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:12:05.770101Z
# [2026.08.31 12:12:05.770] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:12:06.029] INFO    Task 'temporary_qpu': started at 2026-08-31 09:12:06.029176Z
# [2026.08.31 12:12:06.076] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:12:06.076427Z
# [2026.08.31 12:12:06.172] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:12:06.172] INFO    09:12:06.172820Z
# [2026.08.31 12:12:06.220] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:12:06.220287Z
# [2026.08.31 12:12:06.336] INFO    Task 'create_experiment': started at 2026-08-31 09:12:06.336337Z
# [2026.08.31 12:12:06.461] INFO    Task 'create_experiment': ended at 2026-08-31 09:12:06.461409Z
# [2026.08.31 12:12:06.558] INFO    Task 'compile_experiment': started at 2026-08-31 09:12:06.558398Z
# [2026.08.31 12:12:06.648] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:12:06.654] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:12:06.654] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:12:06.654] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:12:06.660] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:12:06.660] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:12:06.660] INFO    Code generation completed for all AWGs. [0.003 s]
# [2026.08.31 12:12:06.660] INFO    Completed compilation step 1 of 1. [0.005 s]
# [2026.08.31 12:12:06.671] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:12:06.671] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:12:06.671] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:12:06.671] INFO      SHFQC_DEV12192        0         11            0           1      7616
# [2026.08.31 12:12:06.671] INFO      SHFQC_DEV12192_sg     0         14            2           1       512
# [2026.08.31 12:12:06.671] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:12:06.671] INFO      TOTAL                           25            2                  8128
# [2026.08.31 12:12:06.671] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:12:06.702] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:12:06.702] INFO    Task 'compile_experiment': ended at 2026-08-31 09:12:06.702429Z
# [2026.08.31 12:12:06.846] INFO    Task 'run_experiment': started at 2026-08-31 09:12:06.846444Z
# [2026.08.31 12:12:07.022] INFO    Starting near-time execution...
# [2026.08.31 12:12:07.108] INFO    Estimated RT execution time: 19.79 s.
# [2026.08.31 12:12:27.186] INFO    Finished near-time execution.
# [2026.08.31 12:12:27.262] INFO    Task 'run_experiment': ended at 2026-08-31 09:12:27.262348Z
# [2026.08.31 12:12:27.434] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:12:27.434] INFO      Workflow 'analysis_workflow': execution started at 2026-08-31
# [2026.08.31 12:12:27.434] INFO      09:12:27.434172Z
# [2026.08.31 12:12:27.434] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:12:27.562] INFO    Task 'collect_shots': started at 2026-08-31 09:12:27.562737Z
# [2026.08.31 12:12:27.613] INFO    Task 'collect_shots': ended at 2026-08-31 09:12:27.613023Z
# [2026.08.31 12:12:27.803] INFO    Task 'fit_data': started at 2026-08-31 09:12:27.803205Z
# [2026.08.31 12:12:28.012] INFO    Task 'fit_data': ended at 2026-08-31 09:12:28.012627Z
# [2026.08.31 12:12:28.140] INFO    Task 'calculate_assignment_matrices': started at 2026-08-31 09:12:28.140148Z
# [2026.08.31 12:12:28.321] INFO    Task 'calculate_assignment_matrices': ended at 2026-08-31 09:12:28.321059Z
# [2026.08.31 12:12:28.429] INFO    Task 'calculate_assignment_fidelities': started at 2026-08-31 09:12:28.429196Z
# [2026.08.31 12:12:28.543] INFO    Task 'calculate_assignment_fidelities': ended at 2026-08-31 09:12:28.542842Z
# [2026.08.31 12:12:28.590] INFO    Task 'plot_iq_blobs': started at 2026-08-31 09:12:28.590933Z
# [2026.08.31 12:12:28.759] INFO    Artifact: 'IQ_blobs_Q2' of type 'Figure' logged at 2026-08-31 09:12:28.757327Z
# [2026.08.31 12:12:29.526] INFO    Task 'plot_iq_blobs': ended at 2026-08-31 09:12:29.526878Z
# [2026.08.31 12:12:29.573] INFO    Task 'plot_assignment_matrices': started at 2026-08-31 09:12:29.573440Z
# [2026.08.31 12:12:29.733] INFO    Artifact: 'Assignment_matrix_Q2' of type 'Figure' logged at 2026-08-31
# [2026.08.31 12:12:29.733] INFO    09:12:29.733772Z
# [2026.08.31 12:12:30.152] INFO    Task 'plot_assignment_matrices': ended at 2026-08-31 09:12:30.136727Z
# [2026.08.31 12:12:30.201] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:12:30.205] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-31 09:12:30.201680Z
# [2026.08.31 12:12:30.205] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:12:30.249] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:12:30.249] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:12:30.249203Z
# [2026.08.31 12:12:30.249] INFO     ──────────────────────────────────────────────────────────────────────────────
# Drive length: 137.714 ns | pi amplitude: 0.25764
# [2026.08.31 12:12:30.427] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:12:30.428] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:12:30.426409Z
# [2026.08.31 12:12:30.430] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:12:30.722] INFO    Task 'temporary_qpu': started at 2026-08-31 09:12:30.722833Z
# [2026.08.31 12:12:30.790] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:12:30.790907Z
# ...
# [2026.08.31 12:22:45.631] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:22:45.631] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:22:45.631] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:22:45.631] INFO      SHFQC_DEV12192        0         11            0           1      7616
# [2026.08.31 12:22:45.631] INFO      SHFQC_DEV12192_sg     0         14            2           1      1536
# [2026.08.31 12:22:45.631] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:22:45.638] INFO      TOTAL                           25            2                  9152
# [2026.08.31 12:22:45.638] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:22:45.654] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:22:45.654] INFO    Task 'compile_experiment': ended at 2026-08-31 09:22:45.654217Z
# [2026.08.31 12:22:45.766] INFO    Task 'run_experiment': started at 2026-08-31 09:22:45.766961Z
# [2026.08.31 12:22:45.903] INFO    Starting near-time execution...
# [2026.08.31 12:22:45.975] INFO    Estimated RT execution time: 19.80 s.
# [2026.08.31 12:23:06.047] INFO    Finished near-time execution.
# [2026.08.31 12:23:06.093] INFO    Task 'run_experiment': ended at 2026-08-31 09:23:06.093908Z
# [2026.08.31 12:23:06.238] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:23:06.238] INFO      Workflow 'analysis_workflow': execution started at 2026-08-31
# [2026.08.31 12:23:06.238] INFO      09:23:06.238243Z
# [2026.08.31 12:23:06.238] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:23:06.335] INFO    Task 'collect_shots': started at 2026-08-31 09:23:06.335181Z
# [2026.08.31 12:23:06.398] INFO    Task 'collect_shots': ended at 2026-08-31 09:23:06.398659Z
# [2026.08.31 12:23:06.639] INFO    Task 'fit_data': started at 2026-08-31 09:23:06.639827Z
# [2026.08.31 12:23:06.848] INFO    Task 'fit_data': ended at 2026-08-31 09:23:06.848057Z
# [2026.08.31 12:23:06.992] INFO    Task 'calculate_assignment_matrices': started at 2026-08-31 09:23:06.992540Z
# [2026.08.31 12:23:07.152] INFO    Task 'calculate_assignment_matrices': ended at 2026-08-31 09:23:07.152093Z
# [2026.08.31 12:23:07.223] INFO    Task 'calculate_assignment_fidelities': started at 2026-08-31 09:23:07.223398Z
# [2026.08.31 12:23:07.303] INFO    Task 'calculate_assignment_fidelities': ended at 2026-08-31 09:23:07.303281Z
# [2026.08.31 12:23:07.336] INFO    Task 'plot_iq_blobs': started at 2026-08-31 09:23:07.336131Z
# [2026.08.31 12:23:07.477] INFO    Artifact: 'IQ_blobs_Q2' of type 'Figure' logged at 2026-08-31 09:23:07.477031Z
# [2026.08.31 12:23:08.132] INFO    Task 'plot_iq_blobs': ended at 2026-08-31 09:23:08.132137Z
# [2026.08.31 12:23:08.180] INFO    Task 'plot_assignment_matrices': started at 2026-08-31 09:23:08.180380Z
# [2026.08.31 12:23:08.278] INFO    Artifact: 'Assignment_matrix_Q2' of type 'Figure' logged at 2026-08-31
# [2026.08.31 12:23:08.280] INFO    09:23:08.276844Z
# [2026.08.31 12:23:08.709] INFO    Task 'plot_assignment_matrices': ended at 2026-08-31 09:23:08.709794Z
# [2026.08.31 12:23:08.742] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:23:08.742] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-31 09:23:08.742498Z
# [2026.08.31 12:23:08.742] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:23:08.790] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:23:08.790] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:23:08.790338Z
# [2026.08.31 12:23:08.794] INFO     ──────────────────────────────────────────────────────────────────────────────
# Drive length: 390.286 ns | pi amplitude: 0.09091
# [2026.08.31 12:23:08.947] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:23:08.948] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:23:08.947105Z
# [2026.08.31 12:23:08.948] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:23:09.159] INFO    Task 'temporary_qpu': started at 2026-08-31 09:23:09.159747Z
# [2026.08.31 12:23:09.245] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:23:09.245718Z
# [2026.08.31 12:23:09.302] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:23:09.302] INFO    09:23:09.302834Z
# [2026.08.31 12:23:09.350] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:23:09.350067Z
# [2026.08.31 12:23:09.430] INFO    Task 'create_experiment': started at 2026-08-31 09:23:09.430257Z
# [2026.08.31 12:23:09.537] INFO    Task 'create_experiment': ended at 2026-08-31 09:23:09.537845Z
# [2026.08.31 12:23:09.623] INFO    Task 'compile_experiment': started at 2026-08-31 09:23:09.606642Z
# [2026.08.31 12:23:09.703] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:23:09.703] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:23:09.715] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:23:09.715] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:23:09.717] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:23:09.719] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:23:09.724] INFO    Code generation completed for all AWGs. [0.005 s]
# [2026.08.31 12:23:09.724] INFO    Completed compilation step 1 of 1. [0.007 s]
# [2026.08.31 12:23:09.731] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:23:09.731] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:23:09.734] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:23:09.735] INFO      SHFQC_DEV12192        0         11            0           1      7616
# [2026.08.31 12:23:09.738] INFO      SHFQC_DEV12192_sg     0         14            2           1      1568
# [2026.08.31 12:23:09.738] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:23:09.738] INFO      TOTAL                           25            2                  9184
# [2026.08.31 12:23:09.738] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:23:09.759] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:23:09.761] INFO    Task 'compile_experiment': ended at 2026-08-31 09:23:09.759519Z
# [2026.08.31 12:23:09.874] INFO    Task 'run_experiment': started at 2026-08-31 09:23:09.874072Z
# [2026.08.31 12:23:10.023] INFO    Starting near-time execution...
# [2026.08.31 12:23:10.111] INFO    Estimated RT execution time: 19.80 s.
# [2026.08.31 12:23:30.231] INFO    Finished near-time execution.
# [2026.08.31 12:23:30.296] INFO    Task 'run_experiment': ended at 2026-08-31 09:23:30.296255Z
# [2026.08.31 12:23:30.408] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:23:30.408] INFO      Workflow 'analysis_workflow': execution started at 2026-08-31
# [2026.08.31 12:23:30.408] INFO      09:23:30.408164Z
# [2026.08.31 12:23:30.408] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:23:30.532] INFO    Task 'collect_shots': started at 2026-08-31 09:23:30.530268Z
# [2026.08.31 12:23:30.569] INFO    Task 'collect_shots': ended at 2026-08-31 09:23:30.569943Z
# [2026.08.31 12:23:30.749] INFO    Task 'fit_data': started at 2026-08-31 09:23:30.745406Z
# [2026.08.31 12:23:30.968] INFO    Task 'fit_data': ended at 2026-08-31 09:23:30.968886Z
# [2026.08.31 12:23:31.066] INFO    Task 'calculate_assignment_matrices': started at 2026-08-31 09:23:31.066804Z
# [2026.08.31 12:23:31.241] INFO    Task 'calculate_assignment_matrices': ended at 2026-08-31 09:23:31.229279Z
# [2026.08.31 12:23:31.329] INFO    Task 'calculate_assignment_fidelities': started at 2026-08-31 09:23:31.329707Z
# [2026.08.31 12:23:31.430] INFO    Task 'calculate_assignment_fidelities': ended at 2026-08-31 09:23:31.430136Z
# [2026.08.31 12:23:31.494] INFO    Task 'plot_iq_blobs': started at 2026-08-31 09:23:31.492156Z
# [2026.08.31 12:23:31.610] INFO    Artifact: 'IQ_blobs_Q2' of type 'Figure' logged at 2026-08-31 09:23:31.610472Z
# [2026.08.31 12:23:32.223] INFO    Task 'plot_iq_blobs': ended at 2026-08-31 09:23:32.223334Z
# [2026.08.31 12:23:32.290] INFO    Task 'plot_assignment_matrices': started at 2026-08-31 09:23:32.290522Z
# [2026.08.31 12:23:32.383] INFO    Artifact: 'Assignment_matrix_Q2' of type 'Figure' logged at 2026-08-31
# [2026.08.31 12:23:32.390] INFO    09:23:32.383070Z
# [2026.08.31 12:23:33.444] INFO    Task 'plot_assignment_matrices': ended at 2026-08-31 09:23:33.444265Z
# [2026.08.31 12:23:33.507] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:23:33.507] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-31 09:23:33.507931Z
# [2026.08.31 12:23:33.516] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:23:33.556] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:23:33.556] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:23:33.556668Z
# [2026.08.31 12:23:33.556] INFO     ──────────────────────────────────────────────────────────────────────────────
# Drive length: 400.0 ns | pi amplitude: 0.0887
# [2026.08.31 12:23:33.708] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:23:33.710] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:23:33.706830Z
# [2026.08.31 12:23:33.712] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:23:33.903] INFO    Task 'temporary_qpu': started at 2026-08-31 09:23:33.903277Z
# [2026.08.31 12:23:33.938] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:23:33.938883Z
# [2026.08.31 12:23:34.022] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:23:34.022] INFO    09:23:34.022955Z
# [2026.08.31 12:23:34.087] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:23:34.087587Z
# [2026.08.31 12:23:34.152] INFO    Task 'create_experiment': started at 2026-08-31 09:23:34.152663Z
# [2026.08.31 12:23:34.265] INFO    Task 'create_experiment': ended at 2026-08-31 09:23:34.265845Z
# [2026.08.31 12:23:34.344] INFO    Task 'compile_experiment': started at 2026-08-31 09:23:34.344476Z
# [2026.08.31 12:23:34.410] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:23:34.410] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:23:34.419] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:23:34.419] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:23:34.422] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:23:34.422] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:23:34.426] INFO    Code generation completed for all AWGs. [0.005 s]
# [2026.08.31 12:23:34.426] INFO    Completed compilation step 1 of 1. [0.008 s]
# [2026.08.31 12:23:34.432] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:23:34.432] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:23:34.440] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:23:34.442] INFO      SHFQC_DEV12192        0         11            0           1      7616
# [2026.08.31 12:23:34.443] INFO      SHFQC_DEV12192_sg     0         14            2           1      1600
# [2026.08.31 12:23:34.443] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:23:34.443] INFO      TOTAL                           25            2                  9216
# [2026.08.31 12:23:34.443] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:23:34.459] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:23:34.459] INFO    Task 'compile_experiment': ended at 2026-08-31 09:23:34.459065Z
# [2026.08.31 12:23:34.571] INFO    Task 'run_experiment': started at 2026-08-31 09:23:34.571974Z
# [2026.08.31 12:23:34.700] INFO    Starting near-time execution...
# [2026.08.31 12:23:34.812] INFO    Estimated RT execution time: 19.80 s.
# [2026.08.31 12:23:54.907] INFO    Finished near-time execution.
# [2026.08.31 12:23:54.966] INFO    Task 'run_experiment': ended at 2026-08-31 09:23:54.966381Z
# [2026.08.31 12:23:55.101] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:23:55.101] INFO      Workflow 'analysis_workflow': execution started at 2026-08-31
# [2026.08.31 12:23:55.101] INFO      09:23:55.101967Z
# [2026.08.31 12:23:55.116] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:23:55.195] INFO    Task 'collect_shots': started at 2026-08-31 09:23:55.195884Z
# [2026.08.31 12:23:55.243] INFO    Task 'collect_shots': ended at 2026-08-31 09:23:55.243803Z
# [2026.08.31 12:23:55.403] INFO    Task 'fit_data': started at 2026-08-31 09:23:55.403519Z
# [2026.08.31 12:23:55.611] INFO    Task 'fit_data': ended at 2026-08-31 09:23:55.611369Z
# [2026.08.31 12:23:55.691] INFO    Task 'calculate_assignment_matrices': started at 2026-08-31 09:23:55.691370Z
# [2026.08.31 12:23:55.860] INFO    Task 'calculate_assignment_matrices': ended at 2026-08-31 09:23:55.854277Z
# [2026.08.31 12:23:55.948] INFO    Task 'calculate_assignment_fidelities': started at 2026-08-31 09:23:55.948818Z
# [2026.08.31 12:23:56.076] INFO    Task 'calculate_assignment_fidelities': ended at 2026-08-31 09:23:56.076189Z
# [2026.08.31 12:23:56.113] INFO    Task 'plot_iq_blobs': started at 2026-08-31 09:23:56.113797Z
# [2026.08.31 12:23:56.237] INFO    Artifact: 'IQ_blobs_Q2' of type 'Figure' logged at 2026-08-31 09:23:56.237351Z
# [2026.08.31 12:23:56.930] INFO    Task 'plot_iq_blobs': ended at 2026-08-31 09:23:56.930970Z
# [2026.08.31 12:23:57.056] INFO    Task 'plot_assignment_matrices': started at 2026-08-31 09:23:57.056316Z
# [2026.08.31 12:23:57.172] INFO    Artifact: 'Assignment_matrix_Q2' of type 'Figure' logged at 2026-08-31
# [2026.08.31 12:23:57.172] INFO    09:23:57.172706Z
# [2026.08.31 12:23:57.568] INFO    Task 'plot_assignment_matrices': ended at 2026-08-31 09:23:57.552971Z
# [2026.08.31 12:23:57.615] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:23:57.615] INFO      Workflow 'analysis_workflow': execution ended at 2026-08-31 09:23:57.615727Z
# [2026.08.31 12:23:57.617] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:23:57.648] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:23:57.662] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:23:57.648814Z
# [2026.08.31 12:23:57.662] INFO     ──────────────────────────────────────────────────────────────────────────────
# Sweep array shape (drive lengths, states, shots): (36, 2, 32768)

# %% [markdown]
# #### Analysis Plots

# %%
rel_std_0_arr = np.array([m['rel_std_0'] for m in ss_drive_length_sweep_metrics])
fidelity_arr = np.array(ss_drive_length_sweep_fidelities, dtype=float)

optimal_index = int(np.nanargmin(rel_std_0_arr))
print('Best drive length:', round(drive_length_arr[optimal_index] * 1e9, 3), 'ns',
      '| Rabi frequency:', round(rabi_freq_arr[optimal_index] * 1e-6, 3), 'MHz',
      '| rel_std_0:', round(float(rel_std_0_arr[optimal_index]), 4))

fig, ax = plt.subplots(2, 1, sharex=True, figsize=(10, 8))
fig.suptitle(f'Single shot vs. Rabi frequency - {qubit_to_measure.uid}', fontsize=16)
fig.supxlabel('Rabi frequency, MHz')

ax[0].plot(rabi_freq_arr * 1e-6, rel_std_0_arr, '.k')
ax[0].set_ylabel('Relative STD state 0')
ax[0].set_yscale('log')

ax[1].plot(rabi_freq_arr * 1e-6, fidelity_arr * 100, '.k')
ax[1].set_ylabel('Assignment fidelity, %')

for axis in ax:
    axis.axvline(x=rabi_freq_arr[optimal_index] * 1e-6, ls='-.', color='r',
                 label='optimal')
    axis.legend()

file_path = get_path_to_file('Single_shots_vs_rabi_freq_', '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')
# Out:
# Best drive length: 244.571 ns | Rabi frequency: 4.089 MHz | rel_std_0: 1.2252

# %% [markdown]
# #### Update Parameters

# %%
data_ss = {
    'ss_drive_length_sweep_arr': ss_drive_length_sweep_arr,
    'states': list(states),
    'ge_drive_length': drive_length_arr,
    'rabi_freq': rabi_freq_arr,
    'ge_drive_amplitude_pi': ge_drive_amplitude_pi_arr,
    'rel_std_0': rel_std_0_arr,
    'assignment_fidelity': fidelity_arr,
    'n_shots': 2**n_avg_exponent,
    'comment': 'Sweep of the pi-pulse length, array dim [drive_length, state, shot]',
}
data_ss.update(
    {k: v for k, v in attrs.asdict(qubit_to_measure.parameters).items()
     if isinstance(v, (int, float, str))}
)
data_ss['sample_name'] = sample_name
data_ss['qubit_name'] = qubit_name
data_ss['cooldown_start_date'] = cooldown_start_date

file_path = get_path_to_file('Single_shots_0_pi_diff_pipulses_', '.mat')
savemat(file_path, data_ss)
print(f'Saved drive-length sweep to: {file_path}')
# Out:
# Saved drive-length sweep to: N:\xld\qubit_thermometry_v2\ES-009-DE_1-2_9150\COOLDOWN_2026-08-26\Q2\20260831_122359_Single_shots_0_pi_diff_pipulses_.mat

# %%
if update_global_parameters:
    temp_pars = deepcopy(qubit_to_measure.parameters)
    temp_pars.ge_drive_length = float(drive_length_arr[optimal_index])
    temp_pars.ge_drive_amplitude_pi = float(ge_drive_amplitude_pi_arr[optimal_index])
    # temp_pars.ge_drive_pulse = ge_drive_pulse
    qubit_to_measure.parameters = temp_pars
    save(qpu, qpu_file_path)
    print('Updated global experiment parameters!\n')

print('ge drive length: ', qubit_to_measure.parameters.ge_drive_length)
print('ge drive amplitude pi: ', qubit_to_measure.parameters.ge_drive_amplitude_pi)
# Out:
# Updated global experiment parameters!
#
# ge drive length:  2.4457142857142856e-07
# ge drive amplitude pi:  0.1450703458642064

# %%
qpu.quantum_elements
# Out:
# [TunableTransmonQubit(
# │   uid='Q2',
# │   signals={
# │   │   'drive': 'q0/drive',
# │   │   'drive_ef': 'q0/drive_ef',
# │   │   'measure': 'q0/measure',
# │   │   'acquire': 'q0/acquire'
# │   },
# │   parameters=TunableTransmonQubitParameters(
# │   │   custom={},
# │   │   ge_T1=1.3645176509647932e-05,
# │   │   ge_T2=5.227829805594839e-06,
# │   │   ge_T2_star=8.607061549037454e-06,
# │   │   ef_T1=3.823989734157484e-06,
# │   │   ef_T2=1.0727739619875858e-06,
# │   │   ef_T2_star=7.980095959592148e-06,
# │   │   drive_lo_frequency=4800000000.0,
# │   │   readout_lo_frequency=6000000000.0,
# │   │   resonance_frequency_ge=5004729039.10699,
# │   │   resonance_frequency_ef=4811929098.0324335,
# │   │   readout_resonator_frequency=np.float64(5959580000.0),
# │   │   ge_drive_amplitude_pi=0.1450703458642064,
# │   │   ge_drive_amplitude_pi2=0.07343142790133057,
# │   │   ge_drive_length=2.4457142857142856e-07,
# │   │   ge_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0.2413462769901743,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   ef_drive_amplitude_pi=0.6507087790475553,
# │   │   ef_drive_amplitude_pi2=0.3099951813175842,
# │   │   ef_drive_length=1e-07,
# │   │   ef_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0.08010717043720025,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   qubit_resonator_coupling_strength_g=0,
# │   │   ge_chi_shift=0,
# │   │   readout_amplitude=0.25357142857142856,
# │   │   readout_length=1.9e-06,
# │   │   readout_pulse={
# │   │   │   'function': 'gaussian_square',
# │   │   │   'width': 1.7599999999999999e-06
# │   │   },
# │   │   readout_integration_length=1.9e-06,
# │   │   readout_integration_delay=8e-08,
# │   │   readout_integration_kernels_type='default',
# │   │   readout_integration_kernels=None,
# │   │   readout_integration_discrimination_thresholds=None,
# │   │   reset_delay_length=0.0003,
# │   │   drive_range=0,
# │   │   readout_range_out=-20,
# │   │   readout_range_in=-40,
# │   │   flux_range=5,
# │   │   spectroscopy_length=2e-05,
# │   │   spectroscopy_amplitude=0.4,
# │   │   spectroscopy_pulse={
# │   │   │   'function': 'const',
# │   │   │   'can_compress': True
# │   │   },
# │   │   dc_slot=0,
# │   │   dc_voltage_parking=0.0,
# │   │   flux_offset_voltage=0.0,
# │   │   user_defined={}
# │   )
# )
# ]

# %% [markdown]
# ## Single Shot Measurement for Different Integration Lengths and Delays

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

n_avg_exponent = 15

states = 'ge'

print('Readout length:            ', qubit_to_measure.parameters.readout_length)
print('Readout integration length:',
      qubit_to_measure.parameters.readout_integration_length)
print('Readout integration delay: ',
      qubit_to_measure.parameters.readout_integration_delay)

# TODO
# Here the readout pulse amplitude and length are fixed and we vary the
# integration delay and integration (weighting) length.
readout_length = qubit_to_measure.parameters.readout_length
readout_integration_delay_arr = np.linspace(60, 100, 5) * 1e-9
readout_integration_length_arr = np.array([readout_length])
# to sweep the integration length as well (old commented-out line
# `ro_len = np.arange(100, 2100 - port_delay_sw[k], 100)*1e-9`):
# readout_integration_length_arr = np.arange(100, 2100, 200) * 1e-9

qubit_to_measure = qubits[0]
# Out:
# Readout length:             1.9e-06
# Readout integration length: 1.9e-06
# Readout integration delay:  8e-08

# %% [markdown]
# #### Run Workflow

# %%
options = iq_blobs.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(True)
options.do_analysis(False)  # only the projected statistics are needed here

ss_delay_sweep_metrics = []
ss_delay_sweep_shots = []

for integration_delay in readout_integration_delay_arr:
    print('Integration delay:', round(integration_delay * 1e9, 3), 'ns')

    metrics_inner = []
    shots_inner = []

    for integration_length in readout_integration_length_arr:
        print('  Integration length:', round(integration_length * 1e9, 3), 'ns')

        temporary_parameters = {}
        temp_pars = deepcopy(qubit_to_measure.parameters)
        temp_pars.readout_length = readout_length
        temp_pars.readout_integration_delay = float(integration_delay)
        temp_pars.readout_integration_length = float(integration_length)
        temporary_parameters[qubit_to_measure.uid] = temp_pars

        exp_workflow = iq_blobs.experiment_workflow(
            session=session,
            qpu=qpu,
            qubits=[qubit_to_measure.uid],
            states=states,
            options=options,
            temporary_parameters=temporary_parameters,
        )
        workflow_result = exp_workflow.run()

        shots = collect_shots_from_result(
            workflow_result.output, qubit_to_measure.uid, states
        )
        shots_inner.append(np.array([shots[s] for s in states]))

        res = analyze_single_shots(shots, state_0='g', state_1='e', plot=False)
        metrics_inner.append(
            {k: v for k, v in res.items() if isinstance(v, (int, float, complex))}
        )

    ss_delay_sweep_metrics.append(metrics_inner)
    ss_delay_sweep_shots.append(shots_inner)

ss_delay_sweep_arr = np.array(ss_delay_sweep_shots)
print('Sweep array shape (delays, integration lengths, states, shots):',
      ss_delay_sweep_arr.shape)
# Out:
# Integration delay: 60.0 ns
#   Integration length: 1900.0 ns
# [2026.08.31 12:24:00.316] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:24:00.327] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:24:00.316158Z
# [2026.08.31 12:24:00.327] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:24:00.576] INFO    Task 'temporary_qpu': started at 2026-08-31 09:24:00.573823Z
# [2026.08.31 12:24:00.620] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:24:00.620674Z
# [2026.08.31 12:24:00.718] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:24:00.718] INFO    09:24:00.718767Z
# [2026.08.31 12:24:00.765] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:24:00.765449Z
# [2026.08.31 12:24:00.861] INFO    Task 'create_experiment': started at 2026-08-31 09:24:00.861852Z
# [2026.08.31 12:24:00.976] INFO    Task 'create_experiment': ended at 2026-08-31 09:24:00.976815Z
# [2026.08.31 12:24:01.070] INFO    Task 'compile_experiment': started at 2026-08-31 09:24:01.070891Z
# [2026.08.31 12:24:01.231] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:24:01.231] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:24:01.231] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:24:01.240] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:24:01.240] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:24:01.240] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:24:01.253] INFO    Code generation completed for all AWGs. [0.006 s]
# [2026.08.31 12:24:01.253] INFO    Completed compilation step 1 of 1. [0.012 s]
# [2026.08.31 12:24:01.262] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:24:01.262] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:24:01.271] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:24:01.271] INFO      SHFQC_DEV12192        0         11            0           1      7616
# [2026.08.31 12:24:01.273] INFO      SHFQC_DEV12192_sg     0         14            2           1       992
# [2026.08.31 12:24:01.273] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:24:01.273] INFO      TOTAL                           25            2                  8608
# [2026.08.31 12:24:01.273] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:24:01.295] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:24:01.295] INFO    Task 'compile_experiment': ended at 2026-08-31 09:24:01.295964Z
# [2026.08.31 12:24:01.430] INFO    Task 'run_experiment': started at 2026-08-31 09:24:01.430591Z
# [2026.08.31 12:24:01.617] INFO    Starting near-time execution...
# [2026.08.31 12:24:01.681] INFO    Estimated RT execution time: 19.79 s.
# [2026.08.31 12:24:21.762] INFO    Finished near-time execution.
# [2026.08.31 12:24:21.833] INFO    Task 'run_experiment': ended at 2026-08-31 09:24:21.833688Z
# [2026.08.31 12:24:21.998] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:24:22.000] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:24:21.997063Z
# [2026.08.31 12:24:22.004] INFO     ──────────────────────────────────────────────────────────────────────────────
# Integration delay: 70.0 ns
#   Integration length: 1900.0 ns
# [2026.08.31 12:24:22.174] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:24:22.174] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:24:22.171689Z
# [2026.08.31 12:24:22.174] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:24:22.377] INFO    Task 'temporary_qpu': started at 2026-08-31 09:24:22.377202Z
# [2026.08.31 12:24:22.429] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:24:22.429903Z
# [2026.08.31 12:24:22.538] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:24:22.538] INFO    09:24:22.530623Z
# [2026.08.31 12:24:22.585] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:24:22.585684Z
# [2026.08.31 12:24:22.681] INFO    Task 'create_experiment': started at 2026-08-31 09:24:22.681938Z
# [2026.08.31 12:24:22.810] INFO    Task 'create_experiment': ended at 2026-08-31 09:24:22.810114Z
# [2026.08.31 12:24:22.906] INFO    Task 'compile_experiment': started at 2026-08-31 09:24:22.906894Z
# [2026.08.31 12:24:22.994] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:24:22.994] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:24:22.994] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:24:23.001] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:24:23.001] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:24:23.002] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:24:23.005] INFO    Code generation completed for all AWGs. [0.004 s]
# [2026.08.31 12:24:23.008] INFO    Completed compilation step 1 of 1. [0.008 s]
# [2026.08.31 12:24:23.016] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:24:23.016] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:24:23.019] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:24:23.021] INFO      SHFQC_DEV12192        0         11            0           1      7616
# [2026.08.31 12:24:23.021] INFO      SHFQC_DEV12192_sg     0         14            2           1       992
# [2026.08.31 12:24:23.023] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:24:23.025] INFO      TOTAL                           25            2                  8608
# [2026.08.31 12:24:23.025] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:24:23.049] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:24:23.051] INFO    Task 'compile_experiment': ended at 2026-08-31 09:24:23.049188Z
# [2026.08.31 12:24:23.162] INFO    Task 'run_experiment': started at 2026-08-31 09:24:23.162498Z
# [2026.08.31 12:24:23.301] INFO    Starting near-time execution...
# [2026.08.31 12:24:23.372] INFO    Estimated RT execution time: 19.79 s.
# [2026.08.31 12:24:43.441] INFO    Finished near-time execution.
# [2026.08.31 12:24:43.538] INFO    Task 'run_experiment': ended at 2026-08-31 09:24:43.538664Z
# [2026.08.31 12:24:43.682] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:24:43.682] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:24:43.682084Z
# [2026.08.31 12:24:43.682] INFO     ──────────────────────────────────────────────────────────────────────────────
# Integration delay: 80.0 ns
#   Integration length: 1900.0 ns
# [2026.08.31 12:24:43.827] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:24:43.827] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:24:43.827598Z
# [2026.08.31 12:24:43.827] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:24:44.084] INFO    Task 'temporary_qpu': started at 2026-08-31 09:24:44.084767Z
# [2026.08.31 12:24:44.127] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:24:44.127299Z
# [2026.08.31 12:24:44.212] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:24:44.212] INFO    09:24:44.212875Z
# [2026.08.31 12:24:44.269] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:24:44.269565Z
# [2026.08.31 12:24:44.360] INFO    Task 'create_experiment': started at 2026-08-31 09:24:44.360702Z
# [2026.08.31 12:24:44.500] INFO    Task 'create_experiment': ended at 2026-08-31 09:24:44.500532Z
# [2026.08.31 12:24:44.604] INFO    Task 'compile_experiment': started at 2026-08-31 09:24:44.604930Z
# [2026.08.31 12:24:44.702] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:24:44.707] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:24:44.707] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:24:44.710] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:24:44.710] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:24:44.712] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:24:44.716] INFO    Code generation completed for all AWGs. [0.005 s]
# [2026.08.31 12:24:44.716] INFO    Completed compilation step 1 of 1. [0.007 s]
# [2026.08.31 12:24:44.726] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:24:44.731] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:24:44.731] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:24:44.731] INFO      SHFQC_DEV12192        0         11            0           1      7616
# [2026.08.31 12:24:44.731] INFO      SHFQC_DEV12192_sg     0         14            2           1       992
# [2026.08.31 12:24:44.731] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:24:44.731] INFO      TOTAL                           25            2                  8608
# [2026.08.31 12:24:44.742] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:24:44.756] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:24:44.756] INFO    Task 'compile_experiment': ended at 2026-08-31 09:24:44.756789Z
# [2026.08.31 12:24:44.886] INFO    Task 'run_experiment': started at 2026-08-31 09:24:44.886097Z
# [2026.08.31 12:24:45.062] INFO    Starting near-time execution...
# [2026.08.31 12:24:45.143] INFO    Estimated RT execution time: 19.79 s.
# [2026.08.31 12:25:05.258] INFO    Finished near-time execution.
# [2026.08.31 12:25:05.339] INFO    Task 'run_experiment': ended at 2026-08-31 09:25:05.339162Z
# [2026.08.31 12:25:05.483] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:25:05.483] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:25:05.483143Z
# [2026.08.31 12:25:05.483] INFO     ──────────────────────────────────────────────────────────────────────────────
# Integration delay: 90.0 ns
#   Integration length: 1900.0 ns
# [2026.08.31 12:25:05.676] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:25:05.678] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:25:05.660381Z
# [2026.08.31 12:25:05.682] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:25:05.916] INFO    Task 'temporary_qpu': started at 2026-08-31 09:25:05.916250Z
# [2026.08.31 12:25:05.965] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:25:05.965770Z
# [2026.08.31 12:25:06.048] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:25:06.059] INFO    09:25:06.048276Z
# [2026.08.31 12:25:06.111] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:25:06.111924Z
# [2026.08.31 12:25:06.220] INFO    Task 'create_experiment': started at 2026-08-31 09:25:06.220795Z
# [2026.08.31 12:25:06.349] INFO    Task 'create_experiment': ended at 2026-08-31 09:25:06.349778Z
# [2026.08.31 12:25:06.438] INFO    Task 'compile_experiment': started at 2026-08-31 09:25:06.438045Z
# [2026.08.31 12:25:06.526] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:25:06.528] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:25:06.528] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:25:06.530] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:25:06.530] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:25:06.532] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:25:06.532] INFO    Code generation completed for all AWGs. [0.002 s]
# [2026.08.31 12:25:06.538] INFO    Completed compilation step 1 of 1. [0.006 s]
# [2026.08.31 12:25:06.547] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:25:06.550] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:25:06.552] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:25:06.552] INFO      SHFQC_DEV12192        0         11            0           1      7616
# [2026.08.31 12:25:06.553] INFO      SHFQC_DEV12192_sg     0         14            2           1       992
# [2026.08.31 12:25:06.553] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:25:06.553] INFO      TOTAL                           25            2                  8608
# [2026.08.31 12:25:06.553] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:25:06.574] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:25:06.581] INFO    Task 'compile_experiment': ended at 2026-08-31 09:25:06.581244Z
# [2026.08.31 12:25:06.702] INFO    Task 'run_experiment': started at 2026-08-31 09:25:06.702884Z
# [2026.08.31 12:25:06.866] INFO    Starting near-time execution...
# [2026.08.31 12:25:06.930] INFO    Estimated RT execution time: 19.79 s.
# [2026.08.31 12:25:27.002] INFO    Finished near-time execution.
# [2026.08.31 12:25:27.099] INFO    Task 'run_experiment': ended at 2026-08-31 09:25:27.099727Z
# [2026.08.31 12:25:27.308] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:25:27.308] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:25:27.308200Z
# [2026.08.31 12:25:27.314] INFO     ──────────────────────────────────────────────────────────────────────────────
# Integration delay: 100.0 ns
#   Integration length: 1900.0 ns
# [2026.08.31 12:25:27.483] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:25:27.485] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:25:27.483508Z
# [2026.08.31 12:25:27.485] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:25:27.740] INFO    Task 'temporary_qpu': started at 2026-08-31 09:25:27.740892Z
# [2026.08.31 12:25:27.838] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:25:27.838978Z
# [2026.08.31 12:25:27.972] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:25:27.974] INFO    09:25:27.972197Z
# [2026.08.31 12:25:28.030] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:25:28.030865Z
# [2026.08.31 12:25:28.156] INFO    Task 'create_experiment': started at 2026-08-31 09:25:28.156615Z
# [2026.08.31 12:25:28.257] INFO    Task 'create_experiment': ended at 2026-08-31 09:25:28.257068Z
# [2026.08.31 12:25:28.360] INFO    Task 'compile_experiment': started at 2026-08-31 09:25:28.360494Z
# [2026.08.31 12:25:28.431] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:25:28.431] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:25:28.431] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:25:28.447] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:25:28.447] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:25:28.447] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:25:28.447] INFO    Code generation completed for all AWGs. [0.002 s]
# [2026.08.31 12:25:28.447] INFO    Completed compilation step 1 of 1. [0.003 s]
# [2026.08.31 12:25:28.447] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:25:28.447] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:25:28.447] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:25:28.447] INFO      SHFQC_DEV12192        0         11            0           1      7616
# [2026.08.31 12:25:28.447] INFO      SHFQC_DEV12192_sg     0         14            2           1       992
# [2026.08.31 12:25:28.463] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:25:28.463] INFO      TOTAL                           25            2                  8608
# [2026.08.31 12:25:28.463] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:25:28.479] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:25:28.494] INFO    Task 'compile_experiment': ended at 2026-08-31 09:25:28.494362Z
# [2026.08.31 12:25:28.638] INFO    Task 'run_experiment': started at 2026-08-31 09:25:28.638854Z
# [2026.08.31 12:25:28.793] INFO    Starting near-time execution...
# [2026.08.31 12:25:28.850] INFO    Estimated RT execution time: 19.79 s.
# [2026.08.31 12:25:48.958] INFO    Finished near-time execution.
# [2026.08.31 12:25:49.028] INFO    Task 'run_experiment': ended at 2026-08-31 09:25:49.028528Z
# [2026.08.31 12:25:49.197] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:25:49.205] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:25:49.197136Z
# [2026.08.31 12:25:49.205] INFO     ──────────────────────────────────────────────────────────────────────────────
# Sweep array shape (delays, integration lengths, states, shots): (5, 1, 2, 32768)

# %% [markdown]
# #### Analysis Plots

# %%
# min / argmin of Rel_STD_0 over the nested sweep
min_val = []
argmin_val = []

for metrics_inner in ss_delay_sweep_metrics:
    rel_std_0 = np.array([m['rel_std_0'] for m in metrics_inner])
    min_val.append(np.nanmin(rel_std_0))
    argmin_val.append(int(np.nanargmin(rel_std_0)))

optimal_delay_index = int(np.nanargmin(np.array(min_val)))
optimal_length_index = argmin_val[optimal_delay_index]

readout_integration_delay_opt = float(
    readout_integration_delay_arr[optimal_delay_index]
)
readout_integration_length_opt = float(
    readout_integration_length_arr[optimal_length_index]
)

print('Readout length is', readout_length)
print('Minimal relative error value is', np.round(min_val[optimal_delay_index], 3),
      'for delay', np.round(readout_integration_delay_opt * 1e9, 3),
      'ns (index', optimal_delay_index, ') and integration length',
      readout_integration_length_opt, '(index', optimal_length_index, ').')
if 0 < optimal_delay_index < len(readout_integration_delay_arr) - 1:
    print('Optimal integration delay is between',
          np.round(readout_integration_delay_arr[optimal_delay_index - 1] * 1e9, 3),
          'and',
          np.round(readout_integration_delay_arr[optimal_delay_index + 1] * 1e9, 3),
          'ns')

rel_std_0_arr = np.array(
    [[m['rel_std_0'] for m in metrics_inner]
     for metrics_inner in ss_delay_sweep_metrics]
)

fig, ax = plt.subplots(figsize=(10, 5))
ax.set_title(f'Single shot vs. integration delay - {qubit_to_measure.uid}')
for k, integration_length in enumerate(readout_integration_length_arr):
    ax.plot(readout_integration_delay_arr * 1e9, rel_std_0_arr[:, k], '.-',
            label=f'{integration_length * 1e9:.0f} ns')
ax.axvline(x=readout_integration_delay_opt * 1e9, ls='-.', color='r', label='optimal')
ax.set_xlabel('Readout integration delay, ns')
ax.set_ylabel('Relative STD state 0')
ax.set_yscale('log')
ax.legend(title='Integration length')

file_path = get_path_to_file('Single_shots_vs_delay_and_int_len_', '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')
# Out:
# Readout length is 1.9e-06
# Minimal relative error value is 1.246 for delay 60.0 ns (index 0 ) and integration length 1.9e-06 (index 0 ).

# %% [markdown]
# #### Update Parameters

# %%
# set to a value != None to override the values extracted above.
manual_readout_integration_delay = None
manual_readout_integration_length = None
if manual_readout_integration_delay is not None:
    readout_integration_delay_opt = float(manual_readout_integration_delay)
if manual_readout_integration_length is not None:
    readout_integration_length_opt = float(manual_readout_integration_length)

if update_global_parameters:
    temp_pars = deepcopy(qubit_to_measure.parameters)
    temp_pars.readout_integration_delay = readout_integration_delay_opt
    temp_pars.readout_integration_length = readout_integration_length_opt
    qubit_to_measure.parameters = temp_pars
    save(qpu, qpu_file_path)
    print('Updated global experiment parameters!\n')

print('Readout integration delay: ',
      qubit_to_measure.parameters.readout_integration_delay)
print('Readout integration length: ',
      qubit_to_measure.parameters.readout_integration_length)
# Out:
# Updated global experiment parameters!
#
# Readout integration delay:  6.000000000000001e-08
# Readout integration length:  1.9e-06

# %%
data_ss = {
    'ss_delay_sweep_arr': ss_delay_sweep_arr,
    'states': list(states),
    'readout_integration_delay_sweep': readout_integration_delay_arr,
    'readout_integration_length_sweep': readout_integration_length_arr,
    'readout_length': readout_length,
    'rel_std_0': rel_std_0_arr,
    'n_shots': 2**n_avg_exponent,
    'comment': ('Sweep integration delay and integration length, array dim '
                '[delay, integration_length, state, shot]'),
}
data_ss.update(
    {k: v for k, v in attrs.asdict(qubit_to_measure.parameters).items()
     if isinstance(v, (int, float, str))}
)
data_ss['sample_name'] = sample_name
data_ss['qubit_name'] = qubit_name
data_ss['cooldown_start_date'] = cooldown_start_date

file_path = get_path_to_file('Single_shots_0_pi_sweep_delay_and_ro_len_', '.mat')
savemat(file_path, data_ss)
print(f'Saved delay/integration-length sweep to: {file_path}')
# Out:
# Saved delay/integration-length sweep to: N:\xld\qubit_thermometry_v2\ES-009-DE_1-2_9150\COOLDOWN_2026-08-26\Q2\20260831_122551_Single_shots_0_pi_sweep_delay_and_ro_len_.mat

# %%
qpu.quantum_elements
# Out:
# [TunableTransmonQubit(
# │   uid='Q2',
# │   signals={
# │   │   'drive': 'q0/drive',
# │   │   'drive_ef': 'q0/drive_ef',
# │   │   'measure': 'q0/measure',
# │   │   'acquire': 'q0/acquire'
# │   },
# │   parameters=TunableTransmonQubitParameters(
# │   │   custom={},
# │   │   ge_T1=1.3645176509647932e-05,
# │   │   ge_T2=5.227829805594839e-06,
# │   │   ge_T2_star=8.607061549037454e-06,
# │   │   ef_T1=3.823989734157484e-06,
# │   │   ef_T2=1.0727739619875858e-06,
# │   │   ef_T2_star=7.980095959592148e-06,
# │   │   drive_lo_frequency=4800000000.0,
# │   │   readout_lo_frequency=6000000000.0,
# │   │   resonance_frequency_ge=5004729039.10699,
# │   │   resonance_frequency_ef=4811929098.0324335,
# │   │   readout_resonator_frequency=np.float64(5959580000.0),
# │   │   ge_drive_amplitude_pi=0.1450703458642064,
# │   │   ge_drive_amplitude_pi2=0.07343142790133057,
# │   │   ge_drive_length=2.4457142857142856e-07,
# │   │   ge_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0.2413462769901743,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   ef_drive_amplitude_pi=0.6507087790475553,
# │   │   ef_drive_amplitude_pi2=0.3099951813175842,
# │   │   ef_drive_length=1e-07,
# │   │   ef_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0.08010717043720025,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   qubit_resonator_coupling_strength_g=0,
# │   │   ge_chi_shift=0,
# │   │   readout_amplitude=0.25357142857142856,
# │   │   readout_length=1.9e-06,
# │   │   readout_pulse={
# │   │   │   'function': 'gaussian_square',
# │   │   │   'width': 1.7599999999999999e-06
# │   │   },
# │   │   readout_integration_length=1.9e-06,
# │   │   readout_integration_delay=6.000000000000001e-08,
# │   │   readout_integration_kernels_type='default',
# │   │   readout_integration_kernels=None,
# │   │   readout_integration_discrimination_thresholds=None,
# │   │   reset_delay_length=0.0003,
# │   │   drive_range=0,
# │   │   readout_range_out=-20,
# │   │   readout_range_in=-40,
# │   │   flux_range=5,
# │   │   spectroscopy_length=2e-05,
# │   │   spectroscopy_amplitude=0.4,
# │   │   spectroscopy_pulse={
# │   │   │   'function': 'const',
# │   │   │   'can_compress': True
# │   │   },
# │   │   dc_slot=0,
# │   │   dc_voltage_parking=0.0,
# │   │   flux_offset_voltage=0.0,
# │   │   user_defined={}
# │   )
# )
# ]

# %% [markdown]
# ## Single Shot Measurement for Different Readout Amplitudes and Lengths

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

n_avg_exponent = 14

states = 'ge'

# TODO
# Sweep power and length of the readout pulse. The integration delay is fixed
# and the integration window is equal to the readout pulse length.
readout_amplitude_arr = np.linspace(0.05, 1, 29)
readout_length_arr = np.linspace(1900, 2000, 10) * 1e-9

readout_integration_delay = qubit_to_measure.parameters.readout_integration_delay

qubit_to_measure = qubits[0]

# %% [markdown]
# #### Run Workflow

# %%
options = iq_blobs.experiment_workflow.options()
options.count(2**n_avg_exponent)
options.close_figures(True)
options.do_analysis(False)

ss_ro_sweep_metrics = []

for readout_amplitude in readout_amplitude_arr:
    print('Readout amplitude:', round(float(readout_amplitude), 5))

    metrics_inner = []

    for readout_length in readout_length_arr:
        print('  Readout length:', round(readout_length * 1e9, 3), 'ns')

        temporary_parameters = {}
        temp_pars = deepcopy(qubit_to_measure.parameters)
        temp_pars.readout_amplitude = float(readout_amplitude)
        temp_pars.readout_length = float(readout_length)
        # old: readout_weighting_function_i = pulse_library.const(length=ro_len_sw[i])
        temp_pars.readout_integration_length = float(readout_length)
        temp_pars.readout_integration_delay = readout_integration_delay
        temporary_parameters[qubit_to_measure.uid] = temp_pars

        exp_workflow = iq_blobs.experiment_workflow(
            session=session,
            qpu=qpu,
            qubits=[qubit_to_measure.uid],
            states=states,
            options=options,
            temporary_parameters=temporary_parameters,
        )
        workflow_result = exp_workflow.run()

        shots = collect_shots_from_result(
            workflow_result.output, qubit_to_measure.uid, states
        )
        res = analyze_single_shots(shots, state_0='g', state_1='e', plot=False)
        metrics_inner.append(
            {k: v for k, v in res.items() if isinstance(v, (int, float, complex))}
        )

    ss_ro_sweep_metrics.append(metrics_inner)
# Out:
# Readout amplitude: 0.05
#   Readout length: 1900.0 ns
# [2026.08.31 12:25:51.356] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:25:51.356] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:25:51.341260Z
# [2026.08.31 12:25:51.356] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:25:51.597] INFO    Task 'temporary_qpu': started at 2026-08-31 09:25:51.597526Z
# [2026.08.31 12:25:51.650] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:25:51.650426Z
# [2026.08.31 12:25:51.757] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:25:51.757] INFO    09:25:51.757686Z
# [2026.08.31 12:25:51.815] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:25:51.815156Z
# [2026.08.31 12:25:51.885] INFO    Task 'create_experiment': started at 2026-08-31 09:25:51.885414Z
# [2026.08.31 12:25:51.984] INFO    Task 'create_experiment': ended at 2026-08-31 09:25:51.984800Z
# [2026.08.31 12:25:52.117] INFO    Task 'compile_experiment': started at 2026-08-31 09:25:52.109693Z
# [2026.08.31 12:25:52.197] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:25:52.203] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:25:52.204] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:25:52.206] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:25:52.208] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:25:52.210] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:25:52.215] INFO    Code generation completed for all AWGs. [0.006 s]
# [2026.08.31 12:25:52.220] INFO    Completed compilation step 1 of 1. [0.010 s]
# [2026.08.31 12:25:52.231] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:25:52.237] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:25:52.239] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:25:52.241] INFO      SHFQC_DEV12192        0         11            0           1      7616
# [2026.08.31 12:25:52.243] INFO      SHFQC_DEV12192_sg     0         14            2           1       992
# [2026.08.31 12:25:52.243] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:25:52.243] INFO      TOTAL                           25            2                  8608
# [2026.08.31 12:25:52.245] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:25:52.263] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:25:52.263] INFO    Task 'compile_experiment': ended at 2026-08-31 09:25:52.263516Z
# [2026.08.31 12:25:52.381] INFO    Task 'run_experiment': started at 2026-08-31 09:25:52.381870Z
# [2026.08.31 12:25:52.543] INFO    Starting near-time execution...
# [2026.08.31 12:25:52.635] INFO    Estimated RT execution time: 9.90 s.
# [2026.08.31 12:26:02.690] INFO    Finished near-time execution.
# [2026.08.31 12:26:02.769] INFO    Task 'run_experiment': ended at 2026-08-31 09:26:02.769568Z
# [2026.08.31 12:26:02.898] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:02.903] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:26:02.898719Z
# [2026.08.31 12:26:02.905] INFO     ──────────────────────────────────────────────────────────────────────────────
#   Readout length: 1911.111 ns
# [2026.08.31 12:26:03.075] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:03.075] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:26:03.075094Z
# [2026.08.31 12:26:03.075] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:03.348] INFO    Task 'temporary_qpu': started at 2026-08-31 09:26:03.348474Z
# [2026.08.31 12:26:03.397] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:26:03.397159Z
# [2026.08.31 12:26:03.565] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:26:03.574] INFO    09:26:03.565132Z
# [2026.08.31 12:26:03.638] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:26:03.625080Z
# [2026.08.31 12:26:03.733] INFO    Task 'create_experiment': started at 2026-08-31 09:26:03.733993Z
# [2026.08.31 12:26:03.866] INFO    Task 'create_experiment': ended at 2026-08-31 09:26:03.866015Z
# [2026.08.31 12:26:03.989] INFO    Task 'compile_experiment': started at 2026-08-31 09:26:03.989621Z
# [2026.08.31 12:26:04.069] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:26:04.069] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:26:04.069] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:26:04.085] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:26:04.086] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:26:04.086] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:26:04.092] INFO    Code generation completed for all AWGs. [0.005 s]
# [2026.08.31 12:26:04.092] INFO    Completed compilation step 1 of 1. [0.008 s]
# [2026.08.31 12:26:04.105] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:04.105] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:26:04.105] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:04.114] INFO      SHFQC_DEV12192        0         11            0           1      7648
# [2026.08.31 12:26:04.114] INFO      SHFQC_DEV12192_sg     0         14            2           1       992
# [2026.08.31 12:26:04.116] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:04.118] INFO      TOTAL                           25            2                  8640
# [2026.08.31 12:26:04.118] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:04.132] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:26:04.132] INFO    Task 'compile_experiment': ended at 2026-08-31 09:26:04.132758Z
# [2026.08.31 12:26:04.277] INFO    Task 'run_experiment': started at 2026-08-31 09:26:04.277751Z
# [2026.08.31 12:26:04.429] INFO    Starting near-time execution...
# [2026.08.31 12:26:04.517] INFO    Estimated RT execution time: 9.90 s.
# [2026.08.31 12:26:14.586] INFO    Finished near-time execution.
# [2026.08.31 12:26:14.634] INFO    Task 'run_experiment': ended at 2026-08-31 09:26:14.634678Z
# [2026.08.31 12:26:14.763] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:14.763] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:26:14.763815Z
# [2026.08.31 12:26:14.763] INFO     ──────────────────────────────────────────────────────────────────────────────
#   Readout length: 1922.222 ns
# [2026.08.31 12:26:14.939] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:14.939] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:26:14.939081Z
# [2026.08.31 12:26:14.939] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:15.179] INFO    Task 'temporary_qpu': started at 2026-08-31 09:26:15.179851Z
# [2026.08.31 12:26:15.230] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:26:15.230793Z
# [2026.08.31 12:26:15.340] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:26:15.341] INFO    09:26:15.340295Z
# [2026.08.31 12:26:15.385] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:26:15.384792Z
# [2026.08.31 12:26:15.487] INFO    Task 'create_experiment': started at 2026-08-31 09:26:15.484889Z
# [2026.08.31 12:26:15.606] INFO    Task 'create_experiment': ended at 2026-08-31 09:26:15.606755Z
# [2026.08.31 12:26:15.696] INFO    Task 'compile_experiment': started at 2026-08-31 09:26:15.696273Z
# [2026.08.31 12:26:15.783] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:26:15.784] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:26:15.784] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:26:15.787] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:26:15.789] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:26:15.793] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:26:15.797] INFO    Code generation completed for all AWGs. [0.003 s]
# [2026.08.31 12:26:15.799] INFO    Completed compilation step 1 of 1. [0.007 s]
# [2026.08.31 12:26:15.804] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:15.804] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:26:15.806] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:15.806] INFO      SHFQC_DEV12192        0         11            0           1      7712
# [2026.08.31 12:26:15.806] INFO      SHFQC_DEV12192_sg     0         14            2           1       992
# [2026.08.31 12:26:15.810] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:15.811] INFO      TOTAL                           25            2                  8704
# [2026.08.31 12:26:15.811] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:15.831] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:26:15.833] INFO    Task 'compile_experiment': ended at 2026-08-31 09:26:15.833142Z
# [2026.08.31 12:26:15.957] INFO    Task 'run_experiment': started at 2026-08-31 09:26:15.957065Z
# [2026.08.31 12:26:16.128] INFO    Starting near-time execution...
# [2026.08.31 12:26:16.234] INFO    Estimated RT execution time: 9.90 s.
# [2026.08.31 12:26:26.306] INFO    Finished near-time execution.
# [2026.08.31 12:26:26.404] INFO    Task 'run_experiment': ended at 2026-08-31 09:26:26.404451Z
# [2026.08.31 12:26:26.547] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:26.547] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:26:26.547302Z
# [2026.08.31 12:26:26.547] INFO     ──────────────────────────────────────────────────────────────────────────────
#   Readout length: 1933.333 ns
# [2026.08.31 12:26:26.767] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:26.772] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:26:26.767251Z
# [2026.08.31 12:26:26.772] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:27.043] INFO    Task 'temporary_qpu': started at 2026-08-31 09:26:27.043827Z
# [2026.08.31 12:26:27.094] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:26:27.094415Z
# [2026.08.31 12:26:27.184] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:26:27.189] INFO    09:26:27.184959Z
# [2026.08.31 12:26:27.204] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:26:27.204815Z
# [2026.08.31 12:26:27.300] INFO    Task 'create_experiment': started at 2026-08-31 09:26:27.300602Z
# [2026.08.31 12:26:27.379] INFO    Task 'create_experiment': ended at 2026-08-31 09:26:27.379847Z
# [2026.08.31 12:26:27.436] INFO    Task 'compile_experiment': started at 2026-08-31 09:26:27.436372Z
# [2026.08.31 12:26:27.492] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:26:27.492] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:26:27.492] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:26:27.508] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:26:27.509] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:26:27.509] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:26:27.509] INFO    Code generation completed for all AWGs. [0.002 s]
# [2026.08.31 12:26:27.509] INFO    Completed compilation step 1 of 1. [0.004 s]
# [2026.08.31 12:26:27.525] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:27.525] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:26:27.528] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:27.531] INFO      SHFQC_DEV12192        0         11            0           1      7744
# [2026.08.31 12:26:27.531] INFO      SHFQC_DEV12192_sg     0         14            2           1       992
# [2026.08.31 12:26:27.531] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:27.531] INFO      TOTAL                           25            2                  8736
# [2026.08.31 12:26:27.531] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:27.557] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:26:27.557] INFO    Task 'compile_experiment': ended at 2026-08-31 09:26:27.557706Z
# [2026.08.31 12:26:27.671] INFO    Task 'run_experiment': started at 2026-08-31 09:26:27.671506Z
# [2026.08.31 12:26:27.799] INFO    Starting near-time execution...
# [2026.08.31 12:26:27.896] INFO    Estimated RT execution time: 9.90 s.
# [2026.08.31 12:26:37.974] INFO    Finished near-time execution.
# [2026.08.31 12:26:38.038] INFO    Task 'run_experiment': ended at 2026-08-31 09:26:38.038562Z
# [2026.08.31 12:26:38.166] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:38.166] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:26:38.166054Z
# [2026.08.31 12:26:38.166] INFO     ──────────────────────────────────────────────────────────────────────────────
#   Readout length: 1944.444 ns
# [2026.08.31 12:26:38.344] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:38.344] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:26:38.344683Z
# [2026.08.31 12:26:38.344] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:38.599] INFO    Task 'temporary_qpu': started at 2026-08-31 09:26:38.599214Z
# [2026.08.31 12:26:38.646] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:26:38.646624Z
# [2026.08.31 12:26:38.761] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:26:38.763] INFO    09:26:38.758875Z
# [2026.08.31 12:26:38.807] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:26:38.807997Z
# [2026.08.31 12:26:38.905] INFO    Task 'create_experiment': started at 2026-08-31 09:26:38.905358Z
# [2026.08.31 12:26:39.047] INFO    Task 'create_experiment': ended at 2026-08-31 09:26:39.047881Z
# [2026.08.31 12:26:39.167] INFO    Task 'compile_experiment': started at 2026-08-31 09:26:39.167919Z
# [2026.08.31 12:26:39.257] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:26:39.257] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:26:39.257] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:26:39.257] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:26:39.268] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:26:39.271] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:26:39.275] INFO    Code generation completed for all AWGs. [0.004 s]
# [2026.08.31 12:26:39.275] INFO    Completed compilation step 1 of 1. [0.009 s]
# [2026.08.31 12:26:39.290] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:39.290] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:26:39.292] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:39.294] INFO      SHFQC_DEV12192        0         11            0           1      7808
# [2026.08.31 12:26:39.294] INFO      SHFQC_DEV12192_sg     0         14            2           1       992
# [2026.08.31 12:26:39.296] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:39.296] INFO      TOTAL                           25            2                  8800
# [2026.08.31 12:26:39.299] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:39.310] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:26:39.310] INFO    Task 'compile_experiment': ended at 2026-08-31 09:26:39.310808Z
# [2026.08.31 12:26:39.448] INFO    Task 'run_experiment': started at 2026-08-31 09:26:39.448836Z
# [2026.08.31 12:26:39.612] INFO    Starting near-time execution...
# [2026.08.31 12:26:39.700] INFO    Estimated RT execution time: 9.90 s.
# [2026.08.31 12:26:49.767] INFO    Finished near-time execution.
# [2026.08.31 12:26:49.829] INFO    Task 'run_experiment': ended at 2026-08-31 09:26:49.829939Z
# [2026.08.31 12:26:49.957] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:49.957] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:26:49.957101Z
# [2026.08.31 12:26:49.957] INFO     ──────────────────────────────────────────────────────────────────────────────
#   Readout length: 1955.556 ns
# [2026.08.31 12:26:50.148] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:50.148] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:26:50.148262Z
# [2026.08.31 12:26:50.148] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:50.368] INFO    Task 'temporary_qpu': started at 2026-08-31 09:26:50.368361Z
# [2026.08.31 12:26:50.419] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:26:50.419289Z
# [2026.08.31 12:26:50.499] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:26:50.499] INFO    09:26:50.499731Z
# [2026.08.31 12:26:50.568] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:26:50.568823Z
# [2026.08.31 12:26:50.677] INFO    Task 'create_experiment': started at 2026-08-31 09:26:50.677625Z
# [2026.08.31 12:26:50.808] INFO    Task 'create_experiment': ended at 2026-08-31 09:26:50.808349Z
# [2026.08.31 12:26:50.916] INFO    Task 'compile_experiment': started at 2026-08-31 09:26:50.916457Z
# [2026.08.31 12:26:51.028] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:26:51.028] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:26:51.028] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:26:51.028] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:26:51.028] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:26:51.028] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:26:51.042] INFO    Code generation completed for all AWGs. [0.002 s]
# [2026.08.31 12:26:51.042] INFO    Completed compilation step 1 of 1. [0.005 s]
# [2026.08.31 12:26:51.048] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:51.050] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:26:51.050] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:51.050] INFO      SHFQC_DEV12192        0         11            0           1      7840
# [2026.08.31 12:26:51.050] INFO      SHFQC_DEV12192_sg     0         14            2           1       992
# [2026.08.31 12:26:51.050] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:51.060] INFO      TOTAL                           25            2                  8832
# [2026.08.31 12:26:51.062] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:26:51.076] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:26:51.076] INFO    Task 'compile_experiment': ended at 2026-08-31 09:26:51.076285Z
# [2026.08.31 12:26:51.206] INFO    Task 'run_experiment': started at 2026-08-31 09:26:51.206180Z
# [2026.08.31 12:26:51.399] INFO    Starting near-time execution...
# [2026.08.31 12:26:51.489] INFO    Estimated RT execution time: 9.90 s.
# [2026.08.31 12:27:01.565] INFO    Finished near-time execution.
# [2026.08.31 12:27:01.631] INFO    Task 'run_experiment': ended at 2026-08-31 09:27:01.631041Z
# [2026.08.31 12:27:01.769] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:01.769] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:27:01.769106Z
# [2026.08.31 12:27:01.771] INFO     ──────────────────────────────────────────────────────────────────────────────
#   Readout length: 1966.667 ns
# [2026.08.31 12:27:01.937] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:01.937] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:27:01.937834Z
# [2026.08.31 12:27:01.937] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:02.210] INFO    Task 'temporary_qpu': started at 2026-08-31 09:27:02.210579Z
# [2026.08.31 12:27:02.252] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:27:02.252452Z
# [2026.08.31 12:27:02.320] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:27:02.320] INFO    09:27:02.320555Z
# [2026.08.31 12:27:02.368] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:27:02.368559Z
# [2026.08.31 12:27:02.464] INFO    Task 'create_experiment': started at 2026-08-31 09:27:02.464922Z
# [2026.08.31 12:27:02.597] INFO    Task 'create_experiment': ended at 2026-08-31 09:27:02.597452Z
# [2026.08.31 12:27:02.697] INFO    Task 'compile_experiment': started at 2026-08-31 09:27:02.697828Z
# [2026.08.31 12:27:02.786] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:27:02.786] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:27:02.786] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:27:02.786] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:27:02.797] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:27:02.797] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:27:02.802] INFO    Code generation completed for all AWGs. [0.003 s]
# [2026.08.31 12:27:02.804] INFO    Completed compilation step 1 of 1. [0.006 s]
# [2026.08.31 12:27:02.810] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:02.812] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:27:02.812] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:02.814] INFO      SHFQC_DEV12192        0         11            0           1      7872
# [2026.08.31 12:27:02.814] INFO      SHFQC_DEV12192_sg     0         14            2           1       992
# [2026.08.31 12:27:02.814] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:02.816] INFO      TOTAL                           25            2                  8864
# [2026.08.31 12:27:02.816] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:02.829] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:27:02.829] INFO    Task 'compile_experiment': ended at 2026-08-31 09:27:02.829948Z
# [2026.08.31 12:27:02.955] INFO    Task 'run_experiment': started at 2026-08-31 09:27:02.955656Z
# [2026.08.31 12:27:03.099] INFO    Starting near-time execution...
# [2026.08.31 12:27:03.188] INFO    Estimated RT execution time: 9.90 s.
# [2026.08.31 12:27:13.235] INFO    Finished near-time execution.
# [2026.08.31 12:27:13.323] INFO    Task 'run_experiment': ended at 2026-08-31 09:27:13.323383Z
# [2026.08.31 12:27:13.459] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:13.459] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:27:13.459790Z
# [2026.08.31 12:27:13.474] INFO     ──────────────────────────────────────────────────────────────────────────────
#   Readout length: 1977.778 ns
# [2026.08.31 12:27:13.669] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:13.671] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:27:13.669019Z
# [2026.08.31 12:27:13.671] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:13.973] INFO    Task 'temporary_qpu': started at 2026-08-31 09:27:13.973731Z
# [2026.08.31 12:27:14.038] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:27:14.038588Z
# [2026.08.31 12:27:14.167] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:27:14.167] INFO    09:27:14.167199Z
# [2026.08.31 12:27:14.233] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:27:14.233438Z
# [2026.08.31 12:27:14.362] INFO    Task 'create_experiment': started at 2026-08-31 09:27:14.360883Z
# [2026.08.31 12:27:14.503] INFO    Task 'create_experiment': ended at 2026-08-31 09:27:14.503618Z
# [2026.08.31 12:27:14.615] INFO    Task 'compile_experiment': started at 2026-08-31 09:27:14.615641Z
# [2026.08.31 12:27:14.712] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:27:14.712] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:27:14.712] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:27:14.712] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:27:14.723] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:27:14.723] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:27:14.729] INFO    Code generation completed for all AWGs. [0.006 s]
# [2026.08.31 12:27:14.729] INFO    Completed compilation step 1 of 1. [0.012 s]
# [2026.08.31 12:27:14.745] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:14.747] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:27:14.747] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:14.749] INFO      SHFQC_DEV12192        0         11            0           1      7936
# [2026.08.31 12:27:14.749] INFO      SHFQC_DEV12192_sg     0         14            2           1       992
# [2026.08.31 12:27:14.752] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:14.753] INFO      TOTAL                           25            2                  8928
# [2026.08.31 12:27:14.753] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:14.777] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:27:14.777] INFO    Task 'compile_experiment': ended at 2026-08-31 09:27:14.777239Z
# [2026.08.31 12:27:14.906] INFO    Task 'run_experiment': started at 2026-08-31 09:27:14.906972Z
# [2026.08.31 12:27:15.069] INFO    Starting near-time execution...
# [2026.08.31 12:27:15.165] INFO    Estimated RT execution time: 9.90 s.
# [2026.08.31 12:27:25.253] INFO    Finished near-time execution.
# [2026.08.31 12:27:25.362] INFO    Task 'run_experiment': ended at 2026-08-31 09:27:25.361209Z
# [2026.08.31 12:27:25.489] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:25.489] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:27:25.485930Z
# [2026.08.31 12:27:25.489] INFO     ──────────────────────────────────────────────────────────────────────────────
#   Readout length: 1988.889 ns
# [2026.08.31 12:27:25.635] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:25.635] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:27:25.635922Z
# [2026.08.31 12:27:25.635] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:25.957] INFO    Task 'temporary_qpu': started at 2026-08-31 09:27:25.957122Z
# [2026.08.31 12:27:26.004] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:27:26.004722Z
# [2026.08.31 12:27:26.117] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:27:26.117] INFO    09:27:26.117418Z
# [2026.08.31 12:27:26.189] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:27:26.189590Z
# [2026.08.31 12:27:26.293] INFO    Task 'create_experiment': started at 2026-08-31 09:27:26.293266Z
# [2026.08.31 12:27:26.423] INFO    Task 'create_experiment': ended at 2026-08-31 09:27:26.423057Z
# [2026.08.31 12:27:26.518] INFO    Task 'compile_experiment': started at 2026-08-31 09:27:26.518438Z
# [2026.08.31 12:27:26.615] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:27:26.615] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:27:26.615] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:27:26.615] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:27:26.627] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:27:26.631] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:27:26.631] INFO    Code generation completed for all AWGs. [0.005 s]
# [2026.08.31 12:27:26.631] INFO    Completed compilation step 1 of 1. [0.010 s]
# [2026.08.31 12:27:26.651] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:26.656] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:27:26.656] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:26.656] INFO      SHFQC_DEV12192        0         11            0           1      7968
# [2026.08.31 12:27:26.659] INFO      SHFQC_DEV12192_sg     0         14            2           1       992
# [2026.08.31 12:27:26.659] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:26.659] INFO      TOTAL                           25            2                  8960
# [2026.08.31 12:27:26.659] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:26.681] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:27:26.681] INFO    Task 'compile_experiment': ended at 2026-08-31 09:27:26.681056Z
# [2026.08.31 12:27:26.807] INFO    Task 'run_experiment': started at 2026-08-31 09:27:26.807603Z
# [2026.08.31 12:27:26.980] INFO    Starting near-time execution...
# [2026.08.31 12:27:27.056] INFO    Estimated RT execution time: 9.90 s.
# [2026.08.31 12:27:37.142] INFO    Finished near-time execution.
# [2026.08.31 12:27:37.215] INFO    Task 'run_experiment': ended at 2026-08-31 09:27:37.215614Z
# [2026.08.31 12:27:37.327] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:37.327] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:27:37.327586Z
# [2026.08.31 12:27:37.327] INFO     ──────────────────────────────────────────────────────────────────────────────
#   Readout length: 2000.0 ns
# [2026.08.31 12:27:37.521] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:37.521] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:27:37.505161Z
# [2026.08.31 12:27:37.521] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:37.779] INFO    Task 'temporary_qpu': started at 2026-08-31 09:27:37.779725Z
# [2026.08.31 12:27:37.825] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:27:37.825998Z
# [2026.08.31 12:27:37.906] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:27:37.906] INFO    09:27:37.906500Z
# [2026.08.31 12:27:37.954] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:27:37.954892Z
# [2026.08.31 12:27:38.050] INFO    Task 'create_experiment': started at 2026-08-31 09:27:38.050423Z
# [2026.08.31 12:27:38.164] INFO    Task 'create_experiment': ended at 2026-08-31 09:27:38.164103Z
# [2026.08.31 12:27:38.258] INFO    Task 'compile_experiment': started at 2026-08-31 09:27:38.258414Z
# [2026.08.31 12:27:38.347] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:27:38.355] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:27:38.355] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:27:38.355] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:27:38.355] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:27:38.355] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:27:38.364] INFO    Code generation completed for all AWGs. [0.004 s]
# [2026.08.31 12:27:38.366] INFO    Completed compilation step 1 of 1. [0.008 s]
# [2026.08.31 12:27:38.374] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:38.376] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:27:38.378] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:38.380] INFO      SHFQC_DEV12192        0         11            0           1      8000
# [2026.08.31 12:27:38.382] INFO      SHFQC_DEV12192_sg     0         14            2           1       992
# [2026.08.31 12:27:38.384] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:38.386] INFO      TOTAL                           25            2                  8992
# [2026.08.31 12:27:38.387] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:38.401] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:27:38.401] INFO    Task 'compile_experiment': ended at 2026-08-31 09:27:38.401217Z
# [2026.08.31 12:27:38.563] INFO    Task 'run_experiment': started at 2026-08-31 09:27:38.563495Z
# [2026.08.31 12:27:38.819] INFO    Starting near-time execution...
# [2026.08.31 12:27:38.899] INFO    Estimated RT execution time: 9.90 s.
# [2026.08.31 12:27:48.974] INFO    Finished near-time execution.
# [2026.08.31 12:27:49.053] INFO    Task 'run_experiment': ended at 2026-08-31 09:27:49.053757Z
# [2026.08.31 12:27:49.166] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:49.168] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:27:49.166027Z
# [2026.08.31 12:27:49.170] INFO     ──────────────────────────────────────────────────────────────────────────────
# Readout amplitude: 0.08393
#   Readout length: 1900.0 ns
# [2026.08.31 12:27:49.380] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:49.380] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:27:49.380455Z
# [2026.08.31 12:27:49.380] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:49.614] INFO    Task 'temporary_qpu': started at 2026-08-31 09:27:49.614773Z
# [2026.08.31 12:27:49.671] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:27:49.671475Z
# [2026.08.31 12:27:49.764] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:27:49.764] INFO    09:27:49.764463Z
# [2026.08.31 12:27:49.809] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:27:49.809464Z
# [2026.08.31 12:27:49.919] INFO    Task 'create_experiment': started at 2026-08-31 09:27:49.919827Z
# [2026.08.31 12:27:50.037] INFO    Task 'create_experiment': ended at 2026-08-31 09:27:50.037967Z
# [2026.08.31 12:27:50.129] INFO    Task 'compile_experiment': started at 2026-08-31 09:27:50.129437Z
# [2026.08.31 12:27:50.211] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:27:50.211] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:27:50.211] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:27:50.211] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:27:50.211] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:27:50.211] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:27:50.230] INFO    Code generation completed for all AWGs. [0.005 s]
# [2026.08.31 12:27:50.230] INFO    Completed compilation step 1 of 1. [0.008 s]
# [2026.08.31 12:27:50.247] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:50.247] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:27:50.247] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:50.247] INFO      SHFQC_DEV12192        0         11            0           1      7616
# [2026.08.31 12:27:50.247] INFO      SHFQC_DEV12192_sg     0         14            2           1       992
# [2026.08.31 12:27:50.247] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:50.257] INFO      TOTAL                           25            2                  8608
# [2026.08.31 12:27:50.258] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:27:50.275] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:27:50.275] INFO    Task 'compile_experiment': ended at 2026-08-31 09:27:50.275537Z
# [2026.08.31 12:27:50.410] INFO    Task 'run_experiment': started at 2026-08-31 09:27:50.410189Z
# [2026.08.31 12:27:50.568] INFO    Starting near-time execution...
# [2026.08.31 12:27:50.629] INFO    Estimated RT execution time: 9.90 s.
# [2026.08.31 12:28:00.700] INFO    Finished near-time execution.
# [2026.08.31 12:28:00.758] INFO    Task 'run_experiment': ended at 2026-08-31 09:28:00.756529Z
# [2026.08.31 12:28:00.926] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:28:00.927] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:28:00.926638Z
# [2026.08.31 12:28:00.927] INFO     ──────────────────────────────────────────────────────────────────────────────
#   Readout length: 1911.111 ns
# [2026.08.31 12:28:01.114] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:28:01.116] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:28:01.114476Z
# [2026.08.31 12:28:01.116] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:28:01.376] INFO    Task 'temporary_qpu': started at 2026-08-31 09:28:01.375362Z
# [2026.08.31 12:28:01.431] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:28:01.431166Z
# [2026.08.31 12:28:01.537] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:28:01.538] INFO    09:28:01.536530Z
# [2026.08.31 12:28:01.625] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:28:01.621968Z
# [2026.08.31 12:28:01.764] INFO    Task 'create_experiment': started at 2026-08-31 09:28:01.764713Z
# [2026.08.31 12:28:01.896] INFO    Task 'create_experiment': ended at 2026-08-31 09:28:01.896817Z
# [2026.08.31 12:28:01.973] INFO    Task 'compile_experiment': started at 2026-08-31 09:28:01.973707Z
# [2026.08.31 12:28:02.070] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:28:02.085] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:28:02.085] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:28:02.088] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:28:02.088] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:28:02.093] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:28:02.101] INFO    Code generation completed for all AWGs. [0.007 s]
# [2026.08.31 12:28:02.103] INFO    Completed compilation step 1 of 1. [0.010 s]
# [2026.08.31 12:28:02.108] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:28:02.110] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:28:02.110] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:28:02.112] INFO      SHFQC_DEV12192        0         11            0           1      7648
# [2026.08.31 12:28:02.112] INFO      SHFQC_DEV12192_sg     0         14            2           1       992
# [2026.08.31 12:28:02.112] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:28:02.114] INFO      TOTAL                           25            2                  8640
# [2026.08.31 12:28:02.114] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:28:02.130] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:28:02.133] INFO    Task 'compile_experiment': ended at 2026-08-31 09:28:02.133293Z
# [2026.08.31 12:28:02.245] INFO    Task 'run_experiment': started at 2026-08-31 09:28:02.245127Z
# [2026.08.31 12:28:02.380] INFO    Starting near-time execution...
# [2026.08.31 12:28:02.475] INFO    Estimated RT execution time: 9.90 s.
# [2026.08.31 12:28:12.530] INFO    Finished near-time execution.
# [2026.08.31 12:28:12.595] INFO    Task 'run_experiment': ended at 2026-08-31 09:28:12.595451Z
# [2026.08.31 12:28:12.764] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:28:12.764] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:28:12.764298Z
# [2026.08.31 12:28:12.768] INFO     ──────────────────────────────────────────────────────────────────────────────
#   Readout length: 1922.222 ns
# [2026.08.31 12:28:12.918] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:28:12.928] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:28:12.918192Z
# [2026.08.31 12:28:12.929] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:28:13.094] INFO    Task 'temporary_qpu': started at 2026-08-31 09:28:13.094495Z
# [2026.08.31 12:28:13.130] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:28:13.130615Z
# [2026.08.31 12:28:13.189] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:28:13.189] INFO    09:28:13.189154Z
# [2026.08.31 12:28:13.222] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:28:13.222315Z
# [2026.08.31 12:28:13.286] INFO    Task 'create_experiment': started at 2026-08-31 09:28:13.286217Z
# [2026.08.31 12:28:13.366] INFO    Task 'create_experiment': ended at 2026-08-31 09:28:13.366624Z
# [2026.08.31 12:28:13.433] INFO    Task 'compile_experiment': started at 2026-08-31 09:28:13.432182Z
# [2026.08.31 12:28:13.495] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 12:28:13.495] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 12:28:13.495] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 12:28:13.495] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 12:28:13.505] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 12:28:13.507] INFO    Schedule completed. [0.000 s]
# [2026.08.31 12:28:13.515] INFO    Code generation completed for all AWGs. [0.005 s]
# [2026.08.31 12:28:13.517] INFO    Completed compilation step 1 of 1. [0.009 s]
# [2026.08.31 12:28:13.527] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:28:13.529] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 12:28:13.531] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:28:13.531] INFO      SHFQC_DEV12192        0         11            0           1      7712
# [2026.08.31 12:28:13.533] INFO      SHFQC_DEV12192_sg     0         14            2           1       992
# [2026.08.31 12:28:13.533] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:28:13.533] INFO      TOTAL                           25            2                  8704
# [2026.08.31 12:28:13.535] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 12:28:13.547] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 12:28:13.547] INFO    Task 'compile_experiment': ended at 2026-08-31 09:28:13.547246Z
# [2026.08.31 12:28:13.633] INFO    Task 'run_experiment': started at 2026-08-31 09:28:13.633212Z
# [2026.08.31 12:28:13.751] INFO    Starting near-time execution...
# [2026.08.31 12:28:13.840] INFO    Estimated RT execution time: 9.90 s.
# [2026.08.31 12:28:23.899] INFO    Finished near-time execution.
# [2026.08.31 12:28:23.980] INFO    Task 'run_experiment': ended at 2026-08-31 09:28:23.980175Z
# [2026.08.31 12:28:24.157] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:28:24.157] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 09:28:24.157881Z
# [2026.08.31 12:28:24.173] INFO     ──────────────────────────────────────────────────────────────────────────────
#   Readout length: 1933.333 ns
# [2026.08.31 12:28:24.322] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:28:24.330] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 09:28:24.322488Z
# [2026.08.31 12:28:24.330] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 12:28:24.634] INFO    Task 'temporary_qpu': started at 2026-08-31 09:28:24.634365Z
# [2026.08.31 12:28:24.671] INFO    Task 'temporary_qpu': ended at 2026-08-31 09:28:24.671374Z
# [2026.08.31 12:28:24.752] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 12:28:24.752] INFO    09:28:24.752100Z
# [2026.08.31 12:28:24.817] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 09:28:24.817888Z
# ...
# [2026.08.31 13:21:58.211] INFO      SHFQC_DEV12192        0         11            0           1      7840
# [2026.08.31 13:21:58.211] INFO      SHFQC_DEV12192_sg     0         14            2           1       992
# [2026.08.31 13:21:58.216] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:21:58.216] INFO      TOTAL                           25            2                  8832
# [2026.08.31 13:21:58.216] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:21:58.225] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 13:21:58.225] INFO    Task 'compile_experiment': ended at 2026-08-31 10:21:58.225275Z
# [2026.08.31 13:21:58.659] INFO    Task 'run_experiment': started at 2026-08-31 10:21:58.657537Z
# [2026.08.31 13:21:58.801] INFO    Starting near-time execution...
# [2026.08.31 13:21:58.882] INFO    Estimated RT execution time: 9.90 s.
# [2026.08.31 13:22:08.933] INFO    Finished near-time execution.
# [2026.08.31 13:22:08.998] INFO    Task 'run_experiment': ended at 2026-08-31 10:22:08.998315Z
# [2026.08.31 13:22:09.731] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:09.731] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 10:22:09.731080Z
# [2026.08.31 13:22:09.731] INFO     ──────────────────────────────────────────────────────────────────────────────
#   Readout length: 1966.667 ns
# [2026.08.31 13:22:09.952] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:09.961] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 10:22:09.952333Z
# [2026.08.31 13:22:09.963] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:10.448] INFO    Task 'temporary_qpu': started at 2026-08-31 10:22:10.448082Z
# [2026.08.31 13:22:10.592] INFO    Task 'temporary_qpu': ended at 2026-08-31 10:22:10.592627Z
# [2026.08.31 13:22:10.751] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 13:22:10.751] INFO    10:22:10.751515Z
# [2026.08.31 13:22:10.798] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 10:22:10.798995Z
# [2026.08.31 13:22:10.898] INFO    Task 'create_experiment': started at 2026-08-31 10:22:10.898773Z
# [2026.08.31 13:22:11.040] INFO    Task 'create_experiment': ended at 2026-08-31 10:22:11.034425Z
# [2026.08.31 13:22:11.267] INFO    Task 'compile_experiment': started at 2026-08-31 10:22:11.265860Z
# [2026.08.31 13:22:11.524] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 13:22:11.537] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 13:22:11.537] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 13:22:11.540] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 13:22:11.540] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 13:22:11.544] INFO    Schedule completed. [0.000 s]
# [2026.08.31 13:22:11.549] INFO    Code generation completed for all AWGs. [0.003 s]
# [2026.08.31 13:22:11.549] INFO    Completed compilation step 1 of 1. [0.010 s]
# [2026.08.31 13:22:11.558] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:11.558] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 13:22:11.558] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:11.568] INFO      SHFQC_DEV12192        0         11            0           1      7872
# [2026.08.31 13:22:11.569] INFO      SHFQC_DEV12192_sg     0         14            2           1       992
# [2026.08.31 13:22:11.569] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:11.569] INFO      TOTAL                           25            2                  8864
# [2026.08.31 13:22:11.571] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:11.588] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 13:22:11.593] INFO    Task 'compile_experiment': ended at 2026-08-31 10:22:11.588278Z
# [2026.08.31 13:22:11.734] INFO    Task 'run_experiment': started at 2026-08-31 10:22:11.734926Z
# [2026.08.31 13:22:11.912] INFO    Starting near-time execution...
# [2026.08.31 13:22:11.989] INFO    Estimated RT execution time: 9.90 s.
# [2026.08.31 13:22:22.086] INFO    Finished near-time execution.
# [2026.08.31 13:22:22.156] INFO    Task 'run_experiment': ended at 2026-08-31 10:22:22.156889Z
# [2026.08.31 13:22:22.285] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:22.285] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 10:22:22.285660Z
# [2026.08.31 13:22:22.285] INFO     ──────────────────────────────────────────────────────────────────────────────
#   Readout length: 1977.778 ns
# [2026.08.31 13:22:22.587] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:22.596] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 10:22:22.587858Z
# [2026.08.31 13:22:22.596] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:23.232] INFO    Task 'temporary_qpu': started at 2026-08-31 10:22:23.230050Z
# [2026.08.31 13:22:23.276] INFO    Task 'temporary_qpu': ended at 2026-08-31 10:22:23.276600Z
# [2026.08.31 13:22:23.492] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 13:22:23.508] INFO    10:22:23.492899Z
# [2026.08.31 13:22:23.653] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 10:22:23.637590Z
# [2026.08.31 13:22:24.028] INFO    Task 'create_experiment': started at 2026-08-31 10:22:24.028464Z
# [2026.08.31 13:22:24.160] INFO    Task 'create_experiment': ended at 2026-08-31 10:22:24.160347Z
# [2026.08.31 13:22:24.260] INFO    Task 'compile_experiment': started at 2026-08-31 10:22:24.260720Z
# [2026.08.31 13:22:24.492] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 13:22:24.495] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 13:22:24.495] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 13:22:24.497] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 13:22:24.499] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 13:22:24.503] INFO    Schedule completed. [0.000 s]
# [2026.08.31 13:22:24.505] INFO    Code generation completed for all AWGs. [0.003 s]
# [2026.08.31 13:22:24.510] INFO    Completed compilation step 1 of 1. [0.007 s]
# [2026.08.31 13:22:24.516] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:24.518] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 13:22:24.519] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:24.519] INFO      SHFQC_DEV12192        0         11            0           1      7936
# [2026.08.31 13:22:24.519] INFO      SHFQC_DEV12192_sg     0         14            2           1       992
# [2026.08.31 13:22:24.519] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:24.519] INFO      TOTAL                           25            2                  8928
# [2026.08.31 13:22:24.525] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:24.536] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 13:22:24.536] INFO    Task 'compile_experiment': ended at 2026-08-31 10:22:24.536624Z
# [2026.08.31 13:22:24.978] INFO    Task 'run_experiment': started at 2026-08-31 10:22:24.977847Z
# [2026.08.31 13:22:25.146] INFO    Starting near-time execution...
# [2026.08.31 13:22:25.228] INFO    Estimated RT execution time: 9.90 s.
# [2026.08.31 13:22:35.320] INFO    Finished near-time execution.
# [2026.08.31 13:22:35.432] INFO    Task 'run_experiment': ended at 2026-08-31 10:22:35.432590Z
# [2026.08.31 13:22:35.739] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:35.739] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 10:22:35.739613Z
# [2026.08.31 13:22:35.739] INFO     ──────────────────────────────────────────────────────────────────────────────
#   Readout length: 1988.889 ns
# [2026.08.31 13:22:36.043] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:36.043] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 10:22:36.043896Z
# [2026.08.31 13:22:36.043] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:36.253] INFO    Task 'temporary_qpu': started at 2026-08-31 10:22:36.253665Z
# [2026.08.31 13:22:36.303] INFO    Task 'temporary_qpu': ended at 2026-08-31 10:22:36.303203Z
# [2026.08.31 13:22:36.501] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 13:22:36.501] INFO    10:22:36.497777Z
# [2026.08.31 13:22:36.623] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 10:22:36.623450Z
# [2026.08.31 13:22:37.026] INFO    Task 'create_experiment': started at 2026-08-31 10:22:37.026227Z
# [2026.08.31 13:22:37.155] INFO    Task 'create_experiment': ended at 2026-08-31 10:22:37.155309Z
# [2026.08.31 13:22:37.287] INFO    Task 'compile_experiment': started at 2026-08-31 10:22:37.287018Z
# [2026.08.31 13:22:37.506] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 13:22:37.506] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 13:22:37.506] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 13:22:37.517] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 13:22:37.517] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 13:22:37.517] INFO    Schedule completed. [0.000 s]
# [2026.08.31 13:22:37.522] INFO    Code generation completed for all AWGs. [0.006 s]
# [2026.08.31 13:22:37.522] INFO    Completed compilation step 1 of 1. [0.011 s]
# [2026.08.31 13:22:37.522] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:37.538] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 13:22:37.538] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:37.541] INFO      SHFQC_DEV12192        0         11            0           1      7968
# [2026.08.31 13:22:37.542] INFO      SHFQC_DEV12192_sg     0         14            2           1       992
# [2026.08.31 13:22:37.542] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:37.542] INFO      TOTAL                           25            2                  8960
# [2026.08.31 13:22:37.542] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:37.571] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 13:22:37.575] INFO    Task 'compile_experiment': ended at 2026-08-31 10:22:37.573659Z
# [2026.08.31 13:22:37.957] INFO    Task 'run_experiment': started at 2026-08-31 10:22:37.957686Z
# [2026.08.31 13:22:38.127] INFO    Starting near-time execution...
# [2026.08.31 13:22:38.223] INFO    Estimated RT execution time: 9.90 s.
# [2026.08.31 13:22:48.282] INFO    Finished near-time execution.
# [2026.08.31 13:22:48.349] INFO    Task 'run_experiment': ended at 2026-08-31 10:22:48.349454Z
# [2026.08.31 13:22:48.504] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:48.505] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 10:22:48.500640Z
# [2026.08.31 13:22:48.508] INFO     ──────────────────────────────────────────────────────────────────────────────
#   Readout length: 2000.0 ns
# [2026.08.31 13:22:48.923] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:48.923] INFO      Workflow 'iq_blobs': execution started at 2026-08-31 10:22:48.923181Z
# [2026.08.31 13:22:48.923] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:49.275] INFO    Task 'temporary_qpu': started at 2026-08-31 10:22:49.275987Z
# [2026.08.31 13:22:49.308] INFO    Task 'temporary_qpu': ended at 2026-08-31 10:22:49.308687Z
# [2026.08.31 13:22:49.439] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-08-31
# [2026.08.31 13:22:49.439] INFO    10:22:49.439277Z
# [2026.08.31 13:22:49.513] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-08-31 10:22:49.513401Z
# [2026.08.31 13:22:49.744] INFO    Task 'create_experiment': started at 2026-08-31 10:22:49.744952Z
# [2026.08.31 13:22:50.224] INFO    Task 'create_experiment': ended at 2026-08-31 10:22:50.224077Z
# [2026.08.31 13:22:50.420] INFO    Task 'compile_experiment': started at 2026-08-31 10:22:50.420045Z
# [2026.08.31 13:22:50.531] INFO    Starting LabOne Q Compiler run...
# [2026.08.31 13:22:50.531] INFO    Resolved modulation type of oscillator on signal: 'q0/acquire' to Software
# [2026.08.31 13:22:50.531] INFO    Resolved modulation type of oscillator on signal: 'q0/drive' to Hardware
# [2026.08.31 13:22:50.531] INFO    Resolved modulation type of oscillator on signal: 'q0/drive_ef' to Hardware
# [2026.08.31 13:22:50.531] INFO    Resolved modulation type of oscillator on signal: 'q0/measure' to Software
# [2026.08.31 13:22:50.531] INFO    Schedule completed. [0.000 s]
# [2026.08.31 13:22:50.547] INFO    Code generation completed for all AWGs. [0.005 s]
# [2026.08.31 13:22:50.547] INFO    Completed compilation step 1 of 1. [0.008 s]
# [2026.08.31 13:22:50.547] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:50.547] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.08.31 13:22:50.547] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:50.547] INFO      SHFQC_DEV12192        0         11            0           1      8000
# [2026.08.31 13:22:50.547] INFO      SHFQC_DEV12192_sg     0         14            2           1       992
# [2026.08.31 13:22:50.547] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:50.563] INFO      TOTAL                           25            2                  8992
# [2026.08.31 13:22:50.563] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.08.31 13:22:50.577] INFO    Finished LabOne Q Compiler run.
# [2026.08.31 13:22:50.579] INFO    Task 'compile_experiment': ended at 2026-08-31 10:22:50.579465Z
# [2026.08.31 13:22:50.788] INFO    Task 'run_experiment': started at 2026-08-31 10:22:50.788267Z
# [2026.08.31 13:22:51.113] INFO    Starting near-time execution...
# [2026.08.31 13:22:51.187] INFO    Estimated RT execution time: 9.90 s.
# [2026.08.31 13:23:01.235] INFO    Finished near-time execution.
# [2026.08.31 13:23:01.299] INFO    Task 'run_experiment': ended at 2026-08-31 10:23:01.299373Z
# [2026.08.31 13:23:01.507] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.08.31 13:23:01.507] INFO      Workflow 'iq_blobs': execution ended at 2026-08-31 10:23:01.507201Z
# [2026.08.31 13:23:01.512] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### Analysis Plots

# %%
# min / argmin of Rel_STD_0 and the Rel_STD_0 vs. amplitude plot
rel_std_0_arr = np.array(
    [[m['rel_std_0'] for m in metrics_inner] for metrics_inner in ss_ro_sweep_metrics]
)

optimal_amp_index = int(np.nanargmin(np.nanmin(rel_std_0_arr, axis=1)))
optimal_len_index = int(np.nanargmin(rel_std_0_arr[optimal_amp_index, :]))

readout_amplitude_opt = float(readout_amplitude_arr[optimal_amp_index])
readout_length_opt = float(readout_length_arr[optimal_len_index])

print('Minimal relative error value is',
      np.round(rel_std_0_arr[optimal_amp_index, optimal_len_index], 3),
      'for amplitude', np.round(readout_amplitude_opt, 3),
      '(index', optimal_amp_index, ') and length', readout_length_opt,
      '(index', optimal_len_index, ').')

fig, ax = plt.subplots(figsize=(10, 5))
ax.set_title(f'Single shot vs. readout amplitude - {qubit_to_measure.uid}')
for k, readout_length in enumerate(readout_length_arr):
    ax.plot(readout_amplitude_arr, rel_std_0_arr[:, k], '.-',
            label=f'{readout_length * 1e9:.0f} ns')
ax.axvline(x=readout_amplitude_opt, ls='-.', color='r', label='optimal')
ax.set_xlabel('Readout amplitude, a.u.')
ax.set_ylabel('Relative STD state 0')
ax.set_yscale('log')
ax.legend(title='Readout length', ncol=2)

file_path = get_path_to_file('Single_shots_vs_ro_amp_and_ro_len_', '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')
# Out:
# Minimal relative error value is 1.279 for amplitude 0.254 (index 6 ) and length 1.9e-06 (index 0 ).

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.set_title(f'Relative STD state 0 - {qubit_to_measure.uid}')
im = ax.pcolormesh(readout_length_arr * 1e9, readout_amplitude_arr, rel_std_0_arr,
                   shading='nearest')
cb = fig.colorbar(im)
cb.set_label('Relative STD state 0')
ax.plot(readout_length_opt * 1e9, readout_amplitude_opt, 'rx', ms=12, label='optimal')
ax.set_xlabel('Readout length, ns')
ax.set_ylabel('Readout amplitude, a.u.')
ax.legend()

file_path = get_path_to_file('Single_shots_ro_amp_ro_len_map_', '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %% [markdown]
# #### Update Parameters

# %%
# set to a value != None to override the values extracted above.
manual_readout_amplitude = None
manual_readout_length = None
if manual_readout_amplitude is not None:
    readout_amplitude_opt = float(manual_readout_amplitude)
if manual_readout_length is not None:
    readout_length_opt = float(manual_readout_length)

if update_global_parameters:
    temp_pars = deepcopy(qubit_to_measure.parameters)
    temp_pars.readout_amplitude = readout_amplitude_opt
    temp_pars.readout_length = readout_length_opt
    temp_pars.readout_integration_length = readout_length_opt
    qubit_to_measure.parameters = temp_pars
    save(qpu, qpu_file_path)
    print('Updated global experiment parameters!\n')

print('Readout amplitude: ', qubit_to_measure.parameters.readout_amplitude)
print('Readout length: ', qubit_to_measure.parameters.readout_length)
print('Readout integration length: ',
      qubit_to_measure.parameters.readout_integration_length)
# Out:
# Updated global experiment parameters!
#
# Readout amplitude:  0.25357142857142856
# Readout length:  1.9e-06
# Readout integration length:  1.9e-06

# %%
data_ss = {
    'states': list(states),
    'readout_amplitude_sweep': readout_amplitude_arr,
    'readout_length_sweep': readout_length_arr,
    'readout_integration_delay': readout_integration_delay,
    'rel_std_0': rel_std_0_arr,
    'n_shots': 2**n_avg_exponent,
    'comment': ('Sweep readout amplitude and readout length, array dim '
                '[readout_amplitude, readout_length]'),
}
data_ss.update(
    {k: v for k, v in attrs.asdict(qubit_to_measure.parameters).items()
     if isinstance(v, (int, float, str))}
)
data_ss['sample_name'] = sample_name
data_ss['qubit_name'] = qubit_name
data_ss['cooldown_start_date'] = cooldown_start_date

file_path = get_path_to_file('Single_shots_0_pi_sweep_ro_amp_and_ro_len_', '.mat')
savemat(file_path, data_ss)
print(f'Saved readout amplitude/length sweep to: {file_path}')
# Out:
# Saved readout amplitude/length sweep to: N:\xld\qubit_thermometry_v2\ES-009-DE_1-2_9150\COOLDOWN_2026-08-26\Q2\20260831_132305_Single_shots_0_pi_sweep_ro_amp_and_ro_len_.mat

# %%
readout_opt = {
    'readout_amplitude': qubit_to_measure.parameters.readout_amplitude,
    'readout_length': qubit_to_measure.parameters.readout_length,
    'readout_pulse': qubit_to_measure.parameters.readout_pulse,
    'readout_integration_length': qubit_to_measure.parameters.readout_integration_length,
    'readout_integration_delay': qubit_to_measure.parameters.readout_integration_delay,
    'readout_integration_kernels_type':
        qubit_to_measure.parameters.readout_integration_kernels_type,
    'readout_resonator_frequency': qubit_to_measure.parameters.readout_resonator_frequency,
    'readout_lo_frequency': qubit_to_measure.parameters.readout_lo_frequency,
    'readout_range_out': qubit_to_measure.parameters.readout_range_out,
    'readout_range_in': qubit_to_measure.parameters.readout_range_in,
    'reset_delay_length': qubit_to_measure.parameters.reset_delay_length,
}
pprint(readout_opt)
# Out:
# {'readout_amplitude': 0.25357142857142856,
#  'readout_integration_delay': 6.000000000000001e-08,
#  'readout_integration_kernels_type': 'default',
#  'readout_integration_length': 1.9e-06,
#  'readout_length': 1.9e-06,
#  'readout_lo_frequency': 6000000000.0,
#  'readout_pulse': {'function': 'gaussian_square',
#                    'width': 1.7599999999999999e-06},
#  'readout_range_in': -40,
#  'readout_range_out': -20,
#  'readout_resonator_frequency': np.float64(5959580000.0),
#  'reset_delay_length': 0.0003}

# %%
qpu.quantum_elements
# Out:
# [TunableTransmonQubit(
# │   uid='Q2',
# │   signals={
# │   │   'drive': 'q0/drive',
# │   │   'drive_ef': 'q0/drive_ef',
# │   │   'measure': 'q0/measure',
# │   │   'acquire': 'q0/acquire'
# │   },
# │   parameters=TunableTransmonQubitParameters(
# │   │   custom={},
# │   │   ge_T1=1.3645176509647932e-05,
# │   │   ge_T2=5.227829805594839e-06,
# │   │   ge_T2_star=8.607061549037454e-06,
# │   │   ef_T1=3.823989734157484e-06,
# │   │   ef_T2=1.0727739619875858e-06,
# │   │   ef_T2_star=7.980095959592148e-06,
# │   │   drive_lo_frequency=4800000000.0,
# │   │   readout_lo_frequency=6000000000.0,
# │   │   resonance_frequency_ge=5004729039.10699,
# │   │   resonance_frequency_ef=4811929098.0324335,
# │   │   readout_resonator_frequency=np.float64(5959580000.0),
# │   │   ge_drive_amplitude_pi=0.1450703458642064,
# │   │   ge_drive_amplitude_pi2=0.07343142790133057,
# │   │   ge_drive_length=2.4457142857142856e-07,
# │   │   ge_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0.2413462769901743,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   ef_drive_amplitude_pi=0.6507087790475553,
# │   │   ef_drive_amplitude_pi2=0.3099951813175842,
# │   │   ef_drive_length=1e-07,
# │   │   ef_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0.08010717043720025,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   qubit_resonator_coupling_strength_g=0,
# │   │   ge_chi_shift=0,
# │   │   readout_amplitude=0.25357142857142856,
# │   │   readout_length=1.9e-06,
# │   │   readout_pulse={
# │   │   │   'function': 'gaussian_square',
# │   │   │   'width': 1.7599999999999999e-06
# │   │   },
# │   │   readout_integration_length=1.9e-06,
# │   │   readout_integration_delay=6.000000000000001e-08,
# │   │   readout_integration_kernels_type='default',
# │   │   readout_integration_kernels=None,
# │   │   readout_integration_discrimination_thresholds=None,
# │   │   reset_delay_length=0.0003,
# │   │   drive_range=0,
# │   │   readout_range_out=-20,
# │   │   readout_range_in=-40,
# │   │   flux_range=5,
# │   │   spectroscopy_length=2e-05,
# │   │   spectroscopy_amplitude=0.4,
# │   │   spectroscopy_pulse={
# │   │   │   'function': 'const',
# │   │   │   'can_compress': True
# │   │   },
# │   │   dc_slot=0,
# │   │   dc_voltage_parking=0.0,
# │   │   flux_offset_voltage=0.0,
# │   │   user_defined={}
# │   )
# )
# ]

# %% [markdown]
# # Population Measurements

# %% [markdown]
# Effective-temperature measurements of the qubit.
#
# 1. **Rabi Population Measurements (RPM)** — compare the ef-Rabi amplitude with
#    and without a ge pre-pulse. The ratio of the two oscillation amplitudes
#    gives the residual excited-state population `p_e` and thus the effective
#    temperature. The ef pi-pulse used for the fast (two-point) version is
#    calibrated in `### Setup`.
# 2. **Three Level Population Measurements** — the six-sequence protocol
#    (`x0`, `x1`, `x2`, `y0`, `y1`, `y2`) that yields the nine `A`/`B`/`C`
#    estimators of `p_e/p_g` and the corresponding temperatures `TA1 ... TC3`,
#    including the repeated (statistics) version, the projection-phase
#    optimization and a variant with a ge pre-pulse of swept amplitude.
# 3. **Population Measurements for Different Readout Frequencies** — the same
#    six-sequence protocol repeated for a range of readout resonator
#    frequencies (slow!).
#
# The readout parameters optimized in `# Readout Optimization` and
# `# Single Shot 0 and 1 Measurements` are the starting point here.
#
# `laboneq_applications` has no population experiment, so the experiments and
# workflows are defined in `## Custom Experiment Workflows` below.

# %% [markdown]
# ## Helpers

# %% [markdown]
# #### Additional Imports

# %%
# Needed by the custom population workflows.
from laboneq.workflow.tasks import compile_experiment, run_experiment

from laboneq_applications.core import validation
from laboneq_applications.experiments.options import BaseExperimentOptions
from laboneq_applications.tasks.parameter_updating import (
    temporary_qpu,
    temporary_quantum_elements_from_qpu,
)

from scipy.optimize import fsolve

# %% [markdown]
# #### Fit Helpers

# %%
# Old `lib.helpers.fitting_helper.func_osc` / `fit_Rabi` / `normalize_1d_osc`.DS_Store
def func_osc(x, freq, phase, amp=1, off=0):
    """Old `lib.helpers.fitting_helper.func_osc`, unchanged."""
    return amp * np.cos(freq * x + phase) + off


def fit_rabi_osc(x, y, freq, phase, amp=None, off=None, plot=False, bounds=None):
    """New-structure replacement for the old `fit_Rabi`.

    Same maths (scipy `curve_fit` of `func_osc`), snake_case name. The RPM
    section fits the *raw* magnitude/phase traces, so this stays a manual fit
    instead of the lmfit result of an `analysis_workflow`.
    """
    p0 = [freq, phase]
    if amp is not None:
        p0.append(amp)
        if off is not None:
            p0.append(off)

    kwargs = {} if bounds is None else {'bounds': bounds}
    popt, pcov = curve_fit(func_osc, x, y, p0=p0, **kwargs)

    if plot:
        plt.plot(x, y, '.k')
        plt.plot(x, func_osc(x, *popt), '-r')
        plt.xlabel('Amplitude, a.u.')
        plt.ylabel('Signal, a.u.')
        plt.show()

    return popt, pcov


def normalize_1d_osc(osc, offset=None, norm=None):
    """Old `lib.helpers.fitting_helper.normalize_1d_osc`, unchanged."""
    if offset is None:
        offset = np.mean(osc)
    if norm is None:
        norm = 1 / np.abs(osc.max() - osc.min())

    return 2 * (osc - offset) * norm, offset, norm


def qrpm_dict_from_results(results):
    """New-structure replacement for `get_qrpm_dict_from_list_of_results`.

    Takes a list of `rpm_res` dicts (as built in `#### Analysis Plots` of
    `### Population Measurement`) and flattens them into one dict of arrays,
    with the same keys as the old helper.
    """
    keys = ['I_max', 'I_min', 'Q_max', 'Q_min',
            'mag_max', 'mag_min', 'pha_max', 'pha_min']
    out = {}
    for key in keys:
        for pre_pulse in ['with', 'wo']:
            out[f'{key}_{pre_pulse}'] = np.array(
                [np.mean(res[pre_pulse][key]) for res in results]
            )
    return out

# %% [markdown]
# #### Temperature Helpers

# %%
# Old `lib.helpers.pop_temp_helper_v2`: populations -> pe/pg -> temperature.
# The six population labels of the three-level protocol.
pop_label_list = ['x0', 'x1', 'x2', 'y0', 'y1', 'y2']


def T_calc(C, f_q):
    """Old `T_calc`, unchanged: pe/pg (= C) and f_q in GHz -> temperature in K."""
    h = 6.628e-2
    k = 1.381
    return -(h * f_q / k) / np.log(C)


def A_temp(T, A, f_q, anharm):
    """Old `A_temp`, unchanged. `f_q` and `anharm` in GHz."""
    h = 6.628e-2
    k = 1.381
    f_g2 = 2 * f_q - anharm
    num = 1 - np.exp(-h * f_q / k / T)
    denum = 1 - np.exp(-h * f_g2 / k / T)
    return A - num / denum


def B_temp(T, B, f_q, anharm):
    """Old `B_temp`, unchanged."""
    h = 6.628e-2
    k = 1.381
    f_g2 = 2 * f_q - anharm
    num = np.exp(-h * f_q / k / T) - np.exp(-h * f_g2 / k / T)
    denum = 1 - np.exp(-h * f_q / k / T)
    return B - num / denum


def C_temp(T, C, f_q, anharm):
    """Old `C_temp`, unchanged."""
    h = 6.628e-2
    k = 1.381
    f_g2 = 2 * f_q - anharm
    num = np.exp(-h * f_q / k / T) - np.exp(-h * f_g2 / k / T)
    denum = 1 - np.exp(-h * f_g2 / k / T)
    return C - num / denum


def get_qubit_temperature_parameters(qubit):
    """`f_q` and `anharm` (both in GHz) of the new qubit parameters.

    New-structure replacement for
    `f_q = (lo_settings["qb_lo"] + qubit_parameters["qb_freq"]) * 1e-9` and
    `anharm = qubit_parameters['qb_anharm'] * 1e-9`: both resonance frequencies
    are absolute now, so the anharmonicity is their difference.
    """
    f_q = qubit.parameters.resonance_frequency_ge * 1e-9
    anharm = (
        qubit.parameters.resonance_frequency_ge
        - qubit.parameters.resonance_frequency_ef
    ) * 1e-9
    return f_q, anharm

# %%
def get_ABC(pop_proj):
    """Old `get_ABC`, unchanged: the nine estimators from projected data."""
    x0 = pop_proj['x0']
    x1 = pop_proj['x1']
    x2 = pop_proj['x2']
    y0 = pop_proj['y0']
    y1 = pop_proj['y1']
    y2 = pop_proj['y2']

    result = {}
    result['A1'] = (x0 - x1) / (y0 - y1)
    result['B1'] = (x2 - y2) / (x0 - x1)
    result['C1'] = result['A1'] * result['B1']

    result['A2'] = (y0 - x2) / (x0 - y2)
    result['B2'] = (x1 - y1) / (y0 - x2)
    result['C2'] = result['A2'] * result['B2']

    result['A3'] = (y1 - y2) / (x1 - x2)
    result['B3'] = (x0 - y0) / (y1 - y2)
    result['C3'] = result['A3'] * result['B3']

    return result


def make_projection(pop_full_results, phase):
    """Old `make_projection`, unchanged: rotate and project onto I and Q."""
    res_I = {}
    res_Q = {}
    for k in pop_full_results:
        rot = pop_full_results[k] * np.exp(1j * phase)
        res_I[k] = rot.real
        res_Q[k] = rot.imag

    return res_I, res_Q


def get_temperature(ABC, f_q, anharm=None, three_levels=False):
    """Old `get_temperature`, with `anharm` now optional.

    N.B: with `three_levels=False` the simple low-temperature limit is used and
    `anharm` is ignored (the old notebook called
    `get_temperature(ABC_I, f_q)`, which used to raise a TypeError).
    """
    if three_levels and anharm is None:
        raise ValueError("`anharm` is required when `three_levels=True`.")

    def _pick(val, index):
        """Scalar for this element, whether `val` is a single scalar
        or an array shaped like ABC[k]."""
        arr = np.asarray(val)
        if arr.ndim == 0:
            return arr.item()
        return float(arr[index])

    result = {}
    for k in ABC:
        new_k = 'T' + k
        if k[0] == 'A':
            result[new_k] = T_calc(1 - ABC[k], f_q) * 1e3
            solve_fn = A_temp
        elif k[0] == 'B':
            result[new_k] = T_calc(ABC[k] / (ABC[k] + 1), f_q) * 1e3
            solve_fn = B_temp
        elif k[0] == 'C':
            result[new_k] = T_calc(ABC[k], f_q) * 1e3
            solve_fn = C_temp
        else:
            print('Wrong key in ABC dictionary!')
            continue

        if three_levels:
            for index, x in np.ndenumerate(ABC[k]):
                x0 = float(result[new_k][index]) * 1e-3
                f_q_i = _pick(f_q, index)
                anharm_i = _pick(anharm, index)
                root = fsolve(solve_fn, x0, args=(float(x), f_q_i, anharm_i))
                result[new_k][index] = float(root[0]) * 1e3
                
    return result


def get_stat(data):
    """Old `get_stat`, unchanged: [mean, std, relative error] per key."""
    stat = {}
    for k in data:
        arr = np.asarray(data[k], dtype=float)
        M = np.nanmean(arr)
        V = np.sqrt(np.var(arr, ddof=1))
        stat[k] = np.array([M, V, V / M], dtype=float)
        if stat[k].shape != (3,):
            raise RuntimeError(f"Unexpected stat shape for key {k!r}: "
                               f"{stat[k].shape}, data shape was {arr.shape}")
    return stat


def get_stat_nan(data):
    """Old `get_stat_nan`, unchanged: same as `get_stat` but nan-aware."""
    stat = {}
    for k in data:
        M = np.nanmean(data[k])
        V = np.sqrt(np.nanvar(data[k], ddof=1))
        stat[k] = np.array([M, V, V / M])
    return stat


def make_all_temperatures(pop_full_results, f_q, anharm, phase=0,
                          three_levels=True):
    """Old `make_all_temperatures`, unchanged."""
    proj_I, proj_Q = make_projection(pop_full_results, phase)

    ABC_I = get_ABC(proj_I)
    ABC_Q = get_ABC(proj_Q)

    TABC_I = get_temperature(ABC_I, f_q, anharm, three_levels=three_levels)
    TABC_Q = get_temperature(ABC_Q, f_q, anharm, three_levels=three_levels)
    return TABC_I, TABC_Q

# %%
# Old `get_diff` / `get_axes_and_rotate` / `get_ABC_parallel` / `get_C_from_ABC`:
# the 'parallel' way of processing the data (rotation per difference vector).
def get_diff(pop_proj):
    """Old `get_diff`, unchanged."""
    x0 = pop_proj['x0']
    x1 = pop_proj['x1']
    x2 = pop_proj['x2']
    y0 = pop_proj['y0']
    y1 = pop_proj['y1']
    y2 = pop_proj['y2']
    diff_dict = {}
    # parallel to ge, index 1
    diff_dict['x0x1'] = x0 - x1  # order1, mid
    diff_dict['y0y1'] = y0 - y1  # order1, max
    diff_dict['x2y2'] = x2 - y2  # order0, min

    # parallel to gf, index 2
    diff_dict['y0x2'] = y0 - x2  # order1, mid
    diff_dict['x0y2'] = x0 - y2  # order1, max
    diff_dict['x1y1'] = x1 - y1  # order0, min

    # parallel to ef, index 3
    diff_dict['y1y2'] = y1 - y2  # order1, mid
    diff_dict['x1x2'] = x1 - x2  # order1, max
    diff_dict['x0y0'] = x0 - y0  # order0, min
    return diff_dict


def get_axes_and_rotate(D1, D2, D3):
    """Old `get_axes_and_rotate`, unchanged."""
    Angle1 = np.angle(D1)
    Angle2 = np.angle(D2)
    angle = (Angle1 + Angle2) / 2
    D1_rot = D1 * np.exp(-1j * angle)
    D2_rot = D2 * np.exp(-1j * angle)
    D3_rot = D3 * np.exp(-1j * angle)

    A = D1_rot.real / D2_rot.real
    B = D3_rot.real / D1_rot.real
    C = D3_rot.real / D2_rot.real

    return A, B, C


def get_ABC_parallel(pop_full_results):
    """Old `get_ABC_parallel`, unchanged."""
    diff_dict = get_diff(pop_full_results)

    result = {}
    result['A1'], result['B1'], result['C1'] = get_axes_and_rotate(
        diff_dict['x0x1'], diff_dict['y0y1'], diff_dict['x2y2']
    )
    result['A2'], result['B2'], result['C2'] = get_axes_and_rotate(
        diff_dict['y0x2'], diff_dict['x0y2'], diff_dict['x1y1']
    )
    result['A3'], result['B3'], result['C3'] = get_axes_and_rotate(
        diff_dict['y1y2'], diff_dict['x1x2'], diff_dict['x0y0']
    )
    return result


def get_C_from_ABC(ABC_dict):
    """Old `get_C_from_ABC`, unchanged: every estimator expressed as pe/pg."""
    CCC_dict = {}
    for k in ABC_dict:
        kn = 'C' + k
        if 'A' in k:
            CCC_dict[kn] = 1 - ABC_dict[k]
        elif 'B' in k:
            CCC_dict[kn] = ABC_dict[k] / (1 + ABC_dict[k])
        else:
            CCC_dict[kn] = ABC_dict[k]
    return CCC_dict

# %%
# Old `make_rotation_temperature` / `make_optimal_temperature` /
# `find_optimal_temperature`: projection-phase optimization.
def make_rotation_temperature(data, phase_arr, f_q, anharm, three_levels=True):
    """Old `make_rotation_temperature`, unchanged."""
    STAT_I = {}
    STAT_Q = {}

    for i in range(len(phase_arr)):
        proj_I, proj_Q = make_projection(data, phase_arr[i])

        ABC_I = get_ABC(proj_I)
        ABC_Q = get_ABC(proj_Q)

        TABC_I = get_temperature(ABC_I, f_q, anharm, three_levels=three_levels)
        TABC_Q = get_temperature(ABC_Q, f_q, anharm, three_levels=three_levels)

        stat_TABC_I = get_stat(TABC_I)
        stat_TABC_Q = get_stat(TABC_Q)
        for k in stat_TABC_I:
            if i == 0:
                STAT_I[k] = [stat_TABC_I[k]]
                STAT_Q[k] = [stat_TABC_Q[k]]
            else:
                STAT_I[k].append(stat_TABC_I[k])
                STAT_Q[k].append(stat_TABC_Q[k])

    for k in stat_TABC_I:
        STAT_I[k] = np.array(STAT_I[k])
        STAT_Q[k] = np.array(STAT_Q[k])

    return STAT_I, STAT_Q


def make_optimal_temperature(data, phase_arr, f_q, anharm, skip=(),
                             info_type='rel_err', three_levels=True):
    """Old `make_optimal_temperature`, unchanged."""
    STAT_I, STAT_Q = make_rotation_temperature(
        data, phase_arr, f_q, anharm, three_levels=three_levels
    )

    optimal_method = {'rel_err': 1000, 'phase': 0, 'ph_p': 0,
                      'method': '0', 'axes': '0'}
    it = {'mean': 0, 'error': 1, 'rel_err': 2}[info_type]

    for k in STAT_I:
        if k in skip:
            continue
        rel_Q = np.nanmin(STAT_Q[k][:, it])
        ph_p_Q = np.nanargmin(STAT_Q[k][:, it])
        rel_I = np.nanmin(STAT_I[k][:, it])
        ph_p_I = np.nanargmin(STAT_I[k][:, it])

        if (rel_I or ph_p_Q) < optimal_method['rel_err']:
            optimal_method['method'] = k
            if abs(phase_arr[ph_p_Q]) < abs(phase_arr[ph_p_I]):
                optimal_method['rel_err'] = rel_Q
                optimal_method['phase'] = phase_arr[ph_p_Q]
                optimal_method['ph_p'] = ph_p_Q
                optimal_method['axes'] = 'Q'
            else:
                optimal_method['rel_err'] = rel_I
                optimal_method['phase'] = phase_arr[ph_p_I]
                optimal_method['ph_p'] = ph_p_I
                optimal_method['axes'] = 'I'
    return optimal_method


def find_optimal_temperature(pop_full_results, optimal_method, f_q, anharm,
                             three_levels=True):
    """Old `find_optimal_temperature`, unchanged."""
    proj_I, proj_Q = make_projection(pop_full_results, optimal_method['phase'])

    if optimal_method['axes'] == 'I':
        ABC = get_ABC(proj_I)
    elif optimal_method['axes'] == 'Q':
        ABC = get_ABC(proj_Q)
    else:
        print('Wrong axe in optimal_parameters!')
        return None

    TABC = get_temperature(ABC, f_q, anharm, three_levels=three_levels)
    return TABC[optimal_method['method']]

# %%
# Old `plot_temperatures` / `plot_temp_single` / `plot_stat` /
# `plot_rotation_stat`.
_TEMP_COLOR_CYCLE = ['red', 'orange', 'gold', 'green', 'limegreen', 'cyan',
                     'blue', 'darkviolet', 'magenta']


def plot_temperatures(TABC_I, TABC_Q, skip=(), xlim=None, ylim=None):
    """Old `plot_temperatures`, unchanged (returns the figure now)."""
    fig, ax = plt.subplots(2, 1, sharex=True, figsize=(10, 8))

    ax[0].set_prop_cycle(color=_TEMP_COLOR_CYCLE)
    ax[1].set_prop_cycle(color=_TEMP_COLOR_CYCLE)

    fig.supxlabel('Point number')
    fig.supylabel('Effective temperature, mK')

    ax[0].set_title('I component')
    ax[1].set_title('Q component')

    for k in TABC_I:
        if k in skip:
            continue
        ax[0].plot(TABC_I[k], 'o-', label=k)
    ax[0].legend()

    for k in TABC_Q:
        if k in skip:
            continue
        ax[1].plot(TABC_Q[k], 'o-', label=k)
    ax[1].legend()

    if xlim is not None:
        ax[0].set_xlim(xlim)
        ax[1].set_xlim(xlim)
    if ylim is not None:
        ax[0].set_ylim(ylim)
        ax[1].set_ylim(ylim)

    return fig, ax


def plot_temp_single(TABC, skip=(), xlim=None, ylim=None, xdata=None,
                     xlabel='Point Number'):
    """Old `plot_temp_single`, unchanged."""
    if xdata is not None:
        assert len(xdata) == len(TABC[next(iter(TABC))]), \
            'Provide xdata array of proper length!'
    fig, ax = plt.subplots(1, 1, figsize=(8, 6))

    ax.set_prop_cycle(color=_TEMP_COLOR_CYCLE)

    fig.supxlabel(xlabel)
    fig.supylabel('Effective temperature, mK')

    for k in TABC:
        if k in skip:
            continue
        if xdata is None:
            ax.plot(TABC[k], 'o-', label=k)
        else:
            ax.plot(xdata, TABC[k], 'o-', label=k)
    ax.legend()

    if xlim is not None:
        ax.set_xlim(xlim)
    if ylim is not None:
        ax.set_ylim(ylim)

    return fig, ax


def plot_stat(STAT_I, STAT_Q):
    labels = list(STAT_I.keys())
    
    I_mean = [STAT_I[k][0] for k in labels]
    Q_mean = [STAT_Q[k][0] for k in labels]
    I_err = [STAT_I[k][0] for k in labels]
    Q_err = [STAT_Q[k][0] for k in labels]

    fig, ax = plt.subplots(1, 2, sharex=True, figsize=(10, 8))

    fig.supylabel('Effective temperature, mK')

    ax[0].set_title('I component')
    ax[1].set_title('Q component')

    ax[0].bar(labels, I_mean)
    ax[0].errorbar(labels, I_mean, yerr=I_err, fmt='o', color='r')

    ax[1].bar(labels, Q_mean)
    ax[1].errorbar(labels, Q_mean, yerr=Q_err, fmt='o', color='r')

    return fig, ax


def plot_rotation_stat(phase_arr, STAT_I, STAT_Q, info_type='rel_err'):
    """Old `plot_rotation_stat`, unchanged (3x3 grid of the estimators).

    This also replaces the three hand-written 3x3 plotting cells of the old
    notebook (cells 390-392), which only differed in `info_type`
    ('mean' / 'error' / 'rel_err').
    """
    it, title, ylabel = {
        'mean': (0, 'Mean of effective temperature vs. phase rotation',
                 'Effective temperature, mK'),
        'error': (1, 'Absolute errors for effective temperature vs. phase rotation',
                  'Absolute error'),
        'rel_err': (2, 'Relative errors for effective temperature vs. phase rotation',
                    'Relative error'),
    }[info_type]

    fig, ax = plt.subplots(3, 3, sharex=True, figsize=(10, 8))

    fig.suptitle(title, fontsize=16)
    fig.supylabel(ylabel)
    fig.supxlabel('Phase')

    for row, letter in enumerate(['A', 'B', 'C']):
        for col, index in enumerate(['1', '2', '3']):
            k = f'T{letter}{index}'
            ax[row, col].plot(phase_arr, STAT_I[k][:, it], label='I')
            ax[row, col].plot(phase_arr, STAT_Q[k][:, it], label='Q')
            ax[row, col].set_title(f'{letter}{index}')

    fig.legend(*ax[0, 0].get_legend_handles_labels())

    return fig, ax

# %% [markdown]
# ## Custom Experiment Workflows

# %% [markdown]
# `laboneq_applications` does not provide a population-measurement experiment,
# so the three experiments of this section are defined here in the same way as
# the built-in ones:
#
# - `population` — the six-sequence three-level protocol (old
#   `make_exp_population_full`), optionally with a ge pre-pulse of swept
#   amplitude in front of every sequence (old `make_exp_population_prepulse`).
# - `rabi_population` — the ef-amplitude sweep with and without a ge pre-pulse
#   (old `get_rabi_population_calibration_measurement`).
# - `quick_rabi_population` — only the two extreme points of that sweep, with
#   and without ge pre-pulse (old `get_quick_rabi_population_measurement`).
#
# All three use the qubit parameters (through `temporary_parameters`) and the
# quantum operations of the QPU, so the old `readout_*` dictionaries, signal
# maps and calibration objects are no longer needed.

# %% [markdown]
# #### Three Level Population Experiment

# %%
# Old `make_exp_population_full` / `make_exp_population_prepulse`
# (lib/helpers/meas_helper_mod.py) + `create_exp_population_full`
# (lib/helpers/create_meas_helper.py).

# The six sequences of the three-level protocol, as lists of pi-pulse
# transitions played before the readout:
#   x0: -                 (thermal state)
#   x1: X_ge
#   x2: X_ge, X_ef
#   y0: X_ef
#   y1: X_ef, X_ge
#   y2: X_ef, X_ge, X_ef
POPULATION_SEQUENCES = {
    'x0': (),
    'x1': ('ge',),
    'x2': ('ge', 'ef'),
    'y0': ('ef',),
    'y1': ('ef', 'ge'),
    'y2': ('ef', 'ge', 'ef'),
}


@workflow.workflow_options
class PopulationWorkflowOptions:
    """Options for the population-measurement workflows.

    There is no analysis workflow for these experiments, so only the options of
    the `create_experiment` task (`count`, `averaging_mode`, ...) are relevant.
    """


@workflow.task
@dsl.qubit_experiment
def create_population_experiment(
    qpu,
    qubit,
    prepulse_amplitudes=None,
    options: BaseExperimentOptions | None = None,
):
    """Create the three-level population experiment.

    Arguments:
        qpu: The QPU consisting of the qubits and quantum operations.
        qubit: The qubit to run the experiment on.
        prepulse_amplitudes: If not None, a ge drive pulse with these amplitudes
            is played in front of every sequence and swept in real time
            (old `make_exp_population_prepulse`). If None, the plain
            six-sequence experiment is created (old `make_exp_population_full`).
        options: `BaseExperimentOptions`. The defaults (`AveragingMode.CYCLIC`,
            `AcquisitionType.INTEGRATION`) are what the old experiment used.
    """
    opts = BaseExperimentOptions() if options is None else options
    if prepulse_amplitudes is None:
        qubit = validation.validate_and_convert_single_qubit_sweeps(qubit)
    else:
        qubit, prepulse_amplitudes = (
            validation.validate_and_convert_single_qubit_sweeps(
                qubit, prepulse_amplitudes
            )
        )

    max_measure_section_length = qpu.measure_section_length([qubit])
    qop = qpu.quantum_operations

    def _sequences(prepulse_amplitude=None):
        for label, transitions in POPULATION_SEQUENCES.items():
            with dsl.section(name=f'main_{label}',
                             alignment=SectionAlignment.RIGHT):
                if prepulse_amplitude is not None or transitions:
                    with dsl.section(name=f'drive_{label}',
                                     alignment=SectionAlignment.RIGHT):
                        if prepulse_amplitude is not None:
                            sec = qop.x180(qubit, transition='ge',
                                           amplitude=prepulse_amplitude)
                            sec.alignment = SectionAlignment.RIGHT
                        for transition in transitions:
                            sec = qop.x180(qubit, transition=transition)
                            sec.alignment = SectionAlignment.RIGHT
                with dsl.section(name=f'measure_{label}',
                                 alignment=SectionAlignment.LEFT):
                    sec = qop.measure(
                        qubit,
                        dsl.handles.result_handle(qubit.uid, suffix=label),
                    )
                    sec.length = max_measure_section_length
                    qop.passive_reset(qubit)

    with dsl.acquire_loop_rt(
        count=opts.count,
        averaging_mode=opts.averaging_mode,
        acquisition_type=opts.acquisition_type,
        repetition_mode=opts.repetition_mode,
        repetition_time=opts.repetition_time,
        reset_oscillator_phase=opts.reset_oscillator_phase,
    ):
        if prepulse_amplitudes is None:
            _sequences()
        else:
            with dsl.sweep(
                name=f'prepulse_amplitude_sweep_{qubit.uid}',
                parameter=SweepParameter(
                    f'prepulse_amplitude_{qubit.uid}', prepulse_amplitudes
                ),
            ) as prepulse_amplitude:
                _sequences(prepulse_amplitude)


@workflow.workflow(name='population')
def population_experiment_workflow(
    session,
    qpu,
    qubit,
    prepulse_amplitudes=None,
    temporary_parameters=None,
    options: PopulationWorkflowOptions | None = None,
):
    """The three-level population measurement workflow.

    Replaces the old
    `create_exp_population_full(x180, x180_ef, readout_opt, n_average)` +
    `my_session.compile()` + `my_session.run()` and, with
    `prepulse_amplitudes`, `make_exp_population_prepulse(pulse_sweep, ...)`.
    """
    temp_qpu = temporary_qpu(qpu, temporary_parameters)
    qubit = temporary_quantum_elements_from_qpu(temp_qpu, qubit)
    exp = create_population_experiment(
        temp_qpu,
        qubit,
        prepulse_amplitudes=prepulse_amplitudes,
    )
    compiled_exp = compile_experiment(session, exp)
    result = run_experiment(session, compiled_exp)
    workflow.return_(result)


def collect_population_from_result(result, qubit_uid, labels=pop_label_list):
    """The six population traces of a population workflow result.

    New-structure replacement for
    `results_population_full.get_data('x0_readout')` etc.
    """
    return {
        label: result[dsl.handles.result_handle(qubit_uid, suffix=label)].data
        for label in labels
    }

# %% [markdown]
# #### Rabi Population Experiment

# %%
# Old `get_rabi_population_calibration_measurement`
# (lib/helpers/meas_helper_mod.py).
#   wo:   X_ef(theta), X_ge          -> handle '<uid>/result/wo'
#   with: X_ge, X_ef(theta), X_ge    -> handle '<uid>/result/with'
@workflow.task
@dsl.qubit_experiment
def create_rabi_population_experiment(
    qpu,
    qubit,
    ef_amplitudes,
    options: BaseExperimentOptions | None = None,
):
    """Create the RPM calibration experiment (ef-amplitude sweep).

    Arguments:
        qpu: The QPU consisting of the qubits and quantum operations.
        qubit: The qubit to run the experiment on.
        ef_amplitudes: The ef drive amplitudes to sweep over
            (old `theta_ef_sweep`).
        options: `BaseExperimentOptions`.
    """
    opts = BaseExperimentOptions() if options is None else options
    qubit, ef_amplitudes = validation.validate_and_convert_single_qubit_sweeps(
        qubit, ef_amplitudes
    )

    max_measure_section_length = qpu.measure_section_length([qubit])
    qop = qpu.quantum_operations

    with dsl.acquire_loop_rt(
        count=opts.count,
        averaging_mode=opts.averaging_mode,
        acquisition_type=opts.acquisition_type,
        repetition_mode=opts.repetition_mode,
        repetition_time=opts.repetition_time,
        reset_oscillator_phase=opts.reset_oscillator_phase,
    ):
        with dsl.sweep(
            name=f'ef_amplitude_sweep_{qubit.uid}',
            parameter=SweepParameter(f'ef_amplitude_{qubit.uid}', ef_amplitudes),
        ) as ef_amplitude:
            # without ge pre-pulse
            with dsl.section(name='main_wo', alignment=SectionAlignment.RIGHT):
                with dsl.section(name='drive_wo',
                                 alignment=SectionAlignment.RIGHT):
                    sec = qop.x180(qubit, transition='ef',
                                   amplitude=ef_amplitude)
                    sec.alignment = SectionAlignment.RIGHT
                    sec = qop.x180(qubit, transition='ge')
                    sec.alignment = SectionAlignment.RIGHT
                with dsl.section(name='measure_wo',
                                 alignment=SectionAlignment.LEFT):
                    sec = qop.measure(
                        qubit, dsl.handles.result_handle(qubit.uid, suffix='wo')
                    )
                    sec.length = max_measure_section_length
                    qop.passive_reset(qubit)

            # with ge pre-pulse
            with dsl.section(name='main_with', alignment=SectionAlignment.RIGHT):
                with dsl.section(name='drive_with',
                                 alignment=SectionAlignment.RIGHT):
                    sec = qop.x180(qubit, transition='ge')
                    sec.alignment = SectionAlignment.RIGHT
                    sec = qop.x180(qubit, transition='ef',
                                   amplitude=ef_amplitude)
                    sec.alignment = SectionAlignment.RIGHT
                    sec = qop.x180(qubit, transition='ge')
                    sec.alignment = SectionAlignment.RIGHT
                with dsl.section(name='measure_with',
                                 alignment=SectionAlignment.LEFT):
                    sec = qop.measure(
                        qubit,
                        dsl.handles.result_handle(qubit.uid, suffix='with'),
                    )
                    sec.length = max_measure_section_length
                    qop.passive_reset(qubit)


@workflow.workflow(name='rabi_population')
def rabi_population_experiment_workflow(
    session,
    qpu,
    qubit,
    ef_amplitudes,
    temporary_parameters=None,
    options: PopulationWorkflowOptions | None = None,
):
    """The Rabi-population-measurement calibration workflow."""
    temp_qpu = temporary_qpu(qpu, temporary_parameters)
    qubit = temporary_quantum_elements_from_qpu(temp_qpu, qubit)
    exp = create_rabi_population_experiment(
        temp_qpu,
        qubit,
        ef_amplitudes=ef_amplitudes,
    )
    compiled_exp = compile_experiment(session, exp)
    result = run_experiment(session, compiled_exp)
    workflow.return_(result)

# %% [markdown]
# #### Quick Rabi Population Experiment

# %%
# Old `get_quick_rabi_population_measurement`
# (lib/helpers/meas_helper_mod.py). Only the two extreme points of the
# ef-Rabi are measured, `repetitions` times:
#   wo_min:   X_ef(0),  X_ge                 -> '<uid>/result/wo_min'
#   wo_max:   X_ef(pi), X_ge                 -> '<uid>/result/wo_max'
#   with_min: X_ge,     X_ge                 -> '<uid>/result/with_min'
#   with_max: X_ge, X_ef(pi), X_ge           -> '<uid>/result/with_max'
QUICK_RPM_SEQUENCES = {
    'wo_min': (('ef', 0.0), ('ge', None)),
    'wo_max': (('ef', None), ('ge', None)),
    'with_min': (('ge', None), ('ge', None)),
    'with_max': (('ge', None), ('ef', None), ('ge', None)),
}


@workflow.task
@dsl.qubit_experiment
def create_quick_rabi_population_experiment(
    qpu,
    qubit,
    repetitions=1,
    options: BaseExperimentOptions | None = None,
):
    """Create the quick (two-point) RPM experiment.

    Arguments:
        qpu: The QPU consisting of the qubits and quantum operations.
        qubit: The qubit to run the experiment on.
        repetitions: How many times the four points are repeated
            (old `rep_count` of the `mock_sweep`).
        options: `BaseExperimentOptions`.
    """
    opts = BaseExperimentOptions() if options is None else options
    qubit = validation.validate_and_convert_single_qubit_sweeps(qubit)

    max_measure_section_length = qpu.measure_section_length([qubit])
    qop = qpu.quantum_operations

    with dsl.acquire_loop_rt(
        count=opts.count,
        averaging_mode=opts.averaging_mode,
        acquisition_type=opts.acquisition_type,
        repetition_mode=opts.repetition_mode,
        repetition_time=opts.repetition_time,
        reset_oscillator_phase=opts.reset_oscillator_phase,
    ):
        with dsl.sweep(
            name=f'repetition_sweep_{qubit.uid}',
            parameter=SweepParameter(
                f'repetition_{qubit.uid}', np.arange(repetitions)
            ),
        ):
            for label, pulses in QUICK_RPM_SEQUENCES.items():
                with dsl.section(name=f'main_{label}',
                                 alignment=SectionAlignment.RIGHT):
                    with dsl.section(name=f'drive_{label}',
                                     alignment=SectionAlignment.RIGHT):
                        for transition, amplitude in pulses:
                            sec = qop.x180(qubit, transition=transition,
                                           amplitude=amplitude)
                            sec.alignment = SectionAlignment.RIGHT
                    with dsl.section(name=f'measure_{label}',
                                     alignment=SectionAlignment.LEFT):
                        sec = qop.measure(
                            qubit,
                            dsl.handles.result_handle(qubit.uid, suffix=label),
                        )
                        sec.length = max_measure_section_length
                        qop.passive_reset(qubit)


@workflow.workflow(name='quick_rabi_population')
def quick_rabi_population_experiment_workflow(
    session,
    qpu,
    qubit,
    repetitions=1,
    temporary_parameters=None,
    options: PopulationWorkflowOptions | None = None,
):
    """The quick Rabi-population-measurement workflow."""
    temp_qpu = temporary_qpu(qpu, temporary_parameters)
    qubit = temporary_quantum_elements_from_qpu(temp_qpu, qubit)
    exp = create_quick_rabi_population_experiment(
        temp_qpu,
        qubit,
        repetitions=repetitions,
    )
    compiled_exp = compile_experiment(session, exp)
    result = run_experiment(session, compiled_exp)
    workflow.return_(result)

# %% [markdown]
# ## Rabi Population Measurements (RPM)

# %% [markdown]
# ### Setup

# %% [markdown]
# #### Oscillations Check

# %% [markdown]
# ##### Experiment Parameters

# %%
update_global_parameters = True

n_avg_exponent = 16

# TODO
# range of the ef pulse amplitude scan (old amp_min / amp_max / amp_num)
ef_amp_min = 0
ef_amp_max = 1
n_ef_amp = 51
ef_amplitudes = np.linspace(ef_amp_min, ef_amp_max, n_ef_amp)

# old: detuning_ef = 0; drive_ef_Oscillator_q0.frequency =
#      qubit_parameters["qb_ef_freq"] + detuning_ef
ef_detuning = 0.0

# old: gaussian_pulse_qrpm = pulse_library.gaussian(
#          length=qubit_parameters["qb_ef_len_qrpm"], amplitude=1.0)
# length comes from ef_drive_length, the amplitude is the swept quantity.
ef_drive_pulse = {
    'function': 'gaussian',
    'sigma': 0.25,
}
ef_drive_length = qubits[0].parameters.ef_drive_length

qubit_to_measure = qubits[0]

temporary_parameters = {}
temp_pars = deepcopy(qubit_to_measure.parameters)
temp_pars.ef_drive_pulse = ef_drive_pulse
temp_pars.ef_drive_length = ef_drive_length
temp_pars.resonance_frequency_ef = (
    qubit_to_measure.parameters.resonance_frequency_ef + ef_detuning
)
temporary_parameters[qubit_to_measure.uid] = temp_pars

print('ef drive length:            ', temp_pars.ef_drive_length)
print('ef drive pulse:             ', temp_pars.ef_drive_pulse)
print('ef resonance frequency:     ', temp_pars.resonance_frequency_ef * 1e-9, 'GHz')
print('ge drive amplitude pi:      ', temp_pars.ge_drive_amplitude_pi)
print('Reset delay length:         ', temp_pars.reset_delay_length)
print('Readout amplitude:          ', temp_pars.readout_amplitude)
print('Number of averages:         ', 2**n_avg_exponent)

# %% [markdown]
# ##### Run Workflows

# %%
options = rabi_population_experiment_workflow.options()
options.count(2**n_avg_exponent)

exp_workflow = rabi_population_experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=qubit_to_measure.uid,
    ef_amplitudes=ef_amplitudes,
    options=options,
    temporary_parameters=temporary_parameters,
)
workflow_result = exp_workflow.run()

# %% [markdown]
# ##### Analysis Plots

# %%
result = workflow_result.output

# old: rpm_res[key] = {'amp': my_results.get_axis(f"rpm_{key}")[0], ...}
rpm_res = {}
for pre_pulse in ['with', 'wo']:
    data = result[
        dsl.handles.result_handle(qubit_to_measure.uid, suffix=pre_pulse)
    ].data
    rpm_res[pre_pulse] = {
        'amp': ef_amplitudes,
        'mag': np.abs(data),
        'pha': np.unwrap(np.angle(data)),
    }

# %%
rpm_popt, rpm_pcov = {'with': {}, 'wo': {}}, {'with': {}, 'wo': {}}

freq_estimate = 8

for pre_pulse in ['with', 'wo']:
    rpm_popt[pre_pulse]['mag'], rpm_pcov[pre_pulse]['mag'] = fit_rabi_osc(
        x=rpm_res[pre_pulse]['amp'], y=rpm_res[pre_pulse]['mag'],
        freq=freq_estimate, phase=1.0, amp=1.0, off=0.018, plot=False,
    )
    rpm_popt[pre_pulse]['pha'], rpm_pcov[pre_pulse]['pha'] = fit_rabi_osc(
        x=rpm_res[pre_pulse]['amp'], y=rpm_res[pre_pulse]['pha'],
        freq=freq_estimate, phase=1.0, amp=0.01, off=-0.12, plot=False,
    )

rpm_amp_plot = np.linspace(
    rpm_res['with']['amp'][0], rpm_res['with']['amp'][-1],
    int(rpm_res['with']['amp'].shape[0] * 20),
)

# %%
rpm_fig, rpm_ax = plt.subplots(6, 1, figsize=(10, 18), sharex=True)
rpm_fig.suptitle(f'Rabi population measurement - {qubit_to_measure.uid}')

rpm_ax[0].scatter(rpm_res['with']['amp'], rpm_res['with']['mag'])
rpm_ax[0].set_ylabel('Amplitude with pre-pulse')
rpm_ax[0].plot(rpm_amp_plot, func_osc(rpm_amp_plot, *rpm_popt['with']['mag']),
               color='tab:red', linestyle='dashed')

rpm_ax[1].scatter(rpm_res['wo']['amp'], rpm_res['wo']['mag'])
rpm_ax[1].set_ylabel('Amplitude without pre-pulse')
rpm_ax[1].plot(rpm_amp_plot, func_osc(rpm_amp_plot, *rpm_popt['wo']['mag']),
               color='tab:red', linestyle='dashed')

rpm_ax[2].scatter(rpm_res['with']['amp'], rpm_res['with']['pha'])
rpm_ax[2].set_ylabel('Phase with pre-pulse')
rpm_ax[2].plot(rpm_amp_plot, func_osc(rpm_amp_plot, *rpm_popt['with']['pha']),
               color='tab:red', linestyle='dashed')

rpm_ax[3].scatter(rpm_res['wo']['amp'], rpm_res['wo']['pha'])
rpm_ax[3].set_ylabel('Phase without pre-pulse')
rpm_ax[3].plot(rpm_amp_plot, func_osc(rpm_amp_plot, *rpm_popt['wo']['pha']),
               color='tab:red', linestyle='dashed')

_, offset, norm = normalize_1d_osc(rpm_res['with']['mag'])

rpm_ax[4].scatter(rpm_res['with']['amp'],
                  normalize_1d_osc(rpm_res['with']['mag'])[0],
                  label='with', color='salmon')
rpm_ax[4].plot(rpm_amp_plot,
               normalize_1d_osc(func_osc(rpm_amp_plot, *rpm_popt['with']['mag']),
                                offset, norm)[0],
               color='tab:red', linestyle='dashed')
rpm_ax[4].scatter(rpm_res['wo']['amp'],
                  normalize_1d_osc(rpm_res['wo']['mag'], norm=norm)[0],
                  label='w/o', color='skyblue')
rpm_ax[4].set_ylabel('Amplitude (normalized)')
rpm_ax[4].plot(rpm_amp_plot,
               normalize_1d_osc(func_osc(rpm_amp_plot, *rpm_popt['wo']['mag']),
                                norm=norm)[0],
               color='tab:blue', linestyle='dashed')
rpm_ax[4].legend()

_, offset, norm = normalize_1d_osc(rpm_res['with']['pha'])

rpm_ax[5].scatter(rpm_res['with']['amp'],
                  normalize_1d_osc(rpm_res['with']['pha'])[0],
                  label='with', color='salmon')
rpm_ax[5].plot(rpm_amp_plot,
               normalize_1d_osc(func_osc(rpm_amp_plot, *rpm_popt['with']['pha']),
                                offset, norm)[0],
               color='tab:red', linestyle='dashed')
rpm_ax[5].scatter(rpm_res['wo']['amp'],
                  normalize_1d_osc(rpm_res['wo']['pha'], norm=norm)[0],
                  label='w/o', color='skyblue')
rpm_ax[5].set_ylabel('Phase (normalized)')
rpm_ax[5].plot(rpm_amp_plot,
               normalize_1d_osc(func_osc(rpm_amp_plot, *rpm_popt['wo']['pha']),
                                norm=norm)[0],
               color='tab:blue', linestyle='dashed')
rpm_ax[5].legend()

rpm_ax[-1].set_xlabel('ef-amplitude')

file_path = get_path_to_file('RPM_full_amp_sweep_', '.png')
rpm_fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %% [markdown]
# #### Pi Pulse Check

# %% [markdown]
# ##### Analysis Plots

# %%
# extract min / max pulse amplitudes (old cell 346)
signal_in_mag = True

if signal_in_mag:
    fit_params_with = rpm_popt['with']['mag']
    fit_params_wo = rpm_popt['wo']['mag']
    with_dat = rpm_res['with']['mag']
    wo_dat = rpm_res['wo']['mag']
    ylabel = 'Amplitude'
else:
    fit_params_with = rpm_popt['with']['pha']
    fit_params_wo = rpm_popt['wo']['pha']
    with_dat = rpm_res['with']['pha']
    wo_dat = rpm_res['wo']['pha']
    ylabel = 'Phase'

# alternatives, kept from the old notebook:
# amp_with = fit_params_with[1] / fit_params_with[0]
# amp_wo = fit_params_wo[1] / fit_params_wo[0]
# amp_with = rpm_amp_plot[np.argmax(func_osc(rpm_amp_plot, *fit_params_with))]

amp_with = 0.22
amp_wo = amp_with

amp_avg = (amp_with + amp_wo) / 2

cal_fig, cal_axs = plt.subplots(2, 1, figsize=(10, 7), sharex=True)
cal_fig.suptitle(f'RPM ef pi-pulse calibration - {qubit_to_measure.uid}')

cal_axs[0].scatter(rpm_res['wo']['amp'], with_dat)
cal_axs[0].plot(rpm_amp_plot, func_osc(rpm_amp_plot, *fit_params_with),
                color='tab:red', linestyle='dashed')
cal_axs[0].vlines([amp_with], with_dat.min(), with_dat.max(), color='black',
                  linestyle='dashed', label='with')
cal_axs[0].vlines([amp_avg], with_dat.min(), with_dat.max(), color='tab:green',
                  linestyle='dashed', label='avg')
cal_axs[0].vlines([amp_wo], with_dat.min(), with_dat.max(), color='tab:purple',
                  linestyle='dashed', label='wo')
cal_axs[0].legend()
cal_axs[0].set_ylabel(ylabel)
cal_axs[0].set_title('with ge pre pulse')

cal_axs[1].scatter(rpm_res['wo']['amp'], wo_dat)
cal_axs[1].plot(rpm_amp_plot, func_osc(rpm_amp_plot, *fit_params_wo),
                color='tab:red', linestyle='dashed')
cal_axs[1].vlines([amp_with], wo_dat.min(), wo_dat.max(), color='black',
                  linestyle='dashed', label='with')
cal_axs[1].vlines([amp_avg], wo_dat.min(), wo_dat.max(), color='tab:green',
                  linestyle='dashed', label='avg')
cal_axs[1].vlines([amp_wo], wo_dat.min(), wo_dat.max(), color='tab:purple',
                  linestyle='dashed', label='wo')
cal_axs[1].legend()
cal_axs[1].set_xlabel('ef amplitude')
cal_axs[1].set_ylabel(ylabel)
cal_axs[1].set_title('without ge pre pulse')

file_path = get_path_to_file('RPM_x180_ef_calibration_', '.png')
cal_fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %% [markdown]
# ##### Update Parameters

# %%
# old: x180_ef_rpm = pulse_library.gaussian(
#          uid="x180_ef", length=qubit_parameters["qb_ef_len_qrpm"],
#          amplitude=amp_avg)
#      qubit_parameters["pi_ef_amp_qrpm"] = amp_avg
# set to a value != None to override the value extracted above.
manual_ef_drive_amplitude_pi = None
ef_drive_amplitude_pi_rpm = float(amp_avg)
if manual_ef_drive_amplitude_pi is not None:
    ef_drive_amplitude_pi_rpm = float(manual_ef_drive_amplitude_pi)

temporary_parameters[qubit_to_measure.uid].ef_drive_amplitude_pi = (
    ef_drive_amplitude_pi_rpm
)

if update_global_parameters:
    qubit_to_measure.parameters = deepcopy(
        temporary_parameters[qubit_to_measure.uid]
    )
    save(qpu, qpu_file_path)
    print('Updated global experiment parameters!\n')

print('RPM ef drive amplitude pi: ', ef_drive_amplitude_pi_rpm)
print('ef drive amplitude pi (QPU): ',
      qubit_to_measure.parameters.ef_drive_amplitude_pi)

# %% [markdown]
# ### Population Measurement

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

n_avg_exponent = 17

# old: rep_count = 1 of the mock_sweep
repetitions = 5

qubit_to_measure = qubits[0]

# the RPM pi-pulse calibrated above; the rest of the RPM parameters
# (ef_drive_pulse / ef_drive_length / resonance_frequency_ef) is unchanged.
temporary_parameters = {}
temp_pars = deepcopy(qubit_to_measure.parameters)
temp_pars.ef_drive_pulse = ef_drive_pulse
temp_pars.ef_drive_length = ef_drive_length
temp_pars.ef_drive_amplitude_pi = ef_drive_amplitude_pi_rpm
temporary_parameters[qubit_to_measure.uid] = temp_pars

print('ef drive amplitude pi: ', temp_pars.ef_drive_amplitude_pi)
print('Number of averages:    ', 2**n_avg_exponent)
print('Repetitions:           ', repetitions)

# %% [markdown]
# #### Run Workflow

# %%
options = quick_rabi_population_experiment_workflow.options()
options.count(2**n_avg_exponent)

exp_workflow = quick_rabi_population_experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=qubit_to_measure.uid,
    repetitions=repetitions,
    options=options,
    temporary_parameters=temporary_parameters,
)
workflow_result = exp_workflow.run()

# %% [markdown]
# #### Analysis Plots

# %%
result = workflow_result.output

# old: rpm_res[key] = {'mag_min': np.abs(my_results.get_data(f"rpm_{key}_min")), ...}
rpm_res = {}
for pre_pulse in ['with', 'wo']:
    data = {
        point: result[
            dsl.handles.result_handle(qubit_to_measure.uid,
                                      suffix=f'{pre_pulse}_{point}')
        ].data
        for point in ['min', 'max']
    }
    rpm_res[pre_pulse] = {
        'mag_min': np.abs(data['min']),
        'pha_min': np.angle(data['min']),
        'mag_max': np.abs(data['max']),
        'pha_max': np.angle(data['max']),
        'I_max': np.real(data['max']),
        'Q_max': np.imag(data['max']),
        'I_min': np.real(data['min']),
        'Q_min': np.imag(data['min']),
    }

qrpm_dict = qrpm_dict_from_results([rpm_res])

# %%
quick_rpm_fig_iq, quick_rpm_axs_iq = plt.subplots(2, 1, figsize=(10, 12))

quick_rpm_axs_iq[0].scatter(rpm_res['with']['I_max'], rpm_res['with']['Q_max'])
quick_rpm_axs_iq[0].scatter(rpm_res['with']['I_min'], rpm_res['with']['Q_min'])
quick_rpm_axs_iq[0].set_xlabel('I')
quick_rpm_axs_iq[0].set_ylabel('Q')
quick_rpm_axs_iq[0].set_title('Quick RPM with ge pre-pulse')

quick_rpm_axs_iq[1].scatter(rpm_res['wo']['I_max'], rpm_res['wo']['Q_max'])
quick_rpm_axs_iq[1].scatter(rpm_res['wo']['I_min'], rpm_res['wo']['Q_min'])
quick_rpm_axs_iq[1].set_xlabel('I')
quick_rpm_axs_iq[1].set_ylabel('Q')
quick_rpm_axs_iq[1].set_title('Quick RPM without ge pre-pulse')

file_path = get_path_to_file('Quick_RPM_IQ_', '.png')
quick_rpm_fig_iq.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %%
quick_rpm_fig, quick_rpm_axs = plt.subplots(4, 1, figsize=(10, 12), sharex=True)
quick_rpm_fig.suptitle(f'Quick RPM - {qubit_to_measure.uid}')

y_min = np.repeat(0, rpm_res['with']['mag_min'].size)
# old: y_max = np.repeat(x180_ef_rpm.amplitude, ...)
y_max = np.repeat(ef_drive_amplitude_pi_rpm, rpm_res['with']['mag_min'].size)

for axis, pre_pulse, key in zip(
    quick_rpm_axs,
    ['with', 'wo', 'with', 'wo'],
    ['mag', 'mag', 'pha', 'pha'],
):
    axis.scatter(y_min, rpm_res[pre_pulse][f'{key}_min'])
    axis.scatter(y_max, rpm_res[pre_pulse][f'{key}_max'])
    axis.scatter(np.mean(y_min), np.mean(rpm_res[pre_pulse][f'{key}_min']),
                 marker='x', color='black', s=200)
    axis.scatter(np.mean(y_max), np.mean(rpm_res[pre_pulse][f'{key}_max']),
                 marker='x', color='black', s=200)
    axis.plot(rpm_amp_plot, func_osc(rpm_amp_plot, *rpm_popt[pre_pulse][key]),
              color='tab:red', linestyle='dashed')

for axis, ylabel, title in zip(
    quick_rpm_axs,
    ['Amplitude', 'Amplitude', 'Phase', 'Phase'],
    ['with ge pre-pulse', 'without ge pre-pulse',
     'with ge pre-pulse', 'without ge pre-pulse'],
):
    axis.set_ylabel(ylabel)
    axis.set_title(title)

quick_rpm_axs[-1].set_xlabel('ef amplitude')

amps_with_mag = np.abs(rpm_res['with']['mag_min'] - rpm_res['with']['mag_max'])
amps_with_pha = np.abs(rpm_res['with']['pha_min'] - rpm_res['with']['pha_max'])

amps_wo_mag = np.abs(rpm_res['wo']['mag_min'] - rpm_res['wo']['mag_max'])
amps_wo_pha = np.abs(rpm_res['wo']['pha_min'] - rpm_res['wo']['pha_max'])

mean_amps_with_mag = np.mean(amps_with_mag)
mean_amps_with_pha = np.mean(amps_with_pha)

mean_amps_wo_mag = np.mean(amps_wo_mag)
mean_amps_wo_pha = np.mean(amps_wo_pha)

file_path = get_path_to_file('Quick_RPM_', '.png')
quick_rpm_fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %%
max_iq_with = np.column_stack((rpm_res['with']['I_max'], rpm_res['with']['Q_max']))
min_iq_with = np.column_stack((rpm_res['with']['I_min'], rpm_res['with']['Q_min']))
iq_amp_with = np.linalg.norm(max_iq_with - min_iq_with, axis=1)

max_iq_wo = np.column_stack((rpm_res['wo']['I_max'], rpm_res['wo']['Q_max']))
min_iq_wo = np.column_stack((rpm_res['wo']['I_min'], rpm_res['wo']['Q_min']))
iq_amp_wo = np.linalg.norm(max_iq_wo - min_iq_wo, axis=1)

iq_amp_fig, iq_amp_axs = plt.subplots(2, 1, figsize=(10, 8))
iq_amp_fig.suptitle(f'Quick RPM IQ distances - {qubit_to_measure.uid}')
iq_amp_axs[0].plot(iq_amp_with, marker='o')
iq_amp_axs[0].set_ylabel('with pre-pulse')
iq_amp_axs[1].plot(iq_amp_wo, marker='o')
iq_amp_axs[1].set_ylabel('without pre-pulse')
iq_amp_axs[1].set_xlabel('Measurement')

# %% [markdown]
# ### Temperature

# %% [markdown]
# #### Analysis Plots

# %%
f_q, anharm = get_qubit_temperature_parameters(qubit_to_measure)
print('f_q:   ', f_q, 'GHz')
print('anharm:', anharm, 'GHz')

# old: rpm_pe = amps_wo_mag / (amps_with_mag + amps_wo_mag)
rpm_pe = iq_amp_wo / (iq_amp_wo + iq_amp_with)

rpm_temp = T_calc(C=rpm_pe / (1 - rpm_pe), f_q=f_q)

quick_rpm_temps_fig, quick_rpm_temps_axs = plt.subplots(figsize=(15, 5))
quick_rpm_temps_axs.plot(np.arange(len(rpm_pe)), rpm_temp, marker='o')
quick_rpm_temps_axs.hlines([np.mean(rpm_temp)], 0, len(rpm_pe), color='black',
                           linestyle='dashed', label='average')
quick_rpm_temps_axs.set_ylabel('temp (K)')
quick_rpm_temps_axs.set_xlabel('Measurement')
quick_rpm_temps_axs.set_title(
    f'Quick Rabi Population Measurement - {qubit_to_measure.uid}'
)
quick_rpm_temps_axs.legend()

quick_rpm_temps_hist_fig, quick_rpm_temps_hist_ax = plt.subplots()
quick_rpm_temps_hist_ax.hist(rpm_temp, bins=75)
quick_rpm_temps_hist_ax.set_xlabel('Temperature')
quick_rpm_temps_hist_ax.set_ylabel('Counts')
quick_rpm_temps_hist_ax.set_title(
    f'Quick Rabi Population Measurement - {qubit_to_measure.uid}'
)

print('Mean pe:          ', np.mean(rpm_pe))
print('Mean temperature: ', np.mean(rpm_temp) * 1e3, 'mK')

file_path = get_path_to_file('Quick_RPM_temperature_', '.png')
quick_rpm_temps_fig.savefig(file_path, dpi=600, format='png',
                            bbox_inches='tight')

# %% [markdown]
# #### Update Parameters

# %%
data_rpm = {
    'ef_amplitude_sweep': ef_amplitudes,
    'rpm_mag_with': rpm_res['with']['mag_max'],
    'rpm_mag_wo': rpm_res['wo']['mag_max'],
    'iq_amp_with': iq_amp_with,
    'iq_amp_wo': iq_amp_wo,
    'rpm_pe': rpm_pe,
    'rpm_temp': rpm_temp,
    'ef_drive_amplitude_pi_rpm': ef_drive_amplitude_pi_rpm,
    'n_shots': 2**n_avg_exponent,
    'repetitions': repetitions,
    'f_q': f_q,
    'anharm': anharm,
    'comment': 'Quick Rabi population measurement, temperature in K',
}
data_rpm.update(qrpm_dict)
data_rpm.update(
    {k: v for k, v in attrs.asdict(qubit_to_measure.parameters).items()
     if isinstance(v, (int, float, str))}
)
data_rpm['sample_name'] = sample_name
data_rpm['qubit_name'] = qubit_name
data_rpm['cooldown_start_date'] = cooldown_start_date

file_path = get_path_to_file('RPM_temperature_', '.mat')
savemat(file_path, data_rpm)
print(f'Saved Rabi population measurement to: {file_path}')

# %% [markdown]
# ## Three Level Population Measurements

# %% [markdown]
# ### Single-Point Experiment

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

n_avg_exponent = 15

qubit_to_measure = qubits[0]

# old: readout_opt / readout_low passed to create_exp_population_full
temporary_parameters = {}
temp_pars = deepcopy(qubit_to_measure.parameters)
temporary_parameters[qubit_to_measure.uid] = temp_pars

print('ge drive amplitude pi:      ', temp_pars.ge_drive_amplitude_pi)
print('ef drive amplitude pi:      ', temp_pars.ef_drive_amplitude_pi)
print('Readout amplitude:          ', temp_pars.readout_amplitude)
print('Readout length:             ', temp_pars.readout_length)
print('Readout resonator frequency:', temp_pars.readout_resonator_frequency)
print('Reset delay length:         ', temp_pars.reset_delay_length)
print('Number of averages:         ', 2**n_avg_exponent)

# %% [markdown]
# #### Run Workflow

# %%
options = population_experiment_workflow.options()
options.count(2**n_avg_exponent)

exp_workflow = population_experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=qubit_to_measure.uid,
    options=options,
    temporary_parameters=temporary_parameters,
)
workflow_result = exp_workflow.run()

# %% [markdown]
# #### Analysis Plots

# %%
# old: print(results_population_full.get_data('x0_readout'))
pop_result = collect_population_from_result(
    workflow_result.output, qubit_to_measure.uid
)
for label in pop_label_list:
    print(f'{label}: {pop_result[label]}')

# %% [markdown]
# ### Population Statistics

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = True

n_avg_exponent = 15

# old: N = 3 #Number of measurements
n_measurements = 3

# estimators that are excluded from the plots (old `skip = ['TC2']`)
skip = ['TC2']

three_levels = True

qubit_to_measure = qubits[0]

temporary_parameters = {}
temp_pars = deepcopy(qubit_to_measure.parameters)
temporary_parameters[qubit_to_measure.uid] = temp_pars

f_q, anharm = get_qubit_temperature_parameters(qubit_to_measure)
print('f_q:               ', f_q, 'GHz')
print('anharm:            ', anharm, 'GHz')
print('Number of averages:', 2**n_avg_exponent)
print('Number of runs:    ', n_measurements)

# %% [markdown]
# #### Run Workflow

# %%
options = population_experiment_workflow.options()
options.count(2**n_avg_exponent)

pop_full_results = {}
pop_workflow_results = []

for i in range(n_measurements):
    print('Iteration: ', i)

    exp_workflow = population_experiment_workflow(
        session=session,
        qpu=qpu,
        qubit=qubit_to_measure.uid,
        options=options,
        temporary_parameters=temporary_parameters,
    )
    workflow_result = exp_workflow.run()
    pop_workflow_results.append(workflow_result)

    pop_result = collect_population_from_result(
        workflow_result.output, qubit_to_measure.uid
    )
    for label in pop_label_list:
        pop_full_results.setdefault(label, []).append(pop_result[label])

for label in pop_label_list:
    pop_full_results[label] = np.array(pop_full_results[label])

print('Population array shape (runs,):', pop_full_results['x0'].shape)

# %% [markdown]
# #### Analysis Plots

# %%
# fast temperature extraction (projection onto I and Q at phase 0)
TABC_I, TABC_Q = make_all_temperatures(pop_full_results, f_q, anharm,
                                       three_levels=three_levels)

fig, ax = plot_temperatures(TABC_I, TABC_Q, skip=skip)

file_path = get_path_to_file('Population_stat_', '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %%
STAT_I = get_stat(TABC_I)
STAT_Q = get_stat(TABC_Q)

# give plot_stat copies so it cannot modify the original statistis
STAT_I_plot = {k: v.copy() for k, v in STAT_I.items()}
STAT_Q_plot = {k: v.copy() for k, v in STAT_Q.items()}

fig, ax = plot_stat(STAT_I_plot, STAT_Q_plot)

for k in STAT_I:
    print(k, '| I mean:', np.round(STAT_I[k][0], 3),
          'rel. err:', np.round(STAT_I[k][2], 4),
          '| Q mean:', np.round(STAT_Q[k][0], 3),
          'rel. err:', np.round(STAT_Q[k][2], 4))

file_path = get_path_to_file('Population_stat_bars_', '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %%
# population, 3-level method, proper rotation ('parallel' approach)
ABC = get_ABC_parallel(pop_full_results)
TABC = get_temperature(ABC, f_q, anharm, three_levels=three_levels)

fig, ax = plot_temp_single(TABC, skip=skip)

STAT = get_stat(TABC)
fig_stat, ax_stat = plot_stat(STAT, STAT)

file_path = get_path_to_file('Population_stat_parallel_', '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %%
fig, ax = plt.subplots()
ax.set_title(f'Population measurements on the IQ plane - {qubit_to_measure.uid}')
for label in pop_label_list:
    ax.plot(pop_full_results[label].real, pop_full_results[label].imag, 'o-',
            label=label)
ax.set_xlabel('Real part, a.u.')
ax.set_ylabel('Imaginary part, a.u.')
ax.legend()

file_path = get_path_to_file('Population_stat_IQ_', '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %%
# pe/pg and temperature per estimator, written out explicitly (old cells
# 407-410). `get_C_from_ABC` does the same for a whole ABC dictionary.
A_real = ((pop_full_results['x0'].real - pop_full_results['x1'].real)
          / (pop_full_results['y0'].real - pop_full_results['y1'].real))
A_imag = ((pop_full_results['x0'].imag - pop_full_results['x1'].imag)
          / (pop_full_results['y0'].imag - pop_full_results['y1'].imag))

B_real = ((pop_full_results['x1'].real - pop_full_results['y1'].real)
          / (pop_full_results['y0'].real - pop_full_results['x2'].real))
B_imag = ((pop_full_results['x1'].imag - pop_full_results['y1'].imag)
          / (pop_full_results['y0'].imag - pop_full_results['x2'].imag))

C_real = ((pop_full_results['x0'].real - pop_full_results['y0'].real)
          / (pop_full_results['x1'].real - pop_full_results['x2'].real))
C_imag = ((pop_full_results['x0'].imag - pop_full_results['y0'].imag)
          / (pop_full_results['x1'].imag - pop_full_results['x2'].imag))

fig, ax = plt.subplots()
ax.plot(C_real, '-o', label='C_Q')
ax.plot(C_imag, '-o', label='C_I')
ax.plot(1 - A_real, '-o', label='A_Q')
ax.plot(1 - A_imag, '-o', label='A_I')
ax.plot(B_real / (B_real + 1), '-o', label='B_Q')
ax.plot(B_imag / (B_imag + 1), '-o', label='B_I')
ax.set_xlabel('Experiment number')
ax.set_ylabel('$p_e/p_g$')
ax.legend()

print('Mean pe/pg C_real:', np.mean(C_real) * 1e2)
print('Mean pe/pg C_imag:', np.mean(C_imag) * 1e2)
print('Mean pe/pg A_real:', np.mean(1 - A_real) * 1e2)
print('Mean pe/pg A_imag:', np.mean(1 - A_imag) * 1e2)
print('Mean pe/pg B_real:', np.mean(B_real / (B_real + 1)) * 1e2)
print('Mean pe/pg B_imag:', np.mean(B_imag / (B_imag + 1)) * 1e2)

T_A_real = T_calc(1 - A_real, f_q) * 1e3
T_A_imag = T_calc(1 - A_imag, f_q) * 1e3
T_B_real = T_calc(B_real / (B_real + 1), f_q) * 1e3
T_B_imag = T_calc(B_imag / (B_imag + 1), f_q) * 1e3
T_C_real = T_calc(C_real, f_q) * 1e3
T_C_imag = T_calc(C_imag, f_q) * 1e3

fig, ax = plt.subplots()
ax.plot(T_A_real, '-o', label='A_Q', color='red')
ax.plot(T_A_imag, '-D', mfc='w', label='A_I', color='red')
ax.plot(T_B_real, '-o', label='B_Q', color='blue')
ax.plot(T_B_imag, '-D', mfc='w', label='B_I', color='blue')
ax.plot(T_C_real, '-o', label='C_Q', color='green')
ax.plot(T_C_imag, '-D', mfc='w', label='C_I', color='green')
ax.set_xlabel('Experiment number')
ax.set_ylabel('T_eff, mK')
ax.axhline(100, linestyle='dashed', color='grey')
ax.axhspan(90, 110, color='lightgrey')
ax.legend()

file_path = get_path_to_file('Population_stat_temperatures_', '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %% [markdown]
# #### Update Parameters

# %%
# old: Data_T_stat.update(pop_full_results);
#      Data_T_stat.update(qubit_parameters._params);
#      Data_T_stat.update(lo_settings._params)
data_t_stat = {f'pop_{label}': pop_full_results[label]
               for label in pop_label_list}
data_t_stat.update({f'{k}_I': v for k, v in TABC_I.items()})
data_t_stat.update({f'{k}_Q': v for k, v in TABC_Q.items()})
data_t_stat.update({f'{k}_parallel': v for k, v in TABC.items()})
data_t_stat.update({
    'T_A_real': T_A_real,
    'T_A_imag': T_A_imag,
    'T_B_real': T_B_real,
    'T_B_imag': T_B_imag,
    'T_C_real': T_C_real,
    'T_C_imag': T_C_imag,
    'n_measurements': n_measurements,
    'n_shots': 2**n_avg_exponent,
    'f_q': f_q,
    'anharm': anharm,
    'three_levels': three_levels,
    'comment': ('Three level population statistics, array dim [run]; '
                'temperatures in mK'),
})
data_t_stat.update(
    {k: v for k, v in attrs.asdict(qubit_to_measure.parameters).items()
     if isinstance(v, (int, float, str))}
)
data_t_stat['sample_name'] = sample_name
data_t_stat['qubit_name'] = qubit_name
data_t_stat['cooldown_start_date'] = cooldown_start_date

file_path = get_path_to_file('Teff_stat_all_unsh_', '.mat')
savemat(file_path, data_t_stat)
print(f'Saved population statistics to: {file_path}')

# %% [markdown]
# ### Rotation and Measurement Optimisation

# %% [markdown]
# #### Experiment Parameters

# %%
# No new experiment is run here: the projection phase of the data acquired in
# `### Population Statistics` is optimized.
phase_arr = np.linspace(-1, 1, 65) * np.pi / 2

# estimators that are excluded from the optimization (old skip = ['TA1','TA3'])
skip_optimization = ['TA1', 'TA3']

# optional: use only a slice of the runs (old `pop_slice`)
# pop_slice = {k: v[1:33] for k, v in pop_full_results.items()}
pop_data = pop_full_results

# %% [markdown]
# #### Analysis Plots

# %%
STAT_I, STAT_Q = make_rotation_temperature(pop_data, phase_arr, f_q, anharm,
                                           three_levels=three_levels)

for info_type in ['mean', 'error', 'rel_err']:
    fig, ax = plot_rotation_stat(phase_arr, STAT_I, STAT_Q,
                                 info_type=info_type)
    file_path = get_path_to_file(f'Population_rotation_{info_type}_', '.png')
    fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %%
for k in STAT_I:
    print('For', k)
    print('  I: min rel. err:', np.nanmin(STAT_I[k][:, 2]),
          'at phase point', np.nanargmin(STAT_I[k][:, 2]))
    print('  Q: min rel. err:', np.nanmin(STAT_Q[k][:, 2]),
          'at phase point', np.nanargmin(STAT_Q[k][:, 2]))

# %%
optimal_method = make_optimal_temperature(pop_data, phase_arr, f_q, anharm,
                                          skip=skip_optimization,
                                          three_levels=three_levels)
pprint(optimal_method)

Teff = find_optimal_temperature(pop_data, optimal_method, f_q, anharm,
                                three_levels=three_levels)

fig, ax = plt.subplots()
ax.plot(Teff, 'o-')
ax.set_xlabel('Experiment number')
ax.set_ylabel('T_eff, mK')
ax.set_title(f"Optimal method {optimal_method['method']} "
             f"({optimal_method['axes']}) - {qubit_to_measure.uid}")

print('Mean optimal temperature:', np.nanmean(Teff), 'mK')

file_path = get_path_to_file('Population_optimal_temperature_', '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %% [markdown]
# !stop here

# %%
# statistics at a single (zero) phase, for comparison
STAT_I_0, STAT_Q_0 = make_rotation_temperature(pop_data, [0], f_q, anharm,
                                               three_levels=three_levels)

# give plot_stat copies so it cannot modify the original statistis
STAT_I_0_plot = {k: v.copy() for k, v in STAT_I_0.items()}
STAT_Q_0_plot = {k: v.copy() for k, v in STAT_Q_0.items()}

fig, ax = plot_stat(STAT_I_0_plot, STAT_Q_0_plot)

# %% [markdown]
# #### Update Parameters

# %%
data_t_opt = {
    'phase_arr': phase_arr,
    'optimal_phase': optimal_method['phase'],
    'optimal_method': optimal_method['method'],
    'optimal_axes': optimal_method['axes'],
    'optimal_rel_err': optimal_method['rel_err'],
    'Teff': Teff,
    'f_q': f_q,
    'anharm': anharm,
    'comment': 'Projection-phase optimization of the population statistics',
}
data_t_opt.update({f'STAT_{k}_I': v for k, v in STAT_I.items()})
data_t_opt.update({f'STAT_{k}_Q': v for k, v in STAT_Q.items()})
data_t_opt.update(
    {k: v for k, v in attrs.asdict(qubit_to_measure.parameters).items()
     if isinstance(v, (int, float, str))}
)
data_t_opt['sample_name'] = sample_name
data_t_opt['qubit_name'] = qubit_name
data_t_opt['cooldown_start_date'] = cooldown_start_date

file_path = get_path_to_file('Teff_rotation_optimization_', '.mat')
savemat(file_path, data_t_opt)
print(f'Saved rotation optimization to: {file_path}')

# %% [markdown]
# ### Population with Prepulse

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = False

n_avg_exponent = 17

qubit_to_measure = qubits[0]

# range of the ge pre-pulse amplitude scan (old amp_min / amp_max / amp_num)
prepulse_amp_min = 0
prepulse_amp_max = qubit_to_measure.parameters.ge_drive_amplitude_pi
n_prepulse_amp = 51
prepulse_amplitudes = np.linspace(prepulse_amp_min, prepulse_amp_max,
                                  n_prepulse_amp)

# old: gaussian_pulse = pulse_library.gaussian(
#          length=qubit_parameters["qb_len"], amplitude=1.0)
ge_drive_pulse = {
    'function': 'gaussian',
    'sigma': 0.25,
}

temporary_parameters = {}
temp_pars = deepcopy(qubit_to_measure.parameters)
temp_pars.ge_drive_pulse = ge_drive_pulse
temporary_parameters[qubit_to_measure.uid] = temp_pars

print('ge drive pulse:        ', temp_pars.ge_drive_pulse)
print('ge drive length:       ', temp_pars.ge_drive_length)
print('ge drive amplitude pi: ', temp_pars.ge_drive_amplitude_pi)
print('Number of averages:    ', 2**n_avg_exponent)

# %% [markdown]
# #### Run Workflow

# %%
options = population_experiment_workflow.options()
options.count(2**n_avg_exponent)

exp_workflow = population_experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=qubit_to_measure.uid,
    prepulse_amplitudes=prepulse_amplitudes,
    options=options,
    temporary_parameters=temporary_parameters,
)
workflow_result = exp_workflow.run()

# %% [markdown]
# #### Analysis Plots

# %%
# old: pulse_amp = results_population_prepulse.get_axis("x0_readout")[0]
pulse_amp = prepulse_amplitudes

pop_prepulse_results = collect_population_from_result(
    workflow_result.output, qubit_to_measure.uid
)

# convenience aliases matching the old variable names
x0 = pop_prepulse_results['x0']
x1 = pop_prepulse_results['x1']
x2 = pop_prepulse_results['x2']
y0 = pop_prepulse_results['y0']
y1 = pop_prepulse_results['y1']
y2 = pop_prepulse_results['y2']

fig, ax = plt.subplots()
ax.plot(pulse_amp,
        (abs(x0) - np.min(abs(x0))) / (np.max(abs(x0)) - np.min(abs(x0))),
        'o-')
ax.set_xlabel('Pre-pulse amplitude, a.u.')
ax.set_ylabel('Normalized $|x0|$')
ax.set_title(f'Population with pre-pulse - {qubit_to_measure.uid}')

# %%
A_real = (x0.real - x1.real) / (y0.real - y1.real)
A_imag = (x0.imag - x1.imag) / (y0.imag - y1.imag)

B_real = (x1.real - y1.real) / (y0.real - x2.real)
B_imag = (x1.imag - y1.imag) / (y0.imag - x2.imag)

C_real = (x0.real - y0.real) / (x1.real - x2.real)
C_imag = (x0.imag - y0.imag) / (x1.imag - x2.imag)

pe0 = 1 - A_real[0]
print('Residual excited population at zero pre-pulse amplitude:', pe0)

fig, ax = plt.subplots()
# ax.plot(pulse_amp, C_real, '-o', label='C_Q')
# ax.plot(pulse_amp, C_imag, '-o', label='C_I')
ax.plot(pulse_amp, 1 - A_real, '-o', label='A_Q')
# ax.plot(pulse_amp, 1 - A_imag, '-o', label='A_I')
ax.plot(pulse_amp, B_real / (B_real + 1), '-o', label='B_Q')
# ax.plot(pulse_amp, B_imag / (B_imag + 1), '-o', label='B_I')

pe = (abs(x0) - np.min(abs(x0))) / (np.max(abs(x0)) - np.min(abs(x0)))
pe_sh = (1 - 2 * pe0) * pe + pe0
ax.plot(pulse_amp, pe_sh / (1 - pe_sh), '-')

ax.set_xlabel('Pre-pulse amplitude, a.u.')
ax.set_ylabel('$p_e/p_g$')
ax.set_ylim(0.0, 1.0)
ax.legend()

file_path = get_path_to_file('Population_prepulse_', '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %% [markdown]
# #### Update Parameters

# %%
data_pop_prep = {f'pop_{label}': pop_prepulse_results[label]
                 for label in pop_label_list}
data_pop_prep.update({
    'prepulse_amplitude_sweep': pulse_amp,
    'pe0': pe0,
    'n_shots': 2**n_avg_exponent,
    'comment': ('Three level population vs. ge pre-pulse amplitude, array dim '
                '[prepulse_amplitude]'),
})
data_pop_prep.update(
    {k: v for k, v in attrs.asdict(qubit_to_measure.parameters).items()
     if isinstance(v, (int, float, str))}
)
data_pop_prep['sample_name'] = sample_name
data_pop_prep['qubit_name'] = qubit_name
data_pop_prep['cooldown_start_date'] = cooldown_start_date

file_path = get_path_to_file('Population_prep_', '.mat')
savemat(file_path, data_pop_prep)
print(f'Saved population with pre-pulse to: {file_path}')

# %% [markdown]
# ## Population Measurements for Different Readout Frequencies

# %% [markdown]
# The three-level protocol repeated for a range of readout resonator
# frequencies. Every frequency needs its own compilation, so this is slow.

# %% [markdown]
# #### Experiment Parameters

# %%
update_global_parameters = False

n_avg_exponent = 12

# frequency range around the current readout resonator frequency
freq_range = 10e6
n_points = 25

qubit_to_measure = qubits[0]

# old: ro_freq_arr = np.linspace(qubit_parameters["ro_freq"] - spec_range / 2,
#                                qubit_parameters["ro_freq"] + spec_range / 2,
#                                spec_num)
readout_resonator_frequency_arr = (
    qubit_to_measure.parameters.readout_resonator_frequency
    + np.linspace(-freq_range / 2, freq_range / 2, n_points)
)

# old readout_i dict: readout_range / readout_delay / relax_time
readout_range_out = -25
readout_integration_delay = qubit_to_measure.parameters.readout_integration_delay

print('Readout resonator frequencies: ',
      readout_resonator_frequency_arr[0] * 1e-9, '...',
      readout_resonator_frequency_arr[-1] * 1e-9, 'GHz')
print('Number of averages:            ', 2**n_avg_exponent)

# %% [markdown]
# #### Run Workflow

# %%
options = population_experiment_workflow.options()
options.count(2**n_avg_exponent)

pop_i_results = {}

for readout_resonator_frequency in readout_resonator_frequency_arr:
    print('Readout resonator frequency:',
          round(readout_resonator_frequency * 1e-9, 6), 'GHz')

    temporary_parameters = {}
    temp_pars = deepcopy(qubit_to_measure.parameters)
    temp_pars.readout_resonator_frequency = float(readout_resonator_frequency)
    temp_pars.readout_range_out = readout_range_out
    temp_pars.readout_integration_delay = readout_integration_delay
    temporary_parameters[qubit_to_measure.uid] = temp_pars

    exp_workflow = population_experiment_workflow(
        session=session,
        qpu=qpu,
        qubit=qubit_to_measure.uid,
        options=options,
        temporary_parameters=temporary_parameters,
    )
    workflow_result = exp_workflow.run()

    pop_result = collect_population_from_result(
        workflow_result.output, qubit_to_measure.uid
    )
    for label in pop_label_list:
        pop_i_results.setdefault(label, []).append(pop_result[label])

for label in pop_label_list:
    pop_i_results[label] = np.array(pop_i_results[label])

print('Population array shape (frequencies,):', pop_i_results['x0'].shape)

# %% [markdown]
# #### Analysis Plots

# %%
fig, ax = plt.subplots()
ax.set_title(f'Population vs. readout frequency: IQ - {qubit_to_measure.uid}')
ax.plot(pop_i_results['x0'].real, pop_i_results['x0'].imag, label='x0')
ax.plot(pop_i_results['x1'].real, pop_i_results['x1'].imag, label='x1')
ax.set_xlabel('Real part, a.u.')
ax.set_ylabel('Imaginary part, a.u.')
ax.legend()

fig, ax = plt.subplots(2, 1, sharex=True, figsize=(10, 8))
fig.suptitle(f'Population vs. readout frequency - {qubit_to_measure.uid}')
fig.supxlabel('Readout resonator frequency, GHz')

ax[0].plot(readout_resonator_frequency_arr * 1e-9,
           np.abs(pop_i_results['x0'] - pop_i_results['x1']), 'o-',
           label='|x0 - x1|')
ax[0].set_ylabel('Signal distance, a.u.')
ax[0].legend()

ax[1].plot(readout_resonator_frequency_arr * 1e-9,
           np.unwrap(np.angle(pop_i_results['x0']))
           - np.unwrap(np.angle(pop_i_results['x1'])), 'o-',
           label='phase(x0) - phase(x1)')
ax[1].plot(readout_resonator_frequency_arr * 1e-9,
           np.unwrap(np.angle(pop_i_results['x0']))
           - np.unwrap(np.angle(pop_i_results['y0'])), 'o-',
           label='phase(x0) - phase(y0)')
ax[1].set_ylabel('Phase difference, rad')
ax[1].legend()

file_path = get_path_to_file('Population_vs_ro_freq_', '.png')
fig.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %%
# fast temperature extraction per readout frequency
skip = ['TC3']

TABC_I, TABC_Q = make_all_temperatures(pop_i_results, f_q, anharm,
                                       three_levels=three_levels)

fig, ax = plot_temperatures(TABC_I, TABC_Q, skip=skip)

fig_i, ax_i = plt.subplots(1, 2, sharey=True, figsize=(12, 5))
fig_i.suptitle(f'Temperature vs. readout frequency - {qubit_to_measure.uid}')
for k in TABC_I:
    ax_i[0].plot(readout_resonator_frequency_arr * 1e-9, TABC_I[k], label=k)
    ax_i[1].plot(readout_resonator_frequency_arr * 1e-9, TABC_Q[k], label=k)
ax_i[0].set_title('I component')
ax_i[1].set_title('Q component')
for axis in ax_i:
    axis.set_xlabel('Readout resonator frequency, GHz')
    axis.set_ylim(0, 200)
    axis.legend()
ax_i[0].set_ylabel('Effective temperature, mK')

fig_iq, ax_iq = plt.subplots()
ax_iq.set_title(f'Temperature I vs. Q - {qubit_to_measure.uid}')
for k in TABC_I:
    ax_iq.plot(TABC_I[k], TABC_Q[k], 'o', label=k)
ax_iq.set_xlim(0, 200)
ax_iq.set_ylim(0, 200)
ax_iq.set_xlabel('T_eff (I), mK')
ax_iq.set_ylabel('T_eff (Q), mK')
ax_iq.legend()

STAT_I = get_stat_nan(TABC_I)
STAT_Q = get_stat_nan(TABC_Q)
fig_stat, ax_stat = plot_stat(STAT_I, STAT_Q)

file_path = get_path_to_file('Population_vs_ro_freq_temperature_', '.png')
fig_i.savefig(file_path, dpi=600, format='png', bbox_inches='tight')

# %% [markdown]
# #### Update Parameters

# %%
data_pop_ro_freq = {f'pop_{label}': pop_i_results[label]
                    for label in pop_label_list}
data_pop_ro_freq.update({f'{k}_I': v for k, v in TABC_I.items()})
data_pop_ro_freq.update({f'{k}_Q': v for k, v in TABC_Q.items()})
data_pop_ro_freq.update({
    'readout_resonator_frequency_sweep': readout_resonator_frequency_arr,
    'readout_range_out': readout_range_out,
    'readout_integration_delay': readout_integration_delay,
    'n_shots': 2**n_avg_exponent,
    'f_q': f_q,
    'anharm': anharm,
    'comment': ('Three level population vs. readout resonator frequency, array '
                'dim [readout_resonator_frequency]; temperatures in mK'),
})
data_pop_ro_freq.update(
    {k: v for k, v in attrs.asdict(qubit_to_measure.parameters).items()
     if isinstance(v, (int, float, str))}
)
data_pop_ro_freq['sample_name'] = sample_name
data_pop_ro_freq['qubit_name'] = qubit_name
data_pop_ro_freq['cooldown_start_date'] = cooldown_start_date

file_path = get_path_to_file('Population_vs_ro_freq_', '.mat')
savemat(file_path, data_pop_ro_freq)
print(f'Saved population vs. readout frequency to: {file_path}')

# %%
# set to a value != None to move the readout to the frequency with the lowest
# temperature spread (old notebook did this by hand).
manual_readout_resonator_frequency = None

# spread of the estimators at every readout frequency, as a figure of merit
temperature_matrix = np.array(
    [TABC_I[k] for k in TABC_I if k not in skip], dtype=float
)
rel_err_vs_freq = np.abs(
    np.nanstd(temperature_matrix, axis=0) / np.nanmean(temperature_matrix, axis=0)
)
optimal_index = int(np.nanargmin(rel_err_vs_freq))
readout_resonator_frequency_opt = float(
    readout_resonator_frequency_arr[optimal_index]
)
if manual_readout_resonator_frequency is not None:
    readout_resonator_frequency_opt = float(manual_readout_resonator_frequency)

print('Optimal readout resonator frequency:',
      round(readout_resonator_frequency_opt * 1e-9, 6), 'GHz',
      '(index', optimal_index, ')')

if update_global_parameters:
    temp_pars = deepcopy(qubit_to_measure.parameters)
    temp_pars.readout_resonator_frequency = readout_resonator_frequency_opt
    qubit_to_measure.parameters = temp_pars
    save(qpu, qpu_file_path)
    print('Updated global experiment parameters!\n')

print('Readout resonator frequency: ',
      qubit_to_measure.parameters.readout_resonator_frequency * 1e-9, ' GHz')

# %%
qubits[0].parameters
